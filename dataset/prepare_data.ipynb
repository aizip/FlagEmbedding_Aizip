# %% [markdown]
# # Preparing Data for BEIR Evaluation

# %% [markdown]
# ## Load corpus, queries, and mapping (qrels)

# %%
import json

# %%
with open("/home/jinho/softbank_rag/dataset/sb_full_train_answer_to_questions.json", "r") as f:
    sb_full = json.load(f)

# %%
corpus_len = len(sb_full)
corpus_len
# Out:
# 1701

# %%
corpus = list(sb_full.keys())

# %%
queries = []
query_to_corpus = {}
for c in sb_full:
    for q in sb_full[c]:
        if q not in queries:
            queries.append(q)
            query_to_corpus[q] = c

# %%
query_len = len(queries)
query_len
# Out:
# 10607

# %%
qrels_len = len(query_to_corpus)
assert qrels_len == query_len

# %% [markdown]
# ## Transform dataset into corresponding formats

# %%
queries_l = []
query_to_id = {}
for i in range(len(queries)):
    qid = str(i)
    queries_l.append({"id": qid, "text": queries[i]})
    query_to_id[queries[i]] = qid

# %%
queries_l
# Out:
# [{'id': '0', 'text': 'ゲストのアカウントの有効期限が切れた場合の対応方法を教えて欲しい'},
#  {'id': '1', 'text': 'ゲストのアカウントの有効期限が切れている'},
#  {'id': '2', 'text': 'ゲストアカウントの有効期限が切れたので、再度、有効にして欲しい'},
#  {'id': '3', 'text': 'ゲストアカウントの有効期限を再度有効にしたい'},
#  {'id': '4', 'text': 'WHCについて問い合わせしたい'},
#  {'id': '5', 'text': 'WHCの工数入力について教えてほしい'},
#  {'id': '6', 'text': 'Trinity(WHC)のアドレスを教えてください。'},
#  {'id': '7', 'text': 'WHC申請方法を教えて欲しい'},
#  {'id': '8', 'text': 'WHCの申請をしたい'},
#  {'id': '9', 'text': 'WHCの申請方法を確認したい'},
#  {'id': '10', 'text': '研修はWHCにどのように登録すればよいか？'},
#  {'id': '11', 'text': 'WHCはどのように申請したらいいでしょうか？'},
#  {'id': '12', 'text': 'WHCについて'},
#  {'id': '13', 'text': 'WHCについて問い合わせしたい。'},
#  {'id': '14', 'text': 'Chromeの動作がおかしいので再インストールしたい'},
#  {'id': '15', 'text': '準OAPCでGoogleChromeが起動しなくなりました'},
#  {'id': '16', 'text': 'Chromeをダウングレードしたい'},
#  {'id': '17', 'text': 'Chromeの再インストール方法が知りたい'},
#  {'id': '18', 'text': 'GoogleChromeをインストールしたい'},
#  {'id': '19', 'text': '準OAPCへChromeをインストールしたい'},
#  {'id': '20', 'text': '準OAPCへChromeを設定したい'},
#  {'id': '21', 'text': 'GoogleChromeのインストールが失敗してしまった。'},
#  {'id': '22', 'text': 'Chromeのインストール方法がわかりません。'},
#  {'id': '23', 'text': 'Chromeのアンインストール方法を教えて欲しい'},
#  {'id': '24', 'text': 'データのPDF化が出来ない'},
#  {'id': '25', 'text': 'ファイル等のPDF化について'},
#  {'id': '26', 'text': 'Word文書をPDFに変換したい'},
#  {'id': '27', 'text': 'PDF化の手順を教えて欲しい'},
#  {'id': '28', 'text': 'PC故障により新しいPCに交換になりました。\n資料をPDF化する方法について推奨方法はあるのでしょうか。'},
#  {'id': '29', 'text': 'ExcelなどのファイルをPDF化したい'},
#  {'id': '30', 'text': 'エクセルをPDF化したい'},
#  {'id': '31', 'text': 'PDF化の方法を教えて欲しい'},
#  {'id': '32',
#   'text': 'GooglePlay未登録アプリのインストール時、「インストールはブロックされました\u3000携帯端末のセキュリティ上の設定で供給元不明のApplicationのインストールをブロックしています」とエラーが表示されました。「提供元不明アプリ」にチェックを入れてもよいでしょうか。'},
#  {'id': '33',
#   'text': 'GooglePlay未登録アプリのインストール時、「インストールはブロックされました\u3000携帯端末のセキュリティ上の設定で供給元不明のApplicationのインストールをブロックしています」とエラーが表示されます。'},
#  {'id': '34', 'text': '供給元不明のGooglePlayアプリをインストールする方法を教えてください。'},
#  {'id': '35',
#   'text': 'GooglePlay未登録のアプリをインストールしたいが、「インストールはブロックされました\u3000携帯端末のセキュリティ上の設定で供給元不明のApplicationのインストールをブロックしています」とエラーが表示される。'},
#  {'id': '36',
#   'text': 'GooglePlayアプリをインストールしようとすると、「インストールはブロックされました\u3000携帯端末のセキュリティ上の設定で供給元不明のApplicationのインストールをブロックしています」と表示されます。'},
#  {'id': '37', 'text': 'iPhone/iPadのバックアップ方法を教えてください。'},
#  {'id': '38', 'text': 'iCloudにバックアップがある確認したいが設定の中にiCloudがありません。'},
#  {'id': '39', 'text': 'iCloudのバックアップ方法を教えてください。'},
#  {'id': '40', 'text': 'iCloudのバックアップができない'},
#  {'id': '41', 'text': 'iCloudを使用してバックアップを取得したい'},
#  {'id': '42', 'text': 'View環境でネットワークプリンタの設定をしたい'},
#  {'id': '43', 'text': 'View環境でプリンタインストールしたい'},
#  {'id': '44', 'text': 'View環境でのプリンター設定方法を教えてください。'},
#  {'id': '45', 'text': 'Viewでプリンターを使いたい'},
#  {'id': '46', 'text': 'Viewでプリンタ設定時にIPアドレスを入力したが、エラーになる'},
#  {'id': '47', 'text': 'View環境で複数のプリンタを設定したい'},
#  {'id': '48', 'text': 'Viewのプリンタ設定画面を再表示させたい'},
#  {'id': '49',
#   'text': 'Viewでプリンタの再設定を行っているのですが、操作を誤り「完了しませんでした」と表示されました。\nその後再ログインをしたのですがプリンタ設定画面が出てこなくなりました。'},
#  {'id': '50', 'text': 'View環境でプリンタドライバを再設定する方法を教えてほしい'},
#  {'id': '51', 'text': 'Viewで複合機のIPアドレスを入力し、プリンタの設定を行っているが、エラーになる'},
#  {'id': '52', 'text': '暗号化されたOfficeファイルの解除をしたい'},
#  {'id': '53', 'text': 'Officeのアクセス制限を解除したい'},
#  {'id': '54',
#   'text': 'ファイルサーバーに保存しているPowerPointファイルを客先に送りたい。客先の端末上でもOfficeファイルは問題なく開けるでしょうか。'},
#  {'id': '55', 'text': '暗号化されたOfficeファイルを開くことができない'},
#  {'id': '56', 'text': '暗号化されたOfficeファイルの解除方法を知りたい'},
#  {'id': '57', 'text': 'Excelの暗号化の解除方法がわからない'},
#  {'id': '58', 'text': '社外にExcelファイルを送信する際にAzureRMSの解除をしたい'},
#  {'id': '59', 'text': 'Officeファイルの暗号化を解除したい'},
#  {'id': '60', 'text': '社外にOfficeファイルを送信したいので、暗号化解除の方法を知りたい'},
#  {'id': '61', 'text': 'パワーポイントのファイルをお客様先に送ったら客先で「開けない」と言われた。この場合どうすればいいですか。'},
#  {'id': '62', 'text': 'EUCについて問合せたい'},
#  {'id': '63', 'text': 'EUCについて確認したい'},
#  {'id': '64', 'text': 'EUCの問合せ先はどこですか？'},
#  {'id': '65', 'text': 'EUCの管理部署を教えて欲しい'},
#  {'id': '66', 'text': '部署で購入した端末をOA環境に接続したい'},
#  {'id': '67', 'text': '部門端末をOAネットワークに接続したい'},
#  {'id': '68', 'text': '部門PCをOA化したい'},
#  {'id': '69', 'text': '部門導入PCを社内NWに接続したい'},
#  {'id': '70', 'text': '準OAPCを社内ネットワークに接続したい'},
#  {'id': '71', 'text': '部門PCをOAネットワークに接続したい'},
#  {'id': '72', 'text': '部門購入端末をOANWに繋げたい'},
#  {'id': '73', 'text': '部門PCをOA環境に接続したい'},
#  {'id': '74', 'text': '部門PCを社内NWに接続したい'},
#  {'id': '75', 'text': '部門PCを社内ネットワークに接続する手順が知りたい'},
#  {'id': '76', 'text': 'PCからGmailにアクセスできなくなりました'},
#  {'id': '77', 'text': 'Chromeのキャッシュクリア方法を教えて'},
#  {'id': '78', 'text': 'GoogleChromeを開いてGmailを見ようとしたところ画面が真っ白で何も表示されない。'},
#  {'id': '79', 'text': 'Googleのキャッシュクリア方法を知りたい'},
#  {'id': '80', 'text': 'Google Chromeのキャッシュを削除したい'},
#  {'id': '81', 'text': 'Chromeのキャッシュをクリアしたい'},
#  {'id': '82', 'text': 'GoogleChromeを開くと画面が真っ白でお待ちくださいと表示されている。'},
#  {'id': '83',
#   'text': 'ChromeからGmailに接続できません。メールアドレス入力し次へボタンをクリックするとHTTP500?????と表示された画面になります。'},
#  {'id': '84', 'text': 'OAPCでGmail本文が読み込めません。Googleへの接続に問題が発生していますと表示されています。'},
#  {'id': '85', 'text': 'CI Tools (by CITeam)を使用したい'},
#  {'id': '86', 'text': 'エイリアスから名前検索したい'},
#  {'id': '87', 'text': 'アカウント名から社員名を調べる方法を教えて'},
#  {'id': '88', 'text': 'エイリアスからメールアドレスを確認する方法を教えてください'},
#  {'id': '89', 'text': 'Gmailアカウントから氏名、部署名を取得するには？'},
#  {'id': '90', 'text': 'エイリアスや氏名からメールアドレスを確認する方法を教えてください'},
#  {'id': '91', 'text': 'エイリアスから社員の名前を調べる方法を教えてほしい'},
#  {'id': '92', 'text': '自分のOAアカウントを確認したい'},
#  {'id': '93', 'text': 'CI Toolsをインストールしたい'},
#  {'id': '94', 'text': 'OAアカウントを検索したい'},
#  {'id': '95', 'text': '故障交換をした業務用携帯電話Bの返却宛先を知りたい'},
#  {'id': '96', 'text': '業端BのiPadを返却したい'},
#  {'id': '97', 'text': '派遣社員が使用する業務端末Bの返却方法を教えていただいてもよろしいでしょうか？'},
#  {'id': '98', 'text': '業務端末Bの交換対応後の返却先はどこですが？'},
#  {'id': '99', 'text': '業端Bの返却方法が知りたい'},
#  {'id': '100', 'text': '業務端末Bの返却について'},
#  {'id': '101', 'text': '業務端末Bの返却先はどちらでしょうか'},
#  {'id': '102', 'text': '業端Bの返却方法を教えて'},
#  {'id': '103', 'text': '業務用携帯電話Bの返却はどうしたらいい？'},
#  {'id': '104', 'text': '業端Bの返却手順を教えて'},
#  {'id': '105', 'text': 'Wドライブにてファイルが保存できない'},
#  {'id': '106', 'text': 'Wドライブの容量が不足している。容量増加することは可能ですか。'},
#  {'id': '107', 'text': 'Wドライブの容量が不足してきた'},
#  {'id': '108', 'text': 'Wドライブの容量を増やしたい'},
#  {'id': '109', 'text': 'ViewでファイルのDLを行うと「ディスクがいっぱい」と表示される'},
#  {'id': '110', 'text': 'Wドライブの容量増加をしてほしい'},
#  {'id': '111', 'text': 'Wドライブの容量が枯渇している'},
#  {'id': '112', 'text': 'Wドライブの容量を教えて'},
#  {'id': '113', 'text': 'Wドライブの容量が少ない'},
#  {'id': '114', 'text': 'Wドライブの容量増加をしたい'},
#  {'id': '115', 'text': 'iPhoneの連絡先から別拠点の人の電話番号が検索できなくなりました。改善方法を教えてください。'},
#  {'id': '116', 'text': 'あんしんバックアップアプリ利用方法を教えて欲しい'},
#  {'id': '117', 'text': '機種変更で連絡先を移行したが、残ってしまう連絡先があります。移行方法を教えてください。'},
#  {'id': '118', 'text': 'iPhoneの連絡先が移行出来ない'},
#  {'id': '119', 'text': 'AndroidからiPhoneに機種変更したが、同期で移行できない連絡先があります。'},
#  {'id': '120', 'text': '機種変更の時に連絡先を移行する方法を教えてください。'},
#  {'id': '121', 'text': '共有ドライブに保存したファイルが削除できない'},
#  {'id': '122', 'text': '共有ドライブ内のデータが消せる人の権限を教えて欲しい'},
#  {'id': '123', 'text': '共有ドライブ内に保存したファイルを削除する方法を教えて欲しい'},
#  {'id': '124', 'text': '共有ドライブ内でファイルの削除ができません。どうすればよいですか？'},
#  {'id': '125', 'text': '誤ってワークスペースから退出してしまいました'},
#  {'id': '126', 'text': 'ワークスペースからサインアウトしてしまった場合の再サインイン方法を教えて欲しい'},
#  {'id': '127', 'text': '誤ってワークスペースからサインアウトしてしまいました'},
#  {'id': '128', 'text': 'ワークスペースから退出してしまった場合の再参加方法を教えて欲しい'},
#  {'id': '129', 'text': 'PDFを圧縮しパスワードをかけたい'},
#  {'id': '130', 'text': 'PDFにパスワードをかける方法を教えて'},
#  {'id': '131', 'text': 'PDFファイルのパスワードをかける操作はAdobe Readerでも可能ですか'},
#  {'id': '132', 'text': 'PDFファイルにパスワードを設定する'},
#  {'id': '133', 'text': 'PDFにパスワードをかけるにはソフトのインストールが必要ですか。'},
#  {'id': '134', 'text': 'PDFにパスワードを付与したい'},
#  {'id': '135', 'text': 'PDFでパスワード設定したい'},
#  {'id': '136', 'text': 'PDFファイルにパスワード設定をおこないたい'},
#  {'id': '137', 'text': 'PDFにパスワードをつけたい'},
#  {'id': '138', 'text': 'Acrobat Pro DCでPDFにPWをかけたい'},
#  {'id': '139', 'text': 'Zoomでイヤホンから音が聞こえません'},
#  {'id': '140', 'text': 'Zoomミーティングの際にイヤホンを使うにはどうしたらいいですか？'},
#  {'id': '141', 'text': 'イヤホンではなくPC本体から音声が聞こえる場合の対処方法を教えて'},
#  {'id': '142', 'text': 'イヤホンでZoomミーティングに参加する方法を知りたい'},
#  {'id': '143', 'text': '共有グループの管理者を知りたい'},
#  {'id': '144', 'text': '共有グループの管理者の確認方法を教えて欲しい'},
#  {'id': '145', 'text': '共有グループの管理者を確認したい'},
#  {'id': '146', 'text': '共有グループのMLの管理者を調べたい'},
#  {'id': '147', 'text': '共有メールの管理者を確認したい'},
#  {'id': '148', 'text': '共有グループの管理者の確認方法について'},
#  {'id': '149', 'text': 'G Suite 共有グループメンバー管理で管理者になっている人の確認方法を教えてください'},
#  {'id': '150', 'text': '管理者共有グループの管理者名を確認するには？'},
#  {'id': '151', 'text': '共有グループアドレスの管理者確認方法が知りたい'},
#  {'id': '152', 'text': '共有グループの管理者はどこで確認できますか？'},
#  {'id': '153',
#   'text': '業端A iPhoneでVPNに繋ごうとすると、「VPNサーバーとのネゴシエーションに失敗しました。」というエラーがでてくる'},
#  {'id': '154', 'text': '「VPNサーバーとのネゴシエーションに失敗しました」と表示されました。再設定しか方法はないでしょうか。'},
#  {'id': '155', 'text': 'エラー：「VPNサーバとのネゴシエーションに失敗しました。」が表示される'},
#  {'id': '156', 'text': '業端A iPhoneでVPN接続しようとするとネゴシエーションに失敗しましたが表示される'},
#  {'id': '157', 'text': '「VPNサーバーとのネゴシエーションに失敗しました」と表示されました。対応方法はありますか。'},
#  {'id': '158', 'text': '「VPNサーバとのネゴシエーションに失敗しました」と表示され、iPhoneからVPN接続できない'},
#  {'id': '159', 'text': 'ゲスト管理システムの管理者Gを移管する方法を教えて'},
#  {'id': '160', 'text': 'ゲスト管理システムの管理者グループのゲストを別の管理者グループに移行する方法を教えて'},
#  {'id': '161', 'text': 'ゲスト管理システムの管理者グループに紐づくゲストを別の管理者グループに移行したい'},
#  {'id': '162', 'text': 'ゲスト管理システムの管理者Gを移管することは出来ますか？'},
#  {'id': '163', 'text': 'OAアカウントのパスワードを間違えてビットロッカーのロックがかかってしまった'},
#  {'id': '164', 'text': 'OAPCのBitlocker回復キーを知りたい'},
#  {'id': '165', 'text': 'BitLockerの画面が出てPCにログインできない'},
#  {'id': '166', 'text': 'Bitlockerの回復キーを知りたいです'},
#  {'id': '167',
#   'text': 'OAPCがパスワード入力失敗によりBitLockerのロックがかかってしまいました。解除するための方法を教えてください。'},
#  {'id': '168', 'text': 'OAPCでPC起動時にBitLockerの回復キーを求めてきておりWindowsが起動できません。'},
#  {'id': '169', 'text': 'PC起動時にBitLocker回復キーの入力を求められます'},
#  {'id': '170', 'text': 'OAPC起動時にビットロッカーリカバリーと表示されてログインできません。'},
#  {'id': '171', 'text': 'Bitlocker回復キーを教えてください'},
#  {'id': '172', 'text': 'PC起動時にビットロッカーリカバリーという画面で数字の入力を求められています。'},
#  {'id': '173', 'text': '業務端末AのiPhoneで4G回線が使用できません。'},
#  {'id': '174', 'text': '業務端末AのiPhoneで5G経由の通信ができない'},
#  {'id': '175', 'text': '業務端末AのiPhoneで5G経由の通信ができません。'},
#  {'id': '176', 'text': '業務端末AのiPhoneで4GがOFFになっています。'},
#  {'id': '177', 'text': '業務端末AのiPadで4Gモバイルデータ通信ができない'},
#  {'id': '178', 'text': 'iPhoneのMDMプロファイルインストール時にエラーになる'},
#  {'id': '179',
#   'text': '業端A iPhoneでMDM設定時「プロファイルのインストールができませんでした」と表示されました。どこに問い合わせればいいでしょうか。'},
#  {'id': '180', 'text': 'iPhoneのMDMプロファイルがインストールエラーになってしまいます'},
#  {'id': '181', 'text': 'iPhoneのMDMプロファイルがインストールされません'},
#  {'id': '182', 'text': '「文書の取り出しができませんでした」と表示されてスキャンデータの取り出しができない'},
#  {'id': '183', 'text': 'ゼロックスの親展ボックスからスキャンデータの取り出しができない'},
#  {'id': '184', 'text': 'ゼロックスのスキャナの取り出しができない'},
#  {'id': '185', 'text': '親展ボックスからスキャナの取り出しができない'},
#  {'id': '186', 'text': 'ソリューション販売管理システムについて確認したい'},
#  {'id': '187', 'text': 'ソリューション販売管理システムの問合せ先はどこですか？'},
#  {'id': '188', 'text': 'ソリューション販売管理システムの管理部署を教えて欲しい'},
#  {'id': '189', 'text': 'ソリューション販売管理システムについて問い合わせしたい'},
#  {'id': '190', 'text': '仕入販売管理にログインできない'},
#  {'id': '191', 'text': 'ソリューション販売管理のパスワードを忘れました'},
#  {'id': '192', 'text': '仕入販売管理システムに入れません。'},
#  {'id': '193', 'text': 'ソリューション販売管理システムについて問合せたい'},
#  {'id': '194', 'text': 'ソリューション販売管理システムのPWを初期化したい'},
#  {'id': '195', 'text': 'グループアドレスで不在通知設定をしたい'},
#  {'id': '196', 'text': 'グループアドレスで不在通知の設定は可能ですか？'},
#  {'id': '197', 'text': 'グループメールアドレスで不在通知設定方法を教えて欲しい'},
#  {'id': '198', 'text': 'Googleグループアドレスの不在通知設定をしたい'},
#  {'id': '199', 'text': '共有メールアドレスで不在通知を設定することはできますか？'},
#  {'id': '200', 'text': 'Fruitsの問合せ先はどこですか？'},
#  {'id': '201', 'text': 'VoiceNetについて確認したい'},
#  {'id': '202', 'text': 'VoiceNetの管理部署を教えて欲しい'},
#  {'id': '203', 'text': 'VoiceNetについて問合せたい'},
#  {'id': '204', 'text': 'Fruitsについて確認したい'},
#  {'id': '205', 'text': 'Fruitsの管理部署を教えて欲しい'},
#  {'id': '206', 'text': 'VoiceNetの問合せ先はどこですか？'},
#  {'id': '207', 'text': 'Fruitsについて問合せたい'},
#  {'id': '208', 'text': 'iOS用のアプリ提供をしたいが、提供方法が分からない'},
#  {'id': '209', 'text': '業務用端末にアプリを配信したい'},
#  {'id': '210', 'text': 'iOS用のアプリの提供方法を相談したい'},
#  {'id': '211', 'text': 'iPhoneにアプリの配信をしたいが、対応方法が分からない'},
#  {'id': '212', 'text': 'Android用のアプリをPlayStoreで公開したい'},
#  {'id': '213', 'text': '「この不明な発行元からのアプリがPCに変更を加えることを許可しますか？」が表示されて、設定が変更できない'},
#  {'id': '214',
#   'text': '「この不明な発行元からのアプリがPCに変更を加えることを許可しますか？」が表示され、アプリがインストールできない'},
#  {'id': '215',
#   'text': 'アプリインストール時、「この不明な発行元からのアプリがPCに変更を加えることを許可しますか？」のメッセージが表示される'},
#  {'id': '216',
#   'text': '「この不明な発行元からのアプリがPCに変更を加えることを許可しますか？」のエラーが出て、ソフトがインストールできない'},
#  {'id': '217', 'text': '業端Aから社内無線LAN（yellow）に接続が出来ない'},
#  {'id': '218', 'text': '業端がyellowに繋がらない'},
#  {'id': '219', 'text': 'iPhoneの設定でMDMをインストールしましたが、社内WiFiにまだ繋がりません。'},
#  {'id': '220', 'text': '業務用端末A（iPad）でyellowに接続できない'},
#  {'id': '221', 'text': '業端Aが社内WiFiに繋がらない'},
#  {'id': '222',
#   'text': '故障交換で業端AのiPadを交換しセットアップしているのですが、WiFiのyellowがつかめません。yellowのプロファイルは入っていることは確認済みです。'},
#  {'id': '223', 'text': '業務端末AでYellowに繋がらない'},
#  {'id': '224', 'text': '業務端末がyellowに繋がらない'},
#  {'id': '225', 'text': '業務端末AでYellow接続できない'},
#  {'id': '226', 'text': '業端Aでyellowの接続しようとするとパスワードを要求されてしまい接続できない。'},
#  {'id': '227', 'text': 'AcrobatReaderDCのインストールができない'},
#  {'id': '228', 'text': 'AdobeReaderのインストール方法について教えてほしい'},
#  {'id': '229', 'text': 'Adobe Readerをインストールする方法が知りたい'},
#  {'id': '230', 'text': 'AcrobatReaderのインストール方法を教えてください'},
#  {'id': '231', 'text': 'PDFを開くためにAdobeReaderをインストールしたい。'},
#  {'id': '232', 'text': 'PDFをAdobe Readerで開きたい'},
#  {'id': '233', 'text': 'PDFをAdobe Readerで見れるようにしたい'},
#  {'id': '234', 'text': 'Adobe Readerのインストール方法がわからない'},
#  {'id': '235', 'text': 'PDFを閲覧したいため、AdobeReaderをインストールしたい。手順を教えてほしい。'},
#  {'id': '236', 'text': 'AdobeReaderの最新版をインストールしたい'},
#  {'id': '237', 'text': '付属品のVGA変換アダプタを紛失してしまった'},
#  {'id': '238', 'text': 'VGA変換アダプターを紛失してしまった場合はどうしたらいいですか？'},
#  {'id': '239', 'text': 'VGA変換アダプタをなくしてしまった'},
#  {'id': '240', 'text': 'VGA変換ケーブルを無くした場合どうすればいい？'},
#  {'id': '241', 'text': 'VGA変換アダプタを紛失した'},
#  {'id': '242', 'text': 'OAPC付属の VGA 変換アダプターを紛失してしまったので新しいものが欲しいです。'},
#  {'id': '243', 'text': 'VGA変換アダプタをなくした'},
#  {'id': '244', 'text': 'VGA変換アダプタを落とした'},
#  {'id': '245', 'text': 'PCのVGA変換アダプタを紛失してしまいました'},
#  {'id': '246', 'text': 'VGA変換アダプタを紛失された'},
#  {'id': '247', 'text': 'OAPCの利用者を変更したい'},
#  {'id': '248', 'text': '退職者のOAPCを新規入場者に引き継ぎたい'},
#  {'id': '249', 'text': 'L3DevのPCの所有者を変更したい'},
#  {'id': '250', 'text': '複数名分のOAPCの利用者変更申請を一括で実施したい'},
#  {'id': '251', 'text': 'OAPCの利用者変更申請承認後、いつから社内ネットワークに接続できるようになりますか'},
#  {'id': '252', 'text': 'OAPCの利用者変更申請の申請方法を教えてほしい'},
#  {'id': '253', 'text': '退場者のOAPCの利用者変更をしたい'},
#  {'id': '254', 'text': 'OAMacの利用者変更をしたい'},
#  {'id': '255', 'text': '部門管理PCで外部記録媒体を使用したいのですが申請は必要になりますか。'},
#  {'id': '256', 'text': 'OA化していない部門PCでUSBメモリを利用する場合、USB権限申請は必要ですか？'},
#  {'id': '257', 'text': '部門でスタンドアローンで使っている端末でUSBを使いたい'},
#  {'id': '258', 'text': '部門で管理している端末で外部記録媒体を使用したい'},
#  {'id': '259',
#   'text': '部門PCでネットワークがYellowのPCに対して外付けのDVDデッキを接続したい。PureTerminalからの申請は必要でしょうか'},
#  {'id': '260', 'text': 'L3DaaS環境からL2RDS環境にログインした際、アプリが表示されない。'},
#  {'id': '261', 'text': 'RDSにログインしたが、アイコンが何もない'},
#  {'id': '262', 'text': 'RDSにログインはできるが、アイコン自体が表示されていない'},
#  {'id': '263', 'text': 'RDSにはログインできるがアイコンが存在しない'},
#  {'id': '264', 'text': 'RDSログイン後、アイコンが何も表示されない'},
#  {'id': '265', 'text': 'RDSログイン後、アイコンが表示されない場合の対処方法'},
#  {'id': '266',
#   'text': 'L3環境で先週配信された新RDSアイコンからログインするとremoteApp以下に何もアイコンが表示されていない'},
#  {'id': '267', 'text': 'RDSでアイコンが出て来ない'},
#  {'id': '268', 'text': 'RDSのアイコンが出ない'},
#  {'id': '269', 'text': 'Excelを起動すると「サブスクリプションの有効期限が切れています。」と表示される'},
#  {'id': '270', 'text': 'パワーポイントファイルを開いたときに「サブスクリプションの有効期限が切れているとエラーになる'},
#  {'id': '271', 'text': 'Officeを立ち上げるとサブスクリプションの有効期限が切れていますと表示される'},
#  {'id': '272', 'text': 'サブスクリプションのエラーが出てOfficeが使えない'},
#  {'id': '273', 'text': 'Office365サブスクリプションは有効期限が切れています'},
#  {'id': '274', 'text': 'エクセルを開くとサブスクリプションの有効期限が切れていますと出ます。'},
#  {'id': '275', 'text': 'Office起動時にサブスクリプションの有効期限が切れていますというメッセージが出てしまう'},
#  {'id': '276', 'text': 'Officeファイルを起動すると「サブスクリプションの有効切れ」と表示される。'},
#  {'id': '277', 'text': 'Officeでサブスクリプションの有効期限が切れていますが表示される'},
#  {'id': '278', 'text': 'Officeのサブスクリプションの有効期限が切れています'},
#  {'id': '279', 'text': '業務端末Bで設定したMySoftBankの暗証番号の問い合わせ先を教えて欲しい。'},
#  {'id': '280', 'text': '業務端末Bで設定したMySoftBankの暗証番号を忘れてしまった。'},
#  {'id': '281', 'text': '業務端末BのMySoftBankの暗証番号を確認したい。'},
#  {'id': '282', 'text': '業務端末BのMySoftbankへのログイン方法を教えてください。'},
#  {'id': '283', 'text': '業端BのMySoftBankの暗証番号を確認したい。'},
#  {'id': '284', 'text': '業端BのMySoftbankのパスワードを教えてください。'},
#  {'id': '285', 'text': '準OAPCを借りたい'},
#  {'id': '286', 'text': '準OAPCの貸出申請について'},
#  {'id': '287', 'text': '準OAPCはどこで借りることができますか？'},
#  {'id': '288', 'text': '準OA端末が欲しい'},
#  {'id': '289', 'text': '準OAPCを貸し出してほしい'},
#  {'id': '290', 'text': 'PCを交換したがログインできない。現在ログオン要求を処理できるログオンサーバーはありませんと表示される'},
#  {'id': '291', 'text': 'OAPCにログインできない。「ログイン要求を処理できるログオンサーバーはありません。」'},
#  {'id': '292', 'text': 'OAPCにログインできません。現在ログオン要求を処理できるログオンサーバーはありませんと表示されます'},
#  {'id': '293', 'text': 'OAPCにログインできません。「現在ログオン要求を処理できるログオンサーバーがありません」と表示されます'},
#  {'id': '294',
#   'text': 'PCを起動してログオンしようとしていますが\n「現在ログオン要求を処理できるログオンサーバーがありません」\nとエラーになります'},
#  {'id': '295',
#   'text': '現在ログオン要求を処理できるログオンサーバーはありませんというエラーがでてOAPCにログインできなくなった。解消方法を教えてほしい。'},
#  {'id': '296', 'text': 'OAPCにログインできません。エラー：現在ログオン要求を処理できるログオンサーバーはありません。'},
#  {'id': '297', 'text': 'OAPCにログインできません。現在ログオン要求を処理できるログオンサーバーがありませんと表示されます'},
#  {'id': '298', 'text': '現在、ログオン要求を処理できるサーバーはありません。というエラーの対処方法を教えて'},
#  {'id': '299', 'text': '「ログオン要求を処理できるログオンサーバーはありません」と表示されます'},
#  {'id': '300', 'text': '複数社で利用しているSlackコネクトのチャンネルから特定の会社のみ切り離したい'},
#  {'id': '301', 'text': '複数社間でやり取りしている共有チャンネルから特定の会社のみ切り離すことは出来ますか？'},
#  {'id': '302', 'text': '3社で利用している共有チャンネルから1社のみコネクトを切り離したい場合はどうしたら良いですか？'},
#  {'id': '303', 'text': '3社でSlackコネクトしている場合、特定の1社のみコネクト停止することは出来ますか？'},
#  {'id': '304', 'text': 'Excelは動作を停止しましたと出る'},
#  {'id': '305', 'text': 'Officeの修復方法について手順を教えてほしい'},
#  {'id': '306', 'text': 'Excelのアプリのみ起動しない'},
#  {'id': '307',
#   'text': '問題が発生し、PowerPointの動作が不安定になっています。と表示されてPowerPointファイルが開きません。'},
#  {'id': '308', 'text': 'PowerPointのアプリのみ起動しない'},
#  {'id': '309', 'text': 'Excelを開くとフリーズする'},
#  {'id': '310',
#   'text': 'PowerPointを開くと、以下のポップアップが表示され続けます。「申し訳ございません。問題が発生し、PowerPointの動作が不安定になっています。PowerPointを再起動してください」再起動してもなおりません。'},
#  {'id': '311', 'text': 'Officeをアップデート後にファイルが開かなくなった'},
#  {'id': '312', 'text': 'Wordのアプリのみ起動しない'},
#  {'id': '313',
#   'text': 'PowerPointファイルのみ正常動作しません。申し訳ございません。問題が発生し、PowerPointの動作が不安定になっています。と表示されて編集できません。'},
#  {'id': '314', 'text': '正社員以外のWindowsでのOffice利用方法を教えてほしい'},
#  {'id': '315', 'text': '業務委託社員のOffice利用について'},
#  {'id': '316', 'text': '業務委託社員でOfficeを使用したい'},
#  {'id': '317', 'text': 'Office365の利用は正社員以外でも可能ですか？'},
#  {'id': '318', 'text': '派遣社員がOfficeを使用する場合はどうしたらいいか'},
#  {'id': '319', 'text': 'Officeに利用ルールはありますか？'},
#  {'id': '320', 'text': '業務委託社員にOffice365を利用させたい'},
#  {'id': '321', 'text': '正社員以外の人がOfficeを利用する方法を教えてほしい'},
#  {'id': '322', 'text': '派遣社員のOffice365の利用マニュアルを教えてください'},
#  {'id': '323', 'text': '正社員以外の社員にOffice365を利用させたい'},
#  {'id': '324', 'text': '退職した人が共有ドライブに保存していたデータはどうなりますか？'},
#  {'id': '325', 'text': '辞めた人が共有ドライブ内にデータを保存していた場合の扱いはどうなりますか？'},
#  {'id': '326', 'text': '退職された際共有ドライブ内のファイルはどうなりますか'},
#  {'id': '327', 'text': '共有ドライブ内に辞めた人の作成したデータがある場合、消えてしまいますか？'},
#  {'id': '328', 'text': '退職時、共有ドライブ内のファイルはどうなりますか？'},
#  {'id': '329', 'text': 'FALCONで共有フォルダの利用率を確認することは可能ですか？'},
#  {'id': '330', 'text': '共有フォルダの利用率を確認したい'},
#  {'id': '331', 'text': 'プロジェクトフォルダの利用率を確認したい'},
#  {'id': '332', 'text': '共有フォルダの利用率を確認する方法はありますか？'},
#  {'id': '333', 'text': '業端Aからシングルサインオン（SSO）できない'},
#  {'id': '334', 'text': 'OAMacからSSO認証ができない'},
#  {'id': '335', 'text': 'AndroidからSSO認証が通らない'},
#  {'id': '336', 'text': 'iPhoneからSSO認証できない'},
#  {'id': '337', 'text': 'iPhoneでSSO認証ができない'},
#  {'id': '338', 'text': 'OAMacで社内NWに接続しているがSSO認証できない'},
#  {'id': '339', 'text': '開発DaaSを複数のモニターに表示できますか？'},
#  {'id': '340', 'text': '開発DaaSの画面を２つのディスプレイに表示したい'},
#  {'id': '341', 'text': '開発DaaSの画面を２つのモニターに表示したい'},
#  {'id': '342', 'text': '開発DaaS利用時のマルチディスプレイ表示方法を教えて欲しい'},
#  {'id': '343', 'text': '受入出向社員もZoomアカウントが発行されますか？'},
#  {'id': '344', 'text': 'Zoomアカウント自動払出対象者を教えて'},
#  {'id': '345', 'text': 'SBKK兼務の場合、Zoomアカウントは発行されますか？'},
#  {'id': '346', 'text': 'Zoomのアカウントは誰に発行されますか？'},
#  {'id': '347', 'text': 'OA化可能なMac OSのバージョンを教えて欲しい'},
#  {'id': '348', 'text': '部門購入したMacをOA化したいがOSが対象外と表示された。'},
#  {'id': '349', 'text': '最新OSのMacはいつからOA化できますか？'},
#  {'id': '350', 'text': '最新のMac OSのOA化はいつになりそうでしょうか？'},
#  {'id': '351', 'text': '最新のMac OSはいつ準OA化対応されますか'},
#  {'id': '352', 'text': '最新OSのMacをOA化したい'},
#  {'id': '353', 'text': 'MacOSをアップグレードしてもOA化可能ですか'},
#  {'id': '354', 'text': 'MacOSが新しすぎてOA化できない'},
#  {'id': '355', 'text': '購入したMacの最新OSはいつOA化できますか？'},
#  {'id': '356', 'text': '新バージョンのMac OSはOA化可能ですか'},
#  {'id': '357', 'text': 'PowerPointファイルをGmailに添付して送信するとウィルスに感染しましたとメッセージが出る'},
#  {'id': '358', 'text': 'このメールにはご注意ください。ウィルスや悪質なリンクが含まれている可能性があります。'},
#  {'id': '359',
#   'text': 'Gmail上で「ウィルスの警告 – XX個の添付ファイルにウィルスまたはブロックされたファイルが含まれています」のメッセージが出る'},
#  {'id': '360', 'text': 'Gmail上でのウィルス対応方法について'},
#  {'id': '361',
#   'text': 'Gmail上で「このメールにはご注意ください\u3000ウィルスや悪質なリンクが含まれている可能性があります」のメッセージが出る'},
#  {'id': '362', 'text': 'Admin権限が非承認になった理由を教えて欲しい'},
#  {'id': '363', 'text': 'Admin権限が非承認になったので、理由を知りたい'},
#  {'id': '364', 'text': 'Admin権限が否認された'},
#  {'id': '365', 'text': 'AdobeAcrobatのインストール申請を出したところView環境の為承認されませんでした。'},
#  {'id': '366', 'text': 'ライセンス管理システムでAdmin権限申請を行ったが否認された'},
#  {'id': '367', 'text': 'OAPCのマイクが使えない'},
#  {'id': '368', 'text': 'OAPCでマイク付きイヤホンが使えない'},
#  {'id': '369', 'text': 'OAPCのスピーカーが使用できない'},
#  {'id': '370', 'text': 'OAPCの音量を上げてもスピーカーで音声が聞こえません。どこで設定すればいいでしょうか。'},
#  {'id': '371', 'text': 'OAPCの音声が出ません'},
#  {'id': '372', 'text': 'OAPCで音が再生されない'},
#  {'id': '373', 'text': 'OAPCから音が出なくなりました。'},
#  {'id': '374', 'text': 'OAPCでマイクが使えない'},
#  {'id': '375', 'text': 'L2使用のPCでe-learningを受講しようとしたら、PCから音が出てこない。'},
#  {'id': '376', 'text': 'RDSの利用申請を一括登録できるか'},
#  {'id': '377', 'text': 'RDSの新規利用方法を確認したい'},
#  {'id': '378', 'text': 'RDS環境の利用申請をしたい'},
#  {'id': '379', 'text': 'RDSの申請方法を教えて欲しい'},
#  {'id': '380', 'text': 'RDSの利用申請認証されるまでどれくらいかかるか'},
#  {'id': '381', 'text': 'RDSの一括申請方法を教えて下さい。'},
#  {'id': '382', 'text': 'RDSの申請について教えて'},
#  {'id': '383', 'text': 'RDSを申請から利用開始までどのくらいかかるか'},
#  {'id': '384', 'text': 'RDSを申請後使えるのはいつか？'},
#  {'id': '385', 'text': 'RDSの申請方法を教えて'},
#  {'id': '386', 'text': 'MacからのView接続する方法を教えてください'},
#  {'id': '387', 'text': '自宅からView（仮想）環境への接続方法を教えてください'},
#  {'id': '388', 'text': '自宅からViewに入る手順を教えてください。申請はいるのでしょうか'},
#  {'id': '389', 'text': 'OAPCを社外に持ち出してView接続する方法を教えてください'},
#  {'id': '390', 'text': '自宅でPCを利用しています。\nテザリング接続してViewに入りたいがうまく入れない。'},
#  {'id': '391', 'text': '個人使用のPCでViewに接続したい'},
#  {'id': '392', 'text': '社外でView環境に入るにはどうすればいいのか'},
#  {'id': '393', 'text': '社外からVeiw接続を使用するにはどうすればよいでしょうか'},
#  {'id': '394', 'text': '自宅からView接続する方法を教えてほしい'},
#  {'id': '395', 'text': 'AzureRMSのアップグレード作業をしたいが支援ツール格納先のフォルダに入れない。'},
#  {'id': '396',
#   'text': 'AzureRMSのアップグレード作業が出来ない。\n作業支援チェックツールの入っているフォルダが開けない。'},
#  {'id': '397', 'text': 'AzureRMSCheck.vbsがある場所を教えて欲しい'},
#  {'id': '398', 'text': 'AzureRMSのチェックツールはどこにありますか？'},
#  {'id': '399', 'text': 'AzureRMSのチェックツールがある場所を教えて欲しい'},
#  {'id': '400', 'text': 'RMSのバージョンアップの方法を教えてください。'},
#  {'id': '401', 'text': '採用ドクターについて確認したい'},
#  {'id': '402', 'text': '採用Drの問合せ先はどこですか？'},
#  {'id': '403', 'text': '採用Drの管理部署を教えて欲しい'},
#  {'id': '404', 'text': '採用ドクターについて問合せたい'},
#  {'id': '405', 'text': '採用ドクターの管理部署を教えて欲しい'},
#  {'id': '406', 'text': '採用Drについて問合せたい'},
#  {'id': '407', 'text': '採用ドクターの問合せ先はどこですか？'},
#  {'id': '408', 'text': 'OAPC利用中に「メモリエラー」が表示されるのを解消したい'},
#  {'id': '409', 'text': 'OAPC利用中、GoogleChromeに「メモリエラー」が表示された場合の対処方法を教えて欲しい'},
#  {'id': '410', 'text': 'OAPC利用中に「メモリエラー」が表示された場合の対処方法を教えて欲しい'},
#  {'id': '411', 'text': 'View利用中に「メモリエラー」が表示される'},
#  {'id': '412', 'text': 'View利用中に「メモリエラー」が表示されるのを解決したい'},
#  {'id': '413', 'text': 'OAPCの電源が勝手に落ちる事象が繰り返し発生する'},
#  {'id': '414',
#   'text': 'OAPCで頻繁にブルースクリーン画面が発生しており、バッテリーも持たなくなっているため交換を希望しています'},
#  {'id': '415', 'text': 'OAPCが使用中にブルースクリーンになる。'},
#  {'id': '416', 'text': 'OAPCで動作不良（ブルースクリーン）が多発している。'},
#  {'id': '417', 'text': 'OAPCがブルースクリーンを多発する'},
#  {'id': '418', 'text': 'OAPCを少し移動するとフリーズする事象やブルースクリーンが頻発する状態です。'},
#  {'id': '419', 'text': 'PCのフリーズが頻発するのですが、どうしたらよいですか？'},
#  {'id': '420', 'text': 'ブルースクリーンが出現しQRコードが画面に出る'},
#  {'id': '421', 'text': 'PCの電源が突然落ちることが増えてきており、業務の支障が出ています。対応策を相談したい。'},
#  {'id': '422', 'text': 'PCがブラックアウトします'},
#  {'id': '423', 'text': 'ネットワーク管理GISにログインできない状態です。確認をお願いします。'},
#  {'id': '424', 'text': 'PFOS-GISを使いたい'},
#  {'id': '425', 'text': 'ネットワーク管理GISの問合せ先はどこですか？'},
#  {'id': '426', 'text': 'ネットワーク管理GISについて問合せしたい'},
#  {'id': '427', 'text': 'ネットワーク管理GISの問合せ先を教えて欲しい'},
#  {'id': '428', 'text': '業務端末の回線速度が遅い。'},
#  {'id': '429', 'text': '業務端末Aでデータ通信の速度が低下しました。容量は追加購入できますか。'},
#  {'id': '430', 'text': '業務端末Aの使用可能通信量確認方法を知りたい。'},
#  {'id': '431', 'text': '業務端末Bで通信が遅くなりました。元の速度にするにはどうすればいいでしょうか。'},
#  {'id': '432', 'text': '業務用端末のデータ制限について知りたい'},
#  {'id': '433', 'text': '業務端末Bで速度制限がかかった時の対処方法を教えてください。'},
#  {'id': '434', 'text': 'データ通信の速度で速度が低下しました。容量の追加はできますか。'},
#  {'id': '435', 'text': '業務端末Bのデータ通信で速度制限がかかった。どこに問い合わせればいいでしょうか。'},
#  {'id': '436', 'text': 'データ通信の速度が低下しました。業務端末Aで容量は追加購入できますか。'},
#  {'id': '437', 'text': '業務端末の回線速度が遅いです。'},
#  {'id': '438', 'text': 'プロジェクトフォルダ管理者を追加時、管理者追加ボタンが表示されない'},
#  {'id': '439', 'text': 'プロジェクトフォルダ管理者を追加したいが、管理者追加ボタンが表示されない'},
#  {'id': '440', 'text': 'FALCONでPJフォルダの管理者を追加したいが、追加ボタンが表示されない'},
#  {'id': '441', 'text': 'ファルコンで管理者の追加ができない'},
#  {'id': '442', 'text': 'プロジェクトフォルダ管理者を3名以上追加したいが、管理者追加ボタンが表示されない'},
#  {'id': '443', 'text': '共有フォルダ内のOfficeファイルが読み取り専用になっている'},
#  {'id': '444', 'text': '共有フォルダ上のファイルが読み取り専用になる'},
#  {'id': '445', 'text': 'フォルダの読み取り専用が解除できない'},
#  {'id': '446', 'text': '共有フォルダ内のPowerPointのファイルが読み取り専用になっている'},
#  {'id': '447', 'text': '共有フォルダ上のファイルが読み取り専用になってしまい、編集できない'},
#  {'id': '448', 'text': '共有フォルダ内のExcelファイルが読み取り専用になっている'},
#  {'id': '449', 'text': '販売職用のOAPCの起動パスワード変更後パスワードが不明になりOAPCが起動できなくなりました。'},
#  {'id': '450', 'text': 'SPのPCを新規で貸し出して欲しい'},
#  {'id': '451',
#   'text': 'SV代行になったのですがパソコンを貸与されていない。\nパソコンの貸与は自分で申し込みをするのでしょうか。'},
#  {'id': '452', 'text': '販売職社員のPCを新規で貸し出して欲しい'},
#  {'id': '453', 'text': 'SVになりPC変更になったのですが、起動に5分程度かかります。'},
#  {'id': '454',
#   'text': '以前パソコンの不調について、クルー相談窓口専用フォームから問い合わせを投げたところこちらの窓口に問合せするように言われました。'},
#  {'id': '455', 'text': '販売職用のOAPCが立ち上がらなくなった'},
#  {'id': '456', 'text': '販売職用のOAPCが正常起動しない'},
#  {'id': '457', 'text': 'SVのPCを新規で貸し出して欲しい'},
#  {'id': '458',
#   'text': 'iPadの業務用端末を使ってGmailを使っていますが\niPadに最初から入っているメールアプリで先週日曜以降新しいメールが受信できない\n「受信に失敗しました。」'},
#  {'id': '459', 'text': 'インストール申請をしたが、インストーラのパスがわからない'},
#  {'id': '460', 'text': 'インストール申請をしたが、インストーラを所持していない'},
#  {'id': '461', 'text': '部門PCのインストール申請を行いたいが、検索したPC名が表示されません'},
#  {'id': '462', 'text': 'インストール申請をしたが、インストーラがどこにあるかわからない'},
#  {'id': '463', 'text': 'インストールの申請が承認されたが、 インストーラの入手先が不明なので教えてほしい'},
#  {'id': '464', 'text': 'インストールの申請が承認されたが、 インストーラはどこから入手できますか'},
#  {'id': '465', 'text': 'インストール申請を行ったが、インストーラパスが分かりません。'},
#  {'id': '466',
#   'text': 'インストール申請を行いAdmin権限が付与されましたが\n実際のアプリのインストーラーはどこにあるのでしょうか'},
#  {'id': '467', 'text': 'インストールの申請が承認されたが、 その先の手順を教えてほしい。'},
#  {'id': '468',
#   'text': 'Excelファイルが開かない。エラー 「Microsoft Online Services サインイン アシスタントはこの\nコンピュータにインストールされていません。インスールしてから～。」'},
#  {'id': '469',
#   'text': 'AzureRMSアップグレード後ファイルをひらこうとするとエラーが出て、マイクロソフトサインインアシスタントはインストールされていません。'},
#  {'id': '470',
#   'text': 'エラーが出てExcelが開けません。「サインイン アシスタントはこのコンピュータにインストールされていません」'},
#  {'id': '471',
#   'text': '「Microsoft Online Services サインイン アシスタントはこのコンピュータにインストールされていません。管理者に問い合わせてください。」のポップアップが表示されて、Officeファイルが開かない'},
#  {'id': '472',
#   'text': '「Microsoft Online Services サインイン アシスタントはこの\nコンピュータにインストールされていません。管理者に問い合わせてください。」\nのポップアップが表示されて、Officeファイルが開かない'},
#  {'id': '473',
#   'text': 'Excelファイルを開くと、\n「Microsoft Online Services サインイン アシスタントはこの\nコンピュータにインストールされていません。管理者に問い合わせてください。」\nのポップアップが表示されて、Officeファイルが開かない'},
#  {'id': '474',
#   'text': '準OAPCにてOfficeソフトを開く際に「Microsoft Online Servicesサインインアシスタントはこのコンピュータにインストールされていません。」と出て開けません。'},
#  {'id': '475',
#   'text': 'パワーポイントを開こうとしたらエラーになる。「サインインアシスタントはこのコンピュータにインストールされていません」'},
#  {'id': '476',
#   'text': 'サインイン アシスタントはこのコンピュータにインストールされていませんのメッセージでOfficeファイルが開かない'},
#  {'id': '477',
#   'text': 'Officeファイルを開けません。\nエラーメッセージ:サインインアシスタントはこのコンピュータにインストールされていません'},
#  {'id': '478', 'text': '準OAPCでBlue接続中なのですがインターネットにつながりません。'},
#  {'id': '479', 'text': 'OAPCでblue接続できているがメールや社内システムが使用できない'},
#  {'id': '480', 'text': 'OAPCがインターネットに繋がらない'},
#  {'id': '481', 'text': 'OAPCでOASYS接続中だがインターネットにアクセスできない'},
#  {'id': '482', 'text': 'OAPCがインターネットにつながらない'},
#  {'id': '483', 'text': 'OAPCで社内LAN接続してもインターネットが利用できませんでした。'},
#  {'id': '484', 'text': 'OAPCがblueには接続できるが、インターネットができない'},
#  {'id': '485', 'text': 'OAPCがインターネットに接続できません。'},
#  {'id': '486', 'text': 'OAPCでblue接続できているがインターネットに接続できない'},
#  {'id': '487', 'text': '社内システムにつながるが、インターネットにつながらない'},
#  {'id': '488', 'text': 'OASYS接続中なのですがGmailに接続できません。'},
#  {'id': '489', 'text': 'OAPCが外部WebサイトやGmailに接続できない'},
#  {'id': '490', 'text': 'OAPCでインターネットに接続されていませんと表示される'},
#  {'id': '491', 'text': 'OAPCでblueに接続は出来ているがインターネットにつながらない'},
#  {'id': '492', 'text': 'OAPCがインターネットに接続できない'},
#  {'id': '493', 'text': 'OAPCで社外ネットワーク接続しているのですがインターネット接続ができません'},
#  {'id': '494', 'text': '準OAPCで社内NWに接続しているのですがインターネット接続ができません。'},
#  {'id': '495', 'text': 'OAPCからインターネットが利用できないので対処方法を教えてほしい'},
#  {'id': '496', 'text': '業務端末Bで充電ができません。ケーブルが原因だと思うのですが、交換可能でしょうか。'},
#  {'id': '497', 'text': '業務端末が充電できない。'},
#  {'id': '498', 'text': '業務端末BのiPhoneが充電できない'},
#  {'id': '499', 'text': '業務端末Bが充電できなくなった場合、どこに確認すれば良いですか。'},
#  {'id': '500', 'text': '業務端末Bで充電ができません。部門で交換できますか。'},
#  {'id': '501', 'text': '業務端末Bが充電できなくなりました。'},
#  {'id': '502', 'text': 'BBドメインアカウントでProselfにログインできますか？'},
#  {'id': '503', 'text': 'Proselfを利用できる対象を教えて欲しい'},
#  {'id': '504', 'text': 'Proself上のファイル保存期間はどのくらいですか?'},
#  {'id': '505', 'text': 'ProselfでL3Devアカウントのパスワードを変更する方法を教えて欲しい'},
#  {'id': '506', 'text': 'L3Devのファイルサーバーに接続できない'},
#  {'id': '507', 'text': 'L3Devのチャットシステムにつながらない'},
#  {'id': '508', 'text': 'L3Devアカウントが発行されましたが、すぐにProselfは利用できますか？'},
#  {'id': '509', 'text': 'Proselfのアカウント申請方法を教えて欲しい'},
#  {'id': '510', 'text': 'L3DevのProselfに接続できない'},
#  {'id': '511', 'text': 'Proselfでアップロードできるファイルの上限はありますか？'},
#  {'id': '512', 'text': 'TOMASの問合せ先はどこですか？'},
#  {'id': '513', 'text': 'CrBSの問合せ先はどこですか？'},
#  {'id': '514', 'text': 'TAS-S L2について確認したい'},
#  {'id': '515', 'text': 'BS-DRの問合せ先はどこですか？'},
#  {'id': '516', 'text': 'TAS-S L2の問合せ先はどこですか？'},
#  {'id': '517', 'text': 'TAS-S L3の問合せ先はどこですか？'},
#  {'id': '518', 'text': 'CrBS-Tの問合せ先はどこですか？'},
#  {'id': '519', 'text': 'RISM-BPの問合せ先はどこですか？'},
#  {'id': '520', 'text': 'DFCAの問合せ先はどこですか？'},
#  {'id': '521', 'text': 'TASGRPの問合せ先はどこですか？'},
#  {'id': '522', 'text': 'RTDA2-Jの問合せ先はどこですか？'},
#  {'id': '523', 'text': 'CrBS-Cの問合せ先はどこですか？'},
#  {'id': '524', 'text': 'TeBiAs社内メンテの問合せ先はどこですか？'},
#  {'id': '525', 'text': 'RTDAS2-Jの問合せ先はどこですか？'},
#  {'id': '526', 'text': '業務端末を紛失した場合、弁済金はいくらかかりますか。'},
#  {'id': '527', 'text': '業端AのUSIMカード紛失・ロックされた場合の弁済金はいくらかかりますか。'},
#  {'id': '528', 'text': '業端Aの弁済金の設定基準について教えて欲しい'},
#  {'id': '529',
#   'text': '業端Aの画面破損（落下による）の弁済額は上限4万とありますが、具体的にはいくらくらいになりますでしょうか？'},
#  {'id': '530', 'text': '業務端末の弁済金の実績を教えてください。'},
#  {'id': '531', 'text': '業務端末を水没させた場合、弁済金はいくらかかりますか。'},
#  {'id': '532', 'text': '業端Aの不具合に伴い、弁済金が発生するか確認したい。'},
#  {'id': '533',
#   'text': '退職済の派遣社員の業務端末が画面割れを起こしているため、弁償金・請求先等はどのような応対になりますでしょうか？'},
#  {'id': '534', 'text': 'GoogleEarthProをOAPC(FAT)にインストールする方法を教えてください。'},
#  {'id': '535', 'text': 'Alibaba Cloud を使いたい。'},
#  {'id': '536', 'text': 'knimeを使いたい'},
#  {'id': '537', 'text': 'サクラエディタのインストールは可能ですか？'},
#  {'id': '538', 'text': 'OA提供外のソフトウェアインストールについて'},
#  {'id': '539', 'text': 'Pythonをインストールしても良いですか？'},
#  {'id': '540', 'text': 'Macにsikuliをインストールしたい'},
#  {'id': '541', 'text': 'Sikuliをインストールしたい'},
#  {'id': '542', 'text': 'Macにpythonをインストールしたい'},
#  {'id': '543', 'text': 'gizieをインストールしたい'},
#  {'id': '544', 'text': '名刺カメラアプリをインストールしたい'},
#  {'id': '545', 'text': 'フリーソフトのダウンロードがしたい'},
#  {'id': '546', 'text': 'Tableau Desktopを社用PCでDLしたいのですが可能でしょうか？'},
#  {'id': '547', 'text': 'anacondaをインストールしたい'},
#  {'id': '548', 'text': '無償ソフトウェアのインストール申請について教えて'},
#  {'id': '549', 'text': '「+Lhaca」インストールしたい'},
#  {'id': '550', 'text': 'Firebase使いたい'},
#  {'id': '551', 'text': 'WireSharkをインストールしたい'},
#  {'id': '552', 'text': '7zipをインストールしたい'},
#  {'id': '553', 'text': '有償ソフトウェアをインストールしたい'},
#  {'id': '554', 'text': 'OAPCを自宅のWiFiに接続する'},
#  {'id': '555', 'text': 'OAPCが自宅のWi-Fi接続ができない。'},
#  {'id': '556', 'text': 'OAPCが自宅の無線LANに接続できない'},
#  {'id': '557', 'text': 'OAPCで自宅の無線LANにつなぎたい'},
#  {'id': '558', 'text': 'OAPCが社外ネットワークに繋がらない'},
#  {'id': '559', 'text': '自宅のWi-FiにOAPCが繋がらない'},
#  {'id': '560', 'text': 'OAMacが社外NWに繋がらない'},
#  {'id': '561', 'text': 'OAPCを自宅のネットワークに接続する方法を知りたい'},
#  {'id': '562', 'text': '自宅で支給されているOAPCを使っていますが、自宅のWi-Fiで繋がらない。'},
#  {'id': '563', 'text': 'OAPCが社外ネットワークに接続できない'},
#  {'id': '564', 'text': 'OAPCのMacが故障した場合、交換していただけますか'},
#  {'id': '565', 'text': 'Macを貸与して欲しい。'},
#  {'id': '566', 'text': 'OAPCをMacに変更したい'},
#  {'id': '567', 'text': 'OAPCをMacに変えたい'},
#  {'id': '568', 'text': 'MacのOAPCを貸し出してほしい'},
#  {'id': '569', 'text': 'MacをOA端末として利用したい'},
#  {'id': '570', 'text': 'OAPCをMacにしたい'},
#  {'id': '571', 'text': '開発DaaSの接続時間を短縮したい'},
#  {'id': '572', 'text': '開発DaaSにアクセスする時間を短くしたい'},
#  {'id': '573', 'text': '開発DaaSにアクセスする時間を短くする方法はありますか？'},
#  {'id': '574', 'text': '開発DaaSの接続時間を短縮できますか？'},
#  {'id': '575', 'text': 'O&Mヘルプデスクの問合せ窓口を教えて'},
#  {'id': '576', 'text': 'O&Mヘルプデスクの問合せをしたい'},
#  {'id': '577', 'text': 'O&Mヘルプデスクに入れない'},
#  {'id': '578', 'text': 'O&Mヘルプデスクの所属情報が知りたい'},
#  {'id': '579', 'text': 'O&Mヘルプデスクにログイン出来ない'},
#  {'id': '580', 'text': 'Gmailで全社員に周知メールを送りたい'},
#  {'id': '581', 'text': '全社員宛にメールを送信したい'},
#  {'id': '582', 'text': 'Gmailで全社員にメールを送信したい'},
#  {'id': '583', 'text': '全社員向けにメールをしたい'},
#  {'id': '584', 'text': '全社員へメールをしたい'},
#  {'id': '585', 'text': '全社員にメールを送りたい'},
#  {'id': '586', 'text': '全社員宛てにメールを送りたい'},
#  {'id': '587', 'text': 'SB全社員にメールを送りたい'},
#  {'id': '588', 'text': '全社員のGmail宛に周知を送りたい'},
#  {'id': '589', 'text': '誤って消したgmailを復活したい'},
#  {'id': '590', 'text': '削除したGmailの復元方法はありますか？'},
#  {'id': '591', 'text': 'メールの復元に関して教えて欲しい'},
#  {'id': '592', 'text': '削除したメールの復元をしたい'},
#  {'id': '593', 'text': 'CRMに接続できない。'},
#  {'id': '594', 'text': 'CRMに不具合がある'},
#  {'id': '595', 'text': 'CRMの問合せ先を教えて欲しい'},
#  {'id': '596', 'text': 'CRMにアクセスできなくなった'},
#  {'id': '597', 'text': 'OMSの期限延長方法を教えてください'},
#  {'id': '598', 'text': 'OMSのパスワードが分からない'},
#  {'id': '599', 'text': '作スケのパスワードがわからない'},
#  {'id': '600', 'text': 'OMSのパスワードをリセットしたい'},
#  {'id': '601', 'text': 'OMSのパスワード変更方法を教えて欲しい'},
#  {'id': '602', 'text': '作スケのパスワード変更方法を教えてください。'},
#  {'id': '603', 'text': 'OMSを利用したい'},
#  {'id': '604', 'text': 'OMS、作スケの初期PWを教えてください'},
#  {'id': '605', 'text': 'サスケにログインできない'},
#  {'id': '606', 'text': 'OMSのログイン方法を教えて'},
#  {'id': '607', 'text': 'SSOログイン後、「Error403--Forbidden」が表示されて正常にログインできない。'},
#  {'id': '608', 'text': 'SSOログイン後、「情報ログインしました」が表示されて正常にログインできない。'},
#  {'id': '609', 'text': 'SSOで認証しているシステムに入りたいが、認証画面が出てこない'},
#  {'id': '610', 'text': 'SSOログイン後、「不正なハンドラによる認証の例外」が表示されて正常にログインできない。'},
#  {'id': '611', 'text': '今まで社外でPCからGmailが見れていたが、「403 Forbidden」のエラーが出て見れない'},
#  {'id': '612', 'text': 'SSOでログイン後、再度、認証画面に戻ってしまうのを解消したい'},
#  {'id': '613', 'text': 'SSOログイン後、「情報ログインしました」が表示される'},
#  {'id': '614', 'text': '「Error403--Forbidden」が表示されてGmailにログインできない。'},
#  {'id': '615', 'text': 'Gmailにログインしようとしているが、SSOの画面が出ない'},
#  {'id': '616',
#   'text': 'エイリアスとパスワード入力後、「Error403--Forbidden」が表示されて正常にログインできない。'},
#  {'id': '617',
#   'text': '部署異動に伴いOAPC化しているMacを別の人間に紐づけなおしたいのですがどうのうな手続きをしたら良いでしょうか？'},
#  {'id': '618', 'text': '準OAPCの利用者変更を教えて'},
#  {'id': '619', 'text': '自部門購入PCの利用者変更をしたい'},
#  {'id': '620', 'text': '準OAPCの利用者が変わる場合に必要な手続きを教えてほしい'},
#  {'id': '621', 'text': '準OAPCの使用者変更の方法は'},
#  {'id': '622', 'text': '部門購入し、準OA化したPCの管理者を変更したい'},
#  {'id': '623', 'text': '準OAPCの利用者変更について知りたい'},
#  {'id': '624', 'text': '準OAPCの管理者を変えたい'},
#  {'id': '625', 'text': '準OAPCの管理者を変更したい'},
#  {'id': '626', 'text': '部署購入PCをOA化したのですが利用者を変えるにはどうすればいいですか'},
#  {'id': '627', 'text': 'Zoomミーティングの制限時間はありますか？'},
#  {'id': '628', 'text': '無料アカウントの場合、時間制限はありますか？'},
#  {'id': '629', 'text': 'Zoom会議の利用制限時間はありますか？'},
#  {'id': '630', 'text': 'Zoomの利用制限時間はどのくらいですか？'},
#  {'id': '631', 'text': 'SBTM BSSの問合せ先はどこですか？'},
#  {'id': '632', 'text': 'SBTM BOSの担当者を教えて欲しい'},
#  {'id': '633', 'text': 'SBTM BOSの問合せ先を教えて欲しい'},
#  {'id': '634', 'text': 'SBTM BSSの問合せ先を教えて欲しい'},
#  {'id': '635', 'text': 'SBTM BSSの担当者を教えて欲しい'},
#  {'id': '636', 'text': 'SBTM BOSの問合せ先はどこですか？'},
#  {'id': '637', 'text': '共有フォルダのアクセス権限を付与したい'},
#  {'id': '638', 'text': '共有ファイルサーバーへのアクセス権を付与してほしいのですがどこに問合せをすればいいですか？'},
#  {'id': '639', 'text': '共有フォルダの権限を設定したい'},
#  {'id': '640', 'text': '共有フォルダのアクセス権限付与申請の仕方を教えて'},
#  {'id': '641', 'text': '共有フォルダのアクセス権付与の仕方を教えて'},
#  {'id': '642', 'text': '共有フォルダの管理者権限を変更したい'},
#  {'id': '643', 'text': '共有フォルダの権限を付与したい'},
#  {'id': '644', 'text': 'プロジェクトフォルダーに参照者を追加したい'},
#  {'id': '645', 'text': '共有フォルダへの権限追加方法を教えて'},
#  {'id': '646', 'text': '共有フォルダのアクセス権限を追加したい'},
#  {'id': '647', 'text': '社外に重たいファイルを送りたい'},
#  {'id': '648', 'text': '社外に大容量ファイルを送る場合の方法'},
#  {'id': '649', 'text': '大容量のファイルを社外と共有したいけどどうすればいい？'},
#  {'id': '650', 'text': '社外の人に大容量のファイルを送りたい'},
#  {'id': '651', 'text': '社外にデータを送りたい'},
#  {'id': '652', 'text': '大容量ファイルを外部に送りたい'},
#  {'id': '653', 'text': '社外に重いデータを送付したい'},
#  {'id': '654', 'text': '社外の人へデータファイルを送信したい'},
#  {'id': '655', 'text': '社外に大きいファイルを送りたい'},
#  {'id': '656', 'text': 'ファイル授受システムを使いたい'},
#  {'id': '657', 'text': 'エミュレータの問合せ先はどこですか？'},
#  {'id': '658', 'text': 'AS/400について問合せたい'},
#  {'id': '659', 'text': 'エミュレータについて問合せたい'},
#  {'id': '660', 'text': 'エミュレータの担当窓口を教えて欲しい'},
#  {'id': '661', 'text': 'AS/400の問合せ先はどこですか？'},
#  {'id': '662', 'text': 'AS/400 (エミュレータ)について確認したい'},
#  {'id': '663', 'text': 'AS/400の担当窓口を教えて欲しい'},
#  {'id': '664', 'text': 'View 使用可能なソフトウェアを教えて欲しい'},
#  {'id': '665', 'text': 'View環境にインストールされているアプリケーションを確認したい'},
#  {'id': '666', 'text': 'View環境下でインストール済みとなっているアプリケーションについて教えてほしい。'},
#  {'id': '667', 'text': 'Viewにインストールされているソフトを教えて欲しい'},
#  {'id': '668', 'text': 'Viewで使えるソフトを教えて欲しい'},
#  {'id': '669', 'text': 'Viewで使えるアプリを教えて欲しい'},
#  {'id': '670', 'text': 'HorizonViewで利用できるアプリを確認したい'},
#  {'id': '671', 'text': 'HorizonViewで利用可能なアプリケーションを確認したい'},
#  {'id': '672', 'text': 'Viewにインストール済みのソフトウェアを教えて欲しい'},
#  {'id': '673', 'text': '販売契約社員のAzureRMS申請方法が知りたい'},
#  {'id': '674', 'text': '販売契約社員がOffice265を利用する為にAzureRMSの申請をしたい'},
#  {'id': '675', 'text': '販売契約社員のAzureRMS申請はTarteからできますか？'},
#  {'id': '676', 'text': '販売契約社員でAzureRMSで暗号化されたファイルを開くことが出来ません'},
#  {'id': '677', 'text': '販売契約社員のAzureRMS申請方法を教えてほしい'},
#  {'id': '678', 'text': '販売契約社員でOfficeを使いたい'},
#  {'id': '679', 'text': '販売契約社員のAzureRMSの申請方法を教えてください'},
#  {'id': '680', 'text': '販売契約社員でOffice365を使いたい'},
#  {'id': '681', 'text': '販売契約社員のAzureRMSの申請方法がわかりません'},
#  {'id': '682', 'text': 'OAPCがblueに繋がらなくなったのでプロファイルを削除した。再設定はどうすればいいか'},
#  {'id': '683', 'text': 'OAPCでBlueを利用したい。blueのパスワードを教えてください'},
#  {'id': '684', 'text': '準OAPCでBlue接続できません。パスワード入力を求められます。'},
#  {'id': '685', 'text': 'OAPCから社内LANのblueに自動接続ができなくなった'},
#  {'id': '686', 'text': 'OAPCからblueに接続する際の設定方法について教えてほしい。'},
#  {'id': '687', 'text': '準OAPCをblueに繋ぎたい'},
#  {'id': '688', 'text': 'OAPCがBlueに繋がらない'},
#  {'id': '689', 'text': 'FATPCからblueへ接続する際の接続方法を教えてほしい。'},
#  {'id': '690', 'text': 'ワークスペースを追加の項目からワークスペースを新規で追加してもいいですか？'},
#  {'id': '691', 'text': 'ワークスペースは自身で作成可能ですか？'},
#  {'id': '692', 'text': '自分で新しくワークスペースを作りたい'},
#  {'id': '693', 'text': 'ワークスペースを新規作成の項目は使ってもいいですか？'},
#  {'id': '694', 'text': '「iTunesマークとUSBケーブル接続の画面が表示される」場合、初期化しかないでしょうか。'},
#  {'id': '695', 'text': 'iPhone/iPadでiTunesに接続を乞う画面が表示されます。'},
#  {'id': '696',
#   'text': '「iTunesマークとUSBケーブル接続の画面が表示される」場合、iTunesをインストールして初期化してもいいでしょうか。'},
#  {'id': '697', 'text': 'iPhoneを起動するとiTunesマークとUSBケーブル接続の画面が表示される'},
#  {'id': '698', 'text': 'Wドライブをマウントしていなくても、暗号化は適用されていますか？'},
#  {'id': '699', 'text': 'AzureRMSの暗号化はWドライブでも適用されていますか？'},
#  {'id': '700', 'text': 'Wドライブはマウントしていなくても暗号化されますか？'},
#  {'id': '701', 'text': 'WドライブのデータはAzureRMSで暗号化されていますか？'},
#  {'id': '702', 'text': '削除した共有ドライブ内のファイルの復元はできますか？'},
#  {'id': '703', 'text': '共有ドライブ内のファイルが消えてしまった'},
#  {'id': '704', 'text': '誤って共有ドライブ内のデータを削除してしまったので、元に戻したい'},
#  {'id': '705', 'text': '誤って共有ドライブ内のデータを削除してしまったので、復元したい'},
#  {'id': '706', 'text': '共有ドライブ内の消去してしまったデータの復元方法を教えて欲しい'},
#  {'id': '707', 'text': '会社のメールアドレスで個別にZoomアカウントを作成しても良いですか？'},
#  {'id': '708', 'text': '無料のZoomアカウントを作成しても良いですか？'},
#  {'id': '709', 'text': '個別でZoomアカウントを作成しても良いですか？'},
#  {'id': '710',
#   'text': 'ZoomのTarte申請を実施したが、あなたの現在のものとは異なるZoomアカウントにサインインしています。新しいアカウント管理者にあなたを招待するように求めてください。と表示されてZoomにサインインできない'},
#  {'id': '711',
#   'text': 'SB本務に異動になったが、Zoomサインイン時にあなたの現在のものとは異なるZoomアカウントにサインインしています。新しいアカウント管理者にあなたを招待するように求めてください。と表示されてサインインできない'},
#  {'id': '712',
#   'text': 'あなたの現在のものとは異なるZoomアカウントにサインインしています。新しいアカウント管理者にあなたを招待するように求めてください。と表示されてサインインできない'},
#  {'id': '713',
#   'text': 'Zoomの自動払出対象なのにあなたの現在のものとは異なるZoomアカウントにサインインしています。新しいアカウント管理者にあなたを招待するように求めてください。と表示される'},
#  {'id': '714', 'text': 'L3Dev環境しかない場合、どうやってGmailが確認できますか？'},
#  {'id': '715', 'text': 'L3DevFATからGmailを見たい'},
#  {'id': '716', 'text': '開発共有DaaSにView環境から接続できない'},
#  {'id': '717', 'text': 'L3Dev FATからViewに接続したい'},
#  {'id': '718', 'text': 'L3環境からGmailを閲覧したい'},
#  {'id': '719', 'text': '開発PCでメールの見方を教えて'},
#  {'id': '720', 'text': 'L3DevでGoogleドライブを使いたい'},
#  {'id': '721', 'text': '開発FATからのView接続方法を教えて欲しい'},
#  {'id': '722', 'text': '開発端末からのViw接続手順を教えて欲しい'},
#  {'id': '723', 'text': '開発PCでGmailを見たい'},
#  {'id': '724',
#   'text': 'その他デバイス(プリンタ、IP電話、TV会議など）をBLUE(L2無線)で利用したいのですが可能でしょうか。'},
#  {'id': '725', 'text': 'OAPC以外でblueに接続したい'},
#  {'id': '726', 'text': 'OAPC以外のデバイスからblueに接続したいので、SSIDのパスワードを教えて欲しい'},
#  {'id': '727', 'text': 'OAPCではないデバイスからblueに接続する方法はありますか？'},
#  {'id': '728', 'text': '業端Bの端末価格が知りたい'},
#  {'id': '729', 'text': '業務端末Bの価格確認方法を教えてください。'},
#  {'id': '730', 'text': '業端Bの価格が知りたい。'},
#  {'id': '731', 'text': '業務用端末Bの一覧を確認したい。'},
#  {'id': '732', 'text': '業務端末Bの端末価格やUSIMの価格を調べる方法を教えてください。'},
#  {'id': '733', 'text': '業務端末Bの端末とUSIMの金額を確認したい。'},
#  {'id': '734', 'text': '業務端末BのUSIMの金額を確認したい。'},
#  {'id': '735', 'text': '業務端末Bの端末金額を確認したい。'},
#  {'id': '736', 'text': '部門PCにソフトウェアをインストールする場合の申請方法を教えてほしい'},
#  {'id': '737', 'text': '部門管理のPCにソフトウェアをインストールする場合の申請方法を教えてほしい'},
#  {'id': '738', 'text': '部門管理PCにソフトウェアをインストールする場合の申請方法を教えてほしい'},
#  {'id': '739', 'text': 'ソフトウエアのインストール申請をしたい'},
#  {'id': '740', 'text': '部門端末にSEPをインストールしたい'},
#  {'id': '741', 'text': '部門で購入した端末にソフトをインストールしたい'},
#  {'id': '742', 'text': '部門購入のソフトウェアをOAPCにインストールする場合の申請について教えてください'},
#  {'id': '743', 'text': '部門PCにWindows OSをインストールしたい'},
#  {'id': '744', 'text': '部門PCでインストール申請をしたい'},
#  {'id': '745', 'text': '部門PCにソフトウェアをインストールしたい'},
#  {'id': '746', 'text': '会議通知が退職された人から送られてきているが、削除する方法を教えて欲しい'},
#  {'id': '747', 'text': '休職中の人が作った会議通知を削除したい'},
#  {'id': '748', 'text': '退職者が送ってきた会議通知が自身のカレンダーに残っているため削除したい'},
#  {'id': '749', 'text': 'Googleカレンダーで退職者が設定した会議通知を消したい'},
#  {'id': '750', 'text': 'Googleカレンダで退職者が設定した会議を消したい'},
#  {'id': '751', 'text': '退職者からの会議通知を削除する方法を教えて欲しい'},
#  {'id': '752', 'text': '退職者からの会議通知を削除したい'},
#  {'id': '753', 'text': '退職した人からの会議通知はどうやって削除したらいいですか？'},
#  {'id': '754', 'text': "A'OMAIの問合せ先はどこですか？"},
#  {'id': '755', 'text': 'アオマイの問合せ先はどこですか？'},
#  {'id': '756', 'text': "A'OMAIの管理部署を教えて欲しい"},
#  {'id': '757', 'text': "A'OMAIについて確認したい"},
#  {'id': '758', 'text': 'アオマイについて問合せたい'},
#  {'id': '759', 'text': "A'OMAIについて問合せたい"},
#  {'id': '760', 'text': 'アオマイの管理部署を教えて欲しい'},
#  {'id': '761', 'text': 'L3OAアカウントのパスワードをリセット（ロック解除）したい'},
#  {'id': '762', 'text': 'L3アカウントのパスワードリセット方法を教えて'},
#  {'id': '763', 'text': 'L3アカウントのパスワードリセットについて'},
#  {'id': '764', 'text': 'L3アカウントのパスワードをリセットしたい'},
#  {'id': '765', 'text': 'L3アカウントがパスワードロックされたときどこに連絡すればいい？'},
#  {'id': '766', 'text': '代理でL3アカウントのパスワードリセットをする方法を教えて'},
#  {'id': '767', 'text': 'L3アカウントのパスワードがわからない'},
#  {'id': '768', 'text': 'L2アカウントのパスワードリセット方法を教えて欲しい'},
#  {'id': '769', 'text': 'L3アカウントのパスワードが不明です'},
#  {'id': '770', 'text': 'iPhoneからAndroidへ移行したい'},
#  {'id': '771', 'text': 'AndroidへiPhoneからデータを移したい'},
#  {'id': '772', 'text': 'AndroidへiPhoneから設定変更したい'},
#  {'id': '773', 'text': 'iPhoneからAndroidへ設定を移行したい'},
#  {'id': '774', 'text': 'iPhoneからAndroidへデータを移す方法を知りたい'},
#  {'id': '775', 'text': 'AndroidにiPhoneからデータ移行をしたい'},
#  {'id': '776', 'text': 'AndroidへiPhoneから切り替えたい'},
#  {'id': '777', 'text': 'iPhoneからAndroidへのデータを移したい'},
#  {'id': '778', 'text': 'iPhoneからAndroidへの機種変時の設定が知りたい'},
#  {'id': '779', 'text': 'ソフトウェア担当者の変更方法を教えて'},
#  {'id': '780', 'text': 'ライセンス担当者の変更するにはどうしたらいいか'},
#  {'id': '781', 'text': 'ソフトウェア担当者を変更したい場合はどうすればいいですか。'},
#  {'id': '782', 'text': 'ソフトウェア担当者の変更申請方法を教えて欲しい'},
#  {'id': '783', 'text': 'ソフトウェアの管理部門を変更したい'},
#  {'id': '784', 'text': 'ソフトウェア担当者の変更方法について教えて'},
#  {'id': '785', 'text': 'ソフトウェア管理者の変更方法を教えて'},
#  {'id': '786', 'text': 'ソフトウェア担当者を変更したい'},
#  {'id': '787', 'text': 'ソフトウェア担当者を変更する方法を教えて欲しい'},
#  {'id': '788', 'text': '業務用携帯Bのコンテンツ登録方法を教えて欲しい'},
#  {'id': '789', 'text': '業務端末Bのコンテンツ登録方法を教えてください。'},
#  {'id': '790', 'text': '業端BでMy SoftBankからコンテンツ登録ができない'},
#  {'id': '791', 'text': '業端Bのコンテンツ登録が福岡Bizでできないと言われた場合の対処方法を教えて欲しい'},
#  {'id': '792', 'text': '業務端末Bでコンテンツ登録について確認したい'},
#  {'id': '793', 'text': 'iPadの電話番号を調べたい'},
#  {'id': '794', 'text': 'AndroidのMSNの確認方法を教えてください。'},
#  {'id': '795', 'text': 'iPhone/iPadのMSNの確認方法を教えてください。'},
#  {'id': '796', 'text': '業務端末A（携帯）の電話番号が表示されない'},
#  {'id': '797', 'text': '業務端末Bで電話番号もしくはデータ通信契約番号が表示されません。'},
#  {'id': '798', 'text': '業務端末AのiPhoneでMSNが表示されません。'},
#  {'id': '799', 'text': 'iPadのデータ通信契約番号を知りたい'},
#  {'id': '800', 'text': 'iPadの「MSN（データ通信契約番号）」を確認したい。'},
#  {'id': '801', 'text': '業務端末AのAndroidでMSNが表示されません。'},
#  {'id': '802', 'text': '業務端末AでMSNが表示されません'},
#  {'id': '803', 'text': 'グループアドレスにプロジェクトフォルダの管理者権限を付与したい'},
#  {'id': '804', 'text': 'プロジェクトフォルダのアクセス権にグループアドレスを設定したい'},
#  {'id': '805', 'text': 'プロジェクトフォルダ権限にグループアドレスを設定したい'},
#  {'id': '806', 'text': 'グループアドレスにフォルダアクセス権を設定したい'},
#  {'id': '807', 'text': 'グループアドレスにプロジェクトフォルダ権限を設定したい'},
#  {'id': '808', 'text': 'グループアドレスにプロジェクトフォルダの権限を付与したい'},
#  {'id': '809', 'text': 'グループアドレスにプロジェクトフォルダの権限を付けたい'},
#  {'id': '810', 'text': 'プロジェクトフォルダにアクセス権をつけたい'},
#  {'id': '811', 'text': 'ブラウザが古いと表示されてSlackにサインインできない'},
#  {'id': '812', 'text': 'SlackにサインインしたいのでChromeの更新方法を教えて'},
#  {'id': '813', 'text': 'Slackにサインインできるブラウザにしたい'},
#  {'id': '814', 'text': 'Slackにサインインしようとすると、ブラウザを更新するようエラーが出てしまう'},
#  {'id': '815', 'text': 'ミーティングに参加している人を確認したい'},
#  {'id': '816', 'text': '会議参加者を確認する方法はありますか？'},
#  {'id': '817', 'text': '会議の参加者の一覧が欲しい'},
#  {'id': '818', 'text': '誰が会議に参加していたか確認することはできますか？'},
#  {'id': '819', 'text': 'OAMacで閲覧可能なサイトの一覧はありますか？'},
#  {'id': '820',
#   'text': 'Macローカル上で、etime、smileを表示させる方法をご教示ください。Chromeでintraは表示できるもののコンテンツがエラーとなってしまいます。'},
#  {'id': '821', 'text': 'OAMacで人事Naviは閲覧できますか？'},
#  {'id': '822', 'text': 'OAMacで社内システムにアクセスできますか？'},
#  {'id': '823',
#   'text': '準OAMACの設定を行ったのですが、blueで接続したときにGmailやOAサポートには入れますが、人事naviやPureTerminalやSmileには入れないようです。'},
#  {'id': '824', 'text': '業務端末Aの交換後の返却期限を教えてください。'},
#  {'id': '825', 'text': '業端A交換後の返却ルールについて教えて欲しい'},
#  {'id': '826', 'text': '業端A交換後、旧端末はいつまでに返却すればよいですか？'},
#  {'id': '827', 'text': '業務用端末Bを故障交換した場合の返却方法を教えて欲しい'},
#  {'id': '828', 'text': '固定IPの払い出してほしい'},
#  {'id': '829', 'text': '固定IPにする方法は？'},
#  {'id': '830', 'text': '固定IPの払い出ししたい'},
#  {'id': '831', 'text': '固定IPアドレスを取得するには'},
#  {'id': '832', 'text': '固定ipがほしい'},
#  {'id': '833', 'text': '固定IPの申請手順を確認したい'},
#  {'id': '834', 'text': '固定IPアドレスの申請方法について'},
#  {'id': '835', 'text': '固定IPアドレスの申請方法について教えてほしい'},
#  {'id': '836', 'text': '固定IPを設定することは可能ですか'},
#  {'id': '837', 'text': 'テレビ会議用機器などの固定IPのご申請方法を教えてください。'},
#  {'id': '838',
#   'text': '「このブックを開くための権限がありません。別の資格情報を使ってファイルを開きます」が表示され、Excelファイルが開けない'},
#  {'id': '839', 'text': 'このブックを開くための権限がありません。'},
#  {'id': '840', 'text': 'このブックを開くための権限がありません。別の権限を使って情報を開きますか？'},
#  {'id': '841',
#   'text': 'Excelファイルが開きません。現在のアカウントが表示されるのでクリックするとこのブックを開く権限がありませんと表示されます'},
#  {'id': '842', 'text': 'このブックを開く権限がありません、のエラーが表示されてExcelファイルが開けない'},
#  {'id': '843', 'text': '「このブックを開くための権限がありません。別の資格情報を使ってファイルを開きます」が表示される'},
#  {'id': '844', 'text': 'このブックを開く権限がありません、と表示されてExcelファイルが開けない'},
#  {'id': '845',
#   'text': '「このブックを開くための権限がありません。別の資格情報を使ってファイルを開きます」のエラーメッセージが表示される'},
#  {'id': '846', 'text': 'このプレゼンテーションを開く為の権限がありません\u3000と表示される'},
#  {'id': '847', 'text': 'PCのデスクトップで「アイコンを等間隔に整列」の設定ができない'},
#  {'id': '848', 'text': '「アイコンを等間隔に整列」が選択できない'},
#  {'id': '849', 'text': '「アイコンを等間隔に整列」がクリックできない'},
#  {'id': '850', 'text': '「アイコンを等間隔に整列」にチェックが入らない'},
#  {'id': '851', 'text': '組織グループの正社員用と全社員用の違いを教えて欲しい'},
#  {'id': '852', 'text': '組織グループの正社員用と全社員用の用途を教えて欲しい'},
#  {'id': '853', 'text': '組織グループの用途について教えて欲しい'},
#  {'id': '854', 'text': '組織グループの正社員用と全社員用はどこが異なるのでしょうか？'},
#  {'id': '855', 'text': 'サイバートラスト デバイスID発行のお知らせのメールが発行されているか確認したい'},
#  {'id': '856', 'text': 'サイバートラスト デバイスID発行のお知らせが届かないので、再発行して欲しい'},
#  {'id': '857', 'text': 'OASYS申請後、サイバートラスト デバイスID発行のお知らせのメールが届かない'},
#  {'id': '858', 'text': 'サイバートラスト デバイスID発行のお知らせのメールが見当たらない'},
#  {'id': '859', 'text': '業務用携帯Bの種類が知りたい。'},
#  {'id': '860', 'text': '業端Bに適合するUSIMを確認したい'},
#  {'id': '861', 'text': '業務用携帯Bの機種が知りたい。'},
#  {'id': '862', 'text': '業務用端末Bの機器コードを知りたい。'},
#  {'id': '863', 'text': '業務用携帯B手配機種の商品コードを知りたい'},
#  {'id': '864', 'text': '業務端末Bの販売関連情報を確認したい。'},
#  {'id': '865', 'text': '業務端末Bの製品情報を確認したい。'},
#  {'id': '866', 'text': '業端端末でVPN申請していたが端末交換したため、以前のVPN申請を削除したい。手順を教えてほしい。'},
#  {'id': '867', 'text': '業務端末を返却するに当たってVPNの削除申請を行う方法を知りたい'},
#  {'id': '868', 'text': 'iPhoneのVPN申請の削除方法を教えてほしい'},
#  {'id': '869', 'text': '業務用端末AのVPN削除の仕方について知りたい。'},
#  {'id': '870', 'text': '業端AのVPNの申請を削除したい'},
#  {'id': '871', 'text': '業務端末のVPNの削除申請をしたい。'},
#  {'id': '872', 'text': '業務端末のVPN削除申請方法を教えて欲しい。'},
#  {'id': '873', 'text': 'iPad-VPNの申請を削除したい'},
#  {'id': '874', 'text': 'iPhoneを返却する前にVPNの申請を削除したい'},
#  {'id': '875', 'text': 'OAPCのSlackのバージョンアップはできますか？'},
#  {'id': '876', 'text': 'Slackのデスクトップアプリのバージョンアップをしたい'},
#  {'id': '877', 'text': 'Slackアプリのバージョンアップをしたい'},
#  {'id': '878', 'text': 'Slackアプリのアップデート方法を教えて'},
#  {'id': '879', 'text': 'ソフトウェアセンターが存在していない場合の対処方法を教えて欲しい'},
#  {'id': '880', 'text': 'ソフトウェアセンターがインストールされていない'},
#  {'id': '881', 'text': 'アプリケーションをインストールしようとしたが、ソフトウェアセンターが存在しない'},
#  {'id': '882', 'text': 'ソフトウェアセンターが存在していない'},
#  {'id': '883',
#   'text': 'ソフトウェアセンターからインストールできるソフトウェアがあるとのことだが、そもそもソフトウェアセンターが存在していない'},
#  {'id': '884', 'text': 'ソフトウェアセンターが存在しない'},
#  {'id': '885', 'text': 'スタート内にソフトウェアセンターが存在しない'},
#  {'id': '886', 'text': 'サーバ上にソフトウェアをインストールしたい'},
#  {'id': '887', 'text': 'サーバにMicrosoftのボリュームライセンスをインストールしたいがどうしたらいいですか。'},
#  {'id': '888', 'text': 'サーバーにソフトウェアをインストールしたい'},
#  {'id': '889', 'text': 'サーバにソフトウェアをインストールする手順を教えて欲しい'},
#  {'id': '890', 'text': 'サーバーにアプリケーションをインストールする場合、申請は必要ですか？'},
#  {'id': '891', 'text': 'サーバにソフトウェアをインストールしたいがライセンス管理システムでの申請は必要ですか。'},
#  {'id': '892', 'text': 'サーバにソフトウェアをインストールする場合、申請は必要ですか？'},
#  {'id': '893', 'text': 'サーバーへのソフトウェアインストールについて'},
#  {'id': '894', 'text': 'サーバーにソフトをインストールするのにMicrosoftのボリュームライセンスのインストーラが必要です'},
#  {'id': '895', 'text': 'Excelが使えなくなりました'},
#  {'id': '896', 'text': 'エクセルだけ起動できない'},
#  {'id': '897', 'text': 'エクセルを起動するとエラーが出て開くことができません。'},
#  {'id': '898', 'text': 'WORDが起動しない'},
#  {'id': '899', 'text': 'Excelが開けなくなった'},
#  {'id': '900', 'text': 'PowerPointが開けない'},
#  {'id': '901', 'text': 'パワーポイントが起動しない'},
#  {'id': '902', 'text': 'エクセルが起動しないので対処法を知りたい'},
#  {'id': '903', 'text': 'Excelが動かなくなった'},
#  {'id': '904', 'text': '突然L3DevMacでAquaにつながらなくなった'},
#  {'id': '905', 'text': 'L3Dev端末をaquaにつなげたい'},
#  {'id': '906', 'text': '開発PCがaquaに接続できない'},
#  {'id': '907', 'text': 'aquaの接続方法について'},
#  {'id': '908', 'text': '開発PCでaquaに接続できない場合の対応方法を教えてください。'},
#  {'id': '909', 'text': 'aquaに繋げたい'},
#  {'id': '910', 'text': 'L3Dev端末からAquaに接続したい'},
#  {'id': '911', 'text': 'aquaに接続出来ない'},
#  {'id': '912', 'text': 'L3Dev端末用の無線につなげたい'},
#  {'id': '913', 'text': 'aquaのパスワード教えてください。'},
#  {'id': '914', 'text': '準OA化の手順でLANコンバーターの使い方がよくわかりません'},
#  {'id': '915', 'text': '部門購入PCのセットアップURLへアクセスしたい'},
#  {'id': '916', 'text': '部門で購入した最新のWindows OSだと社内NWに接続できないのでしょうか。'},
#  {'id': '917', 'text': '準OA化作業をしています。LANコンバーターを接続したのですがインターネットに接続できません。'},
#  {'id': '918', 'text': '部門購入PCのセットアップURLへアクセスできる方法を教えてください'},
#  {'id': '919', 'text': '準OA化していますが最初のダウンロードページへのアクセス方法を知りたい'},
#  {'id': '920', 'text': 'CaMPについて問合せたい'},
#  {'id': '921', 'text': 'CaMPの権限が欲しい'},
#  {'id': '922', 'text': 'CaMPの管理部署を教えて欲しい'},
#  {'id': '923', 'text': 'CaMPの問合せ先はどこですか？'},
#  {'id': '924', 'text': 'CaMPについて確認したい'},
#  {'id': '925', 'text': 'CaMPの権限を取得したい'},
#  {'id': '926', 'text': 'CaMPについて'},
#  {'id': '927', 'text': 'Campについて'},
#  {'id': '928', 'text': 'クルーナビについて質問したい'},
#  {'id': '929', 'text': 'クルーナビのパスワードがわからない'},
#  {'id': '930', 'text': 'クルーナビについて確認したい'},
#  {'id': '931', 'text': 'iPadで今までクルーナビが見れていたが再起動したら開かなくなった。VPNは繋がっている'},
#  {'id': '932', 'text': '業務端末のPCでクルーナビにログイン出来ない'},
#  {'id': '933', 'text': 'クルーナビの問い合わせ窓口をしりたい'},
#  {'id': '934', 'text': 'インターネットは接続できるが、クルーナビにアクセスできません'},
#  {'id': '935', 'text': 'クルーナビにアクセスできません'},
#  {'id': '936', 'text': '社外で社内システムを閲覧したい'},
#  {'id': '937', 'text': '社外でOAPCを利用したい'},
#  {'id': '938', 'text': '外出先でOAPCを使いたい'},
#  {'id': '939', 'text': '社外でもPCが使えるようにしたい'},
#  {'id': '940', 'text': 'OAPCで社外環境から社内システムを利用するにはどのようにすれば良いですか'},
#  {'id': '941', 'text': 'OA端末を社外から利用したい'},
#  {'id': '942', 'text': '社外環境でOA標準端末から社内システムを利用したい'},
#  {'id': '943', 'text': '社外から社内システムを利用するのにはどうしたらいいですか？'},
#  {'id': '944', 'text': '社外環境でOAPCを使用したい'},
#  {'id': '945', 'text': 'OAPCで社外環境から社内システムを利用する'},
#  {'id': '946', 'text': 'L3Dev端末故障の為交換したい'},
#  {'id': '947', 'text': 'L3Dev端末が故障したので交換してほしい'},
#  {'id': '948', 'text': 'L3Dev端末の故障交換を実施してほしい'},
#  {'id': '949', 'text': 'L3Dev端末が故障した場合の対処方法を教えて欲しい'},
#  {'id': '950', 'text': '開発環境の端末か故障したので交換してほしい。'},
#  {'id': '951', 'text': 'L3Dev端末の故障交換をしてほしい'},
#  {'id': '952', 'text': '開発端末が故障したので交換したい'},
#  {'id': '953', 'text': '開発端末を故障交換したい'},
#  {'id': '954', 'text': 'L3Dev端末が故障したので、交換したい'},
#  {'id': '955', 'text': '開発端末が故障したので交換してほしい'},
#  {'id': '956', 'text': 'iPhone/iPadのTouch ID（指紋認証）のやり方を教えてください。'},
#  {'id': '957', 'text': 'iPhone/iPadのTouch ID（指紋認証）の登録方法を確認したい。'},
#  {'id': '958', 'text': 'iPhoneの指紋認証の手順を教えてほしい'},
#  {'id': '959', 'text': 'iPhone/iPadのTouch ID（指紋認証）の登録方法を教えてください。'},
#  {'id': '960', 'text': 'iPhone/iPadのTouch ID（指紋認証）に運用ルールはありますか。'},
#  {'id': '961', 'text': 'Googleのアプリケーションでのアドオン利用方法を教えて欲しい'},
#  {'id': '962', 'text': 'Googleドキュメントでアドオンを利用したい'},
#  {'id': '963', 'text': 'Googleのアドオンを利用したいです'},
#  {'id': '964', 'text': 'Googleスプレッドシートでアドオンを利用したい'},
#  {'id': '965', 'text': 'Chromeにアドオンをいれてもいいか'},
#  {'id': '966', 'text': 'Googleのアプリケーションでアドオンを利用する申請方法を教えて欲しい'},
#  {'id': '967', 'text': 'Google Workspaceのアドオンを利用したいです'},
#  {'id': '968', 'text': 'Googleプレゼンテーションでアドオンを利用したい'},
#  {'id': '969', 'text': 'IMSIタイプコードの確認方法を教えてほしい'},
#  {'id': '970', 'text': 'IMSIタイプコードが分らない'},
#  {'id': '971', 'text': 'IMSIタイプコードを確認したい'},
#  {'id': '972', 'text': '業務用携帯Bの新規申請に必要なIMSIタイプコードが不明'},
#  {'id': '973', 'text': 'IMSIタイプコードを調べたい'},
#  {'id': '974', 'text': '業務端末BのiPhoneのバックライトが点灯しない。'},
#  {'id': '975', 'text': '業務端末Aでバックライトが点灯しなくなりました。'},
#  {'id': '976', 'text': '業務端末Bのバックライトが光らなくなりました。'},
#  {'id': '977', 'text': '業務端末Bでバックライトが点灯しなくなりました。交換可能でしょうか。'},
#  {'id': '978', 'text': '業務端末AのiPhoneのバックライトが点灯しない。'},
#  {'id': '979', 'text': '業務端末Aで画面を輝度調整したが、暗いままです。'},
#  {'id': '980', 'text': '業務端末Aで輝度調整ができなくなりました。交換可能でしょうか。'},
#  {'id': '981', 'text': '業務端末Aのバックライトがつかなくなりました。'},
#  {'id': '982', 'text': '業務端末Aでバックライトが点灯しなくなりました。交換可能でしょうか。'},
#  {'id': '983', 'text': '業務端末Bで輝度調整ができなくなりました。交換可能でしょうか。'},
#  {'id': '984', 'text': '出荷統合システムについて確認したい'},
#  {'id': '985', 'text': '出荷統合システムについて問合せたい'},
#  {'id': '986', 'text': '出荷統合システムの問合せ先はどこですか？'},
#  {'id': '987', 'text': '出荷統合システムの管理部署を教えて欲しい'},
#  {'id': '988',
#   'text': 'Office365ライセンス認証時に「ユーザーID または、パスワードが正しくありません。もう一度試してみてください。」と表示された'},
#  {'id': '989',
#   'text': 'Office365でユーザーID または、パスワードが正しくありません。もう一度試してみてください。が発生する。'},
#  {'id': '990', 'text': 'パスワードが違うと表示されてOffice365ライセンス認証に失敗する'},
#  {'id': '991',
#   'text': 'Office365ライセンス認証時にユーザーID または、パスワードが正しくありません。もう一度試してみてください。と表示された'},
#  {'id': '992',
#   'text': 'Office365のライセンス認証で「ユーザーID または、パスワードが正しくありません。もう一度試してみてください。」と表示される'},
#  {'id': '993',
#   'text': 'Office365ライセンス認証時に「ユーザーID または、パスワードが正しくありません。もう一度試してみてください。」と表示されたのですがどうすればいいですか。'},
#  {'id': '994', 'text': 'ユーザー名が違うと表示されてOffice365ライセンス認証が出来ない'},
#  {'id': '995', 'text': '「この項目はもう使用できません」が表示されるのを解消したい'},
#  {'id': '996', 'text': '「この項目はもう使用できません」が表示された場合の対処方法を教えて欲しい'},
#  {'id': '997', 'text': 'SelfServiceからAdmin権限付与時「この項目はもう使用できません」が表示される'},
#  {'id': '998',
#   'text': 'SelfServiceからAdmin権限付与時「この項目はもう使用できません」が表示され、Admin権限が付与できない'},
#  {'id': '999', 'text': 'billing support.ad.intra.eaccess.netにアクセスできません。'},
#  ...]

# %%
assert len(queries_l) == query_len

# %%
import math

# %%
add_factor = 10 ** math.ceil(math.log10(len(queries)))
add_factor
# Out:
# 100000

# %%
corpus_l = []
corpus_to_id = {}
for i in range(len(corpus)):
    docid = str(add_factor + i)
    corpus_l.append({"id": docid, "title": "", "text": corpus[i]})
    corpus_to_id[corpus[i]] = docid

# %%
corpus_l
# Out:
# [{'id': '100000',
#   'title': '',
#   'text': 'Slackのゲストアカウントの有効期限が切れた（解除済みアカウント）場合は、ゲスト管理システムからゲスト新規登録申請と利用サービス登録申請を実施下さい。\n※ゲスト登録が有効期限内の場合は、マイゲスト一覧から利用サービス登録申請のみ実施下さい\n申請方法は下記手順を参照下さい。\n\n・【ゲスト管理システム】マニュアル-申請者向け\nhttps://docs.google.com/presentation/d/1Z0PUkjNUr9r2GCq5ZEEddd5jPUJg48kPMsCxv5Mtw_M/edit#slide=id.g1287222f34d_1_61\n\n申請の上長承認後、5営業日以内にアカウントが有効化されます。\n有効化完了後は下記メールが送信されますので、メールを確認次第、必要なチャンネルにゲストを招待して下さい。\n※ゲストをチャンネルに招待する際はメールアドレスではなくSlack上の氏名で検索下さい\n件名：【ゲスト管理】利用サービスプロビジョニングエラー対応完了通知\n\n■お問合せ先\n・OA Support Net\n\u3000http://oa.bb.local/oasupport/inquiry_web\n\u3000（投稿カテゴリ：Slack）'},
#  {'id': '100001',
#   'title': '',
#   'text': 'WHCの問合せについては、OAサポートデスクではサポート対象外となります。\n下記窓口が担当かと思われますので、直接問合せ願います。\n\n・ＩＴ部門（ＷＨＣ）工数管理窓口\n SBMGRP-WHC@g.softbank.co.jp\n\nまた、WHCの申請についても、OAサポートデスクではサポート対象外となります。\n下記窓口が担当かと思われますので、直接問合せ願います。\n\n・システムコード管理窓口\n SBMGRP-system-code@g.softbank.co.jp'},
#  {'id': '100002',
#   'title': '',
#   'text': 'GoogleChromeのインストール・アンインストール方法については、ソフトウェアセンターから実施して下さい。\n\n■インストール方法\nGoogleChromeのインストール方法については、ソフトウェアセンターから実施して下さい。\n・【SCCM】Windows向けソフトウェアセンター利用マニュアル\n http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/post/sccm_win10\n\nソフトウェアセンターからインストール不可の場合は、Admin権限取得の上、下記手順でインストールして下さい。\n1.Admin権限申請及び適用方法を実施する\n・【社内外共通】L2OAPC/準OAPC Admin権限申請・適用方法\n http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/admintekiyou_shanaigai\n2.下記リンクにアクセスする。\n\u3000https://drive.google.com/drive/folders/1XmkYaUoTWsYq-sOmC6XCuewUILBYINxW\n3.最新版のフォルダをデスクトップにコピーし、フォルダ内のインストーラー（.msi）をダブルクリックする\n※インストーラーをダブルクリック後もインストールできない場合は、インストーラーを右クリック＞管理者として実行を実施して下さい\n\n参考FAQ\n・Q.10-004\u3000Chromeブラウザがインストールできない\n https://sites.google.com/a/g.softbank.co.jp/helpg/discussion-board/chrome/10-004\n\n■アンインストール方法\n・【SCCM】Windows向けソフトウェアセンター利用マニュアル\n http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/post/sccm_win10\n※「インストール済みソフトウェア」（インストールのステータス）タブをクリックし、【Google Chrome Ver.xx.x.xxxx.xxx】をクリックし、アンインストールを実施して下さい。\n\nソフトウェアセンターからアンインストール不可の場合は、Admin権限取得の上、下記手順でアンインストールして下さい。\n1.Admin権限申請及び適用方法を実施する\n・【社内外共通】L2OAPC/準OAPC Admin権限申請・適用方法\n http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/admintekiyou_shanaigai\n2.Windowsキー+Rキーを同時押下し、ファイル名を指定して実行の画面で「appwiz.cpl」を入力し、OKをクリックする。\n3.「Google Chrome」の項目を選択し、「アンインストール」をクリックする。'},
#  {'id': '100003',
#   'title': '',
#   'text': 'ファイルなどのPDF化方法については、下記FAQを参照して下さい。\n\n・ファイルなどのPDF化手順について［FAQ No：F000158899］\n http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/faq/F000158899'},
#  {'id': '100004',
#   'title': '',
#   'text': 'AndroidでGooglePlay未登録アプリのインストール時、「インストールはブロックされました\u3000携帯端末のセキュリティ上の設定で供給元不明のApplicationのインストールをブロックしています」とエラーが表示された場合は、下記手順を実施して下さい。\n設定>その他設定>ロックとセキュリティ内の「提供元不明アプリ」にチェックを付ける\n※アプリのインストールが終わったら再度チェックを外して下さい'},
#  {'id': '100005',
#   'title': '',
#   'text': '業端A iPhone/iPadのiCloudへのバックアップについては、下記を参照下さい。\n・【iPhone/iPad】iCloudバックアップマニュアル\n http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/manual/icloud-backup'},
#  {'id': '100006',
#   'title': '',
#   'text': 'Viewでのプリンタ設定は、下記ページの「Viewで利用する場合」を参照下さい。\n ・複合機（プリンタ）設定\n http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/pc/printer'},
#  {'id': '100007',
#   'title': '',
#   'text': '暗号化ファイルの解除方法については、下記ページを参照して下さい。\n\n・暗号化ファイルの解除\n http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/setting/AzureRMS/rights/unlock'},
#  {'id': '100008',
#   'title': '',
#   'text': 'EUCの問合せについては、OAサポートデスクではサポート対象外となります。\n下記窓口が担当かと思われますので、直接問合せ願います。\n\n・SB C&S サービスデスク\n https://softbankcs.service-now.com/csqa?id=casoa_index'},
#  {'id': '100009',
#   'title': '',
#   'text': '部門PCを社内NW（L2）に接続するには、準OA化が必要となります。\n 詳細は、下記サイトをご覧いただけますでしょうか。\n \n・購入について ※準OAPCの要件をご確認下さい。\n http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/request/purchase\n \n・準OA化\n http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/request/semioapc'},
#  {'id': '100010',
#   'title': '',
#   'text': 'ブラウザのキャッシュクリアについては、下記手順を実施して下さい。\n\n■Windows \n●Chromeのキャッシュクリア\n 1.Google Chromeのブラウザを終了する。\n 2.下記にアクセスし【Cach.bat】をコピーし、デスクトップに貼り付ける\n  https://drive.google.com/drive/folders/1XmkYaUoTWsYq-sOmC6XCuewUILBYINxW\n 3．コピーした【Cache.bat】を実行する\n 4.再度、Google Chromeのブラウザを起動する\n\n■Mac\n●Chromeのキャッシュクリア\n1.commandキー＋Yキーを同時押下する\n2.「閲覧履歴データを消去する」をクリックする\n3.以下を設定する\n\u3000期間⇒全期間\n\u3000詳細⇒閲覧履歴\n\u3000\u3000\u3000\u3000ダウンロード履歴\n\u3000\u3000\u3000\u3000Cookieと他のサイトデータ\n\u3000\u3000\u3000\u3000キャッシュされた画像とファイル\n\u3000\u3000\u3000\u3000にチェックを入れる\n\u3000「データを消去」をクリックする\n4.commandキー＋Qキーを同時押下し、Chromeを終了させる\n●Safariのキャッシュクリア\n1.画面上部の履歴>すべての履歴を表示するをクリックする\n2.履歴を消去...＞消去の対象：全ての履歴＞履歴を消去をクリックする\n3.commandキー＋Qキーを同時押下し、Safariを終了させる'},
#  {'id': '100011',
#   'title': '',
#   'text': 'CI検索ツールについては、Chromeの拡張機能となりますので、下記マニュアルを参照して下さい。\n \n ●Chrome拡張機能一覧\nhttps://sites.google.com/a/g.softbank.co.jp/helpg/chrome-extension\n「CI Tools (by CITeam)」をインストールすると組織メーリングリスト、組織メーリングリスト、OAアカウント（エイリアス）等を検索できます。\n\n■検索方法\n・グループアドレス検索\nChromeブラウザ上の右上の黒い淵で四角い「a」の文字が書かれているロゴをクリック＞■グループ検索にてグループアドレスを入力\n・GoogleAppsユーザー検索\nChromeブラウザ上の右上の黒い淵で四角い「a」の文字が書かれているロゴをクリック＞■Google Appsユーザー検索にてOAアカウント（エイリアス）または氏名を入力'},
#  {'id': '100012',
#   'title': '',
#   'text': '業端Bの返却については手配元部門に返却下さい。\n返却時の必要な対応についても手配元部門に確認下さい。'},
#  {'id': '100013',
#   'title': '',
#   'text': 'Wドライブ容量については、50GBとなり、容量追加については、不可となります。 \n\n現在の容量で足りない場合は、使用しているファイルを精査し、容量を減らして下さい。\nまた、共有フォルダ等も活用して下さい。'},
#  {'id': '100014',
#   'title': '',
#   'text': '機種変更等で移行できない連絡先がある場合、下記ページを参照し、連絡先の移行を実施下さい。\n※回線切り替えがある場合、回線切り替え後に作業して下さい\n\n・Gmailアカウント同期で移行できない連絡先の移行\u3000マニュアル\n http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/ansinBackup2\n※MySoftBankのパスワードを忘れた場合、上記ページの「4. MySoftbank認証ができない場合」を確認下さい'},
#  {'id': '100015',
#   'title': '',
#   'text': '共有ドライブ内のファイルが削除できない場合は、下記にアクセスし、右上の虫眼鏡から下記文言で検索下さい。\n・Q.05-016\u3000共有ドライブ内のファイルを削除するには、どのような権限が必要ですか？\nhttps://sites.google.com/a/g.softbank.co.jp/helpg/discussion-board/document/05-016\n・05 - Googleドライブ（ドキュメント）に関する質問 - \nhttps://sites.google.com/a/g.softbank.co.jp/helpg/discussion-board/document'},
#  {'id': '100016',
#   'title': '',
#   'text': 'ワークスペースからのサインアウトと退出の違いについては下記となります\n\n▼サインアウト\n対象のワークスペースからサインアウトだけで再度SSO認証でサインインすることができます。\nサインイン方法については下記ページを確認下さい。\n\n■Windows\n・Windows版Slackマニュアル\nhttp://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/request/oa-saas/slack/win-setup\n\n■Mac\n・Mac版Slackマニュアル\nhttp://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/request/oa-saas/slack/mac-setup\n\n■iPhone/iPad\n・iPhone版Slackマニュアル\nhttp://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/request/oa-saas/slack/iphone-setup\n\n■Android\n・Android版Slackマニュアル\nhttp://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/request/oa-saas/slack/android-setup\n\n▼退出\nそのワークスペースから抜けることになるため、再参加は不可となります。\n再度参加が必要な場合は、ワークスペース管理者からの招待が必要となりますので退出はしない様、注意下さい。\n誤って退出した場合は下記を参照の上、対応して下さい。\n\n■組織ワークスペースから退出した場合\n該当組織ワークスペースの管理者へ再招待を依頼して下さい\n\nSlack管理者・アンバサダー一覧\nhttps://docs.google.com/spreadsheets/d/1xPsP7oLEk4Biwoexi2KT6aqXPzRsbLyj5iJy1VY8o0Y/edit#gid=393065120\n\n■組織ワークスペース以外から退出した場合\n下記情報を記載の上、WEB投稿で問合せして下さい\n\n・氏名：\n・メールアドレス：\n \n・OA Support Net\nhttp://oa.bb.local/oasupport/inquiry_web\n（カテゴリ：Slack）'},
#  {'id': '100017',
#   'title': '',
#   'text': 'PDFのパスワードを設定したい場合は、下記手順でパスワードを設定して下さい。\n ・AdobeAcrobat等編集ソフトを導入する方法\n ・Zipファイルに圧縮して圧縮時にパスワードをかける方法\n\n■AdobeAcrobatを利用する場合\n\u3000下記ページより利用申請を行い、AdobeAcrobatをインストールして下さい。\n・Adobe Acrobat DC利用について\n http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/AdobeAcrobatDC\n\n■Zipファイルを圧縮して圧縮時にパスワードを設定する場合\n●OAPC/準OAPCの場合\n\u3000ソフトウェアセンターよりLhaplusをインストールして下さい。\n\u3000Lhaplusについては、ソフトウェアセンターからインストールを実施して下さい。\n\u3000・【SCCM】Windows向けソフトウェアセンター利用マニュアル\n\u3000 http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/post/sccm_win10\n●Viewの場合\n\u3000Lhaplusインストール済みなので、そのまま利用して下さい'},
#  {'id': '100018',
#   'title': '',
#   'text': 'Zoomミーティングでイヤホン利用時にイヤホンから音声が聞こえない場合は、下記設定になっているかご確認下さい。\n\nZoomアプリの設定(歯車マーク)＞オーディオ\n＞スピーカー項目のプルダウンから「ヘッドホン」を選択'},
#  {'id': '100019',
#   'title': '',
#   'text': '共有グループの管理者を確認する場合は、下記にページを参照下さい。\n・Q.07-024\u3000グループの管理者を確認することはできますか？\nhttps://sites.google.com/a/g.softbank.co.jp/helpg/discussion-board/group/07-024\n\nなお、ご自身がメンバーになっているグループについては以下手順でも確認できます。\n\nOA Support Naviにアクセス＞Mypage＞詳細情報はこちら＞GoogleApps情報の青い人型のアイコンから管理者の確認\n\n・OA Support Navi\n http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/\n\n上記手順で解決しない場合は、OA Support Netへ下記情報を記載し、投稿下さい。\n\n ・グループアドレスのメールアドレス\n ・表示名\n\n・OA Support Net\n http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/inquiry_web\n（カテゴリ：GoogleApps)'},
#  {'id': '100020',
#   'title': '',
#   'text': '「VPNサーバとのネゴシエーションに失敗しました。」のエラーが発生した場合は、VPNの再インストールを試して下さい。\n\n■iPhone/iPad\n1．設定＞一般＞VPNとデバイス管理より下記プロファイルを削除下さい\n・Cybertrust DeviceiD～\n・iPhoneVPN～\n2．「[iPhone/iPad-VPN]証明書発行のお知らせ IMEI :・・・」メールに記載されている内容に従い、再インストールを実施して下さい。\n\n■Android\n下記ページを参照し、再インストールして下さい。\n・【Android】VPN設定\n http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/android/androidvpn'},
#  {'id': '100021',
#   'title': '',
#   'text': 'ゲスト管理システムの管理者グループに紐づくゲスト全員を別の管理者グループに移行したい場合は、下記手順を参照下さい。\n\n①ゲスト管理システムのゲスト新規登録画面で移行先管理者グループを選択して、ゲスト全員分のゲスト登録と利用サービスの新規申請を実施。\n②「【ゲスト管理】利用サービスプロビジョニングエラー対応完了通知」の受信を確認。\n（申請の承認完了後、5営業日以内に移行先管理者グループメンバー宛に届きます）\n③移行元管理者グループに紐づくゲスト全員の削除申請を実施。\n（ゲスト登録と利用サービス登録の有効期限を短くして申請して下さい）\n④削除完了後（設定した有効期限経過後）、必要に応じて移行元管理者グループを削除。\n\nなお、管理者グループはグループ名とメンバー変更が可能です。\nゲストを移行させる必要がない場合は、グループ名やメンバー変更にて対応下さい。\n\nゲスト管理システムの操作方法は下記手順を参照下さい。\n\n・【ゲスト管理システム】マニュアル-申請者向け\u3000\nhttps://docs.google.com/presentation/d/1Z0PUkjNUr9r2GCq5ZEEddd5jPUJg48kPMsCxv5Mtw_M/edit#slide=id.g1345deaa28b_0_80\n\n・ゲスト管理システム\nhttps://guest.in.g.softbank.co.jp/\n※正社員のみ利用可'},
#  {'id': '100022',
#   'title': '',
#   'text': 'Windows端末で起動時に「BitLocker」が表示され、回復キーを求められた場合は、下記FAQを参照して下さい。\n\n■L2 OAPC/準OAPC\n・BitLockerの画面が出てPCにログインできない[FAQ No:F170328001]\nhttp://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/faq/f170328001\n\nフォーム申請後、「【BitLocker】回復キー申請」の件名でメールが自動送信され、1～2時間程度で「【BitLocker】回復キー通知」のメール件名で回復キーの通知が行われます。\n※1～2時間経っても回復キーが通知されない場合は、担当部署にエスカレーション致しますので、「【BitLocker】回復キー申請」のメール内に記載されている「管理番号:BIT-*****」と該当コンピューター名を確認の上、OAサポートデスクへ問合せ下さい\n\n社員サポートセンター（ＯＡサポートデスク）：平日9:00～18:00\n●Slack：＃help-oaサポート（チャンネル名で検索してください）\n●Ｗｅｂ投稿：OA Support Navi ＞ 問合わせ ＞ Web http://oa.bb.local/oasupport/inquiry_web\n●PC受取/返却：OA Support Navi ＞ 問合わせ ＞ PC受取/返却 http://oa.bb.local/oasupport/inquiry_counter\n●コール予約：OA Support Navi ＞ 問合わせ ＞ コール予約（OA） http://oa.bb.local/oasupport/oa-call-reservation\n\nなお、以下の事象が発生している場合は、端末交換となります。\n・回復キー入力項目が表示されない\n・回復キーが発行できない\n・発行された回復キーで解除できない\n\n・【IoTAM】PC交換申請方法\nhttp://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/pc_exchange\n※解除キー入力不可の場合、データ復元は不可となります\n\n■L3DevPC/準L3DevPC\n下記マニュアルの1-9記載の通り、自身で任意の場所に保存しているのでそちらを確認下さい。\n・【L3Dev】HDD暗号化（Windows、Mac）\nhttp://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/manual/l3dev_encryption\n※OAサポートでは対応不可となります'},
#  {'id': '100023',
#   'title': '',
#   'text': '業端AのiPhoneで4G / 5G経由での通信ができない時、以下のFAQを参照して下さい。\n\n・【業端A】iPhoneで4G / 5G経由での通信が出来ない[FAQ No:F170526021]\n http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/keitai/faq_list_ios/f170526021\n\n上記FAQで改善しない場合、Web投稿より問合せ下さい。\n・Web\n http://oa.bb.local/oasupport/inquiry_web\n（カテゴリ：iPhoneiPad）'},
#  {'id': '100024',
#   'title': '',
#   'text': '業端A iPhone/iPadでMDM設定時「プロファイルのインストールができませんでした」が表示された場合は下記FAQの内容を実施下さい。\n\n・MDM設定時にエラーが発生する[FAQ No:F210310001]\n http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/faq/f210310001\n\n改善しない場合は、必要事項を確認の上、担当部署にエスカレーション致しますので、OAサポートデスクへ問合せ下さい。\n■必要事項\n・対象機種\n・IMEI\n\n社員サポートセンター（ＯＡサポートデスク）：平日9:00～18:00\n●Slack：＃help-oaサポート（チャンネル名で検索してください）\n●Ｗｅｂ投稿：OA Support Navi ＞ 問合わせ ＞ Web（http://oa.bb.local/oasupport/inquiry_web）\n●リモートサポート：OA Support Navi ＞ 問合わせ ＞ リモート/PC受取・返却（http://oa.bb.local/oasupport/inquiry_counter）\n●コール予約：OA Support Navi ＞ 問合わせ ＞ コール予約（OA）（http://oa.bb.local/oasupport/oa-call-reservation）'},
#  {'id': '100025',
#   'title': '',
#   'text': '「文書の取り出しができませんでした」と表示され、ゼロックス機の親展ボックスからスキャンデータの取り出しができない場合には、以下設定変更をして下さい。\n\n1.Windwowsキー＋Rキーを同時押下し、ファイル名を指定して実行に「inetcpl.cpl」を入力し、Enterキーを押下する。\n2.インターネットのプロパティ画面が表示されたら、詳細設定タブをクリックし、【HTTP 1.1を使用する】にチェックを入れる。'},
#  {'id': '100026',
#   'title': '',
#   'text': 'ソリューション販売管理システム（イントラマート）（物販系）の問合せについては、OAサポートデスクではサポート対象外となります。\n下記窓口が担当かと思われますので、直接問合せ願います。\n\n・仕入販売（開発・運転担当）\n SBTMGRP-SHIIRE-OP@g.softbank.co.jp'},
#  {'id': '100027',
#   'title': '',
#   'text': 'Googleのグループアドレスの不在通知設定についてグループアドレスに不在通知を設定することはできません。\n不在通知はアカウントでの設定項目となり、グループアドレスはアカウントとは異なりますので、不在通知を設定することはできません。'},
#  {'id': '100028',
#   'title': '',
#   'text': 'Fruits / VoiceNetの問合せについては、OAサポートデスクではサポート対象外となります。\n下記窓口が担当かと思われますので、直接問合せ願います。\n\n・Ｆｒｕｉｔｓ／Ｖｏｉｃｅｎｅｔ運転担当 \n sbtmgrp-unyou_fruits@g.softbank.co.jp'},
#  {'id': '100029',
#   'title': '',
#   'text': '業端へのアプリの配信や提供方法については、下記より問合せ下さい。\n・Web投稿\n\u3000http://oa.bb.local/oasupport/inquiry_web\n\u3000カテゴリ：iPhoneiPad\n\u3000\u3000\u3000\u3000\u3000\u3000Android'},
#  {'id': '100030',
#   'title': '',
#   'text': '「この不明な発行元からのアプリがPCに変更を加えることを許可しますか？」が表示された場合、管理者権限が必要となります。\n\n下記ページを参照し、Admin権限を取得して下さい。\n・【社内外共通】L2OAPC/準OAPC Admin権限申請・適用方法\n http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/admintekiyou_shanaigai'},
#  {'id': '100031',
#   'title': '',
#   'text': '業端A iPhone/iPad/Androidでyellowに接続できない場合は、下記FAQを参照下さい。\n■iPhone/iPad\n・【iPhone/iPad】yellowに繋がらない[FAQ No:F171201002]\n http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/keitai/faq_list_ios/f171201002\n■Android\n・【Android】yellowに繋がらない[FAQ No:F190320001]\n http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/keitai/faq_list_android/f190320001'},
#  {'id': '100032',
#   'title': '',
#   'text': 'Adobe Readerのインストール・バージョンアップ方法については、下記ページを参照下さい。\n・Adobe Readerインストール・バージョンアップ手順\n http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/AdobeReader_setting\n\nPDFファイルへのアプリケーション関連付け方法については、下記手順を実施下さい。\n1.スタート＞設定（歯車マーク）＞アプリ＞既定のアプリ\u3000の順に起動する\n2.既定のアプリの選択画面で一番下にある「ファイルの種類ごとに既定のアプリを選ぶ」をクリックし、「.pdf」の項目をクリックし「Adobe Acrobat Reader」を選択する'},
#  {'id': '100033',
#   'title': '',
#   'text': 'OAサポートデスク貸出のVGA変換アダプタを紛失した場合は、OAサポートデスクまで問合せ下さい。\n\n社員サポートセンター（ＯＡサポートデスク）：平日9:00～18:00\n●Slack：＃help-oaサポート（チャンネル名で検索してください）\n●Ｗｅｂ投稿：OA Support Navi ＞ 問合わせ ＞ Web http://oa.bb.local/oasupport/inquiry_web\n●PC受取/返却：OA Support Navi ＞ 問合わせ ＞ PC受取/返却 http://oa.bb.local/oasupport/inquiry_counter\n●コール予約：OA Support Navi ＞ 問合わせ ＞ コール予約（OA） http://oa.bb.local/oasupport/oa-call-reservation'},
#  {'id': '100034',
#   'title': '',
#   'text': 'OAPC/準OAPC/Macの利用者変更については、下記ページを参照して下さい。\n\n・利用者を変更したい\n http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/pc/tourokuhenkou\n※システムの仕様上、一括利用者変更機能はございませんので、1台ずつ利用者変更申請を行って下さい。\n※OA化していない部門PCについては、部門での管理となります\n※上長承認後、即時で反映されます（社内ネットワークには上長承認完了後から約30分で利用可能になります）\n\n以下については、利用者変更を実施しないと社内ネットワークへ接続できなくなります。\n必ず利用者変更を実施して下さい。\n・雇用形態が変更となり共通社員番号が変更になった方に紐づいているOAPCおよび準OAPC\n・退職された方に紐付いていたOAPCおよび準OAPC\n・退職された方に紐付いていたOAPCおよび準OAPCを新規入場者が再利用する場合'},
#  {'id': '100035',
#   'title': '',
#   'text': '部門管理PCにて外部記録媒体を使用する場合はライセンス管理システムでのUSB申請は不要となります。'},
#  {'id': '100036',
#   'title': '',
#   'text': 'RDSログイン後、アイコンが表示されない場合は、利用申請がされておりません。\n\nRDSを利用する場合は、下記フォームより申請して下さい。\n・RDS払い出し申請フォーム\n https://docs.google.com/a/g.softbank.co.jp/forms/d/e/1FAIpQLSe6fVPdhMG-4DRCLgEzQlt-MZsyyGQ34bGh55bdzIErCR_QPA/viewform\n※払い出しが完了すると申請者に対して、メール件名：「【必読】RDS環境に関する重要」が送付されます'},
#  {'id': '100037',
#   'title': '',
#   'text': 'Officeファイル起動時、「サブスクリプションの有効期限が切れています。」が表示された場合は下記ページを参照し、再認証を実施下さい。\n・【Office365】Office365起動時によくある認証エラー\n http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/%3Fpost_type%3Dpost%26p%3D40418'},
#  {'id': '100038',
#   'title': '',
#   'text': '業端BのMySoftBankの暗証番号は下記ページを参照下さい。\n・回線停止方法\n http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/keitai/keitai-a/rule/rimotowaipu/linestop\n\u3000（「暗証番号」参照）\n\n記載された暗証番号で認証できない場合はは下記ページを参照し、福岡BizSupportへ問合せ下さい。\n・業務用携帯電話Bのサービス内容変更をしたい\n http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/keitai/keitai-b/information'},
#  {'id': '100039',
#   'title': '',
#   'text': '準OAPCについては、部門で購入し、OA化したものとなりますので、OA側からの貸与はございません。\n \n 準OAPCが必要な場合は下記を参照し、部署で端末購入後、OA化して下さい。\n・PCを購入したい\n http://oa.bb.local/oasupport/pc/pc_buy'},
#  {'id': '100040',
#   'title': '',
#   'text': '「現在ログオン要求を処理できるログオンサーバーはありません。」または、「ドメインが利用できないため、この資格情報ではサインインできません。」が表示された場合は、下記を確認して下さい。\n \n・端末にL2の有線LANは接続していますか？\n※情報コンセントにはL2用・L3Dev用がありますので、ご注意下さい。\n・無線LAN Blueには接続していますか？\n・LANケーブルを交換してもログイン不可か？\n・NW接続可能な他の端末で利用しているLANケーブルを利用しても接続不可か？\n※OAカウンターで端末交換した場合、交換後から15分以上経過しないとログオンできません。\n\nまた、退職された方の端末を新規入場者が利用する場合は、利用者変更が必要となります。\n利用者変更については、下記より実施して下さい。\n\n・Service Catalog\n http://iotam.bb.local/OAService/catalog/pc\n（「利用者変更」から申請して下さい）\n利用者変更申請完了後、下記件名のメールが旧利用者、新利用者、新利用者の上長宛に送付されます。\nメール件名：【申請完了】利用者変更 RA**********\n\n申請完了後、約15分後にNWに接続可能となります。\n15分後も接続不可の場合は、一度、端末再起動後に接続をお試し下さい。\n\n参考FAQ\n・ログイン時に「現在ログオン要求をサービスするログオン サーバーがありません」が表示されログインができない[FAQ No:F190521001]\n http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/faq/f190521001'},
#  {'id': '100041',
#   'title': '',
#   'text': '3社以上とコネクトしている共有チャンネルから特定の会社のみコネクトを切り離したい場合は、切り離したい会社のみを記載の上、共有チャンネル停止申請を実施ください。\n\n・Slack共有チャンネル停止申請\nhttps://docs.google.com/forms/d/e/1FAIpQLSfUh-HmNZzYIY6D_zrpI91Q1oEh3G2FnUZpnjzWIsrtSpdgfw/viewform\n※SBゲスト・ConnectWSで利用している共有チャンネルの場合\n\n・SB SlackConnect(特定会社専用) チャンネル停止申請\nhttps://docs.google.com/forms/d/e/1FAIpQLSfO1cJ2I__8UEpHMntPerYqKg3QO1aaWEX9b6IFiUvxtjzPIw/viewform\n※SB SlackConnect(特定会社専用) WSで利用している共有チャンネルの場合'},
#  {'id': '100042',
#   'title': '',
#   'text': 'Officeソフト修復方法については、下記FAQを参照し、Officeの再インストールを実施して下さい。\n・Officeの再インストール方法を教えて下さい[FAQ No:F170922001]\n http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/faq/f170922001'},
#  {'id': '100043',
#   'title': '',
#   'text': '※2021/11/25より正社員以外（販売契約社員は除く）もOffice365の利用が可能になっています\n\u3000詳細については下記ページを参照下さい\n\u3000・正社員以外のOffice365利用について\n\u3000\u3000http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/office365_non-regularemployees\n\n正社員以外のOffice利用については下記ページを参照下さい。\n・正社員以外のOffice365利用について\n http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/office365_non-regularemployees\n\n販売契約社員については下記ページを参照下さい。\n・【販売契約社員】Office利用方法\n http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/setting/AzureRMS/windows/non_regular'},
#  {'id': '100044',
#   'title': '',
#   'text': '退職時の共有ドライブ内のファイルについては、下記にアクセスし、右上の虫眼鏡から下記文言で検索下さい。\n・Q.05-018\u3000退職時、共有ドライブ内のファイルはどうなりますか？\nhttps://sites.google.com/a/g.softbank.co.jp/helpg/discussion-board/document/05-018\n・05 - Googleドライブ（ドキュメント）に関する質問 - \nhttps://sites.google.com/a/g.softbank.co.jp/helpg/discussion-board/document'},
#  {'id': '100045',
#   'title': '',
#   'text': 'フォルダ利用率の確認方法については、FALCONシステムの管理フォルダ一覧画面でフォルダ名検索を実行すると、検索結果表示画面にて、フォルダ利用率が表示されます。\n※利用率は毎日AM3時前後時点の取得情報となります。\n\n・FSフォルダ作成・権限管理／FALCON\n http://falcon/\n\n参考FAQ\n・フォルダ利用率を調べたい[FAQ No:F170626012]\n http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/faq/f170626012'},
#  {'id': '100046',
#   'title': '',
#   'text': 'Macまたは業務端末からシングルサインオン（SSO）できない場合は、下記FAQを参照して下さい。\n\n・シングルサインオン（SSO）のログイン画面で、FAT端末からはログインできるのにMacや業務用携帯電話からはログインできない［FAQ No：F000200014］\n http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/keitai/F000200014'},
#  {'id': '100047',
#   'title': '',
#   'text': '開発DaaS利用時のマルチディスプレイ表示方法については、下記ページを参照下さい。\n・開発DaaS利用時のマルチディスプレイ表示方法\n http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/l3dev_multi-display'},
#  {'id': '100048',
#   'title': '',
#   'text': 'Zoomアカウント自動払出対象者は以下範囲です。\n所属会社：SBKK\n社員区分： 役員、従業員兼務役員、執行役員（委任型）、顧問、正社員、準社員、嘱託、特別嘱託、契約社員、特定臨時社員、受入出向社員\n本務兼務区分：SBKK本務（SBKK本務のみ対象）\n\nアカウントは入社日または発令日の翌日までに払出されます(申請不要)'},
#  {'id': '100049',
#   'title': '',
#   'text': '現在、OAMac化可能な対象OSについては、下記ページを参照して下さい。\n\n・OA化可能なOSについて\n http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/mac/os-version'},
#  {'id': '100050',
#   'title': '',
#   'text': 'Gmail上で下記のメッセージが表示された場合は、FAQを参照して下さい。\n\nメッセージ\n「このメールにはご注意下さい\u3000ウィルスや悪質なリンクが含まれている可能性があります」\n「ウィルスの警告 – XX個の添付ファイルにウィルスまたはブロックされたファイルが含まれています」\n\n・Gmailでウイルス検知のメッセージが表示される[FAQ No:F180529002]\n http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/faq/f180529002'},
#  {'id': '100051',
#   'title': '',
#   'text': 'Admin権限申請が否認された場合、まずは下記をご確認下さい。\n\n・Admin権限付与時間までに上長の承認は完了していたか？\n・コンピューター名にOAPC（CXOAPC）/準OAPC（CXIRPC）以外のコンピューター名を入力していないか？\n・コンピューター名にViewのコンピューター名を入力していないか？\n→例：CXVIEW********\n・準OAPCでインベントリファイルアップロード直後にAdmin権限申請を行っていないか？\n→インベントリファイルアップロード直後はPureTerminal側に情報が登録されていないので、申請を行うことができません。\n\u3000インベントリファイルアップロードした翌営業日以降に申請可能となります。'},
#  {'id': '100052',
#   'title': '',
#   'text': 'FATPC上で音声が出力できない場合は以下手順を実施して下さい。\n\nOAPC（CXOAPC～）の場合\n■スピーカーの音量設定\n1.画面右下のスピーカーアイコンをクリックする。\n2.音量を調整し、音声が出力されるか確認する。\n\n■キーボード・ボタン操作での音声出力設定\n\u3000各メーカーにより異なりますので、下記を確認して下さい。\n・Lenovo\n→キーボードFn+F1キー押下もしくはF1キー押下でON/OFF設定\n※準OAPC（CXIRPC～）の場合は各メーカーに直接確認下さい\n\n■Webブラウザの音声が出力されない場合\n1.Windowsキー+Rキー同時押下しファイル名を指定して実行を起動して「inetcpl.cpl」を入力し、OKをクリックする。\n2.詳細設定タブをクリックし、マルチメディアの項目にある「Webページのサウンドを再生する」にチェックを入れ、OKをクリックする。\n\n■サウンドドライバー再インストール\n\u3000Admin権限を取得の上、サウンドドライバーを再インストールして下さい。\n・【社内外共通】L2OAPC/準OAPC Admin権限申請・適用方法\n http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/admintekiyou_shanaigai\n ドライバーダウンロード先については、各メーカーのホームページを参照して下さい。\n・Lenovo\n https://support.lenovo.com/jp/ja/solutions/ht100199\n※準OAPC（CXIRPC～）の場合は各メーカーに直接確認下さい\n\n上記手順で改善しない場合は、端末交換となりますので、PC管理システムより申請して下さい。\n・【IoTAM】PC交換申請方法\nhttp://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/pc_exchange\n※準OAPC（CXIRPC～）の場合は上記手順を実施し、改善できない場合は、各メーカーに直接確認下さい'},
#  {'id': '100053',
#   'title': '',
#   'text': 'RDSの利用申請方法については、下記フォームより申請して下さい。\n\n・RDS払い出し申請フォーム\n https://docs.google.com/forms/d/e/1FAIpQLSe6fVPdhMG-4DRCLgEzQlt-MZsyyGQ34bGh55bdzIErCR_QPA/viewform\n※払い出しが完了すると申請者に対して、メール件名：「【必読】RDS環境に関する重要」が送付されます\n\n参考ページ\n・貸出・返却・利用者変更\n（Horizon View（正社員以外）ページのこちらのリンクを参照下さい\u3000をクリック）'},
#  {'id': '100054',
#   'title': '',
#   'text': 'OAPC等を利用し、社外・自宅からViewを利用する場合は、下記ページを参照して下さい。\n※Viewの利用には事前にTarteにて権限申請が必要となります\n\u3000未申請の場合は下記ページを参照し、申請を行って下さい\u3000\n\u3000・Horizon View\n\u3000\u3000http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/setup/View\n\u3000\u3000（上長承認の翌日以降に利用可能となります）\n\n■OAPC/準OAPC\n・View接続方法（OAPC 社外接続編）\n http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/%3Fpost_type%3Dpost%26p%3D22174\n\n■OAPC/準OAPC以外\n・View接続方法（Windows PC（OAPC以外）編）\n http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/%3Fpost_type%3Dpost%26p%3D22175\n\n■OAMac\n・View接続方法（Mac（OAMac）編）\n http://oa.bb.local/oasupport/manual/mac-viewkankyou-kyoutsuuriyou\n\n■OAMac以外\n・View接続方法（Mac（OAMac以外）編）\n http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/%3Fpost_type%3Dpost%26p%3D48797\n\n※社外NW自体の設定・接続不具合については、OAサポート外となります。'},
#  {'id': '100055',
#   'title': '',
#   'text': 'AzureRMSのアップグレードツール（AzureRMSCheck.vbs）については、下記に格納されておりますので、ダウンロード後、デスクトップ等に保存してから実施して下さい。\nhttps://drive.google.com/drive/folders/1St7hIbiPsWO5vXkqn-IBoNXO2TgmTTe8'},
#  {'id': '100056',
#   'title': '',
#   'text': '採用Dr （採用ドクター）の問合せについては、OAサポートデスクではサポート対象外となります。\n下記窓口が担当かと思われますので、直接問合せ願います。\n\n・クルー採用共有\n SBBGRP-salesstaffrecruitment@g.softbank.co.jp'},
#  {'id': '100057',
#   'title': '',
#   'text': '「メモリエラー」が表示された場合は、下記手順で事象が改善するか確認して下さい。 \n\n【OAPC・準OAPC】 \n■Chromeのキャッシュクリア\n・【Google Chrome】キャッシュクリア方法\n http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/chrome_clearcache\n■不要なファイル削除 \n1.下記にアクセスし、【ローカルデータ削除.bat】をコピーし、デスクトップ等に保存する\n\u3000https://drive.google.com/drive/folders/1Clpw778o4MOo-Z0FVYEYIe1hUJ3aNU3h\n2.【ローカルデータ削除.bat】をダブルクリックする。（コマンドプロンプトの画面が一瞬出力されます）\n3.ごみ箱を右クリックし、「ごみ箱を空にする」を実施する\n\n【OAMac】\n■Chromeのキャッシュクリア\n・【Google Chrome】キャッシュクリア方法\n http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/chrome_clearcache\n※「3.【Mac】キャッシュクリア（手動）」参照\n\n【View】\nChromeのキャッシュクリア後、View環境からサインアウトして下さい。\n・【Google Chrome】キャッシュクリア方法\n http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/chrome_clearcache\n・View環境サインアウト手順\nWindowsマーク＞人型マークにカーソルを合わせ、「サインアウト」をクリックする\n※「切断」ではサインアウトされないので、必ず上記手順を実施下さい'},
#  {'id': '100058',
#   'title': '',
#   'text': 'ブルーバック（ブルースクリーン）・ホワイトアウト・ブラックアウト・フリーズ・突然の電源断が発生する場合は、一度、電源ボタンを長押し、再度、電源投入後、症状が解消するか確認して下さい。\n\n参考FAQ\n・端末が固まる・遅い場合の対処方法を知りたい［FAQ No：F000200010］\n http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/faq/F000200010\n・ThinkPadL13のPCでスリープからの復旧時に強制再起動・ブルーバックが発生する［FAQ No：F210527001］\n http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/faq/f210527001\n\n解消しないまたは頻発する場合は、故障となりますので、以下を実施下さい。\n■OAPC\n\u3000端末交換を実施下さい。\n・【IoTAM】PC交換申請方法\nhttp://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/pc_exchange\n■準OAPC\n\u3000端末故障となりますので、下記を参照し、対応下さい。\n・準OAPCが故障してしまったので、修理したい[FAQ No:F191105002]\nhttp://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/faq/f191105002'},
#  {'id': '100059',
#   'title': '',
#   'text': 'ネットワーク管理GISの問合せ先については、OAサポートデスクではサポート対象外となります。\n下記窓口が担当かと思われますので、直接問合せ願います。\n\n・ＮＷ本部情報推進室ＧＩＳ管理\n SBBGRP-GIS@g.softbank.co.jp'},
#  {'id': '100060',
#   'title': '',
#   'text': '速度制限の解除方法については、下記を参照下さい。\n\n■業端A\n2021年10月現在、業端Aでは速度制限は実施しておらず、データ容量は自動追加プランとなっております。\n\n■業端B\n制限解除方法は契約者タイプコード（契約形態：個人・法人・業務用）により、方法が異なります。\n・個人：My SoftBankからの手続きか福岡Bizへの依頼\n・法人：法人コンシェルサイトからの手続きか福岡Bizへの依頼\n・業務用：My SoftBankからの手続きか福岡Bizへの依頼\n下記ページを参照し、手続き下さい。\n・法人コンシェルサイト\n https://portal.business.mb.softbank.jp/portal/BPS0001/;jsessionid=Xh1qbFbMSmc2QsfmLSK2HKMSBJYLQvS0XL4p76sVYWVrdLYynnvW!-1848362821\n・業務用携帯電話Bのサービス内容変更をしたい\n http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/keitai/keitai-b/information'},
#  {'id': '100061',
#   'title': '',
#   'text': 'プロジェクトフォルダ管理者を追加したいが、管理者追加ボタンが表示されない場合、管理者が３名以上になっていないか確認して下さい。\n管理者登録は最大３名までとなっております。\n３名以上の登録は出来ませんので、どなたか削除して頂いた後、登録をお願いします。\n\n参考FAQ\n・FALCONの管理者を追加したいが、[管理者追加]ボタンが表示されない[FAQ No:F170626008]\n http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/faq/f170626008'},
#  {'id': '100062',
#   'title': '',
#   'text': '共有フォルダ上のファイルが読み取り専用になる場合は、下記情報を記載の上、OA Support Netに投稿して下さい。\n\n <提供必須情報>\n・対象フォルダパス\n・PCログインOAアカウント（エイリアス）\n・発生時期\n・周りのユーザも同じ症状か\n・OA環境（FATPC/DaaS/HorizonView/OAMac）\n・エラー画面の画面キャプチャ\n\n・Web投稿：OA Support Navi ＞ 問合わせ ＞ Web\n http://oa.bb.local/\n※カテゴリ：system>Falcon/ファイルサーバ'},
#  {'id': '100063',
#   'title': '',
#   'text': '販売職（SV）・販売契約社員のOAPC貸出・交換については、下記を確認の上、対応して下さい。\n\n■販売職（SV）\nIoTAM申請方法を確認し、OAPCの貸出・交換を実施下さい。\n\n■販売契約社員\n・ｶｽﾀﾏｰｹｱ＆ｵﾍﾟﾚｰｼｮﾝ本部以外の方\nIoTAMより交換申請を実施して下さい。\n・ｶｽﾀﾏｰｹｱ＆ｵﾍﾟﾚｰｼｮﾝ本部の方\nまずは店長・副店長にご確認頂き、その上で、店長・副店長より各窓口に連絡して下さい。\n\n【IoTAM申請方法】\n・【IoTAM】PC貸出申請方法\nhttp://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/pc_lending\n\n・【IoTAM】PC交換申請方法\nhttp://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/pc_exchange\n\nPCの利用が不要になった場合は下記ページを参照し、返却を行って下さい。\n・返却したい\n http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/pc/step3'},
#  {'id': '100064',
#   'title': '',
#   'text': 'インストール兼Admin権限付与申請時のインストーラ保管場所について、インストール申請の承認完了メールに記載されます。'},
#  {'id': '100065',
#   'title': '',
#   'text': '「Microsoft Online Services サインイン アシスタントはこのコンピュータにインストールされていません。管理者に問合せて下さい。」のメッセージが表示されファイルが開けない場合、下記FAQを実施して下さい。\n・[FAQ No:F170306001]AzureRMS権限をリフレッシュする手順が知りたい\n http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/faq/f170306001\n\n上記FAQで解消できない場合は下記を参照し、Office365の入れ直しを実施下さい。\n・Officeの再インストール方法を教えて下さい[FAQ No:F170922001]\n http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/faq/f170922001\n\n参考FAQ\n・[FAQ No:F170704001]Officeファイルを開くとメッセージが表示されファイルが開けない\n http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/faq/f170704001'},
#  {'id': '100066',
#   'title': '',
#   'text': 'インターネット接続が出来ない場合、まずは下記をご確認下さい。\n【ネットワーク接続状況の確認】\n■社内\n・社内有線LANまたは無線LAN blueには接続できているか？\n■社外\n・社外Wi-FIもしくはテザリング接続できているか？\n\n【各種サイトのアクセス状況】\n・社内システムはアクセス可能か？\n・Gmail、外部サイト（Yahoo、Google等）にアクセス可能か？\n \nGmail、外部サイト（Yahoo、Google等）にアクセスするにはZscalerの利用が必要です。\nZscalerにログインしていなく、インターネット接続できていない場合は下記を実施下さい。\n■OAPC / 準OAPC\n・【Windows】Zscaler Client Connectorログイン方法\n http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/zscaler_login_windows\n\n■OAMac\n・【Mac】Zscaler Client Connectorログイン方法\n http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/zscaler_login_mac\n\n参考FAQ\n・ネットワークには接続できるが、外部Webサイト・Gmailに接続できない［FAQ No：F000158884］\n http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/faq/f000158884'},
#  {'id': '100067',
#   'title': '',
#   'text': '業端Bで充電がされない場合は、他のケーブルを使用し、充電できるか確認下さい。\n\n・他のケーブルで充電できる場合\n\u3000ケーブルの故障となりますので、手配元部署に交換を依頼下さい。\n\n・他のケーブルでも充電できない場合\n\u3000端末自体の故障となりますので、手配元部署に交換を依頼下さい。'},
#  {'id': '100068',
#   'title': '',
#   'text': 'L3Devのファイルサーバー、チャットシステム、Proself等で接続不具合が発生した場合は、まずは、FAQを参照して下さい。\n・Proself FAQ\n https://docs.google.com/spreadsheets/d/1P7iKCDlTe8rERv3oH5iDrxOv782TSF144vitLn7xdkc/edit#gid=977654396\n\nFAQの内容で解決できない場合は、下記ページを参照して下さい。\n・L3Devのファイルサーバー、チャットシステム、Proselfに繋がらない\n http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/l3dev/l3devfcp'},
#  {'id': '100069',
#   'title': '',
#   'text': 'TAS系 （CrBS / CrBS-C / CrBS-T / DFCA / RTDA2-J / TAS-S L2 / TAS-S L3 / TAS-S L4 / TeBiAs社内メンテ / TOMAS / BS-DR / RISM-BP)・TASGRP・RTDAS2-Jの問合せについては、OAサポートデスクではサポート対象外となります。\n下記窓口が担当かと思われますので、直接問合せ願います。\n\n・ＴＡＳ運用チーム(SBTM TASGRP利用者連絡用)\n SBTMGRP-tasadmin@g.softbank.co.jp\n・ＴＡＳ系システムサポート (SBTM TAS系システムのユーザからの問合せ用アドレス)\n sbtmgrp-tassupport@g.softbank.co.jp'},
#  {'id': '100070',
#   'title': '',
#   'text': '弁済金については、下記ページを参照下さい。\n・弁済金について\n http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/keitai/keitai-a/rule/bensai'},
#  {'id': '100071',
#   'title': '',
#   'text': 'OA提供外のソフトウェアをインストールしたい場合は下記ページを参照して下さい。\n\n・OA提供外のアプリをインストールする\n http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/setting/AppOtherOaIns\n・ソフトウェアをインストールしたい\n http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/request/software/use\n・ライセンス是正対応\n http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/request/correction\n※各ソフトウェアのインストール方法については、ソフトウェアの提供元に確認して下さい\n\nなお、該当のソフトウェアを利用する前に使用禁止ソフトウェアに該当していないか確認下さい。\n・禁止ソフトウェア\n http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/request/software/use/confirmation/bansoft\n通達：禁止ソフトウェアの利用規制強化について\n http://sb-erp.bb.local/index.html#showCoverView?next=views%2Fhrm%2Fbbs%2FBbsSearchView&params%5bbbsId%5d=NT01300202313862\n\n参考：\nソフトウェアインストールについては、Admin権限が必要となります。\n・【社内外共通】L2OAPC/準OAPC Admin権限申請・適用方法\n http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/admintekiyou_shanaigai'},
#  {'id': '100072',
#   'title': '',
#   'text': 'OAPCの自宅・社外ネットワークへの接続方法については、OAサポート外となります。\n\n自宅・社外NWへ接続不可の場合は、直接社外ネットワークの提供元に確認して下さい。'},
#  {'id': '100073',
#   'title': '',
#   'text': 'OA払い出しOAMacの新規・一時貸出、故障/希望交換については、提供を終了致しました。\n※参考通達\n・OAMac提供終了のご案内\n http://sb-erp.bb.local/index.html#showCoverView?next=views%2Fhrm%2Fbbs%2FBbsSearchView&params%5bbbsId%5d=NT01300201705917\n\n業務上、Macを利用する必要がある場合は、部門にてMacを購入し、OAMac化を実施して下さい。\n・Macを購入したい\n http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/mac/konyu\n・部門MacのOAMac化手順\n http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/mac/oamac-change\n\nOA払い出しのOAMac（コンピュータ名：ISCMAC130）をWindowsのOAPCに交換したい場合は、対象端末のコンピュータ名を確認の上、下記まで問合せ下さい。\n\n社員サポートセンター（ＯＡサポートデスク）：平日9:00～18:00\n●Slack：＃help-oaサポート（チャンネル名で検索してください）\n●Ｗｅｂ投稿：OA Support Navi ＞ 問合わせ ＞ Web http://oa.bb.local/oasupport/inquiry_web\n●PC受取/返却：OA Support Navi ＞ 問合わせ ＞ PC受取/返却 http://oa.bb.local/oasupport/inquiry_counter\n●コール予約：OA Support Navi ＞ 問合わせ ＞ コール予約（OA） http://oa.bb.local/oasupport/oa-call-reservation'},
#  {'id': '100074',
#   'title': '',
#   'text': '開発DaaS環境アクセス時間短縮方法については、下記ページを参照下さい。\n・開発DaaS環境アクセス時間短縮方法\n http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/l3dev_daas-speedup'},
#  {'id': '100075',
#   'title': '',
#   'text': 'O&Mの問合せについては、OAサポートデスクではサポート対象外となります。\n問合せについては、下記ページのフォームより問合せ願います。\n\n・統合ヘルプデスク\n https://open-ui.biz/cms/'},
#  {'id': '100076',
#   'title': '',
#   'text': '全社員宛にGmailを送信したい場合は、下記を参照下さい。\n・Q.03-053\u3000Gmailで全社員宛てのメールを送信する方法を教えてください\n https://sites.google.com/a/g.softbank.co.jp/helpg/discussion-board/gmail/03-053'},
#  {'id': '100077',
#   'title': '',
#   'text': 'Gmailの画面左側の項目をスクロールし「もっと見る」をクリックし、その中の「ゴミ箱」に対象のメールが残っているかご確認下さい。\nもし、ゴミ箱からも削除されている場合は、大変申し訳ございませんが、復元することはできません。'},
#  {'id': '100078',
#   'title': '',
#   'text': 'CRMの問合せについては、OAサポートデスクではサポート対象外となります。\n下記窓口が担当かと思われますので、必要情報を確認の上、直接問合せ願います。\n\n■必要情報 \n ・コンピューター名\n\n・CRMインフォ運転T\n sbmgrp--crminfo-unten@g.softbank.co.jp'},
#  {'id': '100079',
#   'title': '',
#   'text': 'SBTM OMS 作スケ （サスケ）の問合せについては、OAサポートデスクではサポート対象外となります。\n下記窓口が担当かと思われますので、直接問合せ願います。\n\n・作スケヘルプデスク（ＣＳ本部）\n sbtmgrp-sasuke_help@g.softbank.co.jp\n・ＯＭＳ・作スケ（運用・開発担当）\n sbtmgrp-oms-wm@g.softbank.co.jp'},
#  {'id': '100080',
#   'title': '',
#   'text': '以下事象で正常にSSO認証できない場合はChromeのキャッシュクリアを実施下さい。\n・SSO認証画面が表示されない\n・「情報ログインしました」が表示される\n・「不正なハンドラによる認証の例外」が表示される\n・「Error403--Forbidden」が表示される\n・再度認証画面に戻ってしまう\n\n■Chromeのキャッシュクリア\n1.Google Chromeの画面で、「Ctrl」+「Shift」+「Del」キーを押下\n2.「期間」で「全期間」を選択\n 次の項目にチェックが入っていることを確認し、データを削除する\n・閲覧履歴\n・Cookie と他のサイト データ\n・キャッシュされた画像とファイル\n3．Google Chromeを再起動\n※「×」ボタンではなく、Google Chromeの画面右上の3つの点が縦に並んだマークをクリック→「終了」で閉じた後、再度立上げ、再ログインをお願いいたします\n\nChromeキャッシュクリア後もSSO認証画面が表示されない場合は、ログオンしようとしているOAアカウント（エイリアス）を確認の上、担当部署にエスカレーション致しますので、OAサポートデスクへ問合せ下さい。\n\n社員サポートセンター（ＯＡサポートデスク）：平日9:00～18:00\n●Slack：＃help-oaサポート（チャンネル名で検索してください）\n●Ｗｅｂ投稿：OA Support Navi ＞ 問合わせ ＞ Web http://oa.bb.local/oasupport/inquiry_web\n●PC受取/返却：OA Support Navi ＞ 問合わせ ＞ PC受取/返却 http://oa.bb.local/oasupport/inquiry_counter\n●コール予約：OA Support Navi ＞ 問合わせ ＞ コール予約（OA） http://oa.bb.local/oasupport/oa-call-reservation'},
#  {'id': '100081',
#   'title': '',
#   'text': '準OAPCの主管部変更は、Pure Terminalの「利用者変更」で新たな部署の管理者へ変更します。\n \n・【IoTAM】PC利用者変更申請方法\nhttp://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/pc/userchange\n利用者変更申請完了後、下記件名のメールが旧利用者、新利用者、新利用者の上長宛に送付されます。\nメール件名：【申請完了】利用者変更 RA**********\n※利用者変更する準OAPCでOASYS利用している場合は下記ページを参照し、利用権限の削除を実施下さい\n\u3000・OASYS利用申請削除方法\n\u3000\u3000http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/%3Fpost_type%3Dpost%26p%3D33156'},
#  {'id': '100082',
#   'title': '',
#   'text': 'Zoomアカウント自動払出またはTarte申請による有料アカウント払出の方がホストの場合、Zoomミーティングの制限時間はありません。\n※24時間でタイムアウトする仕様です\nTarte申請による無料アカウント払出の方がホストの場合、40分の制限時間があります。'},
#  {'id': '100083',
#   'title': '',
#   'text': 'SBTM BSS/BOSの問合せについては、OAサポートデスクではサポート対象外となります。\n下記窓口が担当かと思われますので、直接問合せ願います。\n\n・【運転担当】ＳＢＴＭＣＣＢ運転\n sbtmgrp-ccb-operation@g.softbank.co.jp'},
#  {'id': '100084',
#   'title': '',
#   'text': 'アクセス権付与（メンバー追加）については、フォルダ管理者のみ対応可能となっております。\nフォルダ管理者にてメンバー追加を行って下さい。\nメンバー追加手順につきましては、下記マニュアルを参照して下さい。\n\n・FALCON プロジェクトフォルダ 利用マニュアル（全般）\n https://docs.google.com/a/g.softbank.co.jp/document/d/1zJN0vsGBR3dJwpIl9BzDKtdihg8W5K9ETlZ-YVQNtNI/edit'},
#  {'id': '100085',
#   'title': '',
#   'text': 'Mobileポスト便 （モバイルポスト便）は2022/1/31でサービス終了しています。\n\n今後はファイル授受システムを使用して下さい。\n・ファイル授受システム\n https://sb-biz.primedrive.jp/v2/browse#SBPOST\n・マニュアル\n https://sb-biz.primedrive.jp/help-new/web/ja/'},
#  {'id': '100086',
#   'title': '',
#   'text': 'AS/400 (エミュレータ)の問合せについては、OAサポートデスクではサポート対象外となります。\n下記窓口が担当かと思われますので、直接問合せ願います。\n\n・SB C&S サービスデスク\n https://softbankcs.service-now.com/csqa?id=casoa_index'},
#  {'id': '100087',
#   'title': '',
#   'text': 'View環境上にインストールされているアプリケーションについては、下記ページを参照して下さい。\n\n・インストール済アプリケーション一覧 \n http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/view/application/install'},
#  {'id': '100088',
#   'title': '',
#   'text': '販売契約社員がOffice365/AzureRMSをご利用する場合は、Tarteからの利用申請が必要となります。\n※2019/2/14以降、販売契約社員以外の正社員以外の方については、自動権限付与となります。\n \n・Tarte\nhttp://portal.tarte.bb.local/Tarte/sso\nSB社内以外からの接続は以下でログイン下さい。（VPN接続を除く）\nhttp://tarte.g.softbank.co.jp/Tarte/sso\n （画面左側のメニューの「申請」→「システム権限申請」→「AzureRMS_SB」をクリックし、申請ください。）\n※申請可能なエイリアス（OAアカウント）については、下記ページにて確認下さい\n・OA Support Navi ＞ MyPage\n http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/mypage\n（アカウント部分に記載されている「SB」のアカウントが今後利用するOAアカウント（エイリアス）となります）\n \n すでに申請済みの場合は上長承認後、翌日の午後以降からご利用になれます。'},
#  {'id': '100089',
#   'title': '',
#   'text': 'Blueの接続方法については、下記ページを参照して下さい。\n\n・Blue\n http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/setting/blue\n※Blueのパスワードについては、セキュリティ上、非公開となります\n\n自動接続できなくなった場合\n■Windows\n下記FAQを参照して下さい。\n・スタンバイから復帰後、Wi-Fiが再接続されない[FAQ No:F180515001]\n http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/faq/f180515001\n\n■Mac\n下記FAQを参照して下さい。\n・[FAQ No:F170417004]【Mac】インターネットにアクセスできない\n http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/faq/f170417004'},
#  {'id': '100090',
#   'title': '',
#   'text': 'ワークスペースについては、個人での作成は不可となります。\n※「ワークスペースを追加する」の項目が存在しますが、使用禁止となります'},
#  {'id': '100091',
#   'title': '',
#   'text': 'iPhone/iPadで「PCとUSBケーブル接続の画面が表示される」場合は、下記FAQを参照下さい。\n・【iPhone/iPad】iTunesに接続を請うアイコンが表示された[FAQ No:F171130002]\n http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/keitai/faq_list_ios/f171130002\n\n解消しない場合は担当部署にエスカレーション致しますので、OAサポートデスクへ問合せ下さい。\n社員サポートセンター（ＯＡサポートデスク）：平日9:00～18:00\n●Slack：＃help-oaサポート（チャンネル名で検索してください）\n●Ｗｅｂ投稿：OA Support Navi ＞ 問合わせ ＞ Web（http://oa.bb.local/oasupport/inquiry_web）\n●リモートサポート：OA Support Navi ＞ 問合わせ ＞ リモート/PC受取・返却（http://oa.bb.local/oasupport/inquiry_counter）\n●コール予約：OA Support Navi ＞ 問合わせ ＞ コール予約（OA）（http://oa.bb.local/oasupport/oa-call-reservation）'},
#  {'id': '100092',
#   'title': '',
#   'text': 'Wドライブについては、暗号化が実施されております。\nまた、Wドライブがマウントされていない状態でも暗号化は実施されております。'},
#  {'id': '100093',
#   'title': '',
#   'text': '共有ドライブ内で削除したファイルの復元方法については、下記にアクセスし、右上の虫眼鏡から下記文言で検索下さい。\n・Q.05-017\u3000削除した共有ドライブ内のファイルの復元はできますか？\nhttps://sites.google.com/a/g.softbank.co.jp/helpg/discussion-board/document/05-017\n・05 - Googleドライブ（ドキュメント）に関する質問 - \nhttps://sites.google.com/a/g.softbank.co.jp/helpg/discussion-board/document'},
#  {'id': '100094',
#   'title': '',
#   'text': '無料のZoomアカウントを社内のメールアドレス（@g.softbank.co.jp）で個別に作成することは禁止です。\n※会社貸与アドレスの個人利用はセキュリティ上のリスクがあるため、無料のZoomアカウントを作成して会議を主催することは厳禁（セキュリティ違反）です。'},
#  {'id': '100095',
#   'title': '',
#   'text': 'Zoomの自動払出対象（SBKK本務の正社員）もしくは自動払出対象外でTarte申請済みにも関わらず、サインイン時に「あなたの現在のものとは異なるZoomアカウントにサインインしています。新しいアカウント管理者にあなたを招待するように求めてください。」と表示される場合、他会社等（SBKK全社展開以外のZoomテナント）に@g.softbank.co.jpのメールアドレスでアカウント登録があることが原因で全社展開のZoomアカウントが払出しされていない可能性があります。（Zoomの仕様上、同一メールアドレスで複数テナントにアカウント登録できないため）\n\n今後、SBKKの業務としてZoomにサインインしての利用が必要な場合、その旨記載の上、WEB投稿で問合せ下さい。\nなお、全社展開のZoomを利用する場合、今まで利用していた他会社等のZoomにはサインインできなくなりますので了承願います。\n\n・Web投稿\n http://oa.bb.local/oasupport/inquiry_web\n カテゴリ：Zoom\n\n逆に、他会社の業務としてZoomにサインインしての利用が必要な場合、他会社のアカウントを利用することになるため、全社展開のアカウントは払出しできません。\nもし、SBKKのミーティングに参加する必要がある場合はサインインせず「ミーティングに参加」から参加して下さい。\n※他会社の業務でZoomを利用する場合はその会社のPCを利用して下さい（SBKKのPCで他会社の業務をすることは禁止）'},
#  {'id': '100096',
#   'title': '',
#   'text': 'L3/L3DevエリアからL2環境を使いたい場合は下記ページを参照下さい。\n\n・L3/L3DevエリアからL2環境を使いたい場合\n http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/%3Fpost_type%3Dpost%26p%3D16459'},
#  {'id': '100097',
#   'title': '',
#   'text': 'OAPC以外（その他デバイス(プリンタ、IP電話、TV会議など））での無線LAN blueの利用については、下記リンク先を参照頂き申請をお願いいたします。\n・端末認証\nhttp://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/request/deviceAuthentication\n※端末区分などにより接続の可否についてライセンス窓口にて確認致します'},
#  {'id': '100098',
#   'title': '',
#   'text': '業端Bで発注を希望する端末・USIMの金額を確認したい場合は下記ページを参照下さい。\n・価格確認方法（業端B）\n http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/keitai/keitai-b/price\n\n新機種等でオンラインショップとクルーナビいずれにも記載がない場合、Web投稿して下さい。\n・Web投稿\n\u3000http://oa.bb.local/oasupport/inquiry_web\n\u3000カテゴリ：業務用携帯B\n\u3000\u3000\u3000\u3000\u3000\u3000業務用携帯B>業務用携帯管理システム（IoTAM）'},
#  {'id': '100099',
#   'title': '',
#   'text': '部門PCにソフトウェアをインストールする場合のライセンス管理システムでの申請方法については、以下手順で申請を行って下さい。\n\n申請メニュー＞インストール兼Ａｄｍｉｎ権限付与申請＞インストール情報 [追加]ボタンクリック＞インストールユーザ/ＰＣ情報  [検索]ボタンクリック＞インストール検索で「その他PC追加」をクリックし、検索を実施行って下さい。'},
#  {'id': '100100',
#   'title': '',
#   'text': '退職者が送ってきた会議通知を削除したい場合は、会議通知を受けた各人のカレンダーで会議の削除を実施して下さい。\n削除できない場合は担当部署にエスカレーション致しますので、OAサポートデスクへ問合せ下さい。\n\n社員サポートセンター（ＯＡサポートデスク）：平日9:00～18:00\n●Slack：＃help-oaサポート（チャンネル名で検索してください）\n●Ｗｅｂ投稿：OA Support Navi ＞ 問合わせ ＞ Web http://oa.bb.local/oasupport/inquiry_web\n●PC受取/返却：OA Support Navi ＞ 問合わせ ＞ PC受取/返却 http://oa.bb.local/oasupport/inquiry_counter\n●コール予約：OA Support Navi ＞ 問合わせ ＞ コール予約（OA） http://oa.bb.local/oasupport/oa-call-reservation'},
#  {'id': '100101',
#   'title': '',
#   'text': "A'OMAI（アオマイ）の問合せについては、OAサポートデスクではサポート対象外となります。\n下記窓口が担当かと思われますので、直接問合せ願います。\n\n・情報ｼｽﾃﾑ統括 情報ｼｽﾃﾑ本部 ﾓﾊﾞｲﾙｼｽﾃﾑ統括部 顧客ｼｽﾃﾑ部 GINIEｼｽﾃﾑ課\n el-support@jcei.co.jp"},
#  {'id': '100102',
#   'title': '',
#   'text': 'L3アカウントのパスワードリセット（不明）については、Tarteからパスワードリセットを実施して下さい。\n\n・Tarte\nhttp://portal.tarte.bb.local/Tarte/sso\nSB社内以外からの接続は以下でログイン下さい。（VPN接続を除く）\nhttp://tarte.g.softbank.co.jp/Tarte/sso\n※所属部署の上長の方のみから申請可能となります。\n\nTarteでのパスワードリセット方法については、下記マニュアルを参照して下さい。\n・【Tarte】ワークフロー利用マニュアル_L3アカウント初期設定\n https://drive.google.com/drive/folders/1c2f-j0siOBg1iml7YzfXvjkG-bM-1Y_Q'},
#  {'id': '100103',
#   'title': '',
#   'text': 'iPhone端末からAndroid端末への移行方法については、下記ページを参照下さい。\n\n・iPhone→Androidへの移行\n http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/android/bigning'},
#  {'id': '100104',
#   'title': '',
#   'text': 'ソフトウェア担当者を変更したい場合は、フォームよりご依頼下さい。\n\n・ソフトウェア/PCデバイス担当者変更依頼\nhttps://docs.google.com/forms/d/e/1FAIpQLSc4it3YLi4loyL7mix9Lu--dJ_YzRtApW4PgPd1NSPI6zyVdg/viewform\n※部ごとで3名設定可能です'},
#  {'id': '100105',
#   'title': '',
#   'text': '業端Bのコンテンツ登録については、My SoftBankより登録下さい。\nただし、請求群や契約区分により登録できない場合がございます。\n\n不明点がある場合、回線情報（MSN・ICCID・請求群・契約者タイプコード）および登録希望コンテンツを記載の上、Web投稿して下さい。\n・Web投稿\n http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/inquiry_web\n\u3000カテゴリ：業務用端末B>業務用携帯管理システム（IoTAM）'},
#  {'id': '100106',
#   'title': '',
#   'text': 'MSN確認方法は以下となります。\n\n【iPhone/iPad】\niPhone：設定＞電話＞自分の番号\niPad： 設定＞一般＞情報のデータ通信契約番号\n・【業端A】iPadの「MSN（データ通信契約番号）」を確認したい[FAQ No:F170530004]\nhttp://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/keitai/faq_list_ios/f170530004\n\n【Android】\n設定＞端末情報＞端末の状態の電話番号\n\n【ガラケー】\nメニュー→0→電話番号\n\n上記手順で確認できない場合は一度、SIMを抜き挿しし、再起動で改善するか確認して下さい。\n・【iPhone/iPad】強制再起動の方法\n http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/manual/iOS-reboot\n・【Android】強制再起動の方法\n http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/manual/android-reboot\n\n上記手順で確認できない場合は、下記情報を確認の上、対応下さい。\n■必要事項\n・機種名\n・共通社員番号\n・ICCID\n\n■業端A\n・Web投稿\n http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/inquiry_web\nカテゴリ：iPhoneiPad>業務用携帯管理システム（IoTAM）\n                  Android>業務用携帯管理システム（IoTAM）\n\u3000\u3000\u3000\u3000\u3000業務用端末B>業務用携帯管理システム（IoTAM）\n■業端B\n 手配元部署に確認して下さい。\n\n参考FAQ\n・【業端A】「電話番号」「データ通信契約番号」欄の表示が不明となっている[FAQ No:F170526024]\n http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/keitai/f170526024'},
#  {'id': '100107',
#   'title': '',
#   'text': 'プロジェクトフォルダに対して、グループアドレスへのアクセス権限付与することは仕様上できません。\n・FALCON  プロジェクトフォルダ 利用マニュアル（全般） \n https://docs.google.com/document/d/1zJN0vsGBR3dJwpIl9BzDKtdihg8W5K9ETlZ-YVQNtNI/edit\n 「セキュリティグループ一覧 画面」\n 「セキュリティグループ新規作成手順」を確認し、FALCON上で新しいグループを作成する形となります。'},
#  {'id': '100108',
#   'title': '',
#   'text': 'Slackサインイン時に下記メッセージまたは同じような内容のメッセージが表示される場合は、Chromeのバージョンアップが必要です。\n\n■メッセージ\n・このブラウザは、yyyy年mm月dd日以降サポート対象外になります。Slack を使い続けるにはブラウザを更新してください。\n・このブラウザに対応していません\n\n下記手順を確認の上、最新バージョンのChromeをインストールして下さい。\n\n・Google Chrome再インストール方法\nhttp://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/%3Fpost_type%3Dpost%26p%3D35747'},
#  {'id': '100109',
#   'title': '',
#   'text': 'Zoomミーティングの参加者一覧の確認方法は下記を参照下さい。\n※ミーティング中に参加者一覧を抽出することはZoomの仕様上不可\n\n■手順\n①ミーティング終了後にホストにて下記URLにアクセス\nhttps://zoom.us/account/my/report#/\n②検索条件を入力して検索後、対象ミーティングの参加者の数をクリック\n\nZoomのレポート機能については下記ページも参照下さい。\n・Zoom レポート入門\nhttps://support.zoom.us/hc/ja/articles/201363213-%E3%83%AC%E3%83%9D%E3%83%BC%E3%83%88%E3%81%AE%E5%9F%BA%E6%9C%AC%E6%93%8D%E4%BD%9C'},
#  {'id': '100110',
#   'title': '',
#   'text': 'OAMacでのblue接続時の閲覧可能サイトについては下記ページを参照して下さい。\n\n・Macローカルで可能なこと・不可能なこと\nhttp://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/mac/mac-local'},
#  {'id': '100111',
#   'title': '',
#   'text': '端末交換後の返却ルールについては下記となります。\n\n【業端A】\n交換後、旧端末については2週間以内に返却下さい。\n返却頂けない場合、2016年8月12日配信通達「【業務用携帯電話A】 運用ルール強化・徹底について（返却ルール）」の通り、弁済金の対象となります。\nhttp://sb-erp.bb.local/index.html#showCoverView?next=views%2Fhrm%2Fbbs%2FBbsSearchView&params%5bbbsId%5d=NT01100201603807\n\n【業端B】\n部門手配の業端Bの場合は部門管理者に相談下さい。'},
#  {'id': '100112',
#   'title': '',
#   'text': '固定IPアドレスの申請方法については、下記ページを参照下さい。\n\n・ネットワーク作業申請\n https://sites.google.com/a/g.softbank.co.jp/nw-shen-qing/'},
#  {'id': '100113',
#   'title': '',
#   'text': '「このブックを開くための権限がありません。別の資格情報を使ってファイルを開きます」が表示された場合は、下記手順を実施して下さい。\n※手順1～4を順番に実施し、その手順で解決しない場合は、次の手順を実施して下さい\n\n■手順1\n・Windows10の場合\n対象ファイルを右クリック＞RMSによる保護＞その場で保護＞会社定義の保護\n・Windows11の場合\n対象ファイルを右クリック＞その他のオプションを確認＞RMSによる保護＞その場で保護＞会社定義の保護\n\n■手順２\n※例としてExcelでの手順を記載しています\nWindowsマーク＞すべてのアプリ＞Excel＞ファイル＞情報＞ブックの保護＞アクセスの制限＞テンプレートの取得\n\n■手順3\n下記FAQを実施して下さい。\n・[FAQ No:F170306001]AzureRMS権限をリフレッシュする手順が知りたい\n http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/faq/f170306001\n\n■手順4\n下記FAQを実施して下さい。\n・Officeの再インストール方法を教えて下さい[FAQ No:F170922001]\n http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/faq/f170922001\n\nの手順を実施して下さい。\n\n参考FAQ\n・[FAQ No:F170704001]Officeファイルを開くとメッセージが表示されファイルが開けない\n http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/faq/f170704001'},
#  {'id': '100114',
#   'title': '',
#   'text': '「アイコンを等間隔に整列」にチェックが入らないのは仕様となります。\n\nアイコンを等間隔に整列させたい場合は右クリック＞アイコンを等間隔に整列をクリックするとデスクトップのアイコンが\n等間隔に整列しますので、都度実施下さい。'},
#  {'id': '100115',
#   'title': '',
#   'text': '組織グループの全社員用と正社員用の違いについては、下記を参照下さい。\n・Q.07-028\u3000組織グループの全社員用と正社員用の違いを教えてください\n https://sites.google.com/a/g.softbank.co.jp/helpg/discussion-board/group/07-028'},
#  {'id': '100116',
#   'title': '',
#   'text': 'OASYS申請後、「サイバートラスト デバイスID発行のお知らせ」のメールが届かない場合は、受信トレイにない場合は迷惑メール、ごみ箱に入っている可能性があるので、そちらを確認下さい。\n\n一定期間迷惑メールフォルダに格納されていた場合、自動で削除されてしまいます。\nその場合はTarteにてOASYSの削除申請を行い上長承認後、再度、新規申請が必要となります。\n①OASYS利用申請削除方法\n http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/%3Fpost_type%3Dpost%26p%3D33156\n②OASYS\n http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/request/oasys\n※各々のページある「1.VPN申請方法」を実施下さい'},
#  {'id': '100117',
#   'title': '',
#   'text': '業端Bの製品情報についてはケータイガイドより参照下さい。\n・ケータイガイド\n http://cck-l2.bb.local/guide/menu_list/'},
#  {'id': '100118',
#   'title': '',
#   'text': '業務端末のVPN削除したい場合は、以下のマニュアルを参照の上、削除申請を行って下さい。\n\n【iPhone/iPad】\n・iPhone/iPad VPN削除申請方法\n http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/%3Fpost_type%3Dpost%26p%3D32888\n\n【Android】\n・Android（OS13以上） VPN削除申請方法\nTarteで申請していませんので削除申請はありません'},
#  {'id': '100119',
#   'title': '',
#   'text': 'Slackのデスクトップアプリのアップデート方法は下記手順を参照下さい。\n\n・Slack デスクトップアプリをアップデートする\nhttps://slack.com/intl/ja-jp/help/articles/360048367814-Slack-%E3%83%87%E3%82%B9%E3%82%AF%E3%83%88%E3%83%83%E3%83%97%E3%82%A2%E3%83%97%E3%83%AA%E3%82%92%E3%82%A2%E3%83%83%E3%83%97%E3%83%87%E3%83%BC%E3%83%88%E3%81%99%E3%82%8B'},
#  {'id': '100120',
#   'title': '',
# ...
#  {'id': '100964',
#   'title': '',
#   'text': '別々に登録された移動機とUSIMを移動機+USIMにする場合、管理情報変更よりUSIM・移動機の紐づけ変更が可能です。\n下記マニュアルを参照し、実施下さい。\n・【IoTAM】業務用携帯B 操作マニュアル（ユーザー展開用）\n https://docs.google.com/presentation/d/1-cjNwei93iZgDuexh6h6tzc6gFzdHH3EQS3Xljlwq1g/edit#slide=id.p#'},
#  {'id': '100965',
#   'title': '',
#   'text': 'モニター貸出・交換については、下記を参照して下さい。\n・【IoTAM】PC一時貸出・備品貸出申請方法\nhttp://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/temporary_loan\n\n■交換の場合\nOAサポートデスクから貸出したBenQ製のモニターのみ故障した場合、交換となります。\n交換を希望する場合は下記まで問合せ下さい。\n社員サポートセンター（ＯＡサポートデスク）：平日9:00～18:00\n●Slack：＃help-oaサポート（チャンネル名で検索してください）\n●Ｗｅｂ投稿：OA Support Navi ＞ 問合わせ ＞ Web http://oa.bb.local/oasupport/inquiry_web\n●PC受取/返却：OA Support Navi ＞ 問合わせ ＞ PC受取/返却 http://oa.bb.local/oasupport/inquiry_counter\n●コール予約：OA Support Navi ＞ 問合わせ ＞ コール予約（OA） http://oa.bb.local/oasupport/oa-call-reservation\n\u3000\u3000\u3000\u3000   \n\nなお、在庫数には限りがございますので、在庫が枯渇した場合は、払い出し不可となりますので、部門にて購入して下さい。'},
#  {'id': '100966',
#   'title': '',
#   'text': 'FALCONでのプロジェクトフォルダ申請の反映時間については、下記となります。\n\n\u3000各種申請\t                  \u3000\u3000\u3000\u3000\u3000\u3000\u3000処理が反映されるまでの時間\tメール通知先\n・フォルダ(ルート)フォルダ新規作成\u3000\u3000\u3000\u3000\u300030～60分\t\u3000\u3000\u3000\u3000\u3000\u3000\u3000\u3000申請者・管理者\n・フォルダ(ルート)フォルダ新規作成(エラー時)  30～60分\t\u3000\u3000\u3000\u3000\u3000\u3000\u3000\u3000申請者\n・フォルダ(ルート)削除\t\u3000\u3000\u3000\u3000\u3000\u3000\u3000\u3000\u3000\u300030～60分\t\u3000\u3000\u3000\u3000\u3000\u3000\u3000\u3000申請者\n・管理者変更\t\u3000\u3000\u3000\u3000\u3000\u3000\u3000\u3000\u3000\u3000\u3000\u3000 即時反映\t\u3000\u3000\u3000\u3000\u3000\u3000\u3000\u3000申請者・管理者\n・管理者削除\t\u3000\u3000\u3000\u3000\u3000\u3000\u3000\u3000\u3000\u3000\u3000\u3000 即時反映\t\u3000\u3000\u3000\u3000\u3000\u3000\u3000\u3000メール通知無し\n・サブフォルダ作成\t\u3000\u3000\u3000\u3000\u3000\u3000\u3000\u3000\u3000\u300030～60分\t\u3000\u3000\u3000\u3000\u3000\u3000\u3000\u3000申請者\n・サブフォルダ削除\t\u3000\u3000\u3000\u3000\u3000\u3000\u3000\u3000\u3000   30～60分\t\u3000\u3000\u3000\u3000\u3000\u3000\u3000\u3000申請者\n・メンバ追加\t\u3000\u3000\u3000\u3000\u3000\u3000\u3000\u3000\u3000\u3000\u3000\u3000 30～60分\t\u3000\u3000\u3000\u3000\u3000\u3000\u3000\u3000申請者\n・メンバ削除\t\u3000\u3000\u3000\u3000\u3000\u3000\u3000\u3000\u3000\u3000\u3000\u3000 30～60分\t\u3000\u3000\u3000\u3000\u3000\u3000\u3000\u3000申請者\n・フォルダ拡張\t\u3000\u3000\u3000\u3000\u3000\u3000\u3000\u3000\u3000\u3000\u3000\u3000 1～15分\t\u3000\u3000\u3000\u3000\u3000\u3000\u3000\u3000申請者'},
#  {'id': '100967',
#   'title': '',
#   'text': '【○○○○さん】OAPC返却依頼のメールが届いた場合、メール記載されている日付時点でOAPCの利用が確認できない為、返却依頼させていただいています。\n\n対応方法については、下記を参照して下さい。\n\n■該当端末を利用しない方\n\u3000PC管理システムより返却申請を行い、下記ページを参照し、OAPCを返却して下さい。\n・返却したい\n http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/pc/step3\n※返却するPCでOASYS利用している場合は下記ページを参照し、利用権限の削除を実施下さい\n\u3000・OASYS利用申請削除方法\n\u3000\u3000http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/%3Fpost_type%3Dpost%26p%3D33156\n\n■継続して該当端末を利用したい方\n\u3000該当端末の電源を入れて、社内ネットワークに接続し、ご利用下さい。\n\n■該当端末を返却したが、OAPC返却依頼のメールが届いた方\n\u3000メールに記載されている日付と返却日にタイムラグがある為、該当メールが送信されている可能性があります。\n\n上記以外で不明点がある場合は、OAサポートデスクへ問合せ下さい。\n\n社員サポートセンター（ＯＡサポートデスク）：平日9:00～18:00\n●Slack：＃help-oaサポート（チャンネル名で検索してください）\n●Ｗｅｂ投稿：OA Support Navi ＞ 問合わせ ＞ Web http://oa.bb.local/oasupport/inquiry_web\n●PC受取/返却：OA Support Navi ＞ 問合わせ ＞ PC受取/返却 http://oa.bb.local/oasupport/inquiry_counter\n●コール予約：OA Support Navi ＞ 問合わせ ＞ コール予約（OA） http://oa.bb.local/oasupport/oa-call-reservation'},
#  {'id': '100968',
#   'title': '',
#   'text': 'Gmail送信後に共有グループ宛にメールでエラーが返ってくる場合は、エラーメール内にvault_archive〇〇@g.softbank.co.jp（※〇〇は2桁の数字）が入っている。）が記載されている場合は、下記事項を記載の上、OA Support Netに投稿して下さい。\n\n・OA Support Net\n http://oa.bb.local/oasupport/inquiry_web\n（カテゴリ：GoogleApps）\n \n ・送信元メールアドレス\n ・送信先メールアドレス\n ・件名\n ・日時\n ・エラーが出ている場合は、その内容を全文\n ・メールヘッダ\n <ヘッダ取得手順>\n 該当のメールを開き、「返信」ボタンの右隣にある「▼」(その他)をクリック、メニューより「メッセージのソースを表示」をクリック＞別画面が開く＞開いた画面のテキストをコピーし、メモ帳などで保存'},
#  {'id': '100969',
#   'title': '',
#   'text': 'Zoomミーティングのパスコードは必ず設定して下さい。\nパスコードを設定することで悪意のある第三者のランダムな入室を防ぎます。\n\n・【Zoom】利用ガイダンス\nhttps://docs.google.com/presentation/d/1wKxE3hcF5w8hHUZMRtieukVZymARwiEkt-GPMdAkG2k/edit#slide=id.g83484d85b2_12_19'},
#  {'id': '100970',
#   'title': '',
#   'text': 'HDDの増設は、特に申請等の必要はありません。 \n \n 注意点として、現在USBのアクセス規制がかかっておりますので、USB接続のハードディスク（外付けHDD）は認識できません。 \n SATAやIDE等で接続すればご使用いただけますので、PCの接続規格をご確認の上実施して下さい。'},
#  {'id': '100971',
#   'title': '',
#   'text': '業端AのUSIMを他の端末に差替えて利用することは禁止しております。\n・使用上のルール・規程（全般）\n http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/keitai/keitai-a/rule/kitei'},
#  {'id': '100972',
#   'title': '',
#   'text': '他社キャリアの業端B解約はIoTAMではできませんので下記ドキュメントを確認下さい。\n・【IoTAM】業務用携帯B 操作マニュアル（ユーザー展開用）\n https://docs.google.com/presentation/d/1-cjNwei93iZgDuexh6h6tzc6gFzdHH3EQS3Xljlwq1g/edit#slide=id.p\n参考ページ\n・他キャリア手配（docomo・au・その他）\n http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/keitai/keitai-b/arrangement/othercarriers\n\nまた、IoTAMから情報削除する為には解約・廃棄申請は必要です。\n回線解約手続き完了後、IoTAMより解約・廃棄申請を上げて下さい。'},
#  {'id': '100973',
#   'title': '',
#   'text': '不明・SIMなし・圏外の表示となり、回線に不具合が発生している場合、まずは以下をお試し下さい。\n・電源OFF/ON\n・SIMカードの抜き差し\n・設定＞モバイル通信＞モバイルデータ通信のOFF/ON\n\n解消されない場合は、下記で対応下さい\n\n【「不明」表示】\n■業端A\n共通社員番号、氏名、IMEI、ICCIDを確認の上、Web投稿して下さい。\n・Web投稿\n http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/inquiry_web\nカテゴリ：iPhoneiPad>業務用携帯管理システム（IoTAM）\n                  Android>業務用携帯管理システム（IoTAM）\n■業端B\n部門にてOTA再配信を依頼下さい。\n・業務用携帯電話Bのサービス内容変更をしたい\n http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/keitai/keitai-b/information\n\n【「SIMなし」「圏外」表示】\n■業端A\nUSIM・端末不具合を切り分け、IoTAMより故障交換申請を行って下さい。\n・IoTAM故障交換申請（業端A）\nhttp://iotam.bb.local/OAService/catalog/gtaMenu\n・業端A_IoTAM操作マニュアル\nhttps://docs.google.com/document/d/1CKtnPkW0IEIfVfMjZksNXC8470PgO4lRJaViTtQ_tT0/edit#bookmark=kix.pidy15flbgu2\n■業端B\nUSIM・端末不具合を切り分け、部門にて修理等のご対応をお願いいたします。'},
#  {'id': '100974',
#   'title': '',
#   'text': '転送設定・解除方法については下記を参照下さい。\n\n【業端A】\nMySoftBankから転送設定・転送解除が可能となります。\n・MySoftbank\n https://www.softbank.jp/mysoftbank/\n※業端Aから個人携帯電話への転送設定はセキュリティ上、NGとなっております\n\u3000固定電話もしくは部門手配の業端Bへの転送でしたら可能となります\n\nMySoftBankのパスワードがわからない場合は、Web投稿して下さい。\n\n【業端B】\n転送設定・解除方法については部門内で確認下さい。'},
#  {'id': '100975',
#   'title': '',
#   'text': 'OAPCの交換については、まずは下記ページを参照して下さい。\n・OAPC故障切り分け方法\n http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/pc/kosyou\n\n上記切り分け後、交換が必要な場合は下記ページを参照の上、交換申請を実施下さい。\n・【IoTAM】PC交換申請方法\n http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/pc_exchange\n※修理については、承っておりません。すべて交換対応となります。\n※準OAPC（CXIRPC）、OAMac（ISCMAC130/ISCMAC131/COAMAC）は対象外です。\n※故障・不具合でのみ交換可能となります\n\u3000特定の機種や高スペック端末への希望交換については、交換不可となります\n※コンピューター名の確認については、天板右上に貼付されている白いテプラのコンピューター名を記載して下さい。\n※交換元端末のACアダプタ・VGAアダプタ等の備品も端末と一緒に返却して下さい\n※本社以外の発送については、SB拠点のみ可能となります\n※送付先に変更がある場合は、OAサポートデスクまで問合せ下さい\n※交換PCでOASYS利用しない場合は、下記ページを参照し、返却PCの利用権限の削除を実施下さい\n\u3000・OASYS利用申請削除方法\n\u3000\u3000http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/%3Fpost_type%3Dpost%26p%3D33156\n\n社員サポートセンター（ＯＡサポートデスク）：平日9:00～18:00\n●Slack：＃help-oaサポート（チャンネル名で検索してください）\n●Ｗｅｂ投稿：OA Support Navi ＞ 問合わせ ＞ Web http://oa.bb.local/oasupport/inquiry_web\n●PC受取/返却：OA Support Navi ＞ 問合わせ ＞ PC受取/返却 http://oa.bb.local/oasupport/inquiry_counter\n●コール予約：OA Support Navi ＞ 問合わせ ＞ コール予約（OA） http://oa.bb.local/oasupport/oa-call-reservation'},
#  {'id': '100976',
#   'title': '',
#   'text': 'スマホAD・スマホフレンドからよくある問合せは、下記を参照下さい。\n・Q&A一覧（業端B関連）\nhttps://goo.gl/YWjS3o\n※OAサポートデスクに問合せ頂いても、サポート対象外となります'},
#  {'id': '100977',
#   'title': '',
#   'text': '「未検証のプロファイルサイバートラストプロファイルサービスの真正性を確認できませんでした。ファイルをインストールできませんでした。」が表示された場合は、下記を確認下さい。\n ■確認事項\n ・コモンネームと端末のIMEIが一致しているメールをご利用していますか？\n ・設定メールを端末上で開きリンクをタップしていますか？'},
#  {'id': '100978',
#   'title': '',
#   'text': '販売職の業端B iPhone/iPad/AndroidでのGmail・VPNの利用等については、下記フォームより問合せして下さい。\n \n・【業端B】お問合せフォーム\n https://docs.google.com/a/g.softbank.co.jp/forms/d/e/1FAIpQLSf_sv6KJ3Ic8QEDUZRDR6UVEhMhB3t1Pg57Wl93a5Fp9Pwq9g/viewform?c=0&w=1'},
#  {'id': '100979',
#   'title': '',
#   'text': '統合マスタWEBの問合せについては、OAサポートデスクではサポート対象外となります。\n下記窓口が担当かと思われますので、直接問合せ願います。\n\n・代理店マスタ運用（営業推進本部）\n sbmgrp-master-info@g.softbank.co.jp'},
#  {'id': '100980',
#   'title': '',
#   'text': 'Slackアカウントの提供範囲については下記となります。\n\n■自動払い出し対象者\n所属会社：SBKK\n社員区分： 役員、従業員兼務役員、執行役員（委任型）、顧問、正社員、準社員、嘱託、特別嘱託、契約社員、受入出向社員、販売契約社員、特定臨時社員\n※C&Sが本務の場合は対象外\n\n■自動払い出し非対象者（特定社員）\n所属会社：SBKK\n社員区分：アルバイト、派遣社員、業務委託、非社員\n特定社員でSlack利用が必要な場合はTarteより申請下さい。\n・Tarte\nhttp://portal.tarte.bb.local/Tarte/tarteMain\n※「システム権限申請」の「Slack」を検索して申請下さい\n申請前に必ず下記と注意事項を確認して下さい。\n・【Slack】 特定社員利用開始\n https://docs.google.com/presentation/d/1rgLsB7eacZgzWp39_g2wSWYfldfo1lFMIYHKRc-befA/edit#slide=id.ga28c8ec33d_8_0\n＜注意事項＞\n・「@g.softbank.co.jp」のメールアドレスを保持していることが必須です\n・社外送信不可の場合、特定社員専用WSにのみ招待されます(ゲストWSには招待されません)\n・上長承認された申請のみ処理されます\n\n\n■社外ユーザーの方\nゲストとして招待可能となります。\n詳細については、下記を参照下さい。\n・【Slack】 ゲスト利用開始\n https://docs.google.com/presentation/d/1yRbSx-831z7OzR7nofqRzjDCvZWmZGue8YJQx5wq7cQ/edit#slide=id.ga28c8ec33d_8_0\n\n問合せについては、下記よりお願いします。\n・OA Support Net\n http://oa.bb.local/oasupport/inquiry_web\n\u3000（カテゴリ：Slack）\n\n【注意】\nSlackアカウントについてはメーリングリストでの登録不可となります'},
#  {'id': '100981',
#   'title': '',
#   'text': '迷惑メールおよび不審なメールを受信した場合は、下記FAQを参照下さい。\n・迷惑メールまたは不審なメールを受信してしまった[FAQ No:F191021001]\n http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/faq/f191021001'},
#  {'id': '100982',
#   'title': '',
#   'text': '組織フォルダの仕様については、下記を参照して下さい。\n\n【ネーミングルール】\n\\\\bbwcfs.local\\Share**\\DATA*\\ShareOrg\\SBB\\SBB_(組織番号)_(組織名)\n\\\\bbwcfs.local\\Share**\\DATA*\\ShareOrg\\SBM\\SBM_(組織番号)_(組織名)\n\\\\bbwcfs.local\\Share**\\DATA*\\ShareOrg\\SBTM\\SBTM_(組織番号)_(組織名)\n\n【作成段階のアクセス権について】\n当該フォルダは、作成段階で組織に所属しているメンバーに対してのみ、アクセス権が自動的に付与されます。\n※「メンバ一覧」には表示されません。\nまた、アクセス権はその組織の会社のOAアカウント（エイリアス）に付与されます。\n※SBM組織部署はSBMのOAアカウント（エイリアス）、SBB組織部署はSBBのOAアカウント（エイリアス） 等\n\n【他組織のメンバ追加方法】\n個別のメンバ追加につきましては、下記2通りございます。\n1．フォルダ管理者の方にて個別にメンバ追加申請を行う。\n※初期構成では組織の上長がフォルダ管理者となっております。\n2．他組織の方にて、FALCONにログイン頂き、\n\u3000アクセス対象フォルダの検索後、アクセス権申請を行い、\n\u3000申請をう受けたフォルダ管理者にて承認後、アクセス権付与。\n※初期構成では組織の上長へ申請されます。\n※ここでの他組織は、組織の所属部署に属さないメンバーを指します。\n※兼務者でSBMのOAアカウント（エイリアス）が組織の所属部署のメンバの場合、\n\u3000他OAアカウント（エイリアス）（SBB・SBTM等）であってもアクセス権申請はできません。\n\n【初期フォルダ管理者ならびに管理者追加について】\n初期状態では、所属組織の上長が管理者として設定されておりますので、FALCON上で上長の方に管理者追加を行って頂きます様お願い致します。\n※組織の所属部署のメンバーおよび配下組織の上長のみ、管理者として追加可能\n※（例）部フォルダであれば配下組織の課長等\n\n【フォルダ管理者の確認方法】\nフォルダ管理者を確認するには、FALCONに該当組織のOAアカウント（エイリアス）にてログインすることで、確認が可能です。\n「組織フォルダ一覧」＞対象組織の「詳細」をクリック＞「管理者一覧」'},
#  {'id': '100983',
#   'title': '',
#   'text': '自身のOAアカウント（エイリアス）がロックされた場合は、下記ページを参照し、パスワードリセットを実施下さい。\n※自身以外のOAアカウント（エイリアス）がロックされた場合も同様です\n・OAアカウント（エイリアス）のパスワードを変更したい\n http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/pc/password\n\n※注意※\nSBC&SのOAアカウント（エイリアス）については、パスワードリセット対象外となりますので、下記ページを参照して下さい。\n・C&S Portal\n\u3000https://portal.bb.local/oa/\n※サイトアクセス時に「この接続ではプライバシーが保護されません」が表示された場合は下記SSB C&S サービスデスクに問合せ下さい\n・SB C&S サービスデスク\n https://softbankcs.service-now.com/csqa?id=casoa_index'},
#  {'id': '100984',
#   'title': '',
#   'text': 'セキュリティソフトについては下記FAQを参照下さい。\n・【セキュリティソフト】FAQ\n https://docs.google.com/spreadsheets/d/1zz48M_hYa0PbxtUGlFdVAvXxBUVK8E12yI5UGp-A0Hc/edit#gid=0'},
#  {'id': '100985', 'title': '', 'text': 'AzureRMSの対応を行っていないと暗号化されたファイルが開けません。'},
#  {'id': '100986',
#   'title': '',
#   'text': '誤ったコンピューター名でインベントリファイルをアップロードしてしまった場合は、再度、端末側のコンピューター名を修正し、アップロードをしなおして下さい。\nすでにドメイン参加を実施してしまっている場合は、端末初期化後、再度、準OAPC化を実施して下さい。\n\nなお、誤ったコンピュータ名でドメイン参加している場合は、対象のコンピュータ名を下記までお知らせ下さい。\n・Web投稿\n http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/inquiry_web\n\u3000（カテゴリ：PC）'},
#  {'id': '100987',
#   'title': '',
#   'text': 'VSOC-VPNについては無線（blue）での接続が前提になります。\nご自身のOAPCでblueに接続してからVPNを利用いただくようお願いします。\n\n下記ページを参照し、無線LAN（blue）への接続を実施して下さい。\n・Blue\n http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/setting/blue\n\nVSOCに関する問合せについては、下記を参照下さい。\n・VSOC（SOC）案内\nhttps://open-ui.biz/cms/vsoc \n・VSOC｜FAQ\nhttps://open-ui.biz/cms/vsoc/faq/\n・問合せ先\nhttps://open-ui.biz/cms/vsoc/contact/\n※OAサポートに問合せいただいても回答できかねます'},
#  {'id': '100988',
#   'title': '',
#   'text': 'プリンタ設定方法については、下記ページを参照して下さい。\n・複合機（プリンタ）設定\n http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/pc/printer\n\n■MPC6003 SPF（リコー株式会社製）\n・【Ricoh】プリンタ利用マニュアル（OAPC/準OAPC）\n http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/pc/printer_ricoh\n\n■ゼロックス（ApeosPort-V C6676 PFS-PC）\n・【Xerox】プリンタ利用マニュアル（OAPC/準OAPC）\n http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/pc/printer_xerox'},
#  {'id': '100989',
#   'title': '',
#   'text': '周辺機器一時貸出・交換依頼フォームから申請後、キャンセルしたい場合は、OAサポートデスクに下記情報を提供して下さい。\n\n申請番号：BHN-****\n※メール件名：[周辺機器交換] 【申請番号:BHN-****】 周辺機器準備完了のお知らせ\u3000参照\n申請者共通社員番号：\n申請者氏名：\n\n社員サポートセンター（ＯＡサポートデスク）：平日9:00～18:00\n●Slack：＃help-oaサポート（チャンネル名で検索してください）\n●Ｗｅｂ投稿：OA Support Navi ＞ 問合わせ ＞ Web http://oa.bb.local/oasupport/inquiry_web\n●PC受取/返却：OA Support Navi ＞ 問合わせ ＞ PC受取/返却 http://oa.bb.local/oasupport/inquiry_counter\n●コール予約：OA Support Navi ＞ 問合わせ ＞ コール予約（OA） http://oa.bb.local/oasupport/oa-call-reservation'},
#  {'id': '100990',
#   'title': '',
#   'text': '業端Aでは速度制限は実施しておらず、データ容量は自動追加プランとなっております。'},
#  {'id': '100991',
#   'title': '',
#   'text': 'InfoBarrier監視アラートメッセージのポップアップが表示された場合は、社内ネットワークに接続した状態で下記手順を実施して下さい。 \n社内：L2有線LANまたは無線LAN blue\n社外：OASYS VPN接続\n \n ＜手順＞ \n 「隠れているインジケーターを表示します（▲）」をクリック＞InfoBarrierアイコン（上下矢印の赤いアイコン）を右クリックし、「最新の情報に更新」を実施し、しばらく（2～3日程度）放置する'},
#  {'id': '100992',
#   'title': '',
#   'text': 'GoogleChromeでパスワードを自動入力・保存したい場合は、下記ページを参照して下さい。\n\n・パスワードを管理する\n https://support.google.com/chrome/answer/95606?co=GENIE.Platform%3DDesktop&hl=ja'},
#  {'id': '100993',
#   'title': '',
#   'text': 'L2環境で作成した暗号化されたファイルをL3環境で開きたい場合は、事前に送付元のL2環境上で暗号化を解除してから、L3環境で開いて下さい。\n\n・暗号化ファイルの解除\n http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/setting/AzureRMS/rights/unlock\n\nL3環境上での暗号化施策については、OAサポート外となりますので、下記より問合せ下さい。\n・Web投稿\n http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/inquiry_web\n\u3000（カテゴリ：other > CCOC系統合端末）'},
#  {'id': '100994',
#   'title': '',
#   'text': '画面下部にある「OneNote と共に起動」のチェックを外して、「終了」をクリックして下さい。'},
#  {'id': '100995',
#   'title': '',
#   'text': '総務部配備以外のプリンタを利用する場合は、Admin権限を取得した上でドライバーインストールが必要となります。\n\n・【社内外共通】L2OAPC/準OAPC Admin権限申請・適用方法\n http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/admintekiyou_shanaigai\n\nなお、総務部配備以外のプリンタ設定方法については、OAサポート外となりますので、プリンタのメーカーに直接お問合せ下さい。'},
#  {'id': '100996',
#   'title': '',
#   'text': 'OA共有アカウントは原則禁止となっており、大型モニタでの情報共有等限られた用途のみ発行可能です。\n発行が必要な場合は、下記より相談下さい。\n・ISC相談ガイド\n https://sites.google.com/g.softbank.co.jp/sp-usersguide/isc_form\n\nISCの承認完了後、以下必要事項を揃えた上でOA Support Netより投稿下さい。\n・OA Support Net\n http://oa.bb.local/oasupport/inquiry_web\n\u3000（カテゴリ：OAアカウント）\n【必要事項】\n・ISC相談番号\n・相談者（ユーザー）\n・ISC相談時の内容の画面キャプチャ（システムの画面キャプチャ等）'},
#  {'id': '100997',
#   'title': '',
#   'text': 'ARKの問合せについては、OAサポートデスクではサポート対象外となります。\n下記ページを参照して下さい。\n\n・ARK/Chronos-Core Portal\n http://ark-chronos.bb.local/Docs/#/'},
#  {'id': '100998',
#   'title': '',
#   'text': 'Cisco VPN接続時、「Untrusted VPN Server Blocked！」が表示された場合はウイルスファイルの更新を行って下さい。\n\n 1.タスクバーにある▲をクリックし、Symantec Endpoint Protection（SEP）のアイコン（黄色の盾のようなアイコン）を右クリックで開き、「Symantec Endpoint Protectionを開く」を選択する。\n 2.「このアプリがデバイスに変更を加えることを許可しますか？」のメッセージが表示されたら、自身のOAアカウントのパスワードを入力し、「はい」をクリックします。\n 3.LiveUpdate...をクリックする\n 4.LiveUpdate完了後画面を閉じ、再度、タスクバーからSEPアイコンを右クリックで開き、「ポリシーの更新」をクリックする'},
#  {'id': '100999',
#   'title': '',
#   'text': '業端Bも業端Aと同様にMDM・Gmail・VPNを使用することができます。\n業端Aと同等のセキュリティ要件を満たすものに限ります。\n但し申請や予算の確保が必要になるものがございます、必要に応じて下記ページを参照し、対応下さい。\n\n・業務用携帯電話Bで社内システム(Gmail・Slack)を利用する場合\n http://oa.bb.local/curator_web/oasupport/?jumpurl=http://oa.bb.local/oasupport/keitai/keitai-a/rule/keitai/keitai-b'},
#  ...]

# %%
assert len(corpus_l) == len(corpus)

# %%
qrels_l = []
for q in queries:
    c = query_to_corpus[q]
    qid = query_to_id[q]
    docid = corpus_to_id[c]
    qrels_l.append({"qid": qid, "docid": docid, "relevance": 1})

# %%
qrels_l
# Out:
# [{'qid': '0', 'docid': '100000', 'relevance': 1},
#  {'qid': '1', 'docid': '100000', 'relevance': 1},
#  {'qid': '2', 'docid': '100000', 'relevance': 1},
#  {'qid': '3', 'docid': '100000', 'relevance': 1},
#  {'qid': '4', 'docid': '100001', 'relevance': 1},
#  {'qid': '5', 'docid': '100001', 'relevance': 1},
#  {'qid': '6', 'docid': '100001', 'relevance': 1},
#  {'qid': '7', 'docid': '100001', 'relevance': 1},
#  {'qid': '8', 'docid': '100001', 'relevance': 1},
#  {'qid': '9', 'docid': '100001', 'relevance': 1},
#  {'qid': '10', 'docid': '100001', 'relevance': 1},
#  {'qid': '11', 'docid': '100001', 'relevance': 1},
#  {'qid': '12', 'docid': '100001', 'relevance': 1},
#  {'qid': '13', 'docid': '100001', 'relevance': 1},
#  {'qid': '14', 'docid': '100002', 'relevance': 1},
#  {'qid': '15', 'docid': '100002', 'relevance': 1},
#  {'qid': '16', 'docid': '100002', 'relevance': 1},
#  {'qid': '17', 'docid': '100002', 'relevance': 1},
#  {'qid': '18', 'docid': '100002', 'relevance': 1},
#  {'qid': '19', 'docid': '100002', 'relevance': 1},
#  {'qid': '20', 'docid': '100002', 'relevance': 1},
#  {'qid': '21', 'docid': '100002', 'relevance': 1},
#  {'qid': '22', 'docid': '100002', 'relevance': 1},
#  {'qid': '23', 'docid': '100002', 'relevance': 1},
#  {'qid': '24', 'docid': '100003', 'relevance': 1},
#  {'qid': '25', 'docid': '100003', 'relevance': 1},
#  {'qid': '26', 'docid': '100003', 'relevance': 1},
#  {'qid': '27', 'docid': '100003', 'relevance': 1},
#  {'qid': '28', 'docid': '100003', 'relevance': 1},
#  {'qid': '29', 'docid': '100003', 'relevance': 1},
#  {'qid': '30', 'docid': '100003', 'relevance': 1},
#  {'qid': '31', 'docid': '100003', 'relevance': 1},
#  {'qid': '32', 'docid': '100004', 'relevance': 1},
#  {'qid': '33', 'docid': '100004', 'relevance': 1},
#  {'qid': '34', 'docid': '100004', 'relevance': 1},
#  {'qid': '35', 'docid': '100004', 'relevance': 1},
#  {'qid': '36', 'docid': '100004', 'relevance': 1},
#  {'qid': '37', 'docid': '100005', 'relevance': 1},
#  {'qid': '38', 'docid': '100005', 'relevance': 1},
#  {'qid': '39', 'docid': '100005', 'relevance': 1},
#  {'qid': '40', 'docid': '100005', 'relevance': 1},
#  {'qid': '41', 'docid': '100005', 'relevance': 1},
#  {'qid': '42', 'docid': '100006', 'relevance': 1},
#  {'qid': '43', 'docid': '100006', 'relevance': 1},
#  {'qid': '44', 'docid': '100006', 'relevance': 1},
#  {'qid': '45', 'docid': '100006', 'relevance': 1},
#  {'qid': '46', 'docid': '100006', 'relevance': 1},
#  {'qid': '47', 'docid': '100006', 'relevance': 1},
#  {'qid': '48', 'docid': '100006', 'relevance': 1},
#  {'qid': '49', 'docid': '100006', 'relevance': 1},
#  {'qid': '50', 'docid': '100006', 'relevance': 1},
#  {'qid': '51', 'docid': '100006', 'relevance': 1},
#  {'qid': '52', 'docid': '100007', 'relevance': 1},
#  {'qid': '53', 'docid': '100007', 'relevance': 1},
#  {'qid': '54', 'docid': '100007', 'relevance': 1},
#  {'qid': '55', 'docid': '100007', 'relevance': 1},
#  {'qid': '56', 'docid': '100007', 'relevance': 1},
#  {'qid': '57', 'docid': '100007', 'relevance': 1},
#  {'qid': '58', 'docid': '100007', 'relevance': 1},
#  {'qid': '59', 'docid': '100007', 'relevance': 1},
#  {'qid': '60', 'docid': '100007', 'relevance': 1},
#  {'qid': '61', 'docid': '100007', 'relevance': 1},
#  {'qid': '62', 'docid': '100008', 'relevance': 1},
#  {'qid': '63', 'docid': '100008', 'relevance': 1},
#  {'qid': '64', 'docid': '100008', 'relevance': 1},
#  {'qid': '65', 'docid': '100008', 'relevance': 1},
#  {'qid': '66', 'docid': '100009', 'relevance': 1},
#  {'qid': '67', 'docid': '100009', 'relevance': 1},
#  {'qid': '68', 'docid': '100009', 'relevance': 1},
#  {'qid': '69', 'docid': '100009', 'relevance': 1},
#  {'qid': '70', 'docid': '100009', 'relevance': 1},
#  {'qid': '71', 'docid': '100009', 'relevance': 1},
#  {'qid': '72', 'docid': '100009', 'relevance': 1},
#  {'qid': '73', 'docid': '100009', 'relevance': 1},
#  {'qid': '74', 'docid': '100009', 'relevance': 1},
#  {'qid': '75', 'docid': '100009', 'relevance': 1},
#  {'qid': '76', 'docid': '100010', 'relevance': 1},
#  {'qid': '77', 'docid': '100010', 'relevance': 1},
#  {'qid': '78', 'docid': '100010', 'relevance': 1},
#  {'qid': '79', 'docid': '100010', 'relevance': 1},
#  {'qid': '80', 'docid': '100010', 'relevance': 1},
#  {'qid': '81', 'docid': '100010', 'relevance': 1},
#  {'qid': '82', 'docid': '100010', 'relevance': 1},
#  {'qid': '83', 'docid': '100010', 'relevance': 1},
#  {'qid': '84', 'docid': '100010', 'relevance': 1},
#  {'qid': '85', 'docid': '100011', 'relevance': 1},
#  {'qid': '86', 'docid': '100011', 'relevance': 1},
#  {'qid': '87', 'docid': '100011', 'relevance': 1},
#  {'qid': '88', 'docid': '100011', 'relevance': 1},
#  {'qid': '89', 'docid': '100011', 'relevance': 1},
#  {'qid': '90', 'docid': '100011', 'relevance': 1},
#  {'qid': '91', 'docid': '100011', 'relevance': 1},
#  {'qid': '92', 'docid': '100011', 'relevance': 1},
#  {'qid': '93', 'docid': '100011', 'relevance': 1},
#  {'qid': '94', 'docid': '100011', 'relevance': 1},
#  {'qid': '95', 'docid': '100012', 'relevance': 1},
#  {'qid': '96', 'docid': '100012', 'relevance': 1},
#  {'qid': '97', 'docid': '100012', 'relevance': 1},
#  {'qid': '98', 'docid': '100012', 'relevance': 1},
#  {'qid': '99', 'docid': '100012', 'relevance': 1},
#  {'qid': '100', 'docid': '100012', 'relevance': 1},
#  {'qid': '101', 'docid': '100012', 'relevance': 1},
#  {'qid': '102', 'docid': '100012', 'relevance': 1},
#  {'qid': '103', 'docid': '100012', 'relevance': 1},
#  {'qid': '104', 'docid': '100012', 'relevance': 1},
#  {'qid': '105', 'docid': '100013', 'relevance': 1},
#  {'qid': '106', 'docid': '100013', 'relevance': 1},
#  {'qid': '107', 'docid': '100013', 'relevance': 1},
#  {'qid': '108', 'docid': '100013', 'relevance': 1},
#  {'qid': '109', 'docid': '100013', 'relevance': 1},
#  {'qid': '110', 'docid': '100013', 'relevance': 1},
#  {'qid': '111', 'docid': '100013', 'relevance': 1},
#  {'qid': '112', 'docid': '100013', 'relevance': 1},
#  {'qid': '113', 'docid': '100013', 'relevance': 1},
#  {'qid': '114', 'docid': '100013', 'relevance': 1},
#  {'qid': '115', 'docid': '100014', 'relevance': 1},
#  {'qid': '116', 'docid': '100014', 'relevance': 1},
#  {'qid': '117', 'docid': '100014', 'relevance': 1},
#  {'qid': '118', 'docid': '100014', 'relevance': 1},
#  {'qid': '119', 'docid': '100014', 'relevance': 1},
#  {'qid': '120', 'docid': '100014', 'relevance': 1},
#  {'qid': '121', 'docid': '100015', 'relevance': 1},
#  {'qid': '122', 'docid': '100015', 'relevance': 1},
#  {'qid': '123', 'docid': '100015', 'relevance': 1},
#  {'qid': '124', 'docid': '100015', 'relevance': 1},
#  {'qid': '125', 'docid': '100016', 'relevance': 1},
#  {'qid': '126', 'docid': '100016', 'relevance': 1},
#  {'qid': '127', 'docid': '100016', 'relevance': 1},
#  {'qid': '128', 'docid': '100016', 'relevance': 1},
#  {'qid': '129', 'docid': '100017', 'relevance': 1},
#  {'qid': '130', 'docid': '100017', 'relevance': 1},
#  {'qid': '131', 'docid': '100017', 'relevance': 1},
#  {'qid': '132', 'docid': '100017', 'relevance': 1},
#  {'qid': '133', 'docid': '100017', 'relevance': 1},
#  {'qid': '134', 'docid': '100017', 'relevance': 1},
#  {'qid': '135', 'docid': '100017', 'relevance': 1},
#  {'qid': '136', 'docid': '100017', 'relevance': 1},
#  {'qid': '137', 'docid': '100017', 'relevance': 1},
#  {'qid': '138', 'docid': '100017', 'relevance': 1},
#  {'qid': '139', 'docid': '100018', 'relevance': 1},
#  {'qid': '140', 'docid': '100018', 'relevance': 1},
#  {'qid': '141', 'docid': '100018', 'relevance': 1},
#  {'qid': '142', 'docid': '100018', 'relevance': 1},
#  {'qid': '143', 'docid': '100019', 'relevance': 1},
#  {'qid': '144', 'docid': '100019', 'relevance': 1},
#  {'qid': '145', 'docid': '100019', 'relevance': 1},
#  {'qid': '146', 'docid': '100019', 'relevance': 1},
#  {'qid': '147', 'docid': '100019', 'relevance': 1},
#  {'qid': '148', 'docid': '100019', 'relevance': 1},
#  {'qid': '149', 'docid': '100019', 'relevance': 1},
#  {'qid': '150', 'docid': '100019', 'relevance': 1},
#  {'qid': '151', 'docid': '100019', 'relevance': 1},
#  {'qid': '152', 'docid': '100019', 'relevance': 1},
#  {'qid': '153', 'docid': '100020', 'relevance': 1},
#  {'qid': '154', 'docid': '100020', 'relevance': 1},
#  {'qid': '155', 'docid': '100020', 'relevance': 1},
#  {'qid': '156', 'docid': '100020', 'relevance': 1},
#  {'qid': '157', 'docid': '100020', 'relevance': 1},
#  {'qid': '158', 'docid': '100020', 'relevance': 1},
#  {'qid': '159', 'docid': '100021', 'relevance': 1},
#  {'qid': '160', 'docid': '100021', 'relevance': 1},
#  {'qid': '161', 'docid': '100021', 'relevance': 1},
#  {'qid': '162', 'docid': '100021', 'relevance': 1},
#  {'qid': '163', 'docid': '100022', 'relevance': 1},
#  {'qid': '164', 'docid': '100022', 'relevance': 1},
#  {'qid': '165', 'docid': '100022', 'relevance': 1},
#  {'qid': '166', 'docid': '100022', 'relevance': 1},
#  {'qid': '167', 'docid': '100022', 'relevance': 1},
#  {'qid': '168', 'docid': '100022', 'relevance': 1},
#  {'qid': '169', 'docid': '100022', 'relevance': 1},
#  {'qid': '170', 'docid': '100022', 'relevance': 1},
#  {'qid': '171', 'docid': '100022', 'relevance': 1},
#  {'qid': '172', 'docid': '100022', 'relevance': 1},
#  {'qid': '173', 'docid': '100023', 'relevance': 1},
#  {'qid': '174', 'docid': '100023', 'relevance': 1},
#  {'qid': '175', 'docid': '100023', 'relevance': 1},
#  {'qid': '176', 'docid': '100023', 'relevance': 1},
#  {'qid': '177', 'docid': '100023', 'relevance': 1},
#  {'qid': '178', 'docid': '100024', 'relevance': 1},
#  {'qid': '179', 'docid': '100024', 'relevance': 1},
#  {'qid': '180', 'docid': '100024', 'relevance': 1},
#  {'qid': '181', 'docid': '100024', 'relevance': 1},
#  {'qid': '182', 'docid': '100025', 'relevance': 1},
#  {'qid': '183', 'docid': '100025', 'relevance': 1},
#  {'qid': '184', 'docid': '100025', 'relevance': 1},
#  {'qid': '185', 'docid': '100025', 'relevance': 1},
#  {'qid': '186', 'docid': '100026', 'relevance': 1},
#  {'qid': '187', 'docid': '100026', 'relevance': 1},
#  {'qid': '188', 'docid': '100026', 'relevance': 1},
#  {'qid': '189', 'docid': '100026', 'relevance': 1},
#  {'qid': '190', 'docid': '100026', 'relevance': 1},
#  {'qid': '191', 'docid': '100026', 'relevance': 1},
#  {'qid': '192', 'docid': '100026', 'relevance': 1},
#  {'qid': '193', 'docid': '100026', 'relevance': 1},
#  {'qid': '194', 'docid': '100026', 'relevance': 1},
#  {'qid': '195', 'docid': '100027', 'relevance': 1},
#  {'qid': '196', 'docid': '100027', 'relevance': 1},
#  {'qid': '197', 'docid': '100027', 'relevance': 1},
#  {'qid': '198', 'docid': '100027', 'relevance': 1},
#  {'qid': '199', 'docid': '100027', 'relevance': 1},
#  {'qid': '200', 'docid': '100028', 'relevance': 1},
#  {'qid': '201', 'docid': '100028', 'relevance': 1},
#  {'qid': '202', 'docid': '100028', 'relevance': 1},
#  {'qid': '203', 'docid': '100028', 'relevance': 1},
#  {'qid': '204', 'docid': '100028', 'relevance': 1},
#  {'qid': '205', 'docid': '100028', 'relevance': 1},
#  {'qid': '206', 'docid': '100028', 'relevance': 1},
#  {'qid': '207', 'docid': '100028', 'relevance': 1},
#  {'qid': '208', 'docid': '100029', 'relevance': 1},
#  {'qid': '209', 'docid': '100029', 'relevance': 1},
#  {'qid': '210', 'docid': '100029', 'relevance': 1},
#  {'qid': '211', 'docid': '100029', 'relevance': 1},
#  {'qid': '212', 'docid': '100029', 'relevance': 1},
#  {'qid': '213', 'docid': '100030', 'relevance': 1},
#  {'qid': '214', 'docid': '100030', 'relevance': 1},
#  {'qid': '215', 'docid': '100030', 'relevance': 1},
#  {'qid': '216', 'docid': '100030', 'relevance': 1},
#  {'qid': '217', 'docid': '100031', 'relevance': 1},
#  {'qid': '218', 'docid': '100031', 'relevance': 1},
#  {'qid': '219', 'docid': '100031', 'relevance': 1},
#  {'qid': '220', 'docid': '100031', 'relevance': 1},
#  {'qid': '221', 'docid': '100031', 'relevance': 1},
#  {'qid': '222', 'docid': '100031', 'relevance': 1},
#  {'qid': '223', 'docid': '100031', 'relevance': 1},
#  {'qid': '224', 'docid': '100031', 'relevance': 1},
#  {'qid': '225', 'docid': '100031', 'relevance': 1},
#  {'qid': '226', 'docid': '100031', 'relevance': 1},
#  {'qid': '227', 'docid': '100032', 'relevance': 1},
#  {'qid': '228', 'docid': '100032', 'relevance': 1},
#  {'qid': '229', 'docid': '100032', 'relevance': 1},
#  {'qid': '230', 'docid': '100032', 'relevance': 1},
#  {'qid': '231', 'docid': '100032', 'relevance': 1},
#  {'qid': '232', 'docid': '100032', 'relevance': 1},
#  {'qid': '233', 'docid': '100032', 'relevance': 1},
#  {'qid': '234', 'docid': '100032', 'relevance': 1},
#  {'qid': '235', 'docid': '100032', 'relevance': 1},
#  {'qid': '236', 'docid': '100032', 'relevance': 1},
#  {'qid': '237', 'docid': '100033', 'relevance': 1},
#  {'qid': '238', 'docid': '100033', 'relevance': 1},
#  {'qid': '239', 'docid': '100033', 'relevance': 1},
#  {'qid': '240', 'docid': '100033', 'relevance': 1},
#  {'qid': '241', 'docid': '100033', 'relevance': 1},
#  {'qid': '242', 'docid': '100033', 'relevance': 1},
#  {'qid': '243', 'docid': '100033', 'relevance': 1},
#  {'qid': '244', 'docid': '100033', 'relevance': 1},
#  {'qid': '245', 'docid': '100033', 'relevance': 1},
#  {'qid': '246', 'docid': '100033', 'relevance': 1},
#  {'qid': '247', 'docid': '100034', 'relevance': 1},
#  {'qid': '248', 'docid': '100034', 'relevance': 1},
#  {'qid': '249', 'docid': '100034', 'relevance': 1},
#  {'qid': '250', 'docid': '100034', 'relevance': 1},
#  {'qid': '251', 'docid': '100034', 'relevance': 1},
#  {'qid': '252', 'docid': '100034', 'relevance': 1},
#  {'qid': '253', 'docid': '100034', 'relevance': 1},
#  {'qid': '254', 'docid': '100034', 'relevance': 1},
#  {'qid': '255', 'docid': '100035', 'relevance': 1},
#  {'qid': '256', 'docid': '100035', 'relevance': 1},
#  {'qid': '257', 'docid': '100035', 'relevance': 1},
#  {'qid': '258', 'docid': '100035', 'relevance': 1},
#  {'qid': '259', 'docid': '100035', 'relevance': 1},
#  {'qid': '260', 'docid': '100036', 'relevance': 1},
#  {'qid': '261', 'docid': '100036', 'relevance': 1},
#  {'qid': '262', 'docid': '100036', 'relevance': 1},
#  {'qid': '263', 'docid': '100036', 'relevance': 1},
#  {'qid': '264', 'docid': '100036', 'relevance': 1},
#  {'qid': '265', 'docid': '100036', 'relevance': 1},
#  {'qid': '266', 'docid': '100036', 'relevance': 1},
#  {'qid': '267', 'docid': '100036', 'relevance': 1},
#  {'qid': '268', 'docid': '100036', 'relevance': 1},
#  {'qid': '269', 'docid': '100037', 'relevance': 1},
#  {'qid': '270', 'docid': '100037', 'relevance': 1},
#  {'qid': '271', 'docid': '100037', 'relevance': 1},
#  {'qid': '272', 'docid': '100037', 'relevance': 1},
#  {'qid': '273', 'docid': '100037', 'relevance': 1},
#  {'qid': '274', 'docid': '100037', 'relevance': 1},
#  {'qid': '275', 'docid': '100037', 'relevance': 1},
#  {'qid': '276', 'docid': '100037', 'relevance': 1},
#  {'qid': '277', 'docid': '100037', 'relevance': 1},
#  {'qid': '278', 'docid': '100037', 'relevance': 1},
#  {'qid': '279', 'docid': '100038', 'relevance': 1},
#  {'qid': '280', 'docid': '100038', 'relevance': 1},
#  {'qid': '281', 'docid': '100038', 'relevance': 1},
#  {'qid': '282', 'docid': '100038', 'relevance': 1},
#  {'qid': '283', 'docid': '100038', 'relevance': 1},
#  {'qid': '284', 'docid': '100038', 'relevance': 1},
#  {'qid': '285', 'docid': '100039', 'relevance': 1},
#  {'qid': '286', 'docid': '100039', 'relevance': 1},
#  {'qid': '287', 'docid': '100039', 'relevance': 1},
#  {'qid': '288', 'docid': '100039', 'relevance': 1},
#  {'qid': '289', 'docid': '100039', 'relevance': 1},
#  {'qid': '290', 'docid': '100040', 'relevance': 1},
#  {'qid': '291', 'docid': '100040', 'relevance': 1},
#  {'qid': '292', 'docid': '100040', 'relevance': 1},
#  {'qid': '293', 'docid': '100040', 'relevance': 1},
#  {'qid': '294', 'docid': '100040', 'relevance': 1},
#  {'qid': '295', 'docid': '100040', 'relevance': 1},
#  {'qid': '296', 'docid': '100040', 'relevance': 1},
#  {'qid': '297', 'docid': '100040', 'relevance': 1},
#  {'qid': '298', 'docid': '100040', 'relevance': 1},
#  {'qid': '299', 'docid': '100040', 'relevance': 1},
#  {'qid': '300', 'docid': '100041', 'relevance': 1},
#  {'qid': '301', 'docid': '100041', 'relevance': 1},
#  {'qid': '302', 'docid': '100041', 'relevance': 1},
#  {'qid': '303', 'docid': '100041', 'relevance': 1},
#  {'qid': '304', 'docid': '100042', 'relevance': 1},
#  {'qid': '305', 'docid': '100042', 'relevance': 1},
#  {'qid': '306', 'docid': '100042', 'relevance': 1},
#  {'qid': '307', 'docid': '100042', 'relevance': 1},
#  {'qid': '308', 'docid': '100042', 'relevance': 1},
#  {'qid': '309', 'docid': '100042', 'relevance': 1},
#  {'qid': '310', 'docid': '100042', 'relevance': 1},
#  {'qid': '311', 'docid': '100042', 'relevance': 1},
#  {'qid': '312', 'docid': '100042', 'relevance': 1},
#  {'qid': '313', 'docid': '100042', 'relevance': 1},
#  {'qid': '314', 'docid': '100043', 'relevance': 1},
#  {'qid': '315', 'docid': '100043', 'relevance': 1},
#  {'qid': '316', 'docid': '100043', 'relevance': 1},
#  {'qid': '317', 'docid': '100043', 'relevance': 1},
#  {'qid': '318', 'docid': '100043', 'relevance': 1},
#  {'qid': '319', 'docid': '100043', 'relevance': 1},
#  {'qid': '320', 'docid': '100043', 'relevance': 1},
#  {'qid': '321', 'docid': '100043', 'relevance': 1},
#  {'qid': '322', 'docid': '100043', 'relevance': 1},
#  {'qid': '323', 'docid': '100043', 'relevance': 1},
#  {'qid': '324', 'docid': '100044', 'relevance': 1},
#  {'qid': '325', 'docid': '100044', 'relevance': 1},
#  {'qid': '326', 'docid': '100044', 'relevance': 1},
#  {'qid': '327', 'docid': '100044', 'relevance': 1},
#  {'qid': '328', 'docid': '100044', 'relevance': 1},
#  {'qid': '329', 'docid': '100045', 'relevance': 1},
#  {'qid': '330', 'docid': '100045', 'relevance': 1},
#  {'qid': '331', 'docid': '100045', 'relevance': 1},
#  {'qid': '332', 'docid': '100045', 'relevance': 1},
#  {'qid': '333', 'docid': '100046', 'relevance': 1},
#  {'qid': '334', 'docid': '100046', 'relevance': 1},
#  {'qid': '335', 'docid': '100046', 'relevance': 1},
#  {'qid': '336', 'docid': '100046', 'relevance': 1},
#  {'qid': '337', 'docid': '100046', 'relevance': 1},
#  {'qid': '338', 'docid': '100046', 'relevance': 1},
#  {'qid': '339', 'docid': '100047', 'relevance': 1},
#  {'qid': '340', 'docid': '100047', 'relevance': 1},
#  {'qid': '341', 'docid': '100047', 'relevance': 1},
#  {'qid': '342', 'docid': '100047', 'relevance': 1},
#  {'qid': '343', 'docid': '100048', 'relevance': 1},
#  {'qid': '344', 'docid': '100048', 'relevance': 1},
#  {'qid': '345', 'docid': '100048', 'relevance': 1},
#  {'qid': '346', 'docid': '100048', 'relevance': 1},
#  {'qid': '347', 'docid': '100049', 'relevance': 1},
#  {'qid': '348', 'docid': '100049', 'relevance': 1},
#  {'qid': '349', 'docid': '100049', 'relevance': 1},
#  {'qid': '350', 'docid': '100049', 'relevance': 1},
#  {'qid': '351', 'docid': '100049', 'relevance': 1},
#  {'qid': '352', 'docid': '100049', 'relevance': 1},
#  {'qid': '353', 'docid': '100049', 'relevance': 1},
#  {'qid': '354', 'docid': '100049', 'relevance': 1},
#  {'qid': '355', 'docid': '100049', 'relevance': 1},
#  {'qid': '356', 'docid': '100049', 'relevance': 1},
#  {'qid': '357', 'docid': '100050', 'relevance': 1},
#  {'qid': '358', 'docid': '100050', 'relevance': 1},
#  {'qid': '359', 'docid': '100050', 'relevance': 1},
#  {'qid': '360', 'docid': '100050', 'relevance': 1},
#  {'qid': '361', 'docid': '100050', 'relevance': 1},
#  {'qid': '362', 'docid': '100051', 'relevance': 1},
#  {'qid': '363', 'docid': '100051', 'relevance': 1},
#  {'qid': '364', 'docid': '100051', 'relevance': 1},
#  {'qid': '365', 'docid': '100051', 'relevance': 1},
#  {'qid': '366', 'docid': '100051', 'relevance': 1},
#  {'qid': '367', 'docid': '100052', 'relevance': 1},
#  {'qid': '368', 'docid': '100052', 'relevance': 1},
#  {'qid': '369', 'docid': '100052', 'relevance': 1},
#  {'qid': '370', 'docid': '100052', 'relevance': 1},
#  {'qid': '371', 'docid': '100052', 'relevance': 1},
#  {'qid': '372', 'docid': '100052', 'relevance': 1},
#  {'qid': '373', 'docid': '100052', 'relevance': 1},
#  {'qid': '374', 'docid': '100052', 'relevance': 1},
#  {'qid': '375', 'docid': '100052', 'relevance': 1},
#  {'qid': '376', 'docid': '100053', 'relevance': 1},
#  {'qid': '377', 'docid': '100053', 'relevance': 1},
#  {'qid': '378', 'docid': '100053', 'relevance': 1},
#  {'qid': '379', 'docid': '100053', 'relevance': 1},
#  {'qid': '380', 'docid': '100053', 'relevance': 1},
#  {'qid': '381', 'docid': '100053', 'relevance': 1},
#  {'qid': '382', 'docid': '100053', 'relevance': 1},
#  {'qid': '383', 'docid': '100053', 'relevance': 1},
#  {'qid': '384', 'docid': '100053', 'relevance': 1},
#  {'qid': '385', 'docid': '100053', 'relevance': 1},
#  {'qid': '386', 'docid': '100054', 'relevance': 1},
#  {'qid': '387', 'docid': '100054', 'relevance': 1},
#  {'qid': '388', 'docid': '100054', 'relevance': 1},
#  {'qid': '389', 'docid': '100054', 'relevance': 1},
#  {'qid': '390', 'docid': '100054', 'relevance': 1},
#  {'qid': '391', 'docid': '100054', 'relevance': 1},
#  {'qid': '392', 'docid': '100054', 'relevance': 1},
#  {'qid': '393', 'docid': '100054', 'relevance': 1},
#  {'qid': '394', 'docid': '100054', 'relevance': 1},
#  {'qid': '395', 'docid': '100055', 'relevance': 1},
#  {'qid': '396', 'docid': '100055', 'relevance': 1},
#  {'qid': '397', 'docid': '100055', 'relevance': 1},
#  {'qid': '398', 'docid': '100055', 'relevance': 1},
#  {'qid': '399', 'docid': '100055', 'relevance': 1},
#  {'qid': '400', 'docid': '100055', 'relevance': 1},
#  {'qid': '401', 'docid': '100056', 'relevance': 1},
#  {'qid': '402', 'docid': '100056', 'relevance': 1},
#  {'qid': '403', 'docid': '100056', 'relevance': 1},
#  {'qid': '404', 'docid': '100056', 'relevance': 1},
#  {'qid': '405', 'docid': '100056', 'relevance': 1},
#  {'qid': '406', 'docid': '100056', 'relevance': 1},
#  {'qid': '407', 'docid': '100056', 'relevance': 1},
#  {'qid': '408', 'docid': '100057', 'relevance': 1},
#  {'qid': '409', 'docid': '100057', 'relevance': 1},
#  {'qid': '410', 'docid': '100057', 'relevance': 1},
#  {'qid': '411', 'docid': '100057', 'relevance': 1},
#  {'qid': '412', 'docid': '100057', 'relevance': 1},
#  {'qid': '413', 'docid': '100058', 'relevance': 1},
#  {'qid': '414', 'docid': '100058', 'relevance': 1},
#  {'qid': '415', 'docid': '100058', 'relevance': 1},
#  {'qid': '416', 'docid': '100058', 'relevance': 1},
#  {'qid': '417', 'docid': '100058', 'relevance': 1},
#  {'qid': '418', 'docid': '100058', 'relevance': 1},
#  {'qid': '419', 'docid': '100058', 'relevance': 1},
#  {'qid': '420', 'docid': '100058', 'relevance': 1},
#  {'qid': '421', 'docid': '100058', 'relevance': 1},
#  {'qid': '422', 'docid': '100058', 'relevance': 1},
#  {'qid': '423', 'docid': '100059', 'relevance': 1},
#  {'qid': '424', 'docid': '100059', 'relevance': 1},
#  {'qid': '425', 'docid': '100059', 'relevance': 1},
#  {'qid': '426', 'docid': '100059', 'relevance': 1},
#  {'qid': '427', 'docid': '100059', 'relevance': 1},
#  {'qid': '428', 'docid': '100060', 'relevance': 1},
#  {'qid': '429', 'docid': '100060', 'relevance': 1},
#  {'qid': '430', 'docid': '100060', 'relevance': 1},
#  {'qid': '431', 'docid': '100060', 'relevance': 1},
#  {'qid': '432', 'docid': '100060', 'relevance': 1},
#  {'qid': '433', 'docid': '100060', 'relevance': 1},
#  {'qid': '434', 'docid': '100060', 'relevance': 1},
#  {'qid': '435', 'docid': '100060', 'relevance': 1},
#  {'qid': '436', 'docid': '100060', 'relevance': 1},
#  {'qid': '437', 'docid': '100060', 'relevance': 1},
#  {'qid': '438', 'docid': '100061', 'relevance': 1},
#  {'qid': '439', 'docid': '100061', 'relevance': 1},
#  {'qid': '440', 'docid': '100061', 'relevance': 1},
#  {'qid': '441', 'docid': '100061', 'relevance': 1},
#  {'qid': '442', 'docid': '100061', 'relevance': 1},
#  {'qid': '443', 'docid': '100062', 'relevance': 1},
#  {'qid': '444', 'docid': '100062', 'relevance': 1},
#  {'qid': '445', 'docid': '100062', 'relevance': 1},
#  {'qid': '446', 'docid': '100062', 'relevance': 1},
#  {'qid': '447', 'docid': '100062', 'relevance': 1},
#  {'qid': '448', 'docid': '100062', 'relevance': 1},
#  {'qid': '449', 'docid': '100063', 'relevance': 1},
#  {'qid': '450', 'docid': '100063', 'relevance': 1},
#  {'qid': '451', 'docid': '100063', 'relevance': 1},
#  {'qid': '452', 'docid': '100063', 'relevance': 1},
#  {'qid': '453', 'docid': '100063', 'relevance': 1},
#  {'qid': '454', 'docid': '100063', 'relevance': 1},
#  {'qid': '455', 'docid': '100063', 'relevance': 1},
#  {'qid': '456', 'docid': '100063', 'relevance': 1},
#  {'qid': '457', 'docid': '100063', 'relevance': 1},
#  {'qid': '458', 'docid': '100063', 'relevance': 1},
#  {'qid': '459', 'docid': '100064', 'relevance': 1},
#  {'qid': '460', 'docid': '100064', 'relevance': 1},
#  {'qid': '461', 'docid': '100064', 'relevance': 1},
#  {'qid': '462', 'docid': '100064', 'relevance': 1},
#  {'qid': '463', 'docid': '100064', 'relevance': 1},
#  {'qid': '464', 'docid': '100064', 'relevance': 1},
#  {'qid': '465', 'docid': '100064', 'relevance': 1},
#  {'qid': '466', 'docid': '100064', 'relevance': 1},
#  {'qid': '467', 'docid': '100064', 'relevance': 1},
#  {'qid': '468', 'docid': '100065', 'relevance': 1},
#  {'qid': '469', 'docid': '100065', 'relevance': 1},
#  {'qid': '470', 'docid': '100065', 'relevance': 1},
#  {'qid': '471', 'docid': '100065', 'relevance': 1},
#  {'qid': '472', 'docid': '100065', 'relevance': 1},
#  {'qid': '473', 'docid': '100065', 'relevance': 1},
#  {'qid': '474', 'docid': '100065', 'relevance': 1},
#  {'qid': '475', 'docid': '100065', 'relevance': 1},
#  {'qid': '476', 'docid': '100065', 'relevance': 1},
#  {'qid': '477', 'docid': '100065', 'relevance': 1},
#  {'qid': '478', 'docid': '100066', 'relevance': 1},
#  {'qid': '479', 'docid': '100066', 'relevance': 1},
#  {'qid': '480', 'docid': '100066', 'relevance': 1},
#  {'qid': '481', 'docid': '100066', 'relevance': 1},
#  {'qid': '482', 'docid': '100066', 'relevance': 1},
#  {'qid': '483', 'docid': '100066', 'relevance': 1},
#  {'qid': '484', 'docid': '100066', 'relevance': 1},
#  {'qid': '485', 'docid': '100066', 'relevance': 1},
#  {'qid': '486', 'docid': '100066', 'relevance': 1},
#  {'qid': '487', 'docid': '100066', 'relevance': 1},
#  {'qid': '488', 'docid': '100066', 'relevance': 1},
#  {'qid': '489', 'docid': '100066', 'relevance': 1},
#  {'qid': '490', 'docid': '100066', 'relevance': 1},
#  {'qid': '491', 'docid': '100066', 'relevance': 1},
#  {'qid': '492', 'docid': '100066', 'relevance': 1},
#  {'qid': '493', 'docid': '100066', 'relevance': 1},
#  {'qid': '494', 'docid': '100066', 'relevance': 1},
#  {'qid': '495', 'docid': '100066', 'relevance': 1},
#  {'qid': '496', 'docid': '100067', 'relevance': 1},
#  {'qid': '497', 'docid': '100067', 'relevance': 1},
#  {'qid': '498', 'docid': '100067', 'relevance': 1},
#  {'qid': '499', 'docid': '100067', 'relevance': 1},
#  {'qid': '500', 'docid': '100067', 'relevance': 1},
#  {'qid': '501', 'docid': '100067', 'relevance': 1},
#  {'qid': '502', 'docid': '100068', 'relevance': 1},
#  {'qid': '503', 'docid': '100068', 'relevance': 1},
#  {'qid': '504', 'docid': '100068', 'relevance': 1},
#  {'qid': '505', 'docid': '100068', 'relevance': 1},
#  {'qid': '506', 'docid': '100068', 'relevance': 1},
#  {'qid': '507', 'docid': '100068', 'relevance': 1},
#  {'qid': '508', 'docid': '100068', 'relevance': 1},
#  {'qid': '509', 'docid': '100068', 'relevance': 1},
#  {'qid': '510', 'docid': '100068', 'relevance': 1},
#  {'qid': '511', 'docid': '100068', 'relevance': 1},
#  {'qid': '512', 'docid': '100069', 'relevance': 1},
#  {'qid': '513', 'docid': '100069', 'relevance': 1},
#  {'qid': '514', 'docid': '100069', 'relevance': 1},
#  {'qid': '515', 'docid': '100069', 'relevance': 1},
#  {'qid': '516', 'docid': '100069', 'relevance': 1},
#  {'qid': '517', 'docid': '100069', 'relevance': 1},
#  {'qid': '518', 'docid': '100069', 'relevance': 1},
#  {'qid': '519', 'docid': '100069', 'relevance': 1},
#  {'qid': '520', 'docid': '100069', 'relevance': 1},
#  {'qid': '521', 'docid': '100069', 'relevance': 1},
#  {'qid': '522', 'docid': '100069', 'relevance': 1},
#  {'qid': '523', 'docid': '100069', 'relevance': 1},
#  {'qid': '524', 'docid': '100069', 'relevance': 1},
#  {'qid': '525', 'docid': '100069', 'relevance': 1},
#  {'qid': '526', 'docid': '100070', 'relevance': 1},
#  {'qid': '527', 'docid': '100070', 'relevance': 1},
#  {'qid': '528', 'docid': '100070', 'relevance': 1},
#  {'qid': '529', 'docid': '100070', 'relevance': 1},
#  {'qid': '530', 'docid': '100070', 'relevance': 1},
#  {'qid': '531', 'docid': '100070', 'relevance': 1},
#  {'qid': '532', 'docid': '100070', 'relevance': 1},
#  {'qid': '533', 'docid': '100070', 'relevance': 1},
#  {'qid': '534', 'docid': '100071', 'relevance': 1},
#  {'qid': '535', 'docid': '100071', 'relevance': 1},
#  {'qid': '536', 'docid': '100071', 'relevance': 1},
#  {'qid': '537', 'docid': '100071', 'relevance': 1},
#  {'qid': '538', 'docid': '100071', 'relevance': 1},
#  {'qid': '539', 'docid': '100071', 'relevance': 1},
#  {'qid': '540', 'docid': '100071', 'relevance': 1},
#  {'qid': '541', 'docid': '100071', 'relevance': 1},
#  {'qid': '542', 'docid': '100071', 'relevance': 1},
#  {'qid': '543', 'docid': '100071', 'relevance': 1},
#  {'qid': '544', 'docid': '100071', 'relevance': 1},
#  {'qid': '545', 'docid': '100071', 'relevance': 1},
#  {'qid': '546', 'docid': '100071', 'relevance': 1},
#  {'qid': '547', 'docid': '100071', 'relevance': 1},
#  {'qid': '548', 'docid': '100071', 'relevance': 1},
#  {'qid': '549', 'docid': '100071', 'relevance': 1},
#  {'qid': '550', 'docid': '100071', 'relevance': 1},
#  {'qid': '551', 'docid': '100071', 'relevance': 1},
#  {'qid': '552', 'docid': '100071', 'relevance': 1},
#  {'qid': '553', 'docid': '100071', 'relevance': 1},
#  {'qid': '554', 'docid': '100072', 'relevance': 1},
#  {'qid': '555', 'docid': '100072', 'relevance': 1},
#  {'qid': '556', 'docid': '100072', 'relevance': 1},
#  {'qid': '557', 'docid': '100072', 'relevance': 1},
#  {'qid': '558', 'docid': '100072', 'relevance': 1},
#  {'qid': '559', 'docid': '100072', 'relevance': 1},
#  {'qid': '560', 'docid': '100072', 'relevance': 1},
#  {'qid': '561', 'docid': '100072', 'relevance': 1},
#  {'qid': '562', 'docid': '100072', 'relevance': 1},
#  {'qid': '563', 'docid': '100072', 'relevance': 1},
#  {'qid': '564', 'docid': '100073', 'relevance': 1},
#  {'qid': '565', 'docid': '100073', 'relevance': 1},
#  {'qid': '566', 'docid': '100073', 'relevance': 1},
#  {'qid': '567', 'docid': '100073', 'relevance': 1},
#  {'qid': '568', 'docid': '100073', 'relevance': 1},
#  {'qid': '569', 'docid': '100073', 'relevance': 1},
#  {'qid': '570', 'docid': '100073', 'relevance': 1},
#  {'qid': '571', 'docid': '100074', 'relevance': 1},
#  {'qid': '572', 'docid': '100074', 'relevance': 1},
#  {'qid': '573', 'docid': '100074', 'relevance': 1},
#  {'qid': '574', 'docid': '100074', 'relevance': 1},
#  {'qid': '575', 'docid': '100075', 'relevance': 1},
#  {'qid': '576', 'docid': '100075', 'relevance': 1},
#  {'qid': '577', 'docid': '100075', 'relevance': 1},
#  {'qid': '578', 'docid': '100075', 'relevance': 1},
#  {'qid': '579', 'docid': '100075', 'relevance': 1},
#  {'qid': '580', 'docid': '100076', 'relevance': 1},
#  {'qid': '581', 'docid': '100076', 'relevance': 1},
#  {'qid': '582', 'docid': '100076', 'relevance': 1},
#  {'qid': '583', 'docid': '100076', 'relevance': 1},
#  {'qid': '584', 'docid': '100076', 'relevance': 1},
#  {'qid': '585', 'docid': '100076', 'relevance': 1},
#  {'qid': '586', 'docid': '100076', 'relevance': 1},
#  {'qid': '587', 'docid': '100076', 'relevance': 1},
#  {'qid': '588', 'docid': '100076', 'relevance': 1},
#  {'qid': '589', 'docid': '100077', 'relevance': 1},
#  {'qid': '590', 'docid': '100077', 'relevance': 1},
#  {'qid': '591', 'docid': '100077', 'relevance': 1},
#  {'qid': '592', 'docid': '100077', 'relevance': 1},
#  {'qid': '593', 'docid': '100078', 'relevance': 1},
#  {'qid': '594', 'docid': '100078', 'relevance': 1},
#  {'qid': '595', 'docid': '100078', 'relevance': 1},
#  {'qid': '596', 'docid': '100078', 'relevance': 1},
#  {'qid': '597', 'docid': '100079', 'relevance': 1},
#  {'qid': '598', 'docid': '100079', 'relevance': 1},
#  {'qid': '599', 'docid': '100079', 'relevance': 1},
#  {'qid': '600', 'docid': '100079', 'relevance': 1},
#  {'qid': '601', 'docid': '100079', 'relevance': 1},
#  {'qid': '602', 'docid': '100079', 'relevance': 1},
#  {'qid': '603', 'docid': '100079', 'relevance': 1},
#  {'qid': '604', 'docid': '100079', 'relevance': 1},
#  {'qid': '605', 'docid': '100079', 'relevance': 1},
#  {'qid': '606', 'docid': '100079', 'relevance': 1},
#  {'qid': '607', 'docid': '100080', 'relevance': 1},
#  {'qid': '608', 'docid': '100080', 'relevance': 1},
#  {'qid': '609', 'docid': '100080', 'relevance': 1},
#  {'qid': '610', 'docid': '100080', 'relevance': 1},
#  {'qid': '611', 'docid': '100080', 'relevance': 1},
#  {'qid': '612', 'docid': '100080', 'relevance': 1},
#  {'qid': '613', 'docid': '100080', 'relevance': 1},
#  {'qid': '614', 'docid': '100080', 'relevance': 1},
#  {'qid': '615', 'docid': '100080', 'relevance': 1},
#  {'qid': '616', 'docid': '100080', 'relevance': 1},
#  {'qid': '617', 'docid': '100081', 'relevance': 1},
#  {'qid': '618', 'docid': '100081', 'relevance': 1},
#  {'qid': '619', 'docid': '100081', 'relevance': 1},
#  {'qid': '620', 'docid': '100081', 'relevance': 1},
#  {'qid': '621', 'docid': '100081', 'relevance': 1},
#  {'qid': '622', 'docid': '100081', 'relevance': 1},
#  {'qid': '623', 'docid': '100081', 'relevance': 1},
#  {'qid': '624', 'docid': '100081', 'relevance': 1},
#  {'qid': '625', 'docid': '100081', 'relevance': 1},
#  {'qid': '626', 'docid': '100081', 'relevance': 1},
#  {'qid': '627', 'docid': '100082', 'relevance': 1},
#  {'qid': '628', 'docid': '100082', 'relevance': 1},
#  {'qid': '629', 'docid': '100082', 'relevance': 1},
#  {'qid': '630', 'docid': '100082', 'relevance': 1},
#  {'qid': '631', 'docid': '100083', 'relevance': 1},
#  {'qid': '632', 'docid': '100083', 'relevance': 1},
#  {'qid': '633', 'docid': '100083', 'relevance': 1},
#  {'qid': '634', 'docid': '100083', 'relevance': 1},
#  {'qid': '635', 'docid': '100083', 'relevance': 1},
#  {'qid': '636', 'docid': '100083', 'relevance': 1},
#  {'qid': '637', 'docid': '100084', 'relevance': 1},
#  {'qid': '638', 'docid': '100084', 'relevance': 1},
#  {'qid': '639', 'docid': '100084', 'relevance': 1},
#  {'qid': '640', 'docid': '100084', 'relevance': 1},
#  {'qid': '641', 'docid': '100084', 'relevance': 1},
#  {'qid': '642', 'docid': '100084', 'relevance': 1},
#  {'qid': '643', 'docid': '100084', 'relevance': 1},
#  {'qid': '644', 'docid': '100084', 'relevance': 1},
#  {'qid': '645', 'docid': '100084', 'relevance': 1},
#  {'qid': '646', 'docid': '100084', 'relevance': 1},
#  {'qid': '647', 'docid': '100085', 'relevance': 1},
#  {'qid': '648', 'docid': '100085', 'relevance': 1},
#  {'qid': '649', 'docid': '100085', 'relevance': 1},
#  {'qid': '650', 'docid': '100085', 'relevance': 1},
#  {'qid': '651', 'docid': '100085', 'relevance': 1},
#  {'qid': '652', 'docid': '100085', 'relevance': 1},
#  {'qid': '653', 'docid': '100085', 'relevance': 1},
#  {'qid': '654', 'docid': '100085', 'relevance': 1},
#  {'qid': '655', 'docid': '100085', 'relevance': 1},
#  {'qid': '656', 'docid': '100085', 'relevance': 1},
#  {'qid': '657', 'docid': '100086', 'relevance': 1},
#  {'qid': '658', 'docid': '100086', 'relevance': 1},
#  {'qid': '659', 'docid': '100086', 'relevance': 1},
#  {'qid': '660', 'docid': '100086', 'relevance': 1},
#  {'qid': '661', 'docid': '100086', 'relevance': 1},
#  {'qid': '662', 'docid': '100086', 'relevance': 1},
#  {'qid': '663', 'docid': '100086', 'relevance': 1},
#  {'qid': '664', 'docid': '100087', 'relevance': 1},
#  {'qid': '665', 'docid': '100087', 'relevance': 1},
#  {'qid': '666', 'docid': '100087', 'relevance': 1},
#  {'qid': '667', 'docid': '100087', 'relevance': 1},
#  {'qid': '668', 'docid': '100087', 'relevance': 1},
#  {'qid': '669', 'docid': '100087', 'relevance': 1},
#  {'qid': '670', 'docid': '100087', 'relevance': 1},
#  {'qid': '671', 'docid': '100087', 'relevance': 1},
#  {'qid': '672', 'docid': '100087', 'relevance': 1},
#  {'qid': '673', 'docid': '100088', 'relevance': 1},
#  {'qid': '674', 'docid': '100088', 'relevance': 1},
#  {'qid': '675', 'docid': '100088', 'relevance': 1},
#  {'qid': '676', 'docid': '100088', 'relevance': 1},
#  {'qid': '677', 'docid': '100088', 'relevance': 1},
#  {'qid': '678', 'docid': '100088', 'relevance': 1},
#  {'qid': '679', 'docid': '100088', 'relevance': 1},
#  {'qid': '680', 'docid': '100088', 'relevance': 1},
#  {'qid': '681', 'docid': '100088', 'relevance': 1},
#  {'qid': '682', 'docid': '100089', 'relevance': 1},
#  {'qid': '683', 'docid': '100089', 'relevance': 1},
#  {'qid': '684', 'docid': '100089', 'relevance': 1},
#  {'qid': '685', 'docid': '100089', 'relevance': 1},
#  {'qid': '686', 'docid': '100089', 'relevance': 1},
#  {'qid': '687', 'docid': '100089', 'relevance': 1},
#  {'qid': '688', 'docid': '100089', 'relevance': 1},
#  {'qid': '689', 'docid': '100089', 'relevance': 1},
#  {'qid': '690', 'docid': '100090', 'relevance': 1},
#  {'qid': '691', 'docid': '100090', 'relevance': 1},
#  {'qid': '692', 'docid': '100090', 'relevance': 1},
#  {'qid': '693', 'docid': '100090', 'relevance': 1},
#  {'qid': '694', 'docid': '100091', 'relevance': 1},
#  {'qid': '695', 'docid': '100091', 'relevance': 1},
#  {'qid': '696', 'docid': '100091', 'relevance': 1},
#  {'qid': '697', 'docid': '100091', 'relevance': 1},
#  {'qid': '698', 'docid': '100092', 'relevance': 1},
#  {'qid': '699', 'docid': '100092', 'relevance': 1},
#  {'qid': '700', 'docid': '100092', 'relevance': 1},
#  {'qid': '701', 'docid': '100092', 'relevance': 1},
#  {'qid': '702', 'docid': '100093', 'relevance': 1},
#  {'qid': '703', 'docid': '100093', 'relevance': 1},
#  {'qid': '704', 'docid': '100093', 'relevance': 1},
#  {'qid': '705', 'docid': '100093', 'relevance': 1},
#  {'qid': '706', 'docid': '100093', 'relevance': 1},
#  {'qid': '707', 'docid': '100094', 'relevance': 1},
#  {'qid': '708', 'docid': '100094', 'relevance': 1},
#  {'qid': '709', 'docid': '100094', 'relevance': 1},
#  {'qid': '710', 'docid': '100095', 'relevance': 1},
#  {'qid': '711', 'docid': '100095', 'relevance': 1},
#  {'qid': '712', 'docid': '100095', 'relevance': 1},
#  {'qid': '713', 'docid': '100095', 'relevance': 1},
#  {'qid': '714', 'docid': '100096', 'relevance': 1},
#  {'qid': '715', 'docid': '100096', 'relevance': 1},
#  {'qid': '716', 'docid': '100096', 'relevance': 1},
#  {'qid': '717', 'docid': '100096', 'relevance': 1},
#  {'qid': '718', 'docid': '100096', 'relevance': 1},
#  {'qid': '719', 'docid': '100096', 'relevance': 1},
#  {'qid': '720', 'docid': '100096', 'relevance': 1},
#  {'qid': '721', 'docid': '100096', 'relevance': 1},
#  {'qid': '722', 'docid': '100096', 'relevance': 1},
#  {'qid': '723', 'docid': '100096', 'relevance': 1},
#  {'qid': '724', 'docid': '100097', 'relevance': 1},
#  {'qid': '725', 'docid': '100097', 'relevance': 1},
#  {'qid': '726', 'docid': '100097', 'relevance': 1},
#  {'qid': '727', 'docid': '100097', 'relevance': 1},
#  {'qid': '728', 'docid': '100098', 'relevance': 1},
#  {'qid': '729', 'docid': '100098', 'relevance': 1},
#  {'qid': '730', 'docid': '100098', 'relevance': 1},
#  {'qid': '731', 'docid': '100098', 'relevance': 1},
#  {'qid': '732', 'docid': '100098', 'relevance': 1},
#  {'qid': '733', 'docid': '100098', 'relevance': 1},
#  {'qid': '734', 'docid': '100098', 'relevance': 1},
#  {'qid': '735', 'docid': '100098', 'relevance': 1},
#  {'qid': '736', 'docid': '100099', 'relevance': 1},
#  {'qid': '737', 'docid': '100099', 'relevance': 1},
#  {'qid': '738', 'docid': '100099', 'relevance': 1},
#  {'qid': '739', 'docid': '100099', 'relevance': 1},
#  {'qid': '740', 'docid': '100099', 'relevance': 1},
#  {'qid': '741', 'docid': '100099', 'relevance': 1},
#  {'qid': '742', 'docid': '100099', 'relevance': 1},
#  {'qid': '743', 'docid': '100099', 'relevance': 1},
#  {'qid': '744', 'docid': '100099', 'relevance': 1},
#  {'qid': '745', 'docid': '100099', 'relevance': 1},
#  {'qid': '746', 'docid': '100100', 'relevance': 1},
#  {'qid': '747', 'docid': '100100', 'relevance': 1},
#  {'qid': '748', 'docid': '100100', 'relevance': 1},
#  {'qid': '749', 'docid': '100100', 'relevance': 1},
#  {'qid': '750', 'docid': '100100', 'relevance': 1},
#  {'qid': '751', 'docid': '100100', 'relevance': 1},
#  {'qid': '752', 'docid': '100100', 'relevance': 1},
#  {'qid': '753', 'docid': '100100', 'relevance': 1},
#  {'qid': '754', 'docid': '100101', 'relevance': 1},
#  {'qid': '755', 'docid': '100101', 'relevance': 1},
#  {'qid': '756', 'docid': '100101', 'relevance': 1},
#  {'qid': '757', 'docid': '100101', 'relevance': 1},
#  {'qid': '758', 'docid': '100101', 'relevance': 1},
#  {'qid': '759', 'docid': '100101', 'relevance': 1},
#  {'qid': '760', 'docid': '100101', 'relevance': 1},
#  {'qid': '761', 'docid': '100102', 'relevance': 1},
#  {'qid': '762', 'docid': '100102', 'relevance': 1},
#  {'qid': '763', 'docid': '100102', 'relevance': 1},
#  {'qid': '764', 'docid': '100102', 'relevance': 1},
#  {'qid': '765', 'docid': '100102', 'relevance': 1},
#  {'qid': '766', 'docid': '100102', 'relevance': 1},
#  {'qid': '767', 'docid': '100102', 'relevance': 1},
#  {'qid': '768', 'docid': '100102', 'relevance': 1},
#  {'qid': '769', 'docid': '100102', 'relevance': 1},
#  {'qid': '770', 'docid': '100103', 'relevance': 1},
#  {'qid': '771', 'docid': '100103', 'relevance': 1},
#  {'qid': '772', 'docid': '100103', 'relevance': 1},
#  {'qid': '773', 'docid': '100103', 'relevance': 1},
#  {'qid': '774', 'docid': '100103', 'relevance': 1},
#  {'qid': '775', 'docid': '100103', 'relevance': 1},
#  {'qid': '776', 'docid': '100103', 'relevance': 1},
#  {'qid': '777', 'docid': '100103', 'relevance': 1},
#  {'qid': '778', 'docid': '100103', 'relevance': 1},
#  {'qid': '779', 'docid': '100104', 'relevance': 1},
#  {'qid': '780', 'docid': '100104', 'relevance': 1},
#  {'qid': '781', 'docid': '100104', 'relevance': 1},
#  {'qid': '782', 'docid': '100104', 'relevance': 1},
#  {'qid': '783', 'docid': '100104', 'relevance': 1},
#  {'qid': '784', 'docid': '100104', 'relevance': 1},
#  {'qid': '785', 'docid': '100104', 'relevance': 1},
#  {'qid': '786', 'docid': '100104', 'relevance': 1},
#  {'qid': '787', 'docid': '100104', 'relevance': 1},
#  {'qid': '788', 'docid': '100105', 'relevance': 1},
#  {'qid': '789', 'docid': '100105', 'relevance': 1},
#  {'qid': '790', 'docid': '100105', 'relevance': 1},
#  {'qid': '791', 'docid': '100105', 'relevance': 1},
#  {'qid': '792', 'docid': '100105', 'relevance': 1},
#  {'qid': '793', 'docid': '100106', 'relevance': 1},
#  {'qid': '794', 'docid': '100106', 'relevance': 1},
#  {'qid': '795', 'docid': '100106', 'relevance': 1},
#  {'qid': '796', 'docid': '100106', 'relevance': 1},
#  {'qid': '797', 'docid': '100106', 'relevance': 1},
#  {'qid': '798', 'docid': '100106', 'relevance': 1},
#  {'qid': '799', 'docid': '100106', 'relevance': 1},
#  {'qid': '800', 'docid': '100106', 'relevance': 1},
#  {'qid': '801', 'docid': '100106', 'relevance': 1},
#  {'qid': '802', 'docid': '100106', 'relevance': 1},
#  {'qid': '803', 'docid': '100107', 'relevance': 1},
#  {'qid': '804', 'docid': '100107', 'relevance': 1},
#  {'qid': '805', 'docid': '100107', 'relevance': 1},
#  {'qid': '806', 'docid': '100107', 'relevance': 1},
#  {'qid': '807', 'docid': '100107', 'relevance': 1},
#  {'qid': '808', 'docid': '100107', 'relevance': 1},
#  {'qid': '809', 'docid': '100107', 'relevance': 1},
#  {'qid': '810', 'docid': '100107', 'relevance': 1},
#  {'qid': '811', 'docid': '100108', 'relevance': 1},
#  {'qid': '812', 'docid': '100108', 'relevance': 1},
#  {'qid': '813', 'docid': '100108', 'relevance': 1},
#  {'qid': '814', 'docid': '100108', 'relevance': 1},
#  {'qid': '815', 'docid': '100109', 'relevance': 1},
#  {'qid': '816', 'docid': '100109', 'relevance': 1},
#  {'qid': '817', 'docid': '100109', 'relevance': 1},
#  {'qid': '818', 'docid': '100109', 'relevance': 1},
#  {'qid': '819', 'docid': '100110', 'relevance': 1},
#  {'qid': '820', 'docid': '100110', 'relevance': 1},
#  {'qid': '821', 'docid': '100110', 'relevance': 1},
#  {'qid': '822', 'docid': '100110', 'relevance': 1},
#  {'qid': '823', 'docid': '100110', 'relevance': 1},
#  {'qid': '824', 'docid': '100111', 'relevance': 1},
#  {'qid': '825', 'docid': '100111', 'relevance': 1},
#  {'qid': '826', 'docid': '100111', 'relevance': 1},
#  {'qid': '827', 'docid': '100111', 'relevance': 1},
#  {'qid': '828', 'docid': '100112', 'relevance': 1},
#  {'qid': '829', 'docid': '100112', 'relevance': 1},
#  {'qid': '830', 'docid': '100112', 'relevance': 1},
#  {'qid': '831', 'docid': '100112', 'relevance': 1},
#  {'qid': '832', 'docid': '100112', 'relevance': 1},
#  {'qid': '833', 'docid': '100112', 'relevance': 1},
#  {'qid': '834', 'docid': '100112', 'relevance': 1},
#  {'qid': '835', 'docid': '100112', 'relevance': 1},
#  {'qid': '836', 'docid': '100112', 'relevance': 1},
#  {'qid': '837', 'docid': '100112', 'relevance': 1},
#  {'qid': '838', 'docid': '100113', 'relevance': 1},
#  {'qid': '839', 'docid': '100113', 'relevance': 1},
#  {'qid': '840', 'docid': '100113', 'relevance': 1},
#  {'qid': '841', 'docid': '100113', 'relevance': 1},
#  {'qid': '842', 'docid': '100113', 'relevance': 1},
#  {'qid': '843', 'docid': '100113', 'relevance': 1},
#  {'qid': '844', 'docid': '100113', 'relevance': 1},
#  {'qid': '845', 'docid': '100113', 'relevance': 1},
#  {'qid': '846', 'docid': '100113', 'relevance': 1},
#  {'qid': '847', 'docid': '100114', 'relevance': 1},
#  {'qid': '848', 'docid': '100114', 'relevance': 1},
#  {'qid': '849', 'docid': '100114', 'relevance': 1},
#  {'qid': '850', 'docid': '100114', 'relevance': 1},
#  {'qid': '851', 'docid': '100115', 'relevance': 1},
#  {'qid': '852', 'docid': '100115', 'relevance': 1},
#  {'qid': '853', 'docid': '100115', 'relevance': 1},
#  {'qid': '854', 'docid': '100115', 'relevance': 1},
#  {'qid': '855', 'docid': '100116', 'relevance': 1},
#  {'qid': '856', 'docid': '100116', 'relevance': 1},
#  {'qid': '857', 'docid': '100116', 'relevance': 1},
#  {'qid': '858', 'docid': '100116', 'relevance': 1},
#  {'qid': '859', 'docid': '100117', 'relevance': 1},
#  {'qid': '860', 'docid': '100117', 'relevance': 1},
#  {'qid': '861', 'docid': '100117', 'relevance': 1},
#  {'qid': '862', 'docid': '100117', 'relevance': 1},
#  {'qid': '863', 'docid': '100117', 'relevance': 1},
#  {'qid': '864', 'docid': '100117', 'relevance': 1},
#  {'qid': '865', 'docid': '100117', 'relevance': 1},
#  {'qid': '866', 'docid': '100118', 'relevance': 1},
#  {'qid': '867', 'docid': '100118', 'relevance': 1},
#  {'qid': '868', 'docid': '100118', 'relevance': 1},
#  {'qid': '869', 'docid': '100118', 'relevance': 1},
#  {'qid': '870', 'docid': '100118', 'relevance': 1},
#  {'qid': '871', 'docid': '100118', 'relevance': 1},
#  {'qid': '872', 'docid': '100118', 'relevance': 1},
#  {'qid': '873', 'docid': '100118', 'relevance': 1},
#  {'qid': '874', 'docid': '100118', 'relevance': 1},
#  {'qid': '875', 'docid': '100119', 'relevance': 1},
#  {'qid': '876', 'docid': '100119', 'relevance': 1},
#  {'qid': '877', 'docid': '100119', 'relevance': 1},
#  {'qid': '878', 'docid': '100119', 'relevance': 1},
#  {'qid': '879', 'docid': '100120', 'relevance': 1},
#  {'qid': '880', 'docid': '100120', 'relevance': 1},
#  {'qid': '881', 'docid': '100120', 'relevance': 1},
#  {'qid': '882', 'docid': '100120', 'relevance': 1},
#  {'qid': '883', 'docid': '100120', 'relevance': 1},
#  {'qid': '884', 'docid': '100120', 'relevance': 1},
#  {'qid': '885', 'docid': '100120', 'relevance': 1},
#  {'qid': '886', 'docid': '100121', 'relevance': 1},
#  {'qid': '887', 'docid': '100121', 'relevance': 1},
#  {'qid': '888', 'docid': '100121', 'relevance': 1},
#  {'qid': '889', 'docid': '100121', 'relevance': 1},
#  {'qid': '890', 'docid': '100121', 'relevance': 1},
#  {'qid': '891', 'docid': '100121', 'relevance': 1},
#  {'qid': '892', 'docid': '100121', 'relevance': 1},
#  {'qid': '893', 'docid': '100121', 'relevance': 1},
#  {'qid': '894', 'docid': '100121', 'relevance': 1},
#  {'qid': '895', 'docid': '100122', 'relevance': 1},
#  {'qid': '896', 'docid': '100122', 'relevance': 1},
#  {'qid': '897', 'docid': '100122', 'relevance': 1},
#  {'qid': '898', 'docid': '100122', 'relevance': 1},
#  {'qid': '899', 'docid': '100122', 'relevance': 1},
#  {'qid': '900', 'docid': '100122', 'relevance': 1},
#  {'qid': '901', 'docid': '100122', 'relevance': 1},
#  {'qid': '902', 'docid': '100122', 'relevance': 1},
#  {'qid': '903', 'docid': '100122', 'relevance': 1},
#  {'qid': '904', 'docid': '100123', 'relevance': 1},
#  {'qid': '905', 'docid': '100123', 'relevance': 1},
#  {'qid': '906', 'docid': '100123', 'relevance': 1},
#  {'qid': '907', 'docid': '100123', 'relevance': 1},
#  {'qid': '908', 'docid': '100123', 'relevance': 1},
#  {'qid': '909', 'docid': '100123', 'relevance': 1},
#  {'qid': '910', 'docid': '100123', 'relevance': 1},
#  {'qid': '911', 'docid': '100123', 'relevance': 1},
#  {'qid': '912', 'docid': '100123', 'relevance': 1},
#  {'qid': '913', 'docid': '100123', 'relevance': 1},
#  {'qid': '914', 'docid': '100124', 'relevance': 1},
#  {'qid': '915', 'docid': '100124', 'relevance': 1},
#  {'qid': '916', 'docid': '100124', 'relevance': 1},
#  {'qid': '917', 'docid': '100124', 'relevance': 1},
#  {'qid': '918', 'docid': '100124', 'relevance': 1},
#  {'qid': '919', 'docid': '100124', 'relevance': 1},
#  {'qid': '920', 'docid': '100125', 'relevance': 1},
#  {'qid': '921', 'docid': '100125', 'relevance': 1},
#  {'qid': '922', 'docid': '100125', 'relevance': 1},
#  {'qid': '923', 'docid': '100125', 'relevance': 1},
#  {'qid': '924', 'docid': '100125', 'relevance': 1},
#  {'qid': '925', 'docid': '100125', 'relevance': 1},
#  {'qid': '926', 'docid': '100125', 'relevance': 1},
#  {'qid': '927', 'docid': '100125', 'relevance': 1},
#  {'qid': '928', 'docid': '100126', 'relevance': 1},
#  {'qid': '929', 'docid': '100126', 'relevance': 1},
#  {'qid': '930', 'docid': '100126', 'relevance': 1},
#  {'qid': '931', 'docid': '100126', 'relevance': 1},
#  {'qid': '932', 'docid': '100126', 'relevance': 1},
#  {'qid': '933', 'docid': '100126', 'relevance': 1},
#  {'qid': '934', 'docid': '100126', 'relevance': 1},
#  {'qid': '935', 'docid': '100126', 'relevance': 1},
#  {'qid': '936', 'docid': '100127', 'relevance': 1},
#  {'qid': '937', 'docid': '100127', 'relevance': 1},
#  {'qid': '938', 'docid': '100127', 'relevance': 1},
#  {'qid': '939', 'docid': '100127', 'relevance': 1},
#  {'qid': '940', 'docid': '100127', 'relevance': 1},
#  {'qid': '941', 'docid': '100127', 'relevance': 1},
#  {'qid': '942', 'docid': '100127', 'relevance': 1},
#  {'qid': '943', 'docid': '100127', 'relevance': 1},
#  {'qid': '944', 'docid': '100127', 'relevance': 1},
#  {'qid': '945', 'docid': '100127', 'relevance': 1},
#  {'qid': '946', 'docid': '100128', 'relevance': 1},
#  {'qid': '947', 'docid': '100128', 'relevance': 1},
#  {'qid': '948', 'docid': '100128', 'relevance': 1},
#  {'qid': '949', 'docid': '100128', 'relevance': 1},
#  {'qid': '950', 'docid': '100128', 'relevance': 1},
#  {'qid': '951', 'docid': '100128', 'relevance': 1},
#  {'qid': '952', 'docid': '100128', 'relevance': 1},
#  {'qid': '953', 'docid': '100128', 'relevance': 1},
#  {'qid': '954', 'docid': '100128', 'relevance': 1},
#  {'qid': '955', 'docid': '100128', 'relevance': 1},
#  {'qid': '956', 'docid': '100129', 'relevance': 1},
#  {'qid': '957', 'docid': '100129', 'relevance': 1},
#  {'qid': '958', 'docid': '100129', 'relevance': 1},
#  {'qid': '959', 'docid': '100129', 'relevance': 1},
#  {'qid': '960', 'docid': '100129', 'relevance': 1},
#  {'qid': '961', 'docid': '100130', 'relevance': 1},
#  {'qid': '962', 'docid': '100130', 'relevance': 1},
#  {'qid': '963', 'docid': '100130', 'relevance': 1},
#  {'qid': '964', 'docid': '100130', 'relevance': 1},
#  {'qid': '965', 'docid': '100130', 'relevance': 1},
#  {'qid': '966', 'docid': '100130', 'relevance': 1},
#  {'qid': '967', 'docid': '100130', 'relevance': 1},
#  {'qid': '968', 'docid': '100130', 'relevance': 1},
#  {'qid': '969', 'docid': '100131', 'relevance': 1},
#  {'qid': '970', 'docid': '100131', 'relevance': 1},
#  {'qid': '971', 'docid': '100131', 'relevance': 1},
#  {'qid': '972', 'docid': '100131', 'relevance': 1},
#  {'qid': '973', 'docid': '100131', 'relevance': 1},
#  {'qid': '974', 'docid': '100132', 'relevance': 1},
#  {'qid': '975', 'docid': '100132', 'relevance': 1},
#  {'qid': '976', 'docid': '100132', 'relevance': 1},
#  {'qid': '977', 'docid': '100132', 'relevance': 1},
#  {'qid': '978', 'docid': '100132', 'relevance': 1},
#  {'qid': '979', 'docid': '100132', 'relevance': 1},
#  {'qid': '980', 'docid': '100132', 'relevance': 1},
#  {'qid': '981', 'docid': '100132', 'relevance': 1},
#  {'qid': '982', 'docid': '100132', 'relevance': 1},
#  {'qid': '983', 'docid': '100132', 'relevance': 1},
#  {'qid': '984', 'docid': '100133', 'relevance': 1},
#  {'qid': '985', 'docid': '100133', 'relevance': 1},
#  {'qid': '986', 'docid': '100133', 'relevance': 1},
#  {'qid': '987', 'docid': '100133', 'relevance': 1},
#  {'qid': '988', 'docid': '100134', 'relevance': 1},
#  {'qid': '989', 'docid': '100134', 'relevance': 1},
#  {'qid': '990', 'docid': '100134', 'relevance': 1},
#  {'qid': '991', 'docid': '100134', 'relevance': 1},
#  {'qid': '992', 'docid': '100134', 'relevance': 1},
#  {'qid': '993', 'docid': '100134', 'relevance': 1},
#  {'qid': '994', 'docid': '100134', 'relevance': 1},
#  {'qid': '995', 'docid': '100135', 'relevance': 1},
#  {'qid': '996', 'docid': '100135', 'relevance': 1},
#  {'qid': '997', 'docid': '100135', 'relevance': 1},
#  {'qid': '998', 'docid': '100135', 'relevance': 1},
#  {'qid': '999', 'docid': '100136', 'relevance': 1},
#  ...]

# %%
assert len(qrels_l) == len(queries)

# %% [markdown]
# ## Export

# %%
DATA_DIR = "/home/jinho/FlagEmbedding_Aizip/dataset/sb_qna"

# %%
with open(f"{DATA_DIR}/test_queries.jsonl", "w") as f:
    for record in queries_l:
        f.write(json.dumps(record) + '\n')

# %%
with open(f"{DATA_DIR}/test_qrels.jsonl", "w") as f:
    for record in qrels_l:
        f.write(json.dumps(record) + '\n')

# %%
with open(f"{DATA_DIR}/corpus.jsonl", "w") as f:
    for record in corpus_l:
        f.write(json.dumps(record) + '\n')

# %% [markdown]
# ## (For Japanese) Create a split version

# %%
from sudachipy import tokenizer
from sudachipy import dictionary

# %%
mode = tokenizer.Tokenizer.SplitMode.B

# %%
tokenizer_obj = dictionary.Dictionary().create()

# %%
corpus_l[0]['text']
# Out:
# 'Slackのゲストアカウントの有効期限が切れた（解除済みアカウント）場合は、ゲスト管理システムからゲスト新規登録申請と利用サービス登録申請を実施下さい。\n※ゲスト登録が有効期限内の場合は、マイゲスト一覧から利用サービス登録申請のみ実施下さい\n申請方法は下記手順を参照下さい。\n\n・【ゲスト管理システム】マニュアル-申請者向け\nhttps://docs.google.com/presentation/d/1Z0PUkjNUr9r2GCq5ZEEddd5jPUJg48kPMsCxv5Mtw_M/edit#slide=id.g1287222f34d_1_61\n\n申請の上長承認後、5営業日以内にアカウントが有効化されます。\n有効化完了後は下記メールが送信されますので、メールを確認次第、必要なチャンネルにゲストを招待して下さい。\n※ゲストをチャンネルに招待する際はメールアドレスではなくSlack上の氏名で検索下さい\n件名：【ゲスト管理】利用サービスプロビジョニングエラー対応完了通知\n\n■お問合せ先\n・OA Support Net\n\u3000http://oa.bb.local/oasupport/inquiry_web\n\u3000（投稿カテゴリ：Slack）'

# %%
def split_text(input_dic):
    new_dic = input_dic.copy()
    split_t = ' '.join([m.surface() for m in tokenizer_obj.tokenize(input_dic['text'], mode)])
    new_dic['text'] = split_t
    return new_dic

# %%
split_queries_l = [split_text(q) for q in queries_l]

# %%
split_queries_l
# Out:
# [{'id': '0', 'text': 'ゲスト の アカウント の 有効 期限 が 切れ た 場合 の 対応 方法 を 教え て 欲しい'},
#  {'id': '1', 'text': 'ゲスト の アカウント の 有効 期限 が 切れ て いる'},
#  {'id': '2', 'text': 'ゲスト アカウント の 有効 期限 が 切れ た の で 、 再度 、 有効 に し て 欲しい'},
#  {'id': '3', 'text': 'ゲスト アカウント の 有効 期限 を 再度 有効 に し たい'},
#  {'id': '4', 'text': 'WHC に つい て 問い合わせ し たい'},
#  {'id': '5', 'text': 'WHC の 工数 入力 に つい て 教え て ほしい'},
#  {'id': '6', 'text': 'Trinity ( WHC ) の アドレス を 教え て ください 。'},
#  {'id': '7', 'text': 'WHC 申請 方法 を 教え て 欲しい'},
#  {'id': '8', 'text': 'WHC の 申請 を し たい'},
#  {'id': '9', 'text': 'WHC の 申請 方法 を 確認 し たい'},
#  {'id': '10', 'text': '研修 は WHC に どの よう に 登録 すれ ば よい か ？'},
#  {'id': '11', 'text': 'WHC は どの よう に 申請 し たら いい でしょう か ？'},
#  {'id': '12', 'text': 'WHC に つい て'},
#  {'id': '13', 'text': 'WHC に つい て 問い合わせ し たい 。'},
#  {'id': '14', 'text': 'Chrome の 動作 が おかしい の で 再 インストール し たい'},
#  {'id': '15', 'text': '準 OAPC で GoogleChrome が 起動 し なく なり まし た'},
#  {'id': '16', 'text': 'Chrome を ダウン グレード し たい'},
#  {'id': '17', 'text': 'Chrome の 再 インストール 方法 が 知り たい'},
#  {'id': '18', 'text': 'GoogleChrome を インストール し たい'},
#  {'id': '19', 'text': '準 OAPC へ Chrome を インストール し たい'},
#  {'id': '20', 'text': '準 OAPC へ Chrome を 設定 し たい'},
#  {'id': '21', 'text': 'GoogleChrome の インストール が 失敗 し て しまっ た 。'},
#  {'id': '22', 'text': 'Chrome の インストール 方法 が わかり ませ ん 。'},
#  {'id': '23', 'text': 'Chrome の アンインストール 方法 を 教え て 欲しい'},
#  {'id': '24', 'text': 'データ の PDF 化 が 出来 ない'},
#  {'id': '25', 'text': 'ファイル 等 の PDF 化 に つい て'},
#  {'id': '26', 'text': 'Word 文書 を PDF に 変換 し たい'},
#  {'id': '27', 'text': 'PDF 化 の 手順 を 教え て 欲しい'},
#  {'id': '28',
#   'text': 'PC 故障 に より 新しい PC に 交換 に なり まし た 。 \n 資料 を PDF 化 する 方法 に つい て 推奨 方法 は ある の でしょう か 。'},
#  {'id': '29', 'text': 'Excel など の ファイル を PDF 化 し たい'},
#  {'id': '30', 'text': 'エクセル を PDF 化 し たい'},
#  {'id': '31', 'text': 'PDF 化 の 方法 を 教え て 欲しい'},
#  {'id': '32',
#   'text': 'GooglePlay 未登録 アプリ の インストール 時 、 「 インストール は ブロック さ れ まし た \u3000 携帯 端末 の セキュリティ 上 の 設定 で 供給 元 不明 の Application の インストール を ブロック し て い ます 」 と エラー が 表示 さ れ まし た 。 「 提供 元 不明 アプリ 」 に チェック を 入れ て も よい でしょう か 。'},
#  {'id': '33',
#   'text': 'GooglePlay 未登録 アプリ の インストール 時 、 「 インストール は ブロック さ れ まし た \u3000 携帯 端末 の セキュリティ 上 の 設定 で 供給 元 不明 の Application の インストール を ブロック し て い ます 」 と エラー が 表示 さ れ ます 。'},
#  {'id': '34', 'text': '供給 元 不明 の GooglePlay アプリ を インストール する 方法 を 教え て ください 。'},
#  {'id': '35',
#   'text': 'GooglePlay 未登録 の アプリ を インストール し たい が 、 「 インストール は ブロック さ れ まし た \u3000 携帯 端末 の セキュリティ 上 の 設定 で 供給 元 不明 の Application の インストール を ブロック し て い ます 」 と エラー が 表示 さ れる 。'},
#  {'id': '36',
#   'text': 'GooglePlay アプリ を インストール しよう と する と 、 「 インストール は ブロック さ れ まし た \u3000 携帯 端末 の セキュリティ 上 の 設定 で 供給 元 不明 の Application の インストール を ブロック し て い ます 」 と 表示 さ れ ます 。'},
#  {'id': '37', 'text': 'iPhone / iPad の バックアップ 方法 を 教え て ください 。'},
#  {'id': '38',
#   'text': 'iCloud に バックアップ が ある 確認 し たい が 設定 の 中 に iCloud が あり ませ ん 。'},
#  {'id': '39', 'text': 'iCloud の バックアップ 方法 を 教え て ください 。'},
#  {'id': '40', 'text': 'iCloud の バックアップ が でき ない'},
#  {'id': '41', 'text': 'iCloud を 使用 し て バックアップ を 取得 し たい'},
#  {'id': '42', 'text': 'View 環境 で ネットワーク プリンタ の 設定 を し たい'},
#  {'id': '43', 'text': 'View 環境 で プリンタ インストール し たい'},
#  {'id': '44', 'text': 'View 環境 で の プリンター 設定 方法 を 教え て ください 。'},
#  {'id': '45', 'text': 'View で プリンター を 使い たい'},
#  {'id': '46', 'text': 'View で プリンタ 設定 時 に IP アドレス を 入力 し た が 、 エラー に なる'},
#  {'id': '47', 'text': 'View 環境 で 複数 の プリンタ を 設定 し たい'},
#  {'id': '48', 'text': 'View の プリンタ 設定 画面 を 再表示 さ せ たい'},
#  {'id': '49',
#   'text': 'View で プリンタ の 再設定 を 行っ て いる の です が 、 操作 を 誤り 「 完了 し ませ ん でし た 」 と 表示 さ れ まし た 。 \n その 後 再 ログイン を し た の です が プリンタ 設定 画面 が 出 て こ なく なり まし た 。'},
#  {'id': '50', 'text': 'View 環境 で プリンタ ドライバ を 再設定 する 方法 を 教え て ほしい'},
#  {'id': '51',
#   'text': 'View で 複合機 の IP アドレス を 入力 し 、 プリンタ の 設定 を 行っ て いる が 、 エラー に なる'},
#  {'id': '52', 'text': '暗号化 さ れ た Office ファイル の 解除 を し たい'},
#  {'id': '53', 'text': 'Office の アクセス 制限 を 解除 し たい'},
#  {'id': '54',
#   'text': 'ファイル サーバー に 保存 し て いる PowerPoint ファイル を 客先 に 送り たい 。 客先 の 端末 上 で も Office ファイル は 問題 なく 開ける でしょう か 。'},
#  {'id': '55', 'text': '暗号化 さ れ た Office ファイル を 開く こと が でき ない'},
#  {'id': '56', 'text': '暗号化 さ れ た Office ファイル の 解除 方法 を 知り たい'},
#  {'id': '57', 'text': 'Excel の 暗号化 の 解除 方法 が わから ない'},
#  {'id': '58', 'text': '社外 に Excel ファイル を 送信 する 際 に AzureRMS の 解除 を し たい'},
#  {'id': '59', 'text': 'Office ファイル の 暗号化 を 解除 し たい'},
#  {'id': '60', 'text': '社外 に Office ファイル を 送信 し たい の で 、 暗号化 解除 の 方法 を 知り たい'},
#  {'id': '61',
#   'text': 'パワーポイント の ファイル を お客様 先 に 送っ たら 客先 で 「 開け ない 」 と 言わ れ た 。 この 場合 どう すれ ば いい です か 。'},
#  {'id': '62', 'text': 'EUC に つい て 問合せ たい'},
#  {'id': '63', 'text': 'EUC に つい て 確認 し たい'},
#  {'id': '64', 'text': 'EUC の 問合せ先 は どこ です か ？'},
#  {'id': '65', 'text': 'EUC の 管理 部署 を 教え て 欲しい'},
#  {'id': '66', 'text': '部署 で 購入 し た 端末 を OA 環境 に 接続 し たい'},
#  {'id': '67', 'text': '部門 端末 を OA ネットワーク に 接続 し たい'},
#  {'id': '68', 'text': '部門 PC を OA 化 し たい'},
#  {'id': '69', 'text': '部門 導入 PC を 社内 NW に 接続 し たい'},
#  {'id': '70', 'text': '準 OAPC を 社内 ネットワーク に 接続 し たい'},
#  {'id': '71', 'text': '部門 PC を OA ネットワーク に 接続 し たい'},
#  {'id': '72', 'text': '部門 購入 端末 を OANW に 繋げ たい'},
#  {'id': '73', 'text': '部門 PC を OA 環境 に 接続 し たい'},
#  {'id': '74', 'text': '部門 PC を 社内 NW に 接続 し たい'},
#  {'id': '75', 'text': '部門 PC を 社内 ネットワーク に 接続 する 手順 が 知り たい'},
#  {'id': '76', 'text': 'PC から Gmail に アクセス でき なく なり まし た'},
#  {'id': '77', 'text': 'Chrome の キャッシュ クリア 方法 を 教え て'},
#  {'id': '78',
#   'text': 'GoogleChrome を 開い て Gmail を 見よう と し た ところ 画面 が 真っ白 で 何 も 表示 さ れ ない 。'},
#  {'id': '79', 'text': 'Google の キャッシュ クリア 方法 を 知り たい'},
#  {'id': '80', 'text': 'Google Chrome の キャッシュ を 削除 し たい'},
#  {'id': '81', 'text': 'Chrome の キャッシュ を クリア し たい'},
#  {'id': '82',
#   'text': 'GoogleChrome を 開く と 画面 が 真っ白 で お 待ち ください と 表示 さ れ て いる 。'},
#  {'id': '83',
#   'text': 'Chrome から Gmail に 接続 でき ませ ん 。 メール アドレス 入力 し 次 へ ボタン を クリック する と HTTP 500 ? ? ? ? ? と 表示 さ れ た 画面 に なり ます 。'},
#  {'id': '84',
#   'text': 'OAPC で Gmail 本文 が 読み込め ませ ん 。 Google へ の 接続 に 問題 が 発生 し て い ます と 表示 さ れ て い ます 。'},
#  {'id': '85', 'text': 'CI   Tools   ( by   CITeam ) を 使用 し たい'},
#  {'id': '86', 'text': 'エイリアス から 名前 検索 し たい'},
#  {'id': '87', 'text': 'アカウント名 から 社員名 を 調べる 方法 を 教え て'},
#  {'id': '88', 'text': 'エイリアス から メール アドレス を 確認 する 方法 を 教え て ください'},
#  {'id': '89', 'text': 'Gmail アカウント から 氏名 、 部署名 を 取得 する に は ？'},
#  {'id': '90', 'text': 'エイリアス や 氏名 から メール アドレス を 確認 する 方法 を 教え て ください'},
#  {'id': '91', 'text': 'エイリアス から 社員 の 名前 を 調べる 方法 を 教え て ほしい'},
#  {'id': '92', 'text': '自分 の OA アカウント を 確認 し たい'},
#  {'id': '93', 'text': 'CI   Tools を インストール し たい'},
#  {'id': '94', 'text': 'OA アカウント を 検索 し たい'},
#  {'id': '95', 'text': '故障 交換 を し た 業務用 携帯 電話 B の 返却 宛先 を 知り たい'},
#  {'id': '96', 'text': '業 端 B の iPad を 返却 し たい'},
#  {'id': '97',
#   'text': '派遣 社員 が 使用 する 業務 端末 B の 返却 方法 を 教え て いただい て も よろしい でしょう か ？'},
#  {'id': '98', 'text': '業務 端末 B の 交換 対応 後 の 返却 先 は どこ です が ？'},
#  {'id': '99', 'text': '業 端 B の 返却 方法 が 知り たい'},
#  {'id': '100', 'text': '業務 端末 B の 返却 に つい て'},
#  {'id': '101', 'text': '業務 端末 B の 返却 先 は どちら でしょう か'},
#  {'id': '102', 'text': '業 端 B の 返却 方法 を 教え て'},
#  {'id': '103', 'text': '業務用 携帯 電話 B の 返却 は どう し たら いい ？'},
#  {'id': '104', 'text': '業 端 B の 返却 手順 を 教え て'},
#  {'id': '105', 'text': 'W ドライブ にて ファイル が 保存 でき ない'},
#  {'id': '106', 'text': 'W ドライブ の 容量 が 不足 し て いる 。 容量 増加 する こと は 可能 です か 。'},
#  {'id': '107', 'text': 'W ドライブ の 容量 が 不足 し て き た'},
#  {'id': '108', 'text': 'W ドライブ の 容量 を 増やし たい'},
#  {'id': '109', 'text': 'View で ファイル の DL を 行う と 「 ディスク が いっぱい 」 と 表示 さ れる'},
#  {'id': '110', 'text': 'W ドライブ の 容量 増加 を し て ほしい'},
#  {'id': '111', 'text': 'W ドライブ の 容量 が 枯渇 し て いる'},
#  {'id': '112', 'text': 'W ドライブ の 容量 を 教え て'},
#  {'id': '113', 'text': 'W ドライブ の 容量 が 少ない'},
#  {'id': '114', 'text': 'W ドライブ の 容量 増加 を し たい'},
#  {'id': '115',
#   'text': 'iPhone の 連絡先 から 別 拠点 の 人 の 電話 番号 が 検索 でき なく なり まし た 。 改善 方法 を 教え て ください 。'},
#  {'id': '116', 'text': 'あんしん バックアップ アプリ 利用 方法 を 教え て 欲しい'},
#  {'id': '117',
#   'text': '機種 変更 で 連絡先 を 移行 し た が 、 残っ て しまう 連絡先 が あり ます 。 移行 方法 を 教え て ください 。'},
#  {'id': '118', 'text': 'iPhone の 連絡先 が 移行 出来 ない'},
#  {'id': '119',
#   'text': 'Android から iPhone に 機種 変更 し た が 、 同期 で 移行 でき ない 連絡先 が あり ます 。'},
#  {'id': '120', 'text': '機種 変更 の 時 に 連絡先 を 移行 する 方法 を 教え て ください 。'},
#  {'id': '121', 'text': '共有 ドライブ に 保存 し た ファイル が 削除 でき ない'},
#  {'id': '122', 'text': '共有 ドライブ 内 の データ が 消せる 人 の 権限 を 教え て 欲しい'},
#  {'id': '123', 'text': '共有 ドライブ 内 に 保存 し た ファイル を 削除 する 方法 を 教え て 欲しい'},
#  {'id': '124', 'text': '共有 ドライブ 内 で ファイル の 削除 が でき ませ ん 。 どう すれ ば よい です か ？'},
#  {'id': '125', 'text': '誤っ て ワークス ペース から 退出 し て しまい まし た'},
#  {'id': '126',
#   'text': 'ワークス ペース から サイン アウト し て しまっ た 場合 の 再 サイン イン 方法 を 教え て 欲しい'},
#  {'id': '127', 'text': '誤っ て ワークス ペース から サイン アウト し て しまい まし た'},
#  {'id': '128', 'text': 'ワークス ペース から 退出 し て しまっ た 場合 の 再 参加 方法 を 教え て 欲しい'},
#  {'id': '129', 'text': 'PDF を 圧縮 し パスワード を かけ たい'},
#  {'id': '130', 'text': 'PDF に パスワード を かける 方法 を 教え て'},
#  {'id': '131',
#   'text': 'PDF ファイル の パスワード を かける 操作 は Adobe   Reader で も 可能 です か'},
#  {'id': '132', 'text': 'PDF ファイル に パスワード を 設定 する'},
#  {'id': '133', 'text': 'PDF に パスワード を かける に は ソフト の インストール が 必要 です か 。'},
#  {'id': '134', 'text': 'PDF に パスワード を 付与 し たい'},
#  {'id': '135', 'text': 'PDF で パスワード 設定 し たい'},
#  {'id': '136', 'text': 'PDF ファイル に パスワード 設定 を おこない たい'},
#  {'id': '137', 'text': 'PDF に パスワード を つけ たい'},
#  {'id': '138', 'text': 'Acrobat   Pro   DC で PDF に PW を かけ たい'},
#  {'id': '139', 'text': 'Zoom で イヤホン から 音 が 聞こえ ませ ん'},
#  {'id': '140', 'text': 'Zoom ミーティング の 際 に イヤホン を 使う に は どう し たら いい です か ？'},
#  {'id': '141', 'text': 'イヤホン で は なく PC 本体 から 音声 が 聞こえる 場合 の 対処 方法 を 教え て'},
#  {'id': '142', 'text': 'イヤホン で Zoom ミーティング に 参加 する 方法 を 知り たい'},
#  {'id': '143', 'text': '共有 グループ の 管理者 を 知り たい'},
#  {'id': '144', 'text': '共有 グループ の 管理者 の 確認 方法 を 教え て 欲しい'},
#  {'id': '145', 'text': '共有 グループ の 管理者 を 確認 し たい'},
#  {'id': '146', 'text': '共有 グループ の ML の 管理者 を 調べ たい'},
#  {'id': '147', 'text': '共有 メール の 管理者 を 確認 し たい'},
#  {'id': '148', 'text': '共有 グループ の 管理者 の 確認 方法 に つい て'},
#  {'id': '149',
#   'text': 'G   Suite   共有 グループ メンバー 管理 で 管理者 に なっ て いる 人 の 確認 方法 を 教え て ください'},
#  {'id': '150', 'text': '管理者 共有 グループ の 管理者 名 を 確認 する に は ？'},
#  {'id': '151', 'text': '共有 グループ アドレス の 管理者 確認 方法 が 知り たい'},
#  {'id': '152', 'text': '共有 グループ の 管理者 は どこ で 確認 でき ます か ？'},
#  {'id': '153',
#   'text': '業 端 A   iPhone で VPN に 繋ごう と する と 、 「 VPN サーバー と の ネゴシエーション に 失敗 し まし た 。 」 と いう エラー が で て くる'},
#  {'id': '154',
#   'text': '「 VPN サーバー と の ネゴシエーション に 失敗 し まし た 」 と 表示 さ れ まし た 。 再設定 しか 方法 は ない でしょう か 。'},
#  {'id': '155',
#   'text': 'エラー ： 「 VPN サーバ と の ネゴシエーション に 失敗 し まし た 。 」 が 表示 さ れる'},
#  {'id': '156',
#   'text': '業 端 A   iPhone で VPN 接続 しよう と する と ネゴシエーション に 失敗 し まし た が 表示 さ れる'},
#  {'id': '157',
#   'text': '「 VPN サーバー と の ネゴシエーション に 失敗 し まし た 」 と 表示 さ れ まし た 。 対応 方法 は あり ます か 。'},
#  {'id': '158',
#   'text': '「 VPN サーバ と の ネゴシエーション に 失敗 し まし た 」 と 表示 さ れ 、 iPhone から VPN 接続 でき ない'},
#  {'id': '159', 'text': 'ゲスト 管理 システム の 管理者 G を 移管 する 方法 を 教え て'},
#  {'id': '160',
#   'text': 'ゲスト 管理 システム の 管理者 グループ の ゲスト を 別 の 管理者 グループ に 移行 する 方法 を 教え て'},
#  {'id': '161',
#   'text': 'ゲスト 管理 システム の 管理者 グループ に 紐 づく ゲスト を 別 の 管理者 グループ に 移行 し たい'},
#  {'id': '162', 'text': 'ゲスト 管理 システム の 管理者 G を 移管 する こと は 出来 ます か ？'},
#  {'id': '163',
#   'text': 'OA アカウント の パスワード を 間違え て ビット ロッカー の ロック が かかっ て しまっ た'},
#  {'id': '164', 'text': 'OAPC の Bitlocker 回復 キー を 知り たい'},
#  {'id': '165', 'text': 'BitLocker の 画面 が 出 て PC に ログイン でき ない'},
#  {'id': '166', 'text': 'Bitlocker の 回復 キー を 知り たい です'},
#  {'id': '167',
#   'text': 'OAPC が パスワード 入力 失敗 に より BitLocker の ロック が かかっ て しまい まし た 。 解除 する ため の 方法 を 教え て ください 。'},
#  {'id': '168',
#   'text': 'OAPC で PC 起動 時 に BitLocker の 回復 キー を 求め て き て おり Windows が 起動 でき ませ ん 。'},
#  {'id': '169', 'text': 'PC 起動 時 に BitLocker 回復 キー の 入力 を 求め られ ます'},
#  {'id': '170', 'text': 'OAPC 起動 時 に ビット ロッカー リカバリー と 表示 さ れ て ログイン でき ませ ん 。'},
#  {'id': '171', 'text': 'Bitlocker 回復 キー を 教え て ください'},
#  {'id': '172',
#   'text': 'PC 起動 時 に ビット ロッカー リカバリー と いう 画面 で 数字 の 入力 を 求め られ て い ます 。'},
#  {'id': '173', 'text': '業務 端末 A の iPhone で 4 G 回線 が 使用 でき ませ ん 。'},
#  {'id': '174', 'text': '業務 端末 A の iPhone で 5 G 経由 の 通信 が でき ない'},
#  {'id': '175', 'text': '業務 端末 A の iPhone で 5 G 経由 の 通信 が でき ませ ん 。'},
#  {'id': '176', 'text': '業務 端末 A の iPhone で 4 G が OFF に なっ て い ます 。'},
#  {'id': '177', 'text': '業務 端末 A の iPad で 4 G モバイル データ 通信 が でき ない'},
#  {'id': '178', 'text': 'iPhone の MDM プロファイル インストール 時 に エラー に なる'},
#  {'id': '179',
#   'text': '業 端 A   iPhone で MDM 設定 時 「 プロファイル の インストール が でき ませ ん でし た 」 と 表示 さ れ まし た 。 どこ に 問い合わせれ ば いい でしょう か 。'},
#  {'id': '180', 'text': 'iPhone の MDM プロファイル が インストール エラー に なっ て しまい ます'},
#  {'id': '181', 'text': 'iPhone の MDM プロファイル が インストール さ れ ませ ん'},
#  {'id': '182',
#   'text': '「 文書 の 取り出し が でき ませ ん でし た 」 と 表示 さ れ て スキャン データ の 取り出し が でき ない'},
#  {'id': '183', 'text': 'ゼロックス の 親展 ボックス から スキャン データ の 取り出し が でき ない'},
#  {'id': '184', 'text': 'ゼロックス の スキャナ の 取り出し が でき ない'},
#  {'id': '185', 'text': '親展 ボックス から スキャナ の 取り出し が でき ない'},
#  {'id': '186', 'text': 'ソリューション 販売 管理 システム に つい て 確認 し たい'},
#  {'id': '187', 'text': 'ソリューション 販売 管理 システム の 問合せ先 は どこ です か ？'},
#  {'id': '188', 'text': 'ソリューション 販売 管理 システム の 管理 部署 を 教え て 欲しい'},
#  {'id': '189', 'text': 'ソリューション 販売 管理 システム に つい て 問い合わせ し たい'},
#  {'id': '190', 'text': '仕入 販売 管理 に ログイン でき ない'},
#  {'id': '191', 'text': 'ソリューション 販売 管理 の パスワード を 忘れ まし た'},
#  {'id': '192', 'text': '仕入 販売 管理 システム に 入れ ませ ん 。'},
#  {'id': '193', 'text': 'ソリューション 販売 管理 システム に つい て 問合せ たい'},
#  {'id': '194', 'text': 'ソリューション 販売 管理 システム の PW を 初期化 し たい'},
#  {'id': '195', 'text': 'グループ アドレス で 不在 通知 設定 を し たい'},
#  {'id': '196', 'text': 'グループ アドレス で 不在 通知 の 設定 は 可能 です か ？'},
#  {'id': '197', 'text': 'グループ メール アドレス で 不在 通知 設定 方法 を 教え て 欲しい'},
#  {'id': '198', 'text': 'Google グループ アドレス の 不在 通知 設定 を し たい'},
#  {'id': '199', 'text': '共有 メール アドレス で 不在 通知 を 設定 する こと は でき ます か ？'},
#  {'id': '200', 'text': 'Fruits の 問合せ先 は どこ です か ？'},
#  {'id': '201', 'text': 'VoiceNet に つい て 確認 し たい'},
#  {'id': '202', 'text': 'VoiceNet の 管理 部署 を 教え て 欲しい'},
#  {'id': '203', 'text': 'VoiceNet に つい て 問合せ たい'},
#  {'id': '204', 'text': 'Fruits に つい て 確認 し たい'},
#  {'id': '205', 'text': 'Fruits の 管理 部署 を 教え て 欲しい'},
#  {'id': '206', 'text': 'VoiceNet の 問合せ先 は どこ です か ？'},
#  {'id': '207', 'text': 'Fruits に つい て 問合せ たい'},
#  {'id': '208', 'text': 'iOS 用 の アプリ 提供 を し たい が 、 提供 方法 が 分から ない'},
#  {'id': '209', 'text': '業務用 端末 に アプリ を 配信 し たい'},
#  {'id': '210', 'text': 'iOS 用 の アプリ の 提供 方法 を 相談 し たい'},
#  {'id': '211', 'text': 'iPhone に アプリ の 配信 を し たい が 、 対応 方法 が 分から ない'},
#  {'id': '212', 'text': 'Android 用 の アプリ を PlayStore で 公開 し たい'},
#  {'id': '213',
#   'text': '「 この 不明 な 発行元 から の アプリ が PC に 変更 を 加える こと を 許可 し ます か ？ 」 が 表示 さ れ て 、 設定 が 変更 でき ない'},
#  {'id': '214',
#   'text': '「 この 不明 な 発行元 から の アプリ が PC に 変更 を 加える こと を 許可 し ます か ？ 」 が 表示 さ れ 、 アプリ が インストール でき ない'},
#  {'id': '215',
#   'text': 'アプリ インストール 時 、 「 この 不明 な 発行元 から の アプリ が PC に 変更 を 加える こと を 許可 し ます か ？ 」 の メッセージ が 表示 さ れる'},
#  {'id': '216',
#   'text': '「 この 不明 な 発行元 から の アプリ が PC に 変更 を 加える こと を 許可 し ます か ？ 」 の エラー が 出 て 、 ソフト が インストール でき ない'},
#  {'id': '217', 'text': '業 端 A から 社内 無線 LAN （ yellow ） に 接続 が 出来 ない'},
#  {'id': '218', 'text': '業 端 が yellow に 繋がら ない'},
#  {'id': '219',
#   'text': 'iPhone の 設定 で MDM を インストール し まし た が 、 社内 WiFi に まだ 繋がり ませ ん 。'},
#  {'id': '220', 'text': '業務用 端末 A （ iPad ） で yellow に 接続 でき ない'},
#  {'id': '221', 'text': '業 端 A が 社内 WiFi に 繋がら ない'},
#  {'id': '222',
#   'text': '故障 交換 で 業 端 A の iPad を 交換 し セットアップ し て いる の です が 、 WiFi の yellow が つかめ ませ ん 。 yellow の プロファイル は 入っ て いる こと は 確認 済み です 。'},
#  {'id': '223', 'text': '業務 端末 A で Yellow に 繋がら ない'},
#  {'id': '224', 'text': '業務 端末 が yellow に 繋がら ない'},
#  {'id': '225', 'text': '業務 端末 A で Yellow 接続 でき ない'},
#  {'id': '226',
#   'text': '業 端 A で yellow の 接続 しよう と する と パスワード を 要求 さ れ て しまい 接続 でき ない 。'},
#  {'id': '227', 'text': 'AcrobatReaderDC の インストール が でき ない'},
#  {'id': '228', 'text': 'AdobeReader の インストール 方法 に つい て 教え て ほしい'},
#  {'id': '229', 'text': 'Adobe   Reader を インストール する 方法 が 知り たい'},
#  {'id': '230', 'text': 'AcrobatReader の インストール 方法 を 教え て ください'},
#  {'id': '231', 'text': 'PDF を 開く ため に AdobeReader を インストール し たい 。'},
#  {'id': '232', 'text': 'PDF を Adobe   Reader で 開き たい'},
#  {'id': '233', 'text': 'PDF を Adobe   Reader で 見れる よう に し たい'},
#  {'id': '234', 'text': 'Adobe   Reader の インストール 方法 が わから ない'},
#  {'id': '235',
#   'text': 'PDF を 閲覧 し たい ため 、 AdobeReader を インストール し たい 。 手順 を 教え て ほしい 。'},
#  {'id': '236', 'text': 'AdobeReader の 最新 版 を インストール し たい'},
#  {'id': '237', 'text': '付属品 の VGA 変換 アダプタ を 紛失 し て しまっ た'},
#  {'id': '238', 'text': 'VGA 変換 アダプター を 紛失 し て しまっ た 場合 は どう し たら いい です か ？'},
#  {'id': '239', 'text': 'VGA 変換 アダプタ を なくし て しまっ た'},
#  {'id': '240', 'text': 'VGA 変換 ケーブル を 無くし た 場合 どう すれ ば いい ？'},
#  {'id': '241', 'text': 'VGA 変換 アダプタ を 紛失 し た'},
#  {'id': '242',
#   'text': 'OAPC 付属 の   VGA   変換 アダプター を 紛失 し て しまっ た の で 新しい もの が 欲しい です 。'},
#  {'id': '243', 'text': 'VGA 変換 アダプタ を なくし た'},
#  {'id': '244', 'text': 'VGA 変換 アダプタ を 落とし た'},
#  {'id': '245', 'text': 'PC の VGA 変換 アダプタ を 紛失 し て しまい まし た'},
#  {'id': '246', 'text': 'VGA 変換 アダプタ を 紛失 さ れ た'},
#  {'id': '247', 'text': 'OAPC の 利用者 を 変更 し たい'},
#  {'id': '248', 'text': '退職者 の OAPC を 新規 入場者 に 引き継ぎ たい'},
#  {'id': '249', 'text': 'L 3 Dev の PC の 所有者 を 変更 し たい'},
#  {'id': '250', 'text': '複数 名分 の OAPC の 利用者 変更 申請 を 一括 で 実施 し たい'},
#  {'id': '251',
#   'text': 'OAPC の 利用者 変更 申請 承認 後 、 いつ から 社内 ネットワーク に 接続 できる よう に なり ます か'},
#  {'id': '252', 'text': 'OAPC の 利用者 変更 申請 の 申請 方法 を 教え て ほしい'},
#  {'id': '253', 'text': '退場者 の OAPC の 利用者 変更 を し たい'},
#  {'id': '254', 'text': 'OAMac の 利用者 変更 を し たい'},
#  {'id': '255',
#   'text': '部門 管理 PC で 外部 記録 媒体 を 使用 し たい の です が 申請 は 必要 に なり ます か 。'},
#  {'id': '256',
#   'text': 'OA 化 し て い ない 部門 PC で USB メモリ を 利用 する 場合 、 USB 権限 申請 は 必要 です か ？'},
#  {'id': '257', 'text': '部門 で スタンドアローン で 使っ て いる 端末 で USB を 使い たい'},
#  {'id': '258', 'text': '部門 で 管理 し て いる 端末 で 外部 記録 媒体 を 使用 し たい'},
#  {'id': '259',
#   'text': '部門 PC で ネットワーク が Yellow の PC に 対し て 外付け の DVD デッキ を 接続 し たい 。 PureTerminal から の 申請 は 必要 でしょう か'},
#  {'id': '260',
#   'text': 'L 3 DaaS 環境 から L 2 RDS 環境 に ログイン し た 際 、 アプリ が 表示 さ れ ない 。'},
#  {'id': '261', 'text': 'RDS に ログイン し た が 、 アイコン が 何 も ない'},
#  {'id': '262', 'text': 'RDS に ログイン は できる が 、 アイコン 自体 が 表示 さ れ て い ない'},
#  {'id': '263', 'text': 'RDS に は ログイン できる が アイコン が 存在 し ない'},
#  {'id': '264', 'text': 'RDS ログイン 後 、 アイコン が 何 も 表示 さ れ ない'},
#  {'id': '265', 'text': 'RDS ログイン 後 、 アイコン が 表示 さ れ ない 場合 の 対処 方法'},
#  {'id': '266',
#   'text': 'L 3 環境 で 先週 配信 さ れ た 新 RDS アイコン から ログイン する と remoteApp 以下 に 何 も アイコン が 表示 さ れ て い ない'},
#  {'id': '267', 'text': 'RDS で アイコン が 出 て 来 ない'},
#  {'id': '268', 'text': 'RDS の アイコン が 出 ない'},
#  {'id': '269',
#   'text': 'Excel を 起動 する と 「 サブスクリプション の 有効 期限 が 切れ て い ます 。 」 と 表示 さ れる'},
#  {'id': '270',
#   'text': 'パワーポイント ファイル を 開い た とき に 「 サブスクリプション の 有効 期限 が 切れ て いる と エラー に なる'},
#  {'id': '271',
#   'text': 'Office を 立ち上げる と サブスクリプション の 有効 期限 が 切れ て い ます と 表示 さ れる'},
#  {'id': '272', 'text': 'サブスクリプション の エラー が 出 て Office が 使え ない'},
#  {'id': '273', 'text': 'Office 365 サブスクリプション は 有効 期限 が 切れ て い ます'},
#  {'id': '274', 'text': 'エクセル を 開く と サブスクリプション の 有効 期限 が 切れ て い ます と 出 ます 。'},
#  {'id': '275',
#   'text': 'Office 起動 時 に サブスクリプション の 有効 期限 が 切れ て い ます と いう メッセージ が 出 て しまう'},
#  {'id': '276',
#   'text': 'Office ファイル を 起動 する と 「 サブスクリプション の 有効 切れ 」 と 表示 さ れる 。'},
#  {'id': '277', 'text': 'Office で サブスクリプション の 有効 期限 が 切れ て い ます が 表示 さ れる'},
#  {'id': '278', 'text': 'Office の サブスクリプション の 有効 期限 が 切れ て い ます'},
#  {'id': '279',
#   'text': '業務 端末 B で 設定 し た MySoftBank の 暗証 番号 の 問い合わせ先 を 教え て 欲しい 。'},
#  {'id': '280', 'text': '業務 端末 B で 設定 し た MySoftBank の 暗証 番号 を 忘れ て しまっ た 。'},
#  {'id': '281', 'text': '業務 端末 B の MySoftBank の 暗証 番号 を 確認 し たい 。'},
#  {'id': '282', 'text': '業務 端末 B の MySoftbank へ の ログイン 方法 を 教え て ください 。'},
#  {'id': '283', 'text': '業 端 B の MySoftBank の 暗証 番号 を 確認 し たい 。'},
#  {'id': '284', 'text': '業 端 B の MySoftbank の パスワード を 教え て ください 。'},
#  {'id': '285', 'text': '準 OAPC を 借り たい'},
#  {'id': '286', 'text': '準 OAPC の 貸出 申請 に つい て'},
#  {'id': '287', 'text': '準 OAPC は どこ で 借りる こと が でき ます か ？'},
#  {'id': '288', 'text': '準 OA 端末 が 欲しい'},
#  {'id': '289', 'text': '準 OAPC を 貸し出し て ほしい'},
#  {'id': '290',
#   'text': 'PC を 交換 し た が ログイン でき ない 。 現在 ログオン 要求 を 処理 できる ログオン サーバー は あり ませ ん と 表示 さ れる'},
#  {'id': '291',
#   'text': 'OAPC に ログイン でき ない 。 「 ログイン 要求 を 処理 できる ログオン サーバー は あり ませ ん 。 」'},
#  {'id': '292',
#   'text': 'OAPC に ログイン でき ませ ん 。 現在 ログオン 要求 を 処理 できる ログオン サーバー は あり ませ ん と 表示 さ れ ます'},
#  {'id': '293',
#   'text': 'OAPC に ログイン でき ませ ん 。 「 現在 ログオン 要求 を 処理 できる ログオン サーバー が あり ませ ん 」 と 表示 さ れ ます'},
#  {'id': '294',
#   'text': 'PC を 起動 し て ログオン しよう と し て い ます が \n 「 現在 ログオン 要求 を 処理 できる ログオン サーバー が あり ませ ん 」 \n と エラー に なり ます'},
#  {'id': '295',
#   'text': '現在 ログオン 要求 を 処理 できる ログオン サーバー は あり ませ ん と いう エラー が で て OAPC に ログイン でき なく なっ た 。 解消 方法 を 教え て ほしい 。'},
#  {'id': '296',
#   'text': 'OAPC に ログイン でき ませ ん 。 エラー ： 現在 ログオン 要求 を 処理 できる ログオン サーバー は あり ませ ん 。'},
#  {'id': '297',
#   'text': 'OAPC に ログイン でき ませ ん 。 現在 ログオン 要求 を 処理 できる ログオン サーバー が あり ませ ん と 表示 さ れ ます'},
#  {'id': '298',
#   'text': '現在 、 ログオン 要求 を 処理 できる サーバー は あり ませ ん 。 と いう エラー の 対処 方法 を 教え て'},
#  {'id': '299', 'text': '「 ログオン 要求 を 処理 できる ログオン サーバー は あり ませ ん 」 と 表示 さ れ ます'},
#  {'id': '300',
#   'text': '複数社 で 利用 し て いる Slack コネクト の チャンネル から 特定 の 会社 のみ 切り離し たい'},
#  {'id': '301',
#   'text': '複数社 間 で やり取り し て いる 共有 チャンネル から 特定 の 会社 のみ 切り離す こと は 出来 ます か ？'},
#  {'id': '302',
#   'text': '3 社 で 利用 し て いる 共有 チャンネル から 1 社 のみ コネクト を 切り離し たい 場合 は どう し たら 良い です か ？'},
#  {'id': '303',
#   'text': '3 社 で Slack コネクト し て いる 場合 、 特定 の 1 社 のみ コネクト 停止 する こと は 出来 ます か ？'},
#  {'id': '304', 'text': 'Excel は 動作 を 停止 し まし た と 出る'},
#  {'id': '305', 'text': 'Office の 修復 方法 に つい て 手順 を 教え て ほしい'},
#  {'id': '306', 'text': 'Excel の アプリ のみ 起動 し ない'},
#  {'id': '307',
#   'text': '問題 が 発生 し 、 PowerPoint の 動作 が 不安定 に なっ て い ます 。 と 表示 さ れ て PowerPoint ファイル が 開き ませ ん 。'},
#  {'id': '308', 'text': 'PowerPoint の アプリ のみ 起動 し ない'},
#  {'id': '309', 'text': 'Excel を 開く と フリーズ する'},
#  {'id': '310',
#   'text': 'PowerPoint を 開く と 、 以下 の ポップ アップ が 表示 さ れ 続け ます 。 「 申し訳 ござい ませ ん 。 問題 が 発生 し 、 PowerPoint の 動作 が 不安定 に なっ て い ます 。 PowerPoint を 再起動 し て ください 」 再起動 し て も なおり ませ ん 。'},
#  {'id': '311', 'text': 'Office を アップデート 後 に ファイル が 開か なく なっ た'},
#  {'id': '312', 'text': 'Word の アプリ のみ 起動 し ない'},
#  {'id': '313',
#   'text': 'PowerPoint ファイル のみ 正常 動作 し ませ ん 。 申し訳 ござい ませ ん 。 問題 が 発生 し 、 PowerPoint の 動作 が 不安定 に なっ て い ます 。 と 表示 さ れ て 編集 でき ませ ん 。'},
#  {'id': '314', 'text': '正社員 以外 の Windows で の Office 利用 方法 を 教え て ほしい'},
#  {'id': '315', 'text': '業務 委託 社員 の Office 利用 に つい て'},
#  {'id': '316', 'text': '業務 委託 社員 で Office を 使用 し たい'},
#  {'id': '317', 'text': 'Office 365 の 利用 は 正社員 以外 で も 可能 です か ？'},
#  {'id': '318', 'text': '派遣 社員 が Office を 使用 する 場合 は どう し たら いい か'},
#  {'id': '319', 'text': 'Office に 利用 ルール は あり ます か ？'},
#  {'id': '320', 'text': '業務 委託 社員 に Office 365 を 利用 さ せ たい'},
#  {'id': '321', 'text': '正社員 以外 の 人 が Office を 利用 する 方法 を 教え て ほしい'},
#  {'id': '322', 'text': '派遣 社員 の Office 365 の 利用 マニュアル を 教え て ください'},
#  {'id': '323', 'text': '正社員 以外 の 社員 に Office 365 を 利用 さ せ たい'},
#  {'id': '324', 'text': '退職 し た 人 が 共有 ドライブ に 保存 し て い た データ は どう なり ます か ？'},
#  {'id': '325',
#   'text': '辞め た 人 が 共有 ドライブ 内 に データ を 保存 し て い た 場合 の 扱い は どう なり ます か ？'},
#  {'id': '326', 'text': '退職 さ れ た 際 共有 ドライブ 内 の ファイル は どう なり ます か'},
#  {'id': '327',
#   'text': '共有 ドライブ 内 に 辞め た 人 の 作成 し た データ が ある 場合 、 消え て しまい ます か ？'},
#  {'id': '328', 'text': '退職時 、 共有 ドライブ 内 の ファイル は どう なり ます か ？'},
#  {'id': '329', 'text': 'FALCON で 共有 フォルダ の 利用率 を 確認 する こと は 可能 です か ？'},
#  {'id': '330', 'text': '共有 フォルダ の 利用率 を 確認 し たい'},
#  {'id': '331', 'text': 'プロジェクト フォルダ の 利用率 を 確認 し たい'},
#  {'id': '332', 'text': '共有 フォルダ の 利用率 を 確認 する 方法 は あり ます か ？'},
#  {'id': '333', 'text': '業 端 A から シングル サイン オン （ SSO ） でき ない'},
#  {'id': '334', 'text': 'OAMac から SSO 認証 が でき ない'},
#  {'id': '335', 'text': 'Android から SSO 認証 が 通ら ない'},
#  {'id': '336', 'text': 'iPhone から SSO 認証 でき ない'},
#  {'id': '337', 'text': 'iPhone で SSO 認証 が でき ない'},
#  {'id': '338', 'text': 'OAMac で 社内 NW に 接続 し て いる が SSO 認証 でき ない'},
#  {'id': '339', 'text': '開発 DaaS を 複数 の モニター に 表示 でき ます か ？'},
#  {'id': '340', 'text': '開発 DaaS の 画面 を ２ つ の ディスプレイ に 表示 し たい'},
#  {'id': '341', 'text': '開発 DaaS の 画面 を ２ つ の モニター に 表示 し たい'},
#  {'id': '342', 'text': '開発 DaaS 利用 時 の マルチ ディスプレイ 表示 方法 を 教え て 欲しい'},
#  {'id': '343', 'text': '受入 出向 社員 も Zoom アカウント が 発行 さ れ ます か ？'},
#  {'id': '344', 'text': 'Zoom アカウント 自動 払出 対象者 を 教え て'},
#  {'id': '345', 'text': 'SBKK 兼務 の 場合 、 Zoom アカウント は 発行 さ れ ます か ？'},
#  {'id': '346', 'text': 'Zoom の アカウント は 誰 に 発行 さ れ ます か ？'},
#  {'id': '347', 'text': 'OA 化 可能 な Mac   OS の バージョン を 教え て 欲しい'},
#  {'id': '348', 'text': '部門 購入 し た Mac を OA 化 し たい が OS が 対象外 と 表示 さ れ た 。'},
#  {'id': '349', 'text': '最新 OS の Mac は いつ から OA 化 でき ます か ？'},
#  {'id': '350', 'text': '最新 の Mac   OS の OA 化 は いつ に なり そう でしょう か ？'},
#  {'id': '351', 'text': '最新 の Mac   OS は いつ 準 OA 化 対応 さ れ ます か'},
#  {'id': '352', 'text': '最新 OS の Mac を OA 化 し たい'},
#  {'id': '353', 'text': 'MacOS を アップグレード し て も OA 化 可能 です か'},
#  {'id': '354', 'text': 'MacOS が 新し すぎ て OA 化 でき ない'},
#  {'id': '355', 'text': '購入 し た Mac の 最新 OS は いつ OA 化 でき ます か ？'},
#  {'id': '356', 'text': '新 バージョン の Mac   OS は OA 化 可能 です か'},
#  {'id': '357',
#   'text': 'PowerPoint ファイル を Gmail に 添付 し て 送信 する と ウィルス に 感染 し まし た と メッセージ が 出る'},
#  {'id': '358',
#   'text': 'この メール に は ご 注意 ください 。 ウィルス や 悪質 な リンク が 含ま れ て いる 可能性 が あり ます 。'},
#  {'id': '359',
#   'text': 'Gmail 上 で 「 ウィルス の 警告   –   XX 個 の 添付 ファイル に ウィルス また は ブロック さ れ た ファイル が 含ま れ て い ます 」 の メッセージ が 出る'},
#  {'id': '360', 'text': 'Gmail 上 で の ウィルス 対応 方法 に つい て'},
#  {'id': '361',
#   'text': 'Gmail 上 で 「 この メール に は ご 注意 ください \u3000 ウィルス や 悪質 な リンク が 含ま れ て いる 可能性 が あり ます 」 の メッセージ が 出る'},
#  {'id': '362', 'text': 'Admin 権限 が 非 承認 に なっ た 理由 を 教え て 欲しい'},
#  {'id': '363', 'text': 'Admin 権限 が 非 承認 に なっ た の で 、 理由 を 知り たい'},
#  {'id': '364', 'text': 'Admin 権限 が 否認 さ れ た'},
#  {'id': '365',
#   'text': 'AdobeAcrobat の インストール 申請 を 出し た ところ View 環境 の 為 承認 さ れ ませ ん でし た 。'},
#  {'id': '366', 'text': 'ライセンス 管理 システム で Admin 権限 申請 を 行っ た が 否認 さ れ た'},
#  {'id': '367', 'text': 'OAPC の マイク が 使え ない'},
#  {'id': '368', 'text': 'OAPC で マイク 付き イヤホン が 使え ない'},
#  {'id': '369', 'text': 'OAPC の スピーカー が 使用 でき ない'},
#  {'id': '370',
#   'text': 'OAPC の 音量 を 上げ て も スピーカー で 音声 が 聞こえ ませ ん 。 どこ で 設定 すれ ば いい でしょう か 。'},
#  {'id': '371', 'text': 'OAPC の 音声 が 出 ませ ん'},
#  {'id': '372', 'text': 'OAPC で 音 が 再生 さ れ ない'},
#  {'id': '373', 'text': 'OAPC から 音 が 出 なく なり まし た 。'},
#  {'id': '374', 'text': 'OAPC で マイク が 使え ない'},
#  {'id': '375',
#   'text': 'L 2 使用 の PC で e-learning を 受講 しよう と し たら 、 PC から 音 が 出 て こ ない 。'},
#  {'id': '376', 'text': 'RDS の 利用 申請 を 一括 登録 できる か'},
#  {'id': '377', 'text': 'RDS の 新規 利用 方法 を 確認 し たい'},
#  {'id': '378', 'text': 'RDS 環境 の 利用 申請 を し たい'},
#  {'id': '379', 'text': 'RDS の 申請 方法 を 教え て 欲しい'},
#  {'id': '380', 'text': 'RDS の 利用 申請 認証 さ れる まで どれ くらい かかる か'},
#  {'id': '381', 'text': 'RDS の 一括 申請 方法 を 教え て 下さい 。'},
#  {'id': '382', 'text': 'RDS の 申請 に つい て 教え て'},
#  {'id': '383', 'text': 'RDS を 申請 から 利用 開始 まで どの くらい かかる か'},
#  {'id': '384', 'text': 'RDS を 申請後 使える の は いつ か ？'},
#  {'id': '385', 'text': 'RDS の 申請 方法 を 教え て'},
#  {'id': '386', 'text': 'Mac から の View 接続 する 方法 を 教え て ください'},
#  {'id': '387', 'text': '自宅 から View （ 仮想 ） 環境 へ の 接続 方法 を 教え て ください'},
#  {'id': '388', 'text': '自宅 から View に 入る 手順 を 教え て ください 。 申請 は いる の でしょう か'},
#  {'id': '389', 'text': 'OAPC を 社外 に 持ち出し て View 接続 する 方法 を 教え て ください'},
#  {'id': '390',
#   'text': '自宅 で PC を 利用 し て い ます 。 \n テザリング 接続 し て View に 入り たい が うまく 入れ ない 。'},
#  {'id': '391', 'text': '個人 使用 の PC で View に 接続 し たい'},
#  {'id': '392', 'text': '社外 で View 環境 に 入る に は どう すれ ば いい の か'},
#  {'id': '393', 'text': '社外 から Veiw 接続 を 使用 する に は どう すれ ば よい でしょう か'},
#  {'id': '394', 'text': '自宅 から View 接続 する 方法 を 教え て ほしい'},
#  {'id': '395',
#   'text': 'AzureRMS の アップグレード 作業 を し たい が 支援 ツール 格納先 の フォルダ に 入れ ない 。'},
#  {'id': '396',
#   'text': 'AzureRMS の アップグレード 作業 が 出来 ない 。 \n 作業 支援 チェック ツール の 入っ て いる フォルダ が 開け ない 。'},
#  {'id': '397', 'text': 'AzureRMSCheck . vbs が ある 場所 を 教え て 欲しい'},
#  {'id': '398', 'text': 'AzureRMS の チェック ツール は どこ に あり ます か ？'},
#  {'id': '399', 'text': 'AzureRMS の チェック ツール が ある 場所 を 教え て 欲しい'},
#  {'id': '400', 'text': 'RMS の バージョン アップ の 方法 を 教え て ください 。'},
#  {'id': '401', 'text': '採用 ドクター に つい て 確認 し たい'},
#  {'id': '402', 'text': '採用 Dr の 問合せ先 は どこ です か ？'},
#  {'id': '403', 'text': '採用 Dr の 管理 部署 を 教え て 欲しい'},
#  {'id': '404', 'text': '採用 ドクター に つい て 問合せ たい'},
#  {'id': '405', 'text': '採用 ドクター の 管理 部署 を 教え て 欲しい'},
#  {'id': '406', 'text': '採用 Dr に つい て 問合せ たい'},
#  {'id': '407', 'text': '採用 ドクター の 問合せ先 は どこ です か ？'},
#  {'id': '408', 'text': 'OAPC 利用 中 に 「 メモリ エラー 」 が 表示 さ れる の を 解消 し たい'},
#  {'id': '409',
#   'text': 'OAPC 利用 中 、 GoogleChrome に 「 メモリ エラー 」 が 表示 さ れ た 場合 の 対処 方法 を 教え て 欲しい'},
#  {'id': '410',
#   'text': 'OAPC 利用 中 に 「 メモリ エラー 」 が 表示 さ れ た 場合 の 対処 方法 を 教え て 欲しい'},
#  {'id': '411', 'text': 'View 利用 中 に 「 メモリ エラー 」 が 表示 さ れる'},
#  {'id': '412', 'text': 'View 利用 中 に 「 メモリ エラー 」 が 表示 さ れる の を 解決 し たい'},
#  {'id': '413', 'text': 'OAPC の 電源 が 勝手に 落ちる 事象 が 繰り返し 発生 する'},
#  {'id': '414',
#   'text': 'OAPC で 頻繁 に ブルー スクリーン 画面 が 発生 し て おり 、 バッテリー も 持た なく なっ て いる ため 交換 を 希望 し て い ます'},
#  {'id': '415', 'text': 'OAPC が 使用 中 に ブルー スクリーン に なる 。'},
#  {'id': '416', 'text': 'OAPC で 動作 不良 （ ブルー スクリーン ） が 多発 し て いる 。'},
#  {'id': '417', 'text': 'OAPC が ブルー スクリーン を 多発 する'},
#  {'id': '418',
#   'text': 'OAPC を 少し 移動 する と フリーズ する 事象 や ブルー スクリーン が 頻発 する 状態 です 。'},
#  {'id': '419', 'text': 'PC の フリーズ が 頻発 する の です が 、 どう し たら よい です か ？'},
#  {'id': '420', 'text': 'ブルー スクリーン が 出現 し QR コード が 画面 に 出る'},
#  {'id': '421',
#   'text': 'PC の 電源 が 突然 落ちる こと が 増え て き て おり 、 業務 の 支障 が 出 て い ます 。 対応策 を 相談 し たい 。'},
#  {'id': '422', 'text': 'PC が ブラック アウト し ます'},
#  {'id': '423', 'text': 'ネットワーク 管理 GIS に ログイン でき ない 状態 です 。 確認 を お 願い し ます 。'},
#  {'id': '424', 'text': 'PFOS - GIS を 使い たい'},
#  {'id': '425', 'text': 'ネットワーク 管理 GIS の 問合せ先 は どこ です か ？'},
#  {'id': '426', 'text': 'ネットワーク 管理 GIS に つい て 問合せ し たい'},
#  {'id': '427', 'text': 'ネットワーク 管理 GIS の 問合せ先 を 教え て 欲しい'},
#  {'id': '428', 'text': '業務 端末 の 回線 速度 が 遅い 。'},
#  {'id': '429',
#   'text': '業務 端末 A で データ 通信 の 速度 が 低下 し まし た 。 容量 は 追加 購入 でき ます か 。'},
#  {'id': '430', 'text': '業務 端末 A の 使用 可能 通信 量 確認 方法 を 知り たい 。'},
#  {'id': '431',
#   'text': '業務 端末 B で 通信 が 遅く なり まし た 。 元 の 速度 に する に は どう すれ ば いい でしょう か 。'},
#  {'id': '432', 'text': '業務用 端末 の データ 制限 に つい て 知り たい'},
#  {'id': '433', 'text': '業務 端末 B で 速度 制限 が かかっ た 時 の 対処 方法 を 教え て ください 。'},
#  {'id': '434', 'text': 'データ 通信 の 速度 で 速度 が 低下 し まし た 。 容量 の 追加 は でき ます か 。'},
#  {'id': '435',
#   'text': '業務 端末 B の データ 通信 で 速度 制限 が かかっ た 。 どこ に 問い合わせれ ば いい でしょう か 。'},
#  {'id': '436',
#   'text': 'データ 通信 の 速度 が 低下 し まし た 。 業務 端末 A で 容量 は 追加 購入 でき ます か 。'},
#  {'id': '437', 'text': '業務 端末 の 回線 速度 が 遅い です 。'},
#  {'id': '438', 'text': 'プロジェクト フォルダ 管理者 を 追加 時 、 管理者 追加 ボタン が 表示 さ れ ない'},
#  {'id': '439', 'text': 'プロジェクト フォルダ 管理者 を 追加 し たい が 、 管理者 追加 ボタン が 表示 さ れ ない'},
#  {'id': '440',
#   'text': 'FALCON で PJ フォルダ の 管理者 を 追加 し たい が 、 追加 ボタン が 表示 さ れ ない'},
#  {'id': '441', 'text': 'ファルコン で 管理者 の 追加 が でき ない'},
#  {'id': '442',
#   'text': 'プロジェクト フォルダ 管理者 を 3 名 以上 追加 し たい が 、 管理者 追加 ボタン が 表示 さ れ ない'},
#  {'id': '443', 'text': '共有 フォルダ 内 の Office ファイル が 読み取り 専用 に なっ て いる'},
#  {'id': '444', 'text': '共有 フォルダ 上 の ファイル が 読み取り 専用 に なる'},
#  {'id': '445', 'text': 'フォルダ の 読み取り 専用 が 解除 でき ない'},
#  {'id': '446', 'text': '共有 フォルダ 内 の PowerPoint の ファイル が 読み取り 専用 に なっ て いる'},
#  {'id': '447', 'text': '共有 フォルダ 上 の ファイル が 読み取り 専用 に なっ て しまい 、 編集 でき ない'},
#  {'id': '448', 'text': '共有 フォルダ 内 の Excel ファイル が 読み取り 専用 に なっ て いる'},
#  {'id': '449',
#   'text': '販売職 用 の OAPC の 起動 パスワード 変更 後 パスワード が 不明 に なり OAPC が 起動 でき なく なり まし た 。'},
#  {'id': '450', 'text': 'SP の PC を 新規 で 貸し出し て 欲しい'},
#  {'id': '451',
#   'text': 'SV 代行 に なっ た の です が パソコン を 貸与 さ れ て い ない 。 \n パソコン の 貸与 は 自分 で 申し込み を する の でしょう か 。'},
#  {'id': '452', 'text': '販売職 社員 の PC を 新規 で 貸し出し て 欲しい'},
#  {'id': '453', 'text': 'SV に なり PC 変更 に なっ た の です が 、 起動 に 5 分 程度 かかり ます 。'},
#  {'id': '454',
#   'text': '以前 パソコン の 不調 に つい て 、 クルー 相談 窓口 専用 フォーム から 問い合わせ を 投げ た ところ こちら の 窓口 に 問合せ する よう に 言わ れ まし た 。'},
#  {'id': '455', 'text': '販売職 用 の OAPC が 立ち上がら なく なっ た'},
#  {'id': '456', 'text': '販売職 用 の OAPC が 正常 起動 し ない'},
#  {'id': '457', 'text': 'SV の PC を 新規 で 貸し出し て 欲しい'},
#  {'id': '458',
#   'text': 'iPad の 業務用 端末 を 使っ て Gmail を 使っ て い ます が \n iPad に 最初 から 入っ て いる メール アプリ で 先週 日曜 以降 新しい メール が 受信 でき ない \n 「 受信 に 失敗 し まし た 。 」'},
#  {'id': '459', 'text': 'インストール 申請 を し た が 、 インストーラ の パス が わから ない'},
#  {'id': '460', 'text': 'インストール 申請 を し た が 、 インストーラ を 所持 し て い ない'},
#  {'id': '461',
#   'text': '部門 PC の インストール 申請 を 行い たい が 、 検索 し た PC 名 が 表示 さ れ ませ ん'},
#  {'id': '462', 'text': 'インストール 申請 を し た が 、 インストーラ が どこ に ある か わから ない'},
#  {'id': '463',
#   'text': 'インストール の 申請 が 承認 さ れ た が 、   インストーラ の 入手先 が 不明 な の で 教え て ほしい'},
#  {'id': '464',
#   'text': 'インストール の 申請 が 承認 さ れ た が 、   インストーラ は どこ から 入手 でき ます か'},
#  {'id': '465', 'text': 'インストール 申請 を 行っ た が 、 インストーラパス が 分かり ませ ん 。'},
#  {'id': '466',
#   'text': 'インストール 申請 を 行い Admin 権限 が 付与 さ れ まし た が \n 実際 の アプリ の インストーラー は どこ に ある の でしょう か'},
#  {'id': '467', 'text': 'インストール の 申請 が 承認 さ れ た が 、   その 先 の 手順 を 教え て ほしい 。'},
#  {'id': '468',
#   'text': 'Excel ファイル が 開か ない 。 エラー   「 Microsoft   Online   Services   サイン イン   アシスタント は この \n コンピュータ に インストール さ れ て い ませ ん 。 インスール し て から ～ 。 」'},
#  {'id': '469',
#   'text': 'AzureRMS アップグレード 後 ファイル を ひらこう と する と エラー が 出 て 、 マイクロソフトサインインアシスタント は インストール さ れ て い ませ ん 。'},
#  {'id': '470',
#   'text': 'エラー が 出 て Excel が 開け ませ ん 。 「 サイン イン   アシスタント は この コンピュータ に インストール さ れ て い ませ ん 」'},
#  {'id': '471',
#   'text': '「 Microsoft   Online   Services   サイン イン   アシスタント は この コンピュータ に インストール さ れ て い ませ ん 。 管理者 に 問い合わせ て ください 。 」 の ポップ アップ が 表示 さ れ て 、 Office ファイル が 開か ない'},
#  {'id': '472',
#   'text': '「 Microsoft   Online   Services   サイン イン   アシスタント は この \n コンピュータ に インストール さ れ て い ませ ん 。 管理者 に 問い合わせ て ください 。 」 \n の ポップ アップ が 表示 さ れ て 、 Office ファイル が 開か ない'},
#  {'id': '473',
#   'text': 'Excel ファイル を 開く と 、 \n 「 Microsoft   Online   Services   サイン イン   アシスタント は この \n コンピュータ に インストール さ れ て い ませ ん 。 管理者 に 問い合わせ て ください 。 」 \n の ポップ アップ が 表示 さ れ て 、 Office ファイル が 開か ない'},
#  {'id': '474',
#   'text': '準 OAPC にて Office ソフト を 開く 際 に 「 Microsoft   Online   Services サイン イン アシスタント は この コンピュータ に インストール さ れ て い ませ ん 。 」 と 出 て 開け ませ ん 。'},
#  {'id': '475',
#   'text': 'パワー ポイント を 開こう と し たら エラー に なる 。 「 サイン イン アシスタント は この コンピュータ に インストール さ れ て い ませ ん 」'},
#  {'id': '476',
#   'text': 'サイン イン   アシスタント は この コンピュータ に インストール さ れ て い ませ ん の メッセージ で Office ファイル が 開か ない'},
#  {'id': '477',
#   'text': 'Office ファイル を 開け ませ ん 。 \n エラー メッセージ : サイン イン アシスタント は この コンピュータ に インストール さ れ て い ませ ん'},
#  {'id': '478', 'text': '準 OAPC で Blue 接続 中 な の です が インターネット に つながり ませ ん 。'},
#  {'id': '479', 'text': 'OAPC で blue 接続 でき て いる が メール や 社内 システム が 使用 でき ない'},
#  {'id': '480', 'text': 'OAPC が インターネット に 繋がら ない'},
#  {'id': '481', 'text': 'OAPC で OASYS 接続 中 だ が インターネット に アクセス でき ない'},
#  {'id': '482', 'text': 'OAPC が インターネット に つながら ない'},
#  {'id': '483', 'text': 'OAPC で 社内 LAN 接続 し て も インターネット が 利用 でき ませ ん でし た 。'},
#  {'id': '484', 'text': 'OAPC が blue に は 接続 できる が 、 インターネット が でき ない'},
#  {'id': '485', 'text': 'OAPC が インターネット に 接続 でき ませ ん 。'},
#  {'id': '486', 'text': 'OAPC で blue 接続 でき て いる が インターネット に 接続 でき ない'},
#  {'id': '487', 'text': '社内 システム に つながる が 、 インターネット に つながら ない'},
#  {'id': '488', 'text': 'OASYS 接続 中 な の です が Gmail に 接続 でき ませ ん 。'},
#  {'id': '489', 'text': 'OAPC が 外部 Web サイト や Gmail に 接続 でき ない'},
#  {'id': '490', 'text': 'OAPC で インターネット に 接続 さ れ て い ませ ん と 表示 さ れる'},
#  {'id': '491', 'text': 'OAPC で blue に 接続 は 出来 て いる が インターネット に つながら ない'},
#  {'id': '492', 'text': 'OAPC が インターネット に 接続 でき ない'},
#  {'id': '493',
#   'text': 'OAPC で 社外 ネットワーク 接続 し て いる の です が インターネット 接続 が でき ませ ん'},
#  {'id': '494',
#   'text': '準 OAPC で 社内 NW に 接続 し て いる の です が インターネット 接続 が でき ませ ん 。'},
#  {'id': '495', 'text': 'OAPC から インターネット が 利用 でき ない の で 対処 方法 を 教え て ほしい'},
#  {'id': '496',
#   'text': '業務 端末 B で 充電 が でき ませ ん 。 ケーブル が 原因 だ と 思う の です が 、 交換 可能 でしょう か 。'},
#  {'id': '497', 'text': '業務 端末 が 充電 でき ない 。'},
#  {'id': '498', 'text': '業務 端末 B の iPhone が 充電 でき ない'},
#  {'id': '499', 'text': '業務 端末 B が 充電 でき なく なっ た 場合 、 どこ に 確認 すれ ば 良い です か 。'},
#  {'id': '500', 'text': '業務 端末 B で 充電 が でき ませ ん 。 部門 で 交換 でき ます か 。'},
#  {'id': '501', 'text': '業務 端末 B が 充電 でき なく なり まし た 。'},
#  {'id': '502', 'text': 'BB ドメイン アカウント で Proself に ログイン でき ます か ？'},
#  {'id': '503', 'text': 'Proself を 利用 できる 対象 を 教え て 欲しい'},
#  {'id': '504', 'text': 'Proself 上 の ファイル 保存 期間 は どの くらい です か ?'},
#  {'id': '505',
#   'text': 'Proself で L 3 Dev アカウント の パスワード を 変更 する 方法 を 教え て 欲しい'},
#  {'id': '506', 'text': 'L 3 Dev の ファイル サーバー に 接続 でき ない'},
#  {'id': '507', 'text': 'L 3 Dev の チャット システム に つながら ない'},
#  {'id': '508',
#   'text': 'L 3 Dev アカウント が 発行 さ れ まし た が 、 すぐ に Proself は 利用 でき ます か ？'},
#  {'id': '509', 'text': 'Proself の アカウント 申請 方法 を 教え て 欲しい'},
#  {'id': '510', 'text': 'L 3 Dev の Proself に 接続 でき ない'},
#  {'id': '511', 'text': 'Proself で アップロード できる ファイル の 上限 は あり ます か ？'},
#  {'id': '512', 'text': 'TOMAS の 問合せ先 は どこ です か ？'},
#  {'id': '513', 'text': 'CrBS の 問合せ先 は どこ です か ？'},
#  {'id': '514', 'text': 'TAS - S   L 2 に つい て 確認 し たい'},
#  {'id': '515', 'text': 'BS - DR の 問合せ先 は どこ です か ？'},
#  {'id': '516', 'text': 'TAS - S   L 2 の 問合せ先 は どこ です か ？'},
#  {'id': '517', 'text': 'TAS - S   L 3 の 問合せ先 は どこ です か ？'},
#  {'id': '518', 'text': 'CrBS - T の 問合せ先 は どこ です か ？'},
#  {'id': '519', 'text': 'RISM - BP の 問合せ先 は どこ です か ？'},
#  {'id': '520', 'text': 'DFCA の 問合せ先 は どこ です か ？'},
#  {'id': '521', 'text': 'TASGRP の 問合せ先 は どこ です か ？'},
#  {'id': '522', 'text': 'RTDA 2 - J の 問合せ先 は どこ です か ？'},
#  {'id': '523', 'text': 'CrBS - C の 問合せ先 は どこ です か ？'},
#  {'id': '524', 'text': 'TeBiAs 社内 メンテ の 問合せ先 は どこ です か ？'},
#  {'id': '525', 'text': 'RTDAS 2 - J の 問合せ先 は どこ です か ？'},
#  {'id': '526', 'text': '業務 端末 を 紛失 し た 場合 、 弁済 金 は いくら かかり ます か 。'},
#  {'id': '527',
#   'text': '業 端 A の USIM カード 紛失 ・ ロック さ れ た 場合 の 弁済 金 は いくら かかり ます か 。'},
#  {'id': '528', 'text': '業 端 A の 弁済 金 の 設定 基準 に つい て 教え て 欲しい'},
#  {'id': '529',
#   'text': '業 端 A の 画面 破損 （ 落下 に よる ） の 弁済額 は 上限 4万 と あり ます が 、 具体的 に は いくら くらい に なり ます でしょう か ？'},
#  {'id': '530', 'text': '業務 端末 の 弁済 金 の 実績 を 教え て ください 。'},
#  {'id': '531', 'text': '業務 端末 を 水没 さ せ た 場合 、 弁済 金 は いくら かかり ます か 。'},
#  {'id': '532', 'text': '業 端 A の 不具合 に 伴い 、 弁済 金 が 発生 する か 確認 し たい 。'},
#  {'id': '533',
#   'text': '退職 済 の 派遣 社員 の 業務 端末 が 画面 割れ を 起こし て いる ため 、 弁償 金 ・ 請求先 等 は どのような 応対 に なり ます でしょう か ？'},
#  {'id': '534',
#   'text': 'GoogleEarthPro を OAPC ( FAT ) に インストール する 方法 を 教え て ください 。'},
#  {'id': '535', 'text': 'Alibaba   Cloud   を 使い たい 。'},
#  {'id': '536', 'text': 'knime を 使い たい'},
#  {'id': '537', 'text': 'サクラ エディタ の インストール は 可能 です か ？'},
#  {'id': '538', 'text': 'OA 提供 外 の ソフトウェア インストール に つい て'},
#  {'id': '539', 'text': 'Python を インストール し て も 良い です か ？'},
#  {'id': '540', 'text': 'Mac に sikuli を インストール し たい'},
#  {'id': '541', 'text': 'Sikuli を インストール し たい'},
#  {'id': '542', 'text': 'Mac に python を インストール し たい'},
#  {'id': '543', 'text': 'gizie を インストール し たい'},
#  {'id': '544', 'text': '名刺 カメラ アプリ を インストール し たい'},
#  {'id': '545', 'text': 'フリー ソフト の ダウンロード が し たい'},
#  {'id': '546',
#   'text': 'Tableau   Desktop を 社用 PC で DL し たい の です が 可能 でしょう か ？'},
#  {'id': '547', 'text': 'anaconda を インストール し たい'},
#  {'id': '548', 'text': '無償 ソフトウェア の インストール 申請 に つい て 教え て'},
#  {'id': '549', 'text': '「 + Lhaca 」 インストール し たい'},
#  {'id': '550', 'text': 'Firebase 使い たい'},
#  {'id': '551', 'text': 'WireShark を インストール し たい'},
#  {'id': '552', 'text': '7 zip を インストール し たい'},
#  {'id': '553', 'text': '有償 ソフトウェア を インストール し たい'},
#  {'id': '554', 'text': 'OAPC を 自宅 の WiFi に 接続 する'},
#  {'id': '555', 'text': 'OAPC が 自宅 の Wi-Fi 接続 が でき ない 。'},
#  {'id': '556', 'text': 'OAPC が 自宅 の 無線 LAN に 接続 でき ない'},
#  {'id': '557', 'text': 'OAPC で 自宅 の 無線 LAN に つなぎ たい'},
#  {'id': '558', 'text': 'OAPC が 社外 ネットワーク に 繋がら ない'},
#  {'id': '559', 'text': '自宅 の Wi-Fi に OAPC が 繋がら ない'},
#  {'id': '560', 'text': 'OAMac が 社外 NW に 繋がら ない'},
#  {'id': '561', 'text': 'OAPC を 自宅 の ネットワーク に 接続 する 方法 を 知り たい'},
#  {'id': '562',
#   'text': '自宅 で 支給 さ れ て いる OAPC を 使っ て い ます が 、 自宅 の Wi-Fi で 繋がら ない 。'},
#  {'id': '563', 'text': 'OAPC が 社外 ネットワーク に 接続 でき ない'},
#  {'id': '564', 'text': 'OAPC の Mac が 故障 し た 場合 、 交換 し て いただけ ます か'},
#  {'id': '565', 'text': 'Mac を 貸与 し て 欲しい 。'},
#  {'id': '566', 'text': 'OAPC を Mac に 変更 し たい'},
#  {'id': '567', 'text': 'OAPC を Mac に 変え たい'},
#  {'id': '568', 'text': 'Mac の OAPC を 貸し出し て ほしい'},
#  {'id': '569', 'text': 'Mac を OA 端末 と し て 利用 し たい'},
#  {'id': '570', 'text': 'OAPC を Mac に し たい'},
#  {'id': '571', 'text': '開発 DaaS の 接続 時間 を 短縮 し たい'},
#  {'id': '572', 'text': '開発 DaaS に アクセス する 時間 を 短く し たい'},
#  {'id': '573', 'text': '開発 DaaS に アクセス する 時間 を 短く する 方法 は あり ます か ？'},
#  {'id': '574', 'text': '開発 DaaS の 接続 時間 を 短縮 でき ます か ？'},
#  {'id': '575', 'text': 'O & M ヘルプ デスク の 問合せ 窓口 を 教え て'},
#  {'id': '576', 'text': 'O & M ヘルプ デスク の 問合せ を し たい'},
#  {'id': '577', 'text': 'O & M ヘルプ デスク に 入れ ない'},
#  {'id': '578', 'text': 'O & M ヘルプ デスク の 所属 情報 が 知り たい'},
#  {'id': '579', 'text': 'O & M ヘルプ デスク に ログイン 出来 ない'},
#  {'id': '580', 'text': 'Gmail で 全社員 に 周知 メール を 送り たい'},
#  {'id': '581', 'text': '全社員 宛 に メール を 送信 し たい'},
#  {'id': '582', 'text': 'Gmail で 全社員 に メール を 送信 し たい'},
#  {'id': '583', 'text': '全社員 向け に メール を し たい'},
#  {'id': '584', 'text': '全社員 へ メール を し たい'},
#  {'id': '585', 'text': '全社員 に メール を 送り たい'},
#  {'id': '586', 'text': '全社員 宛て に メール を 送り たい'},
#  {'id': '587', 'text': 'SB 全社員 に メール を 送り たい'},
#  {'id': '588', 'text': '全社員 の Gmail 宛 に 周知 を 送り たい'},
#  {'id': '589', 'text': '誤っ て 消し た gmail を 復活 し たい'},
#  {'id': '590', 'text': '削除 し た Gmail の 復元 方法 は あり ます か ？'},
#  {'id': '591', 'text': 'メール の 復元 に 関し て 教え て 欲しい'},
#  {'id': '592', 'text': '削除 し た メール の 復元 を し たい'},
#  {'id': '593', 'text': 'CRM に 接続 でき ない 。'},
#  {'id': '594', 'text': 'CRM に 不具合 が ある'},
#  {'id': '595', 'text': 'CRM の 問合せ先 を 教え て 欲しい'},
#  {'id': '596', 'text': 'CRM に アクセス でき なく なっ た'},
#  {'id': '597', 'text': 'OMS の 期限 延長 方法 を 教え て ください'},
#  {'id': '598', 'text': 'OMS の パスワード が 分から ない'},
#  {'id': '599', 'text': '作 スケ の パスワード が わから ない'},
#  {'id': '600', 'text': 'OMS の パスワード を リセット し たい'},
#  {'id': '601', 'text': 'OMS の パスワード 変更 方法 を 教え て 欲しい'},
#  {'id': '602', 'text': '作 スケ の パスワード 変更 方法 を 教え て ください 。'},
#  {'id': '603', 'text': 'OMS を 利用 し たい'},
#  {'id': '604', 'text': 'OMS 、 作 スケ の 初期 PW を 教え て ください'},
#  {'id': '605', 'text': 'サスケ に ログイン でき ない'},
#  {'id': '606', 'text': 'OMS の ログイン 方法 を 教え て'},
#  {'id': '607',
#   'text': 'SSO ログイン 後 、 「 Error 403 -- Forbidden 」 が 表示 さ れ て 正常 に ログイン でき ない 。'},
#  {'id': '608',
#   'text': 'SSO ログイン 後 、 「 情報 ログイン し まし た 」 が 表示 さ れ て 正常 に ログイン でき ない 。'},
#  {'id': '609', 'text': 'SSO で 認証 し て いる システム に 入り たい が 、 認証 画面 が 出 て こ ない'},
#  {'id': '610',
#   'text': 'SSO ログイン 後 、 「 不正 な ハンドラ に よる 認証 の 例外 」 が 表示 さ れ て 正常 に ログイン でき ない 。'},
#  {'id': '611',
#   'text': '今まで 社外 で PC から Gmail が 見れ て い た が 、 「 403   Forbidden 」 の エラー が 出 て 見れ ない'},
#  {'id': '612', 'text': 'SSO で ログイン 後 、 再度 、 認証 画面 に 戻っ て しまう の を 解消 し たい'},
#  {'id': '613', 'text': 'SSO ログイン 後 、 「 情報 ログイン し まし た 」 が 表示 さ れる'},
#  {'id': '614',
#   'text': '「 Error 403 -- Forbidden 」 が 表示 さ れ て Gmail に ログイン でき ない 。'},
#  {'id': '615', 'text': 'Gmail に ログイン しよう と し て いる が 、 SSO の 画面 が 出 ない'},
#  {'id': '616',
#   'text': 'エイリアス と パスワード 入力 後 、 「 Error 403 -- Forbidden 」 が 表示 さ れ て 正常 に ログイン でき ない 。'},
#  {'id': '617',
#   'text': '部署 異動 に 伴い OAPC 化 し て いる Mac を 別 の 人間 に 紐 づけ なおし たい の です が どう の う な 手続き を し たら 良い でしょう か ？'},
#  {'id': '618', 'text': '準 OAPC の 利用者 変更 を 教え て'},
#  {'id': '619', 'text': '自部門 購入 PC の 利用者 変更 を し たい'},
#  {'id': '620', 'text': '準 OAPC の 利用者 が 変わる 場合 に 必要 な 手続き を 教え て ほしい'},
#  {'id': '621', 'text': '準 OAPC の 使用者 変更 の 方法 は'},
#  {'id': '622', 'text': '部門 購入 し 、 準 OA 化 し た PC の 管理者 を 変更 し たい'},
#  {'id': '623', 'text': '準 OAPC の 利用者 変更 に つい て 知り たい'},
#  {'id': '624', 'text': '準 OAPC の 管理者 を 変え たい'},
#  {'id': '625', 'text': '準 OAPC の 管理者 を 変更 し たい'},
#  {'id': '626',
#   'text': '部署 購入 PC を OA 化 し た の です が 利用者 を 変える に は どう すれ ば いい です か'},
#  {'id': '627', 'text': 'Zoom ミーティング の 制限 時間 は あり ます か ？'},
#  {'id': '628', 'text': '無料 アカウント の 場合 、 時間 制限 は あり ます か ？'},
#  {'id': '629', 'text': 'Zoom 会議 の 利用 制限 時間 は あり ます か ？'},
#  {'id': '630', 'text': 'Zoom の 利用 制限 時間 は どの くらい です か ？'},
#  {'id': '631', 'text': 'SBTM   BSS の 問合せ先 は どこ です か ？'},
#  {'id': '632', 'text': 'SBTM   BOS の 担当者 を 教え て 欲しい'},
#  {'id': '633', 'text': 'SBTM   BOS の 問合せ先 を 教え て 欲しい'},
#  {'id': '634', 'text': 'SBTM   BSS の 問合せ先 を 教え て 欲しい'},
#  {'id': '635', 'text': 'SBTM   BSS の 担当者 を 教え て 欲しい'},
#  {'id': '636', 'text': 'SBTM   BOS の 問合せ先 は どこ です か ？'},
#  {'id': '637', 'text': '共有 フォルダ の アクセス 権限 を 付与 し たい'},
#  {'id': '638',
#   'text': '共有 ファイル サーバー へ の アクセス権 を 付与 し て ほしい の です が どこ に 問合せ を すれ ば いい です か ？'},
#  {'id': '639', 'text': '共有 フォルダ の 権限 を 設定 し たい'},
#  {'id': '640', 'text': '共有 フォルダ の アクセス 権限 付与 申請 の 仕方 を 教え て'},
#  {'id': '641', 'text': '共有 フォルダ の アクセス権 付与 の 仕方 を 教え て'},
#  {'id': '642', 'text': '共有 フォルダ の 管理者 権限 を 変更 し たい'},
#  {'id': '643', 'text': '共有 フォルダ の 権限 を 付与 し たい'},
#  {'id': '644', 'text': 'プロジェクト フォルダー に 参照 者 を 追加 し たい'},
#  {'id': '645', 'text': '共有 フォルダ へ の 権限 追加 方法 を 教え て'},
#  {'id': '646', 'text': '共有 フォルダ の アクセス 権限 を 追加 し たい'},
#  {'id': '647', 'text': '社外 に 重たい ファイル を 送り たい'},
#  {'id': '648', 'text': '社外 に 大 容量 ファイル を 送る 場合 の 方法'},
#  {'id': '649', 'text': '大 容量 の ファイル を 社外 と 共有 し たい けど どう すれ ば いい ？'},
#  {'id': '650', 'text': '社外 の 人 に 大 容量 の ファイル を 送り たい'},
#  {'id': '651', 'text': '社外 に データ を 送り たい'},
#  {'id': '652', 'text': '大 容量 ファイル を 外部 に 送り たい'},
#  {'id': '653', 'text': '社外 に 重い データ を 送付 し たい'},
#  {'id': '654', 'text': '社外 の 人 へ データ ファイル を 送信 し たい'},
#  {'id': '655', 'text': '社外 に 大きい ファイル を 送り たい'},
#  {'id': '656', 'text': 'ファイル 授受 システム を 使い たい'},
#  {'id': '657', 'text': 'エミュレータ の 問合せ先 は どこ です か ？'},
#  {'id': '658', 'text': 'AS / 400 に つい て 問合せ たい'},
#  {'id': '659', 'text': 'エミュレータ に つい て 問合せ たい'},
#  {'id': '660', 'text': 'エミュレータ の 担当 窓口 を 教え て 欲しい'},
#  {'id': '661', 'text': 'AS / 400 の 問合せ先 は どこ です か ？'},
#  {'id': '662', 'text': 'AS / 400   ( エミュレータ ) に つい て 確認 し たい'},
#  {'id': '663', 'text': 'AS / 400 の 担当 窓口 を 教え て 欲しい'},
#  {'id': '664', 'text': 'View   使用 可能 な ソフトウェア を 教え て 欲しい'},
#  {'id': '665', 'text': 'View 環境 に インストール さ れ て いる アプリケーション を 確認 し たい'},
#  {'id': '666',
#   'text': 'View 環境 下 で インストール 済み と なっ て いる アプリケーション に つい て 教え て ほしい 。'},
#  {'id': '667', 'text': 'View に インストール さ れ て いる ソフト を 教え て 欲しい'},
#  {'id': '668', 'text': 'View で 使える ソフト を 教え て 欲しい'},
#  {'id': '669', 'text': 'View で 使える アプリ を 教え て 欲しい'},
#  {'id': '670', 'text': 'HorizonView で 利用 できる アプリ を 確認 し たい'},
#  {'id': '671', 'text': 'HorizonView で 利用 可能 な アプリケーション を 確認 し たい'},
#  {'id': '672', 'text': 'View に インストール 済み の ソフトウェア を 教え て 欲しい'},
#  {'id': '673', 'text': '販売 契約 社員 の AzureRMS 申請 方法 が 知り たい'},
#  {'id': '674',
#   'text': '販売 契約 社員 が Office 265 を 利用 する 為 に AzureRMS の 申請 を し たい'},
#  {'id': '675', 'text': '販売 契約 社員 の AzureRMS 申請 は Tarte から でき ます か ？'},
#  {'id': '676',
#   'text': '販売 契約 社員 で AzureRMS で 暗号化 さ れ た ファイル を 開く こと が 出来 ませ ん'},
#  {'id': '677', 'text': '販売 契約 社員 の AzureRMS 申請 方法 を 教え て ほしい'},
#  {'id': '678', 'text': '販売 契約 社員 で Office を 使い たい'},
#  {'id': '679', 'text': '販売 契約 社員 の AzureRMS の 申請 方法 を 教え て ください'},
#  {'id': '680', 'text': '販売 契約 社員 で Office 365 を 使い たい'},
#  {'id': '681', 'text': '販売 契約 社員 の AzureRMS の 申請 方法 が わかり ませ ん'},
#  {'id': '682',
#   'text': 'OAPC が blue に 繋がら なく なっ た の で プロファイル を 削除 し た 。 再設定 は どう すれ ば いい か'},
#  {'id': '683', 'text': 'OAPC で Blue を 利用 し たい 。 blue の パスワード を 教え て ください'},
#  {'id': '684', 'text': '準 OAPC で Blue 接続 でき ませ ん 。 パスワード 入力 を 求め られ ます 。'},
#  {'id': '685', 'text': 'OAPC から 社内 LAN の blue に 自動 接続 が でき なく なっ た'},
#  {'id': '686', 'text': 'OAPC から blue に 接続 する 際 の 設定 方法 に つい て 教え て ほしい 。'},
#  {'id': '687', 'text': '準 OAPC を blue に 繋ぎ たい'},
#  {'id': '688', 'text': 'OAPC が Blue に 繋がら ない'},
#  {'id': '689', 'text': 'FATPC から blue へ 接続 する 際 の 接続 方法 を 教え て ほしい 。'},
#  {'id': '690',
#   'text': 'ワークス ペース を 追加 の 項目 から ワークス ペース を 新規 で 追加 し て も いい です か ？'},
#  {'id': '691', 'text': 'ワークス ペース は 自身 で 作成 可能 です か ？'},
#  {'id': '692', 'text': '自分 で 新しく ワークス ペース を 作り たい'},
#  {'id': '693', 'text': 'ワークス ペース を 新規 作成 の 項目 は 使っ て も いい です か ？'},
#  {'id': '694',
#   'text': '「 iTunes マーク と USB ケーブル 接続 の 画面 が 表示 さ れる 」 場合 、 初期化 しか ない でしょう か 。'},
#  {'id': '695', 'text': 'iPhone / iPad で iTunes に 接続 を 乞う 画面 が 表示 さ れ ます 。'},
#  {'id': '696',
#   'text': '「 iTunes マーク と USB ケーブル 接続 の 画面 が 表示 さ れる 」 場合 、 iTunes を インストール し て 初期化 し て も いい でしょう か 。'},
#  {'id': '697',
#   'text': 'iPhone を 起動 する と iTunes マーク と USB ケーブル 接続 の 画面 が 表示 さ れる'},
#  {'id': '698', 'text': 'W ドライブ を マウント し て い なく て も 、 暗号化 は 適用 さ れ て い ます か ？'},
#  {'id': '699', 'text': 'AzureRMS の 暗号化 は W ドライブ で も 適用 さ れ て い ます か ？'},
#  {'id': '700', 'text': 'W ドライブ は マウント し て い なく て も 暗号化 さ れ ます か ？'},
# ...
#  {'id': '758', 'text': 'アオマイ に つい て 問合せ たい'},
#  {'id': '759', 'text': "A ' OMAI に つい て 問合せ たい"},
#  {'id': '760', 'text': 'アオマイ の 管理 部署 を 教え て 欲しい'},
#  {'id': '761', 'text': 'L 3 OA アカウント の パスワード を リセット （ ロック 解除 ） し たい'},
#  {'id': '762', 'text': 'L 3 アカウント の パスワード リセット 方法 を 教え て'},
#  {'id': '763', 'text': 'L 3 アカウント の パスワード リセット に つい て'},
#  {'id': '764', 'text': 'L 3 アカウント の パスワード を リセット し たい'},
#  {'id': '765', 'text': 'L 3 アカウント が パスワード ロック さ れ た とき どこ に 連絡 すれ ば いい ？'},
#  {'id': '766', 'text': '代理 で L 3 アカウント の パスワード リセット を する 方法 を 教え て'},
#  {'id': '767', 'text': 'L 3 アカウント の パスワード が わから ない'},
#  {'id': '768', 'text': 'L 2 アカウント の パスワード リセット 方法 を 教え て 欲しい'},
#  {'id': '769', 'text': 'L 3 アカウント の パスワード が 不明 です'},
#  {'id': '770', 'text': 'iPhone から Android へ 移行 し たい'},
#  {'id': '771', 'text': 'Android へ iPhone から データ を 移し たい'},
#  {'id': '772', 'text': 'Android へ iPhone から 設定 変更 し たい'},
#  {'id': '773', 'text': 'iPhone から Android へ 設定 を 移行 し たい'},
#  {'id': '774', 'text': 'iPhone から Android へ データ を 移す 方法 を 知り たい'},
#  {'id': '775', 'text': 'Android に iPhone から データ 移行 を し たい'},
#  {'id': '776', 'text': 'Android へ iPhone から 切り替え たい'},
#  {'id': '777', 'text': 'iPhone から Android へ の データ を 移し たい'},
#  {'id': '778', 'text': 'iPhone から Android へ の 機種変 時 の 設定 が 知り たい'},
#  {'id': '779', 'text': 'ソフトウェア 担当者 の 変更 方法 を 教え て'},
#  {'id': '780', 'text': 'ライセンス 担当者 の 変更 する に は どう し たら いい か'},
#  {'id': '781', 'text': 'ソフトウェア 担当者 を 変更 し たい 場合 は どう すれ ば いい です か 。'},
#  {'id': '782', 'text': 'ソフトウェア 担当者 の 変更 申請 方法 を 教え て 欲しい'},
#  {'id': '783', 'text': 'ソフトウェア の 管理 部門 を 変更 し たい'},
#  {'id': '784', 'text': 'ソフトウェア 担当者 の 変更 方法 に つい て 教え て'},
#  {'id': '785', 'text': 'ソフトウェア 管理者 の 変更 方法 を 教え て'},
#  {'id': '786', 'text': 'ソフトウェア 担当者 を 変更 し たい'},
#  {'id': '787', 'text': 'ソフトウェア 担当者 を 変更 する 方法 を 教え て 欲しい'},
#  {'id': '788', 'text': '業務用 携帯 B の コンテンツ 登録 方法 を 教え て 欲しい'},
#  {'id': '789', 'text': '業務 端末 B の コンテンツ 登録 方法 を 教え て ください 。'},
#  {'id': '790', 'text': '業 端 B で My   SoftBank から コンテンツ 登録 が でき ない'},
#  {'id': '791',
#   'text': '業 端 B の コンテンツ 登録 が 福岡 Biz で でき ない と 言わ れ た 場合 の 対処 方法 を 教え て 欲しい'},
#  {'id': '792', 'text': '業務 端末 B で コンテンツ 登録 に つい て 確認 し たい'},
#  {'id': '793', 'text': 'iPad の 電話 番号 を 調べ たい'},
#  {'id': '794', 'text': 'Android の MSN の 確認 方法 を 教え て ください 。'},
#  {'id': '795', 'text': 'iPhone / iPad の MSN の 確認 方法 を 教え て ください 。'},
#  {'id': '796', 'text': '業務 端末 A （ 携帯 ） の 電話 番号 が 表示 さ れ ない'},
#  {'id': '797', 'text': '業務 端末 B で 電話 番号 もしくは データ 通信 契約 番号 が 表示 さ れ ませ ん 。'},
#  {'id': '798', 'text': '業務 端末 A の iPhone で MSN が 表示 さ れ ませ ん 。'},
#  {'id': '799', 'text': 'iPad の データ 通信 契約 番号 を 知り たい'},
#  {'id': '800', 'text': 'iPad の 「 MSN （ データ 通信 契約 番号 ） 」 を 確認 し たい 。'},
#  {'id': '801', 'text': '業務 端末 A の Android で MSN が 表示 さ れ ませ ん 。'},
#  {'id': '802', 'text': '業務 端末 A で MSN が 表示 さ れ ませ ん'},
#  {'id': '803', 'text': 'グループ アドレス に プロジェクト フォルダ の 管理者 権限 を 付与 し たい'},
#  {'id': '804', 'text': 'プロジェクト フォルダ の アクセス権 に グループ アドレス を 設定 し たい'},
#  {'id': '805', 'text': 'プロジェクト フォルダ 権限 に グループ アドレス を 設定 し たい'},
#  {'id': '806', 'text': 'グループ アドレス に フォルダ アクセス権 を 設定 し たい'},
#  {'id': '807', 'text': 'グループ アドレス に プロジェクト フォルダ 権限 を 設定 し たい'},
#  {'id': '808', 'text': 'グループ アドレス に プロジェクト フォルダ の 権限 を 付与 し たい'},
#  {'id': '809', 'text': 'グループ アドレス に プロジェクト フォルダ の 権限 を 付け たい'},
#  {'id': '810', 'text': 'プロジェクト フォルダ に アクセス権 を つけ たい'},
#  {'id': '811', 'text': 'ブラウザ が 古い と 表示 さ れ て Slack に サイン イン でき ない'},
#  {'id': '812', 'text': 'Slack に サイン イン し たい の で Chrome の 更新 方法 を 教え て'},
#  {'id': '813', 'text': 'Slack に サイン イン できる ブラウザ に し たい'},
#  {'id': '814',
#   'text': 'Slack に サイン イン しよう と する と 、 ブラウザ を 更新 する よう エラー が 出 て しまう'},
#  {'id': '815', 'text': 'ミーティング に 参加 し て いる 人 を 確認 し たい'},
#  {'id': '816', 'text': '会議 参加者 を 確認 する 方法 は あり ます か ？'},
#  {'id': '817', 'text': '会議 の 参加者 の 一覧 が 欲しい'},
#  {'id': '818', 'text': '誰 が 会議 に 参加 し て い た か 確認 する こと は でき ます か ？'},
#  {'id': '819', 'text': 'OAMac で 閲覧 可能 な サイト の 一覧 は あり ます か ？'},
#  {'id': '820',
#   'text': 'Mac ローカル 上 で 、 etime 、 smile を 表示 さ せる 方法 を ご 教示 ください 。 Chrome で intra は 表示 できる もの の コンテンツ が エラー と なっ て しまい ます 。'},
#  {'id': '821', 'text': 'OAMac で 人事 Navi は 閲覧 でき ます か ？'},
#  {'id': '822', 'text': 'OAMac で 社内 システム に アクセス でき ます か ？'},
#  {'id': '823',
#   'text': '準 OAMAC の 設定 を 行っ た の です が 、 blue で 接続 し た とき に Gmail や OA サポート に は 入れ ます が 、 人事 navi や PureTerminal や Smile に は 入れ ない よう です 。'},
#  {'id': '824', 'text': '業務 端末 A の 交換 後 の 返却 期限 を 教え て ください 。'},
#  {'id': '825', 'text': '業 端 A 交換 後 の 返却 ルール に つい て 教え て 欲しい'},
#  {'id': '826', 'text': '業 端 A 交換 後 、 旧 端末 は いつ まで に 返却 すれ ば よい です か ？'},
#  {'id': '827', 'text': '業務用 端末 B を 故障 交換 し た 場合 の 返却 方法 を 教え て 欲しい'},
#  {'id': '828', 'text': '固定 IP の 払い出し て ほしい'},
#  {'id': '829', 'text': '固定 IP に する 方法 は ？'},
#  {'id': '830', 'text': '固定 IP の 払い出し し たい'},
#  {'id': '831', 'text': '固定 IP アドレス を 取得 する に は'},
#  {'id': '832', 'text': '固定 ip が ほしい'},
#  {'id': '833', 'text': '固定 IP の 申請 手順 を 確認 し たい'},
#  {'id': '834', 'text': '固定 IP アドレス の 申請 方法 に つい て'},
#  {'id': '835', 'text': '固定 IP アドレス の 申請 方法 に つい て 教え て ほしい'},
#  {'id': '836', 'text': '固定 IP を 設定 する こと は 可能 です か'},
#  {'id': '837', 'text': 'テレビ 会議用 機器 など の 固定 IP の ご 申請 方法 を 教え て ください 。'},
#  {'id': '838',
#   'text': '「 この ブック を 開く ため の 権限 が あり ませ ん 。 別 の 資格 情報 を 使っ て ファイル を 開き ます 」 が 表示 さ れ 、 Excel ファイル が 開け ない'},
#  {'id': '839', 'text': 'この ブック を 開く ため の 権限 が あり ませ ん 。'},
#  {'id': '840',
#   'text': 'この ブック を 開く ため の 権限 が あり ませ ん 。 別 の 権限 を 使っ て 情報 を 開き ます か ？'},
#  {'id': '841',
#   'text': 'Excel ファイル が 開き ませ ん 。 現在 の アカウント が 表示 さ れる の で クリック する と この ブック を 開く 権限 が あり ませ ん と 表示 さ れ ます'},
#  {'id': '842',
#   'text': 'この ブック を 開く 権限 が あり ませ ん 、 の エラー が 表示 さ れ て Excel ファイル が 開け ない'},
#  {'id': '843',
#   'text': '「 この ブック を 開く ため の 権限 が あり ませ ん 。 別 の 資格 情報 を 使っ て ファイル を 開き ます 」 が 表示 さ れる'},
#  {'id': '844',
#   'text': 'この ブック を 開く 権限 が あり ませ ん 、 と 表示 さ れ て Excel ファイル が 開け ない'},
#  {'id': '845',
#   'text': '「 この ブック を 開く ため の 権限 が あり ませ ん 。 別 の 資格 情報 を 使っ て ファイル を 開き ます 」 の エラー メッセージ が 表示 さ れる'},
#  {'id': '846', 'text': 'この プレゼンテーション を 開く 為 の 権限 が あり ませ ん \u3000 と 表示 さ れる'},
#  {'id': '847', 'text': 'PC の デスクトップ で 「 アイコン を 等間隔 に 整列 」 の 設定 が でき ない'},
#  {'id': '848', 'text': '「 アイコン を 等間隔 に 整列 」 が 選択 でき ない'},
#  {'id': '849', 'text': '「 アイコン を 等間隔 に 整列 」 が クリック でき ない'},
#  {'id': '850', 'text': '「 アイコン を 等間隔 に 整列 」 に チェック が 入ら ない'},
#  {'id': '851', 'text': '組織 グループ の 正 社員用 と 全 社員用 の 違い を 教え て 欲しい'},
#  {'id': '852', 'text': '組織 グループ の 正 社員用 と 全 社員用 の 用途 を 教え て 欲しい'},
#  {'id': '853', 'text': '組織 グループ の 用途 に つい て 教え て 欲しい'},
#  {'id': '854', 'text': '組織 グループ の 正 社員用 と 全 社員用 は どこ が 異なる の でしょう か ？'},
#  {'id': '855',
#   'text': 'サイバー トラスト   デバイス ID 発行 の お知らせ の メール が 発行 さ れ て いる か 確認 し たい'},
#  {'id': '856',
#   'text': 'サイバー トラスト   デバイス ID 発行 の お知らせ が 届か ない の で 、 再発行 し て 欲しい'},
#  {'id': '857',
#   'text': 'OASYS 申請後 、 サイバー トラスト   デバイス ID 発行 の お知らせ の メール が 届か ない'},
#  {'id': '858', 'text': 'サイバー トラスト   デバイス ID 発行 の お知らせ の メール が 見当たら ない'},
#  {'id': '859', 'text': '業務用 携帯 B の 種類 が 知り たい 。'},
#  {'id': '860', 'text': '業 端 B に 適合 する USIM を 確認 し たい'},
#  {'id': '861', 'text': '業務用 携帯 B の 機種 が 知り たい 。'},
#  {'id': '862', 'text': '業務用 端末 B の 機器 コード を 知り たい 。'},
#  {'id': '863', 'text': '業務用 携帯 B 手配 機種 の 商品 コード を 知り たい'},
#  {'id': '864', 'text': '業務 端末 B の 販売 関連 情報 を 確認 し たい 。'},
#  {'id': '865', 'text': '業務 端末 B の 製品 情報 を 確認 し たい 。'},
#  {'id': '866',
#   'text': '業 端 端末 で VPN 申請 し て い た が 端末 交換 し た ため 、 以前 の VPN 申請 を 削除 し たい 。 手順 を 教え て ほしい 。'},
#  {'id': '867', 'text': '業務 端末 を 返却 する に 当たっ て VPN の 削除 申請 を 行う 方法 を 知り たい'},
#  {'id': '868', 'text': 'iPhone の VPN 申請 の 削除 方法 を 教え て ほしい'},
#  {'id': '869', 'text': '業務用 端末 A の VPN 削除 の 仕方 に つい て 知り たい 。'},
#  {'id': '870', 'text': '業 端 A の VPN の 申請 を 削除 し たい'},
#  {'id': '871', 'text': '業務 端末 の VPN の 削除 申請 を し たい 。'},
#  {'id': '872', 'text': '業務 端末 の VPN 削除 申請 方法 を 教え て 欲しい 。'},
#  {'id': '873', 'text': 'iPad - VPN の 申請 を 削除 し たい'},
#  {'id': '874', 'text': 'iPhone を 返却 する 前 に VPN の 申請 を 削除 し たい'},
#  {'id': '875', 'text': 'OAPC の Slack の バージョン アップ は でき ます か ？'},
#  {'id': '876', 'text': 'Slack の デスクトップ アプリ の バージョン アップ を し たい'},
#  {'id': '877', 'text': 'Slack アプリ の バージョン アップ を し たい'},
#  {'id': '878', 'text': 'Slack アプリ の アップデート 方法 を 教え て'},
#  {'id': '879', 'text': 'ソフトウェア センター が 存在 し て い ない 場合 の 対処 方法 を 教え て 欲しい'},
#  {'id': '880', 'text': 'ソフトウェア センター が インストール さ れ て い ない'},
#  {'id': '881',
#   'text': 'アプリケーション を インストール しよう と し た が 、 ソフトウェア センター が 存在 し ない'},
#  {'id': '882', 'text': 'ソフトウェア センター が 存在 し て い ない'},
#  {'id': '883',
#   'text': 'ソフトウェア センター から インストール できる ソフトウェア が ある と の こと だ が 、 そもそも ソフトウェア センター が 存在 し て い ない'},
#  {'id': '884', 'text': 'ソフトウェア センター が 存在 し ない'},
#  {'id': '885', 'text': 'スタート 内 に ソフトウェア センター が 存在 し ない'},
#  {'id': '886', 'text': 'サーバ 上 に ソフトウェア を インストール し たい'},
#  {'id': '887',
#   'text': 'サーバ に Microsoft の ボリューム ライセンス を インストール し たい が どう し たら いい です か 。'},
#  {'id': '888', 'text': 'サーバー に ソフトウェア を インストール し たい'},
#  {'id': '889', 'text': 'サーバ に ソフトウェア を インストール する 手順 を 教え て 欲しい'},
#  {'id': '890', 'text': 'サーバー に アプリケーション を インストール する 場合 、 申請 は 必要 です か ？'},
#  {'id': '891',
#   'text': 'サーバ に ソフトウェア を インストール し たい が ライセンス 管理 システム で の 申請 は 必要 です か 。'},
#  {'id': '892', 'text': 'サーバ に ソフトウェア を インストール する 場合 、 申請 は 必要 です か ？'},
#  {'id': '893', 'text': 'サーバー へ の ソフトウェア インストール に つい て'},
#  {'id': '894',
#   'text': 'サーバー に ソフト を インストール する の に Microsoft の ボリューム ライセンス の インストーラ が 必要 です'},
#  {'id': '895', 'text': 'Excel が 使え なく なり まし た'},
#  {'id': '896', 'text': 'エクセル だけ 起動 でき ない'},
#  {'id': '897', 'text': 'エクセル を 起動 する と エラー が 出 て 開く こと が でき ませ ん 。'},
#  {'id': '898', 'text': 'WORD が 起動 し ない'},
#  {'id': '899', 'text': 'Excel が 開け なく なっ た'},
#  {'id': '900', 'text': 'PowerPoint が 開け ない'},
#  {'id': '901', 'text': 'パワーポイント が 起動 し ない'},
#  {'id': '902', 'text': 'エクセル が 起動 し ない の で 対処法 を 知り たい'},
#  {'id': '903', 'text': 'Excel が 動か なく なっ た'},
#  {'id': '904', 'text': '突然 L 3 DevMac で Aqua に つながら なく なっ た'},
#  {'id': '905', 'text': 'L 3 Dev 端末 を aqua に つなげ たい'},
#  {'id': '906', 'text': '開発 PC が aqua に 接続 でき ない'},
#  {'id': '907', 'text': 'aqua の 接続 方法 に つい て'},
#  {'id': '908', 'text': '開発 PC で aqua に 接続 でき ない 場合 の 対応 方法 を 教え て ください 。'},
#  {'id': '909', 'text': 'aqua に 繋げ たい'},
#  {'id': '910', 'text': 'L 3 Dev 端末 から Aqua に 接続 し たい'},
#  {'id': '911', 'text': 'aqua に 接続 出来 ない'},
#  {'id': '912', 'text': 'L 3 Dev 端末 用 の 無線 に つなげ たい'},
#  {'id': '913', 'text': 'aqua の パスワード 教え て ください 。'},
#  {'id': '914', 'text': '準 OA 化 の 手順 で LAN コンバーター の 使い方 が よく わかり ませ ん'},
#  {'id': '915', 'text': '部門 購入 PC の セットアップ URL へ アクセス し たい'},
#  {'id': '916',
#   'text': '部門 で 購入 し た 最新 の Windows   OS だ と 社内 NW に 接続 でき ない の でしょう か 。'},
#  {'id': '917',
#   'text': '準 OA 化 作業 を し て い ます 。 LAN コンバーター を 接続 し た の です が インターネット に 接続 でき ませ ん 。'},
#  {'id': '918', 'text': '部門 購入 PC の セットアップ URL へ アクセス できる 方法 を 教え て ください'},
#  {'id': '919',
#   'text': '準 OA 化 し て い ます が 最初 の ダウンロード ページ へ の アクセス 方法 を 知り たい'},
#  {'id': '920', 'text': 'CaMP に つい て 問合せ たい'},
#  {'id': '921', 'text': 'CaMP の 権限 が 欲しい'},
#  {'id': '922', 'text': 'CaMP の 管理 部署 を 教え て 欲しい'},
#  {'id': '923', 'text': 'CaMP の 問合せ先 は どこ です か ？'},
#  {'id': '924', 'text': 'CaMP に つい て 確認 し たい'},
#  {'id': '925', 'text': 'CaMP の 権限 を 取得 し たい'},
#  {'id': '926', 'text': 'CaMP に つい て'},
#  {'id': '927', 'text': 'Camp に つい て'},
#  {'id': '928', 'text': 'クルーナビ に つい て 質問 し たい'},
#  {'id': '929', 'text': 'クルーナビ の パスワード が わから ない'},
#  {'id': '930', 'text': 'クルーナビ に つい て 確認 し たい'},
#  {'id': '931',
#   'text': 'iPad で 今まで クルーナビ が 見れ て い た が 再起動 し たら 開か なく なっ た 。 VPN は 繋がっ て いる'},
#  {'id': '932', 'text': '業務 端末 の PC で クルーナビ に ログイン 出来 ない'},
#  {'id': '933', 'text': 'クルーナビ の 問い合わせ 窓口 を しり たい'},
#  {'id': '934', 'text': 'インターネット は 接続 できる が 、 クルーナビ に アクセス でき ませ ん'},
#  {'id': '935', 'text': 'クルーナビ に アクセス でき ませ ん'},
#  {'id': '936', 'text': '社外 で 社内 システム を 閲覧 し たい'},
#  {'id': '937', 'text': '社外 で OAPC を 利用 し たい'},
#  {'id': '938', 'text': '外出先 で OAPC を 使い たい'},
#  {'id': '939', 'text': '社外 で も PC が 使える よう に し たい'},
#  {'id': '940',
#   'text': 'OAPC で 社外 環境 から 社内 システム を 利用 する に は どの よう に すれ ば 良い です か'},
#  {'id': '941', 'text': 'OA 端末 を 社外 から 利用 し たい'},
#  {'id': '942', 'text': '社外 環境 で OA 標準 端末 から 社内 システム を 利用 し たい'},
#  {'id': '943', 'text': '社外 から 社内 システム を 利用 する の に は どう し たら いい です か ？'},
#  {'id': '944', 'text': '社外 環境 で OAPC を 使用 し たい'},
#  {'id': '945', 'text': 'OAPC で 社外 環境 から 社内 システム を 利用 する'},
#  {'id': '946', 'text': 'L 3 Dev 端末 故障 の 為 交換 し たい'},
#  {'id': '947', 'text': 'L 3 Dev 端末 が 故障 し た の で 交換 し て ほしい'},
#  {'id': '948', 'text': 'L 3 Dev 端末 の 故障 交換 を 実施 し て ほしい'},
#  {'id': '949', 'text': 'L 3 Dev 端末 が 故障 し た 場合 の 対処 方法 を 教え て 欲しい'},
#  {'id': '950', 'text': '開発 環境 の 端末 か 故障 し た の で 交換 し て ほしい 。'},
#  {'id': '951', 'text': 'L 3 Dev 端末 の 故障 交換 を し て ほしい'},
#  {'id': '952', 'text': '開発 端末 が 故障 し た の で 交換 し たい'},
#  {'id': '953', 'text': '開発 端末 を 故障 交換 し たい'},
#  {'id': '954', 'text': 'L 3 Dev 端末 が 故障 し た の で 、 交換 し たい'},
#  {'id': '955', 'text': '開発 端末 が 故障 し た の で 交換 し て ほしい'},
#  {'id': '956',
#   'text': 'iPhone / iPad の Touch   ID （ 指紋 認証 ） の やり方 を 教え て ください 。'},
#  {'id': '957',
#   'text': 'iPhone / iPad の Touch   ID （ 指紋 認証 ） の 登録 方法 を 確認 し たい 。'},
#  {'id': '958', 'text': 'iPhone の 指紋 認証 の 手順 を 教え て ほしい'},
#  {'id': '959',
#   'text': 'iPhone / iPad の Touch   ID （ 指紋 認証 ） の 登録 方法 を 教え て ください 。'},
#  {'id': '960',
#   'text': 'iPhone / iPad の Touch   ID （ 指紋 認証 ） に 運用 ルール は あり ます か 。'},
#  {'id': '961', 'text': 'Google の アプリケーション で の アドオン 利用 方法 を 教え て 欲しい'},
#  {'id': '962', 'text': 'Google ドキュメント で アドオン を 利用 し たい'},
#  {'id': '963', 'text': 'Google の アドオン を 利用 し たい です'},
#  {'id': '964', 'text': 'Google スプレッドシート で アドオン を 利用 し たい'},
#  {'id': '965', 'text': 'Chrome に アドオン を いれ て も いい か'},
#  {'id': '966', 'text': 'Google の アプリケーション で アドオン を 利用 する 申請 方法 を 教え て 欲しい'},
#  {'id': '967', 'text': 'Google   Workspace の アドオン を 利用 し たい です'},
#  {'id': '968', 'text': 'Google プレゼンテーション で アドオン を 利用 し たい'},
#  {'id': '969', 'text': 'IMSI タイプ コード の 確認 方法 を 教え て ほしい'},
#  {'id': '970', 'text': 'IMSI タイプ コード が 分ら ない'},
#  {'id': '971', 'text': 'IMSI タイプ コード を 確認 し たい'},
#  {'id': '972', 'text': '業務用 携帯 B の 新規 申請 に 必要 な IMSI タイプ コード が 不明'},
#  {'id': '973', 'text': 'IMSI タイプ コード を 調べ たい'},
#  {'id': '974', 'text': '業務 端末 B の iPhone の バック ライト が 点灯 し ない 。'},
#  {'id': '975', 'text': '業務 端末 A で バック ライト が 点灯 し なく なり まし た 。'},
#  {'id': '976', 'text': '業務 端末 B の バック ライト が 光ら なく なり まし た 。'},
#  {'id': '977', 'text': '業務 端末 B で バック ライト が 点灯 し なく なり まし た 。 交換 可能 でしょう か 。'},
#  {'id': '978', 'text': '業務 端末 A の iPhone の バック ライト が 点灯 し ない 。'},
#  {'id': '979', 'text': '業務 端末 A で 画面 を 輝度 調整 し た が 、 暗い まま です 。'},
#  {'id': '980', 'text': '業務 端末 A で 輝度 調整 が でき なく なり まし た 。 交換 可能 でしょう か 。'},
#  {'id': '981', 'text': '業務 端末 A の バック ライト が つか なく なり まし た 。'},
#  {'id': '982', 'text': '業務 端末 A で バック ライト が 点灯 し なく なり まし た 。 交換 可能 でしょう か 。'},
#  {'id': '983', 'text': '業務 端末 B で 輝度 調整 が でき なく なり まし た 。 交換 可能 でしょう か 。'},
#  {'id': '984', 'text': '出荷 統合 システム に つい て 確認 し たい'},
#  {'id': '985', 'text': '出荷 統合 システム に つい て 問合せ たい'},
#  {'id': '986', 'text': '出荷 統合 システム の 問合せ先 は どこ です か ？'},
#  {'id': '987', 'text': '出荷 統合 システム の 管理 部署 を 教え て 欲しい'},
#  {'id': '988',
#   'text': 'Office 365 ライセンス 認証 時 に 「 ユーザー ID   また は 、 パスワード が 正しく あり ませ ん 。 もう 一度 試し て み て ください 。 」 と 表示 さ れ た'},
#  {'id': '989',
#   'text': 'Office 365 で ユーザー ID   また は 、 パスワード が 正しく あり ませ ん 。 もう 一度 試し て み て ください 。 が 発生 する 。'},
#  {'id': '990', 'text': 'パスワード が 違う と 表示 さ れ て Office 365 ライセンス 認証 に 失敗 する'},
#  {'id': '991',
#   'text': 'Office 365 ライセンス 認証 時 に ユーザー ID   また は 、 パスワード が 正しく あり ませ ん 。 もう 一度 試し て み て ください 。 と 表示 さ れ た'},
#  {'id': '992',
#   'text': 'Office 365 の ライセンス 認証 で 「 ユーザー ID   また は 、 パスワード が 正しく あり ませ ん 。 もう 一度 試し て み て ください 。 」 と 表示 さ れる'},
#  {'id': '993',
#   'text': 'Office 365 ライセンス 認証 時 に 「 ユーザー ID   また は 、 パスワード が 正しく あり ませ ん 。 もう 一度 試し て み て ください 。 」 と 表示 さ れ た の です が どう すれ ば いい です か 。'},
#  {'id': '994', 'text': 'ユーザー名 が 違う と 表示 さ れ て Office 365 ライセンス 認証 が 出来 ない'},
#  {'id': '995', 'text': '「 この 項目 は もう 使用 でき ませ ん 」 が 表示 さ れる の を 解消 し たい'},
#  {'id': '996',
#   'text': '「 この 項目 は もう 使用 でき ませ ん 」 が 表示 さ れ た 場合 の 対処 方法 を 教え て 欲しい'},
#  {'id': '997',
#   'text': 'SelfService から Admin 権限 付与 時 「 この 項目 は もう 使用 でき ませ ん 」 が 表示 さ れる'},
#  {'id': '998',
#   'text': 'SelfService から Admin 権限 付与 時 「 この 項目 は もう 使用 でき ませ ん 」 が 表示 さ れ 、 Admin 権限 が 付与 でき ない'},
#  {'id': '999',
#   'text': 'billing   support . ad . intra . eaccess . net に アクセス でき ませ ん 。'},
#  ...]

# %%
split_corpus_l = [split_text(c) for c in corpus_l]

# %%
split_corpus_l
# Out:
# [{'id': '100000',
#   'title': '',
#   'text': 'Slack の ゲスト アカウント の 有効 期限 が 切れ た （ 解除 済み アカウント ） 場合 は 、 ゲスト 管理 システム から ゲスト 新規 登録 申請 と 利用 サービス 登録 申請 を 実施 下さい 。 \n ※ ゲスト 登録 が 有効 期限内 の 場合 は 、 マイゲスト 一覧 から 利用 サービス 登録 申請 のみ 実施 下さい \n 申請 方法 は 下記 手順 を 参照 下さい 。 \n\n ・ 【 ゲスト 管理 システム 】 マニュアル - 申請者 向け \n https : / / docs . google . com / presentation / d / 1 Z 0 PUkjNUr 9 r 2 GCq 5 ZEEddd 5 jPUJg 48 kPMsCxv 5 Mtw _ M / edit # slide = id . g 1287222 f 34 d _ 1 _ 61 \n\n 申請 の 上長 承認 後 、 5 営業日 以内 に アカウント が 有効 化 さ れ ます 。 \n 有効 化 完了 後 は 下記 メール が 送信 さ れ ます の で 、 メール を 確認 次第 、 必要 な チャンネル に ゲスト を 招待 し て 下さい 。 \n ※ ゲスト を チャンネル に 招待 する 際 は メール アドレス で は なく Slack 上 の 氏名 で 検索 下さい \n 件名 ： 【 ゲスト 管理 】 利用 サービスプロビジョニングエラー 対応 完了 通知 \n\n ■ お 問合せ先 \n ・ OA   Support   Net \n\u3000 http:// oa . bb . local / oasupport / inquiry _ web \n\u3000 （ 投稿 カテゴリ ： Slack ）'},
#  {'id': '100001',
#   'title': '',
#   'text': 'WHC の 問合せ に つい て は 、 OA サポート デスク で は サポート 対象外 と なり ます 。 \n 下記 窓口 が 担当 か と 思わ れ ます の で 、 直接 問合せ 願い ます 。 \n\n ・ ＩＴ 部門 （ ＷＨＣ ） 工数 管理 窓口 \n  SBMGRP - WHC @ g . softbank .co.jp \n\n また 、 WHC の 申請 に つい て も 、 OA サポート デスク で は サポート 対象外 と なり ます 。 \n 下記 窓口 が 担当 か と 思わ れ ます の で 、 直接 問合せ 願い ます 。 \n\n ・ システム コード 管理 窓口 \n  SBMGRP - system - code @ g . softbank .co.jp'},
#  {'id': '100002',
#   'title': '',
#   'text': 'GoogleChrome の インストール ・ アンインストール 方法 に つい て は 、 ソフトウェア センター から 実施 し て 下さい 。 \n\n ■ インストール 方法 \n GoogleChrome の インストール 方法 に つい て は 、 ソフトウェア センター から 実施 し て 下さい 。 \n ・ 【 SCCM 】 Windows 向け ソフトウェア センター 利用 マニュアル \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / post / sccm _ win 10 \n\n ソフトウェア センター から インストール 不可 の 場合 は 、 Admin 権限 取得 の 上 、 下記 手順 で インストール し て 下さい 。 \n 1 . Admin 権限 申請 及び 適用 方法 を 実施 する \n ・ 【 社内外 共通 】 L 2 OAPC / 準 OAPC   Admin 権限 申請 ・ 適用 方法 \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / admintekiyou _ shanaigai \n 2 . 下記 リンク に アクセス する 。 \n\u3000 https : / / drive . google . com / drive / folders / 1 XmkYaUoTWsYq - sOmC 6 XCuewUILBYINxW \n 3 . 最新 版 の フォルダ を デスクトップ に コピー し 、 フォルダ 内 の インストーラー （ . msi ） を ダブル クリック する \n ※ インストーラー を ダブル クリック 後 も インストール でき ない 場合 は 、 インストーラー を 右 クリック ＞ 管理者 と し て 実行 を 実施 し て 下さい \n\n 参考 FAQ \n ・ Q . 10 - 004 \u3000 Chrome ブラウザ が インストール でき ない \n  https : / / sites . google . com / a / g . softbank .co.jp / helpg / discussion - board / chrome / 10 - 004 \n\n ■ アンインストール 方法 \n ・ 【 SCCM 】 Windows 向け ソフトウェア センター 利用 マニュアル \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / post / sccm _ win 10 \n ※ 「 インストール 済み ソフトウェア 」 （ インストール の ステータス ） タブ を クリック し 、 【 Google Chrome   Ver . xx . x . xxxx . xxx 】 を クリック し 、 アンインストール を 実施 し て 下さい 。 \n\n ソフトウェア センター から アンインストール 不可 の 場合 は 、 Admin 権限 取得 の 上 、 下記 手順 で アンインストール し て 下さい 。 \n 1 . Admin 権限 申請 及び 適用 方法 を 実施 する \n ・ 【 社内外 共通 】 L 2 OAPC / 準 OAPC   Admin 権限 申請 ・ 適用 方法 \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / admintekiyou _ shanaigai \n 2 . Windows キー + R キー を 同時 押下 し 、 ファイル 名 を 指定 し て 実行 の 画面 で 「 appwiz . cpl 」 を 入力 し 、 OK を クリック する 。 \n 3 . 「 Google Chrome 」 の 項目 を 選択 し 、 「 アンインストール 」 を クリック する 。'},
#  {'id': '100003',
#   'title': '',
#   'text': 'ファイル など の PDF 化 方法 に つい て は 、 下記 FAQ を 参照 し て 下さい 。 \n\n ・ ファイル など の PDF 化 手順 に つい て ［ FAQ   No ： F 000158899 ］ \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / faq / F 000158899'},
#  {'id': '100004',
#   'title': '',
#   'text': 'Android で GooglePlay 未登録 アプリ の インストール 時 、 「 インストール は ブロック さ れ まし た \u3000 携帯 端末 の セキュリティ 上 の 設定 で 供給 元 不明 の Application の インストール を ブロック し て い ます 」 と エラー が 表示 さ れ た 場合 は 、 下記 手順 を 実施 し て 下さい 。 \n 設定 > その 他 設定 > ロック と セキュリティ 内 の 「 提供 元 不明 アプリ 」 に チェック を 付ける \n ※ アプリ の インストール が 終わっ たら 再度 チェック を 外し て 下さい'},
#  {'id': '100005',
#   'title': '',
#   'text': '業 端 A   iPhone / iPad の iCloud へ の バックアップ に つい て は 、 下記 を 参照 下さい 。 \n ・ 【 iPhone / iPad 】 iCloud バックアップ マニュアル \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / manual / icloud - backup'},
#  {'id': '100006',
#   'title': '',
#   'text': 'View で の プリンタ 設定 は 、 下記 ページ の 「 View で 利用 する 場合 」 を 参照 下さい 。 \n  ・ 複合機（プリンタ） 設定 \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / pc / printer'},
#  {'id': '100007',
#   'title': '',
#   'text': '暗号化 ファイル の 解除 方法 に つい て は 、 下記 ページ を 参照 し て 下さい 。 \n\n ・ 暗号化 ファイル の 解除 \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / setting / AzureRMS / rights / unlock'},
#  {'id': '100008',
#   'title': '',
#   'text': 'EUC の 問合せ に つい て は 、 OA サポート デスク で は サポート 対象外 と なり ます 。 \n 下記 窓口 が 担当 か と 思わ れ ます の で 、 直接 問合せ 願い ます 。 \n\n ・ SB C&S   サービス デスク \n  https : / / softbankcs . service - now . com / csqa ? id = casoa _ index'},
#  {'id': '100009',
#   'title': '',
#   'text': '部門 PC を 社内 NW （ L 2 ） に 接続 する に は 、 準 OA 化 が 必要 と なり ます 。 \n  詳細 は 、 下記 サイト を ご覧 いただけ ます でしょう か 。 \n \n ・ 購入 に つい て   ※ 準 OAPC の 要件 を ご 確認 下さい 。 \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / request / purchase \n \n ・ 準 OA 化 \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / request / semioapc'},
#  {'id': '100010',
#   'title': '',
#   'text': 'ブラウザ の キャッシュ クリア に つい て は 、 下記 手順 を 実施 し て 下さい 。 \n\n ■ Windows   \n ● Chrome の キャッシュ クリア \n  1 . Google Chrome の ブラウザ を 終了 する 。 \n  2 . 下記 に アクセス し 【 Cach . bat 】 を コピー し 、 デスクトップ に 貼り付ける \n   https : / / drive . google . com / drive / folders / 1 XmkYaUoTWsYq - sOmC 6 XCuewUILBYINxW \n  3 ． コピー し た 【 Cache . bat 】 を 実行 する \n  4 . 再度 、 Google Chrome の ブラウザ を 起動 する \n\n ■ Mac \n ● Chrome の キャッシュ クリア \n 1 . command キー ＋ Y キー を 同時 押下 する \n 2 . 「 閲覧 履歴 データ を 消去 する 」 を クリック する \n 3 . 以下 を 設定 する \n\u3000 期間 ⇒ 全 期間 \n\u3000 詳細 ⇒ 閲覧 履歴 \n\u3000\u3000\u3000\u3000 ダウンロード 履歴 \n\u3000\u3000\u3000\u3000 Cookie と 他 の サイト データ \n\u3000\u3000\u3000\u3000 キャッシュ さ れ た 画像 と ファイル \n\u3000\u3000\u3000\u3000 に チェック を 入れる \n\u3000 「 データ を 消去 」 を クリック する \n 4 . command キー ＋ Q キー を 同時 押下 し 、 Chrome を 終了 さ せる \n ● Safari の キャッシュ クリア \n 1 . 画面 上部 の 履歴 > すべて の 履歴 を 表示 する を クリック する \n 2 . 履歴 を 消去 . . . ＞ 消去 の 対象 ： 全て の 履歴 ＞ 履歴 を 消去 を クリック する \n 3 . command キー ＋ Q キー を 同時 押下 し 、 Safari を 終了 さ せる'},
#  {'id': '100011',
#   'title': '',
#   'text': 'CI 検索 ツール に つい て は 、 Chrome の 拡張 機能 と なり ます の で 、 下記 マニュアル を 参照 し て 下さい 。 \n \n  ● Chrome 拡張 機能 一覧 \n https : / / sites . google . com / a / g . softbank .co.jp / helpg / chrome - extension \n 「 CI   Tools   ( by   CITeam ) 」 を インストール する と 組織 メーリング リスト 、 組織 メーリング リスト 、 OA アカウント （ エイリアス ） 等 を 検索 でき ます 。 \n\n ■ 検索 方法 \n ・ グループ アドレス 検索 \n Chrome ブラウザ 上 の 右上 の 黒い 淵 で 四角い 「 a 」 の 文字 が 書か れ て いる ロゴ を クリック ＞ ■ グループ 検索 にて グループ アドレス を 入力 \n ・ GoogleApps ユーザー 検索 \n Chrome ブラウザ 上 の 右上 の 黒い 淵 で 四角い 「 a 」 の 文字 が 書か れ て いる ロゴ を クリック ＞ ■ Google   Apps ユーザー 検索 にて OA アカウント （ エイリアス ） また は 氏名 を 入力'},
#  {'id': '100012',
#   'title': '',
#   'text': '業 端 B の 返却 に つい て は 手配 元 部門 に 返却 下さい 。 \n 返却 時 の 必要 な 対応 に つい て も 手配 元 部門 に 確認 下さい 。'},
#  {'id': '100013',
#   'title': '',
#   'text': 'W ドライブ 容量 に つい て は 、 50 GB と なり 、 容量 追加 に つい て は 、 不可 と なり ます 。   \n\n 現在 の 容量 で 足り ない 場合 は 、 使用 し て いる ファイル を 精査 し 、 容量 を 減らし て 下さい 。 \n また 、 共有 フォルダ 等 も 活用 し て 下さい 。'},
#  {'id': '100014',
#   'title': '',
#   'text': '機種 変更 等 で 移行 でき ない 連絡先 が ある 場合 、 下記 ページ を 参照 し 、 連絡先 の 移行 を 実施 下さい 。 \n ※ 回線 切り替え が ある 場合 、 回線 切り替え 後 に 作業 し て 下さい \n\n ・ Gmail アカウント 同期 で 移行 でき ない 連絡先 の 移行 \u3000 マニュアル \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / ansinBackup 2 \n ※ MySoftBank の パスワード を 忘れ た 場合 、 上記 ページ の 「 4 .   MySoftbank 認証 が でき ない 場合 」 を 確認 下さい'},
#  {'id': '100015',
#   'title': '',
#   'text': '共有 ドライブ 内 の ファイル が 削除 でき ない 場合 は 、 下記 に アクセス し 、 右上 の 虫眼鏡 から 下記 文言 で 検索 下さい 。 \n ・ Q . 05 - 016 \u3000 共有 ドライブ 内 の ファイル を 削除 する に は 、 どのような 権限 が 必要 です か ？ \n https : / / sites . google . com / a / g . softbank .co.jp / helpg / discussion - board / document / 05 - 016 \n ・ 05   -   Google ドライブ （ ドキュメント ） に 関する 質問   -   \n https : / / sites . google . com / a / g . softbank .co.jp / helpg / discussion - board / document'},
#  {'id': '100016',
#   'title': '',
#   'text': 'ワークス ペース から の サイン アウト と 退出 の 違い に つい て は 下記 と なり ます \n\n ▼ サイン アウト \n 対象 の ワークス ペース から サイン アウト だけ で 再度 SSO 認証 で サイン イン する こと が でき ます 。 \n サイン イン 方法 に つい て は 下記 ページ を 確認 下さい 。 \n\n ■ Windows \n ・ Windows 版 Slack マニュアル \n http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / request / oa - saas / slack / win - setup \n\n ■ Mac \n ・ Mac 版 Slack マニュアル \n http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / request / oa - saas / slack / mac - setup \n\n ■ iPhone / iPad \n ・ iPhone 版 Slack マニュアル \n http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / request / oa - saas / slack / iphone - setup \n\n ■ Android \n ・ Android 版 Slack マニュアル \n http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / request / oa - saas / slack / android - setup \n\n ▼ 退出 \n その ワークス ペース から 抜ける こと に なる ため 、 再 参加 は 不可 と なり ます 。 \n 再度 参加 が 必要 な 場合 は 、 ワークス ペース 管理者 から の 招待 が 必要 と なり ます の で 退出 は し ない 様 、 注意 下さい 。 \n 誤っ て 退出 し た 場合 は 下記 を 参照 の 上 、 対応 し て 下さい 。 \n\n ■ 組織 ワークス ペース から 退出 し た 場合 \n 該当 組織 ワークス ペース の 管理者 へ 再 招待 を 依頼 し て 下さい \n\n Slack 管理者 ・ アンバサダー 一覧 \n https : / / docs . google . com / spreadsheets / d / 1 xPsP 7 oLEk 4 Biwoexi 2 KT 6 aqXPzRsbLyj 5 iJy 1 VY 8 o 0 Y / edit # gid = 393065120 \n\n ■ 組織 ワークス ペース 以外 から 退出 し た 場合 \n 下記 情報 を 記載 の 上 、 WEB 投稿 で 問合せ し て 下さい \n\n ・ 氏名 ： \n ・ メール アドレス ： \n \n ・ OA   Support   Net \n http:// oa . bb . local / oasupport / inquiry _ web \n （ カテゴリ ： Slack ）'},
#  {'id': '100017',
#   'title': '',
#   'text': 'PDF の パスワード を 設定 し たい 場合 は 、 下記 手順 で パスワード を 設定 し て 下さい 。 \n  ・ AdobeAcrobat 等 編集 ソフト を 導入 する 方法 \n  ・ Zip ファイル に 圧縮 し て 圧縮 時 に パスワード を かける 方法 \n\n ■ AdobeAcrobat を 利用 する 場合 \n\u3000 下記 ページ より 利用 申請 を 行い 、 AdobeAcrobat を インストール し て 下さい 。 \n ・ Adobe   Acrobat   DC 利用 に つい て \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / AdobeAcrobatDC \n\n ■ Zip ファイル を 圧縮 し て 圧縮 時 に パスワード を 設定 する 場合 \n ● OAPC / 準 OAPC の 場合 \n\u3000 ソフトウェア センター より Lhaplus を インストール し て 下さい 。 \n\u3000 Lhaplus に つい て は 、 ソフトウェア センター から インストール を 実施 し て 下さい 。 \n\u3000 ・ 【 SCCM 】 Windows 向け ソフトウェア センター 利用 マニュアル \n\u3000  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / post / sccm _ win 10 \n ● View の 場合 \n\u3000 Lhaplus インストール 済み な の で 、 そのまま 利用 し て 下さい'},
#  {'id': '100018',
#   'title': '',
#   'text': 'Zoom ミーティング で イヤホン 利用 時 に イヤホン から 音声 が 聞こえ ない 場合 は 、 下記 設定 に なっ て いる か ご 確認 下さい 。 \n\n Zoom アプリ の 設定 ( 歯車 マーク ) ＞ オーディオ \n ＞ スピーカー 項目 の プルダウン から 「 ヘッドホン 」 を 選択'},
#  {'id': '100019',
#   'title': '',
#   'text': '共有 グループ の 管理者 を 確認 する 場合 は 、 下記 に ページ を 参照 下さい 。 \n ・ Q . 07 - 024 \u3000 グループ の 管理者 を 確認 する こと は でき ます か ？ \n https : / / sites . google . com / a / g . softbank .co.jp / helpg / discussion - board / group / 07 - 024 \n\n なお 、 ご自身 が メンバー に なっ て いる グループ に つい て は 以下 手順 で も 確認 でき ます 。 \n\n OA   Support   Navi に アクセス ＞ Mypage ＞ 詳細 情報 は こちら ＞ GoogleApps 情報 の 青い 人型 の アイコン から 管理者 の 確認 \n\n ・ OA   Support   Navi \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / \n\n 上記 手順 で 解決 し ない 場合 は 、 OA   Support   Net へ 下記 情報 を 記載 し 、 投稿 下さい 。 \n\n  ・ グループ アドレス の メール アドレス \n  ・ 表示 名 \n\n ・ OA   Support   Net \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / inquiry _ web \n （ カテゴリ ： GoogleApps )'},
#  {'id': '100020',
#   'title': '',
#   'text': '「 VPN サーバ と の ネゴシエーション に 失敗 し まし た 。 」 の エラー が 発生 し た 場合 は 、 VPN の 再 インストール を 試し て 下さい 。 \n\n ■ iPhone / iPad \n 1 ． 設定 ＞ 一般 ＞ VPN と デバイス 管理 より 下記 プロファイル を 削除 下さい \n ・ Cybertrust   DeviceiD ～ \n ・ iPhoneVPN ～ \n 2 ． 「 [ iPhone / iPad - VPN ] 証明書 発行 の お知らせ   IMEI   : ・ ・ ・ 」 メール に 記載 さ れ て いる 内容 に 従い 、 再 インストール を 実施 し て 下さい 。 \n\n ■ Android \n 下記 ページ を 参照 し 、 再 インストール し て 下さい 。 \n ・ 【 Android 】 VPN 設定 \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / android / androidvpn'},
#  {'id': '100021',
#   'title': '',
#   'text': 'ゲスト 管理 システム の 管理者 グループ に 紐 づく ゲスト 全員 を 別 の 管理者 グループ に 移行 し たい 場合 は 、 下記 手順 を 参照 下さい 。 \n\n ① ゲスト 管理 システム の ゲスト 新規 登録 画面 で 移行 先 管理者 グループ を 選択 し て 、 ゲスト 全員 分 の ゲスト 登録 と 利用 サービス の 新規 申請 を 実施 。 \n ② 「 【 ゲスト 管理 】 利用 サービスプロビジョニングエラー 対応 完了 通知 」 の 受信 を 確認 。 \n （ 申請 の 承認 完了 後 、 5 営業日 以内 に 移行 先 管理者 グループ メンバー 宛 に 届き ます ） \n ③ 移行 元 管理者 グループ に 紐 づく ゲスト 全員 の 削除 申請 を 実施 。 \n （ ゲスト 登録 と 利用 サービス 登録 の 有効 期限 を 短く し て 申請 し て 下さい ） \n ④ 削除 完了 後 （ 設定 し た 有効 期限 経過 後 ） 、 必要 に 応じ て 移行 元 管理者 グループ を 削除 。 \n\n なお 、 管理者 グループ は グループ 名 と メンバー 変更 が 可能 です 。 \n ゲスト を 移行 さ せる 必要 が ない 場合 は 、 グループ 名 や メンバー 変更 にて 対応 下さい 。 \n\n ゲスト 管理 システム の 操作 方法 は 下記 手順 を 参照 下さい 。 \n\n ・ 【 ゲスト 管理 システム 】 マニュアル - 申請者 向け \u3000 \n https : / / docs . google . com / presentation / d / 1 Z 0 PUkjNUr 9 r 2 GCq 5 ZEEddd 5 jPUJg 48 kPMsCxv 5 Mtw _ M / edit # slide = id . g 1345 deaa 28 b _ 0 _ 80 \n\n ・ ゲスト 管理 システム \n https : / / guest . in . g . softbank .co.jp / \n ※ 正社員 のみ 利用 可'},
#  {'id': '100022',
#   'title': '',
#   'text': 'Windows 端末 で 起動 時 に 「 BitLocker 」 が 表示 さ れ 、 回復 キー を 求め られ た 場合 は 、 下記 FAQ を 参照 し て 下さい 。 \n\n ■ L 2   OAPC / 準 OAPC \n ・ BitLocker の 画面 が 出 て PC に ログイン でき ない [ FAQ   No : F 170328001 ] \n http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / faq / f 170328001 \n\n フォーム 申請後 、 「 【 BitLocker 】 回復 キー 申請 」 の 件名 で メール が 自動 送信 さ れ 、 1 ～ 2 時間 程度 で 「 【 BitLocker 】 回復 キー 通知 」 の メール 件名 で 回復 キー の 通知 が 行わ れ ます 。 \n ※ 1 ～ 2 時間 経っ て も 回復 キー が 通知 さ れ ない 場合 は 、 担当 部署 に エスカレーション 致し ます の で 、 「 【 BitLocker 】 回復 キー 申請 」 の メール 内 に 記載 さ れ て いる 「 管理 番号 : BIT - * * * * * 」 と 該当 コンピューター 名 を 確認 の 上 、 OA サポート デスク へ 問合せ 下さい \n\n 社員 サポート センター （ ＯＡ サポート デスク ） ： 平日 9 : 00 ～ 18 : 00 \n ● Slack ： ＃ help - oa サポート （ チャンネル 名 で 検索 し て ください ） \n ● Ｗｅｂ 投稿 ： OA   Support   Navi   ＞   問合わせ   ＞   Web   http:// oa . bb . local / oasupport / inquiry _ web \n ● PC 受取 / 返却 ： OA   Support   Navi   ＞   問合わせ   ＞   PC 受取 / 返却   http:// oa . bb . local / oasupport / inquiry _ counter \n ● コール 予約 ： OA   Support   Navi   ＞   問合わせ   ＞   コール 予約 （ OA ）   http:// oa . bb . local / oasupport / oa - call - reservation \n\n なお 、 以下 の 事象 が 発生 し て いる 場合 は 、 端末 交換 と なり ます 。 \n ・ 回復 キー 入力 項目 が 表示 さ れ ない \n ・ 回復 キー が 発行 でき ない \n ・ 発行 さ れ た 回復 キー で 解除 でき ない \n\n ・ 【 IoTAM 】 PC 交換 申請 方法 \n http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / pc _ exchange \n ※ 解除 キー 入力 不可 の 場合 、 データ 復元 は 不可 と なり ます \n\n ■ L 3 DevPC / 準 L 3 DevPC \n 下記 マニュアル の 1 - 9 記載 の 通り 、 自身 で 任意 の 場所 に 保存 し て いる の で そちら を 確認 下さい 。 \n ・ 【 L 3 Dev 】 HDD 暗号化 （ Windows 、 Mac ） \n http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / manual / l 3 dev _ encryption \n ※ OA サポート で は 対応 不可 と なり ます'},
#  {'id': '100023',
#   'title': '',
#   'text': '業 端 A の iPhone で 4 G   /   5 G 経由 で の 通信 が でき ない 時 、 以下 の FAQ を 参照 し て 下さい 。 \n\n ・ 【 業 端 A 】 iPhone で 4 G   /   5 G 経由 で の 通信 が 出来 ない [ FAQ   No : F 170526021 ] \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / keitai / faq _ list _ ios / f 170526021 \n\n 上記 FAQ で 改善 し ない 場合 、 Web 投稿 より 問合せ 下さい 。 \n ・ Web \n  http:// oa . bb . local / oasupport / inquiry _ web \n （ カテゴリ ： iPhoneiPad ）'},
#  {'id': '100024',
#   'title': '',
#   'text': '業 端 A   iPhone / iPad で MDM 設定 時 「 プロファイル の インストール が でき ませ ん でし た 」 が 表示 さ れ た 場合 は 下記 FAQ の 内容 を 実施 下さい 。 \n\n ・ MDM 設定 時 に エラー が 発生 する [ FAQ   No : F 210310001 ] \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / faq / f 210310001 \n\n 改善 し ない 場合 は 、 必要 事項 を 確認 の 上 、 担当 部署 に エスカレーション 致し ます の で 、 OA サポート デスク へ 問合せ 下さい 。 \n ■ 必要 事項 \n ・ 対象 機種 \n ・ IMEI \n\n 社員 サポート センター （ ＯＡ サポート デスク ） ： 平日 9 : 00 ～ 18 : 00 \n ● Slack ： ＃ help - oa サポート （ チャンネル 名 で 検索 し て ください ） \n ● Ｗｅｂ 投稿 ： OA   Support   Navi   ＞   問合わせ   ＞   Web （ http:// oa . bb . local / oasupport / inquiry _ web ） \n ● リモート サポート ： OA   Support   Navi   ＞   問合わせ   ＞   リモート / PC 受取 ・ 返却 （ http:// oa . bb . local / oasupport / inquiry _ counter ） \n ● コール 予約 ： OA   Support   Navi   ＞   問合わせ   ＞   コール 予約 （ OA ） （ http:// oa . bb . local / oasupport / oa - call - reservation ）'},
#  {'id': '100025',
#   'title': '',
#   'text': '「 文書 の 取り出し が でき ませ ん でし た 」 と 表示 さ れ 、 ゼロックス 機 の 親展 ボックス から スキャン データ の 取り出し が でき ない 場合 に は 、 以下 設定 変更 を し て 下さい 。 \n\n 1 . Windwows キー ＋ R キー を 同時 押下 し 、 ファイル 名 を 指定 し て 実行 に 「 inetcpl . cpl 」 を 入力 し 、 Enter キー を 押下 する 。 \n 2 . インターネット の プロパティ 画面 が 表示 さ れ たら 、 詳細 設定 タブ を クリック し 、 【 HTTP   1.1 を 使用 する 】 に チェック を 入れる 。'},
#  {'id': '100026',
#   'title': '',
#   'text': 'ソリューション 販売 管理 システム （ イントラマート ） （ 物販 系 ） の 問合せ に つい て は 、 OA サポート デスク で は サポート 対象外 と なり ます 。 \n 下記 窓口 が 担当 か と 思わ れ ます の で 、 直接 問合せ 願い ます 。 \n\n ・ 仕入 販売 （ 開発 ・ 運転 担当 ） \n  SBTMGRP - SHIIRE - OP @ g . softbank .co.jp'},
#  {'id': '100027',
#   'title': '',
#   'text': 'Google の グループ アドレス の 不在 通知 設定 に つい て グループ アドレス に 不在 通知 を 設定 する こと は でき ませ ん 。 \n 不在 通知 は アカウント で の 設定 項目 と なり 、 グループ アドレス は アカウント と は 異なり ます の で 、 不在 通知 を 設定 する こと は でき ませ ん 。'},
#  {'id': '100028',
#   'title': '',
#   'text': 'Fruits   /   VoiceNet の 問合せ に つい て は 、 OA サポート デスク で は サポート 対象外 と なり ます 。 \n 下記 窓口 が 担当 か と 思わ れ ます の で 、 直接 問合せ 願い ます 。 \n\n ・ Ｆｒｕｉｔｓ ／ Ｖｏｉｃｅｎｅｔ 運転 担当   \n  sbtmgrp - unyou _ fruits @ g . softbank .co.jp'},
#  {'id': '100029',
#   'title': '',
#   'text': '業 端 へ の アプリ の 配信 や 提供 方法 に つい て は 、 下記 より 問合せ 下さい 。 \n ・ Web 投稿 \n\u3000 http:// oa . bb . local / oasupport / inquiry _ web \n\u3000 カテゴリ ： iPhoneiPad \n\u3000\u3000\u3000\u3000\u3000\u3000 Android'},
#  {'id': '100030',
#   'title': '',
#   'text': '「 この 不明 な 発行元 から の アプリ が PC に 変更 を 加える こと を 許可 し ます か ？ 」 が 表示 さ れ た 場合 、 管理者 権限 が 必要 と なり ます 。 \n\n 下記 ページ を 参照 し 、 Admin 権限 を 取得 し て 下さい 。 \n ・ 【 社内外 共通 】 L 2 OAPC / 準 OAPC   Admin 権限 申請 ・ 適用 方法 \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / admintekiyou _ shanaigai'},
#  {'id': '100031',
#   'title': '',
#   'text': '業 端 A   iPhone / iPad / Android で yellow に 接続 でき ない 場合 は 、 下記 FAQ を 参照 下さい 。 \n ■ iPhone / iPad \n ・ 【 iPhone / iPad 】 yellow に 繋がら ない [ FAQ   No : F 171201002 ] \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / keitai / faq _ list _ ios / f 171201002 \n ■ Android \n ・ 【 Android 】 yellow に 繋がら ない [ FAQ   No : F 190320001 ] \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / keitai / faq _ list _ android / f 190320001'},
#  {'id': '100032',
#   'title': '',
#   'text': 'Adobe   Reader の インストール ・ バージョン アップ 方法 に つい て は 、 下記 ページ を 参照 下さい 。 \n ・ Adobe   Reader インストール ・ バージョン アップ 手順 \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / AdobeReader _ setting \n\n PDF ファイル へ の アプリケーション 関連付け 方法 に つい て は 、 下記 手順 を 実施 下さい 。 \n 1 . スタート ＞ 設定 （ 歯車 マーク ） ＞ アプリ ＞ 既定 の アプリ \u3000 の 順 に 起動 する \n 2 . 既定 の アプリ の 選択 画面 で 一番 下 に ある 「 ファイル の 種類 ごと に 既定 の アプリ を 選ぶ 」 を クリック し 、 「 . pdf 」 の 項目 を クリック し 「 Adobe   Acrobat   Reader 」 を 選択 する'},
#  {'id': '100033',
#   'title': '',
#   'text': 'OA サポート デスク 貸出 の VGA 変換 アダプタ を 紛失 し た 場合 は 、 OA サポート デスク まで 問合せ 下さい 。 \n\n 社員 サポート センター （ ＯＡ サポート デスク ） ： 平日 9 : 00 ～ 18 : 00 \n ● Slack ： ＃ help - oa サポート （ チャンネル 名 で 検索 し て ください ） \n ● Ｗｅｂ 投稿 ： OA   Support   Navi   ＞   問合わせ   ＞   Web   http:// oa . bb . local / oasupport / inquiry _ web \n ● PC 受取 / 返却 ： OA   Support   Navi   ＞   問合わせ   ＞   PC 受取 / 返却   http:// oa . bb . local / oasupport / inquiry _ counter \n ● コール 予約 ： OA   Support   Navi   ＞   問合わせ   ＞   コール 予約 （ OA ）   http:// oa . bb . local / oasupport / oa - call - reservation'},
#  {'id': '100034',
#   'title': '',
#   'text': 'OAPC / 準 OAPC / Mac の 利用者 変更 に つい て は 、 下記 ページ を 参照 し て 下さい 。 \n\n ・ 利用者 を 変更 し たい \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / pc / tourokuhenkou \n ※ システム の 仕様 上 、 一括 利用者 変更 機能 は ござい ませ ん の で 、 1 台 ずつ 利用者 変更 申請 を 行っ て 下さい 。 \n ※ OA 化 し て い ない 部門 PC に つい て は 、 部門 で の 管理 と なり ます \n ※ 上長 承認 後 、 即時 で 反映 さ れ ます （ 社内 ネットワーク に は 上長 承認 完了 後 から 約 30 分 で 利用 可能 に なり ます ） \n\n 以下 に つい て は 、 利用者 変更 を 実施 し ない と 社内 ネットワーク へ 接続 でき なく なり ます 。 \n 必ず 利用者 変更 を 実施 し て 下さい 。 \n ・ 雇用 形態 が 変更 と なり 共通 社員 番号 が 変更 に なっ た 方 に 紐づい て いる OAPC および 準 OAPC \n ・ 退職 さ れ た 方 に 紐 付い て い た OAPC および 準 OAPC \n ・ 退職 さ れ た 方 に 紐 付い て い た OAPC および 準 OAPC を 新規 入場者 が 再利用 する 場合'},
#  {'id': '100035',
#   'title': '',
#   'text': '部門 管理 PC にて 外部 記録 媒体 を 使用 する 場合 は ライセンス 管理 システム で の USB 申請 は 不要 と なり ます 。'},
#  {'id': '100036',
#   'title': '',
#   'text': 'RDS ログイン 後 、 アイコン が 表示 さ れ ない 場合 は 、 利用 申請 が さ れ て おり ませ ん 。 \n\n RDS を 利用 する 場合 は 、 下記 フォーム より 申請 し て 下さい 。 \n ・ RDS 払い出し 申請 フォーム \n  https : / / docs . google . com / a / g . softbank .co.jp / forms / d / e / 1 FAIpQLSe 6 fVPdhMG - 4 DRCLgEzQlt - MZsyyGQ 34 bGh 55 bdzIErCR _ QPA / viewform \n ※ 払い出し が 完了 する と 申請者 に 対し て 、 メール 件名 ： 「 【 必読 】 RDS 環境 に 関する 重要 」 が 送付 さ れ ます'},
#  {'id': '100037',
#   'title': '',
#   'text': 'Office ファイル 起動 時 、 「 サブスクリプション の 有効 期限 が 切れ て い ます 。 」 が 表示 さ れ た 場合 は 下記 ページ を 参照 し 、 再 認証 を 実施 下さい 。 \n ・ 【 Office 365 】 Office 365 起動 時 に よく ある 認証 エラー \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / % 3 Fpost _ type % 3 Dpost % 26 p % 3 D 40418'},
#  {'id': '100038',
#   'title': '',
#   'text': '業 端 B の MySoftBank の 暗証 番号 は 下記 ページ を 参照 下さい 。 \n ・ 回線 停止 方法 \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / keitai / keitai - a / rule / rimotowaipu / linestop \n\u3000 （ 「 暗証 番号 」 参照 ） \n\n 記載 さ れ た 暗証 番号 で 認証 でき ない 場合 は は 下記 ページ を 参照 し 、 福岡 BizSupport へ 問合せ 下さい 。 \n ・ 業務用 携帯 電話 B の サービス 内容 変更 を し たい \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / keitai / keitai - b / information'},
#  {'id': '100039',
#   'title': '',
#   'text': '準 OAPC に つい て は 、 部門 で 購入 し 、 OA 化 し た もの と なり ます の で 、 OA 側 から の 貸与 は ござい ませ ん 。 \n \n  準 OAPC が 必要 な 場合 は 下記 を 参照 し 、 部署 で 端末 購入 後 、 OA 化 し て 下さい 。 \n ・ PC を 購入 し たい \n  http:// oa . bb . local / oasupport / pc / pc _ buy'},
#  {'id': '100040',
#   'title': '',
#   'text': '「 現在 ログオン 要求 を 処理 できる ログオン サーバー は あり ませ ん 。 」 また は 、 「 ドメイン が 利用 でき ない ため 、 この 資格 情報 で は サイン イン でき ませ ん 。 」 が 表示 さ れ た 場合 は 、 下記 を 確認 し て 下さい 。 \n \n ・ 端末 に L 2 の 有線 LAN は 接続 し て い ます か ？ \n ※ 情報 コンセント に は L 2 用 ・ L 3 Dev 用 が あり ます の で 、 ご 注意 下さい 。 \n ・ 無線 LAN   Blue に は 接続 し て い ます か ？ \n ・ LAN ケーブル を 交換 し て も ログイン 不可 か ？ \n ・ NW 接続 可能 な 他 の 端末 で 利用 し て いる LAN ケーブル を 利用 し て も 接続 不可 か ？ \n ※ OA カウンター で 端末 交換 し た 場合 、 交換 後 から 15 分 以上 経過 し ない と ログオン でき ませ ん 。 \n\n また 、 退職 さ れ た 方 の 端末 を 新規 入場者 が 利用 する 場合 は 、 利用者 変更 が 必要 と なり ます 。 \n 利用者 変更 に つい て は 、 下記 より 実施 し て 下さい 。 \n\n ・ Service   Catalog \n  http:// iotam . bb . local / OAService / catalog / pc \n （ 「 利用者 変更 」 から 申請 し て 下さい ） \n 利用者 変更 申請 完了 後 、 下記 件名 の メール が 旧 利用者 、 新 利用者 、 新 利用者 の 上長 宛 に 送付 さ れ ます 。 \n メール 件名 ： 【 申請 完了 】 利用者 変更   RA * * * * * * * * * * \n\n 申請 完了 後 、 約 15 分 後 に NW に 接続 可能 と なり ます 。 \n 15 分 後 も 接続 不可 の 場合 は 、 一度 、 端末 再起動 後 に 接続 を お 試し 下さい 。 \n\n 参考 FAQ \n ・ ログイン時 に 「 現在 ログオン 要求 を サービス する ログオン   サーバー が あり ませ ん 」 が 表示 さ れ ログイン が でき ない [ FAQ   No : F 190521001 ] \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / faq / f 190521001'},
#  {'id': '100041',
#   'title': '',
#   'text': '3 社 以上 と コネクト し て いる 共有 チャンネル から 特定 の 会社 のみ コネクト を 切り離し たい 場合 は 、 切り離し たい 会社 のみ を 記載 の 上 、 共有 チャンネル 停止 申請 を 実施 ください 。 \n\n ・ Slack 共有 チャンネル 停止 申請 \n https : / / docs . google . com / forms / d / e / 1 FAIpQLSfUh - HmNZzYIY 6 D _ zrpI 91 Q 1 oEh 3 G 2 FnUZpnjzWIsrtSpdgfw / viewform \n ※ SB ゲスト ・ ConnectWS で 利用 し て いる 共有 チャンネル の 場合 \n\n ・ SB   SlackConnect ( 特定 会社 専用 )   チャンネル 停止 申請 \n https : / / docs . google . com / forms / d / e / 1 FAIpQLSfO 1 cJ 2 I _ _ 8 UEpHMntPerYqKg 3 QO 1 aaWEX 9 b 6 IFiUvxtjzPIw / viewform \n ※ SB   SlackConnect ( 特定 会社 専用 )   WS で 利用 し て いる 共有 チャンネル の 場合'},
#  {'id': '100042',
#   'title': '',
#   'text': 'Office ソフト 修復 方法 に つい て は 、 下記 FAQ を 参照 し 、 Office の 再 インストール を 実施 し て 下さい 。 \n ・ Office の 再 インストール 方法 を 教え て 下さい [ FAQ   No : F 170922001 ] \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / faq / f 170922001'},
#  {'id': '100043',
#   'title': '',
#   'text': '※ 2021 / 11 / 25 より 正社員 以外 （ 販売 契約 社員 は 除く ） も Office 365 の 利用 が 可能 に なっ て い ます \n\u3000 詳細 に つい て は 下記 ページ を 参照 下さい \n\u3000 ・ 正社員 以外 の Office 365 利用 に つい て \n\u3000\u3000 http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / office 365 _ non - regularemployees \n\n 正社員 以外 の Office 利用 に つい て は 下記 ページ を 参照 下さい 。 \n ・ 正社員 以外 の Office 365 利用 に つい て \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / office 365 _ non - regularemployees \n\n 販売 契約 社員 に つい て は 下記 ページ を 参照 下さい 。 \n ・ 【 販売 契約 社員 】 Office 利用 方法 \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / setting / AzureRMS / windows / non _ regular'},
#  {'id': '100044',
#   'title': '',
#   'text': '退職時 の 共有 ドライブ 内 の ファイル に つい て は 、 下記 に アクセス し 、 右上 の 虫眼鏡 から 下記 文言 で 検索 下さい 。 \n ・ Q . 05 - 018 \u3000 退職時 、 共有 ドライブ 内 の ファイル は どう なり ます か ？ \n https : / / sites . google . com / a / g . softbank .co.jp / helpg / discussion - board / document / 05 - 018 \n ・ 05   -   Google ドライブ （ ドキュメント ） に 関する 質問   -   \n https : / / sites . google . com / a / g . softbank .co.jp / helpg / discussion - board / document'},
#  {'id': '100045',
#   'title': '',
#   'text': 'フォルダ 利用率 の 確認 方法 に つい て は 、 FALCON システム の 管理 フォルダ 一覧 画面 で フォルダ 名 検索 を 実行 する と 、 検索 結果 表示 画面 にて 、 フォルダ 利用率 が 表示 さ れ ます 。 \n ※ 利用率 は 毎日 AM 3 時 前後 時点 の 取得 情報 と なり ます 。 \n\n ・ FS フォルダ 作成 ・ 権限 管理 ／ FALCON \n  http:// falcon / \n\n 参考 FAQ \n ・ フォルダ 利用率 を 調べ たい [ FAQ   No : F 170626012 ] \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / faq / f 170626012'},
#  {'id': '100046',
#   'title': '',
#   'text': 'Mac また は 業務 端末 から シングル サイン オン （ SSO ） でき ない 場合 は 、 下記 FAQ を 参照 し て 下さい 。 \n\n ・ シングル サイン オン （ SSO ） の ログイン 画面 で 、 FAT 端末 から は ログイン できる の に Mac や 業務用 携帯 電話 から は ログイン でき ない ［ FAQ   No ： F 000200014 ］ \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / keitai / F 000200014'},
#  {'id': '100047',
#   'title': '',
#   'text': '開発 DaaS 利用 時 の マルチ ディスプレイ 表示 方法 に つい て は 、 下記 ページ を 参照 下さい 。 \n ・ 開発 DaaS 利用 時 の マルチ ディスプレイ 表示 方法 \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / l 3 dev _ multi - display'},
#  {'id': '100048',
#   'title': '',
#   'text': 'Zoom アカウント 自動 払出 対象者 は 以下 範囲 です 。 \n 所属 会社 ： SBKK \n 社員 区分 ：   役員 、 従業員 兼務 役員 、 執行 役員 （ 委任 型 ） 、 顧問 、 正社員 、 準社員 、 嘱託 、 特別 嘱託 、 契約 社員 、 特定 臨時 社員 、 受入 出向 社員 \n 本務 兼務 区分 ： SBKK 本務 （ SBKK 本務 のみ 対象 ） \n\n アカウント は 入社日 また は 発令日 の 翌日 まで に 払出 さ れ ます ( 申請 不要 )'},
#  {'id': '100049',
#   'title': '',
#   'text': '現在 、 OAMac 化 可能 な 対象 OS に つい て は 、 下記 ページ を 参照 し て 下さい 。 \n\n ・ OA 化 可能 な OS に つい て \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / mac / os - version'},
#  {'id': '100050',
#   'title': '',
#   'text': 'Gmail 上 で 下記 の メッセージ が 表示 さ れ た 場合 は 、 FAQ を 参照 し て 下さい 。 \n\n メッセージ \n 「 この メール に は ご 注意 下さい \u3000 ウィルス や 悪質 な リンク が 含ま れ て いる 可能性 が あり ます 」 \n 「 ウィルス の 警告   –   XX 個 の 添付 ファイル に ウィルス また は ブロック さ れ た ファイル が 含ま れ て い ます 」 \n\n ・ Gmail で ウイルス 検知 の メッセージ が 表示 さ れる [ FAQ   No : F 180529002 ] \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / faq / f 180529002'},
#  {'id': '100051',
#   'title': '',
#   'text': 'Admin 権限 申請 が 否認 さ れ た 場合 、 まず は 下記 を ご 確認 下さい 。 \n\n ・ Admin 権限 付与 時間 まで に 上長 の 承認 は 完了 し て い た か ？ \n ・ コンピューター 名 に OAPC （ CXOAPC ） / 準 OAPC （ CXIRPC ） 以外 の コンピューター 名 を 入力 し て い ない か ？ \n ・ コンピューター 名 に View の コンピューター 名 を 入力 し て い ない か ？ \n → 例 ： CXVIEW * * * * * * * * \n ・ 準 OAPC で インベントリ ファイル アップロード 直後 に Admin 権限 申請 を 行っ て い ない か ？ \n → インベントリ ファイル アップロード 直後 は PureTerminal 側 に 情報 が 登録 さ れ て い ない の で 、 申請 を 行う こと が でき ませ ん 。 \n\u3000 インベントリ ファイル アップロード し た 翌営業日 以降 に 申請 可能 と なり ます 。'},
#  {'id': '100052',
#   'title': '',
#   'text': 'FATPC 上 で 音声 が 出力 でき ない 場合 は 以下 手順 を 実施 し て 下さい 。 \n\n OAPC （ CXOAPC ～ ） の 場合 \n ■ スピーカー の 音量 設定 \n 1 . 画面 右下 の スピーカー アイコン を クリック する 。 \n 2 . 音量 を 調整 し 、 音声 が 出力 さ れる か 確認 する 。 \n\n ■ キーボード ・ ボタン 操作 で の 音声 出力 設定 \n\u3000 各 メーカー に より 異なり ます の で 、 下記 を 確認 し て 下さい 。 \n ・ Lenovo \n → キーボード Fn + F 1 キー 押下 もしくは F 1 キー 押下 で ON / OFF 設定 \n ※ 準 OAPC （ CXIRPC ～ ） の 場合 は 各 メーカー に 直接 確認 下さい \n\n ■ Web ブラウザ の 音声 が 出力 さ れ ない 場合 \n 1 . Windows キー + R キー 同時 押下 し ファイル 名 を 指定 し て 実行 を 起動 し て 「 inetcpl . cpl 」 を 入力 し 、 OK を クリック する 。 \n 2 . 詳細 設定 タブ を クリック し 、 マルチメディア の 項目 に ある 「 Web ページ の サウンド を 再生 する 」 に チェック を 入れ 、 OK を クリック する 。 \n\n ■ サウンド ドライバー 再 インストール \n\u3000 Admin 権限 を 取得 の 上 、 サウンド ドライバー を 再 インストール し て 下さい 。 \n ・ 【 社内外 共通 】 L 2 OAPC / 準 OAPC   Admin 権限 申請 ・ 適用 方法 \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / admintekiyou _ shanaigai \n  ドライバー ダウンロード 先 に つい て は 、 各 メーカー の ホームページ を 参照 し て 下さい 。 \n ・ Lenovo \n  https : / / support . lenovo . com / jp / ja / solutions / ht 100199 \n ※ 準 OAPC （ CXIRPC ～ ） の 場合 は 各 メーカー に 直接 確認 下さい \n\n 上記 手順 で 改善 し ない 場合 は 、 端末 交換 と なり ます の で 、 PC 管理 システム より 申請 し て 下さい 。 \n ・ 【 IoTAM 】 PC 交換 申請 方法 \n http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / pc _ exchange \n ※ 準 OAPC （ CXIRPC ～ ） の 場合 は 上記 手順 を 実施 し 、 改善 でき ない 場合 は 、 各 メーカー に 直接 確認 下さい'},
#  {'id': '100053',
#   'title': '',
#   'text': 'RDS の 利用 申請 方法 に つい て は 、 下記 フォーム より 申請 し て 下さい 。 \n\n ・ RDS 払い出し 申請 フォーム \n  https : / / docs . google . com / forms / d / e / 1 FAIpQLSe 6 fVPdhMG - 4 DRCLgEzQlt - MZsyyGQ 34 bGh 55 bdzIErCR _ QPA / viewform \n ※ 払い出し が 完了 する と 申請者 に 対し て 、 メール 件名 ： 「 【 必読 】 RDS 環境 に 関する 重要 」 が 送付 さ れ ます \n\n 参考 ページ \n ・ 貸出 ・ 返却 ・ 利用者 変更 \n （ Horizon   View （ 正社員 以外 ） ページ の こちら の リンク を 参照 下さい \u3000 を クリック ）'},
#  {'id': '100054',
#   'title': '',
#   'text': 'OAPC 等 を 利用 し 、 社外 ・ 自宅 から View を 利用 する 場合 は 、 下記 ページ を 参照 し て 下さい 。 \n ※ View の 利用 に は 事前 に Tarte にて 権限 申請 が 必要 と なり ます \n\u3000 未申請 の 場合 は 下記 ページ を 参照 し 、 申請 を 行っ て 下さい \u3000 \n\u3000 ・ Horizon   View \n\u3000\u3000 http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / setup / View \n\u3000\u3000 （ 上長 承認 の 翌日 以降 に 利用 可能 と なり ます ） \n\n ■ OAPC / 準 OAPC \n ・ View 接続 方法 （ OAPC   社外 接続 編 ） \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / % 3 Fpost _ type % 3 Dpost % 26 p % 3 D 22174 \n\n ■ OAPC / 準 OAPC 以外 \n ・ View 接続 方法 （ Windows   PC （ OAPC 以外 ） 編 ） \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / % 3 Fpost _ type % 3 Dpost % 26 p % 3 D 22175 \n\n ■ OAMac \n ・ View 接続 方法 （ Mac （ OAMac ） 編 ） \n  http:// oa . bb . local / oasupport / manual / mac - viewkankyou - kyoutsuuriyou \n\n ■ OAMac 以外 \n ・ View 接続 方法 （ Mac （ OAMac 以外 ） 編 ） \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / % 3 Fpost _ type % 3 Dpost % 26 p % 3 D 48797 \n\n ※ 社外 NW 自体 の 設定 ・ 接続 不具合 に つい て は 、 OA サポート 外 と なり ます 。'},
#  {'id': '100055',
#   'title': '',
#   'text': 'AzureRMS の アップグレード ツール （ AzureRMSCheck . vbs ） に つい て は 、 下記 に 格納 さ れ て おり ます の で 、 ダウンロード 後 、 デスクトップ 等 に 保存 し て から 実施 し て 下さい 。 \n https : / / drive . google . com / drive / folders / 1St 7 hIbiPsWO 5 vXkqn - IBoNXO 2 TgmTTe 8'},
#  {'id': '100056',
#   'title': '',
#   'text': '採用 Dr   （ 採用 ドクター ） の 問合せ に つい て は 、 OA サポート デスク で は サポート 対象外 と なり ます 。 \n 下記 窓口 が 担当 か と 思わ れ ます の で 、 直接 問合せ 願い ます 。 \n\n ・ クルー 採用 共有 \n  SBBGRP - salesstaffrecruitment @ g . softbank .co.jp'},
#  {'id': '100057',
#   'title': '',
#   'text': '「 メモリ エラー 」 が 表示 さ れ た 場合 は 、 下記 手順 で 事象 が 改善 する か 確認 し て 下さい 。   \n\n 【 OAPC ・ 準 OAPC 】   \n ■ Chrome の キャッシュ クリア \n ・ 【 Google Chrome 】 キャッシュ クリア 方法 \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / chrome _ clearcache \n ■ 不要 な ファイル 削除   \n 1 . 下記 に アクセス し 、 【 ローカル データ 削除 . bat 】 を コピー し 、 デスクトップ 等 に 保存 する \n\u3000 https : / / drive . google . com / drive / folders / 1 Clpw 778 o 4 MOo - Z 0 FVYEYIe 1 hUJ 3 aNU 3 h \n 2 . 【 ローカル データ 削除 . bat 】 を ダブル クリック する 。 （ コマンド プロンプト の 画面 が 一瞬 出力 さ れ ます ） \n 3 . ごみ箱 を 右 クリック し 、 「 ごみ箱 を 空 に する 」 を 実施 する \n\n 【 OAMac 】 \n ■ Chrome の キャッシュ クリア \n ・ 【 Google Chrome 】 キャッシュ クリア 方法 \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / chrome _ clearcache \n ※ 「 3 . 【 Mac 】 キャッシュ クリア （ 手動 ） 」 参照 \n\n 【 View 】 \n Chrome の キャッシュ クリア 後 、 View 環境 から サイン アウト し て 下さい 。 \n ・ 【 Google Chrome 】 キャッシュ クリア 方法 \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / chrome _ clearcache \n ・ View 環境 サイン アウト 手順 \n Windows マーク ＞ 人型 マーク に カーソル を 合わせ 、 「 サイン アウト 」 を クリック する \n ※ 「 切断 」 で は サイン アウト さ れ ない の で 、 必ず 上記 手順 を 実施 下さい'},
#  {'id': '100058',
#   'title': '',
#   'text': 'ブルー バック （ ブルー スクリーン ） ・ ホワイト アウト ・ ブラック アウト ・ フリーズ ・ 突然 の 電源 断 が 発生 する 場合 は 、 一度 、 電源 ボタン を 長押し 、 再度 、 電源 投入 後 、 症状 が 解消 する か 確認 し て 下さい 。 \n\n 参考 FAQ \n ・ 端末 が 固まる ・ 遅い 場合 の 対処 方法 を 知り たい ［ FAQ   No ： F 000200010 ］ \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / faq / F 000200010 \n ・ ThinkPadL 13 の PC で スリープ から の 復旧 時 に 強制 再起動 ・ ブルー バック が 発生 する ［ FAQ   No ： F 210527001 ］ \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / faq / f 210527001 \n\n 解消 し ない また は 頻発 する 場合 は 、 故障 と なり ます の で 、 以下 を 実施 下さい 。 \n ■ OAPC \n\u3000 端末 交換 を 実施 下さい 。 \n ・ 【 IoTAM 】 PC 交換 申請 方法 \n http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / pc _ exchange \n ■ 準 OAPC \n\u3000 端末 故障 と なり ます の で 、 下記 を 参照 し 、 対応 下さい 。 \n ・ 準 OAPC が 故障 し て しまっ た の で 、 修理 し たい [ FAQ   No : F 191105002 ] \n http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / faq / f 191105002'},
#  {'id': '100059',
#   'title': '',
#   'text': 'ネットワーク 管理 GIS の 問合せ先 に つい て は 、 OA サポート デスク で は サポート 対象外 と なり ます 。 \n 下記 窓口 が 担当 か と 思わ れ ます の で 、 直接 問合せ 願い ます 。 \n\n ・ ＮＷ 本部 情報 推進 室 ＧＩＳ 管理 \n  SBBGRP - GIS @ g . softbank .co.jp'},
#  {'id': '100060',
#   'title': '',
#   'text': '速度 制限 の 解除 方法 に つい て は 、 下記 を 参照 下さい 。 \n\n ■ 業 端 A \n 2021 年 10 月 現在 、 業 端 A で は 速度 制限 は 実施 し て おら ず 、 データ 容量 は 自動 追加 プラン と なっ て おり ます 。 \n\n ■ 業 端 B \n 制限 解除 方法 は 契約者 タイプ コード （ 契約 形態 ： 個人 ・ 法人 ・ 業務用 ） に より 、 方法 が 異なり ます 。 \n ・ 個人 ： My   SoftBank から の 手続き か 福岡 Biz へ の 依頼 \n ・ 法人 ： 法人 コンシェルサイト から の 手続き か 福岡 Biz へ の 依頼 \n ・ 業務用 ： My   SoftBank から の 手続き か 福岡 Biz へ の 依頼 \n 下記 ページ を 参照 し 、 手続き 下さい 。 \n ・ 法人 コンシェルサイト \n  https : / / portal . business . mb . softbank . jp / portal / BPS 0001 / ; jsessionid = Xh 1 qbFbMSmc 2 QsfmLSK 2 HKMSBJYLQvS 0 XL 4 p 76 sVYWVrdLYynnvW ! - 1848362821 \n ・ 業務用 携帯 電話 B の サービス 内容 変更 を し たい \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / keitai / keitai - b / information'},
#  {'id': '100061',
#   'title': '',
#   'text': 'プロジェクト フォルダ 管理者 を 追加 し たい が 、 管理者 追加 ボタン が 表示 さ れ ない 場合 、 管理者 が ３ 名 以上 に なっ て い ない か 確認 し て 下さい 。 \n 管理者 登録 は 最大 ３ 名 まで と なっ て おり ます 。 \n ３ 名 以上 の 登録 は 出来 ませ ん の で 、 どなた か 削除 し て 頂い た 後 、 登録 を お 願い し ます 。 \n\n 参考 FAQ \n ・ FALCON の 管理者 を 追加 し たい が 、 [ 管理者 追加 ] ボタン が 表示 さ れ ない [ FAQ   No : F 170626008 ] \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / faq / f 170626008'},
#  {'id': '100062',
#   'title': '',
#   'text': '共有 フォルダ 上 の ファイル が 読み取り 専用 に なる 場合 は 、 下記 情報 を 記載 の 上 、 OA   Support   Net に 投稿 し て 下さい 。 \n\n  < 提供 必須 情報 > \n ・ 対象 フォルダパス \n ・ PC ログイン OA アカウント （ エイリアス ） \n ・ 発生 時期 \n ・ 周り の ユーザ も 同じ 症状 か \n ・ OA 環境 （ FATPC / DaaS / HorizonView / OAMac ） \n ・ エラー 画面 の 画面 キャプチャ \n\n ・ Web 投稿 ： OA   Support   Navi   ＞   問合わせ   ＞   Web \n  http:// oa . bb . local / \n ※ カテゴリ ： system > Falcon / ファイル サーバ'},
#  {'id': '100063',
#   'title': '',
#   'text': '販売職 （ SV ） ・ 販売 契約 社員 の OAPC 貸出 ・ 交換 に つい て は 、 下記 を 確認 の 上 、 対応 し て 下さい 。 \n\n ■ 販売職 （ SV ） \n IoTAM 申請 方法 を 確認 し 、 OAPC の 貸出 ・ 交換 を 実施 下さい 。 \n\n ■ 販売 契約 社員 \n ・ ｶｽﾀﾏｰｹｱ ＆ ｵﾍﾟﾚｰｼｮﾝ 本部 以外 の 方 \n IoTAM より 交換 申請 を 実施 し て 下さい 。 \n ・ ｶｽﾀﾏｰｹｱ ＆ ｵﾍﾟﾚｰｼｮﾝ 本部 の 方 \n まず は 店長 ・ 副 店長 に ご 確認 頂き 、 その 上 で 、 店長 ・ 副 店長 より 各 窓口 に 連絡 し て 下さい 。 \n\n 【 IoTAM 申請 方法 】 \n ・ 【 IoTAM 】 PC 貸出 申請 方法 \n http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / pc _ lending \n\n ・ 【 IoTAM 】 PC 交換 申請 方法 \n http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / pc _ exchange \n\n PC の 利用 が 不要 に なっ た 場合 は 下記 ページ を 参照 し 、 返却 を 行っ て 下さい 。 \n ・ 返却 し たい \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / pc / step 3'},
#  {'id': '100064',
#   'title': '',
#   'text': 'インストール 兼 Admin 権限 付与 申請時 の インストーラ 保管 場所 に つい て 、 インストール 申請 の 承認 完了 メール に 記載 さ れ ます 。'},
#  {'id': '100065',
#   'title': '',
#   'text': '「 Microsoft   Online   Services   サイン イン   アシスタント は この コンピュータ に インストール さ れ て い ませ ん 。 管理者 に 問合せ て 下さい 。 」 の メッセージ が 表示 さ れ ファイル が 開け ない 場合 、 下記 FAQ を 実施 し て 下さい 。 \n ・ [ FAQ   No : F 170306001 ] AzureRMS 権限 を リフレッシュ する 手順 が 知り たい \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / faq / f 170306001 \n\n 上記 FAQ で 解消 でき ない 場合 は 下記 を 参照 し 、 Office 365 の 入れ直し を 実施 下さい 。 \n ・ Office の 再 インストール 方法 を 教え て 下さい [ FAQ   No : F 170922001 ] \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / faq / f 170922001 \n\n 参考 FAQ \n ・ [ FAQ   No : F 170704001 ] Office ファイル を 開く と メッセージ が 表示 さ れ ファイル が 開け ない \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / faq / f 170704001'},
#  {'id': '100066',
#   'title': '',
#   'text': 'インターネット 接続 が 出来 ない 場合 、 まず は 下記 を ご 確認 下さい 。 \n 【 ネットワーク 接続 状況 の 確認 】 \n ■ 社内 \n ・ 社内 有線 LAN また は 無線 LAN   blue に は 接続 でき て いる か ？ \n ■ 社外 \n ・ 社外 Wi-FI もしくは テザリング 接続 でき て いる か ？ \n\n 【 各種 サイト の アクセス 状況 】 \n ・ 社内 システム は アクセス 可能 か ？ \n ・ Gmail 、 外部 サイト （ Yahoo 、 Google 等 ） に アクセス 可能 か ？ \n \n Gmail 、 外部 サイト （ Yahoo 、 Google 等 ） に アクセス する に は Zscaler の 利用 が 必要 です 。 \n Zscaler に ログイン し て い なく 、 インターネット 接続 でき て い ない 場合 は 下記 を 実施 下さい 。 \n ■ OAPC   /   準 OAPC \n ・ 【 Windows 】 Zscaler   Client   Connector ログイン 方法 \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / zscaler _ login _ windows \n\n ■ OAMac \n ・ 【 Mac 】 Zscaler   Client   Connector ログイン 方法 \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / zscaler _ login _ mac \n\n 参考 FAQ \n ・ ネットワーク に は 接続 できる が 、 外部 Web サイト ・ Gmail に 接続 でき ない ［ FAQ   No ： F 000158884 ］ \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / faq / f 000158884'},
#  {'id': '100067',
#   'title': '',
#   'text': '業 端 B で 充電 が さ れ ない 場合 は 、 他 の ケーブル を 使用 し 、 充電 できる か 確認 下さい 。 \n\n ・ 他 の ケーブル で 充電 できる 場合 \n\u3000 ケーブル の 故障 と なり ます の で 、 手配 元 部署 に 交換 を 依頼 下さい 。 \n\n ・ 他 の ケーブル で も 充電 でき ない 場合 \n\u3000 端末 自体 の 故障 と なり ます の で 、 手配 元 部署 に 交換 を 依頼 下さい 。'},
#  {'id': '100068',
#   'title': '',
#   'text': 'L 3 Dev の ファイル サーバー 、 チャット システム 、 Proself 等 で 接続 不具合 が 発生 し た 場合 は 、 まず は 、 FAQ を 参照 し て 下さい 。 \n ・ Proself   FAQ \n  https : / / docs . google . com / spreadsheets / d / 1 P 7 iKCDlTe 8 rERv 3 oH 5 iDrxOv 782 TSF 144 vitLn 7 xdkc / edit # gid = 977654396 \n\n FAQ の 内容 で 解決 でき ない 場合 は 、 下記 ページ を 参照 し て 下さい 。 \n ・ L 3 Dev の ファイル サーバー 、 チャット システム 、 Proself に 繋がら ない \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / l 3 dev / l 3 devfcp'},
#  {'id': '100069',
#   'title': '',
#   'text': 'TAS 系   （ CrBS   /   CrBS - C   /   CrBS - T   /   DFCA   /   RTDA 2 - J   /   TAS - S   L 2   /   TAS - S   L 3   /   TAS - S   L 4   /   TeBiAs 社内 メンテ   /   TOMAS   /   BS - DR   /   RISM - BP ) ・ TASGRP ・ RTDAS 2 - J の 問合せ に つい て は 、 OA サポート デスク で は サポート 対象外 と なり ます 。 \n 下記 窓口 が 担当 か と 思わ れ ます の で 、 直接 問合せ 願い ます 。 \n\n ・ ＴＡＳ 運用 チーム ( SBTM   TASGRP 利用者 連絡 用 ) \n  SBTMGRP - tasadmin @ g . softbank .co.jp \n ・ ＴＡＳ 系 システム サポート   ( SBTM   TAS 系 システム の ユーザ から の 問合せ 用 アドレス ) \n  sbtmgrp - tassupport @ g . softbank .co.jp'},
#  {'id': '100070',
#   'title': '',
#   'text': '弁済 金 に つい て は 、 下記 ページ を 参照 下さい 。 \n ・ 弁済 金 に つい て \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / keitai / keitai - a / rule / bensai'},
#  {'id': '100071',
#   'title': '',
#   'text': 'OA 提供 外 の ソフトウェア を インストール し たい 場合 は 下記 ページ を 参照 し て 下さい 。 \n\n ・ OA 提供 外 の アプリ を インストール する \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / setting / AppOtherOaIns \n ・ ソフトウェア を インストール し たい \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / request / software / use \n ・ ライセンス 是正 対応 \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / request / correction \n ※ 各 ソフトウェア の インストール 方法 に つい て は 、 ソフトウェア の 提供 元 に 確認 し て 下さい \n\n なお 、 該当 の ソフトウェア を 利用 する 前 に 使用 禁止 ソフトウェア に 該当 し て い ない か 確認 下さい 。 \n ・ 禁止 ソフトウェア \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / request / software / use / confirmation / bansoft \n 通達 ： 禁止 ソフトウェア の 利用 規制 強化 に つい て \n  http:// sb - erp . bb . local / index . html # showCoverView ? next = views % 2 Fhrm % 2 Fbbs % 2 FBbsSearchView & params % 5 bbbsId % 5 d = NT 01300202313862 \n\n 参考 ： \n ソフトウェア インストール に つい て は 、 Admin 権限 が 必要 と なり ます 。 \n ・ 【 社内外 共通 】 L 2 OAPC / 準 OAPC   Admin 権限 申請 ・ 適用 方法 \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / admintekiyou _ shanaigai'},
#  {'id': '100072',
#   'title': '',
#   'text': 'OAPC の 自宅 ・ 社外 ネットワーク へ の 接続 方法 に つい て は 、 OA サポート 外 と なり ます 。 \n\n 自宅 ・ 社外 NW へ 接続 不可 の 場合 は 、 直接 社外 ネットワーク の 提供 元 に 確認 し て 下さい 。'},
#  {'id': '100073',
#   'title': '',
#   'text': 'OA 払い出し OAMac の 新規 ・ 一時 貸出 、 故障 / 希望 交換 に つい て は 、 提供 を 終了 致し まし た 。 \n ※ 参考 通達 \n ・ OAMac 提供 終了 の ご 案内 \n  http:// sb - erp . bb . local / index . html # showCoverView ? next = views % 2 Fhrm % 2 Fbbs % 2 FBbsSearchView & params % 5 bbbsId % 5 d = NT 01300201705917 \n\n 業務上 、 Mac を 利用 する 必要 が ある 場合 は 、 部門 にて Mac を 購入 し 、 OAMac 化 を 実施 し て 下さい 。 \n ・ Mac を 購入 し たい \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / mac / konyu \n ・ 部門 Mac の OAMac 化 手順 \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / mac / oamac - change \n\n OA 払い出し の OAMac （ コンピュータ 名 ： ISCMAC 130 ） を Windows の OAPC に 交換 し たい 場合 は 、 対象 端末 の コンピュータ 名 を 確認 の 上 、 下記 まで 問合せ 下さい 。 \n\n 社員 サポート センター （ ＯＡ サポート デスク ） ： 平日 9 : 00 ～ 18 : 00 \n ● Slack ： ＃ help - oa サポート （ チャンネル 名 で 検索 し て ください ） \n ● Ｗｅｂ 投稿 ： OA   Support   Navi   ＞   問合わせ   ＞   Web   http:// oa . bb . local / oasupport / inquiry _ web \n ● PC 受取 / 返却 ： OA   Support   Navi   ＞   問合わせ   ＞   PC 受取 / 返却   http:// oa . bb . local / oasupport / inquiry _ counter \n ● コール 予約 ： OA   Support   Navi   ＞   問合わせ   ＞   コール 予約 （ OA ）   http:// oa . bb . local / oasupport / oa - call - reservation'},
#  {'id': '100074',
#   'title': '',
#   'text': '開発 DaaS 環境 アクセス 時間 短縮 方法 に つい て は 、 下記 ページ を 参照 下さい 。 \n ・ 開発 DaaS 環境 アクセス 時間 短縮 方法 \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / l 3 dev _ daas - speedup'},
#  {'id': '100075',
#   'title': '',
#   'text': 'O & M の 問合せ に つい て は 、 OA サポート デスク で は サポート 対象外 と なり ます 。 \n 問合せ に つい て は 、 下記 ページ の フォーム より 問合せ 願い ます 。 \n\n ・ 統合 ヘルプ デスク \n  https : / / open - ui . biz / cms /'},
#  {'id': '100076',
#   'title': '',
#   'text': '全社員 宛 に Gmail を 送信 し たい 場合 は 、 下記 を 参照 下さい 。 \n ・ Q . 03 - 053 \u3000 Gmail で 全社員 宛て の メール を 送信 する 方法 を 教え て ください \n  https : / / sites . google . com / a / g . softbank .co.jp / helpg / discussion - board / gmail / 03 - 053'},
#  {'id': '100077',
#   'title': '',
#   'text': 'Gmail の 画面 左側 の 項目 を スクロール し 「 もっと 見る 」 を クリック し 、 その 中 の 「 ゴミ箱 」 に 対象 の メール が 残っ て いる か ご 確認 下さい 。 \n もし 、 ゴミ箱 から も 削除 さ れ て いる 場合 は 、 大変 申し訳 ござい ませ ん が 、 復元 する こと は でき ませ ん 。'},
#  {'id': '100078',
#   'title': '',
#   'text': 'CRM の 問合せ に つい て は 、 OA サポート デスク で は サポート 対象外 と なり ます 。 \n 下記 窓口 が 担当 か と 思わ れ ます の で 、 必要 情報 を 確認 の 上 、 直接 問合せ 願い ます 。 \n\n ■ 必要 情報   \n  ・ コンピューター 名 \n\n ・ CRM インフォ 運転 T \n  sbmgrp -- crminfo - unten @ g . softbank .co.jp'},
#  {'id': '100079',
#   'title': '',
#   'text': 'SBTM   OMS   作 スケ   （ サスケ ） の 問合せ に つい て は 、 OA サポート デスク で は サポート 対象外 と なり ます 。 \n 下記 窓口 が 担当 か と 思わ れ ます の で 、 直接 問合せ 願い ます 。 \n\n ・ 作 スケヘルプデスク （ ＣＳ 本部 ） \n  sbtmgrp - sasuke _ help @ g . softbank .co.jp \n ・ ＯＭＳ ・ 作 スケ （ 運用 ・ 開発 担当 ） \n  sbtmgrp - oms - wm @ g . softbank .co.jp'},
#  {'id': '100080',
#   'title': '',
#   'text': '以下 事象 で 正常 に SSO 認証 でき ない 場合 は Chrome の キャッシュ クリア を 実施 下さい 。 \n ・ SSO 認証 画面 が 表示 さ れ ない \n ・ 「 情報 ログイン し まし た 」 が 表示 さ れる \n ・ 「 不正 な ハンドラ に よる 認証 の 例外 」 が 表示 さ れる \n ・ 「 Error 403 -- Forbidden 」 が 表示 さ れる \n ・ 再度 認証 画面 に 戻っ て しまう \n\n ■ Chrome の キャッシュ クリア \n 1 . Google Chrome の 画面 で 、 「 Ctrl 」 + 「 Shift 」 + 「 Del 」 キー を 押下 \n 2 . 「 期間 」 で 「 全 期間 」 を 選択 \n  次 の 項目 に チェック が 入っ て いる こと を 確認 し 、 データ を 削除 する \n ・ 閲覧 履歴 \n ・ Cookie   と 他 の サイト   データ \n ・ キャッシュ さ れ た 画像 と ファイル \n 3 ． Google Chrome を 再起動 \n ※ 「 × 」 ボタン で は なく 、 Google Chrome の 画面 右上 の 3 つ の 点 が 縦 に 並ん だ マーク を クリック → 「 終了 」 で 閉じ た 後 、 再度 立上げ 、 再 ログイン を お 願い いたし ます \n\n Chrome キャッシュ クリア 後 も SSO 認証 画面 が 表示 さ れ ない 場合 は 、 ログオン しよう と し て いる OA アカウント （ エイリアス ） を 確認 の 上 、 担当 部署 に エスカレーション 致し ます の で 、 OA サポート デスク へ 問合せ 下さい 。 \n\n 社員 サポート センター （ ＯＡ サポート デスク ） ： 平日 9 : 00 ～ 18 : 00 \n ● Slack ： ＃ help - oa サポート （ チャンネル 名 で 検索 し て ください ） \n ● Ｗｅｂ 投稿 ： OA   Support   Navi   ＞   問合わせ   ＞   Web   http:// oa . bb . local / oasupport / inquiry _ web \n ● PC 受取 / 返却 ： OA   Support   Navi   ＞   問合わせ   ＞   PC 受取 / 返却   http:// oa . bb . local / oasupport / inquiry _ counter \n ● コール 予約 ： OA   Support   Navi   ＞   問合わせ   ＞   コール 予約 （ OA ）   http:// oa . bb . local / oasupport / oa - call - reservation'},
#  {'id': '100081',
#   'title': '',
#   'text': '準 OAPC の 主管部 変更 は 、 Pure   Terminal の 「 利用者 変更 」 で 新た な 部署 の 管理者 へ 変更 し ます 。 \n \n ・ 【 IoTAM 】 PC 利用者 変更 申請 方法 \n http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / pc / userchange \n 利用者 変更 申請 完了 後 、 下記 件名 の メール が 旧 利用者 、 新 利用者 、 新 利用者 の 上長 宛 に 送付 さ れ ます 。 \n メール 件名 ： 【 申請 完了 】 利用者 変更   RA * * * * * * * * * * \n ※ 利用者 変更 する 準 OAPC で OASYS 利用 し て いる 場合 は 下記 ページ を 参照 し 、 利用 権限 の 削除 を 実施 下さい \n\u3000 ・ OASYS 利用 申請 削除 方法 \n\u3000\u3000 http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / % 3 Fpost _ type % 3 Dpost % 26 p % 3 D3 3156'},
#  {'id': '100082',
#   'title': '',
#   'text': 'Zoom アカウント 自動 払出 また は Tarte 申請 に よる 有料 アカウント 払出 の 方 が ホスト の 場合 、 Zoom ミーティング の 制限 時間 は あり ませ ん 。 \n ※ 24 時間 で タイム アウト する 仕様 です \n Tarte 申請 に よる 無料 アカウント 払出 の 方 が ホスト の 場合 、 40 分 の 制限 時間 が あり ます 。'},
#  {'id': '100083',
#   'title': '',
# ...
#  {'id': '100971',
#   'title': '',
#   'text': '業 端 A の USIM を 他 の 端末 に 差替え て 利用 する こと は 禁止 し て おり ます 。 \n ・ 使用 上 の ルール ・ 規程 （ 全般 ） \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / keitai / keitai - a / rule / kitei'},
#  {'id': '100972',
#   'title': '',
#   'text': '他社 キャリア の 業 端 B 解約 は IoTAM で は でき ませ ん の で 下記 ドキュメント を 確認 下さい 。 \n ・ 【 IoTAM 】 業務用 携帯 B   操作 マニュアル （ ユーザー 展開 用 ） \n  https : / / docs . google . com / presentation / d / 1 - cjNwei 93 iZgDuexh 6 h 6 tzc 6 gFzdHH 3 EQS 3 Xljlwq 1 g / edit # slide = id . p \n 参考 ページ \n ・ 他 キャリア 手配 （ docomo ・ au ・ その 他 ） \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / keitai / keitai - b / arrangement / othercarriers \n\n また 、 IoTAM から 情報 削除 する 為 に は 解約 ・ 廃棄 申請 は 必要 です 。 \n 回線 解約 手続き 完了 後 、 IoTAM より 解約 ・ 廃棄 申請 を 上げ て 下さい 。'},
#  {'id': '100973',
#   'title': '',
#   'text': '不明 ・ SIM なし ・ 圏外 の 表示 と なり 、 回線 に 不具合 が 発生 し て いる 場合 、 まず は 以下 を お 試し 下さい 。 \n ・ 電源 OFF / ON \n ・ SIM カード の 抜き差し \n ・ 設定 ＞ モバイル 通信 ＞ モバイル データ 通信 の OFF / ON \n\n 解消 さ れ ない 場合 は 、 下記 で 対応 下さい \n\n 【 「 不明 」 表示 】 \n ■ 業 端 A \n 共通 社員 番号 、 氏名 、 IMEI 、 ICCID を 確認 の 上 、 Web 投稿 し て 下さい 。 \n ・ Web 投稿 \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / inquiry _ web \n カテゴリ ： iPhoneiPad > 業務用 携帯 管理 システム （ IoTAM ） \n                   Android > 業務用 携帯 管理 システム （ IoTAM ） \n ■ 業 端 B \n 部門 にて OTA 再 配信 を 依頼 下さい 。 \n ・ 業務用 携帯 電話 B の サービス 内容 変更 を し たい \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / keitai / keitai - b / information \n\n 【 「 SIM なし 」 「 圏外 」 表示 】 \n ■ 業 端 A \n USIM ・ 端末 不具合 を 切り分け 、 IoTAM より 故障 交換 申請 を 行っ て 下さい 。 \n ・ IoTAM 故障 交換 申請 （ 業 端 A ） \n http:// iotam . bb . local / OAService / catalog / gtaMenu \n ・ 業 端 A _ IoTAM 操作 マニュアル \n https : / / docs . google . com / document / d / 1 CKtnPkW 0 IEIfVfMjZksNXC 8470 PgO 4 lRJaViTtQ _ tT 0 / edit # bookmark = kix . pidy 15 flbgu 2 \n ■ 業 端 B \n USIM ・ 端末 不具合 を 切り分け 、 部門 にて 修理 等 の ご 対応 を お 願い いたし ます 。'},
#  {'id': '100974',
#   'title': '',
#   'text': '転送 設定 ・ 解除 方法 に つい て は 下記 を 参照 下さい 。 \n\n 【 業 端 A 】 \n MySoftBank から 転送 設定 ・ 転送 解除 が 可能 と なり ます 。 \n ・ MySoftbank \n  https : / / www . softbank . jp / mysoftbank / \n ※ 業 端 A から 個人 携帯 電話 へ の 転送 設定 は セキュリティ 上 、 NG と なっ て おり ます \n\u3000 固定 電話 もしくは 部門 手配 の 業 端 B へ の 転送 でし たら 可能 と なり ます \n\n MySoftBank の パスワード が わから ない 場合 は 、 Web 投稿 し て 下さい 。 \n\n 【 業 端 B 】 \n 転送 設定 ・ 解除 方法 に つい て は 部門内 で 確認 下さい 。'},
#  {'id': '100975',
#   'title': '',
#   'text': 'OAPC の 交換 に つい て は 、 まず は 下記 ページ を 参照 し て 下さい 。 \n ・ OAPC 故障 切り分け 方法 \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / pc / kosyou \n\n 上記 切り分け 後 、 交換 が 必要 な 場合 は 下記 ページ を 参照 の 上 、 交換 申請 を 実施 下さい 。 \n ・ 【 IoTAM 】 PC 交換 申請 方法 \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / pc _ exchange \n ※ 修理 に つい て は 、 承っ て おり ませ ん 。 すべて 交換 対応 と なり ます 。 \n ※ 準 OAPC （ CXIRPC ） 、 OAMac （ ISCMAC 130 / ISCMAC 131 / COAMAC ） は 対象外 です 。 \n ※ 故障 ・ 不具合 で のみ 交換 可能 と なり ます \n\u3000 特定 の 機種 や 高スペック 端末 へ の 希望 交換 に つい て は 、 交換 不可 と なり ます \n ※ コンピューター 名 の 確認 に つい て は 、 天板 右上 に 貼付 さ れ て いる 白い テプラ の コンピューター 名 を 記載 し て 下さい 。 \n ※ 交換 元 端末 の AC アダプタ ・ VGA アダプタ 等 の 備品 も 端末 と 一緒 に 返却 し て 下さい \n ※ 本社 以外 の 発送 に つい て は 、 SB 拠点 のみ 可能 と なり ます \n ※ 送付先 に 変更 が ある 場合 は 、 OA サポート デスク まで 問合せ 下さい \n ※ 交換 PC で OASYS 利用 し ない 場合 は 、 下記 ページ を 参照 し 、 返却 PC の 利用 権限 の 削除 を 実施 下さい \n\u3000 ・ OASYS 利用 申請 削除 方法 \n\u3000\u3000 http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / % 3 Fpost _ type % 3 Dpost % 26 p % 3 D3 3156 \n\n 社員 サポート センター （ ＯＡ サポート デスク ） ： 平日 9 : 00 ～ 18 : 00 \n ● Slack ： ＃ help - oa サポート （ チャンネル 名 で 検索 し て ください ） \n ● Ｗｅｂ 投稿 ： OA   Support   Navi   ＞   問合わせ   ＞   Web   http:// oa . bb . local / oasupport / inquiry _ web \n ● PC 受取 / 返却 ： OA   Support   Navi   ＞   問合わせ   ＞   PC 受取 / 返却   http:// oa . bb . local / oasupport / inquiry _ counter \n ● コール 予約 ： OA   Support   Navi   ＞   問合わせ   ＞   コール 予約 （ OA ）   http:// oa . bb . local / oasupport / oa - call - reservation'},
#  {'id': '100976',
#   'title': '',
#   'text': 'スマホ AD ・ スマホ フレンド から よく ある 問合せ は 、 下記 を 参照 下さい 。 \n ・ Q&A 一覧 （ 業 端 B 関連 ） \n https : / / goo . gl / YWjS 3 o \n ※ OA サポート デスク に 問合せ 頂い て も 、 サポート 対象外 と なり ます'},
#  {'id': '100977',
#   'title': '',
#   'text': '「 未 検証 の プロファイルサイバートラストプロファイルサービス の 真正性 を 確認 でき ませ ん でし た 。 ファイル を インストール でき ませ ん でし た 。 」 が 表示 さ れ た 場合 は 、 下記 を 確認 下さい 。 \n  ■ 確認 事項 \n  ・ コモン ネーム と 端末 の IMEI が 一致 し て いる メール を ご利用 し て い ます か ？ \n  ・ 設定 メール を 端末 上 で 開き リンク を タップ し て い ます か ？'},
#  {'id': '100978',
#   'title': '',
#   'text': '販売職 の 業 端 B   iPhone / iPad / Android で の Gmail ・ VPN の 利用 等 に つい て は 、 下記 フォーム より 問合せ し て 下さい 。 \n \n ・ 【 業 端 B 】 お 問合せ フォーム \n  https : / / docs . google . com / a / g . softbank .co.jp / forms / d / e / 1 FAIpQLSf _ sv 6 KJ 3 Ic 8 QEDUZRDR 6 UVEhMhB 3 t 1 Pg 57 Wl 93 a 5 Fp 9 Pwq 9 g / viewform ? c = 0 & w = 1'},
#  {'id': '100979',
#   'title': '',
#   'text': '統合 マスタ WEB の 問合せ に つい て は 、 OA サポート デスク で は サポート 対象外 と なり ます 。 \n 下記 窓口 が 担当 か と 思わ れ ます の で 、 直接 問合せ 願い ます 。 \n\n ・ 代理店 マスタ 運用 （ 営業 推進 本部 ） \n  sbmgrp - master - info @ g . softbank .co.jp'},
#  {'id': '100980',
#   'title': '',
#   'text': 'Slack アカウント の 提供 範囲 に つい て は 下記 と なり ます 。 \n\n ■ 自動 払い出し 対象者 \n 所属 会社 ： SBKK \n 社員 区分 ：   役員 、 従業員 兼務 役員 、 執行 役員 （ 委任 型 ） 、 顧問 、 正社員 、 準社員 、 嘱託 、 特別 嘱託 、 契約 社員 、 受入 出向 社員 、 販売 契約 社員 、 特定 臨時 社員 \n ※ C & S が 本務 の 場合 は 対象外 \n\n ■ 自動 払い出し 非対象者 （ 特定 社員 ） \n 所属 会社 ： SBKK \n 社員 区分 ： アルバイト 、 派遣 社員 、 業務 委託 、 非 社員 \n 特定 社員 で Slack 利用 が 必要 な 場合 は Tarte より 申請 下さい 。 \n ・ Tarte \n http:// portal . tarte . bb . local / Tarte / tarteMain \n ※ 「 システム 権限 申請 」 の 「 Slack 」 を 検索 し て 申請 下さい \n 申請前 に 必ず 下記 と 注意 事項 を 確認 し て 下さい 。 \n ・ 【 Slack 】   特定 社員 利用 開始 \n  https : / / docs . google . com / presentation / d / 1 rgLsB 7 eacZgzWp 39 _ g 2 wSWYfldfo 1 lFMIYHKRc - befA / edit # slide = id . ga 28 c 8 ec 33 d _ 8 _ 0 \n ＜ 注意 事項 ＞ \n ・ 「 @ g . softbank .co.jp 」 の メール アドレス を 保持 し て いる こと が 必須 です \n ・ 社外 送信 不可 の 場合 、 特定 社員 専用 WS に のみ 招待 さ れ ます ( ゲスト WS に は 招待 さ れ ませ ん ) \n ・ 上長 承認 さ れ た 申請 のみ 処理 さ れ ます \n\n\n ■ 社外 ユーザー の 方 \n ゲスト と し て 招待 可能 と なり ます 。 \n 詳細 に つい て は 、 下記 を 参照 下さい 。 \n ・ 【 Slack 】   ゲスト 利用 開始 \n  https : / / docs . google . com / presentation / d / 1 yRbSx - 831 z 7 OzR 7 nofqRzjDCvZWmZGue 8 YJQx 5 wq 7 cQ / edit # slide = id . ga 28 c 8 ec 33 d _ 8 _ 0 \n\n 問合せ に つい て は 、 下記 より お 願い し ます 。 \n ・ OA   Support   Net \n  http:// oa . bb . local / oasupport / inquiry _ web \n\u3000 （ カテゴリ ： Slack ） \n\n 【 注意 】 \n Slack アカウント に つい て は メーリング リスト で の 登録 不可 と なり ます'},
#  {'id': '100981',
#   'title': '',
#   'text': '迷惑 メール および 不審 な メール を 受信 し た 場合 は 、 下記 FAQ を 参照 下さい 。 \n ・ 迷惑 メール また は 不審 な メール を 受信 し て しまっ た [ FAQ   No : F 191021001 ] \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / faq / f 191021001'},
#  {'id': '100982',
#   'title': '',
#   'text': '組織 フォルダ の 仕様 に つい て は 、 下記 を 参照 し て 下さい 。 \n\n 【 ネーミング ルール 】 \n \\ \\ bbwcfs . local \\ Share * * \\ DATA * \\ ShareOrg \\ SBB \\ SBB _ ( 組織 番号 ) _ ( 組織名 ) \n \\ \\ bbwcfs . local \\ Share * * \\ DATA * \\ ShareOrg \\ SBM \\ SBM _ ( 組織 番号 ) _ ( 組織名 ) \n \\ \\ bbwcfs . local \\ Share * * \\ DATA * \\ ShareOrg \\ SBTM \\ SBTM _ ( 組織 番号 ) _ ( 組織名 ) \n\n 【 作成 段階 の アクセス権 に つい て 】 \n 当該 フォルダ は 、 作成 段階 で 組織 に 所属 し て いる メンバー に 対し て のみ 、 アクセス権 が 自動的 に 付与 さ れ ます 。 \n ※ 「 メンバ 一覧 」 に は 表示 さ れ ませ ん 。 \n また 、 アクセス権 は その 組織 の 会社 の OA アカウント （ エイリアス ） に 付与 さ れ ます 。 \n ※ SBM 組織 部署 は SBM の OA アカウント （ エイリアス ） 、 SBB 組織 部署 は SBB の OA アカウント （ エイリアス ）   等 \n\n 【 他 組織 の メンバ 追加 方法 】 \n 個別 の メンバ 追加 に つき まし ては 、 下記 2 通り ござい ます 。 \n 1 ． フォルダ 管理者 の 方 にて 個別 に メンバ 追加 申請 を 行う 。 \n ※ 初期 構成 で は 組織 の 上長 が フォルダ 管理者 と なっ て おり ます 。 \n 2 ． 他 組織 の 方 にて 、 FALCON に ログイン 頂き 、 \n\u3000 アクセス 対象 フォルダ の 検索 後 、 アクセス権 申請 を 行い 、 \n\u3000 申請 を う 受け た フォルダ 管理者 にて 承認 後 、 アクセス権 付与 。 \n ※ 初期 構成 で は 組織 の 上長 へ 申請 さ れ ます 。 \n ※ ここ で の 他 組織 は 、 組織 の 所属 部署 に 属さ ない メンバー を 指し ます 。 \n ※ 兼務 者 で SBM の OA アカウント （ エイリアス ） が 組織 の 所属 部署 の メンバ の 場合 、 \n\u3000 他 OA アカウント （ エイリアス ） （ SBB ・ SBTM 等 ） で あっ て も アクセス権 申請 は でき ませ ん 。 \n\n 【 初期 フォルダ 管理者 ならび に 管理者 追加 に つい て 】 \n 初期 状態 で は 、 所属 組織 の 上長 が 管理者 と し て 設定 さ れ て おり ます の で 、 FALCON 上 で 上長 の 方 に 管理者 追加 を 行っ て 頂き ます 様 お願い 致し ます 。 \n ※ 組織 の 所属 部署 の メンバー および 配下 組織 の 上長 のみ 、 管理者 と し て 追加 可能 \n ※ （ 例 ） 部 フォルダ で あれ ば 配下 組織 の 課長 等 \n\n 【 フォルダ 管理者 の 確認 方法 】 \n フォルダ 管理者 を 確認 する に は 、 FALCON に 該当 組織 の OA アカウント （ エイリアス ） にて ログイン する こと で 、 確認 が 可能 です 。 \n 「 組織 フォルダ 一覧 」 ＞ 対象 組織 の 「 詳細 」 を クリック ＞ 「 管理者 一覧 」'},
#  {'id': '100983',
#   'title': '',
#   'text': '自身 の OA アカウント （ エイリアス ） が ロック さ れ た 場合 は 、 下記 ページ を 参照 し 、 パスワード リセット を 実施 下さい 。 \n ※ 自身 以外 の OA アカウント （ エイリアス ） が ロック さ れ た 場合 も 同様 です \n ・ OA アカウント （ エイリアス ） の パスワード を 変更 し たい \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / pc / password \n\n ※ 注意 ※ \n SBC & S の OA アカウント （ エイリアス ） に つい て は 、 パスワード リセット 対象外 と なり ます の で 、 下記 ページ を 参照 し て 下さい 。 \n ・ C&S   Portal \n\u3000 https : / / portal . bb . local / oa / \n ※ サイト アクセス 時 に 「 この 接続 で は プライバシー が 保護 さ れ ませ ん 」 が 表示 さ れ た 場合 は 下記 SSB   C&S   サービス デスク に 問合せ 下さい \n ・ SB C&S   サービス デスク \n  https : / / softbankcs . service - now . com / csqa ? id = casoa _ index'},
#  {'id': '100984',
#   'title': '',
#   'text': 'セキュリティ ソフト に つい て は 下記 FAQ を 参照 下さい 。 \n ・ 【 セキュリティ ソフト 】 FAQ \n  https : / / docs . google . com / spreadsheets / d / 1 zz 48 M _ hYa 0 PbxtUGlFdVAvXxBUVK 8 E 12 yI 5 UGp - A 0 Hc / edit # gid = 0'},
#  {'id': '100985',
#   'title': '',
#   'text': 'AzureRMS の 対応 を 行っ て い ない と 暗号化 さ れ た ファイル が 開け ませ ん 。'},
#  {'id': '100986',
#   'title': '',
#   'text': '誤っ た コンピューター 名 で インベントリ ファイル を アップロード し て しまっ た 場合 は 、 再度 、 端末 側 の コンピューター 名 を 修正 し 、 アップロード を し なおし て 下さい 。 \n すでに ドメイン 参加 を 実施 し て しまっ て いる 場合 は 、 端末 初期化 後 、 再度 、 準 OAPC 化 を 実施 し て 下さい 。 \n\n なお 、 誤っ た コンピュータ 名 で ドメイン 参加 し て いる 場合 は 、 対象 の コンピュータ 名 を 下記 まで お 知ら せ 下さい 。 \n ・ Web 投稿 \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / inquiry _ web \n\u3000 （ カテゴリ ： PC ）'},
#  {'id': '100987',
#   'title': '',
#   'text': 'VSOC - VPN に つい て は 無線 （ blue ） で の 接続 が 前提 に なり ます 。 \n ご自身 の OAPC で blue に 接続 し て から VPN を 利用 いただく よう お 願い し ます 。 \n\n 下記 ページ を 参照 し 、 無線 LAN （ blue ） へ の 接続 を 実施 し て 下さい 。 \n ・ Blue \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / setting / blue \n\n VSOC に 関する 問合せ に つい て は 、 下記 を 参照 下さい 。 \n ・ VSOC （ SOC ） 案内 \n https : / / open - ui . biz / cms / vsoc   \n ・ VSOC ｜ FAQ \n https : / / open - ui . biz / cms / vsoc / faq / \n ・ 問合せ先 \n https : / / open - ui . biz / cms / vsoc / contact / \n ※ OA サポート に 問合せ いただい て も 回答 でき かね ます'},
#  {'id': '100988',
#   'title': '',
#   'text': 'プリンタ 設定 方法 に つい て は 、 下記 ページ を 参照 し て 下さい 。 \n ・ 複合機（プリンタ） 設定 \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / pc / printer \n\n ■ MPC 6003   SPF （ リコー 株式 会社 製 ） \n ・ 【 Ricoh 】 プリンタ 利用 マニュアル （ OAPC / 準 OAPC ） \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / pc / printer _ ricoh \n\n ■ ゼロックス （ ApeosPort - V   C 6676   PFS - PC ） \n ・ 【 Xerox 】 プリンタ 利用 マニュアル （ OAPC / 準 OAPC ） \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / pc / printer _ xerox'},
#  {'id': '100989',
#   'title': '',
#   'text': '周辺 機器 一時 貸出 ・ 交換 依頼 フォーム から 申請後 、 キャンセル し たい 場合 は 、 OA サポート デスク に 下記 情報 を 提供 し て 下さい 。 \n\n 申請 番号 ： BHN - * * * * \n ※ メール 件名 ： [ 周辺 機器 交換 ]   【 申請 番号 : BHN - * * * * 】   周辺 機器 準備 完了 の お知らせ \u3000 参照 \n 申請者 共通 社員 番号 ： \n 申請者 氏名 ： \n\n 社員 サポート センター （ ＯＡ サポート デスク ） ： 平日 9 : 00 ～ 18 : 00 \n ● Slack ： ＃ help - oa サポート （ チャンネル 名 で 検索 し て ください ） \n ● Ｗｅｂ 投稿 ： OA   Support   Navi   ＞   問合わせ   ＞   Web   http:// oa . bb . local / oasupport / inquiry _ web \n ● PC 受取 / 返却 ： OA   Support   Navi   ＞   問合わせ   ＞   PC 受取 / 返却   http:// oa . bb . local / oasupport / inquiry _ counter \n ● コール 予約 ： OA   Support   Navi   ＞   問合わせ   ＞   コール 予約 （ OA ）   http:// oa . bb . local / oasupport / oa - call - reservation'},
#  {'id': '100990',
#   'title': '',
#   'text': '業 端 A で は 速度 制限 は 実施 し て おら ず 、 データ 容量 は 自動 追加 プラン と なっ て おり ます 。'},
#  {'id': '100991',
#   'title': '',
#   'text': 'InfoBarrier 監視 アラート メッセージ の ポップ アップ が 表示 さ れ た 場合 は 、 社内 ネットワーク に 接続 し た 状態 で 下記 手順 を 実施 し て 下さい 。   \n 社内 ： L 2 有線 LAN また は 無線 LAN   blue \n 社外 ： OASYS   VPN 接続 \n \n  ＜ 手順 ＞   \n  「 隠れ て いる インジケーター を 表示 し ます （ ▲ ） 」 を クリック ＞ InfoBarrier アイコン （ 上下 矢印 の 赤い アイコン ） を 右 クリック し 、 「 最新 の 情報 に 更新 」 を 実施 し 、 しばらく （ 2 ～ 3 日 程度 ） 放置 する'},
#  {'id': '100992',
#   'title': '',
#   'text': 'GoogleChrome で パスワード を 自動 入力 ・ 保存 し たい 場合 は 、 下記 ページ を 参照 し て 下さい 。 \n\n ・ パスワード を 管理 する \n  https : / / support . google . com / chrome / answer / 95606 ? co = GENIE . Platform % 3 DDesktop & hl = ja'},
#  {'id': '100993',
#   'title': '',
#   'text': 'L 2 環境 で 作成 し た 暗号化 さ れ た ファイル を L 3 環境 で 開き たい 場合 は 、 事前 に 送付 元 の L 2 環境 上 で 暗号化 を 解除 し て から 、 L 3 環境 で 開い て 下さい 。 \n\n ・ 暗号化 ファイル の 解除 \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / setting / AzureRMS / rights / unlock \n\n L 3 環境 上 で の 暗号化 施策 に つい て は 、 OA サポート 外 と なり ます の で 、 下記 より 問合せ 下さい 。 \n ・ Web 投稿 \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / inquiry _ web \n\u3000 （ カテゴリ ： other   >   CCOC 系 統合 端末 ）'},
#  {'id': '100994',
#   'title': '',
#   'text': '画面 下部 に ある 「 OneNote   と 共 に 起動 」 の チェック を 外し て 、 「 終了 」 を クリック し て 下さい 。'},
#  {'id': '100995',
#   'title': '',
#   'text': '総務部 配備 以外 の プリンタ を 利用 する 場合 は 、 Admin 権限 を 取得 し た 上 で ドライバー インストール が 必要 と なり ます 。 \n\n ・ 【 社内外 共通 】 L 2 OAPC / 準 OAPC   Admin 権限 申請 ・ 適用 方法 \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / admintekiyou _ shanaigai \n\n なお 、 総務部 配備 以外 の プリンタ 設定 方法 に つい て は 、 OA サポート 外 と なり ます の で 、 プリンタ の メーカー に 直接 お 問合せ 下さい 。'},
#  {'id': '100996',
#   'title': '',
#   'text': 'OA 共有 アカウント は 原則 禁止 と なっ て おり 、 大型 モニタ で の 情報 共有 等 限ら れ た 用途 のみ 発行 可能 です 。 \n 発行 が 必要 な 場合 は 、 下記 より 相談 下さい 。 \n ・ ISC 相談 ガイド \n  https : / / sites . google . com / g . softbank .co.jp / sp - usersguide / isc _ form \n\n ISC の 承認 完了 後 、 以下 必要 事項 を 揃え た 上 で OA   Support   Net より 投稿 下さい 。 \n ・ OA   Support   Net \n  http:// oa . bb . local / oasupport / inquiry _ web \n\u3000 （ カテゴリ ： OA アカウント ） \n 【 必要 事項 】 \n ・ ISC 相談 番号 \n ・ 相談者（ユーザー） \n ・ ISC 相談 時 の 内容 の 画面 キャプチャ （ システム の 画面 キャプチャ 等 ）'},
#  {'id': '100997',
#   'title': '',
#   'text': 'ARK の 問合せ に つい て は 、 OA サポート デスク で は サポート 対象外 と なり ます 。 \n 下記 ページ を 参照 し て 下さい 。 \n\n ・ ARK / Chronos - Core   Portal \n  http:// ark - chronos . bb . local / Docs / # /'},
#  {'id': '100998',
#   'title': '',
#   'text': 'Cisco   VPN 接続 時 、 「 Untrusted   VPN   Server   Blocked ！ 」 が 表示 さ れ た 場合 は ウイルス ファイル の 更新 を 行っ て 下さい 。 \n\n  1 . タスクバー に ある ▲ を クリック し 、 Symantec   Endpoint   Protection （ SEP ） の アイコン （ 黄色 の 盾 の よう な アイコン ） を 右 クリック で 開き 、 「 Symantec   Endpoint   Protection を 開く 」 を 選択 する 。 \n  2 . 「 この アプリ が デバイス に 変更 を 加える こと を 許可 し ます か ？ 」 の メッセージ が 表示 さ れ たら 、 自身 の OA アカウント の パスワード を 入力 し 、 「 はい 」 を クリック し ます 。 \n  3 . LiveUpdate ... を クリック する \n  4 . LiveUpdate 完了 後 画面 を 閉じ 、 再度 、 タスクバー から SEP アイコン を 右 クリック で 開き 、 「 ポリシー の 更新 」 を クリック する'},
#  {'id': '100999',
#   'title': '',
#   'text': '業 端 B も 業 端 A と 同様 に MDM ・ Gmail ・ VPN を 使用 する こと が でき ます 。 \n 業 端 A と 同等 の セキュリティ 要件 を 満たす もの に 限り ます 。 \n 但し 申請 や 予算 の 確保 が 必要 に なる もの が ござい ます 、 必要 に 応じ て 下記 ページ を 参照 し 、 対応 下さい 。 \n\n ・ 業務用 携帯 電話 B で 社内 システム ( Gmail ・ Slack ) を 利用 する 場合 \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / keitai / keitai - a / rule / keitai / keitai - b'},
#  ...]

# %%
SPLIT_DATA_DIR = "/home/jinho/FlagEmbedding_Aizip/dataset/sudachi_split_b/sb_qna"

# %%
with open(f"{SPLIT_DATA_DIR}/test_queries.jsonl", "w") as f:
    for record in split_queries_l:
        f.write(json.dumps(record) + '\n')

# %%
with open(f"{SPLIT_DATA_DIR}/corpus.jsonl", "w") as f:
    for record in split_corpus_l:
        f.write(json.dumps(record) + '\n')

# %%
with open(f"{SPLIT_DATA_DIR}/test_qrels.jsonl", "w") as f:
    for record in qrels_l:
        f.write(json.dumps(record) + '\n')
