# %% [markdown]
# # Preparing Data for BEIR Evaluation

# %% [markdown]
# ## Load corpus, queries, and mapping (qrels)

# %% [markdown]
# ### SB QNA Example

# %%
import json

# %%
with open("/home/jinho/softbank_rag/dataset/sb_full_train_answer_to_questions.json", "r") as f:
    sb_full = json.load(f)

# %%
corpus_len = len(sb_full)
corpus_len
# Out:
# 1701

# %%
corpus = list(sb_full.keys())

# %%
queries = []
query_to_corpus = {}
for c in sb_full:
    for q in sb_full[c]:
        if q not in queries:
            queries.append(q)
            query_to_corpus[q] = c

# %%
query_len = len(queries)
query_len
# Out:
# 10607

# %%
qrels_len = len(query_to_corpus)
assert qrels_len == query_len

# %% [markdown]
# ### Telsa Manual Example

# %%
import json

# %%
with open("/home/jinho/tesla_rag/data/tesla_v0_0114/full_data_10k.json", "r") as f:
    tesla_full = json.load(f)

# %%
corpus_len = len(tesla_full)
corpus_len
# Out:
# 548

# %%
corpus = list(tesla_full.keys())

# %%
queries = []
query_to_corpus = {}
for c in tesla_full:
    for q in tesla_full[c]:
        if q not in queries:
            queries.append(q)
            query_to_corpus[q] = c

# %%
query_len = len(queries)
query_len
# Out:
# 10782

# %%
qrels_len = len(query_to_corpus)
assert qrels_len == query_len

# %% [markdown]
# ## Transform dataset into corresponding formats

# %%
queries_l = []
query_to_id = {}
for i in range(len(queries)):
    qid = str(i)
    queries_l.append({"id": qid, "text": queries[i]})
    query_to_id[queries[i]] = qid

# %%
queries_l
# Out:
# [{'id': '0',
#   'text': 'What do I need to know about the exterior lights on my car?'},
#  {'id': '1',
#   'text': 'Do the driver and passenger dome lights work the same way?'},
#  {'id': '2', 'text': 'How can I activate the hazard warning flashers?'},
#  {'id': '3', 'text': 'Where can I find the horn in the car?'},
#  {'id': '4',
#   'text': 'Is there a special way to activate the turn signal stalk for high beam headlights?'},
#  {'id': '5',
#   'text': 'Can you tell me more about how the rear view camera works?'},
#  {'id': '6',
#   'text': 'What part of the car has the radar sensor, and is it visible?'},
#  {'id': '7', 'text': 'How do I operate the power window switches?'},
#  {'id': '8',
#   'text': 'What options do I have when using the touch screen in the car?'},
#  {'id': '9',
#   'text': 'Explain how the door open button functions from the interior.'},
#  {'id': '10',
#   'text': 'Is there anything special about the exterior mirrors I should know?'},
#  {'id': '11', 'text': 'How do I manually release the interior door handle?'},
#  {'id': '12',
#   'text': 'If my car is equipped with the radar sensor, where is it located?'},
#  {'id': '13', 'text': 'What features can I control with the drive stalk?'},
#  {'id': '14', 'text': 'How can I access the climate control vent settings?'},
#  {'id': '15', 'text': 'What is the purpose of the key card sensor?'},
#  {'id': '16', 'text': 'Can you tell me the function of the cabin camera?'},
#  {'id': '17', 'text': 'How do I turn on and off the hazard warning flashers?'},
#  {'id': '18', 'text': "What's the best way to manage the exterior mirrors?"},
#  {'id': '19',
#   'text': 'Does the rear door handle operate differently from the front door handle?'},
#  {'id': '20',
#   'text': 'How do I manually release the door from inside the car?'},
#  {'id': '21', 'text': 'Can you explain how to use the manual door release?'},
#  {'id': '22', 'text': 'I need help opening the glovebox. What should I do?'},
#  {'id': '23', 'text': 'Where is the glovebox located in my car?'},
#  {'id': '24', 'text': 'What can I find in the center console?'},
#  {'id': '25',
#   'text': 'How long does it take to master using the scroll buttons?'},
#  {'id': '26',
#   'text': "I'm trying to open the glovebox and it's not working. What could the issue be?"},
#  {'id': '27',
#   'text': 'Can you guide me on how to manually open the doors when inside?'},
#  {'id': '28', 'text': "What's the correct way to access the center console?"},
#  {'id': '29',
#   'text': 'Could you tell me which page the manual door release is explained on?'},
#  {'id': '30',
#   'text': "I can't seem to find the manual door release. Where should I look?"},
#  {'id': '31',
#   'text': 'Where is the interior section discussed in the manual?'},
#  {'id': '32',
#   'text': 'Does the manual provide any information about the center console?'},
#  {'id': '33', 'text': 'Tell me about the glovebox. How do I access it?'},
#  {'id': '34', 'text': 'Are the scroll buttons easy to use?'},
#  {'id': '35', 'text': 'What should I know about using the glovebox?'},
#  {'id': '36',
#   'text': 'When should I use the manual door release instead of the automatic one?'},
#  {'id': '37',
#   'text': 'Does the document mention anything about interior electronics?'},
#  {'id': '38',
#   'text': 'Can you describe the appearance and use of the right scroll button?'},
#  {'id': '39',
#   'text': 'What information does the manual give about the accelerator pedal?'},
#  {'id': '40', 'text': "Why shouldn't I use the touchscreen while driving?"},
#  {'id': '41',
#   'text': 'How can I change the settings of my car using the touchscreen?'},
#  {'id': '42',
#   'text': 'Do I need to use physical buttons to adjust the heating?'},
#  {'id': '43', 'text': "What can I control with the car's touchscreen?"},
#  {'id': '44',
#   'text': 'Is there a way to navigate without taking my eyes off the road?'},
#  {'id': '45', 'text': 'What should I do if the touchscreen is unresponsive?'},
#  {'id': '46', 'text': 'Can I use a screen protector on the touchscreen?'},
#  {'id': '47',
#   'text': 'What might happen if I apply a screen protector to the screen?'},
#  {'id': '48',
#   'text': "Where can I find the car's current status while driving?"},
#  {'id': '49', 'text': "How do I monitor my car's speed and warning messages?"},
#  {'id': '50', 'text': 'Where can I access media controls in my car?'},
#  {'id': '51',
#   'text': 'How do I know if my car has a certain feature on the touchscreen?'},
#  {'id': '52',
#   'text': 'What can the status bar on top of the screen help me with?'},
#  {'id': '53',
#   'text': 'What do I use the navigation section of the screen for?'},
#  {'id': '54',
#   'text': 'How can I access the shortcuts for media and tire pressure?'},
#  {'id': '55',
#   'text': 'Is the software version relevant for illustrations on the touchscreen?'},
#  {'id': '56',
#   'text': 'How do I open the charge port door when the car is parked?'},
#  {'id': '57',
#   'text': 'What are the cautionary notes about using the touchscreen?'},
#  {'id': '58',
#   'text': 'What happens when I open doors or turn lights on with regards to the screen?'},
#  {'id': '59',
#   'text': "What kind of messages appear in the car's status area?"},
#  {'id': '60', 'text': 'Can you show me how to expand the road visualization?'},
#  {'id': '61',
#   'text': "How do I condense the visualization on my car's display?"},
#  {'id': '62',
#   'text': "What details are shown when I expand the car's visualization area?"},
#  {'id': '63',
#   'text': "I can't find the climate controls; where should I look?"},
#  {'id': '64', 'text': 'How do I change the cabin temperature in my car?'},
#  {'id': '65',
#   'text': 'Is there a way to adjust the driver and passenger temperatures separately?'},
#  {'id': '66', 'text': 'Where can I find the app launcher in my car?'},
#  {'id': '67', 'text': "How do I open recent apps in the car's system?"},
#  {'id': '68',
#   'text': "How can I search for a specific setting on my car's display?"},
#  {'id': '69', 'text': 'Can you explain how to use the My Apps feature?'},
#  {'id': '70',
#   'text': "What's the process to customize my frequently used apps?"},
#  {'id': '71', 'text': 'How do I provide touchscreen feedback to Tesla?'},
#  {'id': '72',
#   'text': "The visualization doesn't show all details; is there a way to expand it?"},
#  {'id': '73',
#   'text': 'How can I access the climate control settings without touching the screen?'},
#  {'id': '74', 'text': "I want to open an app; where's the app tray located?"},
#  {'id': '75',
#   'text': 'Which area displays the road and surrounding objects in my car?'},
#  {'id': '76',
#   'text': "I'm having trouble finding the controls screen; can you help?"},
#  {'id': '77', 'text': "How do I close an app once I'm done using it?"},
#  {'id': '78',
#   'text': 'Is there an icon to display more information about a setting?'},
#  {'id': '79',
#   'text': 'Where should I touch to bring up the control customization options?'},
#  {'id': '80',
#   'text': "How do I customize the apps in the My Apps area on my car's touchscreen?"},
#  {'id': '81',
#   'text': 'What happens if I try to add more apps than the maximum number allowed in My Apps?'},
#  {'id': '82',
#   'text': 'Can you show me how to remove an app from the My Apps area?'},
#  {'id': '83',
#   'text': "Is there a way to get a full-screen Park view on my car's display?"},
#  {'id': '84',
#   'text': 'Where can I find the option to control the volume for media and phone calls?'},
#  {'id': '85',
#   'text': "What's the procedure to enter customization mode for My Apps?"},
#  {'id': '86',
#   'text': "I've added too many apps. How do I take one out from My Apps?"},
#  {'id': '87',
#   'text': "How do I display detailed weather information on the car's screen?"},
#  {'id': '88',
#   'text': 'Do seat heaters show up in the My Apps area after I select them?'},
#  {'id': '89',
#   'text': 'If I need to lock or unlock all doors, which icon should I touch on the top status bar?'},
#  {'id': '90',
#   'text': "How can I check the local weather conditions using my car's display?"},
#  {'id': '91',
#   'text': 'Can you explain how the temperature is displayed and what additional information is available with premium connectivity?'},
#  {'id': '92',
#   'text': 'Is it possible to see the air quality index from the car screen, and how do I access it?'},
#  {'id': '93',
#   'text': 'Describe the process of dragging an app from the app tray to customize the bottom bar.'},
#  {'id': '94',
#   'text': 'If I want to replace an app in My Apps, what happens to the existing apps?'},
#  {'id': '95',
#   'text': 'How does the car control the sound volume for navigation instructions?'},
#  {'id': '96',
#   'text': 'What are the steps to view more detailed weather info including humidity and UV index?'},
#  {'id': '97',
#   'text': 'Can the full-screen Park view display media and navigation controls together?'},
#  {'id': '98',
#   'text': 'What should I do to lock all doors quickly using the touchscreen?'},
#  {'id': '99',
#   'text': 'How does the car handle the display of recently added apps in My Apps if I exceed the limit?'},
#  {'id': '100',
#   'text': "Why can't I see the air quality index on my car's touchscreen?"},
#  {'id': '101',
#   'text': "My car isn't displaying the air quality index. Does it only show under certain conditions?"},
#  {'id': '102',
#   'text': 'How can I get more detailed weather information on my Model Y touchscreen?'},
#  {'id': '103',
#   'text': 'What should I do if the time displayed on the screen is incorrect?'},
#  {'id': '104',
#   'text': 'The time shown in my car is wrong. How do I fix that?'},
#  {'id': '105',
#   'text': 'How do I know if my car has the latest software installed?'},
#  {'id': '106',
#   'text': 'When does the HomeLink option appear on the touchscreen?'},
#  {'id': '107',
#   'text': "I can't see the HomeLink option. What might be the reason for this?"},
#  {'id': '108',
#   'text': 'How can I switch driver profiles when my car is parked?'},
#  {'id': '109', 'text': 'I want to configure Valet Mode. Where do I start?'},
#  {'id': '110', 'text': 'How do I enable Sentry Mode when my car is parked?'},
#  {'id': '111',
#   'text': 'If I activate Sentry Mode from the controls, will it stay on permanently?'},
#  {'id': '112',
#   'text': 'What are the limitations of the USB ports in the center console?'},
#  {'id': '113',
#   'text': 'Can I use the center console USB ports for functions other than charging?'},
#  {'id': '114', 'text': 'How can I connect my Model Y to a Wi-Fi network?'},
#  {'id': '115',
#   'text': 'My car has no cellular connectivity. What should I check?'},
#  {'id': '116',
#   'text': 'How can I access Wi-Fi settings from the touchscreen?'},
#  {'id': '117',
#   'text': 'My Model Y isn’t showing cellular network availability. What might be wrong?'},
#  {'id': '118',
#   'text': 'What is the benefit of having premium connectivity for weather updates?'},
#  {'id': '119',
#   'text': 'When does the vehicle automatically update the time, and what does it require?'},
#  {'id': '120', 'text': 'How do I access the Wi-Fi settings on my car?'},
#  {'id': '121',
#   'text': 'What should I do if a popup message appears while driving?'},
#  {'id': '122', 'text': 'Can I get more details about a vehicle alert?'},
#  {'id': '123',
#   'text': 'How can I dismiss a popup notification on the touchscreen?'},
#  {'id': '124',
#   'text': 'What happens if I restart the touchscreen while the car is moving?'},
#  {'id': '125',
#   'text': 'Is a seat belt reminder displayed if it is unfastened?'},
#  {'id': '126',
#   'text': 'How can I learn more about an alert on the touchscreen?'},
#  {'id': '127', 'text': 'What should I do to restart the touchscreen?'},
#  {'id': '128',
#   'text': 'Will pressing the brake pedal affect the touchscreen reset process?'},
#  {'id': '129',
#   'text': "How can I stop the car's GPS location from being accessed by my mobile app?"},
#  {'id': '130',
#   'text': 'Where can I find options to accept or decline a phone call on the touchscreen?'},
#  {'id': '131',
#   'text': 'How do I view a list of vehicle alerts and notifications?'},
#  {'id': '132',
#   'text': 'Is it necessary to be in Park to restart the touchscreen?'},
#  {'id': '133',
#   'text': "How do I know if the vehicle's GPS location is being accessed?"},
#  {'id': '134',
#   'text': 'What types of messages can appear at the bottom of the touchscreen?'},
#  {'id': '135',
#   'text': 'Why is it necessary to shift into Park before restarting the touchscreen?'},
#  {'id': '136',
#   'text': "Can I interact with popup messages on my car's screen?"},
#  {'id': '137',
#   'text': 'What does the bell icon at the top of the Controls do?'},
#  {'id': '138', 'text': 'How do I disable mobile access on the touchscreen?'},
#  {'id': '139', 'text': 'Why might I need to restart the touchscreen?'},
#  {'id': '140',
#   'text': 'Why is my Tesla logo not appearing on the screen after restart?'},
#  {'id': '141',
#   'text': 'How long should I wait for the touchscreen to restart before checking for issues?'},
#  {'id': '142',
#   'text': 'What do I do if my touchscreen is still unresponsive after several minutes?'},
#  {'id': '143',
#   'text': 'Can I power cycle the car without restarting all vehicle components?'},
#  {'id': '144',
#   'text': 'How do I change the display appearance from Dark to Light?'},
#  {'id': '145', 'text': 'What happens if I set the display mode to Auto?'},
#  {'id': '146',
#   'text': 'How can I enable the Reduce Blue Light feature on my car?'},
#  {'id': '147', 'text': 'Why is the screen warmer at night?'},
#  {'id': '148',
#   'text': 'How do I manually adjust the brightness of the touchscreen?'},
#  {'id': '149',
#   'text': 'What should I do if I want to clean the screen without activating it?'},
#  {'id': '150',
#   'text': 'Is it possible to change the touchscreen language when the car is not in Park?'},
#  {'id': '151',
#   'text': 'Do I need to wait for the touchscreen to restart after changing the language?'},
#  {'id': '152', 'text': 'How do I set up the voice recognition language?'},
#  {'id': '153',
#   'text': 'Can I change the voice navigation language to a language not yet downloaded?'},
#  {'id': '154', 'text': 'Is Wi-Fi required to download new language settings?'},
#  {'id': '155', 'text': 'How can I increase the text size on the touchscreen?'},
#  {'id': '156',
#   'text': 'What are the options for displaying the time format on the touchscreen?'},
#  {'id': '157',
#   'text': 'What is the difference between percentage and distance estimation in energy display?'},
#  {'id': '158', 'text': 'How does the car remember my brightness preference?'},
#  {'id': '159',
#   'text': 'What should I do if the screen is not adjusting brightness based on my preference?'},
#  {'id': '160',
#   'text': 'How can I change the temperature display from Fahrenheit to Celsius?'},
#  {'id': '161',
#   'text': 'I need to transfer ownership of my car. How do I perform a factory reset?'},
#  {'id': '162',
#   'text': 'Can you tell me how to enable Joe Mode to reduce chime volume?'},
#  {'id': '163',
#   'text': 'I want to change the name of my vehicle. How do I do that?'},
#  {'id': '164',
#   'text': "What's the procedure to display tire pressures in PSI instead of BAR?"},
#  {'id': '165',
#   'text': "I'm trying to remove my personal data. What's the process for a factory reset?"},
#  {'id': '166',
#   'text': 'How do I switch the distance measurements to kilometers?'},
#  {'id': '167',
#   'text': 'Is there a way to reduce all non-critical chime volumes in the car?'},
#  {'id': '168',
#   'text': 'Can you guide me on how to select imperial units for measurements?'},
#  {'id': '169',
#   'text': 'I need to rename my car. Where do I find the option to do that?'},
#  {'id': '170',
#   'text': 'How do I ensure my personal data is erased when selling my car?'},
#  {'id': '171',
#   'text': "What steps should I follow to change my vehicle's name in the Tesla app?"},
#  {'id': '172',
#   'text': "I'm transferring ownership and need my settings erased. How do I reset the factory settings?"},
#  {'id': '173',
#   'text': 'Where can I go to adjust tire pressure settings to display in different units?'},
#  {'id': '174',
#   'text': 'How do I use the touchscreen to change the measurement system to imperial?'},
#  {'id': '175',
#   'text': "I want to personalize my car's display. How can I change the temperature unit?"},
#  {'id': '176',
#   'text': 'Is there a feature that helps with minimizing chime volume for non-safety issues?'},
#  {'id': '177',
#   'text': 'Is it possible to change the distance units to miles? How?'},
#  {'id': '178',
#   'text': 'What do I need to enter before erasing my personal data with a factory reset?'},
#  {'id': '179', 'text': 'How can I access the option to rename my vehicle?'},
#  {'id': '180', 'text': 'Can I charge my phone using the USB ports in my car?'},
#  {'id': '181',
#   'text': 'What can I do with the USB ports in the center console?'},
#  {'id': '182', 'text': 'Is there a USB port in the glovebox for the Dashcam?'},
#  {'id': '183',
#   'text': 'Do the USB ports in the back seat connect to the car system?'},
#  {'id': '184',
#   'text': "What's the power output of the USB ports in the front compartment?"},
#  {'id': '185',
#   'text': 'My car was made after November 1, 2021. Can the front USB ports do more than just charge?'},
#  {'id': '186',
#   'text': 'Where is the best place to save Dashcam videos in the Model Y?'},
#  {'id': '187', 'text': 'Are there any USB-A ports in my vehicle?'},
#  {'id': '188',
#   'text': 'How do I access the USB ports in the front center console?'},
#  {'id': '189', 'text': 'Does the glovebox USB port come with a flash drive?'},
#  {'id': '190', 'text': 'Can the rear USB ports be used to play music files?'},
#  {'id': '191',
#   'text': 'Why should I use the glovebox USB port for Sentry Mode?'},
#  {'id': '192',
#   'text': 'What kind of USB connection do the front USB ports have?'},
#  {'id': '193',
#   'text': 'Can I use the USB ports in the rear for charging my tablet?'},
#  {'id': '194',
#   'text': 'I want to store my Dashcam videos. Where should I connect my USB drive?'},
#  {'id': '195', 'text': 'Are all the USB ports USB-C in my car?'},
#  {'id': '196',
#   'text': 'Does the Model Y come with an RFID transmitter inside?'},
#  {'id': '197',
#   'text': "How many USB ports are there in my Model Y's center console?"},
#  {'id': '198',
#   'text': 'Is there a difference in power consumption between the glovebox USB port and others?'},
#  {'id': '199',
#   'text': 'Besides the USB ports, where else can I charge my phone in the car?'},
#  {'id': '200',
#   'text': 'Where are the USB-C ports located if my car has seven seats?'},
#  {'id': '201',
#   'text': 'Can the USB ports in my car communicate with the vehicle systems?'},
#  {'id': '202',
#   'text': 'I want to charge my device, where are the USB-C ports in the seven-seat Model Y?'},
#  {'id': '203',
#   'text': "The USB ports in my car don't seem to communicate with the vehicle. Is this normal?"},
#  {'id': '204',
#   'text': "I've got a seven-seat configuration. Are there USB-C ports by the third row?"},
#  {'id': '205',
#   'text': 'Do the USB ports in the car have any other function besides charging?'},
#  {'id': '206',
#   'text': "Can't find the USB-C ports in my seven-seat Model Y. Any idea where they might be?"},
#  {'id': '207',
#   'text': "Are the USB ports in the third row connected to the car's network?"},
#  {'id': '208',
#   'text': 'I see USB-C ports in the back of my car. What can they be used for?'},
#  {'id': '209',
#   'text': 'How many USB-C ports are there if I have a seven-seat Model Y?'},
#  {'id': '210',
#   'text': "My phone isn't syncing with the car. Are the USB ports just for charging?"},
#  {'id': '211',
#   'text': 'Are the USB-C ports in the third row only for charging devices?'},
#  {'id': '212',
#   'text': "What's the purpose of the USB-C ports in a seven-seat model of the car?"},
#  {'id': '213',
#   'text': 'Just noticed USB-C ports in the third row. Do they have any special functions?'},
#  {'id': '214',
#   'text': 'Can I connect my USB device to sync with the car through these ports?'},
#  {'id': '215',
#   'text': 'Do the USB-C ports charge devices quickly in the seven-seat Model Y?'},
#  {'id': '216',
#   'text': 'If my Model Y has seven seats, how many USB ports are available?'},
#  {'id': '217',
#   'text': 'I need to charge my gadget in the third row. Are there USB ports there?'},
#  {'id': '218',
#   'text': "What's the location of USB-C ports if my car has seven seats?"},
#  {'id': '219',
#   'text': 'Is it possible to connect a USB drive to play music directly from the car?'},
#  {'id': '220', 'text': "When does the car know that I'm present?"},
#  {'id': '221',
#   'text': 'Does leaving something plugged into the car drain the low voltage battery?'},
#  {'id': '222',
#   'text': "What's the risk of using non-USB 3.0 compliant cables?"},
#  {'id': '223',
#   'text': 'Can I charge multiple devices with the USB ports using a USB hub?'},
#  {'id': '224', 'text': 'Do devices fail to connect if I use a USB hub?'},
#  {'id': '225',
#   'text': 'How much power does the wireless phone charger provide to my phone?'},
#  {'id': '226',
#   'text': 'Is it normal for my phone to feel warm while using the wireless charger?'},
#  {'id': '227', 'text': 'Will my phone stop charging if I exit the vehicle?'},
#  {'id': '228',
#   'text': "If the car's Battery is discharged, will it still charge my phone on the wireless charger?"},
#  {'id': '229',
#   'text': "My phone isn't charging on the wireless pad. Could it be my phone case?"},
#  {'id': '230',
#   'text': 'What issues can non-USB 3.0 cables cause when charging?'},
#  {'id': '231',
#   'text': "How do I ensure my NFC cards aren't damaged during wireless charging?"},
#  {'id': '232', 'text': 'Can I charge my phone wirelessly if the car is off?'},
#  {'id': '233',
#   'text': 'What precautions should I take with metal objects when using the wireless charger?'},
#  {'id': '234',
#   'text': 'Do I have to worry about my phone case size when charging wirelessly?'},
#  {'id': '235',
#   'text': "Why isn't my phone charging even though it's on the wireless charger?"},
#  {'id': '236',
#   'text': 'Should I remove my credit cards from behind my phone before charging it on the wireless pad?'},
#  {'id': '237',
#   'text': 'Why might my device not be recognized if I use a USB hub?'},
#  {'id': '238',
#   'text': 'Does my phone need to be in direct contact with the wireless pad to charge?'},
#  {'id': '239',
#   'text': 'How does the car communicate with the mobile app to provide power?'},
#  {'id': '240',
#   'text': 'Can I use the low voltage power socket to charge my phone?'},
#  {'id': '241', 'text': 'Where is the power socket located in my car?'},
#  {'id': '242',
#   'text': 'What is the maximum continuous draw for accessories using the power socket?'},
#  {'id': '243',
#   'text': 'What should I do if the connector of an accessory becomes hot while using the power socket?'},
#  {'id': '244',
#   'text': 'My NFC card got damaged while charging my phone. What could be the cause?'},
#  {'id': '245',
#   'text': 'When is power available through the low voltage power socket?'},
#  {'id': '246',
#   'text': "I'm using a non-Tesla accessory, and I've started noticing indicator lights. What should I do?"},
#  {'id': '247',
#   'text': "Is it okay to leave my accessory plugged in when I'm not in the car?"},
#  {'id': '248',
#   'text': 'How can I tell if the vehicle detects a user present?'},
#  {'id': '249',
#   'text': "What happens if I use a power inverter that doesn't support 16V DC input?"},
#  {'id': '250', 'text': 'My accessory seems unusually hot. Is this normal?'},
#  {'id': '251',
#   'text': 'What is the peak current allowed for the power socket?'},
#  {'id': '252', 'text': 'Can I jump start my car using the power socket?'},
#  {'id': '253',
#   'text': 'Why is there a warning against using the power socket for jump starting?'},
#  {'id': '254',
#   'text': 'Where can I find an additional power socket in the car?'},
#  {'id': '255',
#   'text': 'Is it safe to plug non-Tesla accessories into the power socket?'},
#  {'id': '256',
#   'text': 'Do all versions of the Model Y have the 16V requirement for power inverters?'},
#  {'id': '257',
#   'text': "Under what conditions does the car's low voltage power socket supply power?"},
#  {'id': '258',
#   'text': 'What might cause malfunctions when using non-Tesla accessories in the power socket?'},
#  {'id': '259',
#   'text': 'What happens if I plug an accessory into the power socket while charging the high voltage battery?'},
#  {'id': '260',
#   'text': 'What does the overhead view on the touchscreen show when my car is parked?'},
#  {'id': '261',
#   'text': 'How can I open the charge port door using the touchscreen?'},
#  {'id': '262',
#   'text': "My car's brake indicator light is staying on. What should I do?"},
#  {'id': '263',
#   'text': 'How do I customize the shortcut cards at the bottom of the car status display?'},
#  {'id': '264',
#   'text': 'What does it mean if the red brake indicator light is on when driving?'},
#  {'id': '265',
#   'text': 'Why are the indicator lights not turning off after I start my car?'},
#  {'id': '266',
#   'text': 'How do I access the tire pressure information from the touchscreen?'},
#  {'id': '267',
#   'text': 'The amber brake indicator light just came on. What does that indicate?'},
#  {'id': '268',
#   'text': "Why is my car displaying a red brake indicator when it's not starting?"},
#  {'id': '269',
#   'text': 'Is it possible to view trip information from the shortcut cards on the screen?'},
#  {'id': '270',
#   'text': 'What steps should I take if I see a brake system fault on the screen?'},
#  {'id': '271',
#   'text': 'What information does the status area show when Model Y is parked?'},
#  {'id': '272',
#   'text': 'How do I quickly access media controls on the touchscreen?'},
#  {'id': '273',
#   'text': 'I see a message about low brake fluid. What should I do?'},
#  {'id': '274',
#   'text': 'What should I do if the brake booster fault light comes on while driving?'},
#  {'id': '275',
#   'text': 'How can I open the trunks using the touchscreen when my car is parked?'},
#  {'id': '276',
#   'text': 'What does the drive mode display indicate on the screen?'},
#  {'id': '277',
#   'text': "The dashboard isn't showing correctly after a software update. What might cause this?"},
#  {'id': '278',
#   'text': 'I want to check my estimated range. Where can I find that information?'},
#  {'id': '279',
#   'text': 'What might cause the indicator lights to not flash when I press the brake?'},
#  {'id': '280',
#   'text': 'What does it mean if the amber brake indicator lights up on my screen?'},
#  {'id': '281',
#   'text': 'If I see an ABS fault message, can I still drive my electric car safely?'},
#  {'id': '282',
#   'text': 'The touchscreen just showed an amber ABS indicator; what should I do now?'},
#  {'id': '283',
#   'text': "Is the braking system still operational if there's an ABS failure?"},
#  {'id': '284',
#   'text': 'I noticed the amber brake indicator on my Tesla; should I be concerned?'},
#  {'id': '285',
#   'text': "How should I adjust my driving if there's an ABS fault in the car?"},
#  {'id': '286',
#   'text': 'What action should I take when the red parking brake indicator is on?'},
#  {'id': '287',
#   'text': "There's an amber light on my screen showing a parking brake fault. What does this mean?"},
#  {'id': '288',
#   'text': 'What happens if the tire pressure warning lights up on my dashboard?'},
#  {'id': '289',
#   'text': 'If the tire pressure monitoring system indicator flashes, what does it indicate?'},
#  {'id': '290',
#   'text': 'The touchscreen indicates a seat belt issue. How can I fix this?'},
#  {'id': '291',
#   'text': 'What should I do if the parking brake indicator turns amber and shows a fault message?'},
#  {'id': '292',
#   'text': 'Why did the ABS indicator flash when I started my car?'},
#  {'id': '293',
#   'text': 'The red parking brake indicator is on. How did I activate it?'},
#  {'id': '294',
#   'text': 'I saw a warning about tire pressure. How can I resolve this?'},
#  {'id': '295',
#   'text': "Does a seat belt warning mean there's an issue with the belt system?"},
#  {'id': '296',
#   'text': 'How does the hydraulic boost compensation help if a brake booster fault is detected?'},
#  {'id': '297',
#   'text': 'What does it mean if the screen shows an airbag safety message?'},
#  {'id': '298',
#   'text': 'Why might the ABS indicator flash briefly when starting my Tesla?'},
#  {'id': '299',
#   'text': "What does the touchscreen display if there's a parking brake electrical issue in the car?"},
#  {'id': '300', 'text': 'What should I do if the airbag indicator remains on?'},
#  {'id': '301',
#   'text': "My car's electronic stability control indicator is flashing amber. What does that mean?"},
#  {'id': '302', 'text': 'Why might my high beams be unavailable?'},
#  {'id': '303',
#   'text': 'When does the low beam headlights indicator activate?'},
#  {'id': '304',
#   'text': 'The high beam headlights turned off because light was detected. Is this normal?'},
#  {'id': '305',
#   'text': 'What does it mean when the high beams automatically turn back on?'},
#  {'id': '306', 'text': "How do I know when my car's parking lights are on?"},
#  {'id': '307',
#   'text': 'Can you explain why the airbag indicator might not flash briefly?'},
#  {'id': '308',
#   'text': 'The electronic stability control systems have stopped minimizing wheel spin. Is this normal?'},
#  {'id': '309',
#   'text': 'What should I do if the traction control indicator remains on?'},
#  {'id': '310',
#   'text': "Do I need to contact Tesla if my airbag indicator doesn't behave as expected?"},
#  {'id': '311',
#   'text': 'How does my car detect when to turn off the high beams?'},
#  {'id': '312',
#   'text': 'Why would the high beam headlights indicator be disabled?'},
#  {'id': '313',
#   'text': "It seems like my car's front fog lights are on. What does that mean?"},
#  {'id': '314',
#   'text': "If my car's traction control system is turned off, will it affect wheel spin?"},
#  {'id': '315',
#   'text': "I'm seeing a fault warning on the car status screen. What steps should I take?"},
#  {'id': '316',
#   'text': 'What might cause the electronic stability control systems to activate?'},
#  {'id': '317', 'text': 'Why is my car ready to turn off the high beams?'},
#  {'id': '318',
#   'text': "When will my car's high beams automatically turn back on?"},
#  {'id': '319',
#   'text': 'If the stability control indicator stays on, should I be concerned?'},
#  {'id': '320', 'text': 'Why is there a blue snowflake icon on the screen?'},
#  {'id': '321',
#   'text': 'My car is not letting me accelerate as usual, what could be the reason?'},
#  {'id': '322',
#   'text': 'If the car power is limited, could it be because the Battery is low?'},
#  {'id': '323',
#   'text': 'How can I get the quick road visualization to show more details?'},
#  {'id': '324', 'text': "I can't use regenerative braking, what's going on?"},
#  {'id': '325',
#   'text': "The visualization on my touchscreen isn't showing road objects, how do I change that?"},
#  {'id': '326', 'text': 'How do I warm up the battery during cold weather?'},
#  {'id': '327',
#   'text': 'What should I do if a door or trunk is open while driving?'},
#  {'id': '328',
#   'text': "The Autopilot screen doesn't show any vehicles in the blind spot, is this normal?"},
#  {'id': '329', 'text': 'How can I check if Autosteer is available on my car?'},
#  {'id': '330',
#   'text': "Why would the vehicle's systems limit the energy usage?"},
#  {'id': '331',
#   'text': 'The touchscreen driving status is not updating correctly, what might be wrong?'},
#  {'id': '332',
#   'text': 'What does it mean if the regenerative braking is limited?'},
#  {'id': '333',
#   'text': "Sometimes the car doesn't accelerate well, could it be due to cold weather?"},
#  {'id': '334',
#   'text': "How can I use the mobile app to heat my car's Battery?"},
#  {'id': '335',
#   'text': "The road visualization auto-zoom isn't working, how might I fix it?"},
#  {'id': '336',
#   'text': 'I see a gray icon, does that mean Autosteer is available but not activated?'},
#  {'id': '337', 'text': "What kind of errors might limit my car's power?"},
#  {'id': '338',
#   'text': "How do I make sure my vehicle's screen uses the touchscreen space efficiently?"},
#  {'id': '339',
#   'text': 'Why might my car not fully utilize its battery capacity in cold conditions?'},
#  {'id': '340',
#   'text': 'What do the different colors of lines on the display mean?'},
#  {'id': '341',
#   'text': 'How can I see the total estimated driving distance remaining?'},
#  {'id': '342',
#   'text': 'My car shows a blue outline around the speed limit sign. Why is that?'},
#  {'id': '343',
#   'text': 'Is there a way to switch from seeing the battery in miles to percentage?'},
#  {'id': '344', 'text': 'Why is the Autosteer icon gray on my screen?'},
#  {'id': '345',
#   'text': 'What does it mean when the Autosteer icon turns blue?'},
#  {'id': '346',
#   'text': 'Can you explain how to detect other cars on the road?'},
#  {'id': '347', 'text': "How can I tell when I'm above the speed limit?"},
#  {'id': '348',
#   'text': 'The lane in front of my car is highlighted in blue. What does this indicate?'},
#  {'id': '349', 'text': 'How can I view the currently selected drive mode?'},
#  {'id': '350',
#   'text': 'Why is my power meter displaying vertically at the top of the screen?'},
#  {'id': '351',
#   'text': 'Is it possible to change how energy is displayed on my screen?'},
#  {'id': '352',
#   'text': 'What should I do if the display shows red lines around my car?'},
#  {'id': '353',
#   'text': 'How can I find out the current driving speed in my car?'},
#  {'id': '354',
#   'text': 'I see colored lines on the screen. What do they mean?'},
#  {'id': '355', 'text': 'What information do I get from the power meter?'},
#  {'id': '356',
#   'text': 'The driving lane is a single blue line now. What does that mean?'},
#  {'id': '357', 'text': 'What type of speed limit signs does the car detect?'},
#  {'id': '358',
#   'text': 'How can I change the driving distance to percentage view?'},
#  {'id': '359',
#   'text': "The icon for Autosteer isn't turning blue. What's wrong?"},
#  {'id': '360',
#   'text': 'How can I change how energy is displayed on the screen?'},
#  {'id': '361', 'text': 'What should I consider when anticipating a charge?'},
#  {'id': '362', 'text': 'Why is the cruising speed number gray?'},
#  {'id': '363',
#   'text': 'What does it mean if the cruising speed number is gray?'},
#  {'id': '364',
#   'text': 'What should I do when I see alert messages at the bottom of the car status area?'},
#  {'id': '365',
#   'text': 'Why is it important to pay attention to alert messages on the touchscreen?'},
#  {'id': '366',
#   'text': 'The alerts on the touchscreen warned me, should I be concerned if I miss one?'},
#  {'id': '367',
#   'text': 'Is it safe to rely on the touchscreen to see surrounding traffic?'},
#  {'id': '368',
#   'text': 'Can I use the touchscreen to detect vehicles in my blind spot?'},
#  {'id': '369',
#   'text': "Why shouldn't I rely solely on the touchscreen for detecting other vehicles?"},
#  {'id': '370', 'text': "What's the best practice for checking blind spots?"},
#  {'id': '371',
#   'text': 'The range estimates provided seem vague, how should I interpret them?'},
#  {'id': '372',
#   'text': 'How do I set a cruising speed with Traffic-Aware Cruise Control?'},
#  {'id': '373',
#   'text': 'Why are there warnings about relying on the touchscreen for detecting nearby vehicles?'},
#  {'id': '374',
#   'text': 'What should I double-check even if I see traffic on the touchscreen?'},
#  {'id': '375', 'text': 'How does the car show alert messages?'},
#  {'id': '376',
#   'text': "What kind of alert messages might I see on the car's touchscreen?"},
#  {'id': '377',
#   'text': 'What can cause serious injury if I ignore touchscreen alerts?'},
#  {'id': '378',
#   'text': 'What is shown in the car status area of the touchscreen?'},
#  {'id': '379',
#   'text': "How can I ensure safe driving while using the car's features?"},
#  {'id': '380', 'text': 'How do I change the language for voice commands?'},
#  {'id': '381', 'text': 'Can you help me make the car cooler?'},
#  {'id': '382',
#   'text': "I need to call a friend, what's the quick way to do that?"},
#  {'id': '383', 'text': "What's the process to turn on Sentry Mode?"},
#  {'id': '384', 'text': 'Can I lock the doors with a voice command?'},
#  {'id': '385', 'text': 'How do I speed up the windshield wipers?'},
#  {'id': '386',
#   'text': 'My passenger is too warm, what voice command should I use?'},
#  {'id': '387',
#   'text': 'Is there a way to open the glovebox without touching the screen?'},
#  {'id': '388', 'text': "What's the command to unfold the mirrors?"},
#  {'id': '389',
#   'text': 'I want to navigate to a grocery store, how do I do it?'},
#  {'id': '390', 'text': 'Can you show me how to turn on the rear defroster?'},
#  {'id': '391',
#   'text': 'How can I direct airflow to my face using just my voice?'},
#  {'id': '392',
#   'text': "The driver's seat heater needs to be turned off, how can I do that with voice commands?"},
#  {'id': '393', 'text': 'How do I stop charging the car with a voice request?'},
#  {'id': '394',
#   'text': 'Is it possible to sync the climate controls with a command?'},
#  {'id': '395',
#   'text': 'Can I open the charge port without pressing any buttons?'},
#  {'id': '396',
#   'text': 'How can I decrease the fan speed without using the touchscreen?'},
#  {'id': '397', 'text': 'What do I say to open the service settings?'},
#  {'id': '398',
#   'text': 'I need to close the charge port, how do I do that using voice commands?'},
#  {'id': '399',
#   'text': 'Is there a voice command to fold the mirrors when I park?'},
#  {'id': '400',
#   'text': 'How do I drive to a specific location using voice commands?'},
#  {'id': '401',
#   'text': 'Can I use a voice command to navigate to my destination?'},
#  {'id': '402', 'text': 'Show me nearby Superchargers.'},
#  {'id': '403', 'text': 'Is there a way to stop navigation with my voice?'},
#  {'id': '404',
#   'text': "How do I mute the voice guidance in my car's navigation system?"},
#  {'id': '405', 'text': 'What command do I use to navigate home?'},
#  {'id': '406',
#   'text': "Can I say 'Take me to work' to start navigation to my workplace?"},
#  {'id': '407',
#   'text': 'I want to find a Supercharger station nearby. What should I say?'},
#  {'id': '408', 'text': "How do I use the 'Navigate home' voice command?"},
#  {'id': '409',
#   'text': "I don't want to hear voice guidance anymore. How do I mute it?"},
#  {'id': '410',
#   'text': 'Can my car drive to a location I specify using voice control?'},
#  {'id': '411',
#   'text': 'What is the voice command to show nearby Superchargers?'},
#  {'id': '412',
#   'text': 'I’ve defined my work address. How do I use a voice command to go there?'},
#  {'id': '413',
#   'text': "Is there a specific command to stop a navigation route once it's started?"},
#  {'id': '414',
#   'text': "If I'm hungry, is there a voice command to help me find food? (Ignore this question as it requires more information)"},
#  {'id': '415',
#   'text': 'How can I cancel my current navigation using voice control?'},
#  {'id': '416', 'text': 'What do I say to start navigation to my home?'},
#  {'id': '417',
#   'text': 'I set my home address. How do I tell the car to navigate there?'},
#  {'id': '418',
#   'text': 'I want to stop receiving navigation instructions. Can I do it with my voice?'},
#  {'id': '419',
#   'text': 'Can voice commands show me a list of nearby charging stations?'},
#  {'id': '420', 'text': "Can I text John using my car's voice command?"},
#  {'id': '421', 'text': 'How do I lower the volume of the music?'},
#  {'id': '422', 'text': 'My screen is too bright. How can I adjust it?'},
#  {'id': '423', 'text': 'Can you play the next song for me?'},
#  {'id': '424',
#   'text': "I want to listen to 'Imagine' by John Lennon. How can I do that?"},
#  {'id': '425', 'text': 'How do I change the media source to Bluetooth?'},
#  {'id': '426', 'text': "What's the command to pause the current song?"},
#  {'id': '427', 'text': 'Can I call Lisa using voice commands?'},
#  {'id': '428',
#   'text': 'How do I file a bug report about the navigation system?'},
#  {'id': '429', 'text': 'Please open the browser.'},
#  {'id': '430', 'text': 'The music is too loud. Can you reduce the volume?'},
#  {'id': '431',
#   'text': "I'm looking for something in the Owner's Manual. How can I find it?"},
#  {'id': '432', 'text': 'How can I report a problem with the car performance?'},
#  {'id': '433',
#   'text': "I need to search for a new app. What's the command for that?"},
#  {'id': '434', 'text': 'Can you show me the theater on my screen?'},
#  {'id': '435', 'text': 'How do I switch sources to the radio?'},
#  {'id': '436',
#   'text': "What's the best way to improve voice command accuracy when selecting songs?"},
#  {'id': '437', 'text': 'Please adjust the volume to a lower setting.'},
#  {'id': '438',
#   'text': "How do I send a feedback report using my car's voice system?"},
#  {'id': '439', 'text': 'Open the phone app, please.'},
#  {'id': '440',
#   'text': 'What are the components on the car that monitor the surrounding area?'},
#  {'id': '441',
#   'text': 'Can you describe where the cameras are located on my car?'},
#  {'id': '442', 'text': 'Does my car have ultrasonic sensors? Where are they?'},
#  {'id': '443',
#   'text': 'Where is the radar system mounted if my car is equipped with it?'},
#  {'id': '444',
#   'text': 'Tell me more about the electronically-assisted braking and steering systems.'},
#  {'id': '445',
#   'text': "I can't find the cabin camera. Where is it located in the car?"},
#  {'id': '446',
#   'text': 'How do the cameras calibrate when I use the Autopilot features?'},
#  {'id': '447',
#   'text': "My car's cameras are not calibrated yet. How far do I need to drive for calibration?"},
#  {'id': '448',
#   'text': 'Under what conditions does camera calibration complete more quickly?'},
#  {'id': '449',
#   'text': "I drove over 100 miles but the cameras haven't calibrated. What should I do?"},
#  {'id': '450',
#   'text': 'What steps should I take if I need to clear the camera calibration?'},
#  {'id': '451',
#   'text': "Is it necessary to contact Tesla if the calibration hasn't completed after 100 miles?"},
#  {'id': '452',
#   'text': 'If a camera is replaced, what happens to the calibration process?'},
#  {'id': '453',
#   'text': 'Are the Active Safety features available before calibration is complete?'},
#  {'id': '454',
#   'text': 'I need to clear the camera calibration. Can you guide me on how to do that?'},
#  {'id': '455',
#   'text': 'What are the circumstances that might cause recalibration of the cameras?'},
#  {'id': '456',
#   'text': 'How does the touchscreen help with the camera calibration process?'},
#  {'id': '457',
#   'text': 'What influences the camera calibration distance to vary?'},
#  {'id': '458',
#   'text': 'What kind of roads help speed up the camera calibration?'},
#  {'id': '459',
#   'text': 'How important are highly-visible lane markings for camera calibration?'},
#  {'id': '460',
#   'text': "What should I do if the cameras aren't calibrating properly?"},
#  {'id': '461',
#   'text': 'Do I need to drive on a specific type of road for camera calibration to work?'},
#  {'id': '462',
#   'text': "The calibration message won't go away. Is there something I'm missing?"},
#  {'id': '463',
#   'text': 'How can I ensure the cameras are free of obstructions before driving?'},
#  {'id': '464',
#   'text': "Why are some features disabled on my car's touchscreen?"},
#  {'id': '465',
#   'text': 'How does condensation inside the camera enclosures affect Autopilot?'},
#  {'id': '466',
#   'text': 'If a camera gets blocked, will I get a notification on my screen?'},
#  {'id': '467',
#   'text': 'Are there certain weather conditions that can make the cameras less effective?'},
#  {'id': '468',
#   'text': "I'm getting a message about a blocked camera. What should I do?"},
#  {'id': '469',
#   'text': "What's the best way to proactively dry condensation in the camera enclosures?"},
#  {'id': '470',
#   'text': 'Should I worry about faded lane markings affecting my drive?'},
#  {'id': '471',
#   'text': "Is there a way to clear camera calibration if it's causing issues?"},
#  {'id': '472', 'text': 'How often do the cameras require recalibration?'},
#  {'id': '473', 'text': 'Does the car notify me if the cameras need cleaning?'},
#  {'id': '474',
#   'text': 'Can I use Autopilot if one of the cameras is obstructed?'},
#  {'id': '475',
#   'text': 'Will the car show an alert if something is wrong with the cameras?'},
#  {'id': '476',
#   'text': 'How important is it to precondition the cabin in cold weather?'},
#  {'id': '477',
#   'text': "Do I need to clear calibration if there's a software update?"},
#  {'id': '478',
#   'text': "What's the recommended lane to drive in for optimal camera calibration?"},
#  {'id': '479',
#   'text': "If a camera is dirty, does it impact the car's driving features?"},
#  {'id': '480', 'text': 'How many types of keys can I use with the Model Y?'},
#  {'id': '481', 'text': 'What happens if my phone key battery dies?'},
#  {'id': '482', 'text': 'Can I use my phone to unlock the car?'},
#  {'id': '483', 'text': 'How do I set up the phone key for my car?'},
#  {'id': '484', 'text': 'What should I do if I lose my phone key?'},
#  {'id': '485', 'text': 'Can the key card lock the car automatically?'},
#  {'id': '486',
#   'text': "I'm hiking and need to leave my phone in the car. What should I do?"},
#  {'id': '487', 'text': 'How many keys in total can Model Y support?'},
#  {'id': '488',
#   'text': 'Is it possible to use the key fob to open the trunks?'},
#  {'id': '489', 'text': 'Why should I not leave my phone in the car?'},
#  {'id': '490', 'text': "Can the phone key be used if it's turned off?"},
#  {'id': '491',
#   'text': 'How does the car know to unlock when I approach with my phone?'},
#  {'id': '492',
#   'text': 'What should I remember to do when taking the car for a drive?'},
#  {'id': '493', 'text': 'Can the key fob lock the car automatically?'},
#  {'id': '494',
#   'text': 'Is there a way to drive the car if my phone and key card are both unavailable?'},
#  {'id': '495',
#   'text': 'Do I need to pull the door handle for the doors to unlock using the phone key?'},
#  {'id': '496',
#   'text': 'What is the maximum number of key fobs Model Y can support?'},
#  {'id': '497', 'text': 'If my phone is stolen, can I still access my car?'},
#  {'id': '498',
#   'text': "I'm at the beach and concerned about leaving my phone in the car. Any advice?"},
#  {'id': '499',
#   'text': "What should I know about the phone's Bluetooth when it comes to the phone key?"},
#  {'id': '500',
#   'text': 'How do I use my phone as a key for the car without an internet connection?'},
#  {'id': '501',
#   'text': 'If I want to listen to music from my phone in the car, what do I need to do?'},
#  {'id': '502',
#   'text': "Where do I go in the car's settings to see which keys can access my Model Y?"},
#  {'id': '503',
#   'text': 'Can I remove a phone key from the car without the phone being present?'},
#  {'id': '504',
#   'text': 'What happens if I have more than three phone keys near the car?'},
#  {'id': '505',
#   'text': "How do I lock or unlock the car using my phone's NFC capability?"},
#  {'id': '506',
#   'text': "Where on the driver's side door should I hold my phone for the NFC lock/unlock?"},
#  {'id': '507',
#   'text': "What's the process for using a key card to unlock the car?"},
#  {'id': '508',
#   'text': 'Does the car make any sound when I unlock or lock it using the key card?'},
#  {'id': '509',
#   'text': 'Do I have to hold the key card to the car for a certain amount of time to unlock it?'},
#  {'id': '510',
#   'text': "What should I do if the key card isn't unlocking the car?"},
#  {'id': '511',
#   'text': "Once I'm in the car, how do I power it up using the key card?"},
#  {'id': '512', 'text': 'How many key cards do I get with my Model Y?'},
#  {'id': '513',
#   'text': 'Can I keep the key card in my wallet while using it to unlock the car?'},
#  {'id': '514',
#   'text': "What should I do if the mirrors don't fold when I lock or unlock the car?"},
#  {'id': '515',
#   'text': 'Is there a specific position I should hold the key card for it to work?'},
#  {'id': '516',
#   'text': 'Why might I need to press the brake pedal after scanning the key card?'},
#  {'id': '517',
#   'text': "What should I check if I can't unlock the car with my phone?"},
#  {'id': '518',
#   'text': 'What indications does the car give when successfully unlocking with the key card?'},
#  {'id': '519',
#   'text': "How do I turn off the Lock Confirmation Sound if I don't want the horn to sound?"},
#  {'id': '520',
#   'text': "What should I do if the car doesn't recognize my key card?"},
#  {'id': '521',
# ...
#  {'id': '828',
#   'text': "What happens if I double-click the rear trunk button while it's moving?"},
#  {'id': '829',
#   'text': 'Is it possible to manually stop the liftgate in an emergency?'},
#  {'id': '830',
#   'text': 'What safety precautions should I take before using the liftgate?'},
#  {'id': '831',
#   'text': 'Where can I find the low voltage power socket in the trunk?'},
#  {'id': '832',
#   'text': 'I want to open the liftgate but no valid key is detected. What should I do?'},
#  {'id': '833',
#   'text': "My garage has a low ceiling. How do I adjust the liftgate's height?"},
#  {'id': '834',
#   'text': 'If I press the rear trunk button once, what does it do?'},
#  {'id': '835',
#   'text': 'What should I do if the liftgate might hit an object while opening?'},
#  {'id': '836',
#   'text': "Can I override the liftgate's movement if it's already in action?"},
#  {'id': '837',
#   'text': 'Why is there an indicator light on the touchscreen showing my trunk is open?'},
#  {'id': '838',
#   'text': 'How can I ensure the liftgate does not injure someone during operation?'},
#  {'id': '839',
#   'text': "I double-clicked the trunk button but it didn't open. Why could that be?"},
#  {'id': '840', 'text': 'How do I adjust the liftgate to my preferred height?'},
#  {'id': '841',
#   'text': 'What should I do if I want the liftgate to open to a specific height?'},
#  {'id': '842',
#   'text': 'How long do I need to hold the button on the liftgate to set its height?'},
#  {'id': '843',
#   'text': 'I hear a chime when adjusting the liftgate. What does it mean?'},
#  {'id': '844',
#   'text': "What is the maximum height the car's liftgate can open to?"},
#  {'id': '845',
#   'text': "I'm worried the liftgate might hit the garage ceiling. How can I prevent that?"},
#  {'id': '846',
#   'text': 'Why is it important to adjust the liftgate height properly?'},
#  {'id': '847',
#   'text': 'Does the liftgate height depend on the car’s suspension?'},
#  {'id': '848',
#   'text': "If I'm setting the liftgate to a new height, how do I verify it?"},
#  {'id': '849',
#   'text': 'What should I be cautious about when adjusting the liftgate height?'},
#  {'id': '850',
#   'text': 'Is there a precaution I need to take when selecting wheel configuration regarding the liftgate?'},
#  {'id': '851',
#   'text': 'Can the liftgate height be too high for low ceilings?'},
#  {'id': '852',
#   'text': 'What happens if I don’t hear a chime when setting the liftgate?'},
#  {'id': '853',
#   'text': "The liftgate doesn't seem to open to the right height. What could be wrong?"},
#  {'id': '854',
#   'text': 'I want to prevent damage to the liftgate. What should be the ideal adjustment?'},
#  {'id': '855',
#   'text': 'How can the suspension height affect the liftgate operation?'},
#  {'id': '856',
#   'text': "What's the procedure to check if the liftgate is set correctly?"},
#  {'id': '857',
#   'text': 'Is there a sound confirmation for setting the liftgate height?'},
#  {'id': '858',
#   'text': 'Can you explain the process to reopen the liftgate after setting its height?'},
#  {'id': '859',
#   'text': 'I need to change the liftgate height setting. What are the steps again?'},
#  {'id': '860',
#   'text': 'What are the different methods to close the liftgate?'},
#  {'id': '861', 'text': 'How can I use the key fob to close the liftgate?'},
#  {'id': '862',
#   'text': "If there's an obstruction when the liftgate is closing, what will happen?"},
#  {'id': '863',
#   'text': 'The liftgate chimes twice and stops. What should I do?'},
#  {'id': '864', 'text': 'How do I close the parcel shelf properly?'},
#  {'id': '865',
#   'text': 'Can you explain how to fold and unfold the parcel shelf?'},
#  {'id': '866',
#   'text': 'Is there a way to completely remove the parcel shelf?'},
#  {'id': '867',
#   'text': 'What precautions should I take regarding the parcel shelf?'},
#  {'id': '868', 'text': 'How can I access the cargo area in the rear trunk?'},
#  {'id': '869', 'text': 'What is the safest way to secure cargo in my car?'},
#  {'id': '870', 'text': 'Where should heavy cargo be placed in the trunk?'},
#  {'id': '871',
#   'text': 'What is the maximum weight I can load in the lower compartment of the rear trunk?'},
#  {'id': '872',
#   'text': 'How much weight can I safely load in the upper compartment above the lower trunk cover?'},
#  {'id': '873',
#   'text': "What's the best way to distribute weight in the car's trunk areas?"},
#  {'id': '874', 'text': 'What precautions should I take when loading cargo?'},
#  {'id': '875', 'text': 'Can I place heavy objects on the parcel shelf?'},
#  {'id': '876', 'text': "How do I know if I've exceeded the GVWR?"},
#  {'id': '877',
#   'text': 'Is there a specific technique to fold the cargo cover forward?'},
#  {'id': '878', 'text': 'What are the benefits of using the parcel shelf?'},
#  {'id': '879', 'text': 'Why should I secure all cargo before driving?'},
#  {'id': '880',
#   'text': 'What should I do before opening the front trunk of my car?'},
#  {'id': '881', 'text': 'How can I open the front trunk using the key fob?'},
#  {'id': '882',
#   'text': 'Is it necessary to have the car in Park before opening the front trunk?'},
#  {'id': '883', 'text': 'Tell me how to close the hood properly.'},
#  {'id': '884',
#   'text': "I can't get the hood to latch. What am I doing wrong?"},
#  {'id': '885', 'text': 'Do I need to close the hood using both hands?'},
#  {'id': '886',
#   'text': 'What might happen if I apply pressure to the wrong area of the hood?'},
#  {'id': '887', 'text': 'How can I check if the hood is fully closed?'},
#  {'id': '888', 'text': 'Why should I not slam the hood shut?'},
#  {'id': '889',
#   'text': 'The touchscreen is showing a Door Open indicator. What does that mean?'},
#  {'id': '890',
#   'text': 'Why is it important to check for obstacles before opening the hood?'},
#  {'id': '891',
#   'text': 'Can the hood latch just by lowering it without any pressure?'},
#  {'id': '892',
#   'text': 'Describe the correct way to apply pressure when closing the hood.'},
#  {'id': '893',
#   'text': 'Help me understand the warning about ensuring the hood is closed before driving.'},
#  {'id': '894',
#   'text': "What's the best way to prevent scratches when I'm closing the hood?"},
#  {'id': '895',
#   'text': 'How does the image of my car on the touchscreen help with the trunk?'},
#  {'id': '896', 'text': "What's the risk of closing the hood with one hand?"},
#  {'id': '897',
#   'text': "Why shouldn't I apply pressure to the front edge of the hood?"},
#  {'id': '898', 'text': 'How can I open the front trunk using the mobile app?'},
#  {'id': '899',
#   'text': 'Explain the potential dangers of having an open door or trunk while driving.'},
#  {'id': '900',
#   'text': 'What happens if I try to drive with the front trunk open?'},
#  {'id': '901', 'text': 'Can I drive my car if the front trunk is open?'},
#  {'id': '902',
#   'text': 'How is vehicle speed affected if the front trunk remains open while driving?'},
#  {'id': '903', 'text': 'When does the front trunk lock automatically?'},
#  {'id': '904',
#   'text': 'Does the front trunk lock when I lock my car using the touchscreen?'},
#  {'id': '905',
#   'text': 'What will the car do if I leave carrying my key with the front trunk open?'},
#  {'id': '906',
#   'text': 'Is there any special notification on the touchscreen if the front trunk is left open?'},
#  {'id': '907', 'text': 'How does Walk-Away Door Lock affect the front trunk?'},
#  {'id': '908', 'text': 'Does activating Valet Mode lock the front trunk?'},
#  {'id': '909',
#   'text': "If I'm in Valet Mode, is the front trunk automatically locked?"},
#  {'id': '910',
#   'text': 'Explain the notification on the touchscreen if the front trunk is open.'},
#  {'id': '911',
#   'text': 'Tell me about the conditions under which the front trunk locks.'},
#  {'id': '912',
#   'text': 'Will my vehicle speed be limited if I drive with the front trunk open? Why?'},
#  {'id': '913',
#   'text': 'Can you tell me what happens if I use the mobile app to lock the car with the front trunk open?'},
#  {'id': '914',
#   'text': 'Is it possible to keep the front trunk open and still drive the car?'},
#  {'id': '915',
#   'text': 'What happens if I try to shift out of Park with the front trunk open?'},
#  {'id': '916',
#   'text': 'If I lock the car with the key, what happens to the front trunk?'},
#  {'id': '917',
#   'text': 'What role does the Walk-Away Door Lock play in locking the front trunk?'},
#  {'id': '918',
#   'text': 'I want to know if the front trunk will lock automatically in Valet Mode.'},
#  {'id': '919',
#   'text': 'How do the locking features interact with the front trunk when I leave the car?'},
#  {'id': '920',
#   'text': 'How much weight can I safely load in the front trunk?'},
#  {'id': '921',
#   'text': 'What could happen if I load more than 110 lbs in the front trunk?'},
#  {'id': '922',
#   'text': 'Where is the interior release button located in the front trunk?'},
#  {'id': '923',
#   'text': 'Can you explain how the illuminated interior release button works?'},
#  {'id': '924',
#   'text': 'What is the purpose of the interior release button in the front trunk?'},
#  {'id': '925',
#   'text': 'Is there a way for someone to get out if they are locked in the front trunk?'},
#  {'id': '926',
#   'text': 'Why does the interior release button glow after exposure to light?'},
#  {'id': '927',
#   'text': 'Should I be worried about objects hitting the release button inside the trunk?'},
#  {'id': '928',
#   'text': 'Why should people never climb inside the front trunk?'},
#  {'id': '929',
#   'text': 'What precautions should I take when closing the front trunk?'},
#  {'id': '930',
#   'text': 'How do I distribute cargo weight between the front and rear trunks properly?'},
#  {'id': '931',
#   'text': 'Can the front trunk accidentally open if something hits the release button?'},
#  {'id': '932',
#   'text': 'What is the maximum load capacity for the front trunk?'},
#  {'id': '933',
#   'text': "What do I need to consider about the car's total weight when loading cargo?"},
#  {'id': '934',
#   'text': 'Why is it important to follow the Gross Vehicle Weight Rating?'},
#  {'id': '935',
#   'text': 'How can I prevent damage when loading items in the front trunk?'},
#  {'id': '936',
#   'text': "What happens if I don't consider the Gross Vehicle Weight Rating?"},
#  {'id': '937',
#   'text': 'Is it safe to shut the trunk with someone inside as a prank?'},
#  {'id': '938',
#   'text': 'Can anything trigger the release button without pressing it directly?'},
#  {'id': '939',
#   'text': 'How can I ensure the load is balanced between the front and rear trunks?'},
#  {'id': '940',
#   'text': 'How do I open the main storage compartment in the center console?'},
#  {'id': '941',
#   'text': 'Can you explain how to access the rear cup holders in my car?'},
#  {'id': '942', 'text': 'Where are the coat hangers located inside the car?'},
#  {'id': '943',
#   'text': 'Is there a light in the glovebox and when does it turn off?'},
#  {'id': '944',
#   'text': 'What is the process for opening the front storage compartment in the center console?'},
#  {'id': '945',
#   'text': 'Does my car have wireless phone charging capabilities?'},
#  {'id': '946', 'text': 'How can I close the glovebox securely?'},
#  {'id': '947',
#   'text': 'What should I do to release the coat hanger in the second row?'},
#  {'id': '948', 'text': 'How do I lock the glovebox for additional security?'},
#  {'id': '949', 'text': "What's the procedure to set a PIN for the glovebox?"},
#  {'id': '950', 'text': 'How can I use the rear console as an armrest?'},
#  {'id': '951',
#   'text': 'Where can I find the cup holders for the third row in the seven-seat model?'},
#  {'id': '952',
#   'text': 'Does the center console include RFID features for reading key fobs?'},
#  {'id': '953',
#   'text': 'Can the glovebox light turn off automatically and when?'},
#  {'id': '954',
#   'text': 'What should I be aware of regarding the glovebox when driving?'},
#  {'id': '955', 'text': 'How do I access the glovebox using the car controls?'},
#  {'id': '956', 'text': 'Under what circumstances will the glovebox not lock?'},
#  {'id': '957',
#   'text': 'What happens to the glovebox when the Model Y is in Valet Mode?'},
#  {'id': '958',
#   'text': 'What actions can cause the glovebox to lock automatically?'},
#  {'id': '959',
#   'text': 'Where exactly can I find the coat hanger next to the reading light in the second row?'},
#  {'id': '960',
#   'text': 'How should I position my seat to ensure proper airbag safety?'},
#  {'id': '961',
#   'text': 'Can you guide me on the best seat position for reaching the pedals?'},
#  {'id': '962',
#   'text': 'My arms get tired on long drives. Is my seat set up correctly?'},
#  {'id': '963',
#   'text': 'What’s the right distance between my chest and the airbag?'},
#  {'id': '964',
#   'text': 'How do I correctly position the shoulder section of the seat belt?'},
#  {'id': '965',
#   'text': 'I’m uncomfortable with my seat belt across my stomach. How should I adjust it?'},
#  {'id': '966',
#   'text': 'Why can’t I adjust the head support in the front seats?'},
#  {'id': '967', 'text': 'How do I move the front seat forward or backward?'},
#  {'id': '968',
#   'text': 'I need to change the height of my seat. How do I do that?'},
#  {'id': '969',
#   'text': "What adjustments can be made to the seat's tilt angle?"},
#  {'id': '970', 'text': 'How do I adjust the backrest of my seat?'},
#  {'id': '971', 'text': 'What should I know about adjusting lumbar support?'},
#  {'id': '972',
#   'text': 'What risk is there if I move the front seat’s backrest fully forward?'},
#  {'id': '973', 'text': 'What should I check before I adjust a front seat?'},
#  {'id': '974',
#   'text': 'Can you remind me of the precaution with the sun visor and seat adjustment?'},
#  {'id': '975', 'text': 'Is it safe to adjust seats while the car is moving?'},
#  {'id': '976',
#   'text': 'The seat seems too close to the visor. What might be the problem?'},
#  {'id': '977',
#   'text': 'How can I ensure there are no obstacles around the seat before adjusting it?'},
#  {'id': '978',
#   'text': 'I find the lumbar support uncomfortable. How can I adjust it better?'},
#  {'id': '979',
#   'text': 'I’m unsure if my seat is positioned safely. How do I check?'},
#  {'id': '980', 'text': 'Can I adjust the seats while the car is moving?'},
#  {'id': '981',
#   'text': "Why shouldn't I recline the seat back too much while driving?"},
#  {'id': '982',
#   'text': "How can I calibrate the driver seat if it's not adjusting automatically?"},
#  {'id': '983',
#   'text': 'Is it safe to keep items under the driver seat during calibration?'},
#  {'id': '984',
#   'text': 'How do I adjust the second row seats in a 5-seat configuration?'},
#  {'id': '985',
#   'text': 'How do I make sure the seat back is secure after adjusting it?'},
#  {'id': '986',
#   'text': "What's the procedure for adjusting second row seats in the 7-seat model?"},
#  {'id': '987',
#   'text': 'How do I fold the second row seat backs for more cargo space?'},
#  {'id': '988',
#   'text': 'Does adjusting the left second row seat back affect the center seat in the 5-seat model?'},
#  {'id': '989',
#   'text': 'Can I push the second row seat backs forward without holding the handle?'},
#  {'id': '990',
#   'text': 'Is it different to adjust the second row seat backs for 5-seat versus 7-seat versions?'},
#  {'id': '991',
#   'text': 'What should I be careful of when folding the seat backs flat?'},
#  {'id': '992',
#   'text': 'Is there a risk of sliding under the seat belt if my seat is reclined during a drive?'},
#  {'id': '993', 'text': 'How do I know if I need to calibrate my driver seat?'},
#  {'id': '994',
#   'text': 'What are the steps to follow for seat calibration on the touchscreen?'},
#  {'id': '995',
#   'text': 'Are the adjustment handles the same for both 5-seat and 7-seat models?'},
#  {'id': '996',
#   'text': 'Where exactly can I find the handle for adjusting the second row seat in my 7-seat car?'},
#  {'id': '997',
#   'text': 'Should I check anything specific before I start calibrating the seats?'},
#  {'id': '998',
#   'text': "What could happen if I don't properly latch the seat back into position?"},
#  {'id': '999',
#   'text': 'Does adjusting the seats affect passenger safety in any way?'},
#  ...]

# %%
assert len(queries_l) == query_len

# %%
import math

# %%
add_factor = 10 ** math.ceil(math.log10(len(queries)))
add_factor
# Out:
# 100000

# %%
corpus_l = []
corpus_to_id = {}
for i in range(len(corpus)):
    docid = str(add_factor + i)
    corpus_l.append({"id": docid, "title": "", "text": corpus[i]})
    corpus_to_id[corpus[i]] = docid

# %%
corpus_l
# Out:
# [{'id': '100000',
#   'title': '',
#   'text': '1. Exterior lights (Lights on page 72)\n2. Autopilot camera (Cameras on page 19)\n3. Front door handle (Using Exterior Door Handles on page 25)\n4. Key card sensor (Keys on page 21), Autopilot camera (Cameras on page 19)\n5. Rear door handle (Using Exterior Door Handles on page 25)\n6. Charge port (Charging Instructions on page 174)\n7. Autopilot cameras (Cameras on page 19)\n8. Exterior mirrors (Mirrors on page 68)\n9. Radar sensor, if equipped (hidden from view)\n10. Hood/front trunk (Front Trunk on page 30)\n11. Front tow eye cover (Instructions for Transporters on page 225)\n12. Wheels and tires (Wheels and Tires on page 218)\n13. Rear trunk (Rear Trunk on page 28)\n14. Rear view camera (Rear Facing Camera(s) on page 90)\n15. Rear tow eye cover (Instructions for Transporters on page 225)\nExterior\n3\nOverview\n1. Door open button (Opening Doors from the Interior on page 25)\n2. Turn signal stalk (High Beam Headlights on page 73), Turn Signals on page 74, and Wipers and Washers on page 75)\n3. Horn (Horn on page 67)\n4. Drive stalk (How to Shift on page 70, Autopilot Features on page 102)\n5. Touchscreen (Touchscreen on page 5)\n6. Driver dome light (Lights on page 72)\n7. Cabin camera (Cabin Camera on page 141)\n8. Hazard warning flashers (Hazard Warning Flashers on page 74)\n9. Passenger dome light (Lights on page 72)\n10. Climate control vent (see Operating Climate Controls on page 149)\n11. Power window switches (Windows on page 27)\n12. Manual door release (Opening Doors from the Interior on page 25)\n13.'},
#  {'id': '100001',
#   'title': '',
#   'text': "Manual door release (Opening Doors from the Interior on page 25)\n13. Left scroll button (Scroll Buttons on page 66)\n14. Brake pedal (Braking and Stopping on page 76)\n15. Accelerator pedal (Regenerative Braking on page 77)\n16. Right scroll button (Scroll Buttons on page 66)\n17. Center console (Interior Electronics on page 9)\n18. Glovebox (Glovebox on page 32)\nInterior\n4\nMODEL Y Owner's Manual"},
#  {'id': '100002',
#   'title': '',
#   'text': 'WARNING: Always pay attention to road and traffic conditions when driving. To minimize driver distraction and ensure \nthe safety of vehicle occupants as well as other road users, avoid using the touchscreen to adjust settings while the \nvehicle is in motion.\nUse the touchscreen to control many features that, in traditional cars, are controlled using physical buttons (for example, \nadjusting the cabin heating and air conditioning, headlights, etc.). You also use the touchscreen to control media, navigate, \nuse entertainment features, and customize Model Y to suit your preferences. For hands-free access to common touchscreen \ncontrols, use voice commands (see Voice Commands on page 17).\nIf the touchscreen is unresponsive or demonstrates unusual behavior, you can restart it (see Restarting the Touchscreen on \npage 7).\nCAUTION: Do not apply a screen protector on the touchscreen. Doing so can result in unintended inputs to the \ntouchscreen (phantom inputs), delayed response or unresponsiveness to touches, electrostatic discharge which can \ndamage the touchscreen, etc. Any damage caused by installing a screen protector is not covered by the warranty.\nNOTE: Illustrations are provided to improve conceptual understanding only. Depending on vehicle options, software version, \nmarket region and regional and language settings, the details displayed on the screen will differ.\n1. Status bar: Find car controls and status in the top bar (see Top Status Bar Icons on page 6).\n2. Navigation: Change the orientation of the map, find or navigate to a destination, and change navigation settings (see Maps \nand Navigation on page 159).\n3. Car status: This area dynamically displays the current status of Model Y as you drive, park, open doors, turn lights on, etc. \nMonitor this area when driving as it displays important information such as driving speed and warning messages (see Car \nStatus on page 12). When the car is in Park, you can open the trunks or charge port door. This area also houses shortcut \n"cards" for Media, tire pressures, and Trip Information.\nTouchscreen\n5\nOverview'},
#  {'id': '100003',
#   'title': '',
#   'text': "When full self-driving is enabled (if equipped), the car status area displays visualizations of the road and your vehicle's \nsurroundings. You can expand/condense the visualization by dragging the car status area from side to side. Expanding the \nvisualization displays more details about the roadway and its surroundings, including road markings, stop lights, and \nobjects (such as trash cans and poles).\n4. Controls: Control various features and customize Model Y to suit your preferences. The Controls screen appears over the \nmap. Touch an option on the Controls screen to display the various settings and preferences associated with the chosen \noption.\nTo search for a specific setting, touch Search at the top of the Controls screen. Make changes directly from the result or \ntouch the link to jump to that option in Controls.\nWhen an information icon displays beside a specific setting, touch it to display a popup that provides helpful \ndetails about the associated setting.\nNOTE: Many vehicle controls, settings, and preferences (such as climate, media, and navigation) can be adjusted hands-\nfree using voice commands (see Voice Commands on page 17).\nNOTE: You can send touchscreen feedback to Tesla by long-pressing this icon.\n5. Climate controls (driver): Use the left and right arrows to decrease/increase cabin temperature. Touch Split on the popup to \ndisplay separate controls for the driver and passenger. Touch the temperature icon to customize climate control settings \n(see Operating Climate Controls on page 149). The passenger climate controls display when temperature controls have \nbeen Split to provide separate controls for the driver and passenger.\n6. My Apps: For one-touch access to frequently used apps and controls, you can choose what displays here. See Customizing \nMy Apps on page 6.\n7. App Launcher: Touch the app launcher to open the app tray. Then touch any app to open it. The app you choose displays on \ntop of the map. To close an app, drag it downward.\n8. Recent App(s): Displays the most recently used app(s). The number of recent apps displayed here depends on how many \napps have been added to My Apps."},
#  {'id': '100004',
#   'title': '',
#   'text': 'If you add the maximum number of apps to My Apps, only the most recent app displays.\n9. Volume Control: Controls the volume of media player and phone calls (see Volume Controls on page 165). The volume of \nnavigation instructions is controlled separately (see Maps and Navigation on page 159).\n10. Full-screen Park view: (If equipped) Swipe towards the passenger for a full-screen Park view with media and navigation \ncontrols.\nCustomizing My Apps\nFor one-touch access to commonly used apps and controls, \nyou can customize what displays in the My Apps area on the \ntouchscreen\'s bottom bar:\n1. Enter customization mode by touching and holding any \napp or control in the My Apps area. If this area is empty, \ntouch the App Launcher.\n2. Drag any app or control from the app tray onto the My \nApps area in the bottom bar.\nNOTE: Seat heaters selected from the app tray appear \nnext to the temperature, instead of in the My Apps area.\nNOTE: When you\'ve added the maximum number of apps or \ncontrols to My Apps, adding an additional app removes the \nrightmost app.\nNOTE: Remove an app or control from the My Apps area by \ntouching and holding, then touching its associated "X".\nTop Status Bar Icons\nTouch to lock/unlock all doors and trunks.\nDisplays the local weather conditions. Touch \nto display more detailed information about \nthe weather and air quality, including chance \nof rain, humidity, and UV index. Requires \npremium connectivity.\nDisplays the current temperature. If your \nvehicle is equipped with premium \nconnectivity, you can also touch to display \nmore detailed information about the weather \nand air quality, including chance of rain, \nhumidity, and UV index.\nTouchscreen\n6\nMODEL Y Owner\'s Manual'},
#  {'id': '100005',
#   'title': '',
#   'text': "Displays on the touchscreen status bar only \nwhen Model Y detects that the local Air \nQuality Index (AQI) value is poor. A poor \nAQI will have yellow, orange, red, purple, or \nmaroon numbers. Touch to display more \ndetailed information about the weather and \nair quality, including chance of rain, \nhumidity, and UV index. Requires premium \nconnectivity.\n4:20 pm\nYour vehicle automatically updates the time. \nIf the time is incorrect, confirm your vehicle \nhas internet and GPS connectivity with the \nlatest software.\nDisplays on the touchscreen status bar only \nwhen Model Y detects a programmed \nHomeLink within range, and the \ntouchscreen is not already displaying the \nHomeLink screen or popup. See Smart \nGarage on page 62.\nDisplays on the touchscreen status bar only \nwhen Model Y is parked. Add, configure \n(including Valet Mode and Use Easy Entry), \nor quickly switch driver profiles. Driver \nprofiles can also be accessed from the top \nof any Controls screen. See Driver Profiles \non page 87.\nAvailable when Model Y is parked, touch to \nmanually enable or disable Sentry Mode for \nthe current drive cycle. To automatically turn \nSentry Mode on (or off) every time you leave \nyour vehicle, enable the setting from \nControls > Safety > Sentry Mode. See Sentry \nMode on page 146 for more information.\nNOTE: If you turn Sentry Mode on or off \nfrom Controls > Sentry Mode, the shortcuts \non the vehicle's touchscreen and mobile app \nwill only work for the current drive cycle.\nNOTE: For some vehicles manufactured \nafter approximately November 1, 2021, the \ncenter console USB ports may only support \ncharging devices. Use the USB port inside \nthe glove box for all other functions.\nDisplays when Model Y is connected to a \nWi-Fi network.\nDisplays when Model Y is connected to a \ncellular network. Touch this icon for quick \naccess to Wi-Fi settings.\nDisplays when Model Y cellular connectivity \nis unavailable. Touch this icon for quick \naccess to Wi-Fi settings."},
#  {'id': '100006',
#   'title': '',
#   'text': "Touch this icon for quick \naccess to Wi-Fi settings.\nStatus of the front passenger airbag (see \nAirbags on page 50).\nAppears when your vehicle's GPS location is \nactively being accessed in the Tesla mobile \napp by the owner, an added driver, or a third \nparty app you're using. Tap the icon for \ndetails. To disable, navigate to Safety > \nAllow Mobile Access on the touchscreen.\nPopup Messages and Vehicle Alerts\nPopup messages appear at the bottom of the touchscreen. \nFor example, a seat belt reminder appears if a seat belt is \nunfastened in an occupied seat, an alert appears to notify you \nof an incoming phone call, a text message appears (when \napplicable), and voice commands appear when in use. If \napplicable, touch options from these popup messages (for \nexample, accept/decline a phone call, choose an option from \nthe headlight menu, etc.). To dismiss a popup message, \nswipe it downward.\nIf an alert appears on your vehicle's touchscreen, touch Learn \nMore for more details regarding the alert and how it can be \nresolved. You can view a list of vehicle alerts and \nnotifications by touching the bell icon at the top of Controls.\nNOTE: Not all alerts provide additional information at this \ntime.\nRestarting the Touchscreen\nYou can restart your touchscreen if it is unresponsive or \ndemonstrates unusual behavior.\nWARNING: Only restart the touchscreen while the \nvehicle is stopped and in Park. The car status display, \nsafety warnings, backup camera, etc. will not be visible \nduring the restart.\n1. Shift into Park.\n2. Hold down both scroll buttons on the steering wheel until \nthe touchscreen turns black. Pressing the brake pedal \nwhile holding down the scroll buttons does not have any \nimpact and is not required.\nTouchscreen\n7\nOverview"},
#  {'id': '100007',
#   'title': '',
#   'text': "3. After a few seconds, the Tesla logo appears. Wait \napproximately 30 seconds for the touchscreen to restart. \nIf the touchscreen is still unresponsive or demonstrating \nunusual behavior after a few minutes, try power cycling \nthe vehicle (if possible). See Power Cycling the Vehicle on \npage 65.\nNOTE: Pressing the scroll buttons only restarts the \ntouchscreen. It does not restart any other vehicle component \nand does not power Model Y off and on.\nCustomizing Display and Sound Settings\nTouch Controls > Display to adjust display settings to suit \nyour preferences:\n• Appearance: Customize the display to be Dark or Light. \nWhen set to Auto, the brightness changes automatically \nbased on ambient lighting conditions.\n• Reduce Blue Light: When enabled, the display \nautomatically adjusts to use warmer colors at night.\n• Brightness: Drag the slider to manually control the \nbrightness level. If Display Mode is set to Auto, the \ntouchscreen further adjusts based on both the ambient \nlighting conditions and your brightness preference. Model \nY remembers your chosen brightness preference and \nadjusts the touchscreen accordingly.\n• Screen Clean Mode: When enabled, your touchscreen \ndarkens and temporarily disables to facilitate cleaning. \nFollow the onscreen instructions to exit Screen Clean \nMode.\n• Touchscreen Language: Select the language that the \ntouchscreen displays.\nNOTE: Model Y must be in Park to change the language. \nWhen you change the language, you experience a brief \ndelay as Model Y shuts down and restarts the \ntouchscreen.\n• Voice Recognition Language: Choose the language to be \nused for voice commands.\n• Voice Navigation Language: Choose the language that the \nnavigation system uses for spoken instructions.\nNOTE: For languages that require a download, select the \nlanguage in the dropdown list to initiate the download \n(Wi-Fi connection required).\n• Text size: Select between Standard and Large to \ncustomize the text size on your vehicle's touchscreen.\n• Time: Choose to display time in either 12 or 24 hour \nformat.\n• Energy Display: Choose to display remaining energy and \ncharging units as either a percentage of battery energy \nremaining, or as an estimate of the distance you can drive."},
#  {'id': '100008',
#   'title': '',
#   'text': "NOTE: When anticipating when you need to charge, use \nenergy estimate as a general guideline only. Many factors \nhave an impact on energy consumption. See Factors \nAffecting Energy Consumption on page 182.\n• Distance: Choose to display measurements in metric \n(kilometers, centimeters, etc.) or imperial (miles, inches, \netc.) units.\n• Temperature: Choose to display temperature using \nFahrenheit or Celsius.\n• Tire Pressure: Choose to display tire pressures using BAR \nor PSI.\nIn addition to customizing the display, you can enable Joe \nMode to reduce the volume of all chimes that are not related \nto critical safety issues. Touch Controls > Safety > Joe Mode \nto enable.\nNaming your Vehicle\nTo further personalize your vehicle, you can name it. Touch \nControls > Software > Name Your Vehicle located on the right \nside of the touchscreen below the image of Model Y. If your \nvehicle already has a name, touch the existing name to \nchange it. Enter the new name in the popup and touch Save. \nThe name of your Model Y also appears in the Tesla mobile \napp.\nErasing Personal Data with a Factory \nReset\nWhen transferring ownership of Model Y, perform a factory \nreset for security purposes before removing your vehicle \nfrom your account by touching Controls > Service > Factory \nReset. Before erasing data, Model Y verifies your credentials \nby prompting you to enter the user name and password \nassociated with your Tesla account.\nNOTE: Performing a factory reset is only possible when the \nvehicle is in your account. After the vehicle is removed from \nyour account, you no longer have access to perform a reset \nof customized settings to the factory defaults and to erase all \npersonal data.\nTouchscreen\n8\nMODEL Y Owner's Manual"},
#  {'id': '100009',
#   'title': '',
#   'text': 'In addition to storage compartments and cup holders (see \nInterior Storage on page 32), the Model Y interior supports \nvarious electronics such as an RFID transmitter that reads \nkey fobs and key cards (see Keys on page 21), USB ports, a \nwireless phone charger, and a 12V power socket.\nUSB Ports\nModel Y has two USB ports located in the front compartment \nof the center console. These ports can be used to:\n• Connect and charge USB devices.\n• Play audio files stored on a phone or USB device (see \nPlaying Media from Devices on page 166).\n• Save videos when using features such as Sentry Mode or \nDashcam (see Dashcam on page 144 and Sentry Mode on \npage 146).\nNOTE: If your Model Y is equipped with a USB port \nlocated in the glove box (described below), it is \nrecommended that you use the glovebox USB to save \nSentry Mode or Dashcam videos because power \nconsumption is minimized and the location is more \nsecure.\nThe USB ports can output power up to approximately 15W \n(which may vary depending on vehicle manufacture date).\nNOTE: For some vehicles manufactured after approximately \nNovember 1, 2021, the center console USB ports may only \nsupport charging devices. Use the USB port inside the glove \nbox for all other functions.\nBoth ports are USB-C compatible.\nSee USB Drive Requirements for Recording Videos on page \n148 for information about formatting USB flash drives.\nOpen the front compartment of the center console. The front \nUSB ports are located on the rear wall of the compartment.\nDepending on date of manufacture, some vehicles include a \nUSB port located inside the glovebox. This USB-A port is \nequipped with a pre-formatted flash drive, ready to save \nvideos when using features such as Sentry Mode and \nDashcam. Although not its primary purpose, this port can \nalso communicate with the vehicle and can be used to charge \na USB-connected device.\nTwo additional USB ports are located in the rear of the center \nconsole (on vehicles manufactured since approximately June \n2020, these ports are USB-C). These ports charge USB-\nconnected devices but do not communicate with the vehicle.'},
#  {'id': '100010',
#   'title': '',
#   'text': 'These ports charge USB-\nconnected devices but do not communicate with the vehicle.\nIf Model Y is equipped with seven seats, two USB-C ports \nare located at the front of the console located between the \nthird row seats. These ports charge USB-connected devices \nbut do not communicate with the vehicle.\nInterior Electronics\n9\nOverview'},
#  {'id': '100011',
#   'title': '',
#   'text': "NOTE: Power is available when the vehicle detects that a user \nis present. A user is considered present when a person is in \nthe driver seat or interacts with the touchscreen. Power is \nalso available whenever the low voltage battery is being \ncharged or is in use, when you charge the high voltage \nBattery, or when the vehicle is communicating with the \nmobile app. Leaving an accessory plugged in does not \ndeplete the low voltage battery.\nNOTE: Use USB 3.0 compliant cables to connect a device to a \nUSB port. Using non-compliant cables can result in slower \ncharging, potential connection problems or degraded \nperformance.\nNOTE: Do not connect multiple devices using a USB hub. This \ncan prevent connected devices from charging or from being \nrecognized by Media Player, Sentry Mode, Dashcam, etc.\nWireless Phone Charger\nA wireless phone charger (if equipped), is integrated into the \nfront console to provide up to 15W of power to charge a Qi-\nenabled phone. Simply place your phone on the charger. Your \ndevice may feel warm while charging, but this is a normal \neffect of inductive charging.\nWhen placed on the wireless charger, your phone charges \nwhenever the vehicle is powered on (the touchscreen is on \nand you are inside the vehicle). Your phone will not charge \nafter exiting the vehicle unless a feature (such as Sentry \nmode) is enabled and providing power to the USB ports. \nModel Y will also not charge a phone if the vehicle's Battery \nis discharged.\nNOTE: The phone must be in direct contact with the wireless \ncharger. The wireless phone charger may not work if your \nphone case is too large or is made of metal. Try removing the \nphone from its case before placing in the charger.\nCAUTION: Before you charge, remove any objects \n(coins, keys, metal objects, etc.) between the phone \nand charger, as well as any NFC cards (for example, the \nvehicle key card, credit cards, or hotel key) placed on \nor behind the phone (like with integrated phone cases). \nDamage to NFC cards can occur when you charge the \nphone without first removing the card."},
#  {'id': '100012',
#   'title': '',
#   'text': "Damage to NFC cards can occur when you charge the \nphone without first removing the card.\nLow Voltage Power Socket\nYour Model Y has a power socket located in the center \nconsole's rear compartment.\nThe power socket is suitable for accessories requiring up to \n12A continuous draw (16A peak).\nNOTE: For vehicles manufactured after approximately \nNovember 2021, power inverters plugged into the low \nvoltage power socket must support 16V DC input to function.\nAn additional low voltage power socket is located on the left \nside of the rear trunk.\nNOTE: Power is available when the vehicle detects that a user \nis present. A user is considered present when a person is in \nthe driver seat or interacts with the touchscreen. Power is \nalso available whenever the low voltage battery is being \ncharged or is in use, when you charge the high voltage \nBattery, or when the vehicle is communicating with the \nmobile app. Leaving an accessory plugged in does not \ndeplete the low voltage battery.\nWARNING: The power socket and an accessory’s \nconnector can become hot.\nInterior Electronics\n10\nMODEL Y Owner's Manual\nWARNING: To prevent excessive interference with the \nvehicle’s electronics, Tesla recommends that you do \nnot plug any non-Tesla accessories, including power \ninverters, into the low voltage power socket. However, \nif you do use a non-Tesla accessory and notice any \nmalfunctions or unexpected behavior, such as indicator \nlights, alert messages, or excessive heat from the \naccessory, unplug the accessory from the low voltage \npower socket immediately.\nCAUTION: Do not attempt to jump start Model Y using \nthe low voltage power socket. Doing so can result in \ndamage.\nInterior Electronics\n11\nOverview"},
#  {'id': '100013',
#   'title': '',
#   'text': 'Overview\nThe touchscreen displays the status of Model Y at all times. \nWhat you see depends on whether the vehicle is:\n• Parked (shown below).\n• Driving (see Driving Status on page 15).\n• Charging (see Charging Status on page 175).\nWhen Model Y is parked, the status area shows the drive \nmode, estimated range, and an overhead view of the car with \nbuttons you can touch to open the trunks and charge port \ndoor. When you press the brake, Model Y powers up and \nindicator lights flash briefly. Unless an indicator light applies \nto the current situation (for example, a seat belt is not \nfastened), it should turn off. If an indicator light fails to turn \non or off, contact Tesla.\nNOTE: The following image is provided for demonstration \npurposes only. Depending on vehicle options, software \nversion, and market region, the information displayed may be \nslightly different.\nCards\nThe bottom of the car status display also shows shortcut \n"cards" for quick access to Media, tire pressure data, trip \ninformation, and more. Swipe the cards to the left or right to \ncustomize your cards shortcuts.\nIndicator Lights\nThe following indicator lights illuminate to advise you or alert you of a specific status or condition.\nCar Status\n12\nMODEL Y Owner\'s Manual\nUSA: \nIf the touchscreen displays this red brake indicator at any time other than briefly when you first start \nModel Y, a brake system fault is detected, or the level of the brake fluid is low. Contact Tesla immediately. \nApply steady pressure and keep the brake pedal firmly pressed to stop the vehicle when safe to do so.\nCanada: \nIf the touchscreen displays this red brake indicator at any time other than briefly when you first start \nModel Y, a brake system fault is detected, or the level of the brake fluid is low. Contact Tesla \nimmediately. Apply steady pressure and keep the brake pedal firmly pressed to stop the vehicle when \nsafe to do so.\nUSA: \nThe touchscreen displays this amber brake indicator if a brake booster fault is detected. Apply steady \npressure and keep the brake pedal firmly pressed to stop the vehicle when safe to do so.'},
#  {'id': '100014',
#   'title': '',
#   'text': 'Hydraulic Boost \nCompensation will be active (see Braking and Stopping on page 76).\nCanada: \nThe touchscreen displays this amber brake indicator if a brake booster fault is detected. Apply steady \npressure and keep the brake pedal firmly pressed to stop the vehicle when safe to do so. Hydraulic \nBoost Compensation will be active (see Braking and Stopping on page 76).\nUSA: \nThe ABS indicator briefly flashes amber on the touchscreen when you first start Model Y. If this indicator \nlights up at any other time, an ABS fault has occurred and the ABS is not operating. Contact Tesla. The \nbraking system remains fully operational and is not affected by an ABS failure. However, braking distances \nmay increase. Drive cautiously and avoid heavy braking.\nCanada: \nThe ABS indicator briefly flashes amber on the touchscreen when you first start Model Y. If this \nindicator lights up at any other time, an ABS fault has occurred and the ABS is not operating. Contact \nTesla. The braking system remains fully operational and is not affected by an ABS failure. However, \nbraking distances may increase. Drive cautiously and avoid heavy braking.\nUSA: \nWhen you manually apply the parking brake using the touchscreen, the red parking brake indicator lights \nup on the touchscreen.\nCanada: \nWhen you manually apply the parking brake using the touchscreen, the red parking brake indicator \nlights up on the touchscreen.\nUSA: \nIf the parking brake experiences an electrical issue, the amber parking brake indicator lights up and a fault \nmessage displays on the touchscreen.\nCanada: \nIf the parking brake experiences an electrical issue, the amber parking brake indicator lights up and a \nfault message displays on the touchscreen.\nCar Status\n13\nOverview\nTire pressure warning. The pressure of a tire is out of range. If a fault with the Tire Pressure Monitoring \nSystem (TPMS) is detected, the indicator flashes. For a TPMS fault, contact Tesla. See Tire Care and \nMaintenance on page 187.\nA seat belt for an occupied seat is not fastened. See Seat Belts on page 40.\nAirbag safety.'},
#  {'id': '100015',
#   'title': '',
#   'text': "See Seat Belts on page 40.\nAirbag safety. If this indicator does not flash on briefly when Model Y prepares to drive, or if it remains on, \ncontact Tesla immediately. See Airbag Warnings on page 54.\nFront fog lights are on, if equipped. See Lights on page 72.\nParking lights are on (side marker lights, tail lights, and license plate lights) . See Lights on page 72.\nLow beam headlights are on.\nHigh beam headlights are on and is disabled or currently unavailable.\nis enabled and high beams are on. Model Y is ready to turn off the high beams if light is detected. See High \nBeam Headlights on page 73.\nis enabled but high beams are not on because light is detected in front of Model Y. When light is no longer \ndetected, high beams automatically turn back on. See High Beam Headlights on page 73.\nThis indicator flashes amber when the electronic stability control systems are actively minimizing wheel spin \nby controlling brake pressure and motor power. See Traction Control on page 83. If this indicator remains \non, a fault is detected and you should immediately contact Tesla.\nElectronic stability control systems are no longer minimizing wheel spin. On a Rear Wheel Drive vehicle, the \ntraction control system has been turned off, or on an All-Wheel Drive vehicle, Slip Start has been enabled. \nSee Traction Control on page 83.\nCar Status\n14\nMODEL Y Owner's Manual"},
#  {'id': '100016',
#   'title': '',
#   'text': "Trailer mode (if equipped) is active (see Towing and Accessories on page 92).\nVehicle Hold is actively applying the brakes. See Vehicle Hold on page 82.\nA door or trunk is open. See Doors on page 25, Rear Trunk on page 28, or Front Trunk on page 30.\nA blue snowflake appears when some of the energy stored in the Battery may not be available due to cold \nweather conditions. During these cold weather conditions, charging rates may also be limited. If Model Y is \nplugged in, you can heat your Battery by turning on climate control with the mobile app. The snowflake \ndisappears when the Battery is sufficiently warm.\nAppears when regenerative braking is limited. See Regenerative Braking on page 77 for more information.\nVehicle power is currently being limited because the energy remaining in the Battery is low, the vehicle's \nsystems are being heated or cooled, or an error is detected by the drive inverter.\nSee Popup Messages and Vehicle Alerts on page 7 for more information about alert popups on your vehicle's touchscreen.\nDriving Status\nWhen Model Y is driving (or ready to drive), the touchscreen \nshows your current driving status and a real-time \nvisualization of the road as detected by the Autopilot \ncomponents (see Cameras on page 19). The visualization \nautomatically zooms in and out to better utilize touchscreen \nspace and inform you when a vehicle is detected in your blind \nspot.\nNOTE: The following illustration is provided for demonstration \npurposes only. Depending on vehicle options, software \nversion, and market region, the information displayed may be \nslightly different.\nCar Status\n15\nUsing This Owner's Manual\nNOTE: To display more details about the roadway and its \nsurroundings, such as road markings, stop lights, objects \n(such as trash cans and poles), etc., touch Controls > \nAutopilot > Full Self-Driving Visualization Preview (if \nequipped).\n1. When Autosteer is available but you haven't activated it, \nthe icon is gray."},
#  {'id': '100017',
#   'title': '',
#   'text': "When Autosteer is available but you haven't activated it, \nthe icon is gray. When Autosteer is actively steering \nModel Y, the icon is blue (see Autosteer on page 103).\n2. Currently selected drive mode: Park, Reverse, Neutral, or \nDrive.\n3. Driving speed.\n4. The power meter displays real-time power usage (see \nRegenerative Braking on page 77 for more information). \nThe power meter may display vertically at the top of the \ndriving status screen but the function is the same.\n5. Other cars detected on the road (as applicable).\n6. Your Model Y. Colored lines radiate from the image of \nyour Model Y as objects are detected (other motorists, \nguard rails, etc.). The location of the lines correspond to \nthe location of the detected object. The color of the lines \n(white, yellow, orange, or red) represents the object's \nproximity to Model Y, with white being the farthest and \nred being very close and requiring your immediate \nattention. See Lane Assist on page 134.\n7. When Autosteer is active and detecting the driving lane, \nthe lane is highlighted in blue (see Autosteer on page \n103).\nNOTE: If Navigate on Autopilot is active, the driving lane \ndisplays as a single blue line in front of Model Y (see \nNavigate on Autopilot on page 104).\n8. The speed limit that is currently being detected by Speed \nAssist (see Speed Assist on page 140).\nNOTE: A blue outline may appear around the speed limit \nicon to notify that you are above the speed limit.\nNOTE: The icon associated with the detected speed limit \nreflects the style of speed limit signs used in your market \nregion.\n9. Total estimated driving distance (or energy) available. \nTouch the displayed value to change how available energy \nis displayed. You can toggle between driving distance and \npercentage of battery energy remaining. You can also \nchange how energy is displayed by touching Controls > \nDisplay > Energy Display."},
#  {'id': '100018',
#   'title': '',
#   'text': "You can also \nchange how energy is displayed by touching Controls > \nDisplay > Energy Display.\nNOTE: When anticipating when you need to charge, use \nrange estimates as a general guideline only.\n10. The set cruising speed. When Traffic-Aware Cruise \nControl is available but you haven't set a cruising speed, \nthe number is gray (see Traffic-Aware Cruise Control on \npage 102).\nWARNING: Pay attention to important alert messages \nthat display at the bottom of the car status area of the \ntouchscreen. Ignoring these messages can result in \nserious injury or death.\nWARNING: Although the touchscreen shows \nsurrounding traffic, some vehicles may not be \ndisplayed. Never rely on the touchscreen to determine \nif a vehicle is present (for example, in your blind spot). \nAlways use your mirrors and perform shoulder checks.\nCar Status\n16\nMODEL Y Owner's Manual"},
#  {'id': '100019',
#   'title': '',
#   'text': 'NOTE: For your convenience, Tesla allows you to choose from \na variety of languages to use for voice commands. To choose \na different language, touch Controls > Display > Voice \nRecognition Language.\nUse voice commands to easily control settings and \npreferences without using the touchscreen. Voice commands \nare designed to understand natural requests. The following is \na non-exhaustive list of actions that you can perform with \nvoice commands:\n• Adjust climate preferences\n• Tweak the windshield wiper speed and frequency\n• Control various aspects of your vehicle\n• Navigate to a location\n• Call a contact\n• Interact with apps and settings\nTo initiate a voice command, press and release the right scroll \nwheel button on the steering wheel. When a chime sounds, \nmake your request.\nExamples of Voice Commands\nHere is a list of example voice commands. This is not an \nexhaustive list. Tesla is constantly working to improve voice \ncommands.\nNOTE: Your vehicle must be in Park to enable some voice \ncommands (such as Sentry Mode, Dog Mode, etc.).\nClimate Controls\nAdjust your climate preferences:\n• "Make it cooler"\n• "Make it warmer"\n• "Turn on/off the driver\'s seat heater"\n• "Cool down the passenger"\n• "Direct airflow to my face"\n• "Sync climate"\n• "Increase/decrease the fan speed"\n• "Turn on/off rear defroster"\n• "Set the temperature/fan..."\n• "Turn on recirculate"\nWindshield Wipers\nUpdate the windshield wiper speed and frequency based on \nchanging road and weather conditions:\n• "Speed up the wipers"\n• "Increase/decrease windshield wiper speed by..."\n• "Turn on/off the wipers"\nVehicle Controls\nModify various controls in your vehicle:\n• "Sentry Mode on/off"\n• "Keep my car safe"\n• "Lock/unlock the doors"\n• "Turn on Dog Mode"\n• "Fold/unfold the mirrors"\n• "Open/close charge port"\n• "Start/stop charging"\n• "Open service settings"\n• "Open the glovebox"\nNavigation\nSearch for or navigate to a location:\n• "Where is [location]?"'},
#  {'id': '100020',
#   'title': '',
#   'text': '• "Drive to [location]"\n• "Navigate to [location]"\n• "Show nearby Superchargers"\n• "I\'m feeling hungry/lucky" (see Maps and Navigation on \npage 159).\n• "Stop navigation"\n• "Mute voice guidance"\nIf you have defined a navigation address for your home or \nwork locations, you can use a voice command to navigate \nthere by saying "Navigate home" or "Take me to work".\nVoice Commands\n17\nOverview'},
#  {'id': '100021',
#   'title': '',
#   'text': 'Contacts\nTo call or text a contact on your Bluetooth-connected phone \n(see Phone, Calendar, and Web Conferencing on page 60), \nsay:\n• "Call [contact name/phone number]"\n• "Text [contact name/phone number]"\nMedia\nListen to media and adjust your playback preferences:\n• "Listen to [song name]"\n• "Lower/raise the volume"\n• "Skip to next"\n• "Pause/play song"\n• "Change the source to [media source]"\nTo improve voice command recognition accuracy, provide \nmultiple cues in your command, such as artist and song.\nApps and Settings\nEasily navigate through your apps and settings:\n• "Open [Toybox/browser/theater/phone]"\n• "Search for..."\n• "The screen is too bright"\n• "Show me the Owner\'s Manual"\nYou can also file a bug report by saying "Report" , \n"Feedback", or "Bug report".\nFor more information on voice commands, go to https://\nwww.tesla.com/support/voice-commands.\nNOTE: To support ongoing quality improvements, Tesla \ncaptures and processes voice command transcriptions (such \nas “set the temperature…”). Audio voice recordings are not \ncollected, and transcriptions are not associated with your \nTesla account or with your vehicle\'s identification number. To \nfurther protect your privacy, voice commands containing \npersonal data are not captured (such as "Navigate to..." or \n"Make a call to...").\nVoice Commands\n18\nMODEL Y Owner\'s Manual'},
#  {'id': '100022',
#   'title': '',
#   'text': 'Your Model Y includes the following components that \nactively monitor the surrounding area:\n1. A camera is mounted above the rear license plate.\n2. Ultrasonic sensors (if equipped) are located in the front \nand rear bumpers.\n3. A camera is mounted in each door pillar.\n4. Three cameras are mounted to the windshield above the \nrear view mirror.\n5. A camera is mounted to each front fender.\n6. Radar (if equipped) is mounted behind the front bumper.\nModel Y is also equipped with high precision electronically-\nassisted braking and steering systems.\nCabin Camera\nYour Model Y may be equipped with a cabin camera located \nabove the rear view mirror. For more information, see Cabin \nCamera on page 141.\nDrive to Calibrate Cameras\nModel Y must maneuver with precision when Autopilot \nfeatures are being used. Therefore, before some features \nsuch as Lane Departure Avoidance and Automatic \nEmergency Braking can be used for the first time or after \nsome types of service repairs, cameras must complete a self-\ncalibration process. For your convenience, the touchscreen \ndisplays a progress indicator.\nWhen calibration is complete, Autopilot features, as well as \nActive Safety features, are available for use. Calibration \ntypically completes after driving 20-25 miles (32-40 km), \nbut the distance varies depending on road and environmental \nconditions. For example, calibration completes quicker when \ndriving on a straight road with multiple lanes (such as a \ncontrolled-access highway), with highly-visible lane \nmarkings (in the driving lane as well as the adjacent lanes). \nContact Tesla only if your Model Y has not completed the \ncalibration process after driving 100 miles (160 km) in the \ndescribed conditions.\nIf a camera has shifted from its calibrated position (for \nexample, the camera or windshield was replaced), you must \nclear the calibration. To do so, touch Controls > Service > \nCamera Calibration > Clear Calibration. When the calibration \nis cleared, Model Y repeats the calibration process.'},
#  {'id': '100023',
#   'title': '',
#   'text': "When the calibration \nis cleared, Model Y repeats the calibration process. While \nthis helps re-calibrate the cameras in many cases, Clear \nCalibration may not resolve all camera and sensor concerns.\nNOTE: To calibrate, cameras require highly-visible lane \nmarkings in both the driving lane and adjacent lanes (at least \ntwo lanes over on each side of the vehicle). For best results, \ndrive in the middle lane of a multi-lane highway (ideally with \nat least five lanes) that has clear lane markings and minimal \ntraffic.\nNOTE: If you attempt to use a feature that is not available \nuntil the calibration process is complete, the feature is \ndisabled and the touchscreen displays a message.\nNOTE: Model Y must repeat the calibration process if the \ncameras are serviced by Tesla, and in some cases, after a \nsoftware update.\nKeeping Cameras Free of Obstructions\nEnsure all cameras are clean and free of obstructions before \neach drive and before using Autopilot features (see Cleaning \na Camera on page 194). Dirty cameras and sensors (if \nequipped), as well as environmental conditions such as rain \nand faded lane markings, can affect Autopilot performance. If \na camera is obstructed or blinded, Model Y displays a \nmessage on the touchscreen and Autopilot features may not \nbe available. For more information on specific alerts, see \nTroubleshooting Alerts on page 234.\nCondensation can form inside the camera enclosures, \nespecially if you park your vehicle outside in cold or wet \nconditions. The touchscreen may display an alert stating that \na camera is blocked and that some or all Autopilot features \nmay be temporarily restricted until the camera vision is clear. \nTo proactively dry the condensation, precondition the cabin \nCameras\n19\nOverview\nby setting it to a warm temperature, turning the windshield \ndefroster on, and directing the front air vents toward the door \npillars (see Mobile App on page 55).\nCameras\n20\nMODEL Y Owner's Manual"},
#  {'id': '100024',
#   'title': '',
#   'text': 'Types of Keys\nModel Y supports the following types of keys:\n• Phone key - You can set up your personal phone as a \n"phone key" that communicates with Model Y using \nBluetooth. A phone key supports automatic locking and \nunlocking.\n• Key card - Tesla provides two key cards that communicate \nwith Model Y using short range radio-frequency \nidentification (RFID) signals. Unlike the phone key and key \nfobs, the key card does not support automatic locking and \nunlocking. In situations where your phone key has a dead \nbattery, or is lost or stolen, use your key card to unlock, \ndrive, and lock Model Y.\n• Key fob - The key fob (if equipped) allows you to press \nbuttons to open the front and rear trunks, and unlock, \nlock, and drive Model Y. The key fob also supports \nautomatic locking and unlocking, if available in your \nregion (see Walk-Away Door Lock on page 25) and can \nbe used as a backup to your phone key.\nModel Y supports a total of 19 keys, which can include phone \nkeys, key cards, and up to four key fobs.\nCAUTION: Remember to bring a key with you when you \ndrive. Although you can drive Model Y away from its \nkey, you will be unable to power it back on after it \npowers off.\nPhone Key\nCAUTION: Do not leave your paired phone in your \nvehicle (for example, if you are hiking or at the beach). \nIf you must leave your phone in the vehicle, disable \nBluetooth and/or turn the phone off.\nUsing your phone as a key is a convenient way to access your \nModel Y. As you approach, your phone\'s Bluetooth signal is \ndetected and the doors unlock when you pull a door handle. \nLikewise, when you exit and walk away with the phone key, \ndoors automatically lock (provided the Walk-Away Door Lock \nfeature is turned on; see Walk-Away Door Lock on page \n25).\nBefore you can use a phone to access Model Y, follow these \nsteps to authenticate it (see Pairing a New Phone Key on \npage 23).'},
#  {'id': '100025',
#   'title': '',
#   'text': "Once a phone has been authenticated, it no longer requires \nan internet connection to be used as a phone key for Model \nY. However, to use the phone hands-free, access your \nphone's contacts, play media from it, etc., you must also pair \nit and connect it as a Bluetooth device (see Bluetooth on \npage 58).\nTo view a list of keys that can currently access Model Y, or to \nremove a phone key, touch Controls > Locks (see Managing \nKeys on page 23).\nModel Y can connect to three phone keys simultaneously. \nTherefore, if more than three phone keys are detected and \nyou want to authenticate or pair a different phone, move the \nother connected phone key(s) out of range or turn off its \nBluetooth setting.\nSome smartphones with NFC capability can be used to lock/\nunlock your vehicle, just like using a key card. Ensure the \nTesla mobile app is correctly paired to your vehicle and \nenable the NFC function on your phone. Once enabled, \nsimply hold the phone to the driver's side door pillar to lock \nor unlock the door. Refer to your smartphone's instructions \nfor specific information on how to do this.\nKey Card\nTesla provides you with two Model Y key cards, designed to \nfit in your wallet.\nTo use a key card to unlock or lock Model Y, position the card \nas shown and tap it against the card reader located just \nbelow the Autopilot camera on the driver's side door pillar. \nWhen Model Y detects the key card, the exterior lights flash, \nthe mirrors unfold or fold (if Fold Mirrors is on), the horn \nsounds (if Lock Confirmation Sound is on), and the doors \nunlock or lock.\nNOTE: You may need to physically touch the center console \nor driver's side door pillar with the key card, and you may \nneed to hold it against the transmitter for one or two \nseconds.\nOnce inside, power up Model Y by pressing the brake pedal \nwithin two minutes of scanning the key card (see Starting and \nPowering Off on page 65)."},
#  {'id': '100026',
#   'title': '',
#   'text': 'If you wait longer than two \nminutes, you must re-authenticate by placing the key card \nnear the card reader located behind the cup holders on the \ncenter console. When your key card is detected, your two \nminute authentication period restarts.\nKeys\n21\nOpening and Closing'},
#  {'id': '100027',
#   'title': '',
#   'text': 'NOTE: If enabled, Walk-Away Door Lock (see Walk-Away \nDoor Lock on page 25) operates only when you walk away \nusing a phone key or key fob. When you walk away carrying \nyour key card, Model Y does not automatically unlock/lock.\nCAUTION: Always carry your key card with you in your \npurse or wallet to use as a backup in case your \nauthenticated phone has a dead battery, or is lost or \nstolen.\nKey Fob\nIf you have purchased the key fob accessory, you can quickly \nfamiliarize yourself with this key by thinking of it as a \nminiature version of Model Y, with the Tesla badge \nrepresenting the front. The key has three buttons that feel \nlike softer areas on the surface.\n1. Front trunk - Double-click to unlatch the front trunk.\n2. Lock/Unlock All - Single-click to lock doors and trunks \n(all doors and trunks must be closed). Double-click to \nunlock doors and trunks.\n3. Rear trunk - Double-click to unlatch the rear trunk. Hold \ndown for one to two seconds to open the charge port \ndoor.\nOnce inside, power up Model Y by pressing the brake pedal \nwithin two minutes of pressing the unlock button on the key \nfob (see Starting and Powering Off on page 65). If you wait \nlonger than two minutes, you must press the unlock button \nagain, or place the key fob near the card reader located \nbehind the cup holders on the center console. When your key \nfob is detected, the two minute authentication period \nrestarts.\nWhen approaching or leaving Model Y carrying the key fob, \nyou do not need to point the key fob at Model Y as you press \na button, but you must be within operating range.\nRadio equipment on a similar frequency can affect the key. If \nthis happens, move the key at least one foot (30 cm) away \nfrom other electronic devices (phones, laptops, etc.).'},
#  {'id': '100028',
#   'title': '',
# ...
#  {'id': '100536',
#   'title': '',
#   'text': 'Mexico\nIFT-008-SCFI-2015 / NOM-208-SCFI-2016\nTPMS, model: 1472547G, IFT#: RCPTE1421-4384\nLa operación de este equipo está sujeta a las siguientes dos condiciones:\n1. Es posible que este equipo o dispositivo no cause interferencia perjudicial.\n2. Este equipo debe aceptar cualquier interferencia, incluyendo la que pueda causar su operación no deseada.\nCertification Conformity\n293\nConsumer Information'},
#  {'id': '100537',
#   'title': '',
#   'text': 'A\nABS (Anti-lock Braking System): 76\nabsolute speed limit: 140\nacceleration, chill: 84\nacceleration, sport: 84\nacceleration, standard: 84\naccessories: 10\nplugging into power socket: 10\naccessories, towing: 92\nadjacent lane speed: 102\naero covers: 189\nair conditioning: 149\nair filter: 154\nairbag safety information: 54\nairbags, location: 50\nalarm: 142, 146\nall-season tires: 192\nAlways Show Estimated Round Trip Energy: 163\nambient lights: 72\nanti-lock braking (ABS): 76\napps: 5\nArcade: 167\naudio: 66, 165, 167\nplaying files: 165, 167\nsettings: 165\nsteering wheel scroll button: 66\nvolume control: 165\nauto fold: 68\nAuto Lane Change: 102\nauto tilt: 68\nAUTO wipers: 75\nautomatic emergency braking: 138\nautomatic navigation: 159\nnavigating: 159\nAutopark: 122\nautopilot: 134\nside collision warning: 134\nAutopilot: 98, 102, 122, 124, 137, 140\nautomatic emergency braking: 137\nAutopark: 122\nAutosteer: 102\ncollision avoidance assist: 137\nforward collision warning: 137\novertake acceleration: 102\noverview: 98\nspeed assist: 140\nspeed limit warning: 140\nstaying within speed limits: 140\nSummon: 124\nTraffic-Aware Cruise Control: 102\nAutopilot components: 98\nAutosteer: 102\nautosteer on city streets: 118\naverage range: 183\nB\nbackup camera: 90\nBattery (high voltage): 172, 218\nspecifications: 218\ntemperature limits: 172\nbattery (key), replacing: 23\nbattery (low voltage): 172,'},
#  {'id': '100538',
#   'title': '',
#   'text': 'replacing: 23\nbattery (low voltage): 172, 218\ncomplete discharge: 172\nspecifications: 218\nBlind Spot Camera: 134\nBlind Spot Collision Warning: 134\nBlind Spot Collision Warning Chime: 134\nBluetooth: 58, 60, 167\ndevices, playing audio files from: 167\ngeneral information: 58, 60\nphone, pairing and using: 58\nbody repairs: 201\nbody touch up: 196\nBoombox: 167, 168\nbrakes: 76, 138, 216\nautomatic in emergencies: 138\noverview of: 76\nspecifications: 216\nBumper Clearance (Summon): 124\nC\ncabin air filter: 154\ncabin camera: 141\ncabin temperature control: 149\nCalendar: 60\ncalibrating windows: 27\nCalifornia Proposition 65: 290\ncamera, rear-facing: 90\nCamp: 151\ncar cover: 197\ncar wash mode: 194\ncar washes: 194\nCaraoke): 167\ncard: 21\ncargo area: 29\ncargo volume specifications: 214\ncarpets, cleaning: 196\nCCS (Combo): 170\ncertifications (FCC, ISED, CE, NCC): 292\nIndex\nCHAdeMO: 170\nchains: 192\nchange of ownership: 8\ncharge port: 174\ncharge port light: 175\ncharge port manual release: 178\ncharge port release cable: 178\ncharging: 170, 174, 175, 176\ncharge settings: 175, 176\ncharging status: 175, 176\ncomponents and equipment: 170\ninstructions: 174\npublic charging stations: 170\nscheduling: 175, 176\ncharging locations, finding: 162\ncharging stations, displaying on map: 159\nchild protection: 27\ndisabling rear window switches: 27\nchild seats,'},
#  {'id': '100539',
#   'title': '',
#   'text': 'installing and using: 43\ncleaning: 194\nclimate controls: 149\ncoat hangers: 32\ncold weather: 155\ncold weather best practices: 155\ncollision avoidance assist: 137\nColorizer: 167\nconnecting to Wi-Fi: 57\nconsole: 9, 10, 32\nlow voltage power socket: 10\nopening: 32\nrear: 32\nUSB ports: 9\nconsumption chart: 183\ncontact information: 229, 292\nroadside assistance: 229\nTesla: 292\ncopyrights: 287\ncruise control: 102\nD\ndashboard overview: 5\nDashcam: 144\ndata recording: 289\ndata sharing: 289\ndelivery mileage: 290\ndevices: 167\nBluetooth, playing audio files: 167\ndimensions, interior: 214\ndimensions, overhand: 213\ndimensions, specifications: 213\ndisplay settings: 5\nDog: 151\ndome (map) lights: 72\ndoor handles: 25\ndoor labels: 211\ndoor seals: 196\ncleaning: 196\ndoors: 25, 26, 233\nChild Lock: 26\nexterior door handles: 25\ninterior locking and unlocking: 25\nlocking: 25\nopening from exterior: 25\nopening from interior: 25, 233\nopening with no power: 233\nUnlock on Park: 26\nunlocking: 25\ndoors function: 25\nWalk-Away Door Lock: 25\ndrive away locking: 26\ndrive mode, Drive: 70\ndrive mode, Neutral: 70\ndrive mode, Park: 70\ndrive mode, Reverse: 70\ndrive modes, shifting: 70\ndriver: 87\nprofiles: 87\ndriver assistance: 98\ndriving: 34, 65, 182\nseating position: 34\nstarting: 65\ntips to maximize range: 182\nE\neasy entry,'},
#  {'id': '100540',
#   'title': '',
#   'text': 'driver profile: 87\nEDR (event data recorder): 289\nelectric parking brake: 79\nemergency braking: 137\nemergency flashers: 74\nEmergency Lane Departure Avoidance: 134\nemission label: 210\nenergy: 12, 77\ngained from regenerative braking: 77\nrange information: 12\nEnergy app: 183\nenergy use predictions (navigating): 163\nEntertainment: 167\nErase & Reset: 8\nevent data recording: 289\nexterior: 3, 72, 194, 196, 197\nIndex\ncar cover: 197\ncleaning: 194\nlights: 72\noverview: 3\npolishing, touch up, & repair: 196\nexterior dimensions: 213\nF\nfactory defaults, restoring: 8\nfactory reset: 8\nfavorites (Media Player): 167\nFavorites (navigation): 159\nFCC & ISED certifications: 292\nfeature availability: 288\nfeatures, downloading new: 184\nfirmware (software) updates: 184\nflash drive: 144, 146\nflashers, warning: 74\nfloor mats: 197\nfluids: 186\nreplacement intervals: 186\nfog lights: 72\nforward collision warning: 137\nfront airbag, passenger: 51\nfront and rear seats: 34\nfront trunk: 30, 230\nopening with no power: 230\nfull self-driving: 118\nG\ngaming controllers: 167\ngarage doors, opening: 62\ngates, opening: 62\nGAWR: 211\nglovebox: 32\nGlovebox PIN: 143\nGross Axle Weight Rating: 211\nGross Vehicle Weight Rating: 211\nGVWR: 211\nH\nhazard lights: 74\nhazard warning flashers: 74\nhazards: 74\nhead supports: 38\nheadlights: 72,'},
#  {'id': '100541',
#   'title': '',
#   'text': "73\nafter exit: 73\ncontrolling: 72\nhigh beams: 73\nheating: 149\nhigh beam headlights: 73\nhigh voltage: 170, 186, 218\nBattery specifications: 218\ncomponents: 170\nsafety: 186\nhills, stopping on: 82\nHome: 5\nbutton: 5\nscreen: 5\nHome location: 161\nHomeLink: 62, 124\nprogramming and using: 62\nwhen using Summon: 124\nhood: 30, 230\nopening with no power: 230\nhorn: 67\nhub caps: 189\nI\nI'm Feeling Lucky, Hungry: 159\nidentification labels: 210\ninductive phone charger: 10\ninstalling, LATCH child seats: 46\ninstant range: 183\ninterior: 5, 72, 149, 195\ncleaning: 195\nlights: 72\noverview: 5\ntemperature control: 149\ninterior cabin camera: 141\nintrusion detection: 142\nJ\nJ1772: 170\njacking: 200\njump start: 229, 231\nK\nKeep Climate On: 151\nkey: 23\nreplacing battery: 23\nkey card: 21\nkeys: 21, 23\nadding key cards and phone keys: 23\ndeleting key cards and phone keys: 23\ndisplaying a list of: 23\noverview: 21\nL\nlabel: 211\nIndex\nTire and Loading Information: 211\nvehicle certification: 211\nlane assist: 134\nLane Departure Avoidance: 134\nliftgate: 28\nadjust opening height: 28\nopening: 28\nlifting: 200\nlights: 72, 73, 74\nhazard warning: 74\nheadlights after exit: 73\nturn signals: 74\nload limits: 211\nlocation tracking: 159\nlocking: 25\nlug nut covers: 190\nlumbar adjustment: 34\nM\nmaintenance: 185,"},
#  {'id': '100542',
#   'title': '',
#   'text': '186, 187, 194, 198, 199\ncleaning: 194\ndaily checks: 185\nfluid replacement intervals: 186\nmonthly checks: 185\nperiodic checks: 186\nreplacing wiper blades: 198\nservice intervals: 185\ntires: 187\nwasher fluid, topping up: 198\nwasher jets, cleaning: 199\nmap orientation: 159\nmap updates: 164\nmats: 197\nmedia: 165, 167\nsettings: 165\nsources, show and hide: 165\nmileage upon delivery: 290\nmirrors: 68\nmobile app: 55\nmobile app access: 55\nMobile Connector: 170, 174\ndescription: 170\nusing: 174\nmodifications: 201\nmotor specifications: 216\nMy Apps: 6\nmy car does what?: 167\nmyQ: 62\nprogramming and using: 62\nN\nnaming your vehicle: 8\nNavigate on Autopilot: 102\nNHTSA, contacting: 292\nO\nObstacle-Aware Acceleration: 137\noccupancy sensor, front passenger: 51\noccupant classification: 52\nodometer: 89\nOff-Peak Charging: 180\noff-road assist: 83\noffset from speed limit: 140\nOnline Routing: 163\novertake acceleration: 102\nOwner Information, about: 287\nP\nparcel shelf: 29\nPark Assist: 80\nparking brake: 79\nparking, using Autopark: 122\nparking, using Summon: 124\nparts replacement: 201\npassenger detection: 51\npassenger detection, front: 51\npedestrian warning: 91\npersonal data, erasing: 8\nphone: 21, 58,'},
#  {'id': '100543',
#   'title': '',
#   'text': 'erasing: 8\nphone: 21, 58, 60\napp: 60\nauthenticating as a key: 21\nconnecting: 58\nimporting contacts: 58\nin call options: 60\nmaking a call: 60\npairing: 58\nreceiving a call: 60\nrecent calls: 58\nphone app: 60\nphone key: 21, 23\nadding as a key: 23\nremoving as a key: 23\nPIN: 88\nPIN to Drive: 143\npower: 77\ngained from regenerative braking: 77\npower cycling: 65\npower socket: 10\npower windows: 27, 209\nIndex\npowering on and off: 65\nPreconditioning: 180\nProposition 65: 290\npublic charging stations: 170\nR\nradio: 165, 167\nRadio regulatory information: 292\nrange: 77, 182\ndriving tips to maximize: 182\nregenerative braking: 77\nrange assurance: 182\nre-naming your vehicle: 8\nRe-route: 163\nreading light: 32\nreading lights: 72\nrear seats, adjusting and folding: 35\nrear view camera: 90\nrear window switches, disabling: 27\nrecent (Media Player): 167\nRecents (navigation): 159\nrecording: 144, 146\nregenerative braking: 77\nrelative speed limit: 140\nrelease notes: 184\nrestarting the touchscreen: 65\nRFID transponders: 201\nroadside assistance: 229\nroof racks: 213\nrotating tires: 188\nRound Trip Energy (navigating): 163\nrun out of range: 229, 231\nS\nsafety defects, reporting: 292\nsafety information: 42\nseat belts: 42\nsafety information, child seats: 48\nSchedule: 180\nschedule service: 55\nscheduled charging: 180\nscheduled departure: 180\nusing: 180\nseat belts: 40, 41,'},
#  {'id': '100544',
#   'title': '',
#   'text': '41, 196\ncleaning: 196\nin a collision: 41\noverview of: 40\npre-tensioners: 41\nwearing when pregnant: 41\nseat covers: 39\nseat heaters: 149\nseating capacity: 211\nseats: 34, 149\nheaters: 149\nsecond row seats, adjusting and folding: 35\nsecurity settings: 142\nSentry Mode: 146\nservice data recording: 289\nservice intervals: 185\nsettings, acceleration: 84\nSettings, erasing: 8\nshifting drive modes: 70\nshortcuts: 6, 7\nadding to My Apps: 6\nrestarting the touchscreen: 7\nShow Calendar Upon Entry: 60\nside camera(s): 90\nSide Clearance (Summon): 124\nside collision warning: 134\nslip start: 83\nSmart Summon: 126\nsmartphone: 21\nauthenticating as a key: 21\nSoftware Reinstall: 184\nsoftware reset: 8\nsoftware update preferences: 184\nsoftware updates: 184\nspecifications: 216, 218\nbrakes: 216\nHigh Voltage Battery: 218\nlow voltage battery: 218\nmotor: 216\nsteering: 216\nsubsystems: 216\nsuspension: 218\ntires: 218\ntransmission: 216\nwheels: 218\nspecifications, exterior: 213\nspecifications, interior: 214\nspeed assist: 140\nspeed limit warning: 140\nstability control: 83\nstandby: 146\nstarting: 65\nsteering specifications: 216\nsteering wheel: 72\nlights, controlling: 72\nsteering, automatic: 102\nsummer tires: 192\nIndex\nSummon: 124\nSummon Distance: 124\nSuperchargers,'},
#  {'id': '100545',
#   'title': '',
#   'text': 'displaying on map: 159\nSupercharging: 177\ncongestion fees: 177\ndescribed: 177\nidle fees: 177\npay-per-use fees: 177\nsuspension specifications: 218\nT\ntelematics: 289\ntemperature: 12, 67, 149, 172, 221\nBattery (high voltage), limits: 172\ncabin, controls for: 149\nheated steering wheel: 67\noutside: 12\ntires: 221\ntesla profiles: 87\nTeslacam: 144, 146\nthird row seats, accessing: 37\nthird row seats, folding and raising: 37\ntie-down straps: 227\nTire and Loading Information label: 211\ntire noise: 192\nTire Pressure Monitoring System: 191\noverview of: 191\ntire pressures, checking: 187\ntire pressures, displaying: 187\ntires: 187, 188, 192, 218, 219, 221\nall-season: 192\nbalancing: 188\nchains: 192\ninspecting and maintaining: 187\npressures, displaying: 187\npressures, how to check: 187\nquality grading: 221\nreplacing: 188\nreplacing a tire sensor: 192\nrotation: 188\nspecification: 218\nsummer: 192\ntemperature grades: 221\ntire markings: 219\ntraction grade: 221\ntreadwear grade: 221\nwheel configuration: 187\nwinter: 192\ntoll system transponders, attaching: 201\ntorque specifications: 216\ntouch up body: 196\ntouchscreen: 5, 6, 7, 66, 184,'},
#  {'id': '100546',
#   'title': '',
#   'text': '6, 7, 66, 184, 196\nadding shortcuts: 6\ncleaning: 196\ncustomizing My Apps: 6\ndisplay settings: 5\nfrozen: 7\nmain: 5\noverview: 5\nrear: 5\nreboot: 7\nrestarting: 66\nsoftware updates: 184\nunresponsive: 7\ntowing: 229, 231\ntowing a trailer: 92\ntowing instructions: 225\nToybox: 167\nTPMS: 191\noverview of: 191\nTracking Disabled: 159\ntraction control: 83\ntrademarks: 287\nTraffic Light and Stop Sign Control: 111\nTraffic-Aware Cruise Control: 102\ntrailer, towing: 92\ntransmission specifications: 216\ntransponders, attaching: 201\nTransport Canada, contacting: 292\nTransport Mode: 225\ntransporting: 225\ntrip chart: 183\ntrip meter: 89\nTrip Planner: 163\ntrunk, front: 30\ntrunk, rear: 28\nturn signals: 74\nU\nuniform tire quality grading: 221\nUnlock On Park: 26\nunlocking: 25\nUSB devices: 9\nconnecting: 9\nUSB flash drive: 142, 144, 146\nUSB ports: 9\nV\nValet mode: 88\nvehicle certification label: 211\nIndex\nvehicle dimensions: 213\nvehicle ground clearance: 213, 214\nVehicle Hold: 82\nVehicle Identification Number (VIN): 210\nvehicle loading: 211\nventilation: 154\nvents, adjusting: 154\nvideo call: 61\nvideo clips: 144\nView Live Camera: 146\nVIN (Vehicle Identification Number): 210\nvoice commands: 17\nvolume control: 5\nvolume control (media): 165\nW\nWalk-Away Door Lock: 25\nWall Connector: 170\nwarm weather best practices: 158\nwarning flashers: 74\nwasher fluid, topping up: 198\nwasher jets,'},
#  {'id': '100547',
#   'title': '',
#   'text': 'topping up: 198\nwasher jets, cleaning: 199\nwashers, using: 75\nweb conferencing: 61\nwheel chocks: 227\nwheels: 188, 189, 190, 218\naero covers, removing and installing: 189\nalignment: 188\nlug nut covers, removing and installing: 190\nreplacing: 188\nspecifications: 218\ntorque: 218\nWi-Fi, connecting to: 57\nwindows, calibrating: 27\nwindshield washer fluid, topping up: 198\nwinter tires: 192\nwiper blades, replacing: 198\nwipers, using: 75\nwireless phone charger: 10\nWork location: 161\nZ\nZoom: 61\nIndex'}]

# %%
assert len(corpus_l) == len(corpus)

# %%
qrels_l = []
for q in queries:
    c = query_to_corpus[q]
    qid = query_to_id[q]
    docid = corpus_to_id[c]
    qrels_l.append({"qid": qid, "docid": docid, "relevance": 1})

# %%
qrels_l
# Out:
# [{'qid': '0', 'docid': '100000', 'relevance': 1},
#  {'qid': '1', 'docid': '100000', 'relevance': 1},
#  {'qid': '2', 'docid': '100000', 'relevance': 1},
#  {'qid': '3', 'docid': '100000', 'relevance': 1},
#  {'qid': '4', 'docid': '100000', 'relevance': 1},
#  {'qid': '5', 'docid': '100000', 'relevance': 1},
#  {'qid': '6', 'docid': '100000', 'relevance': 1},
#  {'qid': '7', 'docid': '100000', 'relevance': 1},
#  {'qid': '8', 'docid': '100000', 'relevance': 1},
#  {'qid': '9', 'docid': '100000', 'relevance': 1},
#  {'qid': '10', 'docid': '100000', 'relevance': 1},
#  {'qid': '11', 'docid': '100000', 'relevance': 1},
#  {'qid': '12', 'docid': '100000', 'relevance': 1},
#  {'qid': '13', 'docid': '100000', 'relevance': 1},
#  {'qid': '14', 'docid': '100000', 'relevance': 1},
#  {'qid': '15', 'docid': '100000', 'relevance': 1},
#  {'qid': '16', 'docid': '100000', 'relevance': 1},
#  {'qid': '17', 'docid': '100000', 'relevance': 1},
#  {'qid': '18', 'docid': '100000', 'relevance': 1},
#  {'qid': '19', 'docid': '100000', 'relevance': 1},
#  {'qid': '20', 'docid': '100001', 'relevance': 1},
#  {'qid': '21', 'docid': '100001', 'relevance': 1},
#  {'qid': '22', 'docid': '100001', 'relevance': 1},
#  {'qid': '23', 'docid': '100001', 'relevance': 1},
#  {'qid': '24', 'docid': '100001', 'relevance': 1},
#  {'qid': '25', 'docid': '100001', 'relevance': 1},
#  {'qid': '26', 'docid': '100001', 'relevance': 1},
#  {'qid': '27', 'docid': '100001', 'relevance': 1},
#  {'qid': '28', 'docid': '100001', 'relevance': 1},
#  {'qid': '29', 'docid': '100001', 'relevance': 1},
#  {'qid': '30', 'docid': '100001', 'relevance': 1},
#  {'qid': '31', 'docid': '100001', 'relevance': 1},
#  {'qid': '32', 'docid': '100001', 'relevance': 1},
#  {'qid': '33', 'docid': '100001', 'relevance': 1},
#  {'qid': '34', 'docid': '100001', 'relevance': 1},
#  {'qid': '35', 'docid': '100001', 'relevance': 1},
#  {'qid': '36', 'docid': '100001', 'relevance': 1},
#  {'qid': '37', 'docid': '100001', 'relevance': 1},
#  {'qid': '38', 'docid': '100001', 'relevance': 1},
#  {'qid': '39', 'docid': '100001', 'relevance': 1},
#  {'qid': '40', 'docid': '100002', 'relevance': 1},
#  {'qid': '41', 'docid': '100002', 'relevance': 1},
#  {'qid': '42', 'docid': '100002', 'relevance': 1},
#  {'qid': '43', 'docid': '100002', 'relevance': 1},
#  {'qid': '44', 'docid': '100002', 'relevance': 1},
#  {'qid': '45', 'docid': '100002', 'relevance': 1},
#  {'qid': '46', 'docid': '100002', 'relevance': 1},
#  {'qid': '47', 'docid': '100002', 'relevance': 1},
#  {'qid': '48', 'docid': '100002', 'relevance': 1},
#  {'qid': '49', 'docid': '100002', 'relevance': 1},
#  {'qid': '50', 'docid': '100002', 'relevance': 1},
#  {'qid': '51', 'docid': '100002', 'relevance': 1},
#  {'qid': '52', 'docid': '100002', 'relevance': 1},
#  {'qid': '53', 'docid': '100002', 'relevance': 1},
#  {'qid': '54', 'docid': '100002', 'relevance': 1},
#  {'qid': '55', 'docid': '100002', 'relevance': 1},
#  {'qid': '56', 'docid': '100002', 'relevance': 1},
#  {'qid': '57', 'docid': '100002', 'relevance': 1},
#  {'qid': '58', 'docid': '100002', 'relevance': 1},
#  {'qid': '59', 'docid': '100002', 'relevance': 1},
#  {'qid': '60', 'docid': '100003', 'relevance': 1},
#  {'qid': '61', 'docid': '100003', 'relevance': 1},
#  {'qid': '62', 'docid': '100003', 'relevance': 1},
#  {'qid': '63', 'docid': '100003', 'relevance': 1},
#  {'qid': '64', 'docid': '100003', 'relevance': 1},
#  {'qid': '65', 'docid': '100003', 'relevance': 1},
#  {'qid': '66', 'docid': '100003', 'relevance': 1},
#  {'qid': '67', 'docid': '100003', 'relevance': 1},
#  {'qid': '68', 'docid': '100003', 'relevance': 1},
#  {'qid': '69', 'docid': '100003', 'relevance': 1},
#  {'qid': '70', 'docid': '100003', 'relevance': 1},
#  {'qid': '71', 'docid': '100003', 'relevance': 1},
#  {'qid': '72', 'docid': '100003', 'relevance': 1},
#  {'qid': '73', 'docid': '100003', 'relevance': 1},
#  {'qid': '74', 'docid': '100003', 'relevance': 1},
#  {'qid': '75', 'docid': '100003', 'relevance': 1},
#  {'qid': '76', 'docid': '100003', 'relevance': 1},
#  {'qid': '77', 'docid': '100003', 'relevance': 1},
#  {'qid': '78', 'docid': '100003', 'relevance': 1},
#  {'qid': '79', 'docid': '100003', 'relevance': 1},
#  {'qid': '80', 'docid': '100004', 'relevance': 1},
#  {'qid': '81', 'docid': '100004', 'relevance': 1},
#  {'qid': '82', 'docid': '100004', 'relevance': 1},
#  {'qid': '83', 'docid': '100004', 'relevance': 1},
#  {'qid': '84', 'docid': '100004', 'relevance': 1},
#  {'qid': '85', 'docid': '100004', 'relevance': 1},
#  {'qid': '86', 'docid': '100004', 'relevance': 1},
#  {'qid': '87', 'docid': '100004', 'relevance': 1},
#  {'qid': '88', 'docid': '100004', 'relevance': 1},
#  {'qid': '89', 'docid': '100004', 'relevance': 1},
#  {'qid': '90', 'docid': '100004', 'relevance': 1},
#  {'qid': '91', 'docid': '100004', 'relevance': 1},
#  {'qid': '92', 'docid': '100004', 'relevance': 1},
#  {'qid': '93', 'docid': '100004', 'relevance': 1},
#  {'qid': '94', 'docid': '100004', 'relevance': 1},
#  {'qid': '95', 'docid': '100004', 'relevance': 1},
#  {'qid': '96', 'docid': '100004', 'relevance': 1},
#  {'qid': '97', 'docid': '100004', 'relevance': 1},
#  {'qid': '98', 'docid': '100004', 'relevance': 1},
#  {'qid': '99', 'docid': '100004', 'relevance': 1},
#  {'qid': '100', 'docid': '100005', 'relevance': 1},
#  {'qid': '101', 'docid': '100005', 'relevance': 1},
#  {'qid': '102', 'docid': '100005', 'relevance': 1},
#  {'qid': '103', 'docid': '100005', 'relevance': 1},
#  {'qid': '104', 'docid': '100005', 'relevance': 1},
#  {'qid': '105', 'docid': '100005', 'relevance': 1},
#  {'qid': '106', 'docid': '100005', 'relevance': 1},
#  {'qid': '107', 'docid': '100005', 'relevance': 1},
#  {'qid': '108', 'docid': '100005', 'relevance': 1},
#  {'qid': '109', 'docid': '100005', 'relevance': 1},
#  {'qid': '110', 'docid': '100005', 'relevance': 1},
#  {'qid': '111', 'docid': '100005', 'relevance': 1},
#  {'qid': '112', 'docid': '100005', 'relevance': 1},
#  {'qid': '113', 'docid': '100005', 'relevance': 1},
#  {'qid': '114', 'docid': '100005', 'relevance': 1},
#  {'qid': '115', 'docid': '100005', 'relevance': 1},
#  {'qid': '116', 'docid': '100005', 'relevance': 1},
#  {'qid': '117', 'docid': '100005', 'relevance': 1},
#  {'qid': '118', 'docid': '100005', 'relevance': 1},
#  {'qid': '119', 'docid': '100005', 'relevance': 1},
#  {'qid': '120', 'docid': '100006', 'relevance': 1},
#  {'qid': '121', 'docid': '100006', 'relevance': 1},
#  {'qid': '122', 'docid': '100006', 'relevance': 1},
#  {'qid': '123', 'docid': '100006', 'relevance': 1},
#  {'qid': '124', 'docid': '100006', 'relevance': 1},
#  {'qid': '125', 'docid': '100006', 'relevance': 1},
#  {'qid': '126', 'docid': '100006', 'relevance': 1},
#  {'qid': '127', 'docid': '100006', 'relevance': 1},
#  {'qid': '128', 'docid': '100006', 'relevance': 1},
#  {'qid': '129', 'docid': '100006', 'relevance': 1},
#  {'qid': '130', 'docid': '100006', 'relevance': 1},
#  {'qid': '131', 'docid': '100006', 'relevance': 1},
#  {'qid': '132', 'docid': '100006', 'relevance': 1},
#  {'qid': '133', 'docid': '100006', 'relevance': 1},
#  {'qid': '134', 'docid': '100006', 'relevance': 1},
#  {'qid': '135', 'docid': '100006', 'relevance': 1},
#  {'qid': '136', 'docid': '100006', 'relevance': 1},
#  {'qid': '137', 'docid': '100006', 'relevance': 1},
#  {'qid': '138', 'docid': '100006', 'relevance': 1},
#  {'qid': '139', 'docid': '100006', 'relevance': 1},
#  {'qid': '140', 'docid': '100007', 'relevance': 1},
#  {'qid': '141', 'docid': '100007', 'relevance': 1},
#  {'qid': '142', 'docid': '100007', 'relevance': 1},
#  {'qid': '143', 'docid': '100007', 'relevance': 1},
#  {'qid': '144', 'docid': '100007', 'relevance': 1},
#  {'qid': '145', 'docid': '100007', 'relevance': 1},
#  {'qid': '146', 'docid': '100007', 'relevance': 1},
#  {'qid': '147', 'docid': '100007', 'relevance': 1},
#  {'qid': '148', 'docid': '100007', 'relevance': 1},
#  {'qid': '149', 'docid': '100007', 'relevance': 1},
#  {'qid': '150', 'docid': '100007', 'relevance': 1},
#  {'qid': '151', 'docid': '100007', 'relevance': 1},
#  {'qid': '152', 'docid': '100007', 'relevance': 1},
#  {'qid': '153', 'docid': '100007', 'relevance': 1},
#  {'qid': '154', 'docid': '100007', 'relevance': 1},
#  {'qid': '155', 'docid': '100007', 'relevance': 1},
#  {'qid': '156', 'docid': '100007', 'relevance': 1},
#  {'qid': '157', 'docid': '100007', 'relevance': 1},
#  {'qid': '158', 'docid': '100007', 'relevance': 1},
#  {'qid': '159', 'docid': '100007', 'relevance': 1},
#  {'qid': '160', 'docid': '100008', 'relevance': 1},
#  {'qid': '161', 'docid': '100008', 'relevance': 1},
#  {'qid': '162', 'docid': '100008', 'relevance': 1},
#  {'qid': '163', 'docid': '100008', 'relevance': 1},
#  {'qid': '164', 'docid': '100008', 'relevance': 1},
#  {'qid': '165', 'docid': '100008', 'relevance': 1},
#  {'qid': '166', 'docid': '100008', 'relevance': 1},
#  {'qid': '167', 'docid': '100008', 'relevance': 1},
#  {'qid': '168', 'docid': '100008', 'relevance': 1},
#  {'qid': '169', 'docid': '100008', 'relevance': 1},
#  {'qid': '170', 'docid': '100008', 'relevance': 1},
#  {'qid': '171', 'docid': '100008', 'relevance': 1},
#  {'qid': '172', 'docid': '100008', 'relevance': 1},
#  {'qid': '173', 'docid': '100008', 'relevance': 1},
#  {'qid': '174', 'docid': '100008', 'relevance': 1},
#  {'qid': '175', 'docid': '100008', 'relevance': 1},
#  {'qid': '176', 'docid': '100008', 'relevance': 1},
#  {'qid': '177', 'docid': '100008', 'relevance': 1},
#  {'qid': '178', 'docid': '100008', 'relevance': 1},
#  {'qid': '179', 'docid': '100008', 'relevance': 1},
#  {'qid': '180', 'docid': '100009', 'relevance': 1},
#  {'qid': '181', 'docid': '100009', 'relevance': 1},
#  {'qid': '182', 'docid': '100009', 'relevance': 1},
#  {'qid': '183', 'docid': '100009', 'relevance': 1},
#  {'qid': '184', 'docid': '100009', 'relevance': 1},
#  {'qid': '185', 'docid': '100009', 'relevance': 1},
#  {'qid': '186', 'docid': '100009', 'relevance': 1},
#  {'qid': '187', 'docid': '100009', 'relevance': 1},
#  {'qid': '188', 'docid': '100009', 'relevance': 1},
#  {'qid': '189', 'docid': '100009', 'relevance': 1},
#  {'qid': '190', 'docid': '100009', 'relevance': 1},
#  {'qid': '191', 'docid': '100009', 'relevance': 1},
#  {'qid': '192', 'docid': '100009', 'relevance': 1},
#  {'qid': '193', 'docid': '100009', 'relevance': 1},
#  {'qid': '194', 'docid': '100009', 'relevance': 1},
#  {'qid': '195', 'docid': '100009', 'relevance': 1},
#  {'qid': '196', 'docid': '100009', 'relevance': 1},
#  {'qid': '197', 'docid': '100009', 'relevance': 1},
#  {'qid': '198', 'docid': '100009', 'relevance': 1},
#  {'qid': '199', 'docid': '100009', 'relevance': 1},
#  {'qid': '200', 'docid': '100010', 'relevance': 1},
#  {'qid': '201', 'docid': '100010', 'relevance': 1},
#  {'qid': '202', 'docid': '100010', 'relevance': 1},
#  {'qid': '203', 'docid': '100010', 'relevance': 1},
#  {'qid': '204', 'docid': '100010', 'relevance': 1},
#  {'qid': '205', 'docid': '100010', 'relevance': 1},
#  {'qid': '206', 'docid': '100010', 'relevance': 1},
#  {'qid': '207', 'docid': '100010', 'relevance': 1},
#  {'qid': '208', 'docid': '100010', 'relevance': 1},
#  {'qid': '209', 'docid': '100010', 'relevance': 1},
#  {'qid': '210', 'docid': '100010', 'relevance': 1},
#  {'qid': '211', 'docid': '100010', 'relevance': 1},
#  {'qid': '212', 'docid': '100010', 'relevance': 1},
#  {'qid': '213', 'docid': '100010', 'relevance': 1},
#  {'qid': '214', 'docid': '100010', 'relevance': 1},
#  {'qid': '215', 'docid': '100010', 'relevance': 1},
#  {'qid': '216', 'docid': '100010', 'relevance': 1},
#  {'qid': '217', 'docid': '100010', 'relevance': 1},
#  {'qid': '218', 'docid': '100010', 'relevance': 1},
#  {'qid': '219', 'docid': '100010', 'relevance': 1},
#  {'qid': '220', 'docid': '100011', 'relevance': 1},
#  {'qid': '221', 'docid': '100011', 'relevance': 1},
#  {'qid': '222', 'docid': '100011', 'relevance': 1},
#  {'qid': '223', 'docid': '100011', 'relevance': 1},
#  {'qid': '224', 'docid': '100011', 'relevance': 1},
#  {'qid': '225', 'docid': '100011', 'relevance': 1},
#  {'qid': '226', 'docid': '100011', 'relevance': 1},
#  {'qid': '227', 'docid': '100011', 'relevance': 1},
#  {'qid': '228', 'docid': '100011', 'relevance': 1},
#  {'qid': '229', 'docid': '100011', 'relevance': 1},
#  {'qid': '230', 'docid': '100011', 'relevance': 1},
#  {'qid': '231', 'docid': '100011', 'relevance': 1},
#  {'qid': '232', 'docid': '100011', 'relevance': 1},
#  {'qid': '233', 'docid': '100011', 'relevance': 1},
#  {'qid': '234', 'docid': '100011', 'relevance': 1},
#  {'qid': '235', 'docid': '100011', 'relevance': 1},
#  {'qid': '236', 'docid': '100011', 'relevance': 1},
#  {'qid': '237', 'docid': '100011', 'relevance': 1},
#  {'qid': '238', 'docid': '100011', 'relevance': 1},
#  {'qid': '239', 'docid': '100011', 'relevance': 1},
#  {'qid': '240', 'docid': '100012', 'relevance': 1},
#  {'qid': '241', 'docid': '100012', 'relevance': 1},
#  {'qid': '242', 'docid': '100012', 'relevance': 1},
#  {'qid': '243', 'docid': '100012', 'relevance': 1},
#  {'qid': '244', 'docid': '100012', 'relevance': 1},
#  {'qid': '245', 'docid': '100012', 'relevance': 1},
#  {'qid': '246', 'docid': '100012', 'relevance': 1},
#  {'qid': '247', 'docid': '100012', 'relevance': 1},
#  {'qid': '248', 'docid': '100012', 'relevance': 1},
#  {'qid': '249', 'docid': '100012', 'relevance': 1},
#  {'qid': '250', 'docid': '100012', 'relevance': 1},
#  {'qid': '251', 'docid': '100012', 'relevance': 1},
#  {'qid': '252', 'docid': '100012', 'relevance': 1},
#  {'qid': '253', 'docid': '100012', 'relevance': 1},
#  {'qid': '254', 'docid': '100012', 'relevance': 1},
#  {'qid': '255', 'docid': '100012', 'relevance': 1},
#  {'qid': '256', 'docid': '100012', 'relevance': 1},
#  {'qid': '257', 'docid': '100012', 'relevance': 1},
#  {'qid': '258', 'docid': '100012', 'relevance': 1},
#  {'qid': '259', 'docid': '100012', 'relevance': 1},
#  {'qid': '260', 'docid': '100013', 'relevance': 1},
#  {'qid': '261', 'docid': '100013', 'relevance': 1},
#  {'qid': '262', 'docid': '100013', 'relevance': 1},
#  {'qid': '263', 'docid': '100013', 'relevance': 1},
#  {'qid': '264', 'docid': '100013', 'relevance': 1},
#  {'qid': '265', 'docid': '100013', 'relevance': 1},
#  {'qid': '266', 'docid': '100013', 'relevance': 1},
#  {'qid': '267', 'docid': '100013', 'relevance': 1},
#  {'qid': '268', 'docid': '100013', 'relevance': 1},
#  {'qid': '269', 'docid': '100013', 'relevance': 1},
#  {'qid': '270', 'docid': '100013', 'relevance': 1},
#  {'qid': '271', 'docid': '100013', 'relevance': 1},
#  {'qid': '272', 'docid': '100013', 'relevance': 1},
#  {'qid': '273', 'docid': '100013', 'relevance': 1},
#  {'qid': '274', 'docid': '100013', 'relevance': 1},
#  {'qid': '275', 'docid': '100013', 'relevance': 1},
#  {'qid': '276', 'docid': '100013', 'relevance': 1},
#  {'qid': '277', 'docid': '100013', 'relevance': 1},
#  {'qid': '278', 'docid': '100013', 'relevance': 1},
#  {'qid': '279', 'docid': '100013', 'relevance': 1},
#  {'qid': '280', 'docid': '100014', 'relevance': 1},
#  {'qid': '281', 'docid': '100014', 'relevance': 1},
#  {'qid': '282', 'docid': '100014', 'relevance': 1},
#  {'qid': '283', 'docid': '100014', 'relevance': 1},
#  {'qid': '284', 'docid': '100014', 'relevance': 1},
#  {'qid': '285', 'docid': '100014', 'relevance': 1},
#  {'qid': '286', 'docid': '100014', 'relevance': 1},
#  {'qid': '287', 'docid': '100014', 'relevance': 1},
#  {'qid': '288', 'docid': '100014', 'relevance': 1},
#  {'qid': '289', 'docid': '100014', 'relevance': 1},
#  {'qid': '290', 'docid': '100014', 'relevance': 1},
#  {'qid': '291', 'docid': '100014', 'relevance': 1},
#  {'qid': '292', 'docid': '100014', 'relevance': 1},
#  {'qid': '293', 'docid': '100014', 'relevance': 1},
#  {'qid': '294', 'docid': '100014', 'relevance': 1},
#  {'qid': '295', 'docid': '100014', 'relevance': 1},
#  {'qid': '296', 'docid': '100014', 'relevance': 1},
#  {'qid': '297', 'docid': '100014', 'relevance': 1},
#  {'qid': '298', 'docid': '100014', 'relevance': 1},
#  {'qid': '299', 'docid': '100014', 'relevance': 1},
#  {'qid': '300', 'docid': '100015', 'relevance': 1},
#  {'qid': '301', 'docid': '100015', 'relevance': 1},
#  {'qid': '302', 'docid': '100015', 'relevance': 1},
#  {'qid': '303', 'docid': '100015', 'relevance': 1},
#  {'qid': '304', 'docid': '100015', 'relevance': 1},
#  {'qid': '305', 'docid': '100015', 'relevance': 1},
#  {'qid': '306', 'docid': '100015', 'relevance': 1},
#  {'qid': '307', 'docid': '100015', 'relevance': 1},
#  {'qid': '308', 'docid': '100015', 'relevance': 1},
#  {'qid': '309', 'docid': '100015', 'relevance': 1},
#  {'qid': '310', 'docid': '100015', 'relevance': 1},
#  {'qid': '311', 'docid': '100015', 'relevance': 1},
#  {'qid': '312', 'docid': '100015', 'relevance': 1},
#  {'qid': '313', 'docid': '100015', 'relevance': 1},
#  {'qid': '314', 'docid': '100015', 'relevance': 1},
#  {'qid': '315', 'docid': '100015', 'relevance': 1},
#  {'qid': '316', 'docid': '100015', 'relevance': 1},
#  {'qid': '317', 'docid': '100015', 'relevance': 1},
#  {'qid': '318', 'docid': '100015', 'relevance': 1},
#  {'qid': '319', 'docid': '100015', 'relevance': 1},
#  {'qid': '320', 'docid': '100016', 'relevance': 1},
#  {'qid': '321', 'docid': '100016', 'relevance': 1},
#  {'qid': '322', 'docid': '100016', 'relevance': 1},
#  {'qid': '323', 'docid': '100016', 'relevance': 1},
#  {'qid': '324', 'docid': '100016', 'relevance': 1},
#  {'qid': '325', 'docid': '100016', 'relevance': 1},
#  {'qid': '326', 'docid': '100016', 'relevance': 1},
#  {'qid': '327', 'docid': '100016', 'relevance': 1},
#  {'qid': '328', 'docid': '100016', 'relevance': 1},
#  {'qid': '329', 'docid': '100016', 'relevance': 1},
#  {'qid': '330', 'docid': '100016', 'relevance': 1},
#  {'qid': '331', 'docid': '100016', 'relevance': 1},
#  {'qid': '332', 'docid': '100016', 'relevance': 1},
#  {'qid': '333', 'docid': '100016', 'relevance': 1},
#  {'qid': '334', 'docid': '100016', 'relevance': 1},
#  {'qid': '335', 'docid': '100016', 'relevance': 1},
#  {'qid': '336', 'docid': '100016', 'relevance': 1},
#  {'qid': '337', 'docid': '100016', 'relevance': 1},
#  {'qid': '338', 'docid': '100016', 'relevance': 1},
#  {'qid': '339', 'docid': '100016', 'relevance': 1},
#  {'qid': '340', 'docid': '100017', 'relevance': 1},
#  {'qid': '341', 'docid': '100017', 'relevance': 1},
#  {'qid': '342', 'docid': '100017', 'relevance': 1},
#  {'qid': '343', 'docid': '100017', 'relevance': 1},
#  {'qid': '344', 'docid': '100017', 'relevance': 1},
#  {'qid': '345', 'docid': '100017', 'relevance': 1},
#  {'qid': '346', 'docid': '100017', 'relevance': 1},
#  {'qid': '347', 'docid': '100017', 'relevance': 1},
#  {'qid': '348', 'docid': '100017', 'relevance': 1},
#  {'qid': '349', 'docid': '100017', 'relevance': 1},
#  {'qid': '350', 'docid': '100017', 'relevance': 1},
#  {'qid': '351', 'docid': '100017', 'relevance': 1},
#  {'qid': '352', 'docid': '100017', 'relevance': 1},
#  {'qid': '353', 'docid': '100017', 'relevance': 1},
#  {'qid': '354', 'docid': '100017', 'relevance': 1},
#  {'qid': '355', 'docid': '100017', 'relevance': 1},
#  {'qid': '356', 'docid': '100017', 'relevance': 1},
#  {'qid': '357', 'docid': '100017', 'relevance': 1},
#  {'qid': '358', 'docid': '100017', 'relevance': 1},
#  {'qid': '359', 'docid': '100017', 'relevance': 1},
#  {'qid': '360', 'docid': '100018', 'relevance': 1},
#  {'qid': '361', 'docid': '100018', 'relevance': 1},
#  {'qid': '362', 'docid': '100018', 'relevance': 1},
#  {'qid': '363', 'docid': '100018', 'relevance': 1},
#  {'qid': '364', 'docid': '100018', 'relevance': 1},
#  {'qid': '365', 'docid': '100018', 'relevance': 1},
#  {'qid': '366', 'docid': '100018', 'relevance': 1},
#  {'qid': '367', 'docid': '100018', 'relevance': 1},
#  {'qid': '368', 'docid': '100018', 'relevance': 1},
#  {'qid': '369', 'docid': '100018', 'relevance': 1},
#  {'qid': '370', 'docid': '100018', 'relevance': 1},
#  {'qid': '371', 'docid': '100018', 'relevance': 1},
#  {'qid': '372', 'docid': '100018', 'relevance': 1},
#  {'qid': '373', 'docid': '100018', 'relevance': 1},
#  {'qid': '374', 'docid': '100018', 'relevance': 1},
#  {'qid': '375', 'docid': '100018', 'relevance': 1},
#  {'qid': '376', 'docid': '100018', 'relevance': 1},
#  {'qid': '377', 'docid': '100018', 'relevance': 1},
#  {'qid': '378', 'docid': '100018', 'relevance': 1},
#  {'qid': '379', 'docid': '100018', 'relevance': 1},
#  {'qid': '380', 'docid': '100019', 'relevance': 1},
#  {'qid': '381', 'docid': '100019', 'relevance': 1},
#  {'qid': '382', 'docid': '100019', 'relevance': 1},
#  {'qid': '383', 'docid': '100019', 'relevance': 1},
#  {'qid': '384', 'docid': '100019', 'relevance': 1},
#  {'qid': '385', 'docid': '100019', 'relevance': 1},
#  {'qid': '386', 'docid': '100019', 'relevance': 1},
#  {'qid': '387', 'docid': '100019', 'relevance': 1},
#  {'qid': '388', 'docid': '100019', 'relevance': 1},
#  {'qid': '389', 'docid': '100019', 'relevance': 1},
#  {'qid': '390', 'docid': '100019', 'relevance': 1},
#  {'qid': '391', 'docid': '100019', 'relevance': 1},
#  {'qid': '392', 'docid': '100019', 'relevance': 1},
#  {'qid': '393', 'docid': '100019', 'relevance': 1},
#  {'qid': '394', 'docid': '100019', 'relevance': 1},
#  {'qid': '395', 'docid': '100019', 'relevance': 1},
#  {'qid': '396', 'docid': '100019', 'relevance': 1},
#  {'qid': '397', 'docid': '100019', 'relevance': 1},
#  {'qid': '398', 'docid': '100019', 'relevance': 1},
#  {'qid': '399', 'docid': '100019', 'relevance': 1},
#  {'qid': '400', 'docid': '100020', 'relevance': 1},
#  {'qid': '401', 'docid': '100020', 'relevance': 1},
#  {'qid': '402', 'docid': '100020', 'relevance': 1},
#  {'qid': '403', 'docid': '100020', 'relevance': 1},
#  {'qid': '404', 'docid': '100020', 'relevance': 1},
#  {'qid': '405', 'docid': '100020', 'relevance': 1},
#  {'qid': '406', 'docid': '100020', 'relevance': 1},
#  {'qid': '407', 'docid': '100020', 'relevance': 1},
#  {'qid': '408', 'docid': '100020', 'relevance': 1},
#  {'qid': '409', 'docid': '100020', 'relevance': 1},
#  {'qid': '410', 'docid': '100020', 'relevance': 1},
#  {'qid': '411', 'docid': '100020', 'relevance': 1},
#  {'qid': '412', 'docid': '100020', 'relevance': 1},
#  {'qid': '413', 'docid': '100020', 'relevance': 1},
#  {'qid': '414', 'docid': '100020', 'relevance': 1},
#  {'qid': '415', 'docid': '100020', 'relevance': 1},
#  {'qid': '416', 'docid': '100020', 'relevance': 1},
#  {'qid': '417', 'docid': '100020', 'relevance': 1},
#  {'qid': '418', 'docid': '100020', 'relevance': 1},
#  {'qid': '419', 'docid': '100020', 'relevance': 1},
#  {'qid': '420', 'docid': '100021', 'relevance': 1},
#  {'qid': '421', 'docid': '100021', 'relevance': 1},
#  {'qid': '422', 'docid': '100021', 'relevance': 1},
#  {'qid': '423', 'docid': '100021', 'relevance': 1},
#  {'qid': '424', 'docid': '100021', 'relevance': 1},
#  {'qid': '425', 'docid': '100021', 'relevance': 1},
#  {'qid': '426', 'docid': '100021', 'relevance': 1},
#  {'qid': '427', 'docid': '100021', 'relevance': 1},
#  {'qid': '428', 'docid': '100021', 'relevance': 1},
#  {'qid': '429', 'docid': '100021', 'relevance': 1},
#  {'qid': '430', 'docid': '100021', 'relevance': 1},
#  {'qid': '431', 'docid': '100021', 'relevance': 1},
#  {'qid': '432', 'docid': '100021', 'relevance': 1},
#  {'qid': '433', 'docid': '100021', 'relevance': 1},
#  {'qid': '434', 'docid': '100021', 'relevance': 1},
#  {'qid': '435', 'docid': '100021', 'relevance': 1},
#  {'qid': '436', 'docid': '100021', 'relevance': 1},
#  {'qid': '437', 'docid': '100021', 'relevance': 1},
#  {'qid': '438', 'docid': '100021', 'relevance': 1},
#  {'qid': '439', 'docid': '100021', 'relevance': 1},
#  {'qid': '440', 'docid': '100022', 'relevance': 1},
#  {'qid': '441', 'docid': '100022', 'relevance': 1},
#  {'qid': '442', 'docid': '100022', 'relevance': 1},
#  {'qid': '443', 'docid': '100022', 'relevance': 1},
#  {'qid': '444', 'docid': '100022', 'relevance': 1},
#  {'qid': '445', 'docid': '100022', 'relevance': 1},
#  {'qid': '446', 'docid': '100022', 'relevance': 1},
#  {'qid': '447', 'docid': '100022', 'relevance': 1},
#  {'qid': '448', 'docid': '100022', 'relevance': 1},
#  {'qid': '449', 'docid': '100022', 'relevance': 1},
#  {'qid': '450', 'docid': '100022', 'relevance': 1},
#  {'qid': '451', 'docid': '100022', 'relevance': 1},
#  {'qid': '452', 'docid': '100022', 'relevance': 1},
#  {'qid': '453', 'docid': '100022', 'relevance': 1},
#  {'qid': '454', 'docid': '100022', 'relevance': 1},
#  {'qid': '455', 'docid': '100022', 'relevance': 1},
#  {'qid': '456', 'docid': '100022', 'relevance': 1},
#  {'qid': '457', 'docid': '100022', 'relevance': 1},
#  {'qid': '458', 'docid': '100022', 'relevance': 1},
#  {'qid': '459', 'docid': '100022', 'relevance': 1},
#  {'qid': '460', 'docid': '100023', 'relevance': 1},
#  {'qid': '461', 'docid': '100023', 'relevance': 1},
#  {'qid': '462', 'docid': '100023', 'relevance': 1},
#  {'qid': '463', 'docid': '100023', 'relevance': 1},
#  {'qid': '464', 'docid': '100023', 'relevance': 1},
#  {'qid': '465', 'docid': '100023', 'relevance': 1},
#  {'qid': '466', 'docid': '100023', 'relevance': 1},
#  {'qid': '467', 'docid': '100023', 'relevance': 1},
#  {'qid': '468', 'docid': '100023', 'relevance': 1},
#  {'qid': '469', 'docid': '100023', 'relevance': 1},
#  {'qid': '470', 'docid': '100023', 'relevance': 1},
#  {'qid': '471', 'docid': '100023', 'relevance': 1},
#  {'qid': '472', 'docid': '100023', 'relevance': 1},
#  {'qid': '473', 'docid': '100023', 'relevance': 1},
#  {'qid': '474', 'docid': '100023', 'relevance': 1},
#  {'qid': '475', 'docid': '100023', 'relevance': 1},
#  {'qid': '476', 'docid': '100023', 'relevance': 1},
#  {'qid': '477', 'docid': '100023', 'relevance': 1},
#  {'qid': '478', 'docid': '100023', 'relevance': 1},
#  {'qid': '479', 'docid': '100023', 'relevance': 1},
#  {'qid': '480', 'docid': '100024', 'relevance': 1},
#  {'qid': '481', 'docid': '100024', 'relevance': 1},
#  {'qid': '482', 'docid': '100024', 'relevance': 1},
#  {'qid': '483', 'docid': '100024', 'relevance': 1},
#  {'qid': '484', 'docid': '100024', 'relevance': 1},
#  {'qid': '485', 'docid': '100024', 'relevance': 1},
#  {'qid': '486', 'docid': '100024', 'relevance': 1},
#  {'qid': '487', 'docid': '100024', 'relevance': 1},
#  {'qid': '488', 'docid': '100024', 'relevance': 1},
#  {'qid': '489', 'docid': '100024', 'relevance': 1},
#  {'qid': '490', 'docid': '100024', 'relevance': 1},
#  {'qid': '491', 'docid': '100024', 'relevance': 1},
#  {'qid': '492', 'docid': '100024', 'relevance': 1},
#  {'qid': '493', 'docid': '100024', 'relevance': 1},
#  {'qid': '494', 'docid': '100024', 'relevance': 1},
#  {'qid': '495', 'docid': '100024', 'relevance': 1},
#  {'qid': '496', 'docid': '100024', 'relevance': 1},
#  {'qid': '497', 'docid': '100024', 'relevance': 1},
#  {'qid': '498', 'docid': '100024', 'relevance': 1},
#  {'qid': '499', 'docid': '100024', 'relevance': 1},
#  {'qid': '500', 'docid': '100025', 'relevance': 1},
#  {'qid': '501', 'docid': '100025', 'relevance': 1},
#  {'qid': '502', 'docid': '100025', 'relevance': 1},
#  {'qid': '503', 'docid': '100025', 'relevance': 1},
#  {'qid': '504', 'docid': '100025', 'relevance': 1},
#  {'qid': '505', 'docid': '100025', 'relevance': 1},
#  {'qid': '506', 'docid': '100025', 'relevance': 1},
#  {'qid': '507', 'docid': '100025', 'relevance': 1},
#  {'qid': '508', 'docid': '100025', 'relevance': 1},
#  {'qid': '509', 'docid': '100025', 'relevance': 1},
#  {'qid': '510', 'docid': '100025', 'relevance': 1},
#  {'qid': '511', 'docid': '100025', 'relevance': 1},
#  {'qid': '512', 'docid': '100025', 'relevance': 1},
#  {'qid': '513', 'docid': '100025', 'relevance': 1},
#  {'qid': '514', 'docid': '100025', 'relevance': 1},
#  {'qid': '515', 'docid': '100025', 'relevance': 1},
#  {'qid': '516', 'docid': '100025', 'relevance': 1},
#  {'qid': '517', 'docid': '100025', 'relevance': 1},
#  {'qid': '518', 'docid': '100025', 'relevance': 1},
#  {'qid': '519', 'docid': '100025', 'relevance': 1},
#  {'qid': '520', 'docid': '100026', 'relevance': 1},
#  {'qid': '521', 'docid': '100026', 'relevance': 1},
#  {'qid': '522', 'docid': '100026', 'relevance': 1},
#  {'qid': '523', 'docid': '100026', 'relevance': 1},
#  {'qid': '524', 'docid': '100026', 'relevance': 1},
#  {'qid': '525', 'docid': '100026', 'relevance': 1},
#  {'qid': '526', 'docid': '100026', 'relevance': 1},
#  {'qid': '527', 'docid': '100026', 'relevance': 1},
#  {'qid': '528', 'docid': '100026', 'relevance': 1},
#  {'qid': '529', 'docid': '100026', 'relevance': 1},
#  {'qid': '530', 'docid': '100026', 'relevance': 1},
#  {'qid': '531', 'docid': '100026', 'relevance': 1},
#  {'qid': '532', 'docid': '100026', 'relevance': 1},
#  {'qid': '533', 'docid': '100026', 'relevance': 1},
#  {'qid': '534', 'docid': '100026', 'relevance': 1},
#  {'qid': '535', 'docid': '100026', 'relevance': 1},
#  {'qid': '536', 'docid': '100026', 'relevance': 1},
#  {'qid': '537', 'docid': '100026', 'relevance': 1},
#  {'qid': '538', 'docid': '100026', 'relevance': 1},
#  {'qid': '539', 'docid': '100026', 'relevance': 1},
#  {'qid': '540', 'docid': '100027', 'relevance': 1},
#  {'qid': '541', 'docid': '100027', 'relevance': 1},
#  {'qid': '542', 'docid': '100027', 'relevance': 1},
#  {'qid': '543', 'docid': '100027', 'relevance': 1},
#  {'qid': '544', 'docid': '100027', 'relevance': 1},
#  {'qid': '545', 'docid': '100027', 'relevance': 1},
#  {'qid': '546', 'docid': '100027', 'relevance': 1},
#  {'qid': '547', 'docid': '100027', 'relevance': 1},
#  {'qid': '548', 'docid': '100027', 'relevance': 1},
#  {'qid': '549', 'docid': '100027', 'relevance': 1},
#  {'qid': '550', 'docid': '100027', 'relevance': 1},
#  {'qid': '551', 'docid': '100027', 'relevance': 1},
#  {'qid': '552', 'docid': '100027', 'relevance': 1},
#  {'qid': '553', 'docid': '100027', 'relevance': 1},
#  {'qid': '554', 'docid': '100027', 'relevance': 1},
#  {'qid': '555', 'docid': '100027', 'relevance': 1},
#  {'qid': '556', 'docid': '100027', 'relevance': 1},
#  {'qid': '557', 'docid': '100027', 'relevance': 1},
#  {'qid': '558', 'docid': '100027', 'relevance': 1},
#  {'qid': '559', 'docid': '100027', 'relevance': 1},
#  {'qid': '560', 'docid': '100028', 'relevance': 1},
#  {'qid': '561', 'docid': '100028', 'relevance': 1},
#  {'qid': '562', 'docid': '100028', 'relevance': 1},
#  {'qid': '563', 'docid': '100028', 'relevance': 1},
#  {'qid': '564', 'docid': '100028', 'relevance': 1},
#  {'qid': '565', 'docid': '100028', 'relevance': 1},
#  {'qid': '566', 'docid': '100028', 'relevance': 1},
#  {'qid': '567', 'docid': '100028', 'relevance': 1},
#  {'qid': '568', 'docid': '100028', 'relevance': 1},
#  {'qid': '569', 'docid': '100028', 'relevance': 1},
#  {'qid': '570', 'docid': '100028', 'relevance': 1},
#  {'qid': '571', 'docid': '100028', 'relevance': 1},
#  {'qid': '572', 'docid': '100028', 'relevance': 1},
#  {'qid': '573', 'docid': '100028', 'relevance': 1},
#  {'qid': '574', 'docid': '100028', 'relevance': 1},
#  {'qid': '575', 'docid': '100028', 'relevance': 1},
#  {'qid': '576', 'docid': '100028', 'relevance': 1},
#  {'qid': '577', 'docid': '100028', 'relevance': 1},
#  {'qid': '578', 'docid': '100028', 'relevance': 1},
#  {'qid': '579', 'docid': '100028', 'relevance': 1},
#  {'qid': '580', 'docid': '100029', 'relevance': 1},
#  {'qid': '581', 'docid': '100029', 'relevance': 1},
#  {'qid': '582', 'docid': '100029', 'relevance': 1},
#  {'qid': '583', 'docid': '100029', 'relevance': 1},
#  {'qid': '584', 'docid': '100029', 'relevance': 1},
#  {'qid': '585', 'docid': '100029', 'relevance': 1},
#  {'qid': '586', 'docid': '100029', 'relevance': 1},
#  {'qid': '587', 'docid': '100029', 'relevance': 1},
#  {'qid': '588', 'docid': '100029', 'relevance': 1},
#  {'qid': '589', 'docid': '100029', 'relevance': 1},
#  {'qid': '590', 'docid': '100029', 'relevance': 1},
#  {'qid': '591', 'docid': '100029', 'relevance': 1},
#  {'qid': '592', 'docid': '100029', 'relevance': 1},
#  {'qid': '593', 'docid': '100029', 'relevance': 1},
#  {'qid': '594', 'docid': '100029', 'relevance': 1},
#  {'qid': '595', 'docid': '100029', 'relevance': 1},
#  {'qid': '596', 'docid': '100029', 'relevance': 1},
#  {'qid': '597', 'docid': '100029', 'relevance': 1},
#  {'qid': '598', 'docid': '100029', 'relevance': 1},
#  {'qid': '599', 'docid': '100029', 'relevance': 1},
#  {'qid': '600', 'docid': '100030', 'relevance': 1},
#  {'qid': '601', 'docid': '100030', 'relevance': 1},
#  {'qid': '602', 'docid': '100030', 'relevance': 1},
#  {'qid': '603', 'docid': '100030', 'relevance': 1},
#  {'qid': '604', 'docid': '100030', 'relevance': 1},
#  {'qid': '605', 'docid': '100030', 'relevance': 1},
#  {'qid': '606', 'docid': '100030', 'relevance': 1},
#  {'qid': '607', 'docid': '100030', 'relevance': 1},
#  {'qid': '608', 'docid': '100030', 'relevance': 1},
#  {'qid': '609', 'docid': '100030', 'relevance': 1},
#  {'qid': '610', 'docid': '100030', 'relevance': 1},
#  {'qid': '611', 'docid': '100030', 'relevance': 1},
#  {'qid': '612', 'docid': '100030', 'relevance': 1},
#  {'qid': '613', 'docid': '100030', 'relevance': 1},
#  {'qid': '614', 'docid': '100030', 'relevance': 1},
#  {'qid': '615', 'docid': '100030', 'relevance': 1},
#  {'qid': '616', 'docid': '100030', 'relevance': 1},
#  {'qid': '617', 'docid': '100030', 'relevance': 1},
#  {'qid': '618', 'docid': '100030', 'relevance': 1},
#  {'qid': '619', 'docid': '100030', 'relevance': 1},
#  {'qid': '620', 'docid': '100031', 'relevance': 1},
#  {'qid': '621', 'docid': '100031', 'relevance': 1},
#  {'qid': '622', 'docid': '100031', 'relevance': 1},
#  {'qid': '623', 'docid': '100031', 'relevance': 1},
#  {'qid': '624', 'docid': '100031', 'relevance': 1},
#  {'qid': '625', 'docid': '100031', 'relevance': 1},
#  {'qid': '626', 'docid': '100031', 'relevance': 1},
#  {'qid': '627', 'docid': '100031', 'relevance': 1},
#  {'qid': '628', 'docid': '100031', 'relevance': 1},
#  {'qid': '629', 'docid': '100031', 'relevance': 1},
#  {'qid': '630', 'docid': '100031', 'relevance': 1},
#  {'qid': '631', 'docid': '100031', 'relevance': 1},
#  {'qid': '632', 'docid': '100031', 'relevance': 1},
#  {'qid': '633', 'docid': '100031', 'relevance': 1},
#  {'qid': '634', 'docid': '100031', 'relevance': 1},
#  {'qid': '635', 'docid': '100031', 'relevance': 1},
#  {'qid': '636', 'docid': '100031', 'relevance': 1},
#  {'qid': '637', 'docid': '100031', 'relevance': 1},
#  {'qid': '638', 'docid': '100031', 'relevance': 1},
#  {'qid': '639', 'docid': '100031', 'relevance': 1},
#  {'qid': '640', 'docid': '100032', 'relevance': 1},
#  {'qid': '641', 'docid': '100032', 'relevance': 1},
#  {'qid': '642', 'docid': '100032', 'relevance': 1},
#  {'qid': '643', 'docid': '100032', 'relevance': 1},
#  {'qid': '644', 'docid': '100032', 'relevance': 1},
#  {'qid': '645', 'docid': '100032', 'relevance': 1},
#  {'qid': '646', 'docid': '100032', 'relevance': 1},
#  {'qid': '647', 'docid': '100032', 'relevance': 1},
#  {'qid': '648', 'docid': '100032', 'relevance': 1},
#  {'qid': '649', 'docid': '100032', 'relevance': 1},
#  {'qid': '650', 'docid': '100032', 'relevance': 1},
#  {'qid': '651', 'docid': '100032', 'relevance': 1},
#  {'qid': '652', 'docid': '100032', 'relevance': 1},
#  {'qid': '653', 'docid': '100032', 'relevance': 1},
#  {'qid': '654', 'docid': '100032', 'relevance': 1},
#  {'qid': '655', 'docid': '100032', 'relevance': 1},
#  {'qid': '656', 'docid': '100032', 'relevance': 1},
#  {'qid': '657', 'docid': '100032', 'relevance': 1},
#  {'qid': '658', 'docid': '100032', 'relevance': 1},
#  {'qid': '659', 'docid': '100032', 'relevance': 1},
#  {'qid': '660', 'docid': '100033', 'relevance': 1},
#  {'qid': '661', 'docid': '100033', 'relevance': 1},
#  {'qid': '662', 'docid': '100033', 'relevance': 1},
#  {'qid': '663', 'docid': '100033', 'relevance': 1},
#  {'qid': '664', 'docid': '100033', 'relevance': 1},
#  {'qid': '665', 'docid': '100033', 'relevance': 1},
#  {'qid': '666', 'docid': '100033', 'relevance': 1},
#  {'qid': '667', 'docid': '100033', 'relevance': 1},
#  {'qid': '668', 'docid': '100033', 'relevance': 1},
#  {'qid': '669', 'docid': '100033', 'relevance': 1},
#  {'qid': '670', 'docid': '100033', 'relevance': 1},
#  {'qid': '671', 'docid': '100033', 'relevance': 1},
#  {'qid': '672', 'docid': '100033', 'relevance': 1},
#  {'qid': '673', 'docid': '100033', 'relevance': 1},
#  {'qid': '674', 'docid': '100033', 'relevance': 1},
#  {'qid': '675', 'docid': '100033', 'relevance': 1},
#  {'qid': '676', 'docid': '100033', 'relevance': 1},
#  {'qid': '677', 'docid': '100033', 'relevance': 1},
#  {'qid': '678', 'docid': '100033', 'relevance': 1},
#  {'qid': '679', 'docid': '100033', 'relevance': 1},
#  {'qid': '680', 'docid': '100034', 'relevance': 1},
#  {'qid': '681', 'docid': '100034', 'relevance': 1},
#  {'qid': '682', 'docid': '100034', 'relevance': 1},
#  {'qid': '683', 'docid': '100034', 'relevance': 1},
#  {'qid': '684', 'docid': '100034', 'relevance': 1},
#  {'qid': '685', 'docid': '100034', 'relevance': 1},
#  {'qid': '686', 'docid': '100034', 'relevance': 1},
#  {'qid': '687', 'docid': '100034', 'relevance': 1},
#  {'qid': '688', 'docid': '100034', 'relevance': 1},
#  {'qid': '689', 'docid': '100034', 'relevance': 1},
#  {'qid': '690', 'docid': '100034', 'relevance': 1},
#  {'qid': '691', 'docid': '100034', 'relevance': 1},
#  {'qid': '692', 'docid': '100034', 'relevance': 1},
#  {'qid': '693', 'docid': '100034', 'relevance': 1},
#  {'qid': '694', 'docid': '100034', 'relevance': 1},
#  {'qid': '695', 'docid': '100034', 'relevance': 1},
#  {'qid': '696', 'docid': '100034', 'relevance': 1},
#  {'qid': '697', 'docid': '100034', 'relevance': 1},
#  {'qid': '698', 'docid': '100034', 'relevance': 1},
#  {'qid': '699', 'docid': '100034', 'relevance': 1},
#  {'qid': '700', 'docid': '100035', 'relevance': 1},
#  {'qid': '701', 'docid': '100035', 'relevance': 1},
#  {'qid': '702', 'docid': '100035', 'relevance': 1},
#  {'qid': '703', 'docid': '100035', 'relevance': 1},
#  {'qid': '704', 'docid': '100035', 'relevance': 1},
#  {'qid': '705', 'docid': '100035', 'relevance': 1},
#  {'qid': '706', 'docid': '100035', 'relevance': 1},
#  {'qid': '707', 'docid': '100035', 'relevance': 1},
#  {'qid': '708', 'docid': '100035', 'relevance': 1},
#  {'qid': '709', 'docid': '100035', 'relevance': 1},
#  {'qid': '710', 'docid': '100035', 'relevance': 1},
#  {'qid': '711', 'docid': '100035', 'relevance': 1},
#  {'qid': '712', 'docid': '100035', 'relevance': 1},
#  {'qid': '713', 'docid': '100035', 'relevance': 1},
#  {'qid': '714', 'docid': '100035', 'relevance': 1},
#  {'qid': '715', 'docid': '100035', 'relevance': 1},
#  {'qid': '716', 'docid': '100035', 'relevance': 1},
#  {'qid': '717', 'docid': '100035', 'relevance': 1},
#  {'qid': '718', 'docid': '100035', 'relevance': 1},
#  {'qid': '719', 'docid': '100035', 'relevance': 1},
#  {'qid': '720', 'docid': '100036', 'relevance': 1},
#  {'qid': '721', 'docid': '100036', 'relevance': 1},
#  {'qid': '722', 'docid': '100036', 'relevance': 1},
#  {'qid': '723', 'docid': '100036', 'relevance': 1},
#  {'qid': '724', 'docid': '100036', 'relevance': 1},
#  {'qid': '725', 'docid': '100036', 'relevance': 1},
#  {'qid': '726', 'docid': '100036', 'relevance': 1},
#  {'qid': '727', 'docid': '100036', 'relevance': 1},
#  {'qid': '728', 'docid': '100036', 'relevance': 1},
#  {'qid': '729', 'docid': '100036', 'relevance': 1},
#  {'qid': '730', 'docid': '100036', 'relevance': 1},
#  {'qid': '731', 'docid': '100036', 'relevance': 1},
#  {'qid': '732', 'docid': '100036', 'relevance': 1},
#  {'qid': '733', 'docid': '100036', 'relevance': 1},
#  {'qid': '734', 'docid': '100036', 'relevance': 1},
#  {'qid': '735', 'docid': '100036', 'relevance': 1},
#  {'qid': '736', 'docid': '100036', 'relevance': 1},
#  {'qid': '737', 'docid': '100036', 'relevance': 1},
#  {'qid': '738', 'docid': '100036', 'relevance': 1},
#  {'qid': '739', 'docid': '100036', 'relevance': 1},
#  {'qid': '740', 'docid': '100037', 'relevance': 1},
#  {'qid': '741', 'docid': '100037', 'relevance': 1},
#  {'qid': '742', 'docid': '100037', 'relevance': 1},
#  {'qid': '743', 'docid': '100037', 'relevance': 1},
#  {'qid': '744', 'docid': '100037', 'relevance': 1},
#  {'qid': '745', 'docid': '100037', 'relevance': 1},
#  {'qid': '746', 'docid': '100037', 'relevance': 1},
#  {'qid': '747', 'docid': '100037', 'relevance': 1},
#  {'qid': '748', 'docid': '100037', 'relevance': 1},
#  {'qid': '749', 'docid': '100037', 'relevance': 1},
#  {'qid': '750', 'docid': '100037', 'relevance': 1},
#  {'qid': '751', 'docid': '100037', 'relevance': 1},
#  {'qid': '752', 'docid': '100037', 'relevance': 1},
#  {'qid': '753', 'docid': '100037', 'relevance': 1},
#  {'qid': '754', 'docid': '100037', 'relevance': 1},
#  {'qid': '755', 'docid': '100037', 'relevance': 1},
#  {'qid': '756', 'docid': '100037', 'relevance': 1},
#  {'qid': '757', 'docid': '100037', 'relevance': 1},
#  {'qid': '758', 'docid': '100037', 'relevance': 1},
#  {'qid': '759', 'docid': '100037', 'relevance': 1},
#  {'qid': '760', 'docid': '100038', 'relevance': 1},
#  {'qid': '761', 'docid': '100038', 'relevance': 1},
#  {'qid': '762', 'docid': '100038', 'relevance': 1},
#  {'qid': '763', 'docid': '100038', 'relevance': 1},
#  {'qid': '764', 'docid': '100038', 'relevance': 1},
#  {'qid': '765', 'docid': '100038', 'relevance': 1},
#  {'qid': '766', 'docid': '100038', 'relevance': 1},
#  {'qid': '767', 'docid': '100038', 'relevance': 1},
#  {'qid': '768', 'docid': '100038', 'relevance': 1},
#  {'qid': '769', 'docid': '100038', 'relevance': 1},
#  {'qid': '770', 'docid': '100038', 'relevance': 1},
#  {'qid': '771', 'docid': '100038', 'relevance': 1},
#  {'qid': '772', 'docid': '100038', 'relevance': 1},
#  {'qid': '773', 'docid': '100038', 'relevance': 1},
#  {'qid': '774', 'docid': '100038', 'relevance': 1},
#  {'qid': '775', 'docid': '100038', 'relevance': 1},
#  {'qid': '776', 'docid': '100038', 'relevance': 1},
#  {'qid': '777', 'docid': '100038', 'relevance': 1},
#  {'qid': '778', 'docid': '100038', 'relevance': 1},
#  {'qid': '779', 'docid': '100038', 'relevance': 1},
#  {'qid': '780', 'docid': '100039', 'relevance': 1},
#  {'qid': '781', 'docid': '100039', 'relevance': 1},
#  {'qid': '782', 'docid': '100039', 'relevance': 1},
#  {'qid': '783', 'docid': '100039', 'relevance': 1},
#  {'qid': '784', 'docid': '100039', 'relevance': 1},
#  {'qid': '785', 'docid': '100039', 'relevance': 1},
#  {'qid': '786', 'docid': '100039', 'relevance': 1},
#  {'qid': '787', 'docid': '100039', 'relevance': 1},
#  {'qid': '788', 'docid': '100039', 'relevance': 1},
#  {'qid': '789', 'docid': '100039', 'relevance': 1},
#  {'qid': '790', 'docid': '100039', 'relevance': 1},
#  {'qid': '791', 'docid': '100039', 'relevance': 1},
#  {'qid': '792', 'docid': '100039', 'relevance': 1},
#  {'qid': '793', 'docid': '100039', 'relevance': 1},
#  {'qid': '794', 'docid': '100039', 'relevance': 1},
#  {'qid': '795', 'docid': '100039', 'relevance': 1},
#  {'qid': '796', 'docid': '100039', 'relevance': 1},
#  {'qid': '797', 'docid': '100039', 'relevance': 1},
#  {'qid': '798', 'docid': '100039', 'relevance': 1},
#  {'qid': '799', 'docid': '100039', 'relevance': 1},
#  {'qid': '800', 'docid': '100040', 'relevance': 1},
#  {'qid': '801', 'docid': '100040', 'relevance': 1},
#  {'qid': '802', 'docid': '100040', 'relevance': 1},
#  {'qid': '803', 'docid': '100040', 'relevance': 1},
#  {'qid': '804', 'docid': '100040', 'relevance': 1},
#  {'qid': '805', 'docid': '100040', 'relevance': 1},
#  {'qid': '806', 'docid': '100040', 'relevance': 1},
#  {'qid': '807', 'docid': '100040', 'relevance': 1},
#  {'qid': '808', 'docid': '100040', 'relevance': 1},
#  {'qid': '809', 'docid': '100040', 'relevance': 1},
#  {'qid': '810', 'docid': '100040', 'relevance': 1},
#  {'qid': '811', 'docid': '100040', 'relevance': 1},
#  {'qid': '812', 'docid': '100040', 'relevance': 1},
#  {'qid': '813', 'docid': '100040', 'relevance': 1},
#  {'qid': '814', 'docid': '100040', 'relevance': 1},
#  {'qid': '815', 'docid': '100040', 'relevance': 1},
#  {'qid': '816', 'docid': '100040', 'relevance': 1},
#  {'qid': '817', 'docid': '100040', 'relevance': 1},
#  {'qid': '818', 'docid': '100040', 'relevance': 1},
#  {'qid': '819', 'docid': '100040', 'relevance': 1},
#  {'qid': '820', 'docid': '100041', 'relevance': 1},
#  {'qid': '821', 'docid': '100041', 'relevance': 1},
#  {'qid': '822', 'docid': '100041', 'relevance': 1},
#  {'qid': '823', 'docid': '100041', 'relevance': 1},
#  {'qid': '824', 'docid': '100041', 'relevance': 1},
#  {'qid': '825', 'docid': '100041', 'relevance': 1},
#  {'qid': '826', 'docid': '100041', 'relevance': 1},
#  {'qid': '827', 'docid': '100041', 'relevance': 1},
#  {'qid': '828', 'docid': '100041', 'relevance': 1},
#  {'qid': '829', 'docid': '100041', 'relevance': 1},
#  {'qid': '830', 'docid': '100041', 'relevance': 1},
#  {'qid': '831', 'docid': '100041', 'relevance': 1},
#  {'qid': '832', 'docid': '100041', 'relevance': 1},
#  {'qid': '833', 'docid': '100041', 'relevance': 1},
#  {'qid': '834', 'docid': '100041', 'relevance': 1},
#  {'qid': '835', 'docid': '100041', 'relevance': 1},
#  {'qid': '836', 'docid': '100041', 'relevance': 1},
#  {'qid': '837', 'docid': '100041', 'relevance': 1},
#  {'qid': '838', 'docid': '100041', 'relevance': 1},
#  {'qid': '839', 'docid': '100041', 'relevance': 1},
#  {'qid': '840', 'docid': '100042', 'relevance': 1},
#  {'qid': '841', 'docid': '100042', 'relevance': 1},
#  {'qid': '842', 'docid': '100042', 'relevance': 1},
#  {'qid': '843', 'docid': '100042', 'relevance': 1},
#  {'qid': '844', 'docid': '100042', 'relevance': 1},
#  {'qid': '845', 'docid': '100042', 'relevance': 1},
#  {'qid': '846', 'docid': '100042', 'relevance': 1},
#  {'qid': '847', 'docid': '100042', 'relevance': 1},
#  {'qid': '848', 'docid': '100042', 'relevance': 1},
#  {'qid': '849', 'docid': '100042', 'relevance': 1},
#  {'qid': '850', 'docid': '100042', 'relevance': 1},
#  {'qid': '851', 'docid': '100042', 'relevance': 1},
#  {'qid': '852', 'docid': '100042', 'relevance': 1},
#  {'qid': '853', 'docid': '100042', 'relevance': 1},
#  {'qid': '854', 'docid': '100042', 'relevance': 1},
#  {'qid': '855', 'docid': '100042', 'relevance': 1},
#  {'qid': '856', 'docid': '100042', 'relevance': 1},
#  {'qid': '857', 'docid': '100042', 'relevance': 1},
#  {'qid': '858', 'docid': '100042', 'relevance': 1},
#  {'qid': '859', 'docid': '100042', 'relevance': 1},
#  {'qid': '860', 'docid': '100043', 'relevance': 1},
#  {'qid': '861', 'docid': '100043', 'relevance': 1},
#  {'qid': '862', 'docid': '100043', 'relevance': 1},
#  {'qid': '863', 'docid': '100043', 'relevance': 1},
#  {'qid': '864', 'docid': '100043', 'relevance': 1},
#  {'qid': '865', 'docid': '100043', 'relevance': 1},
#  {'qid': '866', 'docid': '100043', 'relevance': 1},
#  {'qid': '867', 'docid': '100043', 'relevance': 1},
#  {'qid': '868', 'docid': '100043', 'relevance': 1},
#  {'qid': '869', 'docid': '100043', 'relevance': 1},
#  {'qid': '870', 'docid': '100043', 'relevance': 1},
#  {'qid': '871', 'docid': '100043', 'relevance': 1},
#  {'qid': '872', 'docid': '100043', 'relevance': 1},
#  {'qid': '873', 'docid': '100043', 'relevance': 1},
#  {'qid': '874', 'docid': '100043', 'relevance': 1},
#  {'qid': '875', 'docid': '100043', 'relevance': 1},
#  {'qid': '876', 'docid': '100043', 'relevance': 1},
#  {'qid': '877', 'docid': '100043', 'relevance': 1},
#  {'qid': '878', 'docid': '100043', 'relevance': 1},
#  {'qid': '879', 'docid': '100043', 'relevance': 1},
#  {'qid': '880', 'docid': '100044', 'relevance': 1},
#  {'qid': '881', 'docid': '100044', 'relevance': 1},
#  {'qid': '882', 'docid': '100044', 'relevance': 1},
#  {'qid': '883', 'docid': '100044', 'relevance': 1},
#  {'qid': '884', 'docid': '100044', 'relevance': 1},
#  {'qid': '885', 'docid': '100044', 'relevance': 1},
#  {'qid': '886', 'docid': '100044', 'relevance': 1},
#  {'qid': '887', 'docid': '100044', 'relevance': 1},
#  {'qid': '888', 'docid': '100044', 'relevance': 1},
#  {'qid': '889', 'docid': '100044', 'relevance': 1},
#  {'qid': '890', 'docid': '100044', 'relevance': 1},
#  {'qid': '891', 'docid': '100044', 'relevance': 1},
#  {'qid': '892', 'docid': '100044', 'relevance': 1},
#  {'qid': '893', 'docid': '100044', 'relevance': 1},
#  {'qid': '894', 'docid': '100044', 'relevance': 1},
#  {'qid': '895', 'docid': '100044', 'relevance': 1},
#  {'qid': '896', 'docid': '100044', 'relevance': 1},
#  {'qid': '897', 'docid': '100044', 'relevance': 1},
#  {'qid': '898', 'docid': '100044', 'relevance': 1},
#  {'qid': '899', 'docid': '100044', 'relevance': 1},
#  {'qid': '900', 'docid': '100045', 'relevance': 1},
#  {'qid': '901', 'docid': '100045', 'relevance': 1},
#  {'qid': '902', 'docid': '100045', 'relevance': 1},
#  {'qid': '903', 'docid': '100045', 'relevance': 1},
#  {'qid': '904', 'docid': '100045', 'relevance': 1},
#  {'qid': '905', 'docid': '100045', 'relevance': 1},
#  {'qid': '906', 'docid': '100045', 'relevance': 1},
#  {'qid': '907', 'docid': '100045', 'relevance': 1},
#  {'qid': '908', 'docid': '100045', 'relevance': 1},
#  {'qid': '909', 'docid': '100045', 'relevance': 1},
#  {'qid': '910', 'docid': '100045', 'relevance': 1},
#  {'qid': '911', 'docid': '100045', 'relevance': 1},
#  {'qid': '912', 'docid': '100045', 'relevance': 1},
#  {'qid': '913', 'docid': '100045', 'relevance': 1},
#  {'qid': '914', 'docid': '100045', 'relevance': 1},
#  {'qid': '915', 'docid': '100045', 'relevance': 1},
#  {'qid': '916', 'docid': '100045', 'relevance': 1},
#  {'qid': '917', 'docid': '100045', 'relevance': 1},
#  {'qid': '918', 'docid': '100045', 'relevance': 1},
#  {'qid': '919', 'docid': '100045', 'relevance': 1},
#  {'qid': '920', 'docid': '100046', 'relevance': 1},
#  {'qid': '921', 'docid': '100046', 'relevance': 1},
#  {'qid': '922', 'docid': '100046', 'relevance': 1},
#  {'qid': '923', 'docid': '100046', 'relevance': 1},
#  {'qid': '924', 'docid': '100046', 'relevance': 1},
#  {'qid': '925', 'docid': '100046', 'relevance': 1},
#  {'qid': '926', 'docid': '100046', 'relevance': 1},
#  {'qid': '927', 'docid': '100046', 'relevance': 1},
#  {'qid': '928', 'docid': '100046', 'relevance': 1},
#  {'qid': '929', 'docid': '100046', 'relevance': 1},
#  {'qid': '930', 'docid': '100046', 'relevance': 1},
#  {'qid': '931', 'docid': '100046', 'relevance': 1},
#  {'qid': '932', 'docid': '100046', 'relevance': 1},
#  {'qid': '933', 'docid': '100046', 'relevance': 1},
#  {'qid': '934', 'docid': '100046', 'relevance': 1},
#  {'qid': '935', 'docid': '100046', 'relevance': 1},
#  {'qid': '936', 'docid': '100046', 'relevance': 1},
#  {'qid': '937', 'docid': '100046', 'relevance': 1},
#  {'qid': '938', 'docid': '100046', 'relevance': 1},
#  {'qid': '939', 'docid': '100046', 'relevance': 1},
#  {'qid': '940', 'docid': '100047', 'relevance': 1},
#  {'qid': '941', 'docid': '100047', 'relevance': 1},
#  {'qid': '942', 'docid': '100047', 'relevance': 1},
#  {'qid': '943', 'docid': '100047', 'relevance': 1},
#  {'qid': '944', 'docid': '100047', 'relevance': 1},
#  {'qid': '945', 'docid': '100047', 'relevance': 1},
#  {'qid': '946', 'docid': '100047', 'relevance': 1},
#  {'qid': '947', 'docid': '100047', 'relevance': 1},
#  {'qid': '948', 'docid': '100047', 'relevance': 1},
#  {'qid': '949', 'docid': '100047', 'relevance': 1},
#  {'qid': '950', 'docid': '100047', 'relevance': 1},
#  {'qid': '951', 'docid': '100047', 'relevance': 1},
#  {'qid': '952', 'docid': '100047', 'relevance': 1},
#  {'qid': '953', 'docid': '100047', 'relevance': 1},
#  {'qid': '954', 'docid': '100047', 'relevance': 1},
#  {'qid': '955', 'docid': '100047', 'relevance': 1},
#  {'qid': '956', 'docid': '100047', 'relevance': 1},
#  {'qid': '957', 'docid': '100047', 'relevance': 1},
#  {'qid': '958', 'docid': '100047', 'relevance': 1},
#  {'qid': '959', 'docid': '100047', 'relevance': 1},
#  {'qid': '960', 'docid': '100048', 'relevance': 1},
#  {'qid': '961', 'docid': '100048', 'relevance': 1},
#  {'qid': '962', 'docid': '100048', 'relevance': 1},
#  {'qid': '963', 'docid': '100048', 'relevance': 1},
#  {'qid': '964', 'docid': '100048', 'relevance': 1},
#  {'qid': '965', 'docid': '100048', 'relevance': 1},
#  {'qid': '966', 'docid': '100048', 'relevance': 1},
#  {'qid': '967', 'docid': '100048', 'relevance': 1},
#  {'qid': '968', 'docid': '100048', 'relevance': 1},
#  {'qid': '969', 'docid': '100048', 'relevance': 1},
#  {'qid': '970', 'docid': '100048', 'relevance': 1},
#  {'qid': '971', 'docid': '100048', 'relevance': 1},
#  {'qid': '972', 'docid': '100048', 'relevance': 1},
#  {'qid': '973', 'docid': '100048', 'relevance': 1},
#  {'qid': '974', 'docid': '100048', 'relevance': 1},
#  {'qid': '975', 'docid': '100048', 'relevance': 1},
#  {'qid': '976', 'docid': '100048', 'relevance': 1},
#  {'qid': '977', 'docid': '100048', 'relevance': 1},
#  {'qid': '978', 'docid': '100048', 'relevance': 1},
#  {'qid': '979', 'docid': '100048', 'relevance': 1},
#  {'qid': '980', 'docid': '100049', 'relevance': 1},
#  {'qid': '981', 'docid': '100049', 'relevance': 1},
#  {'qid': '982', 'docid': '100049', 'relevance': 1},
#  {'qid': '983', 'docid': '100049', 'relevance': 1},
#  {'qid': '984', 'docid': '100049', 'relevance': 1},
#  {'qid': '985', 'docid': '100049', 'relevance': 1},
#  {'qid': '986', 'docid': '100049', 'relevance': 1},
#  {'qid': '987', 'docid': '100049', 'relevance': 1},
#  {'qid': '988', 'docid': '100049', 'relevance': 1},
#  {'qid': '989', 'docid': '100049', 'relevance': 1},
#  {'qid': '990', 'docid': '100049', 'relevance': 1},
#  {'qid': '991', 'docid': '100049', 'relevance': 1},
#  {'qid': '992', 'docid': '100049', 'relevance': 1},
#  {'qid': '993', 'docid': '100049', 'relevance': 1},
#  {'qid': '994', 'docid': '100049', 'relevance': 1},
#  {'qid': '995', 'docid': '100049', 'relevance': 1},
#  {'qid': '996', 'docid': '100049', 'relevance': 1},
#  {'qid': '997', 'docid': '100049', 'relevance': 1},
#  {'qid': '998', 'docid': '100049', 'relevance': 1},
#  {'qid': '999', 'docid': '100049', 'relevance': 1},
#  ...]

# %%
assert len(qrels_l) == len(queries)

# %% [markdown]
# ## Export

# %%
DATA_DIR = "/home/jinho/FlagEmbedding_Aizip/dataset/tesla_manual"

# %%
import os

# Create directory if it doesn't exist
if not os.path.exists(DATA_DIR):
    os.makedirs(DATA_DIR)

# %%
with open(f"{DATA_DIR}/test_queries.jsonl", "w") as f:
    for record in queries_l:
        f.write(json.dumps(record) + '\n')

# %%
with open(f"{DATA_DIR}/test_qrels.jsonl", "w") as f:
    for record in qrels_l:
        f.write(json.dumps(record) + '\n')

# %%
with open(f"{DATA_DIR}/corpus.jsonl", "w") as f:
    for record in corpus_l:
        f.write(json.dumps(record) + '\n')

# %% [markdown]
# Make sure to add the dataset name to /home/jinho/FlagEmbedding_Aizip/FlagEmbedding_Aizip/evaluation/beir/data_loader.py

# %% [markdown]
# ## (For Japanese) Create a split version

# %%
from sudachipy import tokenizer
from sudachipy import dictionary

# %%
mode = tokenizer.Tokenizer.SplitMode.B

# %%
tokenizer_obj = dictionary.Dictionary().create()

# %%
corpus_l[0]['text']
# Out:
# 'Slackのゲストアカウントの有効期限が切れた（解除済みアカウント）場合は、ゲスト管理システムからゲスト新規登録申請と利用サービス登録申請を実施下さい。\n※ゲスト登録が有効期限内の場合は、マイゲスト一覧から利用サービス登録申請のみ実施下さい\n申請方法は下記手順を参照下さい。\n\n・【ゲスト管理システム】マニュアル-申請者向け\nhttps://docs.google.com/presentation/d/1Z0PUkjNUr9r2GCq5ZEEddd5jPUJg48kPMsCxv5Mtw_M/edit#slide=id.g1287222f34d_1_61\n\n申請の上長承認後、5営業日以内にアカウントが有効化されます。\n有効化完了後は下記メールが送信されますので、メールを確認次第、必要なチャンネルにゲストを招待して下さい。\n※ゲストをチャンネルに招待する際はメールアドレスではなくSlack上の氏名で検索下さい\n件名：【ゲスト管理】利用サービスプロビジョニングエラー対応完了通知\n\n■お問合せ先\n・OA Support Net\n\u3000http://oa.bb.local/oasupport/inquiry_web\n\u3000（投稿カテゴリ：Slack）'

# %%
def split_text(input_dic):
    new_dic = input_dic.copy()
    split_t = ' '.join([m.surface() for m in tokenizer_obj.tokenize(input_dic['text'], mode)])
    new_dic['text'] = split_t
    return new_dic

# %%
split_queries_l = [split_text(q) for q in queries_l]

# %%
split_queries_l
# Out:
# [{'id': '0', 'text': 'ゲスト の アカウント の 有効 期限 が 切れ た 場合 の 対応 方法 を 教え て 欲しい'},
#  {'id': '1', 'text': 'ゲスト の アカウント の 有効 期限 が 切れ て いる'},
#  {'id': '2', 'text': 'ゲスト アカウント の 有効 期限 が 切れ た の で 、 再度 、 有効 に し て 欲しい'},
#  {'id': '3', 'text': 'ゲスト アカウント の 有効 期限 を 再度 有効 に し たい'},
#  {'id': '4', 'text': 'WHC に つい て 問い合わせ し たい'},
#  {'id': '5', 'text': 'WHC の 工数 入力 に つい て 教え て ほしい'},
#  {'id': '6', 'text': 'Trinity ( WHC ) の アドレス を 教え て ください 。'},
#  {'id': '7', 'text': 'WHC 申請 方法 を 教え て 欲しい'},
#  {'id': '8', 'text': 'WHC の 申請 を し たい'},
#  {'id': '9', 'text': 'WHC の 申請 方法 を 確認 し たい'},
#  {'id': '10', 'text': '研修 は WHC に どの よう に 登録 すれ ば よい か ？'},
#  {'id': '11', 'text': 'WHC は どの よう に 申請 し たら いい でしょう か ？'},
#  {'id': '12', 'text': 'WHC に つい て'},
#  {'id': '13', 'text': 'WHC に つい て 問い合わせ し たい 。'},
#  {'id': '14', 'text': 'Chrome の 動作 が おかしい の で 再 インストール し たい'},
#  {'id': '15', 'text': '準 OAPC で GoogleChrome が 起動 し なく なり まし た'},
#  {'id': '16', 'text': 'Chrome を ダウン グレード し たい'},
#  {'id': '17', 'text': 'Chrome の 再 インストール 方法 が 知り たい'},
#  {'id': '18', 'text': 'GoogleChrome を インストール し たい'},
#  {'id': '19', 'text': '準 OAPC へ Chrome を インストール し たい'},
#  {'id': '20', 'text': '準 OAPC へ Chrome を 設定 し たい'},
#  {'id': '21', 'text': 'GoogleChrome の インストール が 失敗 し て しまっ た 。'},
#  {'id': '22', 'text': 'Chrome の インストール 方法 が わかり ませ ん 。'},
#  {'id': '23', 'text': 'Chrome の アンインストール 方法 を 教え て 欲しい'},
#  {'id': '24', 'text': 'データ の PDF 化 が 出来 ない'},
#  {'id': '25', 'text': 'ファイル 等 の PDF 化 に つい て'},
#  {'id': '26', 'text': 'Word 文書 を PDF に 変換 し たい'},
#  {'id': '27', 'text': 'PDF 化 の 手順 を 教え て 欲しい'},
#  {'id': '28',
#   'text': 'PC 故障 に より 新しい PC に 交換 に なり まし た 。 \n 資料 を PDF 化 する 方法 に つい て 推奨 方法 は ある の でしょう か 。'},
#  {'id': '29', 'text': 'Excel など の ファイル を PDF 化 し たい'},
#  {'id': '30', 'text': 'エクセル を PDF 化 し たい'},
#  {'id': '31', 'text': 'PDF 化 の 方法 を 教え て 欲しい'},
#  {'id': '32',
#   'text': 'GooglePlay 未登録 アプリ の インストール 時 、 「 インストール は ブロック さ れ まし た \u3000 携帯 端末 の セキュリティ 上 の 設定 で 供給 元 不明 の Application の インストール を ブロック し て い ます 」 と エラー が 表示 さ れ まし た 。 「 提供 元 不明 アプリ 」 に チェック を 入れ て も よい でしょう か 。'},
#  {'id': '33',
#   'text': 'GooglePlay 未登録 アプリ の インストール 時 、 「 インストール は ブロック さ れ まし た \u3000 携帯 端末 の セキュリティ 上 の 設定 で 供給 元 不明 の Application の インストール を ブロック し て い ます 」 と エラー が 表示 さ れ ます 。'},
#  {'id': '34', 'text': '供給 元 不明 の GooglePlay アプリ を インストール する 方法 を 教え て ください 。'},
#  {'id': '35',
#   'text': 'GooglePlay 未登録 の アプリ を インストール し たい が 、 「 インストール は ブロック さ れ まし た \u3000 携帯 端末 の セキュリティ 上 の 設定 で 供給 元 不明 の Application の インストール を ブロック し て い ます 」 と エラー が 表示 さ れる 。'},
#  {'id': '36',
#   'text': 'GooglePlay アプリ を インストール しよう と する と 、 「 インストール は ブロック さ れ まし た \u3000 携帯 端末 の セキュリティ 上 の 設定 で 供給 元 不明 の Application の インストール を ブロック し て い ます 」 と 表示 さ れ ます 。'},
#  {'id': '37', 'text': 'iPhone / iPad の バックアップ 方法 を 教え て ください 。'},
#  {'id': '38',
#   'text': 'iCloud に バックアップ が ある 確認 し たい が 設定 の 中 に iCloud が あり ませ ん 。'},
#  {'id': '39', 'text': 'iCloud の バックアップ 方法 を 教え て ください 。'},
#  {'id': '40', 'text': 'iCloud の バックアップ が でき ない'},
#  {'id': '41', 'text': 'iCloud を 使用 し て バックアップ を 取得 し たい'},
#  {'id': '42', 'text': 'View 環境 で ネットワーク プリンタ の 設定 を し たい'},
#  {'id': '43', 'text': 'View 環境 で プリンタ インストール し たい'},
#  {'id': '44', 'text': 'View 環境 で の プリンター 設定 方法 を 教え て ください 。'},
#  {'id': '45', 'text': 'View で プリンター を 使い たい'},
#  {'id': '46', 'text': 'View で プリンタ 設定 時 に IP アドレス を 入力 し た が 、 エラー に なる'},
#  {'id': '47', 'text': 'View 環境 で 複数 の プリンタ を 設定 し たい'},
#  {'id': '48', 'text': 'View の プリンタ 設定 画面 を 再表示 さ せ たい'},
#  {'id': '49',
#   'text': 'View で プリンタ の 再設定 を 行っ て いる の です が 、 操作 を 誤り 「 完了 し ませ ん でし た 」 と 表示 さ れ まし た 。 \n その 後 再 ログイン を し た の です が プリンタ 設定 画面 が 出 て こ なく なり まし た 。'},
#  {'id': '50', 'text': 'View 環境 で プリンタ ドライバ を 再設定 する 方法 を 教え て ほしい'},
#  {'id': '51',
#   'text': 'View で 複合機 の IP アドレス を 入力 し 、 プリンタ の 設定 を 行っ て いる が 、 エラー に なる'},
#  {'id': '52', 'text': '暗号化 さ れ た Office ファイル の 解除 を し たい'},
#  {'id': '53', 'text': 'Office の アクセス 制限 を 解除 し たい'},
#  {'id': '54',
#   'text': 'ファイル サーバー に 保存 し て いる PowerPoint ファイル を 客先 に 送り たい 。 客先 の 端末 上 で も Office ファイル は 問題 なく 開ける でしょう か 。'},
#  {'id': '55', 'text': '暗号化 さ れ た Office ファイル を 開く こと が でき ない'},
#  {'id': '56', 'text': '暗号化 さ れ た Office ファイル の 解除 方法 を 知り たい'},
#  {'id': '57', 'text': 'Excel の 暗号化 の 解除 方法 が わから ない'},
#  {'id': '58', 'text': '社外 に Excel ファイル を 送信 する 際 に AzureRMS の 解除 を し たい'},
#  {'id': '59', 'text': 'Office ファイル の 暗号化 を 解除 し たい'},
#  {'id': '60', 'text': '社外 に Office ファイル を 送信 し たい の で 、 暗号化 解除 の 方法 を 知り たい'},
#  {'id': '61',
#   'text': 'パワーポイント の ファイル を お客様 先 に 送っ たら 客先 で 「 開け ない 」 と 言わ れ た 。 この 場合 どう すれ ば いい です か 。'},
#  {'id': '62', 'text': 'EUC に つい て 問合せ たい'},
#  {'id': '63', 'text': 'EUC に つい て 確認 し たい'},
#  {'id': '64', 'text': 'EUC の 問合せ先 は どこ です か ？'},
#  {'id': '65', 'text': 'EUC の 管理 部署 を 教え て 欲しい'},
#  {'id': '66', 'text': '部署 で 購入 し た 端末 を OA 環境 に 接続 し たい'},
#  {'id': '67', 'text': '部門 端末 を OA ネットワーク に 接続 し たい'},
#  {'id': '68', 'text': '部門 PC を OA 化 し たい'},
#  {'id': '69', 'text': '部門 導入 PC を 社内 NW に 接続 し たい'},
#  {'id': '70', 'text': '準 OAPC を 社内 ネットワーク に 接続 し たい'},
#  {'id': '71', 'text': '部門 PC を OA ネットワーク に 接続 し たい'},
#  {'id': '72', 'text': '部門 購入 端末 を OANW に 繋げ たい'},
#  {'id': '73', 'text': '部門 PC を OA 環境 に 接続 し たい'},
#  {'id': '74', 'text': '部門 PC を 社内 NW に 接続 し たい'},
#  {'id': '75', 'text': '部門 PC を 社内 ネットワーク に 接続 する 手順 が 知り たい'},
#  {'id': '76', 'text': 'PC から Gmail に アクセス でき なく なり まし た'},
#  {'id': '77', 'text': 'Chrome の キャッシュ クリア 方法 を 教え て'},
#  {'id': '78',
#   'text': 'GoogleChrome を 開い て Gmail を 見よう と し た ところ 画面 が 真っ白 で 何 も 表示 さ れ ない 。'},
#  {'id': '79', 'text': 'Google の キャッシュ クリア 方法 を 知り たい'},
#  {'id': '80', 'text': 'Google Chrome の キャッシュ を 削除 し たい'},
#  {'id': '81', 'text': 'Chrome の キャッシュ を クリア し たい'},
#  {'id': '82',
#   'text': 'GoogleChrome を 開く と 画面 が 真っ白 で お 待ち ください と 表示 さ れ て いる 。'},
#  {'id': '83',
#   'text': 'Chrome から Gmail に 接続 でき ませ ん 。 メール アドレス 入力 し 次 へ ボタン を クリック する と HTTP 500 ? ? ? ? ? と 表示 さ れ た 画面 に なり ます 。'},
#  {'id': '84',
#   'text': 'OAPC で Gmail 本文 が 読み込め ませ ん 。 Google へ の 接続 に 問題 が 発生 し て い ます と 表示 さ れ て い ます 。'},
#  {'id': '85', 'text': 'CI   Tools   ( by   CITeam ) を 使用 し たい'},
#  {'id': '86', 'text': 'エイリアス から 名前 検索 し たい'},
#  {'id': '87', 'text': 'アカウント名 から 社員名 を 調べる 方法 を 教え て'},
#  {'id': '88', 'text': 'エイリアス から メール アドレス を 確認 する 方法 を 教え て ください'},
#  {'id': '89', 'text': 'Gmail アカウント から 氏名 、 部署名 を 取得 する に は ？'},
#  {'id': '90', 'text': 'エイリアス や 氏名 から メール アドレス を 確認 する 方法 を 教え て ください'},
#  {'id': '91', 'text': 'エイリアス から 社員 の 名前 を 調べる 方法 を 教え て ほしい'},
#  {'id': '92', 'text': '自分 の OA アカウント を 確認 し たい'},
#  {'id': '93', 'text': 'CI   Tools を インストール し たい'},
#  {'id': '94', 'text': 'OA アカウント を 検索 し たい'},
#  {'id': '95', 'text': '故障 交換 を し た 業務用 携帯 電話 B の 返却 宛先 を 知り たい'},
#  {'id': '96', 'text': '業 端 B の iPad を 返却 し たい'},
#  {'id': '97',
#   'text': '派遣 社員 が 使用 する 業務 端末 B の 返却 方法 を 教え て いただい て も よろしい でしょう か ？'},
#  {'id': '98', 'text': '業務 端末 B の 交換 対応 後 の 返却 先 は どこ です が ？'},
#  {'id': '99', 'text': '業 端 B の 返却 方法 が 知り たい'},
#  {'id': '100', 'text': '業務 端末 B の 返却 に つい て'},
#  {'id': '101', 'text': '業務 端末 B の 返却 先 は どちら でしょう か'},
#  {'id': '102', 'text': '業 端 B の 返却 方法 を 教え て'},
#  {'id': '103', 'text': '業務用 携帯 電話 B の 返却 は どう し たら いい ？'},
#  {'id': '104', 'text': '業 端 B の 返却 手順 を 教え て'},
#  {'id': '105', 'text': 'W ドライブ にて ファイル が 保存 でき ない'},
#  {'id': '106', 'text': 'W ドライブ の 容量 が 不足 し て いる 。 容量 増加 する こと は 可能 です か 。'},
#  {'id': '107', 'text': 'W ドライブ の 容量 が 不足 し て き た'},
#  {'id': '108', 'text': 'W ドライブ の 容量 を 増やし たい'},
#  {'id': '109', 'text': 'View で ファイル の DL を 行う と 「 ディスク が いっぱい 」 と 表示 さ れる'},
#  {'id': '110', 'text': 'W ドライブ の 容量 増加 を し て ほしい'},
#  {'id': '111', 'text': 'W ドライブ の 容量 が 枯渇 し て いる'},
#  {'id': '112', 'text': 'W ドライブ の 容量 を 教え て'},
#  {'id': '113', 'text': 'W ドライブ の 容量 が 少ない'},
#  {'id': '114', 'text': 'W ドライブ の 容量 増加 を し たい'},
#  {'id': '115',
#   'text': 'iPhone の 連絡先 から 別 拠点 の 人 の 電話 番号 が 検索 でき なく なり まし た 。 改善 方法 を 教え て ください 。'},
#  {'id': '116', 'text': 'あんしん バックアップ アプリ 利用 方法 を 教え て 欲しい'},
#  {'id': '117',
#   'text': '機種 変更 で 連絡先 を 移行 し た が 、 残っ て しまう 連絡先 が あり ます 。 移行 方法 を 教え て ください 。'},
#  {'id': '118', 'text': 'iPhone の 連絡先 が 移行 出来 ない'},
#  {'id': '119',
#   'text': 'Android から iPhone に 機種 変更 し た が 、 同期 で 移行 でき ない 連絡先 が あり ます 。'},
#  {'id': '120', 'text': '機種 変更 の 時 に 連絡先 を 移行 する 方法 を 教え て ください 。'},
#  {'id': '121', 'text': '共有 ドライブ に 保存 し た ファイル が 削除 でき ない'},
#  {'id': '122', 'text': '共有 ドライブ 内 の データ が 消せる 人 の 権限 を 教え て 欲しい'},
#  {'id': '123', 'text': '共有 ドライブ 内 に 保存 し た ファイル を 削除 する 方法 を 教え て 欲しい'},
#  {'id': '124', 'text': '共有 ドライブ 内 で ファイル の 削除 が でき ませ ん 。 どう すれ ば よい です か ？'},
#  {'id': '125', 'text': '誤っ て ワークス ペース から 退出 し て しまい まし た'},
#  {'id': '126',
#   'text': 'ワークス ペース から サイン アウト し て しまっ た 場合 の 再 サイン イン 方法 を 教え て 欲しい'},
#  {'id': '127', 'text': '誤っ て ワークス ペース から サイン アウト し て しまい まし た'},
#  {'id': '128', 'text': 'ワークス ペース から 退出 し て しまっ た 場合 の 再 参加 方法 を 教え て 欲しい'},
#  {'id': '129', 'text': 'PDF を 圧縮 し パスワード を かけ たい'},
#  {'id': '130', 'text': 'PDF に パスワード を かける 方法 を 教え て'},
#  {'id': '131',
#   'text': 'PDF ファイル の パスワード を かける 操作 は Adobe   Reader で も 可能 です か'},
#  {'id': '132', 'text': 'PDF ファイル に パスワード を 設定 する'},
#  {'id': '133', 'text': 'PDF に パスワード を かける に は ソフト の インストール が 必要 です か 。'},
#  {'id': '134', 'text': 'PDF に パスワード を 付与 し たい'},
#  {'id': '135', 'text': 'PDF で パスワード 設定 し たい'},
#  {'id': '136', 'text': 'PDF ファイル に パスワード 設定 を おこない たい'},
#  {'id': '137', 'text': 'PDF に パスワード を つけ たい'},
#  {'id': '138', 'text': 'Acrobat   Pro   DC で PDF に PW を かけ たい'},
#  {'id': '139', 'text': 'Zoom で イヤホン から 音 が 聞こえ ませ ん'},
#  {'id': '140', 'text': 'Zoom ミーティング の 際 に イヤホン を 使う に は どう し たら いい です か ？'},
#  {'id': '141', 'text': 'イヤホン で は なく PC 本体 から 音声 が 聞こえる 場合 の 対処 方法 を 教え て'},
#  {'id': '142', 'text': 'イヤホン で Zoom ミーティング に 参加 する 方法 を 知り たい'},
#  {'id': '143', 'text': '共有 グループ の 管理者 を 知り たい'},
#  {'id': '144', 'text': '共有 グループ の 管理者 の 確認 方法 を 教え て 欲しい'},
#  {'id': '145', 'text': '共有 グループ の 管理者 を 確認 し たい'},
#  {'id': '146', 'text': '共有 グループ の ML の 管理者 を 調べ たい'},
#  {'id': '147', 'text': '共有 メール の 管理者 を 確認 し たい'},
#  {'id': '148', 'text': '共有 グループ の 管理者 の 確認 方法 に つい て'},
#  {'id': '149',
#   'text': 'G   Suite   共有 グループ メンバー 管理 で 管理者 に なっ て いる 人 の 確認 方法 を 教え て ください'},
#  {'id': '150', 'text': '管理者 共有 グループ の 管理者 名 を 確認 する に は ？'},
#  {'id': '151', 'text': '共有 グループ アドレス の 管理者 確認 方法 が 知り たい'},
#  {'id': '152', 'text': '共有 グループ の 管理者 は どこ で 確認 でき ます か ？'},
#  {'id': '153',
#   'text': '業 端 A   iPhone で VPN に 繋ごう と する と 、 「 VPN サーバー と の ネゴシエーション に 失敗 し まし た 。 」 と いう エラー が で て くる'},
#  {'id': '154',
#   'text': '「 VPN サーバー と の ネゴシエーション に 失敗 し まし た 」 と 表示 さ れ まし た 。 再設定 しか 方法 は ない でしょう か 。'},
#  {'id': '155',
#   'text': 'エラー ： 「 VPN サーバ と の ネゴシエーション に 失敗 し まし た 。 」 が 表示 さ れる'},
#  {'id': '156',
#   'text': '業 端 A   iPhone で VPN 接続 しよう と する と ネゴシエーション に 失敗 し まし た が 表示 さ れる'},
#  {'id': '157',
#   'text': '「 VPN サーバー と の ネゴシエーション に 失敗 し まし た 」 と 表示 さ れ まし た 。 対応 方法 は あり ます か 。'},
#  {'id': '158',
#   'text': '「 VPN サーバ と の ネゴシエーション に 失敗 し まし た 」 と 表示 さ れ 、 iPhone から VPN 接続 でき ない'},
#  {'id': '159', 'text': 'ゲスト 管理 システム の 管理者 G を 移管 する 方法 を 教え て'},
#  {'id': '160',
#   'text': 'ゲスト 管理 システム の 管理者 グループ の ゲスト を 別 の 管理者 グループ に 移行 する 方法 を 教え て'},
#  {'id': '161',
#   'text': 'ゲスト 管理 システム の 管理者 グループ に 紐 づく ゲスト を 別 の 管理者 グループ に 移行 し たい'},
#  {'id': '162', 'text': 'ゲスト 管理 システム の 管理者 G を 移管 する こと は 出来 ます か ？'},
#  {'id': '163',
#   'text': 'OA アカウント の パスワード を 間違え て ビット ロッカー の ロック が かかっ て しまっ た'},
#  {'id': '164', 'text': 'OAPC の Bitlocker 回復 キー を 知り たい'},
#  {'id': '165', 'text': 'BitLocker の 画面 が 出 て PC に ログイン でき ない'},
#  {'id': '166', 'text': 'Bitlocker の 回復 キー を 知り たい です'},
#  {'id': '167',
#   'text': 'OAPC が パスワード 入力 失敗 に より BitLocker の ロック が かかっ て しまい まし た 。 解除 する ため の 方法 を 教え て ください 。'},
#  {'id': '168',
#   'text': 'OAPC で PC 起動 時 に BitLocker の 回復 キー を 求め て き て おり Windows が 起動 でき ませ ん 。'},
#  {'id': '169', 'text': 'PC 起動 時 に BitLocker 回復 キー の 入力 を 求め られ ます'},
#  {'id': '170', 'text': 'OAPC 起動 時 に ビット ロッカー リカバリー と 表示 さ れ て ログイン でき ませ ん 。'},
#  {'id': '171', 'text': 'Bitlocker 回復 キー を 教え て ください'},
#  {'id': '172',
#   'text': 'PC 起動 時 に ビット ロッカー リカバリー と いう 画面 で 数字 の 入力 を 求め られ て い ます 。'},
#  {'id': '173', 'text': '業務 端末 A の iPhone で 4 G 回線 が 使用 でき ませ ん 。'},
#  {'id': '174', 'text': '業務 端末 A の iPhone で 5 G 経由 の 通信 が でき ない'},
#  {'id': '175', 'text': '業務 端末 A の iPhone で 5 G 経由 の 通信 が でき ませ ん 。'},
#  {'id': '176', 'text': '業務 端末 A の iPhone で 4 G が OFF に なっ て い ます 。'},
#  {'id': '177', 'text': '業務 端末 A の iPad で 4 G モバイル データ 通信 が でき ない'},
#  {'id': '178', 'text': 'iPhone の MDM プロファイル インストール 時 に エラー に なる'},
#  {'id': '179',
#   'text': '業 端 A   iPhone で MDM 設定 時 「 プロファイル の インストール が でき ませ ん でし た 」 と 表示 さ れ まし た 。 どこ に 問い合わせれ ば いい でしょう か 。'},
#  {'id': '180', 'text': 'iPhone の MDM プロファイル が インストール エラー に なっ て しまい ます'},
#  {'id': '181', 'text': 'iPhone の MDM プロファイル が インストール さ れ ませ ん'},
#  {'id': '182',
#   'text': '「 文書 の 取り出し が でき ませ ん でし た 」 と 表示 さ れ て スキャン データ の 取り出し が でき ない'},
#  {'id': '183', 'text': 'ゼロックス の 親展 ボックス から スキャン データ の 取り出し が でき ない'},
#  {'id': '184', 'text': 'ゼロックス の スキャナ の 取り出し が でき ない'},
#  {'id': '185', 'text': '親展 ボックス から スキャナ の 取り出し が でき ない'},
#  {'id': '186', 'text': 'ソリューション 販売 管理 システム に つい て 確認 し たい'},
#  {'id': '187', 'text': 'ソリューション 販売 管理 システム の 問合せ先 は どこ です か ？'},
#  {'id': '188', 'text': 'ソリューション 販売 管理 システム の 管理 部署 を 教え て 欲しい'},
#  {'id': '189', 'text': 'ソリューション 販売 管理 システム に つい て 問い合わせ し たい'},
#  {'id': '190', 'text': '仕入 販売 管理 に ログイン でき ない'},
#  {'id': '191', 'text': 'ソリューション 販売 管理 の パスワード を 忘れ まし た'},
#  {'id': '192', 'text': '仕入 販売 管理 システム に 入れ ませ ん 。'},
#  {'id': '193', 'text': 'ソリューション 販売 管理 システム に つい て 問合せ たい'},
#  {'id': '194', 'text': 'ソリューション 販売 管理 システム の PW を 初期化 し たい'},
#  {'id': '195', 'text': 'グループ アドレス で 不在 通知 設定 を し たい'},
#  {'id': '196', 'text': 'グループ アドレス で 不在 通知 の 設定 は 可能 です か ？'},
#  {'id': '197', 'text': 'グループ メール アドレス で 不在 通知 設定 方法 を 教え て 欲しい'},
#  {'id': '198', 'text': 'Google グループ アドレス の 不在 通知 設定 を し たい'},
#  {'id': '199', 'text': '共有 メール アドレス で 不在 通知 を 設定 する こと は でき ます か ？'},
#  {'id': '200', 'text': 'Fruits の 問合せ先 は どこ です か ？'},
#  {'id': '201', 'text': 'VoiceNet に つい て 確認 し たい'},
#  {'id': '202', 'text': 'VoiceNet の 管理 部署 を 教え て 欲しい'},
#  {'id': '203', 'text': 'VoiceNet に つい て 問合せ たい'},
#  {'id': '204', 'text': 'Fruits に つい て 確認 し たい'},
#  {'id': '205', 'text': 'Fruits の 管理 部署 を 教え て 欲しい'},
#  {'id': '206', 'text': 'VoiceNet の 問合せ先 は どこ です か ？'},
#  {'id': '207', 'text': 'Fruits に つい て 問合せ たい'},
#  {'id': '208', 'text': 'iOS 用 の アプリ 提供 を し たい が 、 提供 方法 が 分から ない'},
#  {'id': '209', 'text': '業務用 端末 に アプリ を 配信 し たい'},
#  {'id': '210', 'text': 'iOS 用 の アプリ の 提供 方法 を 相談 し たい'},
#  {'id': '211', 'text': 'iPhone に アプリ の 配信 を し たい が 、 対応 方法 が 分から ない'},
#  {'id': '212', 'text': 'Android 用 の アプリ を PlayStore で 公開 し たい'},
#  {'id': '213',
#   'text': '「 この 不明 な 発行元 から の アプリ が PC に 変更 を 加える こと を 許可 し ます か ？ 」 が 表示 さ れ て 、 設定 が 変更 でき ない'},
#  {'id': '214',
#   'text': '「 この 不明 な 発行元 から の アプリ が PC に 変更 を 加える こと を 許可 し ます か ？ 」 が 表示 さ れ 、 アプリ が インストール でき ない'},
#  {'id': '215',
#   'text': 'アプリ インストール 時 、 「 この 不明 な 発行元 から の アプリ が PC に 変更 を 加える こと を 許可 し ます か ？ 」 の メッセージ が 表示 さ れる'},
#  {'id': '216',
#   'text': '「 この 不明 な 発行元 から の アプリ が PC に 変更 を 加える こと を 許可 し ます か ？ 」 の エラー が 出 て 、 ソフト が インストール でき ない'},
#  {'id': '217', 'text': '業 端 A から 社内 無線 LAN （ yellow ） に 接続 が 出来 ない'},
#  {'id': '218', 'text': '業 端 が yellow に 繋がら ない'},
#  {'id': '219',
#   'text': 'iPhone の 設定 で MDM を インストール し まし た が 、 社内 WiFi に まだ 繋がり ませ ん 。'},
#  {'id': '220', 'text': '業務用 端末 A （ iPad ） で yellow に 接続 でき ない'},
#  {'id': '221', 'text': '業 端 A が 社内 WiFi に 繋がら ない'},
#  {'id': '222',
#   'text': '故障 交換 で 業 端 A の iPad を 交換 し セットアップ し て いる の です が 、 WiFi の yellow が つかめ ませ ん 。 yellow の プロファイル は 入っ て いる こと は 確認 済み です 。'},
#  {'id': '223', 'text': '業務 端末 A で Yellow に 繋がら ない'},
#  {'id': '224', 'text': '業務 端末 が yellow に 繋がら ない'},
#  {'id': '225', 'text': '業務 端末 A で Yellow 接続 でき ない'},
#  {'id': '226',
#   'text': '業 端 A で yellow の 接続 しよう と する と パスワード を 要求 さ れ て しまい 接続 でき ない 。'},
#  {'id': '227', 'text': 'AcrobatReaderDC の インストール が でき ない'},
#  {'id': '228', 'text': 'AdobeReader の インストール 方法 に つい て 教え て ほしい'},
#  {'id': '229', 'text': 'Adobe   Reader を インストール する 方法 が 知り たい'},
#  {'id': '230', 'text': 'AcrobatReader の インストール 方法 を 教え て ください'},
#  {'id': '231', 'text': 'PDF を 開く ため に AdobeReader を インストール し たい 。'},
#  {'id': '232', 'text': 'PDF を Adobe   Reader で 開き たい'},
#  {'id': '233', 'text': 'PDF を Adobe   Reader で 見れる よう に し たい'},
#  {'id': '234', 'text': 'Adobe   Reader の インストール 方法 が わから ない'},
#  {'id': '235',
#   'text': 'PDF を 閲覧 し たい ため 、 AdobeReader を インストール し たい 。 手順 を 教え て ほしい 。'},
#  {'id': '236', 'text': 'AdobeReader の 最新 版 を インストール し たい'},
#  {'id': '237', 'text': '付属品 の VGA 変換 アダプタ を 紛失 し て しまっ た'},
#  {'id': '238', 'text': 'VGA 変換 アダプター を 紛失 し て しまっ た 場合 は どう し たら いい です か ？'},
#  {'id': '239', 'text': 'VGA 変換 アダプタ を なくし て しまっ た'},
#  {'id': '240', 'text': 'VGA 変換 ケーブル を 無くし た 場合 どう すれ ば いい ？'},
#  {'id': '241', 'text': 'VGA 変換 アダプタ を 紛失 し た'},
#  {'id': '242',
#   'text': 'OAPC 付属 の   VGA   変換 アダプター を 紛失 し て しまっ た の で 新しい もの が 欲しい です 。'},
#  {'id': '243', 'text': 'VGA 変換 アダプタ を なくし た'},
#  {'id': '244', 'text': 'VGA 変換 アダプタ を 落とし た'},
#  {'id': '245', 'text': 'PC の VGA 変換 アダプタ を 紛失 し て しまい まし た'},
#  {'id': '246', 'text': 'VGA 変換 アダプタ を 紛失 さ れ た'},
#  {'id': '247', 'text': 'OAPC の 利用者 を 変更 し たい'},
#  {'id': '248', 'text': '退職者 の OAPC を 新規 入場者 に 引き継ぎ たい'},
#  {'id': '249', 'text': 'L 3 Dev の PC の 所有者 を 変更 し たい'},
#  {'id': '250', 'text': '複数 名分 の OAPC の 利用者 変更 申請 を 一括 で 実施 し たい'},
#  {'id': '251',
#   'text': 'OAPC の 利用者 変更 申請 承認 後 、 いつ から 社内 ネットワーク に 接続 できる よう に なり ます か'},
#  {'id': '252', 'text': 'OAPC の 利用者 変更 申請 の 申請 方法 を 教え て ほしい'},
#  {'id': '253', 'text': '退場者 の OAPC の 利用者 変更 を し たい'},
#  {'id': '254', 'text': 'OAMac の 利用者 変更 を し たい'},
#  {'id': '255',
#   'text': '部門 管理 PC で 外部 記録 媒体 を 使用 し たい の です が 申請 は 必要 に なり ます か 。'},
#  {'id': '256',
#   'text': 'OA 化 し て い ない 部門 PC で USB メモリ を 利用 する 場合 、 USB 権限 申請 は 必要 です か ？'},
#  {'id': '257', 'text': '部門 で スタンドアローン で 使っ て いる 端末 で USB を 使い たい'},
#  {'id': '258', 'text': '部門 で 管理 し て いる 端末 で 外部 記録 媒体 を 使用 し たい'},
#  {'id': '259',
#   'text': '部門 PC で ネットワーク が Yellow の PC に 対し て 外付け の DVD デッキ を 接続 し たい 。 PureTerminal から の 申請 は 必要 でしょう か'},
#  {'id': '260',
#   'text': 'L 3 DaaS 環境 から L 2 RDS 環境 に ログイン し た 際 、 アプリ が 表示 さ れ ない 。'},
#  {'id': '261', 'text': 'RDS に ログイン し た が 、 アイコン が 何 も ない'},
#  {'id': '262', 'text': 'RDS に ログイン は できる が 、 アイコン 自体 が 表示 さ れ て い ない'},
#  {'id': '263', 'text': 'RDS に は ログイン できる が アイコン が 存在 し ない'},
#  {'id': '264', 'text': 'RDS ログイン 後 、 アイコン が 何 も 表示 さ れ ない'},
#  {'id': '265', 'text': 'RDS ログイン 後 、 アイコン が 表示 さ れ ない 場合 の 対処 方法'},
#  {'id': '266',
#   'text': 'L 3 環境 で 先週 配信 さ れ た 新 RDS アイコン から ログイン する と remoteApp 以下 に 何 も アイコン が 表示 さ れ て い ない'},
#  {'id': '267', 'text': 'RDS で アイコン が 出 て 来 ない'},
#  {'id': '268', 'text': 'RDS の アイコン が 出 ない'},
#  {'id': '269',
#   'text': 'Excel を 起動 する と 「 サブスクリプション の 有効 期限 が 切れ て い ます 。 」 と 表示 さ れる'},
#  {'id': '270',
#   'text': 'パワーポイント ファイル を 開い た とき に 「 サブスクリプション の 有効 期限 が 切れ て いる と エラー に なる'},
#  {'id': '271',
#   'text': 'Office を 立ち上げる と サブスクリプション の 有効 期限 が 切れ て い ます と 表示 さ れる'},
#  {'id': '272', 'text': 'サブスクリプション の エラー が 出 て Office が 使え ない'},
#  {'id': '273', 'text': 'Office 365 サブスクリプション は 有効 期限 が 切れ て い ます'},
#  {'id': '274', 'text': 'エクセル を 開く と サブスクリプション の 有効 期限 が 切れ て い ます と 出 ます 。'},
#  {'id': '275',
#   'text': 'Office 起動 時 に サブスクリプション の 有効 期限 が 切れ て い ます と いう メッセージ が 出 て しまう'},
#  {'id': '276',
#   'text': 'Office ファイル を 起動 する と 「 サブスクリプション の 有効 切れ 」 と 表示 さ れる 。'},
#  {'id': '277', 'text': 'Office で サブスクリプション の 有効 期限 が 切れ て い ます が 表示 さ れる'},
#  {'id': '278', 'text': 'Office の サブスクリプション の 有効 期限 が 切れ て い ます'},
#  {'id': '279',
#   'text': '業務 端末 B で 設定 し た MySoftBank の 暗証 番号 の 問い合わせ先 を 教え て 欲しい 。'},
#  {'id': '280', 'text': '業務 端末 B で 設定 し た MySoftBank の 暗証 番号 を 忘れ て しまっ た 。'},
#  {'id': '281', 'text': '業務 端末 B の MySoftBank の 暗証 番号 を 確認 し たい 。'},
#  {'id': '282', 'text': '業務 端末 B の MySoftbank へ の ログイン 方法 を 教え て ください 。'},
#  {'id': '283', 'text': '業 端 B の MySoftBank の 暗証 番号 を 確認 し たい 。'},
#  {'id': '284', 'text': '業 端 B の MySoftbank の パスワード を 教え て ください 。'},
#  {'id': '285', 'text': '準 OAPC を 借り たい'},
#  {'id': '286', 'text': '準 OAPC の 貸出 申請 に つい て'},
#  {'id': '287', 'text': '準 OAPC は どこ で 借りる こと が でき ます か ？'},
#  {'id': '288', 'text': '準 OA 端末 が 欲しい'},
#  {'id': '289', 'text': '準 OAPC を 貸し出し て ほしい'},
#  {'id': '290',
#   'text': 'PC を 交換 し た が ログイン でき ない 。 現在 ログオン 要求 を 処理 できる ログオン サーバー は あり ませ ん と 表示 さ れる'},
#  {'id': '291',
#   'text': 'OAPC に ログイン でき ない 。 「 ログイン 要求 を 処理 できる ログオン サーバー は あり ませ ん 。 」'},
#  {'id': '292',
#   'text': 'OAPC に ログイン でき ませ ん 。 現在 ログオン 要求 を 処理 できる ログオン サーバー は あり ませ ん と 表示 さ れ ます'},
#  {'id': '293',
#   'text': 'OAPC に ログイン でき ませ ん 。 「 現在 ログオン 要求 を 処理 できる ログオン サーバー が あり ませ ん 」 と 表示 さ れ ます'},
#  {'id': '294',
#   'text': 'PC を 起動 し て ログオン しよう と し て い ます が \n 「 現在 ログオン 要求 を 処理 できる ログオン サーバー が あり ませ ん 」 \n と エラー に なり ます'},
#  {'id': '295',
#   'text': '現在 ログオン 要求 を 処理 できる ログオン サーバー は あり ませ ん と いう エラー が で て OAPC に ログイン でき なく なっ た 。 解消 方法 を 教え て ほしい 。'},
#  {'id': '296',
#   'text': 'OAPC に ログイン でき ませ ん 。 エラー ： 現在 ログオン 要求 を 処理 できる ログオン サーバー は あり ませ ん 。'},
#  {'id': '297',
#   'text': 'OAPC に ログイン でき ませ ん 。 現在 ログオン 要求 を 処理 できる ログオン サーバー が あり ませ ん と 表示 さ れ ます'},
#  {'id': '298',
#   'text': '現在 、 ログオン 要求 を 処理 できる サーバー は あり ませ ん 。 と いう エラー の 対処 方法 を 教え て'},
#  {'id': '299', 'text': '「 ログオン 要求 を 処理 できる ログオン サーバー は あり ませ ん 」 と 表示 さ れ ます'},
#  {'id': '300',
#   'text': '複数社 で 利用 し て いる Slack コネクト の チャンネル から 特定 の 会社 のみ 切り離し たい'},
#  {'id': '301',
#   'text': '複数社 間 で やり取り し て いる 共有 チャンネル から 特定 の 会社 のみ 切り離す こと は 出来 ます か ？'},
#  {'id': '302',
#   'text': '3 社 で 利用 し て いる 共有 チャンネル から 1 社 のみ コネクト を 切り離し たい 場合 は どう し たら 良い です か ？'},
#  {'id': '303',
#   'text': '3 社 で Slack コネクト し て いる 場合 、 特定 の 1 社 のみ コネクト 停止 する こと は 出来 ます か ？'},
#  {'id': '304', 'text': 'Excel は 動作 を 停止 し まし た と 出る'},
#  {'id': '305', 'text': 'Office の 修復 方法 に つい て 手順 を 教え て ほしい'},
#  {'id': '306', 'text': 'Excel の アプリ のみ 起動 し ない'},
#  {'id': '307',
#   'text': '問題 が 発生 し 、 PowerPoint の 動作 が 不安定 に なっ て い ます 。 と 表示 さ れ て PowerPoint ファイル が 開き ませ ん 。'},
#  {'id': '308', 'text': 'PowerPoint の アプリ のみ 起動 し ない'},
#  {'id': '309', 'text': 'Excel を 開く と フリーズ する'},
#  {'id': '310',
#   'text': 'PowerPoint を 開く と 、 以下 の ポップ アップ が 表示 さ れ 続け ます 。 「 申し訳 ござい ませ ん 。 問題 が 発生 し 、 PowerPoint の 動作 が 不安定 に なっ て い ます 。 PowerPoint を 再起動 し て ください 」 再起動 し て も なおり ませ ん 。'},
#  {'id': '311', 'text': 'Office を アップデート 後 に ファイル が 開か なく なっ た'},
#  {'id': '312', 'text': 'Word の アプリ のみ 起動 し ない'},
#  {'id': '313',
#   'text': 'PowerPoint ファイル のみ 正常 動作 し ませ ん 。 申し訳 ござい ませ ん 。 問題 が 発生 し 、 PowerPoint の 動作 が 不安定 に なっ て い ます 。 と 表示 さ れ て 編集 でき ませ ん 。'},
#  {'id': '314', 'text': '正社員 以外 の Windows で の Office 利用 方法 を 教え て ほしい'},
#  {'id': '315', 'text': '業務 委託 社員 の Office 利用 に つい て'},
#  {'id': '316', 'text': '業務 委託 社員 で Office を 使用 し たい'},
#  {'id': '317', 'text': 'Office 365 の 利用 は 正社員 以外 で も 可能 です か ？'},
#  {'id': '318', 'text': '派遣 社員 が Office を 使用 する 場合 は どう し たら いい か'},
#  {'id': '319', 'text': 'Office に 利用 ルール は あり ます か ？'},
#  {'id': '320', 'text': '業務 委託 社員 に Office 365 を 利用 さ せ たい'},
#  {'id': '321', 'text': '正社員 以外 の 人 が Office を 利用 する 方法 を 教え て ほしい'},
#  {'id': '322', 'text': '派遣 社員 の Office 365 の 利用 マニュアル を 教え て ください'},
#  {'id': '323', 'text': '正社員 以外 の 社員 に Office 365 を 利用 さ せ たい'},
#  {'id': '324', 'text': '退職 し た 人 が 共有 ドライブ に 保存 し て い た データ は どう なり ます か ？'},
#  {'id': '325',
#   'text': '辞め た 人 が 共有 ドライブ 内 に データ を 保存 し て い た 場合 の 扱い は どう なり ます か ？'},
#  {'id': '326', 'text': '退職 さ れ た 際 共有 ドライブ 内 の ファイル は どう なり ます か'},
#  {'id': '327',
#   'text': '共有 ドライブ 内 に 辞め た 人 の 作成 し た データ が ある 場合 、 消え て しまい ます か ？'},
#  {'id': '328', 'text': '退職時 、 共有 ドライブ 内 の ファイル は どう なり ます か ？'},
#  {'id': '329', 'text': 'FALCON で 共有 フォルダ の 利用率 を 確認 する こと は 可能 です か ？'},
#  {'id': '330', 'text': '共有 フォルダ の 利用率 を 確認 し たい'},
#  {'id': '331', 'text': 'プロジェクト フォルダ の 利用率 を 確認 し たい'},
#  {'id': '332', 'text': '共有 フォルダ の 利用率 を 確認 する 方法 は あり ます か ？'},
#  {'id': '333', 'text': '業 端 A から シングル サイン オン （ SSO ） でき ない'},
#  {'id': '334', 'text': 'OAMac から SSO 認証 が でき ない'},
#  {'id': '335', 'text': 'Android から SSO 認証 が 通ら ない'},
#  {'id': '336', 'text': 'iPhone から SSO 認証 でき ない'},
#  {'id': '337', 'text': 'iPhone で SSO 認証 が でき ない'},
#  {'id': '338', 'text': 'OAMac で 社内 NW に 接続 し て いる が SSO 認証 でき ない'},
#  {'id': '339', 'text': '開発 DaaS を 複数 の モニター に 表示 でき ます か ？'},
#  {'id': '340', 'text': '開発 DaaS の 画面 を ２ つ の ディスプレイ に 表示 し たい'},
#  {'id': '341', 'text': '開発 DaaS の 画面 を ２ つ の モニター に 表示 し たい'},
#  {'id': '342', 'text': '開発 DaaS 利用 時 の マルチ ディスプレイ 表示 方法 を 教え て 欲しい'},
#  {'id': '343', 'text': '受入 出向 社員 も Zoom アカウント が 発行 さ れ ます か ？'},
#  {'id': '344', 'text': 'Zoom アカウント 自動 払出 対象者 を 教え て'},
#  {'id': '345', 'text': 'SBKK 兼務 の 場合 、 Zoom アカウント は 発行 さ れ ます か ？'},
#  {'id': '346', 'text': 'Zoom の アカウント は 誰 に 発行 さ れ ます か ？'},
#  {'id': '347', 'text': 'OA 化 可能 な Mac   OS の バージョン を 教え て 欲しい'},
#  {'id': '348', 'text': '部門 購入 し た Mac を OA 化 し たい が OS が 対象外 と 表示 さ れ た 。'},
#  {'id': '349', 'text': '最新 OS の Mac は いつ から OA 化 でき ます か ？'},
#  {'id': '350', 'text': '最新 の Mac   OS の OA 化 は いつ に なり そう でしょう か ？'},
#  {'id': '351', 'text': '最新 の Mac   OS は いつ 準 OA 化 対応 さ れ ます か'},
#  {'id': '352', 'text': '最新 OS の Mac を OA 化 し たい'},
#  {'id': '353', 'text': 'MacOS を アップグレード し て も OA 化 可能 です か'},
#  {'id': '354', 'text': 'MacOS が 新し すぎ て OA 化 でき ない'},
#  {'id': '355', 'text': '購入 し た Mac の 最新 OS は いつ OA 化 でき ます か ？'},
#  {'id': '356', 'text': '新 バージョン の Mac   OS は OA 化 可能 です か'},
#  {'id': '357',
#   'text': 'PowerPoint ファイル を Gmail に 添付 し て 送信 する と ウィルス に 感染 し まし た と メッセージ が 出る'},
#  {'id': '358',
#   'text': 'この メール に は ご 注意 ください 。 ウィルス や 悪質 な リンク が 含ま れ て いる 可能性 が あり ます 。'},
#  {'id': '359',
#   'text': 'Gmail 上 で 「 ウィルス の 警告   –   XX 個 の 添付 ファイル に ウィルス また は ブロック さ れ た ファイル が 含ま れ て い ます 」 の メッセージ が 出る'},
#  {'id': '360', 'text': 'Gmail 上 で の ウィルス 対応 方法 に つい て'},
#  {'id': '361',
#   'text': 'Gmail 上 で 「 この メール に は ご 注意 ください \u3000 ウィルス や 悪質 な リンク が 含ま れ て いる 可能性 が あり ます 」 の メッセージ が 出る'},
#  {'id': '362', 'text': 'Admin 権限 が 非 承認 に なっ た 理由 を 教え て 欲しい'},
#  {'id': '363', 'text': 'Admin 権限 が 非 承認 に なっ た の で 、 理由 を 知り たい'},
#  {'id': '364', 'text': 'Admin 権限 が 否認 さ れ た'},
#  {'id': '365',
#   'text': 'AdobeAcrobat の インストール 申請 を 出し た ところ View 環境 の 為 承認 さ れ ませ ん でし た 。'},
#  {'id': '366', 'text': 'ライセンス 管理 システム で Admin 権限 申請 を 行っ た が 否認 さ れ た'},
#  {'id': '367', 'text': 'OAPC の マイク が 使え ない'},
#  {'id': '368', 'text': 'OAPC で マイク 付き イヤホン が 使え ない'},
#  {'id': '369', 'text': 'OAPC の スピーカー が 使用 でき ない'},
#  {'id': '370',
#   'text': 'OAPC の 音量 を 上げ て も スピーカー で 音声 が 聞こえ ませ ん 。 どこ で 設定 すれ ば いい でしょう か 。'},
#  {'id': '371', 'text': 'OAPC の 音声 が 出 ませ ん'},
#  {'id': '372', 'text': 'OAPC で 音 が 再生 さ れ ない'},
#  {'id': '373', 'text': 'OAPC から 音 が 出 なく なり まし た 。'},
#  {'id': '374', 'text': 'OAPC で マイク が 使え ない'},
#  {'id': '375',
#   'text': 'L 2 使用 の PC で e-learning を 受講 しよう と し たら 、 PC から 音 が 出 て こ ない 。'},
#  {'id': '376', 'text': 'RDS の 利用 申請 を 一括 登録 できる か'},
#  {'id': '377', 'text': 'RDS の 新規 利用 方法 を 確認 し たい'},
#  {'id': '378', 'text': 'RDS 環境 の 利用 申請 を し たい'},
#  {'id': '379', 'text': 'RDS の 申請 方法 を 教え て 欲しい'},
#  {'id': '380', 'text': 'RDS の 利用 申請 認証 さ れる まで どれ くらい かかる か'},
#  {'id': '381', 'text': 'RDS の 一括 申請 方法 を 教え て 下さい 。'},
#  {'id': '382', 'text': 'RDS の 申請 に つい て 教え て'},
#  {'id': '383', 'text': 'RDS を 申請 から 利用 開始 まで どの くらい かかる か'},
#  {'id': '384', 'text': 'RDS を 申請後 使える の は いつ か ？'},
#  {'id': '385', 'text': 'RDS の 申請 方法 を 教え て'},
#  {'id': '386', 'text': 'Mac から の View 接続 する 方法 を 教え て ください'},
#  {'id': '387', 'text': '自宅 から View （ 仮想 ） 環境 へ の 接続 方法 を 教え て ください'},
#  {'id': '388', 'text': '自宅 から View に 入る 手順 を 教え て ください 。 申請 は いる の でしょう か'},
#  {'id': '389', 'text': 'OAPC を 社外 に 持ち出し て View 接続 する 方法 を 教え て ください'},
#  {'id': '390',
#   'text': '自宅 で PC を 利用 し て い ます 。 \n テザリング 接続 し て View に 入り たい が うまく 入れ ない 。'},
#  {'id': '391', 'text': '個人 使用 の PC で View に 接続 し たい'},
#  {'id': '392', 'text': '社外 で View 環境 に 入る に は どう すれ ば いい の か'},
#  {'id': '393', 'text': '社外 から Veiw 接続 を 使用 する に は どう すれ ば よい でしょう か'},
#  {'id': '394', 'text': '自宅 から View 接続 する 方法 を 教え て ほしい'},
#  {'id': '395',
#   'text': 'AzureRMS の アップグレード 作業 を し たい が 支援 ツール 格納先 の フォルダ に 入れ ない 。'},
#  {'id': '396',
#   'text': 'AzureRMS の アップグレード 作業 が 出来 ない 。 \n 作業 支援 チェック ツール の 入っ て いる フォルダ が 開け ない 。'},
#  {'id': '397', 'text': 'AzureRMSCheck . vbs が ある 場所 を 教え て 欲しい'},
#  {'id': '398', 'text': 'AzureRMS の チェック ツール は どこ に あり ます か ？'},
#  {'id': '399', 'text': 'AzureRMS の チェック ツール が ある 場所 を 教え て 欲しい'},
#  {'id': '400', 'text': 'RMS の バージョン アップ の 方法 を 教え て ください 。'},
#  {'id': '401', 'text': '採用 ドクター に つい て 確認 し たい'},
#  {'id': '402', 'text': '採用 Dr の 問合せ先 は どこ です か ？'},
#  {'id': '403', 'text': '採用 Dr の 管理 部署 を 教え て 欲しい'},
#  {'id': '404', 'text': '採用 ドクター に つい て 問合せ たい'},
#  {'id': '405', 'text': '採用 ドクター の 管理 部署 を 教え て 欲しい'},
#  {'id': '406', 'text': '採用 Dr に つい て 問合せ たい'},
#  {'id': '407', 'text': '採用 ドクター の 問合せ先 は どこ です か ？'},
#  {'id': '408', 'text': 'OAPC 利用 中 に 「 メモリ エラー 」 が 表示 さ れる の を 解消 し たい'},
#  {'id': '409',
#   'text': 'OAPC 利用 中 、 GoogleChrome に 「 メモリ エラー 」 が 表示 さ れ た 場合 の 対処 方法 を 教え て 欲しい'},
#  {'id': '410',
#   'text': 'OAPC 利用 中 に 「 メモリ エラー 」 が 表示 さ れ た 場合 の 対処 方法 を 教え て 欲しい'},
#  {'id': '411', 'text': 'View 利用 中 に 「 メモリ エラー 」 が 表示 さ れる'},
#  {'id': '412', 'text': 'View 利用 中 に 「 メモリ エラー 」 が 表示 さ れる の を 解決 し たい'},
#  {'id': '413', 'text': 'OAPC の 電源 が 勝手に 落ちる 事象 が 繰り返し 発生 する'},
#  {'id': '414',
#   'text': 'OAPC で 頻繁 に ブルー スクリーン 画面 が 発生 し て おり 、 バッテリー も 持た なく なっ て いる ため 交換 を 希望 し て い ます'},
#  {'id': '415', 'text': 'OAPC が 使用 中 に ブルー スクリーン に なる 。'},
#  {'id': '416', 'text': 'OAPC で 動作 不良 （ ブルー スクリーン ） が 多発 し て いる 。'},
#  {'id': '417', 'text': 'OAPC が ブルー スクリーン を 多発 する'},
#  {'id': '418',
#   'text': 'OAPC を 少し 移動 する と フリーズ する 事象 や ブルー スクリーン が 頻発 する 状態 です 。'},
#  {'id': '419', 'text': 'PC の フリーズ が 頻発 する の です が 、 どう し たら よい です か ？'},
#  {'id': '420', 'text': 'ブルー スクリーン が 出現 し QR コード が 画面 に 出る'},
#  {'id': '421',
#   'text': 'PC の 電源 が 突然 落ちる こと が 増え て き て おり 、 業務 の 支障 が 出 て い ます 。 対応策 を 相談 し たい 。'},
#  {'id': '422', 'text': 'PC が ブラック アウト し ます'},
#  {'id': '423', 'text': 'ネットワーク 管理 GIS に ログイン でき ない 状態 です 。 確認 を お 願い し ます 。'},
#  {'id': '424', 'text': 'PFOS - GIS を 使い たい'},
#  {'id': '425', 'text': 'ネットワーク 管理 GIS の 問合せ先 は どこ です か ？'},
#  {'id': '426', 'text': 'ネットワーク 管理 GIS に つい て 問合せ し たい'},
#  {'id': '427', 'text': 'ネットワーク 管理 GIS の 問合せ先 を 教え て 欲しい'},
#  {'id': '428', 'text': '業務 端末 の 回線 速度 が 遅い 。'},
#  {'id': '429',
#   'text': '業務 端末 A で データ 通信 の 速度 が 低下 し まし た 。 容量 は 追加 購入 でき ます か 。'},
#  {'id': '430', 'text': '業務 端末 A の 使用 可能 通信 量 確認 方法 を 知り たい 。'},
#  {'id': '431',
#   'text': '業務 端末 B で 通信 が 遅く なり まし た 。 元 の 速度 に する に は どう すれ ば いい でしょう か 。'},
#  {'id': '432', 'text': '業務用 端末 の データ 制限 に つい て 知り たい'},
#  {'id': '433', 'text': '業務 端末 B で 速度 制限 が かかっ た 時 の 対処 方法 を 教え て ください 。'},
#  {'id': '434', 'text': 'データ 通信 の 速度 で 速度 が 低下 し まし た 。 容量 の 追加 は でき ます か 。'},
#  {'id': '435',
#   'text': '業務 端末 B の データ 通信 で 速度 制限 が かかっ た 。 どこ に 問い合わせれ ば いい でしょう か 。'},
#  {'id': '436',
#   'text': 'データ 通信 の 速度 が 低下 し まし た 。 業務 端末 A で 容量 は 追加 購入 でき ます か 。'},
#  {'id': '437', 'text': '業務 端末 の 回線 速度 が 遅い です 。'},
#  {'id': '438', 'text': 'プロジェクト フォルダ 管理者 を 追加 時 、 管理者 追加 ボタン が 表示 さ れ ない'},
#  {'id': '439', 'text': 'プロジェクト フォルダ 管理者 を 追加 し たい が 、 管理者 追加 ボタン が 表示 さ れ ない'},
#  {'id': '440',
#   'text': 'FALCON で PJ フォルダ の 管理者 を 追加 し たい が 、 追加 ボタン が 表示 さ れ ない'},
#  {'id': '441', 'text': 'ファルコン で 管理者 の 追加 が でき ない'},
#  {'id': '442',
#   'text': 'プロジェクト フォルダ 管理者 を 3 名 以上 追加 し たい が 、 管理者 追加 ボタン が 表示 さ れ ない'},
#  {'id': '443', 'text': '共有 フォルダ 内 の Office ファイル が 読み取り 専用 に なっ て いる'},
#  {'id': '444', 'text': '共有 フォルダ 上 の ファイル が 読み取り 専用 に なる'},
#  {'id': '445', 'text': 'フォルダ の 読み取り 専用 が 解除 でき ない'},
#  {'id': '446', 'text': '共有 フォルダ 内 の PowerPoint の ファイル が 読み取り 専用 に なっ て いる'},
#  {'id': '447', 'text': '共有 フォルダ 上 の ファイル が 読み取り 専用 に なっ て しまい 、 編集 でき ない'},
#  {'id': '448', 'text': '共有 フォルダ 内 の Excel ファイル が 読み取り 専用 に なっ て いる'},
#  {'id': '449',
#   'text': '販売職 用 の OAPC の 起動 パスワード 変更 後 パスワード が 不明 に なり OAPC が 起動 でき なく なり まし た 。'},
#  {'id': '450', 'text': 'SP の PC を 新規 で 貸し出し て 欲しい'},
#  {'id': '451',
#   'text': 'SV 代行 に なっ た の です が パソコン を 貸与 さ れ て い ない 。 \n パソコン の 貸与 は 自分 で 申し込み を する の でしょう か 。'},
#  {'id': '452', 'text': '販売職 社員 の PC を 新規 で 貸し出し て 欲しい'},
#  {'id': '453', 'text': 'SV に なり PC 変更 に なっ た の です が 、 起動 に 5 分 程度 かかり ます 。'},
#  {'id': '454',
#   'text': '以前 パソコン の 不調 に つい て 、 クルー 相談 窓口 専用 フォーム から 問い合わせ を 投げ た ところ こちら の 窓口 に 問合せ する よう に 言わ れ まし た 。'},
#  {'id': '455', 'text': '販売職 用 の OAPC が 立ち上がら なく なっ た'},
#  {'id': '456', 'text': '販売職 用 の OAPC が 正常 起動 し ない'},
#  {'id': '457', 'text': 'SV の PC を 新規 で 貸し出し て 欲しい'},
#  {'id': '458',
#   'text': 'iPad の 業務用 端末 を 使っ て Gmail を 使っ て い ます が \n iPad に 最初 から 入っ て いる メール アプリ で 先週 日曜 以降 新しい メール が 受信 でき ない \n 「 受信 に 失敗 し まし た 。 」'},
#  {'id': '459', 'text': 'インストール 申請 を し た が 、 インストーラ の パス が わから ない'},
#  {'id': '460', 'text': 'インストール 申請 を し た が 、 インストーラ を 所持 し て い ない'},
#  {'id': '461',
#   'text': '部門 PC の インストール 申請 を 行い たい が 、 検索 し た PC 名 が 表示 さ れ ませ ん'},
#  {'id': '462', 'text': 'インストール 申請 を し た が 、 インストーラ が どこ に ある か わから ない'},
#  {'id': '463',
#   'text': 'インストール の 申請 が 承認 さ れ た が 、   インストーラ の 入手先 が 不明 な の で 教え て ほしい'},
#  {'id': '464',
#   'text': 'インストール の 申請 が 承認 さ れ た が 、   インストーラ は どこ から 入手 でき ます か'},
#  {'id': '465', 'text': 'インストール 申請 を 行っ た が 、 インストーラパス が 分かり ませ ん 。'},
#  {'id': '466',
#   'text': 'インストール 申請 を 行い Admin 権限 が 付与 さ れ まし た が \n 実際 の アプリ の インストーラー は どこ に ある の でしょう か'},
#  {'id': '467', 'text': 'インストール の 申請 が 承認 さ れ た が 、   その 先 の 手順 を 教え て ほしい 。'},
#  {'id': '468',
#   'text': 'Excel ファイル が 開か ない 。 エラー   「 Microsoft   Online   Services   サイン イン   アシスタント は この \n コンピュータ に インストール さ れ て い ませ ん 。 インスール し て から ～ 。 」'},
#  {'id': '469',
#   'text': 'AzureRMS アップグレード 後 ファイル を ひらこう と する と エラー が 出 て 、 マイクロソフトサインインアシスタント は インストール さ れ て い ませ ん 。'},
#  {'id': '470',
#   'text': 'エラー が 出 て Excel が 開け ませ ん 。 「 サイン イン   アシスタント は この コンピュータ に インストール さ れ て い ませ ん 」'},
#  {'id': '471',
#   'text': '「 Microsoft   Online   Services   サイン イン   アシスタント は この コンピュータ に インストール さ れ て い ませ ん 。 管理者 に 問い合わせ て ください 。 」 の ポップ アップ が 表示 さ れ て 、 Office ファイル が 開か ない'},
#  {'id': '472',
#   'text': '「 Microsoft   Online   Services   サイン イン   アシスタント は この \n コンピュータ に インストール さ れ て い ませ ん 。 管理者 に 問い合わせ て ください 。 」 \n の ポップ アップ が 表示 さ れ て 、 Office ファイル が 開か ない'},
#  {'id': '473',
#   'text': 'Excel ファイル を 開く と 、 \n 「 Microsoft   Online   Services   サイン イン   アシスタント は この \n コンピュータ に インストール さ れ て い ませ ん 。 管理者 に 問い合わせ て ください 。 」 \n の ポップ アップ が 表示 さ れ て 、 Office ファイル が 開か ない'},
#  {'id': '474',
#   'text': '準 OAPC にて Office ソフト を 開く 際 に 「 Microsoft   Online   Services サイン イン アシスタント は この コンピュータ に インストール さ れ て い ませ ん 。 」 と 出 て 開け ませ ん 。'},
#  {'id': '475',
#   'text': 'パワー ポイント を 開こう と し たら エラー に なる 。 「 サイン イン アシスタント は この コンピュータ に インストール さ れ て い ませ ん 」'},
#  {'id': '476',
#   'text': 'サイン イン   アシスタント は この コンピュータ に インストール さ れ て い ませ ん の メッセージ で Office ファイル が 開か ない'},
#  {'id': '477',
#   'text': 'Office ファイル を 開け ませ ん 。 \n エラー メッセージ : サイン イン アシスタント は この コンピュータ に インストール さ れ て い ませ ん'},
#  {'id': '478', 'text': '準 OAPC で Blue 接続 中 な の です が インターネット に つながり ませ ん 。'},
#  {'id': '479', 'text': 'OAPC で blue 接続 でき て いる が メール や 社内 システム が 使用 でき ない'},
#  {'id': '480', 'text': 'OAPC が インターネット に 繋がら ない'},
#  {'id': '481', 'text': 'OAPC で OASYS 接続 中 だ が インターネット に アクセス でき ない'},
#  {'id': '482', 'text': 'OAPC が インターネット に つながら ない'},
#  {'id': '483', 'text': 'OAPC で 社内 LAN 接続 し て も インターネット が 利用 でき ませ ん でし た 。'},
#  {'id': '484', 'text': 'OAPC が blue に は 接続 できる が 、 インターネット が でき ない'},
#  {'id': '485', 'text': 'OAPC が インターネット に 接続 でき ませ ん 。'},
#  {'id': '486', 'text': 'OAPC で blue 接続 でき て いる が インターネット に 接続 でき ない'},
#  {'id': '487', 'text': '社内 システム に つながる が 、 インターネット に つながら ない'},
#  {'id': '488', 'text': 'OASYS 接続 中 な の です が Gmail に 接続 でき ませ ん 。'},
#  {'id': '489', 'text': 'OAPC が 外部 Web サイト や Gmail に 接続 でき ない'},
#  {'id': '490', 'text': 'OAPC で インターネット に 接続 さ れ て い ませ ん と 表示 さ れる'},
#  {'id': '491', 'text': 'OAPC で blue に 接続 は 出来 て いる が インターネット に つながら ない'},
#  {'id': '492', 'text': 'OAPC が インターネット に 接続 でき ない'},
#  {'id': '493',
#   'text': 'OAPC で 社外 ネットワーク 接続 し て いる の です が インターネット 接続 が でき ませ ん'},
#  {'id': '494',
#   'text': '準 OAPC で 社内 NW に 接続 し て いる の です が インターネット 接続 が でき ませ ん 。'},
#  {'id': '495', 'text': 'OAPC から インターネット が 利用 でき ない の で 対処 方法 を 教え て ほしい'},
#  {'id': '496',
#   'text': '業務 端末 B で 充電 が でき ませ ん 。 ケーブル が 原因 だ と 思う の です が 、 交換 可能 でしょう か 。'},
#  {'id': '497', 'text': '業務 端末 が 充電 でき ない 。'},
#  {'id': '498', 'text': '業務 端末 B の iPhone が 充電 でき ない'},
#  {'id': '499', 'text': '業務 端末 B が 充電 でき なく なっ た 場合 、 どこ に 確認 すれ ば 良い です か 。'},
#  {'id': '500', 'text': '業務 端末 B で 充電 が でき ませ ん 。 部門 で 交換 でき ます か 。'},
#  {'id': '501', 'text': '業務 端末 B が 充電 でき なく なり まし た 。'},
#  {'id': '502', 'text': 'BB ドメイン アカウント で Proself に ログイン でき ます か ？'},
#  {'id': '503', 'text': 'Proself を 利用 できる 対象 を 教え て 欲しい'},
#  {'id': '504', 'text': 'Proself 上 の ファイル 保存 期間 は どの くらい です か ?'},
#  {'id': '505',
#   'text': 'Proself で L 3 Dev アカウント の パスワード を 変更 する 方法 を 教え て 欲しい'},
#  {'id': '506', 'text': 'L 3 Dev の ファイル サーバー に 接続 でき ない'},
#  {'id': '507', 'text': 'L 3 Dev の チャット システム に つながら ない'},
#  {'id': '508',
#   'text': 'L 3 Dev アカウント が 発行 さ れ まし た が 、 すぐ に Proself は 利用 でき ます か ？'},
#  {'id': '509', 'text': 'Proself の アカウント 申請 方法 を 教え て 欲しい'},
#  {'id': '510', 'text': 'L 3 Dev の Proself に 接続 でき ない'},
#  {'id': '511', 'text': 'Proself で アップロード できる ファイル の 上限 は あり ます か ？'},
#  {'id': '512', 'text': 'TOMAS の 問合せ先 は どこ です か ？'},
#  {'id': '513', 'text': 'CrBS の 問合せ先 は どこ です か ？'},
#  {'id': '514', 'text': 'TAS - S   L 2 に つい て 確認 し たい'},
#  {'id': '515', 'text': 'BS - DR の 問合せ先 は どこ です か ？'},
#  {'id': '516', 'text': 'TAS - S   L 2 の 問合せ先 は どこ です か ？'},
#  {'id': '517', 'text': 'TAS - S   L 3 の 問合せ先 は どこ です か ？'},
#  {'id': '518', 'text': 'CrBS - T の 問合せ先 は どこ です か ？'},
#  {'id': '519', 'text': 'RISM - BP の 問合せ先 は どこ です か ？'},
#  {'id': '520', 'text': 'DFCA の 問合せ先 は どこ です か ？'},
#  {'id': '521', 'text': 'TASGRP の 問合せ先 は どこ です か ？'},
#  {'id': '522', 'text': 'RTDA 2 - J の 問合せ先 は どこ です か ？'},
#  {'id': '523', 'text': 'CrBS - C の 問合せ先 は どこ です か ？'},
#  {'id': '524', 'text': 'TeBiAs 社内 メンテ の 問合せ先 は どこ です か ？'},
#  {'id': '525', 'text': 'RTDAS 2 - J の 問合せ先 は どこ です か ？'},
#  {'id': '526', 'text': '業務 端末 を 紛失 し た 場合 、 弁済 金 は いくら かかり ます か 。'},
#  {'id': '527',
#   'text': '業 端 A の USIM カード 紛失 ・ ロック さ れ た 場合 の 弁済 金 は いくら かかり ます か 。'},
#  {'id': '528', 'text': '業 端 A の 弁済 金 の 設定 基準 に つい て 教え て 欲しい'},
#  {'id': '529',
#   'text': '業 端 A の 画面 破損 （ 落下 に よる ） の 弁済額 は 上限 4万 と あり ます が 、 具体的 に は いくら くらい に なり ます でしょう か ？'},
#  {'id': '530', 'text': '業務 端末 の 弁済 金 の 実績 を 教え て ください 。'},
#  {'id': '531', 'text': '業務 端末 を 水没 さ せ た 場合 、 弁済 金 は いくら かかり ます か 。'},
#  {'id': '532', 'text': '業 端 A の 不具合 に 伴い 、 弁済 金 が 発生 する か 確認 し たい 。'},
#  {'id': '533',
#   'text': '退職 済 の 派遣 社員 の 業務 端末 が 画面 割れ を 起こし て いる ため 、 弁償 金 ・ 請求先 等 は どのような 応対 に なり ます でしょう か ？'},
#  {'id': '534',
#   'text': 'GoogleEarthPro を OAPC ( FAT ) に インストール する 方法 を 教え て ください 。'},
#  {'id': '535', 'text': 'Alibaba   Cloud   を 使い たい 。'},
#  {'id': '536', 'text': 'knime を 使い たい'},
#  {'id': '537', 'text': 'サクラ エディタ の インストール は 可能 です か ？'},
#  {'id': '538', 'text': 'OA 提供 外 の ソフトウェア インストール に つい て'},
#  {'id': '539', 'text': 'Python を インストール し て も 良い です か ？'},
#  {'id': '540', 'text': 'Mac に sikuli を インストール し たい'},
#  {'id': '541', 'text': 'Sikuli を インストール し たい'},
#  {'id': '542', 'text': 'Mac に python を インストール し たい'},
#  {'id': '543', 'text': 'gizie を インストール し たい'},
#  {'id': '544', 'text': '名刺 カメラ アプリ を インストール し たい'},
#  {'id': '545', 'text': 'フリー ソフト の ダウンロード が し たい'},
#  {'id': '546',
#   'text': 'Tableau   Desktop を 社用 PC で DL し たい の です が 可能 でしょう か ？'},
#  {'id': '547', 'text': 'anaconda を インストール し たい'},
#  {'id': '548', 'text': '無償 ソフトウェア の インストール 申請 に つい て 教え て'},
#  {'id': '549', 'text': '「 + Lhaca 」 インストール し たい'},
#  {'id': '550', 'text': 'Firebase 使い たい'},
#  {'id': '551', 'text': 'WireShark を インストール し たい'},
#  {'id': '552', 'text': '7 zip を インストール し たい'},
#  {'id': '553', 'text': '有償 ソフトウェア を インストール し たい'},
#  {'id': '554', 'text': 'OAPC を 自宅 の WiFi に 接続 する'},
#  {'id': '555', 'text': 'OAPC が 自宅 の Wi-Fi 接続 が でき ない 。'},
#  {'id': '556', 'text': 'OAPC が 自宅 の 無線 LAN に 接続 でき ない'},
#  {'id': '557', 'text': 'OAPC で 自宅 の 無線 LAN に つなぎ たい'},
#  {'id': '558', 'text': 'OAPC が 社外 ネットワーク に 繋がら ない'},
#  {'id': '559', 'text': '自宅 の Wi-Fi に OAPC が 繋がら ない'},
#  {'id': '560', 'text': 'OAMac が 社外 NW に 繋がら ない'},
#  {'id': '561', 'text': 'OAPC を 自宅 の ネットワーク に 接続 する 方法 を 知り たい'},
#  {'id': '562',
#   'text': '自宅 で 支給 さ れ て いる OAPC を 使っ て い ます が 、 自宅 の Wi-Fi で 繋がら ない 。'},
#  {'id': '563', 'text': 'OAPC が 社外 ネットワーク に 接続 でき ない'},
#  {'id': '564', 'text': 'OAPC の Mac が 故障 し た 場合 、 交換 し て いただけ ます か'},
#  {'id': '565', 'text': 'Mac を 貸与 し て 欲しい 。'},
#  {'id': '566', 'text': 'OAPC を Mac に 変更 し たい'},
#  {'id': '567', 'text': 'OAPC を Mac に 変え たい'},
#  {'id': '568', 'text': 'Mac の OAPC を 貸し出し て ほしい'},
#  {'id': '569', 'text': 'Mac を OA 端末 と し て 利用 し たい'},
#  {'id': '570', 'text': 'OAPC を Mac に し たい'},
#  {'id': '571', 'text': '開発 DaaS の 接続 時間 を 短縮 し たい'},
#  {'id': '572', 'text': '開発 DaaS に アクセス する 時間 を 短く し たい'},
#  {'id': '573', 'text': '開発 DaaS に アクセス する 時間 を 短く する 方法 は あり ます か ？'},
#  {'id': '574', 'text': '開発 DaaS の 接続 時間 を 短縮 でき ます か ？'},
#  {'id': '575', 'text': 'O & M ヘルプ デスク の 問合せ 窓口 を 教え て'},
#  {'id': '576', 'text': 'O & M ヘルプ デスク の 問合せ を し たい'},
#  {'id': '577', 'text': 'O & M ヘルプ デスク に 入れ ない'},
#  {'id': '578', 'text': 'O & M ヘルプ デスク の 所属 情報 が 知り たい'},
#  {'id': '579', 'text': 'O & M ヘルプ デスク に ログイン 出来 ない'},
#  {'id': '580', 'text': 'Gmail で 全社員 に 周知 メール を 送り たい'},
#  {'id': '581', 'text': '全社員 宛 に メール を 送信 し たい'},
#  {'id': '582', 'text': 'Gmail で 全社員 に メール を 送信 し たい'},
#  {'id': '583', 'text': '全社員 向け に メール を し たい'},
#  {'id': '584', 'text': '全社員 へ メール を し たい'},
#  {'id': '585', 'text': '全社員 に メール を 送り たい'},
#  {'id': '586', 'text': '全社員 宛て に メール を 送り たい'},
#  {'id': '587', 'text': 'SB 全社員 に メール を 送り たい'},
#  {'id': '588', 'text': '全社員 の Gmail 宛 に 周知 を 送り たい'},
#  {'id': '589', 'text': '誤っ て 消し た gmail を 復活 し たい'},
#  {'id': '590', 'text': '削除 し た Gmail の 復元 方法 は あり ます か ？'},
#  {'id': '591', 'text': 'メール の 復元 に 関し て 教え て 欲しい'},
#  {'id': '592', 'text': '削除 し た メール の 復元 を し たい'},
#  {'id': '593', 'text': 'CRM に 接続 でき ない 。'},
#  {'id': '594', 'text': 'CRM に 不具合 が ある'},
#  {'id': '595', 'text': 'CRM の 問合せ先 を 教え て 欲しい'},
#  {'id': '596', 'text': 'CRM に アクセス でき なく なっ た'},
#  {'id': '597', 'text': 'OMS の 期限 延長 方法 を 教え て ください'},
#  {'id': '598', 'text': 'OMS の パスワード が 分から ない'},
#  {'id': '599', 'text': '作 スケ の パスワード が わから ない'},
#  {'id': '600', 'text': 'OMS の パスワード を リセット し たい'},
#  {'id': '601', 'text': 'OMS の パスワード 変更 方法 を 教え て 欲しい'},
#  {'id': '602', 'text': '作 スケ の パスワード 変更 方法 を 教え て ください 。'},
#  {'id': '603', 'text': 'OMS を 利用 し たい'},
#  {'id': '604', 'text': 'OMS 、 作 スケ の 初期 PW を 教え て ください'},
#  {'id': '605', 'text': 'サスケ に ログイン でき ない'},
#  {'id': '606', 'text': 'OMS の ログイン 方法 を 教え て'},
#  {'id': '607',
#   'text': 'SSO ログイン 後 、 「 Error 403 -- Forbidden 」 が 表示 さ れ て 正常 に ログイン でき ない 。'},
#  {'id': '608',
#   'text': 'SSO ログイン 後 、 「 情報 ログイン し まし た 」 が 表示 さ れ て 正常 に ログイン でき ない 。'},
#  {'id': '609', 'text': 'SSO で 認証 し て いる システム に 入り たい が 、 認証 画面 が 出 て こ ない'},
#  {'id': '610',
#   'text': 'SSO ログイン 後 、 「 不正 な ハンドラ に よる 認証 の 例外 」 が 表示 さ れ て 正常 に ログイン でき ない 。'},
#  {'id': '611',
#   'text': '今まで 社外 で PC から Gmail が 見れ て い た が 、 「 403   Forbidden 」 の エラー が 出 て 見れ ない'},
#  {'id': '612', 'text': 'SSO で ログイン 後 、 再度 、 認証 画面 に 戻っ て しまう の を 解消 し たい'},
#  {'id': '613', 'text': 'SSO ログイン 後 、 「 情報 ログイン し まし た 」 が 表示 さ れる'},
#  {'id': '614',
#   'text': '「 Error 403 -- Forbidden 」 が 表示 さ れ て Gmail に ログイン でき ない 。'},
#  {'id': '615', 'text': 'Gmail に ログイン しよう と し て いる が 、 SSO の 画面 が 出 ない'},
#  {'id': '616',
#   'text': 'エイリアス と パスワード 入力 後 、 「 Error 403 -- Forbidden 」 が 表示 さ れ て 正常 に ログイン でき ない 。'},
#  {'id': '617',
#   'text': '部署 異動 に 伴い OAPC 化 し て いる Mac を 別 の 人間 に 紐 づけ なおし たい の です が どう の う な 手続き を し たら 良い でしょう か ？'},
#  {'id': '618', 'text': '準 OAPC の 利用者 変更 を 教え て'},
#  {'id': '619', 'text': '自部門 購入 PC の 利用者 変更 を し たい'},
#  {'id': '620', 'text': '準 OAPC の 利用者 が 変わる 場合 に 必要 な 手続き を 教え て ほしい'},
#  {'id': '621', 'text': '準 OAPC の 使用者 変更 の 方法 は'},
#  {'id': '622', 'text': '部門 購入 し 、 準 OA 化 し た PC の 管理者 を 変更 し たい'},
#  {'id': '623', 'text': '準 OAPC の 利用者 変更 に つい て 知り たい'},
#  {'id': '624', 'text': '準 OAPC の 管理者 を 変え たい'},
#  {'id': '625', 'text': '準 OAPC の 管理者 を 変更 し たい'},
#  {'id': '626',
#   'text': '部署 購入 PC を OA 化 し た の です が 利用者 を 変える に は どう すれ ば いい です か'},
#  {'id': '627', 'text': 'Zoom ミーティング の 制限 時間 は あり ます か ？'},
#  {'id': '628', 'text': '無料 アカウント の 場合 、 時間 制限 は あり ます か ？'},
#  {'id': '629', 'text': 'Zoom 会議 の 利用 制限 時間 は あり ます か ？'},
#  {'id': '630', 'text': 'Zoom の 利用 制限 時間 は どの くらい です か ？'},
#  {'id': '631', 'text': 'SBTM   BSS の 問合せ先 は どこ です か ？'},
#  {'id': '632', 'text': 'SBTM   BOS の 担当者 を 教え て 欲しい'},
#  {'id': '633', 'text': 'SBTM   BOS の 問合せ先 を 教え て 欲しい'},
#  {'id': '634', 'text': 'SBTM   BSS の 問合せ先 を 教え て 欲しい'},
#  {'id': '635', 'text': 'SBTM   BSS の 担当者 を 教え て 欲しい'},
#  {'id': '636', 'text': 'SBTM   BOS の 問合せ先 は どこ です か ？'},
#  {'id': '637', 'text': '共有 フォルダ の アクセス 権限 を 付与 し たい'},
#  {'id': '638',
#   'text': '共有 ファイル サーバー へ の アクセス権 を 付与 し て ほしい の です が どこ に 問合せ を すれ ば いい です か ？'},
#  {'id': '639', 'text': '共有 フォルダ の 権限 を 設定 し たい'},
#  {'id': '640', 'text': '共有 フォルダ の アクセス 権限 付与 申請 の 仕方 を 教え て'},
#  {'id': '641', 'text': '共有 フォルダ の アクセス権 付与 の 仕方 を 教え て'},
#  {'id': '642', 'text': '共有 フォルダ の 管理者 権限 を 変更 し たい'},
#  {'id': '643', 'text': '共有 フォルダ の 権限 を 付与 し たい'},
#  {'id': '644', 'text': 'プロジェクト フォルダー に 参照 者 を 追加 し たい'},
#  {'id': '645', 'text': '共有 フォルダ へ の 権限 追加 方法 を 教え て'},
#  {'id': '646', 'text': '共有 フォルダ の アクセス 権限 を 追加 し たい'},
#  {'id': '647', 'text': '社外 に 重たい ファイル を 送り たい'},
#  {'id': '648', 'text': '社外 に 大 容量 ファイル を 送る 場合 の 方法'},
#  {'id': '649', 'text': '大 容量 の ファイル を 社外 と 共有 し たい けど どう すれ ば いい ？'},
#  {'id': '650', 'text': '社外 の 人 に 大 容量 の ファイル を 送り たい'},
#  {'id': '651', 'text': '社外 に データ を 送り たい'},
#  {'id': '652', 'text': '大 容量 ファイル を 外部 に 送り たい'},
#  {'id': '653', 'text': '社外 に 重い データ を 送付 し たい'},
#  {'id': '654', 'text': '社外 の 人 へ データ ファイル を 送信 し たい'},
#  {'id': '655', 'text': '社外 に 大きい ファイル を 送り たい'},
#  {'id': '656', 'text': 'ファイル 授受 システム を 使い たい'},
#  {'id': '657', 'text': 'エミュレータ の 問合せ先 は どこ です か ？'},
#  {'id': '658', 'text': 'AS / 400 に つい て 問合せ たい'},
#  {'id': '659', 'text': 'エミュレータ に つい て 問合せ たい'},
#  {'id': '660', 'text': 'エミュレータ の 担当 窓口 を 教え て 欲しい'},
#  {'id': '661', 'text': 'AS / 400 の 問合せ先 は どこ です か ？'},
#  {'id': '662', 'text': 'AS / 400   ( エミュレータ ) に つい て 確認 し たい'},
#  {'id': '663', 'text': 'AS / 400 の 担当 窓口 を 教え て 欲しい'},
#  {'id': '664', 'text': 'View   使用 可能 な ソフトウェア を 教え て 欲しい'},
#  {'id': '665', 'text': 'View 環境 に インストール さ れ て いる アプリケーション を 確認 し たい'},
#  {'id': '666',
#   'text': 'View 環境 下 で インストール 済み と なっ て いる アプリケーション に つい て 教え て ほしい 。'},
#  {'id': '667', 'text': 'View に インストール さ れ て いる ソフト を 教え て 欲しい'},
#  {'id': '668', 'text': 'View で 使える ソフト を 教え て 欲しい'},
#  {'id': '669', 'text': 'View で 使える アプリ を 教え て 欲しい'},
#  {'id': '670', 'text': 'HorizonView で 利用 できる アプリ を 確認 し たい'},
#  {'id': '671', 'text': 'HorizonView で 利用 可能 な アプリケーション を 確認 し たい'},
#  {'id': '672', 'text': 'View に インストール 済み の ソフトウェア を 教え て 欲しい'},
#  {'id': '673', 'text': '販売 契約 社員 の AzureRMS 申請 方法 が 知り たい'},
#  {'id': '674',
#   'text': '販売 契約 社員 が Office 265 を 利用 する 為 に AzureRMS の 申請 を し たい'},
#  {'id': '675', 'text': '販売 契約 社員 の AzureRMS 申請 は Tarte から でき ます か ？'},
#  {'id': '676',
#   'text': '販売 契約 社員 で AzureRMS で 暗号化 さ れ た ファイル を 開く こと が 出来 ませ ん'},
#  {'id': '677', 'text': '販売 契約 社員 の AzureRMS 申請 方法 を 教え て ほしい'},
#  {'id': '678', 'text': '販売 契約 社員 で Office を 使い たい'},
#  {'id': '679', 'text': '販売 契約 社員 の AzureRMS の 申請 方法 を 教え て ください'},
#  {'id': '680', 'text': '販売 契約 社員 で Office 365 を 使い たい'},
#  {'id': '681', 'text': '販売 契約 社員 の AzureRMS の 申請 方法 が わかり ませ ん'},
#  {'id': '682',
#   'text': 'OAPC が blue に 繋がら なく なっ た の で プロファイル を 削除 し た 。 再設定 は どう すれ ば いい か'},
#  {'id': '683', 'text': 'OAPC で Blue を 利用 し たい 。 blue の パスワード を 教え て ください'},
#  {'id': '684', 'text': '準 OAPC で Blue 接続 でき ませ ん 。 パスワード 入力 を 求め られ ます 。'},
#  {'id': '685', 'text': 'OAPC から 社内 LAN の blue に 自動 接続 が でき なく なっ た'},
#  {'id': '686', 'text': 'OAPC から blue に 接続 する 際 の 設定 方法 に つい て 教え て ほしい 。'},
#  {'id': '687', 'text': '準 OAPC を blue に 繋ぎ たい'},
#  {'id': '688', 'text': 'OAPC が Blue に 繋がら ない'},
#  {'id': '689', 'text': 'FATPC から blue へ 接続 する 際 の 接続 方法 を 教え て ほしい 。'},
#  {'id': '690',
#   'text': 'ワークス ペース を 追加 の 項目 から ワークス ペース を 新規 で 追加 し て も いい です か ？'},
#  {'id': '691', 'text': 'ワークス ペース は 自身 で 作成 可能 です か ？'},
#  {'id': '692', 'text': '自分 で 新しく ワークス ペース を 作り たい'},
#  {'id': '693', 'text': 'ワークス ペース を 新規 作成 の 項目 は 使っ て も いい です か ？'},
#  {'id': '694',
#   'text': '「 iTunes マーク と USB ケーブル 接続 の 画面 が 表示 さ れる 」 場合 、 初期化 しか ない でしょう か 。'},
#  {'id': '695', 'text': 'iPhone / iPad で iTunes に 接続 を 乞う 画面 が 表示 さ れ ます 。'},
#  {'id': '696',
#   'text': '「 iTunes マーク と USB ケーブル 接続 の 画面 が 表示 さ れる 」 場合 、 iTunes を インストール し て 初期化 し て も いい でしょう か 。'},
#  {'id': '697',
#   'text': 'iPhone を 起動 する と iTunes マーク と USB ケーブル 接続 の 画面 が 表示 さ れる'},
#  {'id': '698', 'text': 'W ドライブ を マウント し て い なく て も 、 暗号化 は 適用 さ れ て い ます か ？'},
#  {'id': '699', 'text': 'AzureRMS の 暗号化 は W ドライブ で も 適用 さ れ て い ます か ？'},
#  {'id': '700', 'text': 'W ドライブ は マウント し て い なく て も 暗号化 さ れ ます か ？'},
# ...
#  {'id': '758', 'text': 'アオマイ に つい て 問合せ たい'},
#  {'id': '759', 'text': "A ' OMAI に つい て 問合せ たい"},
#  {'id': '760', 'text': 'アオマイ の 管理 部署 を 教え て 欲しい'},
#  {'id': '761', 'text': 'L 3 OA アカウント の パスワード を リセット （ ロック 解除 ） し たい'},
#  {'id': '762', 'text': 'L 3 アカウント の パスワード リセット 方法 を 教え て'},
#  {'id': '763', 'text': 'L 3 アカウント の パスワード リセット に つい て'},
#  {'id': '764', 'text': 'L 3 アカウント の パスワード を リセット し たい'},
#  {'id': '765', 'text': 'L 3 アカウント が パスワード ロック さ れ た とき どこ に 連絡 すれ ば いい ？'},
#  {'id': '766', 'text': '代理 で L 3 アカウント の パスワード リセット を する 方法 を 教え て'},
#  {'id': '767', 'text': 'L 3 アカウント の パスワード が わから ない'},
#  {'id': '768', 'text': 'L 2 アカウント の パスワード リセット 方法 を 教え て 欲しい'},
#  {'id': '769', 'text': 'L 3 アカウント の パスワード が 不明 です'},
#  {'id': '770', 'text': 'iPhone から Android へ 移行 し たい'},
#  {'id': '771', 'text': 'Android へ iPhone から データ を 移し たい'},
#  {'id': '772', 'text': 'Android へ iPhone から 設定 変更 し たい'},
#  {'id': '773', 'text': 'iPhone から Android へ 設定 を 移行 し たい'},
#  {'id': '774', 'text': 'iPhone から Android へ データ を 移す 方法 を 知り たい'},
#  {'id': '775', 'text': 'Android に iPhone から データ 移行 を し たい'},
#  {'id': '776', 'text': 'Android へ iPhone から 切り替え たい'},
#  {'id': '777', 'text': 'iPhone から Android へ の データ を 移し たい'},
#  {'id': '778', 'text': 'iPhone から Android へ の 機種変 時 の 設定 が 知り たい'},
#  {'id': '779', 'text': 'ソフトウェア 担当者 の 変更 方法 を 教え て'},
#  {'id': '780', 'text': 'ライセンス 担当者 の 変更 する に は どう し たら いい か'},
#  {'id': '781', 'text': 'ソフトウェア 担当者 を 変更 し たい 場合 は どう すれ ば いい です か 。'},
#  {'id': '782', 'text': 'ソフトウェア 担当者 の 変更 申請 方法 を 教え て 欲しい'},
#  {'id': '783', 'text': 'ソフトウェア の 管理 部門 を 変更 し たい'},
#  {'id': '784', 'text': 'ソフトウェア 担当者 の 変更 方法 に つい て 教え て'},
#  {'id': '785', 'text': 'ソフトウェア 管理者 の 変更 方法 を 教え て'},
#  {'id': '786', 'text': 'ソフトウェア 担当者 を 変更 し たい'},
#  {'id': '787', 'text': 'ソフトウェア 担当者 を 変更 する 方法 を 教え て 欲しい'},
#  {'id': '788', 'text': '業務用 携帯 B の コンテンツ 登録 方法 を 教え て 欲しい'},
#  {'id': '789', 'text': '業務 端末 B の コンテンツ 登録 方法 を 教え て ください 。'},
#  {'id': '790', 'text': '業 端 B で My   SoftBank から コンテンツ 登録 が でき ない'},
#  {'id': '791',
#   'text': '業 端 B の コンテンツ 登録 が 福岡 Biz で でき ない と 言わ れ た 場合 の 対処 方法 を 教え て 欲しい'},
#  {'id': '792', 'text': '業務 端末 B で コンテンツ 登録 に つい て 確認 し たい'},
#  {'id': '793', 'text': 'iPad の 電話 番号 を 調べ たい'},
#  {'id': '794', 'text': 'Android の MSN の 確認 方法 を 教え て ください 。'},
#  {'id': '795', 'text': 'iPhone / iPad の MSN の 確認 方法 を 教え て ください 。'},
#  {'id': '796', 'text': '業務 端末 A （ 携帯 ） の 電話 番号 が 表示 さ れ ない'},
#  {'id': '797', 'text': '業務 端末 B で 電話 番号 もしくは データ 通信 契約 番号 が 表示 さ れ ませ ん 。'},
#  {'id': '798', 'text': '業務 端末 A の iPhone で MSN が 表示 さ れ ませ ん 。'},
#  {'id': '799', 'text': 'iPad の データ 通信 契約 番号 を 知り たい'},
#  {'id': '800', 'text': 'iPad の 「 MSN （ データ 通信 契約 番号 ） 」 を 確認 し たい 。'},
#  {'id': '801', 'text': '業務 端末 A の Android で MSN が 表示 さ れ ませ ん 。'},
#  {'id': '802', 'text': '業務 端末 A で MSN が 表示 さ れ ませ ん'},
#  {'id': '803', 'text': 'グループ アドレス に プロジェクト フォルダ の 管理者 権限 を 付与 し たい'},
#  {'id': '804', 'text': 'プロジェクト フォルダ の アクセス権 に グループ アドレス を 設定 し たい'},
#  {'id': '805', 'text': 'プロジェクト フォルダ 権限 に グループ アドレス を 設定 し たい'},
#  {'id': '806', 'text': 'グループ アドレス に フォルダ アクセス権 を 設定 し たい'},
#  {'id': '807', 'text': 'グループ アドレス に プロジェクト フォルダ 権限 を 設定 し たい'},
#  {'id': '808', 'text': 'グループ アドレス に プロジェクト フォルダ の 権限 を 付与 し たい'},
#  {'id': '809', 'text': 'グループ アドレス に プロジェクト フォルダ の 権限 を 付け たい'},
#  {'id': '810', 'text': 'プロジェクト フォルダ に アクセス権 を つけ たい'},
#  {'id': '811', 'text': 'ブラウザ が 古い と 表示 さ れ て Slack に サイン イン でき ない'},
#  {'id': '812', 'text': 'Slack に サイン イン し たい の で Chrome の 更新 方法 を 教え て'},
#  {'id': '813', 'text': 'Slack に サイン イン できる ブラウザ に し たい'},
#  {'id': '814',
#   'text': 'Slack に サイン イン しよう と する と 、 ブラウザ を 更新 する よう エラー が 出 て しまう'},
#  {'id': '815', 'text': 'ミーティング に 参加 し て いる 人 を 確認 し たい'},
#  {'id': '816', 'text': '会議 参加者 を 確認 する 方法 は あり ます か ？'},
#  {'id': '817', 'text': '会議 の 参加者 の 一覧 が 欲しい'},
#  {'id': '818', 'text': '誰 が 会議 に 参加 し て い た か 確認 する こと は でき ます か ？'},
#  {'id': '819', 'text': 'OAMac で 閲覧 可能 な サイト の 一覧 は あり ます か ？'},
#  {'id': '820',
#   'text': 'Mac ローカル 上 で 、 etime 、 smile を 表示 さ せる 方法 を ご 教示 ください 。 Chrome で intra は 表示 できる もの の コンテンツ が エラー と なっ て しまい ます 。'},
#  {'id': '821', 'text': 'OAMac で 人事 Navi は 閲覧 でき ます か ？'},
#  {'id': '822', 'text': 'OAMac で 社内 システム に アクセス でき ます か ？'},
#  {'id': '823',
#   'text': '準 OAMAC の 設定 を 行っ た の です が 、 blue で 接続 し た とき に Gmail や OA サポート に は 入れ ます が 、 人事 navi や PureTerminal や Smile に は 入れ ない よう です 。'},
#  {'id': '824', 'text': '業務 端末 A の 交換 後 の 返却 期限 を 教え て ください 。'},
#  {'id': '825', 'text': '業 端 A 交換 後 の 返却 ルール に つい て 教え て 欲しい'},
#  {'id': '826', 'text': '業 端 A 交換 後 、 旧 端末 は いつ まで に 返却 すれ ば よい です か ？'},
#  {'id': '827', 'text': '業務用 端末 B を 故障 交換 し た 場合 の 返却 方法 を 教え て 欲しい'},
#  {'id': '828', 'text': '固定 IP の 払い出し て ほしい'},
#  {'id': '829', 'text': '固定 IP に する 方法 は ？'},
#  {'id': '830', 'text': '固定 IP の 払い出し し たい'},
#  {'id': '831', 'text': '固定 IP アドレス を 取得 する に は'},
#  {'id': '832', 'text': '固定 ip が ほしい'},
#  {'id': '833', 'text': '固定 IP の 申請 手順 を 確認 し たい'},
#  {'id': '834', 'text': '固定 IP アドレス の 申請 方法 に つい て'},
#  {'id': '835', 'text': '固定 IP アドレス の 申請 方法 に つい て 教え て ほしい'},
#  {'id': '836', 'text': '固定 IP を 設定 する こと は 可能 です か'},
#  {'id': '837', 'text': 'テレビ 会議用 機器 など の 固定 IP の ご 申請 方法 を 教え て ください 。'},
#  {'id': '838',
#   'text': '「 この ブック を 開く ため の 権限 が あり ませ ん 。 別 の 資格 情報 を 使っ て ファイル を 開き ます 」 が 表示 さ れ 、 Excel ファイル が 開け ない'},
#  {'id': '839', 'text': 'この ブック を 開く ため の 権限 が あり ませ ん 。'},
#  {'id': '840',
#   'text': 'この ブック を 開く ため の 権限 が あり ませ ん 。 別 の 権限 を 使っ て 情報 を 開き ます か ？'},
#  {'id': '841',
#   'text': 'Excel ファイル が 開き ませ ん 。 現在 の アカウント が 表示 さ れる の で クリック する と この ブック を 開く 権限 が あり ませ ん と 表示 さ れ ます'},
#  {'id': '842',
#   'text': 'この ブック を 開く 権限 が あり ませ ん 、 の エラー が 表示 さ れ て Excel ファイル が 開け ない'},
#  {'id': '843',
#   'text': '「 この ブック を 開く ため の 権限 が あり ませ ん 。 別 の 資格 情報 を 使っ て ファイル を 開き ます 」 が 表示 さ れる'},
#  {'id': '844',
#   'text': 'この ブック を 開く 権限 が あり ませ ん 、 と 表示 さ れ て Excel ファイル が 開け ない'},
#  {'id': '845',
#   'text': '「 この ブック を 開く ため の 権限 が あり ませ ん 。 別 の 資格 情報 を 使っ て ファイル を 開き ます 」 の エラー メッセージ が 表示 さ れる'},
#  {'id': '846', 'text': 'この プレゼンテーション を 開く 為 の 権限 が あり ませ ん \u3000 と 表示 さ れる'},
#  {'id': '847', 'text': 'PC の デスクトップ で 「 アイコン を 等間隔 に 整列 」 の 設定 が でき ない'},
#  {'id': '848', 'text': '「 アイコン を 等間隔 に 整列 」 が 選択 でき ない'},
#  {'id': '849', 'text': '「 アイコン を 等間隔 に 整列 」 が クリック でき ない'},
#  {'id': '850', 'text': '「 アイコン を 等間隔 に 整列 」 に チェック が 入ら ない'},
#  {'id': '851', 'text': '組織 グループ の 正 社員用 と 全 社員用 の 違い を 教え て 欲しい'},
#  {'id': '852', 'text': '組織 グループ の 正 社員用 と 全 社員用 の 用途 を 教え て 欲しい'},
#  {'id': '853', 'text': '組織 グループ の 用途 に つい て 教え て 欲しい'},
#  {'id': '854', 'text': '組織 グループ の 正 社員用 と 全 社員用 は どこ が 異なる の でしょう か ？'},
#  {'id': '855',
#   'text': 'サイバー トラスト   デバイス ID 発行 の お知らせ の メール が 発行 さ れ て いる か 確認 し たい'},
#  {'id': '856',
#   'text': 'サイバー トラスト   デバイス ID 発行 の お知らせ が 届か ない の で 、 再発行 し て 欲しい'},
#  {'id': '857',
#   'text': 'OASYS 申請後 、 サイバー トラスト   デバイス ID 発行 の お知らせ の メール が 届か ない'},
#  {'id': '858', 'text': 'サイバー トラスト   デバイス ID 発行 の お知らせ の メール が 見当たら ない'},
#  {'id': '859', 'text': '業務用 携帯 B の 種類 が 知り たい 。'},
#  {'id': '860', 'text': '業 端 B に 適合 する USIM を 確認 し たい'},
#  {'id': '861', 'text': '業務用 携帯 B の 機種 が 知り たい 。'},
#  {'id': '862', 'text': '業務用 端末 B の 機器 コード を 知り たい 。'},
#  {'id': '863', 'text': '業務用 携帯 B 手配 機種 の 商品 コード を 知り たい'},
#  {'id': '864', 'text': '業務 端末 B の 販売 関連 情報 を 確認 し たい 。'},
#  {'id': '865', 'text': '業務 端末 B の 製品 情報 を 確認 し たい 。'},
#  {'id': '866',
#   'text': '業 端 端末 で VPN 申請 し て い た が 端末 交換 し た ため 、 以前 の VPN 申請 を 削除 し たい 。 手順 を 教え て ほしい 。'},
#  {'id': '867', 'text': '業務 端末 を 返却 する に 当たっ て VPN の 削除 申請 を 行う 方法 を 知り たい'},
#  {'id': '868', 'text': 'iPhone の VPN 申請 の 削除 方法 を 教え て ほしい'},
#  {'id': '869', 'text': '業務用 端末 A の VPN 削除 の 仕方 に つい て 知り たい 。'},
#  {'id': '870', 'text': '業 端 A の VPN の 申請 を 削除 し たい'},
#  {'id': '871', 'text': '業務 端末 の VPN の 削除 申請 を し たい 。'},
#  {'id': '872', 'text': '業務 端末 の VPN 削除 申請 方法 を 教え て 欲しい 。'},
#  {'id': '873', 'text': 'iPad - VPN の 申請 を 削除 し たい'},
#  {'id': '874', 'text': 'iPhone を 返却 する 前 に VPN の 申請 を 削除 し たい'},
#  {'id': '875', 'text': 'OAPC の Slack の バージョン アップ は でき ます か ？'},
#  {'id': '876', 'text': 'Slack の デスクトップ アプリ の バージョン アップ を し たい'},
#  {'id': '877', 'text': 'Slack アプリ の バージョン アップ を し たい'},
#  {'id': '878', 'text': 'Slack アプリ の アップデート 方法 を 教え て'},
#  {'id': '879', 'text': 'ソフトウェア センター が 存在 し て い ない 場合 の 対処 方法 を 教え て 欲しい'},
#  {'id': '880', 'text': 'ソフトウェア センター が インストール さ れ て い ない'},
#  {'id': '881',
#   'text': 'アプリケーション を インストール しよう と し た が 、 ソフトウェア センター が 存在 し ない'},
#  {'id': '882', 'text': 'ソフトウェア センター が 存在 し て い ない'},
#  {'id': '883',
#   'text': 'ソフトウェア センター から インストール できる ソフトウェア が ある と の こと だ が 、 そもそも ソフトウェア センター が 存在 し て い ない'},
#  {'id': '884', 'text': 'ソフトウェア センター が 存在 し ない'},
#  {'id': '885', 'text': 'スタート 内 に ソフトウェア センター が 存在 し ない'},
#  {'id': '886', 'text': 'サーバ 上 に ソフトウェア を インストール し たい'},
#  {'id': '887',
#   'text': 'サーバ に Microsoft の ボリューム ライセンス を インストール し たい が どう し たら いい です か 。'},
#  {'id': '888', 'text': 'サーバー に ソフトウェア を インストール し たい'},
#  {'id': '889', 'text': 'サーバ に ソフトウェア を インストール する 手順 を 教え て 欲しい'},
#  {'id': '890', 'text': 'サーバー に アプリケーション を インストール する 場合 、 申請 は 必要 です か ？'},
#  {'id': '891',
#   'text': 'サーバ に ソフトウェア を インストール し たい が ライセンス 管理 システム で の 申請 は 必要 です か 。'},
#  {'id': '892', 'text': 'サーバ に ソフトウェア を インストール する 場合 、 申請 は 必要 です か ？'},
#  {'id': '893', 'text': 'サーバー へ の ソフトウェア インストール に つい て'},
#  {'id': '894',
#   'text': 'サーバー に ソフト を インストール する の に Microsoft の ボリューム ライセンス の インストーラ が 必要 です'},
#  {'id': '895', 'text': 'Excel が 使え なく なり まし た'},
#  {'id': '896', 'text': 'エクセル だけ 起動 でき ない'},
#  {'id': '897', 'text': 'エクセル を 起動 する と エラー が 出 て 開く こと が でき ませ ん 。'},
#  {'id': '898', 'text': 'WORD が 起動 し ない'},
#  {'id': '899', 'text': 'Excel が 開け なく なっ た'},
#  {'id': '900', 'text': 'PowerPoint が 開け ない'},
#  {'id': '901', 'text': 'パワーポイント が 起動 し ない'},
#  {'id': '902', 'text': 'エクセル が 起動 し ない の で 対処法 を 知り たい'},
#  {'id': '903', 'text': 'Excel が 動か なく なっ た'},
#  {'id': '904', 'text': '突然 L 3 DevMac で Aqua に つながら なく なっ た'},
#  {'id': '905', 'text': 'L 3 Dev 端末 を aqua に つなげ たい'},
#  {'id': '906', 'text': '開発 PC が aqua に 接続 でき ない'},
#  {'id': '907', 'text': 'aqua の 接続 方法 に つい て'},
#  {'id': '908', 'text': '開発 PC で aqua に 接続 でき ない 場合 の 対応 方法 を 教え て ください 。'},
#  {'id': '909', 'text': 'aqua に 繋げ たい'},
#  {'id': '910', 'text': 'L 3 Dev 端末 から Aqua に 接続 し たい'},
#  {'id': '911', 'text': 'aqua に 接続 出来 ない'},
#  {'id': '912', 'text': 'L 3 Dev 端末 用 の 無線 に つなげ たい'},
#  {'id': '913', 'text': 'aqua の パスワード 教え て ください 。'},
#  {'id': '914', 'text': '準 OA 化 の 手順 で LAN コンバーター の 使い方 が よく わかり ませ ん'},
#  {'id': '915', 'text': '部門 購入 PC の セットアップ URL へ アクセス し たい'},
#  {'id': '916',
#   'text': '部門 で 購入 し た 最新 の Windows   OS だ と 社内 NW に 接続 でき ない の でしょう か 。'},
#  {'id': '917',
#   'text': '準 OA 化 作業 を し て い ます 。 LAN コンバーター を 接続 し た の です が インターネット に 接続 でき ませ ん 。'},
#  {'id': '918', 'text': '部門 購入 PC の セットアップ URL へ アクセス できる 方法 を 教え て ください'},
#  {'id': '919',
#   'text': '準 OA 化 し て い ます が 最初 の ダウンロード ページ へ の アクセス 方法 を 知り たい'},
#  {'id': '920', 'text': 'CaMP に つい て 問合せ たい'},
#  {'id': '921', 'text': 'CaMP の 権限 が 欲しい'},
#  {'id': '922', 'text': 'CaMP の 管理 部署 を 教え て 欲しい'},
#  {'id': '923', 'text': 'CaMP の 問合せ先 は どこ です か ？'},
#  {'id': '924', 'text': 'CaMP に つい て 確認 し たい'},
#  {'id': '925', 'text': 'CaMP の 権限 を 取得 し たい'},
#  {'id': '926', 'text': 'CaMP に つい て'},
#  {'id': '927', 'text': 'Camp に つい て'},
#  {'id': '928', 'text': 'クルーナビ に つい て 質問 し たい'},
#  {'id': '929', 'text': 'クルーナビ の パスワード が わから ない'},
#  {'id': '930', 'text': 'クルーナビ に つい て 確認 し たい'},
#  {'id': '931',
#   'text': 'iPad で 今まで クルーナビ が 見れ て い た が 再起動 し たら 開か なく なっ た 。 VPN は 繋がっ て いる'},
#  {'id': '932', 'text': '業務 端末 の PC で クルーナビ に ログイン 出来 ない'},
#  {'id': '933', 'text': 'クルーナビ の 問い合わせ 窓口 を しり たい'},
#  {'id': '934', 'text': 'インターネット は 接続 できる が 、 クルーナビ に アクセス でき ませ ん'},
#  {'id': '935', 'text': 'クルーナビ に アクセス でき ませ ん'},
#  {'id': '936', 'text': '社外 で 社内 システム を 閲覧 し たい'},
#  {'id': '937', 'text': '社外 で OAPC を 利用 し たい'},
#  {'id': '938', 'text': '外出先 で OAPC を 使い たい'},
#  {'id': '939', 'text': '社外 で も PC が 使える よう に し たい'},
#  {'id': '940',
#   'text': 'OAPC で 社外 環境 から 社内 システム を 利用 する に は どの よう に すれ ば 良い です か'},
#  {'id': '941', 'text': 'OA 端末 を 社外 から 利用 し たい'},
#  {'id': '942', 'text': '社外 環境 で OA 標準 端末 から 社内 システム を 利用 し たい'},
#  {'id': '943', 'text': '社外 から 社内 システム を 利用 する の に は どう し たら いい です か ？'},
#  {'id': '944', 'text': '社外 環境 で OAPC を 使用 し たい'},
#  {'id': '945', 'text': 'OAPC で 社外 環境 から 社内 システム を 利用 する'},
#  {'id': '946', 'text': 'L 3 Dev 端末 故障 の 為 交換 し たい'},
#  {'id': '947', 'text': 'L 3 Dev 端末 が 故障 し た の で 交換 し て ほしい'},
#  {'id': '948', 'text': 'L 3 Dev 端末 の 故障 交換 を 実施 し て ほしい'},
#  {'id': '949', 'text': 'L 3 Dev 端末 が 故障 し た 場合 の 対処 方法 を 教え て 欲しい'},
#  {'id': '950', 'text': '開発 環境 の 端末 か 故障 し た の で 交換 し て ほしい 。'},
#  {'id': '951', 'text': 'L 3 Dev 端末 の 故障 交換 を し て ほしい'},
#  {'id': '952', 'text': '開発 端末 が 故障 し た の で 交換 し たい'},
#  {'id': '953', 'text': '開発 端末 を 故障 交換 し たい'},
#  {'id': '954', 'text': 'L 3 Dev 端末 が 故障 し た の で 、 交換 し たい'},
#  {'id': '955', 'text': '開発 端末 が 故障 し た の で 交換 し て ほしい'},
#  {'id': '956',
#   'text': 'iPhone / iPad の Touch   ID （ 指紋 認証 ） の やり方 を 教え て ください 。'},
#  {'id': '957',
#   'text': 'iPhone / iPad の Touch   ID （ 指紋 認証 ） の 登録 方法 を 確認 し たい 。'},
#  {'id': '958', 'text': 'iPhone の 指紋 認証 の 手順 を 教え て ほしい'},
#  {'id': '959',
#   'text': 'iPhone / iPad の Touch   ID （ 指紋 認証 ） の 登録 方法 を 教え て ください 。'},
#  {'id': '960',
#   'text': 'iPhone / iPad の Touch   ID （ 指紋 認証 ） に 運用 ルール は あり ます か 。'},
#  {'id': '961', 'text': 'Google の アプリケーション で の アドオン 利用 方法 を 教え て 欲しい'},
#  {'id': '962', 'text': 'Google ドキュメント で アドオン を 利用 し たい'},
#  {'id': '963', 'text': 'Google の アドオン を 利用 し たい です'},
#  {'id': '964', 'text': 'Google スプレッドシート で アドオン を 利用 し たい'},
#  {'id': '965', 'text': 'Chrome に アドオン を いれ て も いい か'},
#  {'id': '966', 'text': 'Google の アプリケーション で アドオン を 利用 する 申請 方法 を 教え て 欲しい'},
#  {'id': '967', 'text': 'Google   Workspace の アドオン を 利用 し たい です'},
#  {'id': '968', 'text': 'Google プレゼンテーション で アドオン を 利用 し たい'},
#  {'id': '969', 'text': 'IMSI タイプ コード の 確認 方法 を 教え て ほしい'},
#  {'id': '970', 'text': 'IMSI タイプ コード が 分ら ない'},
#  {'id': '971', 'text': 'IMSI タイプ コード を 確認 し たい'},
#  {'id': '972', 'text': '業務用 携帯 B の 新規 申請 に 必要 な IMSI タイプ コード が 不明'},
#  {'id': '973', 'text': 'IMSI タイプ コード を 調べ たい'},
#  {'id': '974', 'text': '業務 端末 B の iPhone の バック ライト が 点灯 し ない 。'},
#  {'id': '975', 'text': '業務 端末 A で バック ライト が 点灯 し なく なり まし た 。'},
#  {'id': '976', 'text': '業務 端末 B の バック ライト が 光ら なく なり まし た 。'},
#  {'id': '977', 'text': '業務 端末 B で バック ライト が 点灯 し なく なり まし た 。 交換 可能 でしょう か 。'},
#  {'id': '978', 'text': '業務 端末 A の iPhone の バック ライト が 点灯 し ない 。'},
#  {'id': '979', 'text': '業務 端末 A で 画面 を 輝度 調整 し た が 、 暗い まま です 。'},
#  {'id': '980', 'text': '業務 端末 A で 輝度 調整 が でき なく なり まし た 。 交換 可能 でしょう か 。'},
#  {'id': '981', 'text': '業務 端末 A の バック ライト が つか なく なり まし た 。'},
#  {'id': '982', 'text': '業務 端末 A で バック ライト が 点灯 し なく なり まし た 。 交換 可能 でしょう か 。'},
#  {'id': '983', 'text': '業務 端末 B で 輝度 調整 が でき なく なり まし た 。 交換 可能 でしょう か 。'},
#  {'id': '984', 'text': '出荷 統合 システム に つい て 確認 し たい'},
#  {'id': '985', 'text': '出荷 統合 システム に つい て 問合せ たい'},
#  {'id': '986', 'text': '出荷 統合 システム の 問合せ先 は どこ です か ？'},
#  {'id': '987', 'text': '出荷 統合 システム の 管理 部署 を 教え て 欲しい'},
#  {'id': '988',
#   'text': 'Office 365 ライセンス 認証 時 に 「 ユーザー ID   また は 、 パスワード が 正しく あり ませ ん 。 もう 一度 試し て み て ください 。 」 と 表示 さ れ た'},
#  {'id': '989',
#   'text': 'Office 365 で ユーザー ID   また は 、 パスワード が 正しく あり ませ ん 。 もう 一度 試し て み て ください 。 が 発生 する 。'},
#  {'id': '990', 'text': 'パスワード が 違う と 表示 さ れ て Office 365 ライセンス 認証 に 失敗 する'},
#  {'id': '991',
#   'text': 'Office 365 ライセンス 認証 時 に ユーザー ID   また は 、 パスワード が 正しく あり ませ ん 。 もう 一度 試し て み て ください 。 と 表示 さ れ た'},
#  {'id': '992',
#   'text': 'Office 365 の ライセンス 認証 で 「 ユーザー ID   また は 、 パスワード が 正しく あり ませ ん 。 もう 一度 試し て み て ください 。 」 と 表示 さ れる'},
#  {'id': '993',
#   'text': 'Office 365 ライセンス 認証 時 に 「 ユーザー ID   また は 、 パスワード が 正しく あり ませ ん 。 もう 一度 試し て み て ください 。 」 と 表示 さ れ た の です が どう すれ ば いい です か 。'},
#  {'id': '994', 'text': 'ユーザー名 が 違う と 表示 さ れ て Office 365 ライセンス 認証 が 出来 ない'},
#  {'id': '995', 'text': '「 この 項目 は もう 使用 でき ませ ん 」 が 表示 さ れる の を 解消 し たい'},
#  {'id': '996',
#   'text': '「 この 項目 は もう 使用 でき ませ ん 」 が 表示 さ れ た 場合 の 対処 方法 を 教え て 欲しい'},
#  {'id': '997',
#   'text': 'SelfService から Admin 権限 付与 時 「 この 項目 は もう 使用 でき ませ ん 」 が 表示 さ れる'},
#  {'id': '998',
#   'text': 'SelfService から Admin 権限 付与 時 「 この 項目 は もう 使用 でき ませ ん 」 が 表示 さ れ 、 Admin 権限 が 付与 でき ない'},
#  {'id': '999',
#   'text': 'billing   support . ad . intra . eaccess . net に アクセス でき ませ ん 。'},
#  ...]

# %%
split_corpus_l = [split_text(c) for c in corpus_l]

# %%
split_corpus_l
# Out:
# [{'id': '100000',
#   'title': '',
#   'text': 'Slack の ゲスト アカウント の 有効 期限 が 切れ た （ 解除 済み アカウント ） 場合 は 、 ゲスト 管理 システム から ゲスト 新規 登録 申請 と 利用 サービス 登録 申請 を 実施 下さい 。 \n ※ ゲスト 登録 が 有効 期限内 の 場合 は 、 マイゲスト 一覧 から 利用 サービス 登録 申請 のみ 実施 下さい \n 申請 方法 は 下記 手順 を 参照 下さい 。 \n\n ・ 【 ゲスト 管理 システム 】 マニュアル - 申請者 向け \n https : / / docs . google . com / presentation / d / 1 Z 0 PUkjNUr 9 r 2 GCq 5 ZEEddd 5 jPUJg 48 kPMsCxv 5 Mtw _ M / edit # slide = id . g 1287222 f 34 d _ 1 _ 61 \n\n 申請 の 上長 承認 後 、 5 営業日 以内 に アカウント が 有効 化 さ れ ます 。 \n 有効 化 完了 後 は 下記 メール が 送信 さ れ ます の で 、 メール を 確認 次第 、 必要 な チャンネル に ゲスト を 招待 し て 下さい 。 \n ※ ゲスト を チャンネル に 招待 する 際 は メール アドレス で は なく Slack 上 の 氏名 で 検索 下さい \n 件名 ： 【 ゲスト 管理 】 利用 サービスプロビジョニングエラー 対応 完了 通知 \n\n ■ お 問合せ先 \n ・ OA   Support   Net \n\u3000 http:// oa . bb . local / oasupport / inquiry _ web \n\u3000 （ 投稿 カテゴリ ： Slack ）'},
#  {'id': '100001',
#   'title': '',
#   'text': 'WHC の 問合せ に つい て は 、 OA サポート デスク で は サポート 対象外 と なり ます 。 \n 下記 窓口 が 担当 か と 思わ れ ます の で 、 直接 問合せ 願い ます 。 \n\n ・ ＩＴ 部門 （ ＷＨＣ ） 工数 管理 窓口 \n  SBMGRP - WHC @ g . softbank .co.jp \n\n また 、 WHC の 申請 に つい て も 、 OA サポート デスク で は サポート 対象外 と なり ます 。 \n 下記 窓口 が 担当 か と 思わ れ ます の で 、 直接 問合せ 願い ます 。 \n\n ・ システム コード 管理 窓口 \n  SBMGRP - system - code @ g . softbank .co.jp'},
#  {'id': '100002',
#   'title': '',
#   'text': 'GoogleChrome の インストール ・ アンインストール 方法 に つい て は 、 ソフトウェア センター から 実施 し て 下さい 。 \n\n ■ インストール 方法 \n GoogleChrome の インストール 方法 に つい て は 、 ソフトウェア センター から 実施 し て 下さい 。 \n ・ 【 SCCM 】 Windows 向け ソフトウェア センター 利用 マニュアル \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / post / sccm _ win 10 \n\n ソフトウェア センター から インストール 不可 の 場合 は 、 Admin 権限 取得 の 上 、 下記 手順 で インストール し て 下さい 。 \n 1 . Admin 権限 申請 及び 適用 方法 を 実施 する \n ・ 【 社内外 共通 】 L 2 OAPC / 準 OAPC   Admin 権限 申請 ・ 適用 方法 \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / admintekiyou _ shanaigai \n 2 . 下記 リンク に アクセス する 。 \n\u3000 https : / / drive . google . com / drive / folders / 1 XmkYaUoTWsYq - sOmC 6 XCuewUILBYINxW \n 3 . 最新 版 の フォルダ を デスクトップ に コピー し 、 フォルダ 内 の インストーラー （ . msi ） を ダブル クリック する \n ※ インストーラー を ダブル クリック 後 も インストール でき ない 場合 は 、 インストーラー を 右 クリック ＞ 管理者 と し て 実行 を 実施 し て 下さい \n\n 参考 FAQ \n ・ Q . 10 - 004 \u3000 Chrome ブラウザ が インストール でき ない \n  https : / / sites . google . com / a / g . softbank .co.jp / helpg / discussion - board / chrome / 10 - 004 \n\n ■ アンインストール 方法 \n ・ 【 SCCM 】 Windows 向け ソフトウェア センター 利用 マニュアル \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / post / sccm _ win 10 \n ※ 「 インストール 済み ソフトウェア 」 （ インストール の ステータス ） タブ を クリック し 、 【 Google Chrome   Ver . xx . x . xxxx . xxx 】 を クリック し 、 アンインストール を 実施 し て 下さい 。 \n\n ソフトウェア センター から アンインストール 不可 の 場合 は 、 Admin 権限 取得 の 上 、 下記 手順 で アンインストール し て 下さい 。 \n 1 . Admin 権限 申請 及び 適用 方法 を 実施 する \n ・ 【 社内外 共通 】 L 2 OAPC / 準 OAPC   Admin 権限 申請 ・ 適用 方法 \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / admintekiyou _ shanaigai \n 2 . Windows キー + R キー を 同時 押下 し 、 ファイル 名 を 指定 し て 実行 の 画面 で 「 appwiz . cpl 」 を 入力 し 、 OK を クリック する 。 \n 3 . 「 Google Chrome 」 の 項目 を 選択 し 、 「 アンインストール 」 を クリック する 。'},
#  {'id': '100003',
#   'title': '',
#   'text': 'ファイル など の PDF 化 方法 に つい て は 、 下記 FAQ を 参照 し て 下さい 。 \n\n ・ ファイル など の PDF 化 手順 に つい て ［ FAQ   No ： F 000158899 ］ \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / faq / F 000158899'},
#  {'id': '100004',
#   'title': '',
#   'text': 'Android で GooglePlay 未登録 アプリ の インストール 時 、 「 インストール は ブロック さ れ まし た \u3000 携帯 端末 の セキュリティ 上 の 設定 で 供給 元 不明 の Application の インストール を ブロック し て い ます 」 と エラー が 表示 さ れ た 場合 は 、 下記 手順 を 実施 し て 下さい 。 \n 設定 > その 他 設定 > ロック と セキュリティ 内 の 「 提供 元 不明 アプリ 」 に チェック を 付ける \n ※ アプリ の インストール が 終わっ たら 再度 チェック を 外し て 下さい'},
#  {'id': '100005',
#   'title': '',
#   'text': '業 端 A   iPhone / iPad の iCloud へ の バックアップ に つい て は 、 下記 を 参照 下さい 。 \n ・ 【 iPhone / iPad 】 iCloud バックアップ マニュアル \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / manual / icloud - backup'},
#  {'id': '100006',
#   'title': '',
#   'text': 'View で の プリンタ 設定 は 、 下記 ページ の 「 View で 利用 する 場合 」 を 参照 下さい 。 \n  ・ 複合機（プリンタ） 設定 \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / pc / printer'},
#  {'id': '100007',
#   'title': '',
#   'text': '暗号化 ファイル の 解除 方法 に つい て は 、 下記 ページ を 参照 し て 下さい 。 \n\n ・ 暗号化 ファイル の 解除 \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / setting / AzureRMS / rights / unlock'},
#  {'id': '100008',
#   'title': '',
#   'text': 'EUC の 問合せ に つい て は 、 OA サポート デスク で は サポート 対象外 と なり ます 。 \n 下記 窓口 が 担当 か と 思わ れ ます の で 、 直接 問合せ 願い ます 。 \n\n ・ SB C&S   サービス デスク \n  https : / / softbankcs . service - now . com / csqa ? id = casoa _ index'},
#  {'id': '100009',
#   'title': '',
#   'text': '部門 PC を 社内 NW （ L 2 ） に 接続 する に は 、 準 OA 化 が 必要 と なり ます 。 \n  詳細 は 、 下記 サイト を ご覧 いただけ ます でしょう か 。 \n \n ・ 購入 に つい て   ※ 準 OAPC の 要件 を ご 確認 下さい 。 \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / request / purchase \n \n ・ 準 OA 化 \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / request / semioapc'},
#  {'id': '100010',
#   'title': '',
#   'text': 'ブラウザ の キャッシュ クリア に つい て は 、 下記 手順 を 実施 し て 下さい 。 \n\n ■ Windows   \n ● Chrome の キャッシュ クリア \n  1 . Google Chrome の ブラウザ を 終了 する 。 \n  2 . 下記 に アクセス し 【 Cach . bat 】 を コピー し 、 デスクトップ に 貼り付ける \n   https : / / drive . google . com / drive / folders / 1 XmkYaUoTWsYq - sOmC 6 XCuewUILBYINxW \n  3 ． コピー し た 【 Cache . bat 】 を 実行 する \n  4 . 再度 、 Google Chrome の ブラウザ を 起動 する \n\n ■ Mac \n ● Chrome の キャッシュ クリア \n 1 . command キー ＋ Y キー を 同時 押下 する \n 2 . 「 閲覧 履歴 データ を 消去 する 」 を クリック する \n 3 . 以下 を 設定 する \n\u3000 期間 ⇒ 全 期間 \n\u3000 詳細 ⇒ 閲覧 履歴 \n\u3000\u3000\u3000\u3000 ダウンロード 履歴 \n\u3000\u3000\u3000\u3000 Cookie と 他 の サイト データ \n\u3000\u3000\u3000\u3000 キャッシュ さ れ た 画像 と ファイル \n\u3000\u3000\u3000\u3000 に チェック を 入れる \n\u3000 「 データ を 消去 」 を クリック する \n 4 . command キー ＋ Q キー を 同時 押下 し 、 Chrome を 終了 さ せる \n ● Safari の キャッシュ クリア \n 1 . 画面 上部 の 履歴 > すべて の 履歴 を 表示 する を クリック する \n 2 . 履歴 を 消去 . . . ＞ 消去 の 対象 ： 全て の 履歴 ＞ 履歴 を 消去 を クリック する \n 3 . command キー ＋ Q キー を 同時 押下 し 、 Safari を 終了 さ せる'},
#  {'id': '100011',
#   'title': '',
#   'text': 'CI 検索 ツール に つい て は 、 Chrome の 拡張 機能 と なり ます の で 、 下記 マニュアル を 参照 し て 下さい 。 \n \n  ● Chrome 拡張 機能 一覧 \n https : / / sites . google . com / a / g . softbank .co.jp / helpg / chrome - extension \n 「 CI   Tools   ( by   CITeam ) 」 を インストール する と 組織 メーリング リスト 、 組織 メーリング リスト 、 OA アカウント （ エイリアス ） 等 を 検索 でき ます 。 \n\n ■ 検索 方法 \n ・ グループ アドレス 検索 \n Chrome ブラウザ 上 の 右上 の 黒い 淵 で 四角い 「 a 」 の 文字 が 書か れ て いる ロゴ を クリック ＞ ■ グループ 検索 にて グループ アドレス を 入力 \n ・ GoogleApps ユーザー 検索 \n Chrome ブラウザ 上 の 右上 の 黒い 淵 で 四角い 「 a 」 の 文字 が 書か れ て いる ロゴ を クリック ＞ ■ Google   Apps ユーザー 検索 にて OA アカウント （ エイリアス ） また は 氏名 を 入力'},
#  {'id': '100012',
#   'title': '',
#   'text': '業 端 B の 返却 に つい て は 手配 元 部門 に 返却 下さい 。 \n 返却 時 の 必要 な 対応 に つい て も 手配 元 部門 に 確認 下さい 。'},
#  {'id': '100013',
#   'title': '',
#   'text': 'W ドライブ 容量 に つい て は 、 50 GB と なり 、 容量 追加 に つい て は 、 不可 と なり ます 。   \n\n 現在 の 容量 で 足り ない 場合 は 、 使用 し て いる ファイル を 精査 し 、 容量 を 減らし て 下さい 。 \n また 、 共有 フォルダ 等 も 活用 し て 下さい 。'},
#  {'id': '100014',
#   'title': '',
#   'text': '機種 変更 等 で 移行 でき ない 連絡先 が ある 場合 、 下記 ページ を 参照 し 、 連絡先 の 移行 を 実施 下さい 。 \n ※ 回線 切り替え が ある 場合 、 回線 切り替え 後 に 作業 し て 下さい \n\n ・ Gmail アカウント 同期 で 移行 でき ない 連絡先 の 移行 \u3000 マニュアル \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / ansinBackup 2 \n ※ MySoftBank の パスワード を 忘れ た 場合 、 上記 ページ の 「 4 .   MySoftbank 認証 が でき ない 場合 」 を 確認 下さい'},
#  {'id': '100015',
#   'title': '',
#   'text': '共有 ドライブ 内 の ファイル が 削除 でき ない 場合 は 、 下記 に アクセス し 、 右上 の 虫眼鏡 から 下記 文言 で 検索 下さい 。 \n ・ Q . 05 - 016 \u3000 共有 ドライブ 内 の ファイル を 削除 する に は 、 どのような 権限 が 必要 です か ？ \n https : / / sites . google . com / a / g . softbank .co.jp / helpg / discussion - board / document / 05 - 016 \n ・ 05   -   Google ドライブ （ ドキュメント ） に 関する 質問   -   \n https : / / sites . google . com / a / g . softbank .co.jp / helpg / discussion - board / document'},
#  {'id': '100016',
#   'title': '',
#   'text': 'ワークス ペース から の サイン アウト と 退出 の 違い に つい て は 下記 と なり ます \n\n ▼ サイン アウト \n 対象 の ワークス ペース から サイン アウト だけ で 再度 SSO 認証 で サイン イン する こと が でき ます 。 \n サイン イン 方法 に つい て は 下記 ページ を 確認 下さい 。 \n\n ■ Windows \n ・ Windows 版 Slack マニュアル \n http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / request / oa - saas / slack / win - setup \n\n ■ Mac \n ・ Mac 版 Slack マニュアル \n http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / request / oa - saas / slack / mac - setup \n\n ■ iPhone / iPad \n ・ iPhone 版 Slack マニュアル \n http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / request / oa - saas / slack / iphone - setup \n\n ■ Android \n ・ Android 版 Slack マニュアル \n http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / request / oa - saas / slack / android - setup \n\n ▼ 退出 \n その ワークス ペース から 抜ける こと に なる ため 、 再 参加 は 不可 と なり ます 。 \n 再度 参加 が 必要 な 場合 は 、 ワークス ペース 管理者 から の 招待 が 必要 と なり ます の で 退出 は し ない 様 、 注意 下さい 。 \n 誤っ て 退出 し た 場合 は 下記 を 参照 の 上 、 対応 し て 下さい 。 \n\n ■ 組織 ワークス ペース から 退出 し た 場合 \n 該当 組織 ワークス ペース の 管理者 へ 再 招待 を 依頼 し て 下さい \n\n Slack 管理者 ・ アンバサダー 一覧 \n https : / / docs . google . com / spreadsheets / d / 1 xPsP 7 oLEk 4 Biwoexi 2 KT 6 aqXPzRsbLyj 5 iJy 1 VY 8 o 0 Y / edit # gid = 393065120 \n\n ■ 組織 ワークス ペース 以外 から 退出 し た 場合 \n 下記 情報 を 記載 の 上 、 WEB 投稿 で 問合せ し て 下さい \n\n ・ 氏名 ： \n ・ メール アドレス ： \n \n ・ OA   Support   Net \n http:// oa . bb . local / oasupport / inquiry _ web \n （ カテゴリ ： Slack ）'},
#  {'id': '100017',
#   'title': '',
#   'text': 'PDF の パスワード を 設定 し たい 場合 は 、 下記 手順 で パスワード を 設定 し て 下さい 。 \n  ・ AdobeAcrobat 等 編集 ソフト を 導入 する 方法 \n  ・ Zip ファイル に 圧縮 し て 圧縮 時 に パスワード を かける 方法 \n\n ■ AdobeAcrobat を 利用 する 場合 \n\u3000 下記 ページ より 利用 申請 を 行い 、 AdobeAcrobat を インストール し て 下さい 。 \n ・ Adobe   Acrobat   DC 利用 に つい て \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / AdobeAcrobatDC \n\n ■ Zip ファイル を 圧縮 し て 圧縮 時 に パスワード を 設定 する 場合 \n ● OAPC / 準 OAPC の 場合 \n\u3000 ソフトウェア センター より Lhaplus を インストール し て 下さい 。 \n\u3000 Lhaplus に つい て は 、 ソフトウェア センター から インストール を 実施 し て 下さい 。 \n\u3000 ・ 【 SCCM 】 Windows 向け ソフトウェア センター 利用 マニュアル \n\u3000  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / post / sccm _ win 10 \n ● View の 場合 \n\u3000 Lhaplus インストール 済み な の で 、 そのまま 利用 し て 下さい'},
#  {'id': '100018',
#   'title': '',
#   'text': 'Zoom ミーティング で イヤホン 利用 時 に イヤホン から 音声 が 聞こえ ない 場合 は 、 下記 設定 に なっ て いる か ご 確認 下さい 。 \n\n Zoom アプリ の 設定 ( 歯車 マーク ) ＞ オーディオ \n ＞ スピーカー 項目 の プルダウン から 「 ヘッドホン 」 を 選択'},
#  {'id': '100019',
#   'title': '',
#   'text': '共有 グループ の 管理者 を 確認 する 場合 は 、 下記 に ページ を 参照 下さい 。 \n ・ Q . 07 - 024 \u3000 グループ の 管理者 を 確認 する こと は でき ます か ？ \n https : / / sites . google . com / a / g . softbank .co.jp / helpg / discussion - board / group / 07 - 024 \n\n なお 、 ご自身 が メンバー に なっ て いる グループ に つい て は 以下 手順 で も 確認 でき ます 。 \n\n OA   Support   Navi に アクセス ＞ Mypage ＞ 詳細 情報 は こちら ＞ GoogleApps 情報 の 青い 人型 の アイコン から 管理者 の 確認 \n\n ・ OA   Support   Navi \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / \n\n 上記 手順 で 解決 し ない 場合 は 、 OA   Support   Net へ 下記 情報 を 記載 し 、 投稿 下さい 。 \n\n  ・ グループ アドレス の メール アドレス \n  ・ 表示 名 \n\n ・ OA   Support   Net \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / inquiry _ web \n （ カテゴリ ： GoogleApps )'},
#  {'id': '100020',
#   'title': '',
#   'text': '「 VPN サーバ と の ネゴシエーション に 失敗 し まし た 。 」 の エラー が 発生 し た 場合 は 、 VPN の 再 インストール を 試し て 下さい 。 \n\n ■ iPhone / iPad \n 1 ． 設定 ＞ 一般 ＞ VPN と デバイス 管理 より 下記 プロファイル を 削除 下さい \n ・ Cybertrust   DeviceiD ～ \n ・ iPhoneVPN ～ \n 2 ． 「 [ iPhone / iPad - VPN ] 証明書 発行 の お知らせ   IMEI   : ・ ・ ・ 」 メール に 記載 さ れ て いる 内容 に 従い 、 再 インストール を 実施 し て 下さい 。 \n\n ■ Android \n 下記 ページ を 参照 し 、 再 インストール し て 下さい 。 \n ・ 【 Android 】 VPN 設定 \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / android / androidvpn'},
#  {'id': '100021',
#   'title': '',
#   'text': 'ゲスト 管理 システム の 管理者 グループ に 紐 づく ゲスト 全員 を 別 の 管理者 グループ に 移行 し たい 場合 は 、 下記 手順 を 参照 下さい 。 \n\n ① ゲスト 管理 システム の ゲスト 新規 登録 画面 で 移行 先 管理者 グループ を 選択 し て 、 ゲスト 全員 分 の ゲスト 登録 と 利用 サービス の 新規 申請 を 実施 。 \n ② 「 【 ゲスト 管理 】 利用 サービスプロビジョニングエラー 対応 完了 通知 」 の 受信 を 確認 。 \n （ 申請 の 承認 完了 後 、 5 営業日 以内 に 移行 先 管理者 グループ メンバー 宛 に 届き ます ） \n ③ 移行 元 管理者 グループ に 紐 づく ゲスト 全員 の 削除 申請 を 実施 。 \n （ ゲスト 登録 と 利用 サービス 登録 の 有効 期限 を 短く し て 申請 し て 下さい ） \n ④ 削除 完了 後 （ 設定 し た 有効 期限 経過 後 ） 、 必要 に 応じ て 移行 元 管理者 グループ を 削除 。 \n\n なお 、 管理者 グループ は グループ 名 と メンバー 変更 が 可能 です 。 \n ゲスト を 移行 さ せる 必要 が ない 場合 は 、 グループ 名 や メンバー 変更 にて 対応 下さい 。 \n\n ゲスト 管理 システム の 操作 方法 は 下記 手順 を 参照 下さい 。 \n\n ・ 【 ゲスト 管理 システム 】 マニュアル - 申請者 向け \u3000 \n https : / / docs . google . com / presentation / d / 1 Z 0 PUkjNUr 9 r 2 GCq 5 ZEEddd 5 jPUJg 48 kPMsCxv 5 Mtw _ M / edit # slide = id . g 1345 deaa 28 b _ 0 _ 80 \n\n ・ ゲスト 管理 システム \n https : / / guest . in . g . softbank .co.jp / \n ※ 正社員 のみ 利用 可'},
#  {'id': '100022',
#   'title': '',
#   'text': 'Windows 端末 で 起動 時 に 「 BitLocker 」 が 表示 さ れ 、 回復 キー を 求め られ た 場合 は 、 下記 FAQ を 参照 し て 下さい 。 \n\n ■ L 2   OAPC / 準 OAPC \n ・ BitLocker の 画面 が 出 て PC に ログイン でき ない [ FAQ   No : F 170328001 ] \n http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / faq / f 170328001 \n\n フォーム 申請後 、 「 【 BitLocker 】 回復 キー 申請 」 の 件名 で メール が 自動 送信 さ れ 、 1 ～ 2 時間 程度 で 「 【 BitLocker 】 回復 キー 通知 」 の メール 件名 で 回復 キー の 通知 が 行わ れ ます 。 \n ※ 1 ～ 2 時間 経っ て も 回復 キー が 通知 さ れ ない 場合 は 、 担当 部署 に エスカレーション 致し ます の で 、 「 【 BitLocker 】 回復 キー 申請 」 の メール 内 に 記載 さ れ て いる 「 管理 番号 : BIT - * * * * * 」 と 該当 コンピューター 名 を 確認 の 上 、 OA サポート デスク へ 問合せ 下さい \n\n 社員 サポート センター （ ＯＡ サポート デスク ） ： 平日 9 : 00 ～ 18 : 00 \n ● Slack ： ＃ help - oa サポート （ チャンネル 名 で 検索 し て ください ） \n ● Ｗｅｂ 投稿 ： OA   Support   Navi   ＞   問合わせ   ＞   Web   http:// oa . bb . local / oasupport / inquiry _ web \n ● PC 受取 / 返却 ： OA   Support   Navi   ＞   問合わせ   ＞   PC 受取 / 返却   http:// oa . bb . local / oasupport / inquiry _ counter \n ● コール 予約 ： OA   Support   Navi   ＞   問合わせ   ＞   コール 予約 （ OA ）   http:// oa . bb . local / oasupport / oa - call - reservation \n\n なお 、 以下 の 事象 が 発生 し て いる 場合 は 、 端末 交換 と なり ます 。 \n ・ 回復 キー 入力 項目 が 表示 さ れ ない \n ・ 回復 キー が 発行 でき ない \n ・ 発行 さ れ た 回復 キー で 解除 でき ない \n\n ・ 【 IoTAM 】 PC 交換 申請 方法 \n http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / pc _ exchange \n ※ 解除 キー 入力 不可 の 場合 、 データ 復元 は 不可 と なり ます \n\n ■ L 3 DevPC / 準 L 3 DevPC \n 下記 マニュアル の 1 - 9 記載 の 通り 、 自身 で 任意 の 場所 に 保存 し て いる の で そちら を 確認 下さい 。 \n ・ 【 L 3 Dev 】 HDD 暗号化 （ Windows 、 Mac ） \n http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / manual / l 3 dev _ encryption \n ※ OA サポート で は 対応 不可 と なり ます'},
#  {'id': '100023',
#   'title': '',
#   'text': '業 端 A の iPhone で 4 G   /   5 G 経由 で の 通信 が でき ない 時 、 以下 の FAQ を 参照 し て 下さい 。 \n\n ・ 【 業 端 A 】 iPhone で 4 G   /   5 G 経由 で の 通信 が 出来 ない [ FAQ   No : F 170526021 ] \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / keitai / faq _ list _ ios / f 170526021 \n\n 上記 FAQ で 改善 し ない 場合 、 Web 投稿 より 問合せ 下さい 。 \n ・ Web \n  http:// oa . bb . local / oasupport / inquiry _ web \n （ カテゴリ ： iPhoneiPad ）'},
#  {'id': '100024',
#   'title': '',
#   'text': '業 端 A   iPhone / iPad で MDM 設定 時 「 プロファイル の インストール が でき ませ ん でし た 」 が 表示 さ れ た 場合 は 下記 FAQ の 内容 を 実施 下さい 。 \n\n ・ MDM 設定 時 に エラー が 発生 する [ FAQ   No : F 210310001 ] \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / faq / f 210310001 \n\n 改善 し ない 場合 は 、 必要 事項 を 確認 の 上 、 担当 部署 に エスカレーション 致し ます の で 、 OA サポート デスク へ 問合せ 下さい 。 \n ■ 必要 事項 \n ・ 対象 機種 \n ・ IMEI \n\n 社員 サポート センター （ ＯＡ サポート デスク ） ： 平日 9 : 00 ～ 18 : 00 \n ● Slack ： ＃ help - oa サポート （ チャンネル 名 で 検索 し て ください ） \n ● Ｗｅｂ 投稿 ： OA   Support   Navi   ＞   問合わせ   ＞   Web （ http:// oa . bb . local / oasupport / inquiry _ web ） \n ● リモート サポート ： OA   Support   Navi   ＞   問合わせ   ＞   リモート / PC 受取 ・ 返却 （ http:// oa . bb . local / oasupport / inquiry _ counter ） \n ● コール 予約 ： OA   Support   Navi   ＞   問合わせ   ＞   コール 予約 （ OA ） （ http:// oa . bb . local / oasupport / oa - call - reservation ）'},
#  {'id': '100025',
#   'title': '',
#   'text': '「 文書 の 取り出し が でき ませ ん でし た 」 と 表示 さ れ 、 ゼロックス 機 の 親展 ボックス から スキャン データ の 取り出し が でき ない 場合 に は 、 以下 設定 変更 を し て 下さい 。 \n\n 1 . Windwows キー ＋ R キー を 同時 押下 し 、 ファイル 名 を 指定 し て 実行 に 「 inetcpl . cpl 」 を 入力 し 、 Enter キー を 押下 する 。 \n 2 . インターネット の プロパティ 画面 が 表示 さ れ たら 、 詳細 設定 タブ を クリック し 、 【 HTTP   1.1 を 使用 する 】 に チェック を 入れる 。'},
#  {'id': '100026',
#   'title': '',
#   'text': 'ソリューション 販売 管理 システム （ イントラマート ） （ 物販 系 ） の 問合せ に つい て は 、 OA サポート デスク で は サポート 対象外 と なり ます 。 \n 下記 窓口 が 担当 か と 思わ れ ます の で 、 直接 問合せ 願い ます 。 \n\n ・ 仕入 販売 （ 開発 ・ 運転 担当 ） \n  SBTMGRP - SHIIRE - OP @ g . softbank .co.jp'},
#  {'id': '100027',
#   'title': '',
#   'text': 'Google の グループ アドレス の 不在 通知 設定 に つい て グループ アドレス に 不在 通知 を 設定 する こと は でき ませ ん 。 \n 不在 通知 は アカウント で の 設定 項目 と なり 、 グループ アドレス は アカウント と は 異なり ます の で 、 不在 通知 を 設定 する こと は でき ませ ん 。'},
#  {'id': '100028',
#   'title': '',
#   'text': 'Fruits   /   VoiceNet の 問合せ に つい て は 、 OA サポート デスク で は サポート 対象外 と なり ます 。 \n 下記 窓口 が 担当 か と 思わ れ ます の で 、 直接 問合せ 願い ます 。 \n\n ・ Ｆｒｕｉｔｓ ／ Ｖｏｉｃｅｎｅｔ 運転 担当   \n  sbtmgrp - unyou _ fruits @ g . softbank .co.jp'},
#  {'id': '100029',
#   'title': '',
#   'text': '業 端 へ の アプリ の 配信 や 提供 方法 に つい て は 、 下記 より 問合せ 下さい 。 \n ・ Web 投稿 \n\u3000 http:// oa . bb . local / oasupport / inquiry _ web \n\u3000 カテゴリ ： iPhoneiPad \n\u3000\u3000\u3000\u3000\u3000\u3000 Android'},
#  {'id': '100030',
#   'title': '',
#   'text': '「 この 不明 な 発行元 から の アプリ が PC に 変更 を 加える こと を 許可 し ます か ？ 」 が 表示 さ れ た 場合 、 管理者 権限 が 必要 と なり ます 。 \n\n 下記 ページ を 参照 し 、 Admin 権限 を 取得 し て 下さい 。 \n ・ 【 社内外 共通 】 L 2 OAPC / 準 OAPC   Admin 権限 申請 ・ 適用 方法 \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / admintekiyou _ shanaigai'},
#  {'id': '100031',
#   'title': '',
#   'text': '業 端 A   iPhone / iPad / Android で yellow に 接続 でき ない 場合 は 、 下記 FAQ を 参照 下さい 。 \n ■ iPhone / iPad \n ・ 【 iPhone / iPad 】 yellow に 繋がら ない [ FAQ   No : F 171201002 ] \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / keitai / faq _ list _ ios / f 171201002 \n ■ Android \n ・ 【 Android 】 yellow に 繋がら ない [ FAQ   No : F 190320001 ] \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / keitai / faq _ list _ android / f 190320001'},
#  {'id': '100032',
#   'title': '',
#   'text': 'Adobe   Reader の インストール ・ バージョン アップ 方法 に つい て は 、 下記 ページ を 参照 下さい 。 \n ・ Adobe   Reader インストール ・ バージョン アップ 手順 \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / AdobeReader _ setting \n\n PDF ファイル へ の アプリケーション 関連付け 方法 に つい て は 、 下記 手順 を 実施 下さい 。 \n 1 . スタート ＞ 設定 （ 歯車 マーク ） ＞ アプリ ＞ 既定 の アプリ \u3000 の 順 に 起動 する \n 2 . 既定 の アプリ の 選択 画面 で 一番 下 に ある 「 ファイル の 種類 ごと に 既定 の アプリ を 選ぶ 」 を クリック し 、 「 . pdf 」 の 項目 を クリック し 「 Adobe   Acrobat   Reader 」 を 選択 する'},
#  {'id': '100033',
#   'title': '',
#   'text': 'OA サポート デスク 貸出 の VGA 変換 アダプタ を 紛失 し た 場合 は 、 OA サポート デスク まで 問合せ 下さい 。 \n\n 社員 サポート センター （ ＯＡ サポート デスク ） ： 平日 9 : 00 ～ 18 : 00 \n ● Slack ： ＃ help - oa サポート （ チャンネル 名 で 検索 し て ください ） \n ● Ｗｅｂ 投稿 ： OA   Support   Navi   ＞   問合わせ   ＞   Web   http:// oa . bb . local / oasupport / inquiry _ web \n ● PC 受取 / 返却 ： OA   Support   Navi   ＞   問合わせ   ＞   PC 受取 / 返却   http:// oa . bb . local / oasupport / inquiry _ counter \n ● コール 予約 ： OA   Support   Navi   ＞   問合わせ   ＞   コール 予約 （ OA ）   http:// oa . bb . local / oasupport / oa - call - reservation'},
#  {'id': '100034',
#   'title': '',
#   'text': 'OAPC / 準 OAPC / Mac の 利用者 変更 に つい て は 、 下記 ページ を 参照 し て 下さい 。 \n\n ・ 利用者 を 変更 し たい \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / pc / tourokuhenkou \n ※ システム の 仕様 上 、 一括 利用者 変更 機能 は ござい ませ ん の で 、 1 台 ずつ 利用者 変更 申請 を 行っ て 下さい 。 \n ※ OA 化 し て い ない 部門 PC に つい て は 、 部門 で の 管理 と なり ます \n ※ 上長 承認 後 、 即時 で 反映 さ れ ます （ 社内 ネットワーク に は 上長 承認 完了 後 から 約 30 分 で 利用 可能 に なり ます ） \n\n 以下 に つい て は 、 利用者 変更 を 実施 し ない と 社内 ネットワーク へ 接続 でき なく なり ます 。 \n 必ず 利用者 変更 を 実施 し て 下さい 。 \n ・ 雇用 形態 が 変更 と なり 共通 社員 番号 が 変更 に なっ た 方 に 紐づい て いる OAPC および 準 OAPC \n ・ 退職 さ れ た 方 に 紐 付い て い た OAPC および 準 OAPC \n ・ 退職 さ れ た 方 に 紐 付い て い た OAPC および 準 OAPC を 新規 入場者 が 再利用 する 場合'},
#  {'id': '100035',
#   'title': '',
#   'text': '部門 管理 PC にて 外部 記録 媒体 を 使用 する 場合 は ライセンス 管理 システム で の USB 申請 は 不要 と なり ます 。'},
#  {'id': '100036',
#   'title': '',
#   'text': 'RDS ログイン 後 、 アイコン が 表示 さ れ ない 場合 は 、 利用 申請 が さ れ て おり ませ ん 。 \n\n RDS を 利用 する 場合 は 、 下記 フォーム より 申請 し て 下さい 。 \n ・ RDS 払い出し 申請 フォーム \n  https : / / docs . google . com / a / g . softbank .co.jp / forms / d / e / 1 FAIpQLSe 6 fVPdhMG - 4 DRCLgEzQlt - MZsyyGQ 34 bGh 55 bdzIErCR _ QPA / viewform \n ※ 払い出し が 完了 する と 申請者 に 対し て 、 メール 件名 ： 「 【 必読 】 RDS 環境 に 関する 重要 」 が 送付 さ れ ます'},
#  {'id': '100037',
#   'title': '',
#   'text': 'Office ファイル 起動 時 、 「 サブスクリプション の 有効 期限 が 切れ て い ます 。 」 が 表示 さ れ た 場合 は 下記 ページ を 参照 し 、 再 認証 を 実施 下さい 。 \n ・ 【 Office 365 】 Office 365 起動 時 に よく ある 認証 エラー \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / % 3 Fpost _ type % 3 Dpost % 26 p % 3 D 40418'},
#  {'id': '100038',
#   'title': '',
#   'text': '業 端 B の MySoftBank の 暗証 番号 は 下記 ページ を 参照 下さい 。 \n ・ 回線 停止 方法 \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / keitai / keitai - a / rule / rimotowaipu / linestop \n\u3000 （ 「 暗証 番号 」 参照 ） \n\n 記載 さ れ た 暗証 番号 で 認証 でき ない 場合 は は 下記 ページ を 参照 し 、 福岡 BizSupport へ 問合せ 下さい 。 \n ・ 業務用 携帯 電話 B の サービス 内容 変更 を し たい \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / keitai / keitai - b / information'},
#  {'id': '100039',
#   'title': '',
#   'text': '準 OAPC に つい て は 、 部門 で 購入 し 、 OA 化 し た もの と なり ます の で 、 OA 側 から の 貸与 は ござい ませ ん 。 \n \n  準 OAPC が 必要 な 場合 は 下記 を 参照 し 、 部署 で 端末 購入 後 、 OA 化 し て 下さい 。 \n ・ PC を 購入 し たい \n  http:// oa . bb . local / oasupport / pc / pc _ buy'},
#  {'id': '100040',
#   'title': '',
#   'text': '「 現在 ログオン 要求 を 処理 できる ログオン サーバー は あり ませ ん 。 」 また は 、 「 ドメイン が 利用 でき ない ため 、 この 資格 情報 で は サイン イン でき ませ ん 。 」 が 表示 さ れ た 場合 は 、 下記 を 確認 し て 下さい 。 \n \n ・ 端末 に L 2 の 有線 LAN は 接続 し て い ます か ？ \n ※ 情報 コンセント に は L 2 用 ・ L 3 Dev 用 が あり ます の で 、 ご 注意 下さい 。 \n ・ 無線 LAN   Blue に は 接続 し て い ます か ？ \n ・ LAN ケーブル を 交換 し て も ログイン 不可 か ？ \n ・ NW 接続 可能 な 他 の 端末 で 利用 し て いる LAN ケーブル を 利用 し て も 接続 不可 か ？ \n ※ OA カウンター で 端末 交換 し た 場合 、 交換 後 から 15 分 以上 経過 し ない と ログオン でき ませ ん 。 \n\n また 、 退職 さ れ た 方 の 端末 を 新規 入場者 が 利用 する 場合 は 、 利用者 変更 が 必要 と なり ます 。 \n 利用者 変更 に つい て は 、 下記 より 実施 し て 下さい 。 \n\n ・ Service   Catalog \n  http:// iotam . bb . local / OAService / catalog / pc \n （ 「 利用者 変更 」 から 申請 し て 下さい ） \n 利用者 変更 申請 完了 後 、 下記 件名 の メール が 旧 利用者 、 新 利用者 、 新 利用者 の 上長 宛 に 送付 さ れ ます 。 \n メール 件名 ： 【 申請 完了 】 利用者 変更   RA * * * * * * * * * * \n\n 申請 完了 後 、 約 15 分 後 に NW に 接続 可能 と なり ます 。 \n 15 分 後 も 接続 不可 の 場合 は 、 一度 、 端末 再起動 後 に 接続 を お 試し 下さい 。 \n\n 参考 FAQ \n ・ ログイン時 に 「 現在 ログオン 要求 を サービス する ログオン   サーバー が あり ませ ん 」 が 表示 さ れ ログイン が でき ない [ FAQ   No : F 190521001 ] \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / faq / f 190521001'},
#  {'id': '100041',
#   'title': '',
#   'text': '3 社 以上 と コネクト し て いる 共有 チャンネル から 特定 の 会社 のみ コネクト を 切り離し たい 場合 は 、 切り離し たい 会社 のみ を 記載 の 上 、 共有 チャンネル 停止 申請 を 実施 ください 。 \n\n ・ Slack 共有 チャンネル 停止 申請 \n https : / / docs . google . com / forms / d / e / 1 FAIpQLSfUh - HmNZzYIY 6 D _ zrpI 91 Q 1 oEh 3 G 2 FnUZpnjzWIsrtSpdgfw / viewform \n ※ SB ゲスト ・ ConnectWS で 利用 し て いる 共有 チャンネル の 場合 \n\n ・ SB   SlackConnect ( 特定 会社 専用 )   チャンネル 停止 申請 \n https : / / docs . google . com / forms / d / e / 1 FAIpQLSfO 1 cJ 2 I _ _ 8 UEpHMntPerYqKg 3 QO 1 aaWEX 9 b 6 IFiUvxtjzPIw / viewform \n ※ SB   SlackConnect ( 特定 会社 専用 )   WS で 利用 し て いる 共有 チャンネル の 場合'},
#  {'id': '100042',
#   'title': '',
#   'text': 'Office ソフト 修復 方法 に つい て は 、 下記 FAQ を 参照 し 、 Office の 再 インストール を 実施 し て 下さい 。 \n ・ Office の 再 インストール 方法 を 教え て 下さい [ FAQ   No : F 170922001 ] \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / faq / f 170922001'},
#  {'id': '100043',
#   'title': '',
#   'text': '※ 2021 / 11 / 25 より 正社員 以外 （ 販売 契約 社員 は 除く ） も Office 365 の 利用 が 可能 に なっ て い ます \n\u3000 詳細 に つい て は 下記 ページ を 参照 下さい \n\u3000 ・ 正社員 以外 の Office 365 利用 に つい て \n\u3000\u3000 http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / office 365 _ non - regularemployees \n\n 正社員 以外 の Office 利用 に つい て は 下記 ページ を 参照 下さい 。 \n ・ 正社員 以外 の Office 365 利用 に つい て \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / office 365 _ non - regularemployees \n\n 販売 契約 社員 に つい て は 下記 ページ を 参照 下さい 。 \n ・ 【 販売 契約 社員 】 Office 利用 方法 \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / setting / AzureRMS / windows / non _ regular'},
#  {'id': '100044',
#   'title': '',
#   'text': '退職時 の 共有 ドライブ 内 の ファイル に つい て は 、 下記 に アクセス し 、 右上 の 虫眼鏡 から 下記 文言 で 検索 下さい 。 \n ・ Q . 05 - 018 \u3000 退職時 、 共有 ドライブ 内 の ファイル は どう なり ます か ？ \n https : / / sites . google . com / a / g . softbank .co.jp / helpg / discussion - board / document / 05 - 018 \n ・ 05   -   Google ドライブ （ ドキュメント ） に 関する 質問   -   \n https : / / sites . google . com / a / g . softbank .co.jp / helpg / discussion - board / document'},
#  {'id': '100045',
#   'title': '',
#   'text': 'フォルダ 利用率 の 確認 方法 に つい て は 、 FALCON システム の 管理 フォルダ 一覧 画面 で フォルダ 名 検索 を 実行 する と 、 検索 結果 表示 画面 にて 、 フォルダ 利用率 が 表示 さ れ ます 。 \n ※ 利用率 は 毎日 AM 3 時 前後 時点 の 取得 情報 と なり ます 。 \n\n ・ FS フォルダ 作成 ・ 権限 管理 ／ FALCON \n  http:// falcon / \n\n 参考 FAQ \n ・ フォルダ 利用率 を 調べ たい [ FAQ   No : F 170626012 ] \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / faq / f 170626012'},
#  {'id': '100046',
#   'title': '',
#   'text': 'Mac また は 業務 端末 から シングル サイン オン （ SSO ） でき ない 場合 は 、 下記 FAQ を 参照 し て 下さい 。 \n\n ・ シングル サイン オン （ SSO ） の ログイン 画面 で 、 FAT 端末 から は ログイン できる の に Mac や 業務用 携帯 電話 から は ログイン でき ない ［ FAQ   No ： F 000200014 ］ \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / keitai / F 000200014'},
#  {'id': '100047',
#   'title': '',
#   'text': '開発 DaaS 利用 時 の マルチ ディスプレイ 表示 方法 に つい て は 、 下記 ページ を 参照 下さい 。 \n ・ 開発 DaaS 利用 時 の マルチ ディスプレイ 表示 方法 \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / l 3 dev _ multi - display'},
#  {'id': '100048',
#   'title': '',
#   'text': 'Zoom アカウント 自動 払出 対象者 は 以下 範囲 です 。 \n 所属 会社 ： SBKK \n 社員 区分 ：   役員 、 従業員 兼務 役員 、 執行 役員 （ 委任 型 ） 、 顧問 、 正社員 、 準社員 、 嘱託 、 特別 嘱託 、 契約 社員 、 特定 臨時 社員 、 受入 出向 社員 \n 本務 兼務 区分 ： SBKK 本務 （ SBKK 本務 のみ 対象 ） \n\n アカウント は 入社日 また は 発令日 の 翌日 まで に 払出 さ れ ます ( 申請 不要 )'},
#  {'id': '100049',
#   'title': '',
#   'text': '現在 、 OAMac 化 可能 な 対象 OS に つい て は 、 下記 ページ を 参照 し て 下さい 。 \n\n ・ OA 化 可能 な OS に つい て \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / mac / os - version'},
#  {'id': '100050',
#   'title': '',
#   'text': 'Gmail 上 で 下記 の メッセージ が 表示 さ れ た 場合 は 、 FAQ を 参照 し て 下さい 。 \n\n メッセージ \n 「 この メール に は ご 注意 下さい \u3000 ウィルス や 悪質 な リンク が 含ま れ て いる 可能性 が あり ます 」 \n 「 ウィルス の 警告   –   XX 個 の 添付 ファイル に ウィルス また は ブロック さ れ た ファイル が 含ま れ て い ます 」 \n\n ・ Gmail で ウイルス 検知 の メッセージ が 表示 さ れる [ FAQ   No : F 180529002 ] \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / faq / f 180529002'},
#  {'id': '100051',
#   'title': '',
#   'text': 'Admin 権限 申請 が 否認 さ れ た 場合 、 まず は 下記 を ご 確認 下さい 。 \n\n ・ Admin 権限 付与 時間 まで に 上長 の 承認 は 完了 し て い た か ？ \n ・ コンピューター 名 に OAPC （ CXOAPC ） / 準 OAPC （ CXIRPC ） 以外 の コンピューター 名 を 入力 し て い ない か ？ \n ・ コンピューター 名 に View の コンピューター 名 を 入力 し て い ない か ？ \n → 例 ： CXVIEW * * * * * * * * \n ・ 準 OAPC で インベントリ ファイル アップロード 直後 に Admin 権限 申請 を 行っ て い ない か ？ \n → インベントリ ファイル アップロード 直後 は PureTerminal 側 に 情報 が 登録 さ れ て い ない の で 、 申請 を 行う こと が でき ませ ん 。 \n\u3000 インベントリ ファイル アップロード し た 翌営業日 以降 に 申請 可能 と なり ます 。'},
#  {'id': '100052',
#   'title': '',
#   'text': 'FATPC 上 で 音声 が 出力 でき ない 場合 は 以下 手順 を 実施 し て 下さい 。 \n\n OAPC （ CXOAPC ～ ） の 場合 \n ■ スピーカー の 音量 設定 \n 1 . 画面 右下 の スピーカー アイコン を クリック する 。 \n 2 . 音量 を 調整 し 、 音声 が 出力 さ れる か 確認 する 。 \n\n ■ キーボード ・ ボタン 操作 で の 音声 出力 設定 \n\u3000 各 メーカー に より 異なり ます の で 、 下記 を 確認 し て 下さい 。 \n ・ Lenovo \n → キーボード Fn + F 1 キー 押下 もしくは F 1 キー 押下 で ON / OFF 設定 \n ※ 準 OAPC （ CXIRPC ～ ） の 場合 は 各 メーカー に 直接 確認 下さい \n\n ■ Web ブラウザ の 音声 が 出力 さ れ ない 場合 \n 1 . Windows キー + R キー 同時 押下 し ファイル 名 を 指定 し て 実行 を 起動 し て 「 inetcpl . cpl 」 を 入力 し 、 OK を クリック する 。 \n 2 . 詳細 設定 タブ を クリック し 、 マルチメディア の 項目 に ある 「 Web ページ の サウンド を 再生 する 」 に チェック を 入れ 、 OK を クリック する 。 \n\n ■ サウンド ドライバー 再 インストール \n\u3000 Admin 権限 を 取得 の 上 、 サウンド ドライバー を 再 インストール し て 下さい 。 \n ・ 【 社内外 共通 】 L 2 OAPC / 準 OAPC   Admin 権限 申請 ・ 適用 方法 \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / admintekiyou _ shanaigai \n  ドライバー ダウンロード 先 に つい て は 、 各 メーカー の ホームページ を 参照 し て 下さい 。 \n ・ Lenovo \n  https : / / support . lenovo . com / jp / ja / solutions / ht 100199 \n ※ 準 OAPC （ CXIRPC ～ ） の 場合 は 各 メーカー に 直接 確認 下さい \n\n 上記 手順 で 改善 し ない 場合 は 、 端末 交換 と なり ます の で 、 PC 管理 システム より 申請 し て 下さい 。 \n ・ 【 IoTAM 】 PC 交換 申請 方法 \n http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / pc _ exchange \n ※ 準 OAPC （ CXIRPC ～ ） の 場合 は 上記 手順 を 実施 し 、 改善 でき ない 場合 は 、 各 メーカー に 直接 確認 下さい'},
#  {'id': '100053',
#   'title': '',
#   'text': 'RDS の 利用 申請 方法 に つい て は 、 下記 フォーム より 申請 し て 下さい 。 \n\n ・ RDS 払い出し 申請 フォーム \n  https : / / docs . google . com / forms / d / e / 1 FAIpQLSe 6 fVPdhMG - 4 DRCLgEzQlt - MZsyyGQ 34 bGh 55 bdzIErCR _ QPA / viewform \n ※ 払い出し が 完了 する と 申請者 に 対し て 、 メール 件名 ： 「 【 必読 】 RDS 環境 に 関する 重要 」 が 送付 さ れ ます \n\n 参考 ページ \n ・ 貸出 ・ 返却 ・ 利用者 変更 \n （ Horizon   View （ 正社員 以外 ） ページ の こちら の リンク を 参照 下さい \u3000 を クリック ）'},
#  {'id': '100054',
#   'title': '',
#   'text': 'OAPC 等 を 利用 し 、 社外 ・ 自宅 から View を 利用 する 場合 は 、 下記 ページ を 参照 し て 下さい 。 \n ※ View の 利用 に は 事前 に Tarte にて 権限 申請 が 必要 と なり ます \n\u3000 未申請 の 場合 は 下記 ページ を 参照 し 、 申請 を 行っ て 下さい \u3000 \n\u3000 ・ Horizon   View \n\u3000\u3000 http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / setup / View \n\u3000\u3000 （ 上長 承認 の 翌日 以降 に 利用 可能 と なり ます ） \n\n ■ OAPC / 準 OAPC \n ・ View 接続 方法 （ OAPC   社外 接続 編 ） \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / % 3 Fpost _ type % 3 Dpost % 26 p % 3 D 22174 \n\n ■ OAPC / 準 OAPC 以外 \n ・ View 接続 方法 （ Windows   PC （ OAPC 以外 ） 編 ） \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / % 3 Fpost _ type % 3 Dpost % 26 p % 3 D 22175 \n\n ■ OAMac \n ・ View 接続 方法 （ Mac （ OAMac ） 編 ） \n  http:// oa . bb . local / oasupport / manual / mac - viewkankyou - kyoutsuuriyou \n\n ■ OAMac 以外 \n ・ View 接続 方法 （ Mac （ OAMac 以外 ） 編 ） \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / % 3 Fpost _ type % 3 Dpost % 26 p % 3 D 48797 \n\n ※ 社外 NW 自体 の 設定 ・ 接続 不具合 に つい て は 、 OA サポート 外 と なり ます 。'},
#  {'id': '100055',
#   'title': '',
#   'text': 'AzureRMS の アップグレード ツール （ AzureRMSCheck . vbs ） に つい て は 、 下記 に 格納 さ れ て おり ます の で 、 ダウンロード 後 、 デスクトップ 等 に 保存 し て から 実施 し て 下さい 。 \n https : / / drive . google . com / drive / folders / 1St 7 hIbiPsWO 5 vXkqn - IBoNXO 2 TgmTTe 8'},
#  {'id': '100056',
#   'title': '',
#   'text': '採用 Dr   （ 採用 ドクター ） の 問合せ に つい て は 、 OA サポート デスク で は サポート 対象外 と なり ます 。 \n 下記 窓口 が 担当 か と 思わ れ ます の で 、 直接 問合せ 願い ます 。 \n\n ・ クルー 採用 共有 \n  SBBGRP - salesstaffrecruitment @ g . softbank .co.jp'},
#  {'id': '100057',
#   'title': '',
#   'text': '「 メモリ エラー 」 が 表示 さ れ た 場合 は 、 下記 手順 で 事象 が 改善 する か 確認 し て 下さい 。   \n\n 【 OAPC ・ 準 OAPC 】   \n ■ Chrome の キャッシュ クリア \n ・ 【 Google Chrome 】 キャッシュ クリア 方法 \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / chrome _ clearcache \n ■ 不要 な ファイル 削除   \n 1 . 下記 に アクセス し 、 【 ローカル データ 削除 . bat 】 を コピー し 、 デスクトップ 等 に 保存 する \n\u3000 https : / / drive . google . com / drive / folders / 1 Clpw 778 o 4 MOo - Z 0 FVYEYIe 1 hUJ 3 aNU 3 h \n 2 . 【 ローカル データ 削除 . bat 】 を ダブル クリック する 。 （ コマンド プロンプト の 画面 が 一瞬 出力 さ れ ます ） \n 3 . ごみ箱 を 右 クリック し 、 「 ごみ箱 を 空 に する 」 を 実施 する \n\n 【 OAMac 】 \n ■ Chrome の キャッシュ クリア \n ・ 【 Google Chrome 】 キャッシュ クリア 方法 \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / chrome _ clearcache \n ※ 「 3 . 【 Mac 】 キャッシュ クリア （ 手動 ） 」 参照 \n\n 【 View 】 \n Chrome の キャッシュ クリア 後 、 View 環境 から サイン アウト し て 下さい 。 \n ・ 【 Google Chrome 】 キャッシュ クリア 方法 \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / chrome _ clearcache \n ・ View 環境 サイン アウト 手順 \n Windows マーク ＞ 人型 マーク に カーソル を 合わせ 、 「 サイン アウト 」 を クリック する \n ※ 「 切断 」 で は サイン アウト さ れ ない の で 、 必ず 上記 手順 を 実施 下さい'},
#  {'id': '100058',
#   'title': '',
#   'text': 'ブルー バック （ ブルー スクリーン ） ・ ホワイト アウト ・ ブラック アウト ・ フリーズ ・ 突然 の 電源 断 が 発生 する 場合 は 、 一度 、 電源 ボタン を 長押し 、 再度 、 電源 投入 後 、 症状 が 解消 する か 確認 し て 下さい 。 \n\n 参考 FAQ \n ・ 端末 が 固まる ・ 遅い 場合 の 対処 方法 を 知り たい ［ FAQ   No ： F 000200010 ］ \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / faq / F 000200010 \n ・ ThinkPadL 13 の PC で スリープ から の 復旧 時 に 強制 再起動 ・ ブルー バック が 発生 する ［ FAQ   No ： F 210527001 ］ \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / faq / f 210527001 \n\n 解消 し ない また は 頻発 する 場合 は 、 故障 と なり ます の で 、 以下 を 実施 下さい 。 \n ■ OAPC \n\u3000 端末 交換 を 実施 下さい 。 \n ・ 【 IoTAM 】 PC 交換 申請 方法 \n http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / pc _ exchange \n ■ 準 OAPC \n\u3000 端末 故障 と なり ます の で 、 下記 を 参照 し 、 対応 下さい 。 \n ・ 準 OAPC が 故障 し て しまっ た の で 、 修理 し たい [ FAQ   No : F 191105002 ] \n http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / faq / f 191105002'},
#  {'id': '100059',
#   'title': '',
#   'text': 'ネットワーク 管理 GIS の 問合せ先 に つい て は 、 OA サポート デスク で は サポート 対象外 と なり ます 。 \n 下記 窓口 が 担当 か と 思わ れ ます の で 、 直接 問合せ 願い ます 。 \n\n ・ ＮＷ 本部 情報 推進 室 ＧＩＳ 管理 \n  SBBGRP - GIS @ g . softbank .co.jp'},
#  {'id': '100060',
#   'title': '',
#   'text': '速度 制限 の 解除 方法 に つい て は 、 下記 を 参照 下さい 。 \n\n ■ 業 端 A \n 2021 年 10 月 現在 、 業 端 A で は 速度 制限 は 実施 し て おら ず 、 データ 容量 は 自動 追加 プラン と なっ て おり ます 。 \n\n ■ 業 端 B \n 制限 解除 方法 は 契約者 タイプ コード （ 契約 形態 ： 個人 ・ 法人 ・ 業務用 ） に より 、 方法 が 異なり ます 。 \n ・ 個人 ： My   SoftBank から の 手続き か 福岡 Biz へ の 依頼 \n ・ 法人 ： 法人 コンシェルサイト から の 手続き か 福岡 Biz へ の 依頼 \n ・ 業務用 ： My   SoftBank から の 手続き か 福岡 Biz へ の 依頼 \n 下記 ページ を 参照 し 、 手続き 下さい 。 \n ・ 法人 コンシェルサイト \n  https : / / portal . business . mb . softbank . jp / portal / BPS 0001 / ; jsessionid = Xh 1 qbFbMSmc 2 QsfmLSK 2 HKMSBJYLQvS 0 XL 4 p 76 sVYWVrdLYynnvW ! - 1848362821 \n ・ 業務用 携帯 電話 B の サービス 内容 変更 を し たい \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / keitai / keitai - b / information'},
#  {'id': '100061',
#   'title': '',
#   'text': 'プロジェクト フォルダ 管理者 を 追加 し たい が 、 管理者 追加 ボタン が 表示 さ れ ない 場合 、 管理者 が ３ 名 以上 に なっ て い ない か 確認 し て 下さい 。 \n 管理者 登録 は 最大 ３ 名 まで と なっ て おり ます 。 \n ３ 名 以上 の 登録 は 出来 ませ ん の で 、 どなた か 削除 し て 頂い た 後 、 登録 を お 願い し ます 。 \n\n 参考 FAQ \n ・ FALCON の 管理者 を 追加 し たい が 、 [ 管理者 追加 ] ボタン が 表示 さ れ ない [ FAQ   No : F 170626008 ] \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / faq / f 170626008'},
#  {'id': '100062',
#   'title': '',
#   'text': '共有 フォルダ 上 の ファイル が 読み取り 専用 に なる 場合 は 、 下記 情報 を 記載 の 上 、 OA   Support   Net に 投稿 し て 下さい 。 \n\n  < 提供 必須 情報 > \n ・ 対象 フォルダパス \n ・ PC ログイン OA アカウント （ エイリアス ） \n ・ 発生 時期 \n ・ 周り の ユーザ も 同じ 症状 か \n ・ OA 環境 （ FATPC / DaaS / HorizonView / OAMac ） \n ・ エラー 画面 の 画面 キャプチャ \n\n ・ Web 投稿 ： OA   Support   Navi   ＞   問合わせ   ＞   Web \n  http:// oa . bb . local / \n ※ カテゴリ ： system > Falcon / ファイル サーバ'},
#  {'id': '100063',
#   'title': '',
#   'text': '販売職 （ SV ） ・ 販売 契約 社員 の OAPC 貸出 ・ 交換 に つい て は 、 下記 を 確認 の 上 、 対応 し て 下さい 。 \n\n ■ 販売職 （ SV ） \n IoTAM 申請 方法 を 確認 し 、 OAPC の 貸出 ・ 交換 を 実施 下さい 。 \n\n ■ 販売 契約 社員 \n ・ ｶｽﾀﾏｰｹｱ ＆ ｵﾍﾟﾚｰｼｮﾝ 本部 以外 の 方 \n IoTAM より 交換 申請 を 実施 し て 下さい 。 \n ・ ｶｽﾀﾏｰｹｱ ＆ ｵﾍﾟﾚｰｼｮﾝ 本部 の 方 \n まず は 店長 ・ 副 店長 に ご 確認 頂き 、 その 上 で 、 店長 ・ 副 店長 より 各 窓口 に 連絡 し て 下さい 。 \n\n 【 IoTAM 申請 方法 】 \n ・ 【 IoTAM 】 PC 貸出 申請 方法 \n http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / pc _ lending \n\n ・ 【 IoTAM 】 PC 交換 申請 方法 \n http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / pc _ exchange \n\n PC の 利用 が 不要 に なっ た 場合 は 下記 ページ を 参照 し 、 返却 を 行っ て 下さい 。 \n ・ 返却 し たい \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / pc / step 3'},
#  {'id': '100064',
#   'title': '',
#   'text': 'インストール 兼 Admin 権限 付与 申請時 の インストーラ 保管 場所 に つい て 、 インストール 申請 の 承認 完了 メール に 記載 さ れ ます 。'},
#  {'id': '100065',
#   'title': '',
#   'text': '「 Microsoft   Online   Services   サイン イン   アシスタント は この コンピュータ に インストール さ れ て い ませ ん 。 管理者 に 問合せ て 下さい 。 」 の メッセージ が 表示 さ れ ファイル が 開け ない 場合 、 下記 FAQ を 実施 し て 下さい 。 \n ・ [ FAQ   No : F 170306001 ] AzureRMS 権限 を リフレッシュ する 手順 が 知り たい \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / faq / f 170306001 \n\n 上記 FAQ で 解消 でき ない 場合 は 下記 を 参照 し 、 Office 365 の 入れ直し を 実施 下さい 。 \n ・ Office の 再 インストール 方法 を 教え て 下さい [ FAQ   No : F 170922001 ] \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / faq / f 170922001 \n\n 参考 FAQ \n ・ [ FAQ   No : F 170704001 ] Office ファイル を 開く と メッセージ が 表示 さ れ ファイル が 開け ない \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / faq / f 170704001'},
#  {'id': '100066',
#   'title': '',
#   'text': 'インターネット 接続 が 出来 ない 場合 、 まず は 下記 を ご 確認 下さい 。 \n 【 ネットワーク 接続 状況 の 確認 】 \n ■ 社内 \n ・ 社内 有線 LAN また は 無線 LAN   blue に は 接続 でき て いる か ？ \n ■ 社外 \n ・ 社外 Wi-FI もしくは テザリング 接続 でき て いる か ？ \n\n 【 各種 サイト の アクセス 状況 】 \n ・ 社内 システム は アクセス 可能 か ？ \n ・ Gmail 、 外部 サイト （ Yahoo 、 Google 等 ） に アクセス 可能 か ？ \n \n Gmail 、 外部 サイト （ Yahoo 、 Google 等 ） に アクセス する に は Zscaler の 利用 が 必要 です 。 \n Zscaler に ログイン し て い なく 、 インターネット 接続 でき て い ない 場合 は 下記 を 実施 下さい 。 \n ■ OAPC   /   準 OAPC \n ・ 【 Windows 】 Zscaler   Client   Connector ログイン 方法 \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / zscaler _ login _ windows \n\n ■ OAMac \n ・ 【 Mac 】 Zscaler   Client   Connector ログイン 方法 \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / zscaler _ login _ mac \n\n 参考 FAQ \n ・ ネットワーク に は 接続 できる が 、 外部 Web サイト ・ Gmail に 接続 でき ない ［ FAQ   No ： F 000158884 ］ \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / faq / f 000158884'},
#  {'id': '100067',
#   'title': '',
#   'text': '業 端 B で 充電 が さ れ ない 場合 は 、 他 の ケーブル を 使用 し 、 充電 できる か 確認 下さい 。 \n\n ・ 他 の ケーブル で 充電 できる 場合 \n\u3000 ケーブル の 故障 と なり ます の で 、 手配 元 部署 に 交換 を 依頼 下さい 。 \n\n ・ 他 の ケーブル で も 充電 でき ない 場合 \n\u3000 端末 自体 の 故障 と なり ます の で 、 手配 元 部署 に 交換 を 依頼 下さい 。'},
#  {'id': '100068',
#   'title': '',
#   'text': 'L 3 Dev の ファイル サーバー 、 チャット システム 、 Proself 等 で 接続 不具合 が 発生 し た 場合 は 、 まず は 、 FAQ を 参照 し て 下さい 。 \n ・ Proself   FAQ \n  https : / / docs . google . com / spreadsheets / d / 1 P 7 iKCDlTe 8 rERv 3 oH 5 iDrxOv 782 TSF 144 vitLn 7 xdkc / edit # gid = 977654396 \n\n FAQ の 内容 で 解決 でき ない 場合 は 、 下記 ページ を 参照 し て 下さい 。 \n ・ L 3 Dev の ファイル サーバー 、 チャット システム 、 Proself に 繋がら ない \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / l 3 dev / l 3 devfcp'},
#  {'id': '100069',
#   'title': '',
#   'text': 'TAS 系   （ CrBS   /   CrBS - C   /   CrBS - T   /   DFCA   /   RTDA 2 - J   /   TAS - S   L 2   /   TAS - S   L 3   /   TAS - S   L 4   /   TeBiAs 社内 メンテ   /   TOMAS   /   BS - DR   /   RISM - BP ) ・ TASGRP ・ RTDAS 2 - J の 問合せ に つい て は 、 OA サポート デスク で は サポート 対象外 と なり ます 。 \n 下記 窓口 が 担当 か と 思わ れ ます の で 、 直接 問合せ 願い ます 。 \n\n ・ ＴＡＳ 運用 チーム ( SBTM   TASGRP 利用者 連絡 用 ) \n  SBTMGRP - tasadmin @ g . softbank .co.jp \n ・ ＴＡＳ 系 システム サポート   ( SBTM   TAS 系 システム の ユーザ から の 問合せ 用 アドレス ) \n  sbtmgrp - tassupport @ g . softbank .co.jp'},
#  {'id': '100070',
#   'title': '',
#   'text': '弁済 金 に つい て は 、 下記 ページ を 参照 下さい 。 \n ・ 弁済 金 に つい て \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / keitai / keitai - a / rule / bensai'},
#  {'id': '100071',
#   'title': '',
#   'text': 'OA 提供 外 の ソフトウェア を インストール し たい 場合 は 下記 ページ を 参照 し て 下さい 。 \n\n ・ OA 提供 外 の アプリ を インストール する \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / setting / AppOtherOaIns \n ・ ソフトウェア を インストール し たい \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / request / software / use \n ・ ライセンス 是正 対応 \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / request / correction \n ※ 各 ソフトウェア の インストール 方法 に つい て は 、 ソフトウェア の 提供 元 に 確認 し て 下さい \n\n なお 、 該当 の ソフトウェア を 利用 する 前 に 使用 禁止 ソフトウェア に 該当 し て い ない か 確認 下さい 。 \n ・ 禁止 ソフトウェア \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / request / software / use / confirmation / bansoft \n 通達 ： 禁止 ソフトウェア の 利用 規制 強化 に つい て \n  http:// sb - erp . bb . local / index . html # showCoverView ? next = views % 2 Fhrm % 2 Fbbs % 2 FBbsSearchView & params % 5 bbbsId % 5 d = NT 01300202313862 \n\n 参考 ： \n ソフトウェア インストール に つい て は 、 Admin 権限 が 必要 と なり ます 。 \n ・ 【 社内外 共通 】 L 2 OAPC / 準 OAPC   Admin 権限 申請 ・ 適用 方法 \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / admintekiyou _ shanaigai'},
#  {'id': '100072',
#   'title': '',
#   'text': 'OAPC の 自宅 ・ 社外 ネットワーク へ の 接続 方法 に つい て は 、 OA サポート 外 と なり ます 。 \n\n 自宅 ・ 社外 NW へ 接続 不可 の 場合 は 、 直接 社外 ネットワーク の 提供 元 に 確認 し て 下さい 。'},
#  {'id': '100073',
#   'title': '',
#   'text': 'OA 払い出し OAMac の 新規 ・ 一時 貸出 、 故障 / 希望 交換 に つい て は 、 提供 を 終了 致し まし た 。 \n ※ 参考 通達 \n ・ OAMac 提供 終了 の ご 案内 \n  http:// sb - erp . bb . local / index . html # showCoverView ? next = views % 2 Fhrm % 2 Fbbs % 2 FBbsSearchView & params % 5 bbbsId % 5 d = NT 01300201705917 \n\n 業務上 、 Mac を 利用 する 必要 が ある 場合 は 、 部門 にて Mac を 購入 し 、 OAMac 化 を 実施 し て 下さい 。 \n ・ Mac を 購入 し たい \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / mac / konyu \n ・ 部門 Mac の OAMac 化 手順 \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / mac / oamac - change \n\n OA 払い出し の OAMac （ コンピュータ 名 ： ISCMAC 130 ） を Windows の OAPC に 交換 し たい 場合 は 、 対象 端末 の コンピュータ 名 を 確認 の 上 、 下記 まで 問合せ 下さい 。 \n\n 社員 サポート センター （ ＯＡ サポート デスク ） ： 平日 9 : 00 ～ 18 : 00 \n ● Slack ： ＃ help - oa サポート （ チャンネル 名 で 検索 し て ください ） \n ● Ｗｅｂ 投稿 ： OA   Support   Navi   ＞   問合わせ   ＞   Web   http:// oa . bb . local / oasupport / inquiry _ web \n ● PC 受取 / 返却 ： OA   Support   Navi   ＞   問合わせ   ＞   PC 受取 / 返却   http:// oa . bb . local / oasupport / inquiry _ counter \n ● コール 予約 ： OA   Support   Navi   ＞   問合わせ   ＞   コール 予約 （ OA ）   http:// oa . bb . local / oasupport / oa - call - reservation'},
#  {'id': '100074',
#   'title': '',
#   'text': '開発 DaaS 環境 アクセス 時間 短縮 方法 に つい て は 、 下記 ページ を 参照 下さい 。 \n ・ 開発 DaaS 環境 アクセス 時間 短縮 方法 \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / l 3 dev _ daas - speedup'},
#  {'id': '100075',
#   'title': '',
#   'text': 'O & M の 問合せ に つい て は 、 OA サポート デスク で は サポート 対象外 と なり ます 。 \n 問合せ に つい て は 、 下記 ページ の フォーム より 問合せ 願い ます 。 \n\n ・ 統合 ヘルプ デスク \n  https : / / open - ui . biz / cms /'},
#  {'id': '100076',
#   'title': '',
#   'text': '全社員 宛 に Gmail を 送信 し たい 場合 は 、 下記 を 参照 下さい 。 \n ・ Q . 03 - 053 \u3000 Gmail で 全社員 宛て の メール を 送信 する 方法 を 教え て ください \n  https : / / sites . google . com / a / g . softbank .co.jp / helpg / discussion - board / gmail / 03 - 053'},
#  {'id': '100077',
#   'title': '',
#   'text': 'Gmail の 画面 左側 の 項目 を スクロール し 「 もっと 見る 」 を クリック し 、 その 中 の 「 ゴミ箱 」 に 対象 の メール が 残っ て いる か ご 確認 下さい 。 \n もし 、 ゴミ箱 から も 削除 さ れ て いる 場合 は 、 大変 申し訳 ござい ませ ん が 、 復元 する こと は でき ませ ん 。'},
#  {'id': '100078',
#   'title': '',
#   'text': 'CRM の 問合せ に つい て は 、 OA サポート デスク で は サポート 対象外 と なり ます 。 \n 下記 窓口 が 担当 か と 思わ れ ます の で 、 必要 情報 を 確認 の 上 、 直接 問合せ 願い ます 。 \n\n ■ 必要 情報   \n  ・ コンピューター 名 \n\n ・ CRM インフォ 運転 T \n  sbmgrp -- crminfo - unten @ g . softbank .co.jp'},
#  {'id': '100079',
#   'title': '',
#   'text': 'SBTM   OMS   作 スケ   （ サスケ ） の 問合せ に つい て は 、 OA サポート デスク で は サポート 対象外 と なり ます 。 \n 下記 窓口 が 担当 か と 思わ れ ます の で 、 直接 問合せ 願い ます 。 \n\n ・ 作 スケヘルプデスク （ ＣＳ 本部 ） \n  sbtmgrp - sasuke _ help @ g . softbank .co.jp \n ・ ＯＭＳ ・ 作 スケ （ 運用 ・ 開発 担当 ） \n  sbtmgrp - oms - wm @ g . softbank .co.jp'},
#  {'id': '100080',
#   'title': '',
#   'text': '以下 事象 で 正常 に SSO 認証 でき ない 場合 は Chrome の キャッシュ クリア を 実施 下さい 。 \n ・ SSO 認証 画面 が 表示 さ れ ない \n ・ 「 情報 ログイン し まし た 」 が 表示 さ れる \n ・ 「 不正 な ハンドラ に よる 認証 の 例外 」 が 表示 さ れる \n ・ 「 Error 403 -- Forbidden 」 が 表示 さ れる \n ・ 再度 認証 画面 に 戻っ て しまう \n\n ■ Chrome の キャッシュ クリア \n 1 . Google Chrome の 画面 で 、 「 Ctrl 」 + 「 Shift 」 + 「 Del 」 キー を 押下 \n 2 . 「 期間 」 で 「 全 期間 」 を 選択 \n  次 の 項目 に チェック が 入っ て いる こと を 確認 し 、 データ を 削除 する \n ・ 閲覧 履歴 \n ・ Cookie   と 他 の サイト   データ \n ・ キャッシュ さ れ た 画像 と ファイル \n 3 ． Google Chrome を 再起動 \n ※ 「 × 」 ボタン で は なく 、 Google Chrome の 画面 右上 の 3 つ の 点 が 縦 に 並ん だ マーク を クリック → 「 終了 」 で 閉じ た 後 、 再度 立上げ 、 再 ログイン を お 願い いたし ます \n\n Chrome キャッシュ クリア 後 も SSO 認証 画面 が 表示 さ れ ない 場合 は 、 ログオン しよう と し て いる OA アカウント （ エイリアス ） を 確認 の 上 、 担当 部署 に エスカレーション 致し ます の で 、 OA サポート デスク へ 問合せ 下さい 。 \n\n 社員 サポート センター （ ＯＡ サポート デスク ） ： 平日 9 : 00 ～ 18 : 00 \n ● Slack ： ＃ help - oa サポート （ チャンネル 名 で 検索 し て ください ） \n ● Ｗｅｂ 投稿 ： OA   Support   Navi   ＞   問合わせ   ＞   Web   http:// oa . bb . local / oasupport / inquiry _ web \n ● PC 受取 / 返却 ： OA   Support   Navi   ＞   問合わせ   ＞   PC 受取 / 返却   http:// oa . bb . local / oasupport / inquiry _ counter \n ● コール 予約 ： OA   Support   Navi   ＞   問合わせ   ＞   コール 予約 （ OA ）   http:// oa . bb . local / oasupport / oa - call - reservation'},
#  {'id': '100081',
#   'title': '',
#   'text': '準 OAPC の 主管部 変更 は 、 Pure   Terminal の 「 利用者 変更 」 で 新た な 部署 の 管理者 へ 変更 し ます 。 \n \n ・ 【 IoTAM 】 PC 利用者 変更 申請 方法 \n http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / pc / userchange \n 利用者 変更 申請 完了 後 、 下記 件名 の メール が 旧 利用者 、 新 利用者 、 新 利用者 の 上長 宛 に 送付 さ れ ます 。 \n メール 件名 ： 【 申請 完了 】 利用者 変更   RA * * * * * * * * * * \n ※ 利用者 変更 する 準 OAPC で OASYS 利用 し て いる 場合 は 下記 ページ を 参照 し 、 利用 権限 の 削除 を 実施 下さい \n\u3000 ・ OASYS 利用 申請 削除 方法 \n\u3000\u3000 http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / % 3 Fpost _ type % 3 Dpost % 26 p % 3 D3 3156'},
#  {'id': '100082',
#   'title': '',
#   'text': 'Zoom アカウント 自動 払出 また は Tarte 申請 に よる 有料 アカウント 払出 の 方 が ホスト の 場合 、 Zoom ミーティング の 制限 時間 は あり ませ ん 。 \n ※ 24 時間 で タイム アウト する 仕様 です \n Tarte 申請 に よる 無料 アカウント 払出 の 方 が ホスト の 場合 、 40 分 の 制限 時間 が あり ます 。'},
#  {'id': '100083',
#   'title': '',
# ...
#  {'id': '100971',
#   'title': '',
#   'text': '業 端 A の USIM を 他 の 端末 に 差替え て 利用 する こと は 禁止 し て おり ます 。 \n ・ 使用 上 の ルール ・ 規程 （ 全般 ） \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / keitai / keitai - a / rule / kitei'},
#  {'id': '100972',
#   'title': '',
#   'text': '他社 キャリア の 業 端 B 解約 は IoTAM で は でき ませ ん の で 下記 ドキュメント を 確認 下さい 。 \n ・ 【 IoTAM 】 業務用 携帯 B   操作 マニュアル （ ユーザー 展開 用 ） \n  https : / / docs . google . com / presentation / d / 1 - cjNwei 93 iZgDuexh 6 h 6 tzc 6 gFzdHH 3 EQS 3 Xljlwq 1 g / edit # slide = id . p \n 参考 ページ \n ・ 他 キャリア 手配 （ docomo ・ au ・ その 他 ） \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / keitai / keitai - b / arrangement / othercarriers \n\n また 、 IoTAM から 情報 削除 する 為 に は 解約 ・ 廃棄 申請 は 必要 です 。 \n 回線 解約 手続き 完了 後 、 IoTAM より 解約 ・ 廃棄 申請 を 上げ て 下さい 。'},
#  {'id': '100973',
#   'title': '',
#   'text': '不明 ・ SIM なし ・ 圏外 の 表示 と なり 、 回線 に 不具合 が 発生 し て いる 場合 、 まず は 以下 を お 試し 下さい 。 \n ・ 電源 OFF / ON \n ・ SIM カード の 抜き差し \n ・ 設定 ＞ モバイル 通信 ＞ モバイル データ 通信 の OFF / ON \n\n 解消 さ れ ない 場合 は 、 下記 で 対応 下さい \n\n 【 「 不明 」 表示 】 \n ■ 業 端 A \n 共通 社員 番号 、 氏名 、 IMEI 、 ICCID を 確認 の 上 、 Web 投稿 し て 下さい 。 \n ・ Web 投稿 \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / inquiry _ web \n カテゴリ ： iPhoneiPad > 業務用 携帯 管理 システム （ IoTAM ） \n                   Android > 業務用 携帯 管理 システム （ IoTAM ） \n ■ 業 端 B \n 部門 にて OTA 再 配信 を 依頼 下さい 。 \n ・ 業務用 携帯 電話 B の サービス 内容 変更 を し たい \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / keitai / keitai - b / information \n\n 【 「 SIM なし 」 「 圏外 」 表示 】 \n ■ 業 端 A \n USIM ・ 端末 不具合 を 切り分け 、 IoTAM より 故障 交換 申請 を 行っ て 下さい 。 \n ・ IoTAM 故障 交換 申請 （ 業 端 A ） \n http:// iotam . bb . local / OAService / catalog / gtaMenu \n ・ 業 端 A _ IoTAM 操作 マニュアル \n https : / / docs . google . com / document / d / 1 CKtnPkW 0 IEIfVfMjZksNXC 8470 PgO 4 lRJaViTtQ _ tT 0 / edit # bookmark = kix . pidy 15 flbgu 2 \n ■ 業 端 B \n USIM ・ 端末 不具合 を 切り分け 、 部門 にて 修理 等 の ご 対応 を お 願い いたし ます 。'},
#  {'id': '100974',
#   'title': '',
#   'text': '転送 設定 ・ 解除 方法 に つい て は 下記 を 参照 下さい 。 \n\n 【 業 端 A 】 \n MySoftBank から 転送 設定 ・ 転送 解除 が 可能 と なり ます 。 \n ・ MySoftbank \n  https : / / www . softbank . jp / mysoftbank / \n ※ 業 端 A から 個人 携帯 電話 へ の 転送 設定 は セキュリティ 上 、 NG と なっ て おり ます \n\u3000 固定 電話 もしくは 部門 手配 の 業 端 B へ の 転送 でし たら 可能 と なり ます \n\n MySoftBank の パスワード が わから ない 場合 は 、 Web 投稿 し て 下さい 。 \n\n 【 業 端 B 】 \n 転送 設定 ・ 解除 方法 に つい て は 部門内 で 確認 下さい 。'},
#  {'id': '100975',
#   'title': '',
#   'text': 'OAPC の 交換 に つい て は 、 まず は 下記 ページ を 参照 し て 下さい 。 \n ・ OAPC 故障 切り分け 方法 \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / pc / kosyou \n\n 上記 切り分け 後 、 交換 が 必要 な 場合 は 下記 ページ を 参照 の 上 、 交換 申請 を 実施 下さい 。 \n ・ 【 IoTAM 】 PC 交換 申請 方法 \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / pc _ exchange \n ※ 修理 に つい て は 、 承っ て おり ませ ん 。 すべて 交換 対応 と なり ます 。 \n ※ 準 OAPC （ CXIRPC ） 、 OAMac （ ISCMAC 130 / ISCMAC 131 / COAMAC ） は 対象外 です 。 \n ※ 故障 ・ 不具合 で のみ 交換 可能 と なり ます \n\u3000 特定 の 機種 や 高スペック 端末 へ の 希望 交換 に つい て は 、 交換 不可 と なり ます \n ※ コンピューター 名 の 確認 に つい て は 、 天板 右上 に 貼付 さ れ て いる 白い テプラ の コンピューター 名 を 記載 し て 下さい 。 \n ※ 交換 元 端末 の AC アダプタ ・ VGA アダプタ 等 の 備品 も 端末 と 一緒 に 返却 し て 下さい \n ※ 本社 以外 の 発送 に つい て は 、 SB 拠点 のみ 可能 と なり ます \n ※ 送付先 に 変更 が ある 場合 は 、 OA サポート デスク まで 問合せ 下さい \n ※ 交換 PC で OASYS 利用 し ない 場合 は 、 下記 ページ を 参照 し 、 返却 PC の 利用 権限 の 削除 を 実施 下さい \n\u3000 ・ OASYS 利用 申請 削除 方法 \n\u3000\u3000 http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / % 3 Fpost _ type % 3 Dpost % 26 p % 3 D3 3156 \n\n 社員 サポート センター （ ＯＡ サポート デスク ） ： 平日 9 : 00 ～ 18 : 00 \n ● Slack ： ＃ help - oa サポート （ チャンネル 名 で 検索 し て ください ） \n ● Ｗｅｂ 投稿 ： OA   Support   Navi   ＞   問合わせ   ＞   Web   http:// oa . bb . local / oasupport / inquiry _ web \n ● PC 受取 / 返却 ： OA   Support   Navi   ＞   問合わせ   ＞   PC 受取 / 返却   http:// oa . bb . local / oasupport / inquiry _ counter \n ● コール 予約 ： OA   Support   Navi   ＞   問合わせ   ＞   コール 予約 （ OA ）   http:// oa . bb . local / oasupport / oa - call - reservation'},
#  {'id': '100976',
#   'title': '',
#   'text': 'スマホ AD ・ スマホ フレンド から よく ある 問合せ は 、 下記 を 参照 下さい 。 \n ・ Q&A 一覧 （ 業 端 B 関連 ） \n https : / / goo . gl / YWjS 3 o \n ※ OA サポート デスク に 問合せ 頂い て も 、 サポート 対象外 と なり ます'},
#  {'id': '100977',
#   'title': '',
#   'text': '「 未 検証 の プロファイルサイバートラストプロファイルサービス の 真正性 を 確認 でき ませ ん でし た 。 ファイル を インストール でき ませ ん でし た 。 」 が 表示 さ れ た 場合 は 、 下記 を 確認 下さい 。 \n  ■ 確認 事項 \n  ・ コモン ネーム と 端末 の IMEI が 一致 し て いる メール を ご利用 し て い ます か ？ \n  ・ 設定 メール を 端末 上 で 開き リンク を タップ し て い ます か ？'},
#  {'id': '100978',
#   'title': '',
#   'text': '販売職 の 業 端 B   iPhone / iPad / Android で の Gmail ・ VPN の 利用 等 に つい て は 、 下記 フォーム より 問合せ し て 下さい 。 \n \n ・ 【 業 端 B 】 お 問合せ フォーム \n  https : / / docs . google . com / a / g . softbank .co.jp / forms / d / e / 1 FAIpQLSf _ sv 6 KJ 3 Ic 8 QEDUZRDR 6 UVEhMhB 3 t 1 Pg 57 Wl 93 a 5 Fp 9 Pwq 9 g / viewform ? c = 0 & w = 1'},
#  {'id': '100979',
#   'title': '',
#   'text': '統合 マスタ WEB の 問合せ に つい て は 、 OA サポート デスク で は サポート 対象外 と なり ます 。 \n 下記 窓口 が 担当 か と 思わ れ ます の で 、 直接 問合せ 願い ます 。 \n\n ・ 代理店 マスタ 運用 （ 営業 推進 本部 ） \n  sbmgrp - master - info @ g . softbank .co.jp'},
#  {'id': '100980',
#   'title': '',
#   'text': 'Slack アカウント の 提供 範囲 に つい て は 下記 と なり ます 。 \n\n ■ 自動 払い出し 対象者 \n 所属 会社 ： SBKK \n 社員 区分 ：   役員 、 従業員 兼務 役員 、 執行 役員 （ 委任 型 ） 、 顧問 、 正社員 、 準社員 、 嘱託 、 特別 嘱託 、 契約 社員 、 受入 出向 社員 、 販売 契約 社員 、 特定 臨時 社員 \n ※ C & S が 本務 の 場合 は 対象外 \n\n ■ 自動 払い出し 非対象者 （ 特定 社員 ） \n 所属 会社 ： SBKK \n 社員 区分 ： アルバイト 、 派遣 社員 、 業務 委託 、 非 社員 \n 特定 社員 で Slack 利用 が 必要 な 場合 は Tarte より 申請 下さい 。 \n ・ Tarte \n http:// portal . tarte . bb . local / Tarte / tarteMain \n ※ 「 システム 権限 申請 」 の 「 Slack 」 を 検索 し て 申請 下さい \n 申請前 に 必ず 下記 と 注意 事項 を 確認 し て 下さい 。 \n ・ 【 Slack 】   特定 社員 利用 開始 \n  https : / / docs . google . com / presentation / d / 1 rgLsB 7 eacZgzWp 39 _ g 2 wSWYfldfo 1 lFMIYHKRc - befA / edit # slide = id . ga 28 c 8 ec 33 d _ 8 _ 0 \n ＜ 注意 事項 ＞ \n ・ 「 @ g . softbank .co.jp 」 の メール アドレス を 保持 し て いる こと が 必須 です \n ・ 社外 送信 不可 の 場合 、 特定 社員 専用 WS に のみ 招待 さ れ ます ( ゲスト WS に は 招待 さ れ ませ ん ) \n ・ 上長 承認 さ れ た 申請 のみ 処理 さ れ ます \n\n\n ■ 社外 ユーザー の 方 \n ゲスト と し て 招待 可能 と なり ます 。 \n 詳細 に つい て は 、 下記 を 参照 下さい 。 \n ・ 【 Slack 】   ゲスト 利用 開始 \n  https : / / docs . google . com / presentation / d / 1 yRbSx - 831 z 7 OzR 7 nofqRzjDCvZWmZGue 8 YJQx 5 wq 7 cQ / edit # slide = id . ga 28 c 8 ec 33 d _ 8 _ 0 \n\n 問合せ に つい て は 、 下記 より お 願い し ます 。 \n ・ OA   Support   Net \n  http:// oa . bb . local / oasupport / inquiry _ web \n\u3000 （ カテゴリ ： Slack ） \n\n 【 注意 】 \n Slack アカウント に つい て は メーリング リスト で の 登録 不可 と なり ます'},
#  {'id': '100981',
#   'title': '',
#   'text': '迷惑 メール および 不審 な メール を 受信 し た 場合 は 、 下記 FAQ を 参照 下さい 。 \n ・ 迷惑 メール また は 不審 な メール を 受信 し て しまっ た [ FAQ   No : F 191021001 ] \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / faq / f 191021001'},
#  {'id': '100982',
#   'title': '',
#   'text': '組織 フォルダ の 仕様 に つい て は 、 下記 を 参照 し て 下さい 。 \n\n 【 ネーミング ルール 】 \n \\ \\ bbwcfs . local \\ Share * * \\ DATA * \\ ShareOrg \\ SBB \\ SBB _ ( 組織 番号 ) _ ( 組織名 ) \n \\ \\ bbwcfs . local \\ Share * * \\ DATA * \\ ShareOrg \\ SBM \\ SBM _ ( 組織 番号 ) _ ( 組織名 ) \n \\ \\ bbwcfs . local \\ Share * * \\ DATA * \\ ShareOrg \\ SBTM \\ SBTM _ ( 組織 番号 ) _ ( 組織名 ) \n\n 【 作成 段階 の アクセス権 に つい て 】 \n 当該 フォルダ は 、 作成 段階 で 組織 に 所属 し て いる メンバー に 対し て のみ 、 アクセス権 が 自動的 に 付与 さ れ ます 。 \n ※ 「 メンバ 一覧 」 に は 表示 さ れ ませ ん 。 \n また 、 アクセス権 は その 組織 の 会社 の OA アカウント （ エイリアス ） に 付与 さ れ ます 。 \n ※ SBM 組織 部署 は SBM の OA アカウント （ エイリアス ） 、 SBB 組織 部署 は SBB の OA アカウント （ エイリアス ）   等 \n\n 【 他 組織 の メンバ 追加 方法 】 \n 個別 の メンバ 追加 に つき まし ては 、 下記 2 通り ござい ます 。 \n 1 ． フォルダ 管理者 の 方 にて 個別 に メンバ 追加 申請 を 行う 。 \n ※ 初期 構成 で は 組織 の 上長 が フォルダ 管理者 と なっ て おり ます 。 \n 2 ． 他 組織 の 方 にて 、 FALCON に ログイン 頂き 、 \n\u3000 アクセス 対象 フォルダ の 検索 後 、 アクセス権 申請 を 行い 、 \n\u3000 申請 を う 受け た フォルダ 管理者 にて 承認 後 、 アクセス権 付与 。 \n ※ 初期 構成 で は 組織 の 上長 へ 申請 さ れ ます 。 \n ※ ここ で の 他 組織 は 、 組織 の 所属 部署 に 属さ ない メンバー を 指し ます 。 \n ※ 兼務 者 で SBM の OA アカウント （ エイリアス ） が 組織 の 所属 部署 の メンバ の 場合 、 \n\u3000 他 OA アカウント （ エイリアス ） （ SBB ・ SBTM 等 ） で あっ て も アクセス権 申請 は でき ませ ん 。 \n\n 【 初期 フォルダ 管理者 ならび に 管理者 追加 に つい て 】 \n 初期 状態 で は 、 所属 組織 の 上長 が 管理者 と し て 設定 さ れ て おり ます の で 、 FALCON 上 で 上長 の 方 に 管理者 追加 を 行っ て 頂き ます 様 お願い 致し ます 。 \n ※ 組織 の 所属 部署 の メンバー および 配下 組織 の 上長 のみ 、 管理者 と し て 追加 可能 \n ※ （ 例 ） 部 フォルダ で あれ ば 配下 組織 の 課長 等 \n\n 【 フォルダ 管理者 の 確認 方法 】 \n フォルダ 管理者 を 確認 する に は 、 FALCON に 該当 組織 の OA アカウント （ エイリアス ） にて ログイン する こと で 、 確認 が 可能 です 。 \n 「 組織 フォルダ 一覧 」 ＞ 対象 組織 の 「 詳細 」 を クリック ＞ 「 管理者 一覧 」'},
#  {'id': '100983',
#   'title': '',
#   'text': '自身 の OA アカウント （ エイリアス ） が ロック さ れ た 場合 は 、 下記 ページ を 参照 し 、 パスワード リセット を 実施 下さい 。 \n ※ 自身 以外 の OA アカウント （ エイリアス ） が ロック さ れ た 場合 も 同様 です \n ・ OA アカウント （ エイリアス ） の パスワード を 変更 し たい \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / pc / password \n\n ※ 注意 ※ \n SBC & S の OA アカウント （ エイリアス ） に つい て は 、 パスワード リセット 対象外 と なり ます の で 、 下記 ページ を 参照 し て 下さい 。 \n ・ C&S   Portal \n\u3000 https : / / portal . bb . local / oa / \n ※ サイト アクセス 時 に 「 この 接続 で は プライバシー が 保護 さ れ ませ ん 」 が 表示 さ れ た 場合 は 下記 SSB   C&S   サービス デスク に 問合せ 下さい \n ・ SB C&S   サービス デスク \n  https : / / softbankcs . service - now . com / csqa ? id = casoa _ index'},
#  {'id': '100984',
#   'title': '',
#   'text': 'セキュリティ ソフト に つい て は 下記 FAQ を 参照 下さい 。 \n ・ 【 セキュリティ ソフト 】 FAQ \n  https : / / docs . google . com / spreadsheets / d / 1 zz 48 M _ hYa 0 PbxtUGlFdVAvXxBUVK 8 E 12 yI 5 UGp - A 0 Hc / edit # gid = 0'},
#  {'id': '100985',
#   'title': '',
#   'text': 'AzureRMS の 対応 を 行っ て い ない と 暗号化 さ れ た ファイル が 開け ませ ん 。'},
#  {'id': '100986',
#   'title': '',
#   'text': '誤っ た コンピューター 名 で インベントリ ファイル を アップロード し て しまっ た 場合 は 、 再度 、 端末 側 の コンピューター 名 を 修正 し 、 アップロード を し なおし て 下さい 。 \n すでに ドメイン 参加 を 実施 し て しまっ て いる 場合 は 、 端末 初期化 後 、 再度 、 準 OAPC 化 を 実施 し て 下さい 。 \n\n なお 、 誤っ た コンピュータ 名 で ドメイン 参加 し て いる 場合 は 、 対象 の コンピュータ 名 を 下記 まで お 知ら せ 下さい 。 \n ・ Web 投稿 \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / inquiry _ web \n\u3000 （ カテゴリ ： PC ）'},
#  {'id': '100987',
#   'title': '',
#   'text': 'VSOC - VPN に つい て は 無線 （ blue ） で の 接続 が 前提 に なり ます 。 \n ご自身 の OAPC で blue に 接続 し て から VPN を 利用 いただく よう お 願い し ます 。 \n\n 下記 ページ を 参照 し 、 無線 LAN （ blue ） へ の 接続 を 実施 し て 下さい 。 \n ・ Blue \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / setting / blue \n\n VSOC に 関する 問合せ に つい て は 、 下記 を 参照 下さい 。 \n ・ VSOC （ SOC ） 案内 \n https : / / open - ui . biz / cms / vsoc   \n ・ VSOC ｜ FAQ \n https : / / open - ui . biz / cms / vsoc / faq / \n ・ 問合せ先 \n https : / / open - ui . biz / cms / vsoc / contact / \n ※ OA サポート に 問合せ いただい て も 回答 でき かね ます'},
#  {'id': '100988',
#   'title': '',
#   'text': 'プリンタ 設定 方法 に つい て は 、 下記 ページ を 参照 し て 下さい 。 \n ・ 複合機（プリンタ） 設定 \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / pc / printer \n\n ■ MPC 6003   SPF （ リコー 株式 会社 製 ） \n ・ 【 Ricoh 】 プリンタ 利用 マニュアル （ OAPC / 準 OAPC ） \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / pc / printer _ ricoh \n\n ■ ゼロックス （ ApeosPort - V   C 6676   PFS - PC ） \n ・ 【 Xerox 】 プリンタ 利用 マニュアル （ OAPC / 準 OAPC ） \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / pc / printer _ xerox'},
#  {'id': '100989',
#   'title': '',
#   'text': '周辺 機器 一時 貸出 ・ 交換 依頼 フォーム から 申請後 、 キャンセル し たい 場合 は 、 OA サポート デスク に 下記 情報 を 提供 し て 下さい 。 \n\n 申請 番号 ： BHN - * * * * \n ※ メール 件名 ： [ 周辺 機器 交換 ]   【 申請 番号 : BHN - * * * * 】   周辺 機器 準備 完了 の お知らせ \u3000 参照 \n 申請者 共通 社員 番号 ： \n 申請者 氏名 ： \n\n 社員 サポート センター （ ＯＡ サポート デスク ） ： 平日 9 : 00 ～ 18 : 00 \n ● Slack ： ＃ help - oa サポート （ チャンネル 名 で 検索 し て ください ） \n ● Ｗｅｂ 投稿 ： OA   Support   Navi   ＞   問合わせ   ＞   Web   http:// oa . bb . local / oasupport / inquiry _ web \n ● PC 受取 / 返却 ： OA   Support   Navi   ＞   問合わせ   ＞   PC 受取 / 返却   http:// oa . bb . local / oasupport / inquiry _ counter \n ● コール 予約 ： OA   Support   Navi   ＞   問合わせ   ＞   コール 予約 （ OA ）   http:// oa . bb . local / oasupport / oa - call - reservation'},
#  {'id': '100990',
#   'title': '',
#   'text': '業 端 A で は 速度 制限 は 実施 し て おら ず 、 データ 容量 は 自動 追加 プラン と なっ て おり ます 。'},
#  {'id': '100991',
#   'title': '',
#   'text': 'InfoBarrier 監視 アラート メッセージ の ポップ アップ が 表示 さ れ た 場合 は 、 社内 ネットワーク に 接続 し た 状態 で 下記 手順 を 実施 し て 下さい 。   \n 社内 ： L 2 有線 LAN また は 無線 LAN   blue \n 社外 ： OASYS   VPN 接続 \n \n  ＜ 手順 ＞   \n  「 隠れ て いる インジケーター を 表示 し ます （ ▲ ） 」 を クリック ＞ InfoBarrier アイコン （ 上下 矢印 の 赤い アイコン ） を 右 クリック し 、 「 最新 の 情報 に 更新 」 を 実施 し 、 しばらく （ 2 ～ 3 日 程度 ） 放置 する'},
#  {'id': '100992',
#   'title': '',
#   'text': 'GoogleChrome で パスワード を 自動 入力 ・ 保存 し たい 場合 は 、 下記 ページ を 参照 し て 下さい 。 \n\n ・ パスワード を 管理 する \n  https : / / support . google . com / chrome / answer / 95606 ? co = GENIE . Platform % 3 DDesktop & hl = ja'},
#  {'id': '100993',
#   'title': '',
#   'text': 'L 2 環境 で 作成 し た 暗号化 さ れ た ファイル を L 3 環境 で 開き たい 場合 は 、 事前 に 送付 元 の L 2 環境 上 で 暗号化 を 解除 し て から 、 L 3 環境 で 開い て 下さい 。 \n\n ・ 暗号化 ファイル の 解除 \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / setting / AzureRMS / rights / unlock \n\n L 3 環境 上 で の 暗号化 施策 に つい て は 、 OA サポート 外 と なり ます の で 、 下記 より 問合せ 下さい 。 \n ・ Web 投稿 \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / inquiry _ web \n\u3000 （ カテゴリ ： other   >   CCOC 系 統合 端末 ）'},
#  {'id': '100994',
#   'title': '',
#   'text': '画面 下部 に ある 「 OneNote   と 共 に 起動 」 の チェック を 外し て 、 「 終了 」 を クリック し て 下さい 。'},
#  {'id': '100995',
#   'title': '',
#   'text': '総務部 配備 以外 の プリンタ を 利用 する 場合 は 、 Admin 権限 を 取得 し た 上 で ドライバー インストール が 必要 と なり ます 。 \n\n ・ 【 社内外 共通 】 L 2 OAPC / 準 OAPC   Admin 権限 申請 ・ 適用 方法 \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / admintekiyou _ shanaigai \n\n なお 、 総務部 配備 以外 の プリンタ 設定 方法 に つい て は 、 OA サポート 外 と なり ます の で 、 プリンタ の メーカー に 直接 お 問合せ 下さい 。'},
#  {'id': '100996',
#   'title': '',
#   'text': 'OA 共有 アカウント は 原則 禁止 と なっ て おり 、 大型 モニタ で の 情報 共有 等 限ら れ た 用途 のみ 発行 可能 です 。 \n 発行 が 必要 な 場合 は 、 下記 より 相談 下さい 。 \n ・ ISC 相談 ガイド \n  https : / / sites . google . com / g . softbank .co.jp / sp - usersguide / isc _ form \n\n ISC の 承認 完了 後 、 以下 必要 事項 を 揃え た 上 で OA   Support   Net より 投稿 下さい 。 \n ・ OA   Support   Net \n  http:// oa . bb . local / oasupport / inquiry _ web \n\u3000 （ カテゴリ ： OA アカウント ） \n 【 必要 事項 】 \n ・ ISC 相談 番号 \n ・ 相談者（ユーザー） \n ・ ISC 相談 時 の 内容 の 画面 キャプチャ （ システム の 画面 キャプチャ 等 ）'},
#  {'id': '100997',
#   'title': '',
#   'text': 'ARK の 問合せ に つい て は 、 OA サポート デスク で は サポート 対象外 と なり ます 。 \n 下記 ページ を 参照 し て 下さい 。 \n\n ・ ARK / Chronos - Core   Portal \n  http:// ark - chronos . bb . local / Docs / # /'},
#  {'id': '100998',
#   'title': '',
#   'text': 'Cisco   VPN 接続 時 、 「 Untrusted   VPN   Server   Blocked ！ 」 が 表示 さ れ た 場合 は ウイルス ファイル の 更新 を 行っ て 下さい 。 \n\n  1 . タスクバー に ある ▲ を クリック し 、 Symantec   Endpoint   Protection （ SEP ） の アイコン （ 黄色 の 盾 の よう な アイコン ） を 右 クリック で 開き 、 「 Symantec   Endpoint   Protection を 開く 」 を 選択 する 。 \n  2 . 「 この アプリ が デバイス に 変更 を 加える こと を 許可 し ます か ？ 」 の メッセージ が 表示 さ れ たら 、 自身 の OA アカウント の パスワード を 入力 し 、 「 はい 」 を クリック し ます 。 \n  3 . LiveUpdate ... を クリック する \n  4 . LiveUpdate 完了 後 画面 を 閉じ 、 再度 、 タスクバー から SEP アイコン を 右 クリック で 開き 、 「 ポリシー の 更新 」 を クリック する'},
#  {'id': '100999',
#   'title': '',
#   'text': '業 端 B も 業 端 A と 同様 に MDM ・ Gmail ・ VPN を 使用 する こと が でき ます 。 \n 業 端 A と 同等 の セキュリティ 要件 を 満たす もの に 限り ます 。 \n 但し 申請 や 予算 の 確保 が 必要 に なる もの が ござい ます 、 必要 に 応じ て 下記 ページ を 参照 し 、 対応 下さい 。 \n\n ・ 業務用 携帯 電話 B で 社内 システム ( Gmail ・ Slack ) を 利用 する 場合 \n  http:// oa . bb . local / curator _ web / oasupport / ? jumpurl = http:// oa . bb . local / oasupport / keitai / keitai - a / rule / keitai / keitai - b'},
#  ...]

# %%
SPLIT_DATA_DIR = "/home/jinho/FlagEmbedding_Aizip/dataset/sudachi_split_b/sb_qna"

# %%
with open(f"{SPLIT_DATA_DIR}/test_queries.jsonl", "w") as f:
    for record in split_queries_l:
        f.write(json.dumps(record) + '\n')

# %%
with open(f"{SPLIT_DATA_DIR}/corpus.jsonl", "w") as f:
    for record in split_corpus_l:
        f.write(json.dumps(record) + '\n')

# %%
with open(f"{SPLIT_DATA_DIR}/test_qrels.jsonl", "w") as f:
    for record in qrels_l:
        f.write(json.dumps(record) + '\n')
